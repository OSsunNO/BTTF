# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(0)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 0
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTh1.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                       HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# date
# 2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (17420, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 01:00:00',
#                '2016-07-01 02:00:00', '2016-07-01 03:00:00',
#                '2016-07-01 04:00:00', '2016-07-01 05:00:00',
#                '2016-07-01 06:00:00', '2016-07-01 07:00:00',
#                '2016-07-01 08:00:00', '2016-07-01 09:00:00',
#                ...
#                '2018-06-26 10:00:00', '2018-06-26 11:00:00',
#                '2018-06-26 12:00:00', '2018-06-26 13:00:00',
#                '2018-06-26 14:00:00', '2018-06-26 15:00:00',
#                '2018-06-26 16:00:00', '2018-06-26 17:00:00',
#                '2018-06-26 18:00:00', '2018-06-26 19:00:00'],
#               dtype='datetime64[ns]', name='date', length=17420, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %%
set_seed(24)

# %% [markdown]
# # Model Modification for Linear (Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model(nn.Module):
    """
    Linear model with prediction-based augmentation (attach_pv)
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.channels = configs.enc_in

        
        self.attach_pv = getattr(configs, "attach_pv", False)

        
        self.extra_len = self.pred_len // 3

        
        self.seq_len_aug = self.seq_len + (self.extra_len if self.attach_pv else 0)

        self.individual = configs.individual

        
        if self.individual:
            self.Linear = nn.ModuleList()
            for i in range(self.channels):
                self.Linear.append(nn.Linear(self.seq_len_aug, self.pred_len))
        else:
            self.Linear = nn.Linear(self.seq_len_aug, self.pred_len)


    def forward(self, x, ground_truth=None):
        """
        x: [B, L, C]
        ground_truth: [B, L_gt, C] or None
        """
        B, L, C = x.size()

        
        
        
        if self.attach_pv and (ground_truth is not None):
            
            gt_part = ground_truth[:, :self.extra_len, :]  

            
            x = torch.cat([x, gt_part], dim=1)

        
        
        
        if self.individual:
            out = torch.zeros([B, self.pred_len, C], dtype=x.dtype).to(x.device)
            for i in range(C):
                out[:, :, i] = self.Linear[i](x[:, :, i])
            return out

        else:
            
            out = self.Linear(x.permute(0, 2, 1))
            return out.permute(0, 2, 1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset

target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 96


border1s = [0, 12 * 30 * 24 - seq_len, 12 * 30 * 24 + 4 * 30 * 24 - seq_len]
border2s = [12 * 30 * 24, 12 * 30 * 24 + 4 * 30 * 24, 12 * 30 * 24 + 8 * 30 * 24]

train = target[border1s[0]:border2s[0]]
val = target[border1s[1]:border2s[1]]
test = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val = scaler.transform(val)
test = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data = create_inout_sequences_univariate(val, seq_len, pred_len)
test_data = create_inout_sequences_univariate(test, seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels = torch.tensor([x[1] for x in test_data]).float().to(device)



print("Train Sequences:", train_sequences.shape)
print("Train Labels:", train_labels.shape)
print("Val Sequences:", val_sequences.shape)
print("Val Labels:", val_labels.shape)
print("Test Sequences:", test_sequences.shape)
print("Test Labels:", test_labels.shape)
# Out:
# Train Sequences: torch.Size([8209, 336, 1])
# Train Labels: torch.Size([8209, 96, 1])
# Val Sequences: torch.Size([2785, 336, 1])
# Val Labels: torch.Size([2785, 96, 1])
# Test Sequences: torch.Size([2785, 336, 1])
# Test Labels: torch.Size([2785, 96, 1])

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 96  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.1916117731061427 | Val Loss: 0.101191550726071
# Validation loss decreased (inf --> 0.101192).  Saving model ...
# Updating learning rate to 0.0005
# Epoch 1 | Train Loss: 0.1527918045216961 | Val Loss: 0.09630104816857386
# Validation loss decreased (0.101192 --> 0.096301).  Saving model ...
# Updating learning rate to 0.00025
# Epoch 2 | Train Loss: 0.14915582421688717 | Val Loss: 0.0948566174430942
# Validation loss decreased (0.096301 --> 0.094857).  Saving model ...
# Updating learning rate to 0.000125
# Epoch 3 | Train Loss: 0.1481454655354125 | Val Loss: 0.09419938435100696
# Validation loss decreased (0.094857 --> 0.094199).  Saving model ...
# Updating learning rate to 6.25e-05
# Epoch 4 | Train Loss: 0.14624471872581118 | Val Loss: 0.09478794116611508
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# Epoch 5 | Train Loss: 0.146049126344896 | Val Loss: 0.0937818224245513
# Validation loss decreased (0.094199 --> 0.093782).  Saving model ...
# Updating learning rate to 1.5625e-05
# Epoch 6 | Train Loss: 0.14582710489920606 | Val Loss: 0.09399751887064088
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.8125e-06
# Epoch 7 | Train Loss: 0.1457834795755171 | Val Loss: 0.09389110356145962
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.90625e-06
# Epoch 8 | Train Loss: 0.14553567236615525 | Val Loss: 0.09401950066570532
# EarlyStopping counter: 3 out of 3
# Early stopping triggered. Stopping training.

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 96  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.19087395280715558 | Val Loss: 0.09922984750433402
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.05856027826666832 | MAE: 0.1833038479089737
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.08120271563529968 | MAE: 0.21791771054267883

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.09455299377441406 | MAE: 0.2400999367237091
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.10009056329727173 | MAE: 0.24764026701450348

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.14590580761432648 | MAE: 0.29154396057128906
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.15769320726394653 | MAE: 0.30397480726242065

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([8209, 336, 1])
# val_sequences shape:  torch.Size([2785, 336, 1])
# test_sequences shape:  torch.Size([2785, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([8209, 96, 1])
# val_pv shape:  torch.Size([2785, 96, 1])
# test_pv shape:  torch.Size([2785, 96, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([8209, 96, 1])
# val_labels shape:  torch.Size([2785, 96, 1])
# test_labels shape:  torch.Size([2785, 96, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 96

# %%
segment_len = configs.pred_len // 3
stride = 1  

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([8209, 65, 32, 1]), Val: torch.Size([2785, 65, 32, 1]), Test: torch.Size([2785, 65, 32, 1])
# [Epoch 1] Train seg shape: torch.Size([8209, 65, 32, 1]), Val: torch.Size([2785, 65, 32, 1]), Test: torch.Size([2785, 65, 32, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTh1'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 96,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = params = list(model.Linear[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 0] Training Time = 1.19 sec
# [Segment 0] GPU Memory Start = 371.37 MB
# [Segment 0] GPU Memory End   = 371.83 MB
# [Segment 0] GPU Peak Memory  = 372.94 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 1] Training Time = 0.57 sec
# [Segment 1] GPU Memory Start = 371.83 MB
# [Segment 1] GPU Memory End   = 371.96 MB
# [Segment 1] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 2] Training Time = 0.68 sec
# [Segment 2] GPU Memory Start = 371.96 MB
# [Segment 2] GPU Memory End   = 372.10 MB
# [Segment 2] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 3] Training Time = 0.84 sec
# [Segment 3] GPU Memory Start = 372.10 MB
# [Segment 3] GPU Memory End   = 372.23 MB
# [Segment 3] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 4] Training Time = 0.51 sec
# [Segment 4] GPU Memory Start = 372.23 MB
# [Segment 4] GPU Memory End   = 372.37 MB
# [Segment 4] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 5] Training Time = 1.08 sec
# [Segment 5] GPU Memory Start = 372.37 MB
# [Segment 5] GPU Memory End   = 372.50 MB
# [Segment 5] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 6] Training Time = 0.56 sec
# [Segment 6] GPU Memory Start = 372.50 MB
# [Segment 6] GPU Memory End   = 372.64 MB
# [Segment 6] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 7] Training Time = 0.56 sec
# [Segment 7] GPU Memory Start = 372.64 MB
# [Segment 7] GPU Memory End   = 372.77 MB
# [Segment 7] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 8] Training Time = 0.98 sec
# [Segment 8] GPU Memory Start = 372.77 MB
# [Segment 8] GPU Memory End   = 372.91 MB
# [Segment 8] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 9] Training Time = 0.54 sec
# [Segment 9] GPU Memory Start = 372.91 MB
# [Segment 9] GPU Memory End   = 371.83 MB
# [Segment 9] GPU Peak Memory  = 373.06 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 10] Training Time = 0.58 sec
# [Segment 10] GPU Memory Start = 371.83 MB
# [Segment 10] GPU Memory End   = 371.96 MB
# [Segment 10] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 11] Training Time = 0.56 sec
# [Segment 11] GPU Memory Start = 371.96 MB
# [Segment 11] GPU Memory End   = 372.10 MB
# [Segment 11] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 12] Training Time = 0.57 sec
# [Segment 12] GPU Memory Start = 372.10 MB
# [Segment 12] GPU Memory End   = 372.23 MB
# [Segment 12] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 13] Training Time = 0.56 sec
# [Segment 13] GPU Memory Start = 372.23 MB
# [Segment 13] GPU Memory End   = 372.37 MB
# [Segment 13] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 14] Training Time = 0.58 sec
# [Segment 14] GPU Memory Start = 372.37 MB
# [Segment 14] GPU Memory End   = 372.50 MB
# [Segment 14] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 15] Training Time = 0.58 sec
# [Segment 15] GPU Memory Start = 372.50 MB
# [Segment 15] GPU Memory End   = 372.64 MB
# [Segment 15] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 16] Training Time = 0.58 sec
# [Segment 16] GPU Memory Start = 372.64 MB
# [Segment 16] GPU Memory End   = 372.77 MB
# [Segment 16] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 17] Training Time = 0.57 sec
# [Segment 17] GPU Memory Start = 372.77 MB
# [Segment 17] GPU Memory End   = 372.91 MB
# [Segment 17] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 18] Training Time = 0.84 sec
# [Segment 18] GPU Memory Start = 372.91 MB
# [Segment 18] GPU Memory End   = 373.04 MB
# [Segment 18] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 19] Training Time = 0.76 sec
# [Segment 19] GPU Memory Start = 373.04 MB
# [Segment 19] GPU Memory End   = 371.83 MB
# [Segment 19] GPU Peak Memory  = 373.06 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 20] Training Time = 1.15 sec
# [Segment 20] GPU Memory Start = 371.83 MB
# [Segment 20] GPU Memory End   = 371.96 MB
# [Segment 20] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 21] Training Time = 1.07 sec
# [Segment 21] GPU Memory Start = 371.96 MB
# [Segment 21] GPU Memory End   = 372.10 MB
# [Segment 21] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 22] Training Time = 0.86 sec
# [Segment 22] GPU Memory Start = 372.10 MB
# [Segment 22] GPU Memory End   = 372.23 MB
# [Segment 22] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 23] Training Time = 0.84 sec
# [Segment 23] GPU Memory Start = 372.23 MB
# [Segment 23] GPU Memory End   = 372.37 MB
# [Segment 23] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 24] Training Time = 1.16 sec
# [Segment 24] GPU Memory Start = 372.37 MB
# [Segment 24] GPU Memory End   = 372.50 MB
# [Segment 24] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 25] Training Time = 0.57 sec
# [Segment 25] GPU Memory Start = 372.50 MB
# [Segment 25] GPU Memory End   = 372.64 MB
# [Segment 25] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 26] Training Time = 0.57 sec
# [Segment 26] GPU Memory Start = 372.64 MB
# [Segment 26] GPU Memory End   = 372.77 MB
# [Segment 26] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 27] Training Time = 0.57 sec
# [Segment 27] GPU Memory Start = 372.77 MB
# [Segment 27] GPU Memory End   = 372.91 MB
# [Segment 27] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 28] Training Time = 0.56 sec
# [Segment 28] GPU Memory Start = 372.91 MB
# [Segment 28] GPU Memory End   = 373.04 MB
# [Segment 28] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 29] Training Time = 0.56 sec
# [Segment 29] GPU Memory Start = 373.04 MB
# [Segment 29] GPU Memory End   = 371.83 MB
# [Segment 29] GPU Peak Memory  = 373.06 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 30] Training Time = 0.56 sec
# [Segment 30] GPU Memory Start = 371.83 MB
# [Segment 30] GPU Memory End   = 371.96 MB
# [Segment 30] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 31] Training Time = 0.58 sec
# [Segment 31] GPU Memory Start = 371.96 MB
# [Segment 31] GPU Memory End   = 372.10 MB
# [Segment 31] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 32] Training Time = 0.58 sec
# [Segment 32] GPU Memory Start = 372.10 MB
# [Segment 32] GPU Memory End   = 372.23 MB
# [Segment 32] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 33] Training Time = 0.57 sec
# [Segment 33] GPU Memory Start = 372.23 MB
# [Segment 33] GPU Memory End   = 372.37 MB
# [Segment 33] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 34] Training Time = 0.57 sec
# [Segment 34] GPU Memory Start = 372.37 MB
# [Segment 34] GPU Memory End   = 372.50 MB
# [Segment 34] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 35] Training Time = 0.58 sec
# [Segment 35] GPU Memory Start = 372.50 MB
# [Segment 35] GPU Memory End   = 372.64 MB
# [Segment 35] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 36] Training Time = 0.57 sec
# [Segment 36] GPU Memory Start = 372.64 MB
# [Segment 36] GPU Memory End   = 372.77 MB
# [Segment 36] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 37] Training Time = 1.03 sec
# [Segment 37] GPU Memory Start = 372.77 MB
# [Segment 37] GPU Memory End   = 372.91 MB
# [Segment 37] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 38] Training Time = 1.12 sec
# [Segment 38] GPU Memory Start = 372.91 MB
# [Segment 38] GPU Memory End   = 373.04 MB
# [Segment 38] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 39] Training Time = 0.74 sec
# [Segment 39] GPU Memory Start = 373.04 MB
# [Segment 39] GPU Memory End   = 371.83 MB
# [Segment 39] GPU Peak Memory  = 373.06 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 40] Training Time = 0.59 sec
# [Segment 40] GPU Memory Start = 371.83 MB
# [Segment 40] GPU Memory End   = 371.96 MB
# [Segment 40] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 41] Training Time = 0.58 sec
# [Segment 41] GPU Memory Start = 371.96 MB
# [Segment 41] GPU Memory End   = 372.10 MB
# [Segment 41] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 42] Training Time = 0.58 sec
# [Segment 42] GPU Memory Start = 372.10 MB
# [Segment 42] GPU Memory End   = 372.23 MB
# [Segment 42] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 43] Training Time = 0.59 sec
# [Segment 43] GPU Memory Start = 372.23 MB
# [Segment 43] GPU Memory End   = 372.37 MB
# [Segment 43] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 44] Training Time = 0.58 sec
# [Segment 44] GPU Memory Start = 372.37 MB
# [Segment 44] GPU Memory End   = 372.50 MB
# [Segment 44] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 45] Training Time = 1.11 sec
# [Segment 45] GPU Memory Start = 372.50 MB
# [Segment 45] GPU Memory End   = 372.64 MB
# [Segment 45] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 46] Training Time = 1.16 sec
# [Segment 46] GPU Memory Start = 372.64 MB
# [Segment 46] GPU Memory End   = 372.77 MB
# [Segment 46] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 47] Training Time = 1.01 sec
# [Segment 47] GPU Memory Start = 372.77 MB
# [Segment 47] GPU Memory End   = 372.91 MB
# [Segment 47] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 48] Training Time = 0.58 sec
# [Segment 48] GPU Memory Start = 372.91 MB
# [Segment 48] GPU Memory End   = 373.04 MB
# [Segment 48] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 49] Training Time = 0.59 sec
# [Segment 49] GPU Memory Start = 373.04 MB
# [Segment 49] GPU Memory End   = 371.83 MB
# [Segment 49] GPU Peak Memory  = 373.06 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 50] Training Time = 0.58 sec
# [Segment 50] GPU Memory Start = 371.83 MB
# [Segment 50] GPU Memory End   = 371.96 MB
# [Segment 50] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 51] Training Time = 0.58 sec
# [Segment 51] GPU Memory Start = 371.96 MB
# [Segment 51] GPU Memory End   = 372.10 MB
# [Segment 51] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 52] Training Time = 1.10 sec
# [Segment 52] GPU Memory Start = 372.10 MB
# [Segment 52] GPU Memory End   = 372.23 MB
# [Segment 52] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 53] Training Time = 1.16 sec
# [Segment 53] GPU Memory Start = 372.23 MB
# [Segment 53] GPU Memory End   = 372.37 MB
# [Segment 53] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 54] Training Time = 0.82 sec
# [Segment 54] GPU Memory Start = 372.37 MB
# [Segment 54] GPU Memory End   = 372.50 MB
# [Segment 54] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 55] Training Time = 0.96 sec
# [Segment 55] GPU Memory Start = 372.50 MB
# [Segment 55] GPU Memory End   = 372.64 MB
# [Segment 55] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 56] Training Time = 0.58 sec
# [Segment 56] GPU Memory Start = 372.64 MB
# [Segment 56] GPU Memory End   = 372.77 MB
# [Segment 56] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 57] Training Time = 0.58 sec
# [Segment 57] GPU Memory Start = 372.77 MB
# [Segment 57] GPU Memory End   = 372.91 MB
# [Segment 57] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 58] Training Time = 0.94 sec
# [Segment 58] GPU Memory Start = 372.91 MB
# [Segment 58] GPU Memory End   = 373.04 MB
# [Segment 58] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 59] Training Time = 1.07 sec
# [Segment 59] GPU Memory Start = 373.04 MB
# [Segment 59] GPU Memory End   = 371.83 MB
# [Segment 59] GPU Peak Memory  = 373.06 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 60] Training Time = 0.59 sec
# [Segment 60] GPU Memory Start = 371.83 MB
# [Segment 60] GPU Memory End   = 371.96 MB
# [Segment 60] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 61] Training Time = 0.58 sec
# [Segment 61] GPU Memory Start = 371.96 MB
# [Segment 61] GPU Memory End   = 372.10 MB
# [Segment 61] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 62] Training Time = 0.82 sec
# [Segment 62] GPU Memory Start = 372.10 MB
# [Segment 62] GPU Memory End   = 372.23 MB
# [Segment 62] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 63] Training Time = 0.58 sec
# [Segment 63] GPU Memory Start = 372.23 MB
# [Segment 63] GPU Memory End   = 372.37 MB
# [Segment 63] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 64] Training Time = 0.56 sec
# [Segment 64] GPU Memory Start = 372.37 MB
# [Segment 64] GPU Memory End   = 372.50 MB
# [Segment 64] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 96,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E/",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters())

        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 0] Training Time = 1.21 sec
# [Segment 0] GPU Memory Start = 371.83 MB
# [Segment 0] GPU Memory End   = 371.83 MB
# [Segment 0] GPU Peak Memory  = 373.06 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 1] Training Time = 0.57 sec
# [Segment 1] GPU Memory Start = 371.83 MB
# [Segment 1] GPU Memory End   = 371.96 MB
# [Segment 1] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 2] Training Time = 0.57 sec
# [Segment 2] GPU Memory Start = 371.96 MB
# [Segment 2] GPU Memory End   = 372.10 MB
# [Segment 2] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 3] Training Time = 0.57 sec
# [Segment 3] GPU Memory Start = 372.10 MB
# [Segment 3] GPU Memory End   = 372.23 MB
# [Segment 3] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 4] Training Time = 0.57 sec
# [Segment 4] GPU Memory Start = 372.23 MB
# [Segment 4] GPU Memory End   = 372.37 MB
# [Segment 4] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 5] Training Time = 1.06 sec
# [Segment 5] GPU Memory Start = 372.37 MB
# [Segment 5] GPU Memory End   = 372.50 MB
# [Segment 5] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 6] Training Time = 0.92 sec
# [Segment 6] GPU Memory Start = 371.83 MB
# [Segment 6] GPU Memory End   = 371.96 MB
# [Segment 6] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 7] Training Time = 0.58 sec
# [Segment 7] GPU Memory Start = 371.96 MB
# [Segment 7] GPU Memory End   = 372.10 MB
# [Segment 7] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 8] Training Time = 1.06 sec
# [Segment 8] GPU Memory Start = 372.10 MB
# [Segment 8] GPU Memory End   = 372.23 MB
# [Segment 8] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 9] Training Time = 1.16 sec
# [Segment 9] GPU Memory Start = 372.23 MB
# [Segment 9] GPU Memory End   = 372.37 MB
# [Segment 9] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 10] Training Time = 0.57 sec
# [Segment 10] GPU Memory Start = 372.37 MB
# [Segment 10] GPU Memory End   = 372.50 MB
# [Segment 10] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 11] Training Time = 0.56 sec
# [Segment 11] GPU Memory Start = 372.50 MB
# [Segment 11] GPU Memory End   = 372.64 MB
# [Segment 11] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 12] Training Time = 1.14 sec
# [Segment 12] GPU Memory Start = 372.64 MB
# [Segment 12] GPU Memory End   = 372.77 MB
# [Segment 12] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 13] Training Time = 0.57 sec
# [Segment 13] GPU Memory Start = 372.77 MB
# [Segment 13] GPU Memory End   = 372.91 MB
# [Segment 13] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 14] Training Time = 0.81 sec
# [Segment 14] GPU Memory Start = 372.91 MB
# [Segment 14] GPU Memory End   = 373.04 MB
# [Segment 14] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 15] Training Time = 0.86 sec
# [Segment 15] GPU Memory Start = 373.04 MB
# [Segment 15] GPU Memory End   = 373.18 MB
# [Segment 15] GPU Peak Memory  = 374.30 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 16] Training Time = 0.56 sec
# [Segment 16] GPU Memory Start = 371.83 MB
# [Segment 16] GPU Memory End   = 371.96 MB
# [Segment 16] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 17] Training Time = 0.57 sec
# [Segment 17] GPU Memory Start = 371.96 MB
# [Segment 17] GPU Memory End   = 372.10 MB
# [Segment 17] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 18] Training Time = 0.57 sec
# [Segment 18] GPU Memory Start = 372.10 MB
# [Segment 18] GPU Memory End   = 372.23 MB
# [Segment 18] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 19] Training Time = 0.56 sec
# [Segment 19] GPU Memory Start = 372.23 MB
# [Segment 19] GPU Memory End   = 372.37 MB
# [Segment 19] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 20] Training Time = 0.87 sec
# [Segment 20] GPU Memory Start = 372.37 MB
# [Segment 20] GPU Memory End   = 372.50 MB
# [Segment 20] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 21] Training Time = 0.62 sec
# [Segment 21] GPU Memory Start = 372.50 MB
# [Segment 21] GPU Memory End   = 372.64 MB
# [Segment 21] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 22] Training Time = 0.57 sec
# [Segment 22] GPU Memory Start = 372.64 MB
# [Segment 22] GPU Memory End   = 372.77 MB
# [Segment 22] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 23] Training Time = 0.57 sec
# [Segment 23] GPU Memory Start = 372.77 MB
# [Segment 23] GPU Memory End   = 372.91 MB
# [Segment 23] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 24] Training Time = 0.57 sec
# [Segment 24] GPU Memory Start = 372.91 MB
# [Segment 24] GPU Memory End   = 373.04 MB
# [Segment 24] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 25] Training Time = 0.57 sec
# [Segment 25] GPU Memory Start = 373.04 MB
# [Segment 25] GPU Memory End   = 373.18 MB
# [Segment 25] GPU Peak Memory  = 374.30 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 26] Training Time = 0.57 sec
# [Segment 26] GPU Memory Start = 371.83 MB
# [Segment 26] GPU Memory End   = 371.96 MB
# [Segment 26] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 27] Training Time = 0.57 sec
# [Segment 27] GPU Memory Start = 371.96 MB
# [Segment 27] GPU Memory End   = 372.10 MB
# [Segment 27] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 28] Training Time = 0.56 sec
# [Segment 28] GPU Memory Start = 372.10 MB
# [Segment 28] GPU Memory End   = 372.23 MB
# [Segment 28] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 29] Training Time = 0.56 sec
# [Segment 29] GPU Memory Start = 372.23 MB
# [Segment 29] GPU Memory End   = 372.37 MB
# [Segment 29] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 30] Training Time = 0.56 sec
# [Segment 30] GPU Memory Start = 372.37 MB
# [Segment 30] GPU Memory End   = 372.50 MB
# [Segment 30] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 31] Training Time = 0.57 sec
# [Segment 31] GPU Memory Start = 372.50 MB
# [Segment 31] GPU Memory End   = 372.64 MB
# [Segment 31] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 32] Training Time = 1.03 sec
# [Segment 32] GPU Memory Start = 372.64 MB
# [Segment 32] GPU Memory End   = 372.77 MB
# [Segment 32] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 33] Training Time = 0.57 sec
# [Segment 33] GPU Memory Start = 372.77 MB
# [Segment 33] GPU Memory End   = 372.91 MB
# [Segment 33] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 34] Training Time = 0.56 sec
# [Segment 34] GPU Memory Start = 372.91 MB
# [Segment 34] GPU Memory End   = 373.04 MB
# [Segment 34] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 35] Training Time = 0.58 sec
# [Segment 35] GPU Memory Start = 373.04 MB
# [Segment 35] GPU Memory End   = 373.18 MB
# [Segment 35] GPU Peak Memory  = 374.30 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 36] Training Time = 0.57 sec
# [Segment 36] GPU Memory Start = 371.83 MB
# [Segment 36] GPU Memory End   = 371.96 MB
# [Segment 36] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 37] Training Time = 0.57 sec
# [Segment 37] GPU Memory Start = 371.96 MB
# [Segment 37] GPU Memory End   = 372.10 MB
# [Segment 37] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 38] Training Time = 0.55 sec
# [Segment 38] GPU Memory Start = 372.10 MB
# [Segment 38] GPU Memory End   = 372.23 MB
# [Segment 38] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 39] Training Time = 0.57 sec
# [Segment 39] GPU Memory Start = 372.23 MB
# [Segment 39] GPU Memory End   = 372.37 MB
# [Segment 39] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 40] Training Time = 0.56 sec
# [Segment 40] GPU Memory Start = 372.37 MB
# [Segment 40] GPU Memory End   = 372.50 MB
# [Segment 40] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 41] Training Time = 0.57 sec
# [Segment 41] GPU Memory Start = 372.50 MB
# [Segment 41] GPU Memory End   = 372.64 MB
# [Segment 41] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 42] Training Time = 0.57 sec
# [Segment 42] GPU Memory Start = 372.64 MB
# [Segment 42] GPU Memory End   = 372.77 MB
# [Segment 42] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 43] Training Time = 0.57 sec
# [Segment 43] GPU Memory Start = 372.77 MB
# [Segment 43] GPU Memory End   = 372.91 MB
# [Segment 43] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 44] Training Time = 0.57 sec
# [Segment 44] GPU Memory Start = 372.91 MB
# [Segment 44] GPU Memory End   = 373.04 MB
# [Segment 44] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 45] Training Time = 0.57 sec
# [Segment 45] GPU Memory Start = 373.04 MB
# [Segment 45] GPU Memory End   = 373.18 MB
# [Segment 45] GPU Peak Memory  = 374.30 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 46] Training Time = 0.57 sec
# [Segment 46] GPU Memory Start = 371.83 MB
# [Segment 46] GPU Memory End   = 371.96 MB
# [Segment 46] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 47] Training Time = 0.57 sec
# [Segment 47] GPU Memory Start = 371.96 MB
# [Segment 47] GPU Memory End   = 372.10 MB
# [Segment 47] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 48] Training Time = 0.57 sec
# [Segment 48] GPU Memory Start = 372.10 MB
# [Segment 48] GPU Memory End   = 372.23 MB
# [Segment 48] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 49] Training Time = 0.56 sec
# [Segment 49] GPU Memory Start = 372.23 MB
# [Segment 49] GPU Memory End   = 372.37 MB
# [Segment 49] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 50] Training Time = 0.89 sec
# [Segment 50] GPU Memory Start = 372.37 MB
# [Segment 50] GPU Memory End   = 372.50 MB
# [Segment 50] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 51] Training Time = 0.57 sec
# [Segment 51] GPU Memory Start = 372.50 MB
# [Segment 51] GPU Memory End   = 372.64 MB
# [Segment 51] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 52] Training Time = 0.56 sec
# [Segment 52] GPU Memory Start = 372.64 MB
# [Segment 52] GPU Memory End   = 372.77 MB
# [Segment 52] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 53] Training Time = 1.07 sec
# [Segment 53] GPU Memory Start = 372.77 MB
# [Segment 53] GPU Memory End   = 372.91 MB
# [Segment 53] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 54] Training Time = 0.57 sec
# [Segment 54] GPU Memory Start = 372.91 MB
# [Segment 54] GPU Memory End   = 373.04 MB
# [Segment 54] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 55] Training Time = 0.57 sec
# [Segment 55] GPU Memory Start = 373.04 MB
# [Segment 55] GPU Memory End   = 371.83 MB
# [Segment 55] GPU Peak Memory  = 373.18 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 56] Training Time = 0.58 sec
# [Segment 56] GPU Memory Start = 371.83 MB
# [Segment 56] GPU Memory End   = 371.96 MB
# [Segment 56] GPU Peak Memory  = 373.08 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 57] Training Time = 0.59 sec
# [Segment 57] GPU Memory Start = 371.96 MB
# [Segment 57] GPU Memory End   = 372.10 MB
# [Segment 57] GPU Peak Memory  = 373.21 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 58] Training Time = 0.57 sec
# [Segment 58] GPU Memory Start = 372.10 MB
# [Segment 58] GPU Memory End   = 372.23 MB
# [Segment 58] GPU Peak Memory  = 373.35 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 59] Training Time = 0.57 sec
# [Segment 59] GPU Memory Start = 372.23 MB
# [Segment 59] GPU Memory End   = 372.37 MB
# [Segment 59] GPU Peak Memory  = 373.49 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 60] Training Time = 0.57 sec
# [Segment 60] GPU Memory Start = 372.37 MB
# [Segment 60] GPU Memory End   = 372.50 MB
# [Segment 60] GPU Peak Memory  = 373.62 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 61] Training Time = 0.87 sec
# [Segment 61] GPU Memory Start = 372.50 MB
# [Segment 61] GPU Memory End   = 372.64 MB
# [Segment 61] GPU Peak Memory  = 373.76 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 62] Training Time = 0.86 sec
# [Segment 62] GPU Memory Start = 372.64 MB
# [Segment 62] GPU Memory End   = 372.77 MB
# [Segment 62] GPU Peak Memory  = 373.89 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 63] Training Time = 1.14 sec
# [Segment 63] GPU Memory Start = 372.77 MB
# [Segment 63] GPU Memory End   = 372.91 MB
# [Segment 63] GPU Peak Memory  = 374.03 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.5410 MB
#   yb per batch = 0.0117 MB, total = 3.0117 MB
#   pv per batch = 0.0039 MB, total = 1.0039 MB
# [Segment 64] Training Time = 0.70 sec
# [Segment 64] GPU Memory Start = 372.91 MB
# [Segment 64] GPU Memory End   = 373.04 MB
# [Segment 64] GPU Peak Memory  = 374.16 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 96,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTh1_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.10381829738616943  MAE:0.2516549825668335
# ▶ seg0  mean  MSE:0.10381829738616943  MAE:0.2516549825668335
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.10438048094511032  MAE:0.25203612446784973
# ▶ seg1  mean  MSE:0.10438048094511032  MAE:0.25203612446784973
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.09759604930877686  MAE:0.24507412314414978
# ▶ seg2  mean  MSE:0.09759604930877686  MAE:0.24507412314414978
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.09449206292629242  MAE:0.2408144772052765
# ▶ seg3  mean  MSE:0.09449206292629242  MAE:0.2408144772052765
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.10030429810285568  MAE:0.24775387346744537
# ▶ seg4  mean  MSE:0.10030429810285568  MAE:0.24775387346744537
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.10140151530504227  MAE:0.24832884967327118
# ▶ seg5  mean  MSE:0.10140151530504227  MAE:0.24832884967327118
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.13753138482570648  MAE:0.289543479681015
# ▶ seg6  mean  MSE:0.13753138482570648  MAE:0.289543479681015
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.09775567054748535  MAE:0.24784575402736664
# ▶ seg7  mean  MSE:0.09775567054748535  MAE:0.24784575402736664
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.11660349369049072  MAE:0.27007347345352173
# ▶ seg8  mean  MSE:0.11660349369049072  MAE:0.27007347345352173
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.1044371947646141  MAE:0.2507481575012207
# ▶ seg9  mean  MSE:0.1044371947646141  MAE:0.2507481575012207
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.10095599293708801  MAE:0.25152555108070374
# ▶ seg10  mean  MSE:0.10095599293708801  MAE:0.25152555108070374
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.09776220470666885  MAE:0.24429361522197723
# ▶ seg11  mean  MSE:0.09776220470666885  MAE:0.24429361522197723
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.10077425837516785  MAE:0.2504308521747589
# ▶ seg12  mean  MSE:0.10077425837516785  MAE:0.2504308521747589
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.10138337314128876  MAE:0.246940016746521
# ▶ seg13  mean  MSE:0.10138337314128876  MAE:0.246940016746521
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.09867963939905167  MAE:0.2479303777217865
# ▶ seg14  mean  MSE:0.09867963939905167  MAE:0.2479303777217865
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.10168328136205673  MAE:0.2513585388660431
# ▶ seg15  mean  MSE:0.10168328136205673  MAE:0.2513585388660431
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.1182599887251854  MAE:0.2665926218032837
# ▶ seg16  mean  MSE:0.1182599887251854  MAE:0.2665926218032837
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.10315071046352386  MAE:0.25385358929634094
# ▶ seg17  mean  MSE:0.10315071046352386  MAE:0.25385358929634094
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.097228042781353  MAE:0.2445601224899292
# ▶ seg18  mean  MSE:0.097228042781353  MAE:0.2445601224899292
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.10050908476114273  MAE:0.24809105694293976
# ▶ seg19  mean  MSE:0.10050908476114273  MAE:0.24809105694293976
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.10526319593191147  MAE:0.25315654277801514
# ▶ seg45  mean  MSE:0.10526319593191147  MAE:0.25315654277801514
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.09736932814121246  MAE:0.2440512776374817
# ▶ seg46  mean  MSE:0.09736932814121246  MAE:0.2440512776374817
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.09776230156421661  MAE:0.24372461438179016
# ▶ seg47  mean  MSE:0.09776230156421661  MAE:0.24372461438179016
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.0970546081662178  MAE:0.24586988985538483
# ▶ seg48  mean  MSE:0.0970546081662178  MAE:0.24586988985538483
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.09829041361808777  MAE:0.24733570218086243
# ▶ seg49  mean  MSE:0.09829041361808777  MAE:0.24733570218086243
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.0956847295165062  MAE:0.24337519705295563
# ▶ seg50  mean  MSE:0.0956847295165062  MAE:0.24337519705295563
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.09504919499158859  MAE:0.24124757945537567
# ▶ seg51  mean  MSE:0.09504919499158859  MAE:0.24124757945537567
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.1126672551035881  MAE:0.26180142164230347
# ▶ seg52  mean  MSE:0.1126672551035881  MAE:0.26180142164230347
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.10188370943069458  MAE:0.249375581741333
# ▶ seg53  mean  MSE:0.10188370943069458  MAE:0.249375581741333
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.11303969472646713  MAE:0.262674480676651
# ▶ seg54  mean  MSE:0.11303969472646713  MAE:0.262674480676651
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.09491275995969772  MAE:0.24339517951011658
# ▶ seg55  mean  MSE:0.09491275995969772  MAE:0.24339517951011658
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.10047071427106857  MAE:0.25051242113113403
# ▶ seg56  mean  MSE:0.10047071427106857  MAE:0.25051242113113403
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.11621122062206268  MAE:0.26655805110931396
# ▶ seg57  mean  MSE:0.11621122062206268  MAE:0.26655805110931396
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.09903103113174438  MAE:0.24568048119544983
# ▶ seg58  mean  MSE:0.09903103113174438  MAE:0.24568048119544983
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.10674815624952316  MAE:0.2577241361141205
# ▶ seg59  mean  MSE:0.10674815624952316  MAE:0.2577241361141205
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.09769577533006668  MAE:0.24605295062065125
# ▶ seg60  mean  MSE:0.09769577533006668  MAE:0.24605295062065125
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.10264333337545395  MAE:0.24965393543243408
# ▶ seg61  mean  MSE:0.10264333337545395  MAE:0.24965393543243408
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.09691926091909409  MAE:0.24353565275669098
# ▶ seg62  mean  MSE:0.09691926091909409  MAE:0.24353565275669098
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.09940417110919952  MAE:0.24455858767032623
# ▶ seg63  mean  MSE:0.09940417110919952  MAE:0.24455858767032623
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.0964348092675209  MAE:0.24395741522312164
# ▶ seg64  mean  MSE:0.0964348092675209  MAE:0.24395741522312164
#
# seg10 ch0 MSE : 0.10095599

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 96,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_E1_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTh1_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.09928730875253677  MAE:0.24971985816955566
# ▶ seg0  mean  MSE:0.09928730875253677  MAE:0.24971985816955566
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.09807056933641434  MAE:0.2474038153886795
# ▶ seg52  mean  MSE:0.09807056933641434  MAE:0.2474038153886795
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.1054546982049942  MAE:0.2545875310897827
# ▶ seg53  mean  MSE:0.1054546982049942  MAE:0.2545875310897827
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.09815139323472977  MAE:0.24733935296535492
# ▶ seg54  mean  MSE:0.09815139323472977  MAE:0.24733935296535492
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.10161449760198593  MAE:0.2518799304962158
# ▶ seg55  mean  MSE:0.10161449760198593  MAE:0.2518799304962158
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.09810318052768707  MAE:0.24713921546936035
# ▶ seg56  mean  MSE:0.09810318052768707  MAE:0.24713921546936035
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.0981869101524353  MAE:0.2454630434513092
# ▶ seg57  mean  MSE:0.0981869101524353  MAE:0.2454630434513092
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.10995323210954666  MAE:0.261482834815979
# ▶ seg58  mean  MSE:0.10995323210954666  MAE:0.261482834815979
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.09818277508020401  MAE:0.24561432003974915
# ▶ seg59  mean  MSE:0.09818277508020401  MAE:0.24561432003974915
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.09787973761558533  MAE:0.24472013115882874
# ▶ seg60  mean  MSE:0.09787973761558533  MAE:0.24472013115882874
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.10424390435218811  MAE:0.2517348527908325
# ▶ seg61  mean  MSE:0.10424390435218811  MAE:0.2517348527908325
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.1052563488483429  MAE:0.2560482621192932
# ▶ seg62  mean  MSE:0.1052563488483429  MAE:0.2560482621192932
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.11304863542318344  MAE:0.2643321752548218
# ▶ seg63  mean  MSE:0.11304863542318344  MAE:0.2643321752548218
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.10601826012134552  MAE:0.2544995844364166
# ▶ seg64  mean  MSE:0.10601826012134552  MAE:0.2544995844364166
#
# seg10 ch0 MSE : 0.12976716

# %% [markdown]
# # 2nd Inference for Test Set

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 96
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 96,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTh1_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.14195287227630615  MAE:0.2978186011314392
# ▶ seg0  mean  MSE:0.14195287227630615  MAE:0.2978186011314392
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.14486469328403473  MAE:0.29843270778656006
# ▶ seg1  mean  MSE:0.14486469328403473  MAE:0.29843270778656006
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.09483429789543152  MAE:0.24323716759681702
# ▶ seg2  mean  MSE:0.09483429789543152  MAE:0.24323716759681702
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.06989181041717529  MAE:0.20665913820266724
# ▶ seg3  mean  MSE:0.06989181041717529  MAE:0.20665913820266724
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.09428710490465164  MAE:0.240915909409523
# ▶ seg4  mean  MSE:0.09428710490465164  MAE:0.240915909409523
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.11289463192224503  MAE:0.2588939070701599
# ▶ seg5  mean  MSE:0.11289463192224503  MAE:0.2588939070701599
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.4598785936832428  MAE:0.5491227507591248
# ▶ seg6  mean  MSE:0.4598785936832428  MAE:0.5491227507591248
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.11165285110473633  MAE:0.2578921914100647
# ▶ seg58  mean  MSE:0.11165285110473633  MAE:0.2578921914100647
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.18433724343776703  MAE:0.34292179346084595
# ▶ seg59  mean  MSE:0.18433724343776703  MAE:0.34292179346084595
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.08600819855928421  MAE:0.2340346723794937
# ▶ seg60  mean  MSE:0.08600819855928421  MAE:0.2340346723794937
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.14004798233509064  MAE:0.296214759349823
# ▶ seg61  mean  MSE:0.14004798233509064  MAE:0.296214759349823
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.06925630569458008  MAE:0.20400603115558624
# ▶ seg62  mean  MSE:0.06925630569458008  MAE:0.20400603115558624
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.08556423336267471  MAE:0.22677089273929596
# ▶ seg63  mean  MSE:0.08556423336267471  MAE:0.22677089273929596
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.07691588252782822  MAE:0.21998704969882965
# ▶ seg64  mean  MSE:0.07691588252782822  MAE:0.21998704969882965
#
# seg10 ch0 MSE : 0.12664197

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 96
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 96,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_E1_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTh1_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.09958749264478683  MAE:0.252848356962204
# ▶ seg0  mean  MSE:0.09958749264478683  MAE:0.252848356962204
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.12981031835079193  MAE:0.2823522686958313
# ▶ seg1  mean  MSE:0.12981031835079193  MAE:0.2823522686958313
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.0686691626906395  MAE:0.2062474638223648
# ▶ seg2  mean  MSE:0.0686691626906395  MAE:0.2062474638223648
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.13611863553524017  MAE:0.28403356671333313
# ▶ seg3  mean  MSE:0.13611863553524017  MAE:0.28403356671333313
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.07637126743793488  MAE:0.21156130731105804
# ▶ seg4  mean  MSE:0.07637126743793488  MAE:0.21156130731105804
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.1721925586462021  MAE:0.32873496413230896
# ▶ seg5  mean  MSE:0.1721925586462021  MAE:0.32873496413230896
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.07448900490999222  MAE:0.21486788988113403
# ▶ seg6  mean  MSE:0.07448900490999222  MAE:0.21486788988113403
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.089191734790802  MAE:0.23462972044944763
# ▶ seg7  mean  MSE:0.089191734790802  MAE:0.23462972044944763
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.08226118236780167  MAE:0.22070972621440887
# ▶ seg8  mean  MSE:0.08226118236780167  MAE:0.22070972621440887
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.08912979066371918  MAE:0.23179766535758972
# ▶ seg9  mean  MSE:0.08912979066371918  MAE:0.23179766535758972
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.42397192120552063  MAE:0.5529937744140625
# ▶ seg10  mean  MSE:0.42397192120552063  MAE:0.5529937744140625
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.10252548009157181  MAE:0.24906712770462036
# ▶ seg11  mean  MSE:0.10252548009157181  MAE:0.24906712770462036
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0
# ▶ seg62  mean  MSE:0.1619827151298523  MAE:0.32098957896232605
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.2583959400653839  MAE:0.3961097300052643
# ▶ seg63  mean  MSE:0.2583959400653839  MAE:0.3961097300052643
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.1658315509557724  MAE:0.3155632019042969
# ▶ seg64  mean  MSE:0.1658315509557724  MAE:0.3155632019042969
#
# seg10 ch0 MSE : 0.42397192

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTh1_train = torch.load("./1st_results_ETTh1/train_1st_results.pt")
results1_ETTh1_val = torch.load("./1st_results_ETTh1/val_1st_results.pt")
results1_ETTh1_test = torch.load("./1st_results_ETTh1/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.100091
#
#   Top  1 | seg 03 | MSE 0.094492 (+0.005599)
#   Top  2 | seg 55 | MSE 0.094913 (+0.005178)
#   Top  3 | seg 51 | MSE 0.095049 (+0.005041)
#   Top  4 | seg 50 | MSE 0.095685 (+0.004406)
#   Top  5 | seg 64 | MSE 0.096435 (+0.003656)
#   Top  6 | seg 28 | MSE 0.096460 (+0.003630)
#   Top  7 | seg 62 | MSE 0.096919 (+0.003171)
#   Top  8 | seg 48 | MSE 0.097055 (+0.003036)
#   Top  9 | seg 23 | MSE 0.097087 (+0.003004)
#   Top 10 | seg 18 | MSE 0.097228 (+0.002863)
#   Top 11 | seg 38 | MSE 0.097369 (+0.002722)
#   Top 12 | seg 46 | MSE 0.097369 (+0.002721)
#   Top 13 | seg 34 | MSE 0.097447 (+0.002644)
#   Top 14 | seg 20 | MSE 0.097548 (+0.002543)
#   Top 15 | seg 02 | MSE 0.097596 (+0.002495)
#   Top 16 | seg 60 | MSE 0.097696 (+0.002395)
#   Top 17 | seg 07 | MSE 0.097756 (+0.002335)
#   Top 18 | seg 11 | MSE 0.097762 (+0.002328)
#   Top 19 | seg 47 | MSE 0.097762 (+0.002328)
#   Top 20 | seg 37 | MSE 0.097853 (+0.002238)
#   Top 21 | seg 25 | MSE 0.097931 (+0.002160)
#   Top 22 | seg 22 | MSE 0.098157 (+0.001934)
#   Top 23 | seg 27 | MSE 0.098187 (+0.001903)
#   Top 24 | seg 49 | MSE 0.098290 (+0.001800)
#   Top 25 | seg 35 | MSE 0.098352 (+0.001739)
#   Top 26 | seg 33 | MSE 0.098523 (+0.001568)
#   Top 27 | seg 44 | MSE 0.098655 (+0.001435)
#   Top 28 | seg 14 | MSE 0.098680 (+0.001411)
#   Top 29 | seg 31 | MSE 0.098963 (+0.001127)
#   Top 30 | seg 58 | MSE 0.099031 (+0.001060)
#   Top 31 | seg 63 | MSE 0.099404 (+0.000686)
#   Top 32 | seg 30 | MSE 0.099759 (+0.000332)
#   Top 33 | seg 04 | MSE 0.100304 (-0.000214)
#   Top 34 | seg 43 | MSE 0.100376 (-0.000286)
#   Top 35 | seg 56 | MSE 0.100471 (-0.000380)
#   Top 36 | seg 19 | MSE 0.100509 (-0.000419)
#   Top 37 | seg 12 | MSE 0.100774 (-0.000684)
#   Top 38 | seg 10 | MSE 0.100956 (-0.000865)
#   Top 39 | seg 13 | MSE 0.101383 (-0.001293)
#   Top 40 | seg 05 | MSE 0.101402 (-0.001311)
#   Top 41 | seg 15 | MSE 0.101683 (-0.001593)
#   Top 42 | seg 53 | MSE 0.101884 (-0.001793)
#   Top 43 | seg 40 | MSE 0.101911 (-0.001821)
#   Top 44 | seg 29 | MSE 0.101981 (-0.001890)
#   Top 45 | seg 39 | MSE 0.102153 (-0.002062)
#   Top 46 | seg 61 | MSE 0.102643 (-0.002553)
#   Top 47 | seg 36 | MSE 0.102683 (-0.002592)
#   Top 48 | seg 24 | MSE 0.103047 (-0.002956)
#   Top 49 | seg 17 | MSE 0.103151 (-0.003060)
#   Top 50 | seg 00 | MSE 0.103818 (-0.003728)
#   Top 51 | seg 42 | MSE 0.103854 (-0.003764)
#   Top 52 | seg 01 | MSE 0.104380 (-0.004290)
#   Top 53 | seg 09 | MSE 0.104437 (-0.004347)
#   Top 54 | seg 45 | MSE 0.105263 (-0.005173)
#   Top 55 | seg 59 | MSE 0.106748 (-0.006658)
#   Top 56 | seg 21 | MSE 0.107031 (-0.006941)
#   Top 57 | seg 41 | MSE 0.107549 (-0.007458)
#   Top 58 | seg 32 | MSE 0.108215 (-0.008124)
#   Top 59 | seg 26 | MSE 0.110342 (-0.010251)
#   Top 60 | seg 52 | MSE 0.112667 (-0.012577)
#   Top 61 | seg 54 | MSE 0.113040 (-0.012949)
#   Top 62 | seg 57 | MSE 0.116211 (-0.016121)
#   Top 63 | seg 08 | MSE 0.116603 (-0.016513)
#   Top 64 | seg 16 | MSE 0.118260 (-0.018169)
#   Top 65 | seg 06 | MSE 0.137531 (-0.037441)
#
# Saved top segment indices per channel:
# Channel 0: [3, 55, 51, 50, 64, 28, 62, 48, 23, 18, 38, 46, 34, 20, 2, 60, 7, 11, 47, 37, 25, 22, 27, 49, 35, 33, 44, 14, 31, 58, 63, 30, 4, 43, 56, 19, 12, 10, 13, 5, 15, 53, 40, 29, 39, 61, 36, 24, 17, 0, 42, 1, 9, 45, 59, 21, 41, 32, 26, 52, 54, 57, 8, 16, 6]

# %% [markdown]
# ### 1E->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0
#   Top 54 | seg 30 | MSE 0.105968 (-0.005877)
#   Top 55 | seg 64 | MSE 0.106018 (-0.005928)
#   Top 56 | seg 19 | MSE 0.107468 (-0.007377)
#   Top 57 | seg 05 | MSE 0.107634 (-0.007544)
#   Top 58 | seg 16 | MSE 0.108467 (-0.008376)
#   Top 59 | seg 58 | MSE 0.109953 (-0.009863)
#   Top 60 | seg 31 | MSE 0.112387 (-0.012296)
#   Top 61 | seg 63 | MSE 0.113049 (-0.012958)
#   Top 62 | seg 36 | MSE 0.118815 (-0.018725)
#   Top 63 | seg 23 | MSE 0.122718 (-0.022628)
#   Top 64 | seg 39 | MSE 0.124240 (-0.024150)
#   Top 65 | seg 10 | MSE 0.129767 (-0.029677)
#
# Saved top segment indices per channel:
# Channel 0: [49, 33, 4, 35, 24, 2, 6, 27, 25, 15, 34, 51, 38, 20, 28, 11, 47, 60, 21, 52, 56, 54, 59, 57, 44, 8, 22, 40, 45, 37, 26, 9, 0, 29, 43, 12, 7, 32, 48, 50, 41, 42, 17, 55, 13, 1, 3, 18, 61, 14, 62, 46, 53, 30, 64, 19, 5, 16, 58, 31, 63, 36, 23, 39, 10]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTh1_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.058560 | MAE : 0.183304
#   — Var / |Corr| / Score —
#    K= 5 | Var=1.853e-02 | |ρ|=0.8511 | S=1.0000
#    K=10 | Var=2.400e-02 | |ρ|=0.8190 | S=0.9123
#    K=15 | Var=2.753e-02 | |ρ|=0.8042 | S=0.8923
#    K=20 | Var=3.026e-02 | |ρ|=0.7916 | S=0.8694
#    K=25 | Var=3.098e-02 | |ρ|=0.7888 | S=0.8670
#    K=30 | Var=3.305e-02 | |ρ|=0.7726 | S=0.8085
#    K=35 | Var=3.521e-02 | |ρ|=0.7642 | S=0.8000
#    K=40 | Var=3.889e-02 | |ρ|=0.7489 | S=0.7802
#    K=45 | Var=3.981e-02 | |ρ|=0.7451 | S=0.7749 <- pick
#    K=50 | Var=4.398e-02 | |ρ|=0.7324 | S=0.7807
#    K=55 | Var=4.849e-02 | |ρ|=0.7224 | S=0.8098
#    K=60 | Var=5.380e-02 | |ρ|=0.7064 | S=0.8179
#    K=65 | Var=6.828e-02 | |ρ|=0.6887 | S=1.0000
# [Var-Corr]  K=45
#   MSE = 0.055853 | Δ = +0.002708 | Δ% = +4.62%
#   MAE = 0.179752 | Δ = +0.003551 | Δ% = +1.94%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.058560
# Ensemble mean MSE : 0.055853
# Average Δ MSE     : +0.002708
# Average Δ MSE (%) : +4.62%
#
# Vanilla  mean MAE : 0.183304
# Ensemble mean MAE : 0.179752
# Average Δ MAE     : +0.003551
# Average Δ MAE (%) : +1.94%

# %% [markdown]
# ## 1E->1E

# %%
results1_ETTh1_test['ES']['mae_test_EES']
# Out:
# 0.1833038479089737

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTh1_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.35   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.058560 | MAE : 0.183304
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.498e-02 | |ρ|=0.7919 | S=1.1377
#    K=10 | Var=2.323e-02 | |ρ|=0.8171 | S=1.3500
#    K=15 | Var=2.501e-02 | |ρ|=0.8134 | S=1.3520
#    K=20 | Var=2.795e-02 | |ρ|=0.8027 | S=1.3099
#    K=25 | Var=2.968e-02 | |ρ|=0.7887 | S=1.2081
#    K=30 | Var=3.082e-02 | |ρ|=0.7806 | S=1.1522
#    K=35 | Var=3.314e-02 | |ρ|=0.7665 | S=1.0627
#    K=40 | Var=3.460e-02 | |ρ|=0.7628 | S=1.0574
#    K=45 | Var=3.751e-02 | |ρ|=0.7537 | S=1.0300
#    K=50 | Var=4.216e-02 | |ρ|=0.7352 | S=0.9469
#    K=55 | Var=4.721e-02 | |ρ|=0.7234 | S=0.9394
#    K=60 | Var=5.447e-02 | |ρ|=0.7066 | S=0.9313 <- pick
#    K=65 | Var=6.903e-02 | |ρ|=0.6816 | S=1.0000
# [Var-Corr]  K=60
#    MSE = 0.055351 | Δ = +0.003209 | Δ% = +5.48%
#    MAE = 0.179701 | Δ = +0.003603 | Δ% = +1.97%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.058560
# Ensemble mean MSE  : 0.055351
# Average Δ MSE      : +0.003209
# Average Δ MSE (%)  : +5.48%
#
# Vanilla  mean MAE  : 0.183304
# Ensemble mean MAE  : 0.179701
# Average Δ MAE      : +0.003603
# Average Δ MAE (%)  : +1.97%
