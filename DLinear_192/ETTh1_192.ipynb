# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 2
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(3)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 3
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTh1.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                       HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# date
# 2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (17420, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 01:00:00',
#                '2016-07-01 02:00:00', '2016-07-01 03:00:00',
#                '2016-07-01 04:00:00', '2016-07-01 05:00:00',
#                '2016-07-01 06:00:00', '2016-07-01 07:00:00',
#                '2016-07-01 08:00:00', '2016-07-01 09:00:00',
#                ...
#                '2018-06-26 10:00:00', '2018-06-26 11:00:00',
#                '2018-06-26 12:00:00', '2018-06-26 13:00:00',
#                '2018-06-26 14:00:00', '2018-06-26 15:00:00',
#                '2018-06-26 16:00:00', '2018-06-26 17:00:00',
#                '2018-06-26 18:00:00', '2018-06-26 19:00:00'],
#               dtype='datetime64[ns]', name='date', length=17420, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %%
set_seed(51)

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Decomposition-Linear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.individual = configs.individual
        self.channels = configs.enc_in
        self.attach_to_trend = configs.attach_to_trend
        self.attach_to_seasonal = configs.attach_to_seasonal
        

        
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        

        
        self.seq_len_trend = self.seq_len + (self.pred_len // 3) if self.attach_to_trend else self.seq_len
        self.seq_len_seasonal = self.seq_len + (self.pred_len // 3) if self.attach_to_seasonal else self.seq_len

        
        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))

                
                
                
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            
            
            
            

    def forward(self, x, ground_truth=None):
        
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if ground_truth is not None:
            kernel_size = 25
            self.decompsition = series_decomp(kernel_size)
            ground_truth_seasonal, ground_truth_trend = self.decompsition(ground_truth)

            
            if self.seq_len_seasonal > self.seq_len:
                ground_truth_seasonal=ground_truth_seasonal.permute(0, 2, 1)
                
                seasonal_init = torch.cat([seasonal_init, ground_truth_seasonal], dim=2)
            if self.seq_len_trend > self.seq_len:
                ground_truth_trend=ground_truth_trend.permute(0, 2, 1)
                
                trend_init = torch.cat([trend_init, ground_truth_trend], dim=2)
        
        
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset

target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 192


border1s = [0, 12 * 30 * 24 - seq_len, 12 * 30 * 24 + 4 * 30 * 24 - seq_len]
border2s = [12 * 30 * 24, 12 * 30 * 24 + 4 * 30 * 24, 12 * 30 * 24 + 8 * 30 * 24]

train = target[border1s[0]:border2s[0]]
val = target[border1s[1]:border2s[1]]
test = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val = scaler.transform(val)
test = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data = create_inout_sequences_univariate(val, seq_len, pred_len)
test_data = create_inout_sequences_univariate(test, seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels = torch.tensor([x[1] for x in test_data]).float().to(device)



print("Train Sequences:", train_sequences.shape)
print("Train Labels:", train_labels.shape)
print("Val Sequences:", val_sequences.shape)
print("Val Labels:", val_labels.shape)
print("Test Sequences:", test_sequences.shape)
print("Test Labels:", test_labels.shape)
# Out:
# Train Sequences: torch.Size([8113, 336, 1])
# Train Labels: torch.Size([8113, 192, 1])
# Val Sequences: torch.Size([2689, 336, 1])
# Val Labels: torch.Size([2689, 192, 1])
# Test Sequences: torch.Size([2689, 336, 1])
# Test Labels: torch.Size([2689, 192, 1])

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 192  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.01
# Epoch 0 | Train Loss: 0.3133111357336908 | Val Loss: 0.1544945843079511
# Validation loss decreased (inf --> 0.154495).  Saving model ...
# Updating learning rate to 0.005
# Epoch 1 | Train Loss: 0.20117915515589901 | Val Loss: 0.11718553576399299
# Validation loss decreased (0.154495 --> 0.117186).  Saving model ...
# Updating learning rate to 0.0025
# Epoch 2 | Train Loss: 0.1788134339932851 | Val Loss: 0.11029904837555746
# Validation loss decreased (0.117186 --> 0.110299).  Saving model ...
# Updating learning rate to 0.00125
# Epoch 3 | Train Loss: 0.17191814170695666 | Val Loss: 0.11026430042350993
# Validation loss decreased (0.110299 --> 0.110264).  Saving model ...
# Updating learning rate to 0.000625
# Epoch 4 | Train Loss: 0.16728606227580017 | Val Loss: 0.10779245782862691
# Validation loss decreased (0.110264 --> 0.107792).  Saving model ...
# Updating learning rate to 0.0003125
# Epoch 5 | Train Loss: 0.1655723723898253 | Val Loss: 0.10854504932375515
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00015625
# Epoch 6 | Train Loss: 0.16372700079571545 | Val Loss: 0.10818169932155049
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.8125e-05
# Epoch 7 | Train Loss: 0.16283444033598338 | Val Loss: 0.10948574122260599
# EarlyStopping counter: 3 out of 3
# Early stopping triggered. Stopping training.

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 192  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.01
# Epoch 0 | Train Loss: 0.32360341669771614 | Val Loss: 0.1378765582161791
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.07267593592405319 | MAE: 0.21264927089214325
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.2757994830608368 | MAE: 0.41014230251312256

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.1085018664598465 | MAE: 0.26026251912117004
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.13756023347377777 | MAE: 0.2914961576461792

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.17228668928146362 | MAE: 0.32155582308769226
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.3133045732975006 | MAE: 0.42859113216400146

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([8113, 336, 1])
# val_sequences shape:  torch.Size([2689, 336, 1])
# test_sequences shape:  torch.Size([2689, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([8113, 192, 1])
# val_pv shape:  torch.Size([2689, 192, 1])
# test_pv shape:  torch.Size([2689, 192, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([8113, 192, 1])
# val_labels shape:  torch.Size([2689, 192, 1])
# test_labels shape:  torch.Size([2689, 192, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 192

# %%
segment_len = configs.pred_len // 3
stride = 2 

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([8113, 65, 64, 1]), Val: torch.Size([2689, 65, 64, 1]), Test: torch.Size([2689, 65, 64, 1])
# [Epoch 1] Train seg shape: torch.Size([8113, 65, 64, 1]), Val: torch.Size([2689, 65, 64, 1]), Test: torch.Size([2689, 65, 64, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTh1'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 192,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 0] Training Time = 1.72 sec
# [Segment 0] GPU Memory Start = 688.22 MB
# [Segment 0] GPU Memory End   = 690.14 MB
# [Segment 0] GPU Peak Memory  = 691.40 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 1] Training Time = 1.62 sec
# [Segment 1] GPU Memory Start = 690.14 MB
# [Segment 1] GPU Memory End   = 690.73 MB
# [Segment 1] GPU Peak Memory  = 691.99 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 2] Training Time = 1.65 sec
# [Segment 2] GPU Memory Start = 690.73 MB
# [Segment 2] GPU Memory End   = 690.14 MB
# [Segment 2] GPU Peak Memory  = 691.96 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 3] Training Time = 1.58 sec
# [Segment 3] GPU Memory Start = 690.14 MB
# [Segment 3] GPU Memory End   = 690.73 MB
# [Segment 3] GPU Peak Memory  = 691.99 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 4] Training Time = 1.04 sec
# [Segment 4] GPU Memory Start = 690.73 MB
# [Segment 4] GPU Memory End   = 691.31 MB
# [Segment 4] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 5] Training Time = 1.45 sec
# [Segment 5] GPU Memory Start = 691.31 MB
# [Segment 5] GPU Memory End   = 691.90 MB
# [Segment 5] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 6] Training Time = 1.49 sec
# [Segment 6] GPU Memory Start = 691.90 MB
# [Segment 6] GPU Memory End   = 692.49 MB
# [Segment 6] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 7] Training Time = 1.03 sec
# [Segment 7] GPU Memory Start = 692.49 MB
# [Segment 7] GPU Memory End   = 693.08 MB
# [Segment 7] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 8] Training Time = 1.58 sec
# [Segment 8] GPU Memory Start = 693.08 MB
# [Segment 8] GPU Memory End   = 693.67 MB
# [Segment 8] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 9] Training Time = 1.51 sec
# [Segment 9] GPU Memory Start = 693.67 MB
# [Segment 9] GPU Memory End   = 694.25 MB
# [Segment 9] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 10] Training Time = 1.64 sec
# [Segment 10] GPU Memory Start = 694.25 MB
# [Segment 10] GPU Memory End   = 694.84 MB
# [Segment 10] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 11] Training Time = 1.57 sec
# [Segment 11] GPU Memory Start = 694.84 MB
# [Segment 11] GPU Memory End   = 695.43 MB
# [Segment 11] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 12] Training Time = 1.44 sec
# [Segment 12] GPU Memory Start = 690.14 MB
# [Segment 12] GPU Memory End   = 690.73 MB
# [Segment 12] GPU Peak Memory  = 691.99 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 13] Training Time = 1.02 sec
# [Segment 13] GPU Memory Start = 690.73 MB
# [Segment 13] GPU Memory End   = 691.31 MB
# [Segment 13] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 14] Training Time = 1.61 sec
# [Segment 14] GPU Memory Start = 691.31 MB
# [Segment 14] GPU Memory End   = 691.90 MB
# [Segment 14] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 15] Training Time = 1.60 sec
# [Segment 15] GPU Memory Start = 691.90 MB
# [Segment 15] GPU Memory End   = 692.49 MB
# [Segment 15] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 16] Training Time = 1.64 sec
# [Segment 16] GPU Memory Start = 692.49 MB
# [Segment 16] GPU Memory End   = 693.08 MB
# [Segment 16] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 17] Training Time = 1.41 sec
# [Segment 17] GPU Memory Start = 693.08 MB
# [Segment 17] GPU Memory End   = 693.67 MB
# [Segment 17] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 18] Training Time = 0.72 sec
# [Segment 18] GPU Memory Start = 693.67 MB
# [Segment 18] GPU Memory End   = 694.25 MB
# [Segment 18] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 19] Training Time = 1.46 sec
# [Segment 19] GPU Memory Start = 694.25 MB
# [Segment 19] GPU Memory End   = 694.84 MB
# [Segment 19] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 20] Training Time = 1.45 sec
# [Segment 20] GPU Memory Start = 694.84 MB
# [Segment 20] GPU Memory End   = 695.43 MB
# [Segment 20] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 21] Training Time = 1.49 sec
# [Segment 21] GPU Memory Start = 695.43 MB
# [Segment 21] GPU Memory End   = 690.73 MB
# [Segment 21] GPU Peak Memory  = 696.02 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 22] Training Time = 1.49 sec
# [Segment 22] GPU Memory Start = 690.73 MB
# [Segment 22] GPU Memory End   = 691.31 MB
# [Segment 22] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 23] Training Time = 1.24 sec
# [Segment 23] GPU Memory Start = 691.31 MB
# [Segment 23] GPU Memory End   = 691.90 MB
# [Segment 23] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 24] Training Time = 0.67 sec
# [Segment 24] GPU Memory Start = 691.90 MB
# [Segment 24] GPU Memory End   = 692.49 MB
# [Segment 24] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 25] Training Time = 0.68 sec
# [Segment 25] GPU Memory Start = 692.49 MB
# [Segment 25] GPU Memory End   = 693.08 MB
# [Segment 25] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 26] Training Time = 1.09 sec
# [Segment 26] GPU Memory Start = 693.08 MB
# [Segment 26] GPU Memory End   = 693.67 MB
# [Segment 26] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 27] Training Time = 1.40 sec
# [Segment 27] GPU Memory Start = 693.67 MB
# [Segment 27] GPU Memory End   = 694.25 MB
# [Segment 27] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 28] Training Time = 1.33 sec
# [Segment 28] GPU Memory Start = 694.25 MB
# [Segment 28] GPU Memory End   = 694.84 MB
# [Segment 28] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 29] Training Time = 1.33 sec
# [Segment 29] GPU Memory Start = 694.84 MB
# [Segment 29] GPU Memory End   = 695.43 MB
# [Segment 29] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 30] Training Time = 0.67 sec
# [Segment 30] GPU Memory Start = 695.43 MB
# [Segment 30] GPU Memory End   = 696.02 MB
# [Segment 30] GPU Peak Memory  = 697.28 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 31] Training Time = 0.67 sec
# [Segment 31] GPU Memory Start = 690.73 MB
# [Segment 31] GPU Memory End   = 691.31 MB
# [Segment 31] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 32] Training Time = 0.67 sec
# [Segment 32] GPU Memory Start = 691.31 MB
# [Segment 32] GPU Memory End   = 691.90 MB
# [Segment 32] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 33] Training Time = 0.92 sec
# [Segment 33] GPU Memory Start = 691.90 MB
# [Segment 33] GPU Memory End   = 692.49 MB
# [Segment 33] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 34] Training Time = 1.50 sec
# [Segment 34] GPU Memory Start = 692.49 MB
# [Segment 34] GPU Memory End   = 693.08 MB
# [Segment 34] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 35] Training Time = 1.00 sec
# [Segment 35] GPU Memory Start = 693.08 MB
# [Segment 35] GPU Memory End   = 693.67 MB
# [Segment 35] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 36] Training Time = 1.40 sec
# [Segment 36] GPU Memory Start = 693.67 MB
# [Segment 36] GPU Memory End   = 694.25 MB
# [Segment 36] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 37] Training Time = 1.03 sec
# [Segment 37] GPU Memory Start = 694.25 MB
# [Segment 37] GPU Memory End   = 694.84 MB
# [Segment 37] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 38] Training Time = 0.84 sec
# [Segment 38] GPU Memory Start = 694.84 MB
# [Segment 38] GPU Memory End   = 695.43 MB
# [Segment 38] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 39] Training Time = 0.66 sec
# [Segment 39] GPU Memory Start = 695.43 MB
# [Segment 39] GPU Memory End   = 696.02 MB
# [Segment 39] GPU Peak Memory  = 697.28 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 40] Training Time = 0.67 sec
# [Segment 40] GPU Memory Start = 696.02 MB
# [Segment 40] GPU Memory End   = 691.31 MB
# [Segment 40] GPU Peak Memory  = 696.61 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 41] Training Time = 1.28 sec
# [Segment 41] GPU Memory Start = 691.31 MB
# [Segment 41] GPU Memory End   = 691.90 MB
# [Segment 41] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 42] Training Time = 0.53 sec
# [Segment 42] GPU Memory Start = 691.90 MB
# [Segment 42] GPU Memory End   = 692.49 MB
# [Segment 42] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 43] Training Time = 0.67 sec
# [Segment 43] GPU Memory Start = 692.49 MB
# [Segment 43] GPU Memory End   = 693.08 MB
# [Segment 43] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 44] Training Time = 1.20 sec
# [Segment 44] GPU Memory Start = 693.08 MB
# [Segment 44] GPU Memory End   = 693.67 MB
# [Segment 44] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 45] Training Time = 1.47 sec
# [Segment 45] GPU Memory Start = 693.67 MB
# [Segment 45] GPU Memory End   = 694.25 MB
# [Segment 45] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 46] Training Time = 0.78 sec
# [Segment 46] GPU Memory Start = 694.25 MB
# [Segment 46] GPU Memory End   = 694.84 MB
# [Segment 46] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 47] Training Time = 1.42 sec
# [Segment 47] GPU Memory Start = 694.84 MB
# [Segment 47] GPU Memory End   = 695.43 MB
# [Segment 47] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 48] Training Time = 1.40 sec
# [Segment 48] GPU Memory Start = 695.43 MB
# [Segment 48] GPU Memory End   = 696.02 MB
# [Segment 48] GPU Peak Memory  = 697.28 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 49] Training Time = 1.44 sec
# [Segment 49] GPU Memory Start = 696.02 MB
# [Segment 49] GPU Memory End   = 696.61 MB
# [Segment 49] GPU Peak Memory  = 697.87 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 50] Training Time = 0.68 sec
# [Segment 50] GPU Memory Start = 691.31 MB
# [Segment 50] GPU Memory End   = 691.90 MB
# [Segment 50] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 51] Training Time = 0.67 sec
# [Segment 51] GPU Memory Start = 691.90 MB
# [Segment 51] GPU Memory End   = 692.49 MB
# [Segment 51] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 52] Training Time = 0.76 sec
# [Segment 52] GPU Memory Start = 692.49 MB
# [Segment 52] GPU Memory End   = 693.08 MB
# [Segment 52] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 53] Training Time = 1.38 sec
# [Segment 53] GPU Memory Start = 693.08 MB
# [Segment 53] GPU Memory End   = 693.67 MB
# [Segment 53] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 54] Training Time = 0.67 sec
# [Segment 54] GPU Memory Start = 693.67 MB
# [Segment 54] GPU Memory End   = 694.25 MB
# [Segment 54] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 55] Training Time = 0.67 sec
# [Segment 55] GPU Memory Start = 694.25 MB
# [Segment 55] GPU Memory End   = 694.84 MB
# [Segment 55] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 56] Training Time = 0.67 sec
# [Segment 56] GPU Memory Start = 694.84 MB
# [Segment 56] GPU Memory End   = 695.43 MB
# [Segment 56] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 57] Training Time = 0.67 sec
# [Segment 57] GPU Memory Start = 695.43 MB
# [Segment 57] GPU Memory End   = 696.02 MB
# [Segment 57] GPU Peak Memory  = 697.28 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 58] Training Time = 0.70 sec
# [Segment 58] GPU Memory Start = 696.02 MB
# [Segment 58] GPU Memory End   = 696.61 MB
# [Segment 58] GPU Peak Memory  = 697.87 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 59] Training Time = 1.55 sec
# [Segment 59] GPU Memory Start = 696.61 MB
# [Segment 59] GPU Memory End   = 690.14 MB
# [Segment 59] GPU Peak Memory  = 697.19 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 60] Training Time = 0.68 sec
# [Segment 60] GPU Memory Start = 690.14 MB
# [Segment 60] GPU Memory End   = 690.73 MB
# [Segment 60] GPU Peak Memory  = 691.99 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 61] Training Time = 0.69 sec
# [Segment 61] GPU Memory Start = 690.73 MB
# [Segment 61] GPU Memory End   = 691.31 MB
# [Segment 61] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 62] Training Time = 1.06 sec
# [Segment 62] GPU Memory Start = 691.31 MB
# [Segment 62] GPU Memory End   = 691.90 MB
# [Segment 62] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 63] Training Time = 1.11 sec
# [Segment 63] GPU Memory Start = 691.90 MB
# [Segment 63] GPU Memory End   = 692.49 MB
# [Segment 63] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 64] Training Time = 0.69 sec
# [Segment 64] GPU Memory Start = 692.49 MB
# [Segment 64] GPU Memory End   = 693.08 MB
# [Segment 64] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 192,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E/",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 0] Training Time = 1.52 sec
# [Segment 0] GPU Memory Start = 690.14 MB
# [Segment 0] GPU Memory End   = 690.14 MB
# [Segment 0] GPU Peak Memory  = 691.96 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 1] Training Time = 1.34 sec
# [Segment 1] GPU Memory Start = 690.14 MB
# [Segment 1] GPU Memory End   = 690.73 MB
# [Segment 1] GPU Peak Memory  = 691.99 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 2] Training Time = 0.87 sec
# [Segment 2] GPU Memory Start = 690.73 MB
# [Segment 2] GPU Memory End   = 691.31 MB
# [Segment 2] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 3] Training Time = 1.46 sec
# [Segment 3] GPU Memory Start = 691.31 MB
# [Segment 3] GPU Memory End   = 691.90 MB
# [Segment 3] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 4] Training Time = 1.42 sec
# [Segment 4] GPU Memory Start = 691.90 MB
# [Segment 4] GPU Memory End   = 690.14 MB
# [Segment 4] GPU Peak Memory  = 692.49 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 5] Training Time = 0.75 sec
# [Segment 5] GPU Memory Start = 690.14 MB
# [Segment 5] GPU Memory End   = 690.73 MB
# [Segment 5] GPU Peak Memory  = 691.99 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 6] Training Time = 0.68 sec
# [Segment 6] GPU Memory Start = 690.73 MB
# [Segment 6] GPU Memory End   = 691.31 MB
# [Segment 6] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 7] Training Time = 1.45 sec
# [Segment 7] GPU Memory Start = 691.31 MB
# [Segment 7] GPU Memory End   = 691.90 MB
# [Segment 7] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 8] Training Time = 1.39 sec
# [Segment 8] GPU Memory Start = 691.90 MB
# [Segment 8] GPU Memory End   = 692.49 MB
# [Segment 8] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 9] Training Time = 1.43 sec
# [Segment 9] GPU Memory Start = 692.49 MB
# [Segment 9] GPU Memory End   = 693.08 MB
# [Segment 9] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 10] Training Time = 1.12 sec
# [Segment 10] GPU Memory Start = 693.08 MB
# [Segment 10] GPU Memory End   = 693.67 MB
# [Segment 10] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 11] Training Time = 1.52 sec
# [Segment 11] GPU Memory Start = 693.67 MB
# [Segment 11] GPU Memory End   = 694.25 MB
# [Segment 11] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 12] Training Time = 1.59 sec
# [Segment 12] GPU Memory Start = 694.25 MB
# [Segment 12] GPU Memory End   = 694.84 MB
# [Segment 12] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 13] Training Time = 1.45 sec
# [Segment 13] GPU Memory Start = 694.84 MB
# [Segment 13] GPU Memory End   = 695.43 MB
# [Segment 13] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 14] Training Time = 1.48 sec
# [Segment 14] GPU Memory Start = 690.14 MB
# [Segment 14] GPU Memory End   = 690.73 MB
# [Segment 14] GPU Peak Memory  = 691.99 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 15] Training Time = 1.45 sec
# [Segment 15] GPU Memory Start = 690.73 MB
# [Segment 15] GPU Memory End   = 691.31 MB
# [Segment 15] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 16] Training Time = 1.55 sec
# [Segment 16] GPU Memory Start = 691.31 MB
# [Segment 16] GPU Memory End   = 691.90 MB
# [Segment 16] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 17] Training Time = 1.57 sec
# [Segment 17] GPU Memory Start = 691.90 MB
# [Segment 17] GPU Memory End   = 692.49 MB
# [Segment 17] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 18] Training Time = 1.44 sec
# [Segment 18] GPU Memory Start = 692.49 MB
# [Segment 18] GPU Memory End   = 693.08 MB
# [Segment 18] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 19] Training Time = 1.50 sec
# [Segment 19] GPU Memory Start = 693.08 MB
# [Segment 19] GPU Memory End   = 693.67 MB
# [Segment 19] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 20] Training Time = 1.45 sec
# [Segment 20] GPU Memory Start = 693.67 MB
# [Segment 20] GPU Memory End   = 694.25 MB
# [Segment 20] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 21] Training Time = 1.42 sec
# [Segment 21] GPU Memory Start = 694.25 MB
# [Segment 21] GPU Memory End   = 694.84 MB
# [Segment 21] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 22] Training Time = 1.57 sec
# [Segment 22] GPU Memory Start = 694.84 MB
# [Segment 22] GPU Memory End   = 695.43 MB
# [Segment 22] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 23] Training Time = 0.68 sec
# [Segment 23] GPU Memory Start = 695.43 MB
# [Segment 23] GPU Memory End   = 690.73 MB
# [Segment 23] GPU Peak Memory  = 696.02 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 24] Training Time = 0.97 sec
# [Segment 24] GPU Memory Start = 690.73 MB
# [Segment 24] GPU Memory End   = 691.31 MB
# [Segment 24] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 25] Training Time = 1.41 sec
# [Segment 25] GPU Memory Start = 691.31 MB
# [Segment 25] GPU Memory End   = 691.90 MB
# [Segment 25] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 26] Training Time = 0.77 sec
# [Segment 26] GPU Memory Start = 691.90 MB
# [Segment 26] GPU Memory End   = 692.49 MB
# [Segment 26] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 27] Training Time = 0.90 sec
# [Segment 27] GPU Memory Start = 692.49 MB
# [Segment 27] GPU Memory End   = 693.08 MB
# [Segment 27] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 28] Training Time = 0.65 sec
# [Segment 28] GPU Memory Start = 693.08 MB
# [Segment 28] GPU Memory End   = 693.67 MB
# [Segment 28] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 29] Training Time = 0.66 sec
# [Segment 29] GPU Memory Start = 693.67 MB
# [Segment 29] GPU Memory End   = 694.25 MB
# [Segment 29] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 30] Training Time = 0.74 sec
# [Segment 30] GPU Memory Start = 694.25 MB
# [Segment 30] GPU Memory End   = 694.84 MB
# [Segment 30] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 31] Training Time = 0.75 sec
# [Segment 31] GPU Memory Start = 694.84 MB
# [Segment 31] GPU Memory End   = 695.43 MB
# [Segment 31] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 32] Training Time = 0.76 sec
# [Segment 32] GPU Memory Start = 695.43 MB
# [Segment 32] GPU Memory End   = 696.02 MB
# [Segment 32] GPU Peak Memory  = 697.28 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 33] Training Time = 0.79 sec
# [Segment 33] GPU Memory Start = 690.73 MB
# [Segment 33] GPU Memory End   = 691.31 MB
# [Segment 33] GPU Peak Memory  = 692.58 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 34] Training Time = 0.81 sec
# [Segment 34] GPU Memory Start = 691.31 MB
# [Segment 34] GPU Memory End   = 691.90 MB
# [Segment 34] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 35] Training Time = 1.44 sec
# [Segment 35] GPU Memory Start = 691.90 MB
# [Segment 35] GPU Memory End   = 692.49 MB
# [Segment 35] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 36] Training Time = 1.19 sec
# [Segment 36] GPU Memory Start = 692.49 MB
# [Segment 36] GPU Memory End   = 693.08 MB
# [Segment 36] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 37] Training Time = 1.25 sec
# [Segment 37] GPU Memory Start = 693.08 MB
# [Segment 37] GPU Memory End   = 693.67 MB
# [Segment 37] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 38] Training Time = 0.72 sec
# [Segment 38] GPU Memory Start = 693.67 MB
# [Segment 38] GPU Memory End   = 694.25 MB
# [Segment 38] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 39] Training Time = 0.87 sec
# [Segment 39] GPU Memory Start = 694.25 MB
# [Segment 39] GPU Memory End   = 694.84 MB
# [Segment 39] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 40] Training Time = 1.04 sec
# [Segment 40] GPU Memory Start = 694.84 MB
# [Segment 40] GPU Memory End   = 695.43 MB
# [Segment 40] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 41] Training Time = 0.96 sec
# [Segment 41] GPU Memory Start = 695.43 MB
# [Segment 41] GPU Memory End   = 696.02 MB
# [Segment 41] GPU Peak Memory  = 697.28 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 42] Training Time = 0.91 sec
# [Segment 42] GPU Memory Start = 696.02 MB
# [Segment 42] GPU Memory End   = 691.31 MB
# [Segment 42] GPU Peak Memory  = 696.61 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 43] Training Time = 0.84 sec
# [Segment 43] GPU Memory Start = 691.31 MB
# [Segment 43] GPU Memory End   = 691.90 MB
# [Segment 43] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 44] Training Time = 1.21 sec
# [Segment 44] GPU Memory Start = 691.90 MB
# [Segment 44] GPU Memory End   = 692.49 MB
# [Segment 44] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 45] Training Time = 1.50 sec
# [Segment 45] GPU Memory Start = 692.49 MB
# [Segment 45] GPU Memory End   = 693.08 MB
# [Segment 45] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 46] Training Time = 1.68 sec
# [Segment 46] GPU Memory Start = 693.08 MB
# [Segment 46] GPU Memory End   = 693.67 MB
# [Segment 46] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 47] Training Time = 1.65 sec
# [Segment 47] GPU Memory Start = 693.67 MB
# [Segment 47] GPU Memory End   = 694.25 MB
# [Segment 47] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 48] Training Time = 1.38 sec
# [Segment 48] GPU Memory Start = 694.25 MB
# [Segment 48] GPU Memory End   = 694.84 MB
# [Segment 48] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 49] Training Time = 1.61 sec
# [Segment 49] GPU Memory Start = 694.84 MB
# [Segment 49] GPU Memory End   = 695.43 MB
# [Segment 49] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 50] Training Time = 1.64 sec
# [Segment 50] GPU Memory Start = 695.43 MB
# [Segment 50] GPU Memory End   = 696.02 MB
# [Segment 50] GPU Peak Memory  = 697.28 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 51] Training Time = 1.51 sec
# [Segment 51] GPU Memory Start = 696.02 MB
# [Segment 51] GPU Memory End   = 696.61 MB
# [Segment 51] GPU Peak Memory  = 697.87 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 52] Training Time = 1.62 sec
# [Segment 52] GPU Memory Start = 691.31 MB
# [Segment 52] GPU Memory End   = 691.90 MB
# [Segment 52] GPU Peak Memory  = 693.16 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 53] Training Time = 1.67 sec
# [Segment 53] GPU Memory Start = 691.90 MB
# [Segment 53] GPU Memory End   = 692.49 MB
# [Segment 53] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 54] Training Time = 1.26 sec
# [Segment 54] GPU Memory Start = 692.49 MB
# [Segment 54] GPU Memory End   = 693.08 MB
# [Segment 54] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 55] Training Time = 1.48 sec
# [Segment 55] GPU Memory Start = 693.08 MB
# [Segment 55] GPU Memory End   = 693.67 MB
# [Segment 55] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 56] Training Time = 1.58 sec
# [Segment 56] GPU Memory Start = 693.67 MB
# [Segment 56] GPU Memory End   = 694.25 MB
# [Segment 56] GPU Peak Memory  = 695.52 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 57] Training Time = 0.99 sec
# [Segment 57] GPU Memory Start = 694.25 MB
# [Segment 57] GPU Memory End   = 694.84 MB
# [Segment 57] GPU Peak Memory  = 696.10 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 58] Training Time = 1.10 sec
# [Segment 58] GPU Memory Start = 694.84 MB
# [Segment 58] GPU Memory End   = 695.43 MB
# [Segment 58] GPU Peak Memory  = 696.69 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 59] Training Time = 1.47 sec
# [Segment 59] GPU Memory Start = 695.43 MB
# [Segment 59] GPU Memory End   = 696.02 MB
# [Segment 59] GPU Peak Memory  = 697.28 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 60] Training Time = 1.33 sec
# [Segment 60] GPU Memory Start = 696.02 MB
# [Segment 60] GPU Memory End   = 696.61 MB
# [Segment 60] GPU Peak Memory  = 697.87 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 61] Training Time = 0.67 sec
# [Segment 61] GPU Memory Start = 696.61 MB
# [Segment 61] GPU Memory End   = 691.90 MB
# [Segment 61] GPU Peak Memory  = 697.19 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 62] Training Time = 1.17 sec
# [Segment 62] GPU Memory Start = 691.90 MB
# [Segment 62] GPU Memory End   = 692.49 MB
# [Segment 62] GPU Peak Memory  = 693.75 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 63] Training Time = 0.67 sec
# [Segment 63] GPU Memory Start = 692.49 MB
# [Segment 63] GPU Memory End   = 693.08 MB
# [Segment 63] GPU Peak Memory  = 694.34 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.4180 MB
#   yb per batch = 0.0234 MB, total = 5.9531 MB
#   pv per batch = 0.0078 MB, total = 1.9844 MB
# [Segment 64] Training Time = 1.39 sec
# [Segment 64] GPU Memory Start = 693.08 MB
# [Segment 64] GPU Memory End   = 693.67 MB
# [Segment 64] GPU Peak Memory  = 694.93 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTh1_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.12367547303438187  MAE:0.27930888533592224
# ▶ seg0  mean  MSE:0.12367547303438187  MAE:0.27930888533592224
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.12163310497999191  MAE:0.27642032504081726
# ▶ seg1  mean  MSE:0.12163310497999191  MAE:0.27642032504081726
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.12817101180553436  MAE:0.2807338833808899
# ▶ seg2  mean  MSE:0.12817101180553436  MAE:0.2807338833808899
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.11583001911640167  MAE:0.26977330446243286
# ▶ seg3  mean  MSE:0.11583001911640167  MAE:0.26977330446243286
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.12220417708158493  MAE:0.2736058533191681
# ▶ seg4  mean  MSE:0.12220417708158493  MAE:0.2736058533191681
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.11657818406820297  MAE:0.2696344256401062
# ▶ seg5  mean  MSE:0.11657818406820297  MAE:0.2696344256401062
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.11814502626657486  MAE:0.2727203071117401
# ▶ seg6  mean  MSE:0.11814502626657486  MAE:0.2727203071117401
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.11403769999742508  MAE:0.26754069328308105
# ▶ seg7  mean  MSE:0.11403769999742508  MAE:0.26754069328308105
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.11753791570663452  MAE:0.27024587988853455
# ▶ seg8  mean  MSE:0.11753791570663452  MAE:0.27024587988853455
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.1277599334716797  MAE:0.281826376914978
# ▶ seg9  mean  MSE:0.1277599334716797  MAE:0.281826376914978
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.13400007784366608  MAE:0.2886839807033539
# ▶ seg10  mean  MSE:0.13400007784366608  MAE:0.2886839807033539
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.11666131764650345  MAE:0.2709411382675171
# ▶ seg11  mean  MSE:0.11666131764650345  MAE:0.2709411382675171
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.12179654836654663  MAE:0.27623113989830017
# ▶ seg12  mean  MSE:0.12179654836654663  MAE:0.27623113989830017
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.12196946889162064  MAE:0.2775479555130005
# ▶ seg13  mean  MSE:0.12196946889162064  MAE:0.2775479555130005
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.11703308671712875  MAE:0.2702411413192749
# ▶ seg14  mean  MSE:0.11703308671712875  MAE:0.2702411413192749
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.12143189460039139  MAE:0.27560946345329285
# ▶ seg15  mean  MSE:0.12143189460039139  MAE:0.27560946345329285
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.11757586896419525  MAE:0.2700080871582031
# ▶ seg16  mean  MSE:0.11757586896419525  MAE:0.2700080871582031
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.12042731046676636  MAE:0.2735111713409424
# ▶ seg17  mean  MSE:0.12042731046676636  MAE:0.2735111713409424
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.12074840813875198  MAE:0.2741474211215973
# ▶ seg51  mean  MSE:0.12074840813875198  MAE:0.2741474211215973
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.12033101171255112  MAE:0.2749740183353424
# ▶ seg52  mean  MSE:0.12033101171255112  MAE:0.2749740183353424
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.13059397041797638  MAE:0.2856150269508362
# ▶ seg53  mean  MSE:0.13059397041797638  MAE:0.2856150269508362
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.1264350712299347  MAE:0.2836390733718872
# ▶ seg54  mean  MSE:0.1264350712299347  MAE:0.2836390733718872
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.15526671707630157  MAE:0.31026825308799744
# ▶ seg55  mean  MSE:0.15526671707630157  MAE:0.31026825308799744
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.12877555191516876  MAE:0.2829786539077759
# ▶ seg56  mean  MSE:0.12877555191516876  MAE:0.2829786539077759
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.11732906103134155  MAE:0.2707189917564392
# ▶ seg57  mean  MSE:0.11732906103134155  MAE:0.2707189917564392
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.11567115783691406  MAE:0.2687528729438782
# ▶ seg58  mean  MSE:0.11567115783691406  MAE:0.2687528729438782
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.11798625439405441  MAE:0.2710699737071991
# ▶ seg59  mean  MSE:0.11798625439405441  MAE:0.2710699737071991
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.12658824026584625  MAE:0.27919304370880127
# ▶ seg60  mean  MSE:0.12658824026584625  MAE:0.27919304370880127
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.14070415496826172  MAE:0.29507774114608765
# ▶ seg61  mean  MSE:0.14070415496826172  MAE:0.29507774114608765
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.12110554426908493  MAE:0.27509474754333496
# ▶ seg62  mean  MSE:0.12110554426908493  MAE:0.27509474754333496
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.12671811878681183  MAE:0.28159499168395996
# ▶ seg63  mean  MSE:0.12671811878681183  MAE:0.28159499168395996
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.11747127026319504  MAE:0.2697385251522064
# ▶ seg64  mean  MSE:0.11747127026319504  MAE:0.2697385251522064
#
# seg10 ch0 MSE : 0.130887

# %% [markdown]
# # 2nd Inference for Test Set

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 192
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTh1_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.20749767124652863  MAE:0.3572114109992981
# ▶ seg0  mean  MSE:0.20749767124652863  MAE:0.3572114109992981
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.1244615688920021  MAE:0.2726234197616577
# ▶ seg1  mean  MSE:0.1244615688920021  MAE:0.2726234197616577
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.1847158670425415  MAE:0.32905182242393494
# ▶ seg2  mean  MSE:0.1847158670425415  MAE:0.32905182242393494
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.09360992908477783  MAE:0.24038061499595642
# ▶ seg3  mean  MSE:0.09360992908477783  MAE:0.24038061499595642
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.09212605655193329  MAE:0.23452316224575043
# ▶ seg4  mean  MSE:0.09212605655193329  MAE:0.23452316224575043
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.2579309940338135  MAE:0.4098398983478546
# ▶ seg57  mean  MSE:0.2579309940338135  MAE:0.4098398983478546
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.163765087723732  MAE:0.31795093417167664
# ▶ seg58  mean  MSE:0.163765087723732  MAE:0.31795093417167664
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.10985038429498672  MAE:0.2596258819103241
# ▶ seg59  mean  MSE:0.10985038429498672  MAE:0.2596258819103241
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.16082851588726044  MAE:0.3132701516151428
# ▶ seg60  mean  MSE:0.16082851588726044  MAE:0.3132701516151428
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.14884543418884277  MAE:0.30302900075912476
# ▶ seg61  mean  MSE:0.14884543418884277  MAE:0.30302900075912476
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.1288895159959793  MAE:0.2790006399154663
# ▶ seg62  mean  MSE:0.1288895159959793  MAE:0.2790006399154663
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.3478471636772156  MAE:0.47531670331954956
# ▶ seg63  mean  MSE:0.3478471636772156  MAE:0.47531670331954956
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.2768593728542328  MAE:0.4341055452823639
# ▶ seg64  mean  MSE:0.2768593728542328  MAE:0.4341055452823639
#
# seg10 ch0 MSE : 0.27371922

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 192
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTh1_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.136111781001091  MAE:0.2960642874240875
# ▶ seg0  mean  MSE:0.136111781001091  MAE:0.2960642874240875
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.10187765955924988  MAE:0.24729473888874054
# ▶ seg1  mean  MSE:0.10187765955924988  MAE:0.24729473888874054
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.10736000537872314  MAE:0.2508653700351715
# ▶ seg2  mean  MSE:0.10736000537872314  MAE:0.2508653700351715
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.10344072431325912  MAE:0.25029274821281433
# ▶ seg3  mean  MSE:0.10344072431325912  MAE:0.25029274821281433
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.1707378327846527  MAE:0.3167746663093567
# ▶ seg4  mean  MSE:0.1707378327846527  MAE:0.3167746663093567
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.13827218115329742  MAE:0.2850836515426636
# ▶ seg5  mean  MSE:0.13827218115329742  MAE:0.2850836515426636
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.2287914901971817  MAE:0.3825487792491913
# ▶ seg6  mean  MSE:0.2287914901971817  MAE:0.3825487792491913
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.20806984603405  MAE:0.365749716758728
# ▶ seg7  mean  MSE:0.20806984603405  MAE:0.365749716758728
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.12070902436971664  MAE:0.27231475710868835
# ▶ seg8  mean  MSE:0.12070902436971664  MAE:0.27231475710868835
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.21861590445041656  MAE:0.37381234765052795
# ▶ seg9  mean  MSE:0.21861590445041656  MAE:0.37381234765052795
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.24147354066371918  MAE:0.3941839039325714
# ▶ seg10  mean  MSE:0.24147354066371918  MAE:0.3941839039325714
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.26817023754119873  MAE:0.41810381412506104
# ▶ seg11  mean  MSE:0.26817023754119873  MAE:0.41810381412506104
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.1513875424861908  MAE:0.3069509267807007
# ▶ seg60  mean  MSE:0.1513875424861908  MAE:0.3069509267807007
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.32907918095588684  MAE:0.47582104802131653
# ▶ seg61  mean  MSE:0.32907918095588684  MAE:0.47582104802131653
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.14250236749649048  MAE:0.2932642698287964
# ▶ seg62  mean  MSE:0.14250236749649048  MAE:0.2932642698287964
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.15954357385635376  MAE:0.3140409290790558
# ▶ seg63  mean  MSE:0.15954357385635376  MAE:0.3140409290790558
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.09594252705574036  MAE:0.24083498120307922
# ▶ seg64  mean  MSE:0.09594252705574036  MAE:0.24083498120307922
#
# seg10 ch0 MSE : 0.24147354

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTh1_train = torch.load("./1st_results_ETTh1/train_1st_results.pt")
results1_ETTh1_val = torch.load("./1st_results_ETTh1/val_1st_results.pt")
results1_ETTh1_test = torch.load("./1st_results_ETTh1/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.137560
#
#   Top  1 | seg 07 | MSE 0.114038 (+0.023523)
#   Top  2 | seg 55 | MSE 0.114438 (+0.023122)
#   Top  3 | seg 48 | MSE 0.115126 (+0.022434)
#   Top  4 | seg 03 | MSE 0.115830 (+0.021730)
#   Top  5 | seg 47 | MSE 0.116431 (+0.021129)
#   Top  6 | seg 05 | MSE 0.116578 (+0.020982)
#   Top  7 | seg 11 | MSE 0.116661 (+0.020899)
#   Top  8 | seg 50 | MSE 0.116735 (+0.020826)
#   Top  9 | seg 14 | MSE 0.117033 (+0.020527)
#   Top 10 | seg 42 | MSE 0.117099 (+0.020461)
#   Top 11 | seg 56 | MSE 0.117260 (+0.020300)
#   Top 12 | seg 34 | MSE 0.117524 (+0.020036)
#   Top 13 | seg 08 | MSE 0.117538 (+0.020022)
#   Top 14 | seg 16 | MSE 0.117576 (+0.019984)
#   Top 15 | seg 06 | MSE 0.118145 (+0.019415)
#   Top 16 | seg 23 | MSE 0.118547 (+0.019013)
#   Top 17 | seg 27 | MSE 0.118563 (+0.018997)
#   Top 18 | seg 35 | MSE 0.118836 (+0.018724)
#   Top 19 | seg 20 | MSE 0.118933 (+0.018628)
#   Top 20 | seg 19 | MSE 0.119614 (+0.017946)
#   Top 21 | seg 59 | MSE 0.119728 (+0.017832)
#   Top 22 | seg 18 | MSE 0.120045 (+0.017515)
#   Top 23 | seg 17 | MSE 0.120427 (+0.017133)
#   Top 24 | seg 24 | MSE 0.120621 (+0.016939)
#   Top 25 | seg 49 | MSE 0.120694 (+0.016867)
#   Top 26 | seg 32 | MSE 0.120727 (+0.016833)
#   Top 27 | seg 53 | MSE 0.121021 (+0.016540)
#   Top 28 | seg 28 | MSE 0.121391 (+0.016170)
#   Top 29 | seg 15 | MSE 0.121432 (+0.016128)
#   Top 30 | seg 01 | MSE 0.121633 (+0.015927)
#   Top 31 | seg 12 | MSE 0.121797 (+0.015764)
#   Top 32 | seg 13 | MSE 0.121969 (+0.015591)
#   Top 33 | seg 04 | MSE 0.122204 (+0.015356)
#   Top 34 | seg 45 | MSE 0.122280 (+0.015280)
#   Top 35 | seg 43 | MSE 0.122678 (+0.014882)
#   Top 36 | seg 30 | MSE 0.122941 (+0.014620)
#   Top 37 | seg 00 | MSE 0.123675 (+0.013885)
#   Top 38 | seg 26 | MSE 0.123834 (+0.013726)
#   Top 39 | seg 38 | MSE 0.124036 (+0.013524)
#   Top 40 | seg 62 | MSE 0.124068 (+0.013492)
#   Top 41 | seg 60 | MSE 0.124201 (+0.013360)
#   Top 42 | seg 40 | MSE 0.124256 (+0.013304)
#   Top 43 | seg 46 | MSE 0.124345 (+0.013216)
#   Top 44 | seg 25 | MSE 0.124345 (+0.013216)
#   Top 45 | seg 21 | MSE 0.124394 (+0.013166)
#   Top 46 | seg 54 | MSE 0.124433 (+0.013127)
#   Top 47 | seg 37 | MSE 0.125647 (+0.011913)
#   Top 48 | seg 52 | MSE 0.125672 (+0.011888)
#   Top 49 | seg 61 | MSE 0.125884 (+0.011676)
#   Top 50 | seg 33 | MSE 0.126325 (+0.011235)
#   Top 51 | seg 51 | MSE 0.126982 (+0.010578)
#   Top 52 | seg 31 | MSE 0.127441 (+0.010119)
#   Top 53 | seg 09 | MSE 0.127760 (+0.009800)
#   Top 54 | seg 02 | MSE 0.128171 (+0.009389)
#   Top 55 | seg 44 | MSE 0.129609 (+0.007951)
#   Top 56 | seg 58 | MSE 0.129909 (+0.007651)
#   Top 57 | seg 41 | MSE 0.130166 (+0.007394)
#   Top 58 | seg 29 | MSE 0.133691 (+0.003869)
#   Top 59 | seg 10 | MSE 0.134000 (+0.003560)
#   Top 60 | seg 57 | MSE 0.135015 (+0.002545)
#   Top 61 | seg 22 | MSE 0.135592 (+0.001968)
#   Top 62 | seg 64 | MSE 0.137620 (-0.000060)
#   Top 63 | seg 39 | MSE 0.140198 (-0.002638)
#   Top 64 | seg 63 | MSE 0.144819 (-0.007259)
#   Top 65 | seg 36 | MSE 0.148993 (-0.011433)
#
# Saved top segment indices per channel:
# Channel 0: [7, 55, 48, 3, 47, 5, 11, 50, 14, 42, 56, 34, 8, 16, 6, 23, 27, 35, 20, 19, 59, 18, 17, 24, 49, 32, 53, 28, 15, 1, 12, 13, 4, 45, 43, 30, 0, 26, 38, 62, 60, 40, 46, 25, 21, 54, 37, 52, 61, 33, 51, 31, 9, 2, 44, 58, 41, 29, 10, 57, 22, 64, 39, 63, 36]

# %% [markdown]
# ### 1E->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0
#   Top 54 | seg 56 | MSE 0.128776 (+0.008785)
#   Top 55 | seg 53 | MSE 0.130594 (+0.006966)
#   Top 56 | seg 10 | MSE 0.130887 (+0.006673)
#   Top 57 | seg 06 | MSE 0.131253 (+0.006307)
#   Top 58 | seg 49 | MSE 0.131891 (+0.005670)
#   Top 59 | seg 11 | MSE 0.133720 (+0.003841)
#   Top 60 | seg 07 | MSE 0.134859 (+0.002702)
#   Top 61 | seg 36 | MSE 0.138476 (-0.000915)
#   Top 62 | seg 61 | MSE 0.140704 (-0.003144)
#   Top 63 | seg 25 | MSE 0.145638 (-0.008078)
#   Top 64 | seg 55 | MSE 0.155267 (-0.017706)
#   Top 65 | seg 44 | MSE 0.188775 (-0.051215)
#
# Saved top segment indices per channel:
# Channel 0: [24, 58, 30, 3, 57, 15, 64, 28, 59, 33, 8, 23, 21, 1, 19, 0, 38, 29, 17, 52, 43, 47, 42, 51, 41, 34, 27, 62, 40, 14, 20, 46, 5, 13, 18, 37, 35, 32, 16, 2, 4, 45, 50, 9, 26, 31, 39, 12, 54, 60, 63, 22, 48, 56, 53, 10, 6, 49, 11, 7, 36, 61, 25, 55, 44]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTh1_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.072676 | MAE : 0.212649
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.733e-02 | |ρ|=0.7892 | S=1.0000
#    K=10 | Var=2.949e-02 | |ρ|=0.7737 | S=0.9455
#    K=15 | Var=3.279e-02 | |ρ|=0.7621 | S=0.9360
#    K=20 | Var=3.994e-02 | |ρ|=0.7386 | S=0.9263
#    K=25 | Var=4.141e-02 | |ρ|=0.7291 | S=0.8949 <- pick
#    K=30 | Var=4.553e-02 | |ρ|=0.7237 | S=0.9393
#    K=35 | Var=5.042e-02 | |ρ|=0.7075 | S=0.9319
#    K=40 | Var=5.647e-02 | |ρ|=0.6985 | S=0.9905
#    K=45 | Var=5.882e-02 | |ρ|=0.6906 | S=0.9861
#    K=50 | Var=6.135e-02 | |ρ|=0.6822 | S=0.9817
#    K=55 | Var=6.681e-02 | |ρ|=0.6623 | S=0.9619
#    K=60 | Var=7.178e-02 | |ρ|=0.6457 | S=0.9538
#    K=65 | Var=8.045e-02 | |ρ|=0.6267 | S=1.0000
# [Var-Corr]  K=25
#   MSE = 0.071661 | Δ = +0.001015 | Δ% = +1.40%
#   MAE = 0.206123 | Δ = +0.006526 | Δ% = +3.07%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.072676
# Ensemble mean MSE : 0.071661
# Average Δ MSE     : +0.001015
# Average Δ MSE (%) : +1.40%
#
# Vanilla  mean MAE : 0.212649
# Ensemble mean MAE : 0.206123
# Average Δ MAE     : +0.006526
# Average Δ MAE (%) : +3.07%

# %% [markdown]
# ## 1E->1E

# %%
results1_ETTh1_test['ES']['mae_test_EES']
# Out:
# 0.21264927089214325

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTh1_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.35   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.072676 | MAE : 0.212649
#   — Var / |Corr| / Score —
#    K= 5 | Var=3.366e-02 | |ρ|=0.7742 | S=1.3553
#    K=10 | Var=3.334e-02 | |ρ|=0.7652 | S=1.2755
#    K=15 | Var=3.880e-02 | |ρ|=0.7436 | S=1.1870
#    K=20 | Var=4.190e-02 | |ρ|=0.7395 | S=1.2037
#    K=25 | Var=4.681e-02 | |ρ|=0.7263 | S=1.1747
#    K=30 | Var=5.155e-02 | |ρ|=0.7054 | S=1.0793
#    K=35 | Var=5.297e-02 | |ρ|=0.6983 | S=1.0442
#    K=40 | Var=5.410e-02 | |ρ|=0.6925 | S=1.0149
#    K=45 | Var=5.981e-02 | |ρ|=0.6810 | S=1.0131
#    K=50 | Var=6.322e-02 | |ρ|=0.6657 | S=0.9420
#    K=55 | Var=6.774e-02 | |ρ|=0.6491 | S=0.8792 <- pick
#    K=60 | Var=7.476e-02 | |ρ|=0.6412 | S=0.9288
#    K=65 | Var=9.423e-02 | |ρ|=0.6112 | S=1.0000
# [Var-Corr]  K=55
#    MSE = 0.072879 | Δ = -0.000203 | Δ% = -0.28%
#    MAE = 0.206608 | Δ = +0.006041 | Δ% = +2.84%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.072676
# Ensemble mean MSE  : 0.072879
# Average Δ MSE      : -0.000203
# Average Δ MSE (%)  : -0.28%
#
# Vanilla  mean MAE  : 0.212649
# Ensemble mean MAE  : 0.206608
# Average Δ MAE      : +0.006041
# Average Δ MAE (%)  : +2.84%
