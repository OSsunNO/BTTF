# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(2)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 2
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTm2.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                           HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# date
# 2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 2016-07-01 00:15:00  39.622002  11.309  35.543999  8.551  3.209  1.258
# 2016-07-01 00:30:00  38.868000  10.555  34.365002  7.586  4.435  1.258
# 2016-07-01 00:45:00  35.518002   9.214  32.569000  8.712  4.435  1.215
# 2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
#
#                             OT
# date
# 2016-07-01 00:00:00  38.661999
# 2016-07-01 00:15:00  38.223000
# 2016-07-01 00:30:00  37.344002
# 2016-07-01 00:45:00  37.124001
# 2016-07-01 01:00:00  37.124001

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (69680, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 00:15:00',
#                '2016-07-01 00:30:00', '2016-07-01 00:45:00',
#                '2016-07-01 01:00:00', '2016-07-01 01:15:00',
#                '2016-07-01 01:30:00', '2016-07-01 01:45:00',
#                '2016-07-01 02:00:00', '2016-07-01 02:15:00',
#                ...
#                '2018-06-26 17:30:00', '2018-06-26 17:45:00',
#                '2018-06-26 18:00:00', '2018-06-26 18:15:00',
#                '2018-06-26 18:30:00', '2018-06-26 18:45:00',
#                '2018-06-26 19:00:00', '2018-06-26 19:15:00',
#                '2018-06-26 19:30:00', '2018-06-26 19:45:00'],
#               dtype='datetime64[ns]', name='date', length=69680, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Decomposition-Linear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.individual = configs.individual
        self.channels = configs.enc_in
        self.attach_to_trend = configs.attach_to_trend
        self.attach_to_seasonal = configs.attach_to_seasonal
        

        
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        

        
        self.seq_len_trend = self.seq_len + (self.pred_len // 3) if self.attach_to_trend else self.seq_len
        self.seq_len_seasonal = self.seq_len + (self.pred_len // 3) if self.attach_to_seasonal else self.seq_len

        
        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))

                
                
                
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            
            
            
            

    def forward(self, x, ground_truth=None):
        
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if ground_truth is not None:
            kernel_size = 25
            self.decompsition = series_decomp(kernel_size)
            ground_truth_seasonal, ground_truth_trend = self.decompsition(ground_truth)

            
            if self.seq_len_seasonal > self.seq_len:
                ground_truth_seasonal=ground_truth_seasonal.permute(0, 2, 1)
                
                seasonal_init = torch.cat([seasonal_init, ground_truth_seasonal], dim=2)
            if self.seq_len_trend > self.seq_len:
                ground_truth_trend=ground_truth_trend.permute(0, 2, 1)
                
                trend_init = torch.cat([trend_init, ground_truth_trend], dim=2)
        
        
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 192




train_points = 12 * 30 * 24 * 4
val_points   = 4  * 30 * 24 * 4
test_points  = 4  * 30 * 24 * 4

border1s = [
    0,
    train_points - seq_len,
    train_points + val_points - seq_len
]
border2s = [
    train_points,
    train_points + val_points,
    train_points + val_points + test_points
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([34033, 336, 1])
# Train Labels:    torch.Size([34033, 192, 1])
# Val Sequences:   torch.Size([11329, 336, 1])
# Val Labels:      torch.Size([11329, 192, 1])
# Test Sequences:  torch.Size([11329, 336, 1])
# Test Labels:     torch.Size([11329, 192, 1])

# %%
set_seed(43)

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 192  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.001, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.002
# Epoch 0 | Train Loss: 0.15131372262380624 | Val Loss: 0.13896064913871004
# Validation loss decreased (inf --> 0.138961).  Saving model ...
# Updating learning rate to 0.001
# Epoch 1 | Train Loss: 0.1384607163376938 | Val Loss: 0.13306464416722596
# Validation loss decreased (0.138961 --> 0.133065).  Saving model ...
# Updating learning rate to 0.0005
# Epoch 2 | Train Loss: 0.13544032836150854 | Val Loss: 0.13394976118579507
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# Epoch 3 | Train Loss: 0.1333655908325673 | Val Loss: 0.13379265932549894
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.000125
# Epoch 4 | Train Loss: 0.1325680635785474 | Val Loss: 0.13155445385409492
# Validation loss decreased (0.133065 --> 0.131554).  Saving model ...
# Updating learning rate to 6.25e-05
# Epoch 5 | Train Loss: 0.1319771354415811 | Val Loss: 0.1308588186987269
# Validation loss decreased (0.131554 --> 0.130859).  Saving model ...
# Updating learning rate to 3.125e-05
# Epoch 6 | Train Loss: 0.13159781090803163 | Val Loss: 0.13178438630847025
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.5625e-05
# Epoch 7 | Train Loss: 0.1314579010345882 | Val Loss: 0.13104753451500561
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.8125e-06
# Epoch 8 | Train Loss: 0.13138230010531002 | Val Loss: 0.1308621787800598
# EarlyStopping counter: 3 out of 3
# Early stopping triggered. Stopping training.

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 192  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.001, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.002
# Epoch 0 | Train Loss: 0.1522932508610245 | Val Loss: 0.14822456174018517
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.09137295931577682 | MAE: 0.22588162124156952
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.12336712330579758 | MAE: 0.2710951566696167

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.13115525245666504 | MAE: 0.2634725272655487
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.14857861399650574 | MAE: 0.299867182970047

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.13174788653850555 | MAE: 0.2593616545200348
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.14686881005764008 | MAE: 0.28785496950149536

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([34033, 336, 1])
# val_sequences shape:  torch.Size([11329, 336, 1])
# test_sequences shape:  torch.Size([11329, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([34033, 192, 1])
# val_pv shape:  torch.Size([11329, 192, 1])
# test_pv shape:  torch.Size([11329, 192, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([34033, 192, 1])
# val_labels shape:  torch.Size([11329, 192, 1])
# test_labels shape:  torch.Size([11329, 192, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 192

# %%
segment_len = configs.pred_len // 3
stride = 2

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([34033, 65, 64, 1]), Val: torch.Size([11329, 65, 64, 1]), Test: torch.Size([11329, 65, 64, 1])
# [Epoch 1] Train seg shape: torch.Size([34033, 65, 64, 1]), Val: torch.Size([11329, 65, 64, 1]), Test: torch.Size([11329, 65, 64, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTm2'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 192,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 0] Training Time = 4.22 sec
# [Segment 0] GPU Memory Start = 4287.66 MB
# [Segment 0] GPU Memory End   = 3296.56 MB
# [Segment 0] GPU Peak Memory  = 4287.66 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 1] Training Time = 4.22 sec
# [Segment 1] GPU Memory Start = 3296.56 MB
# [Segment 1] GPU Memory End   = 3297.15 MB
# [Segment 1] GPU Peak Memory  = 3298.41 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 2] Training Time = 4.33 sec
# [Segment 2] GPU Memory Start = 3297.15 MB
# [Segment 2] GPU Memory End   = 3297.74 MB
# [Segment 2] GPU Peak Memory  = 3299.00 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 3] Training Time = 5.22 sec
# [Segment 3] GPU Memory Start = 3297.74 MB
# [Segment 3] GPU Memory End   = 3298.33 MB
# [Segment 3] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 4] Training Time = 5.13 sec
# [Segment 4] GPU Memory Start = 3298.33 MB
# [Segment 4] GPU Memory End   = 3298.91 MB
# [Segment 4] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 5] Training Time = 5.18 sec
# [Segment 5] GPU Memory Start = 3298.91 MB
# [Segment 5] GPU Memory End   = 3299.50 MB
# [Segment 5] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 6] Training Time = 3.47 sec
# [Segment 6] GPU Memory Start = 3299.50 MB
# [Segment 6] GPU Memory End   = 3300.09 MB
# [Segment 6] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 7] Training Time = 3.99 sec
# [Segment 7] GPU Memory Start = 3300.09 MB
# [Segment 7] GPU Memory End   = 3300.68 MB
# [Segment 7] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 8] Training Time = 4.28 sec
# [Segment 8] GPU Memory Start = 3300.68 MB
# [Segment 8] GPU Memory End   = 3301.27 MB
# [Segment 8] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 9] Training Time = 4.26 sec
# [Segment 9] GPU Memory Start = 3301.27 MB
# [Segment 9] GPU Memory End   = 3301.85 MB
# [Segment 9] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 10] Training Time = 4.27 sec
# [Segment 10] GPU Memory Start = 3296.56 MB
# [Segment 10] GPU Memory End   = 3297.15 MB
# [Segment 10] GPU Peak Memory  = 3298.41 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 11] Training Time = 3.28 sec
# [Segment 11] GPU Memory Start = 3297.15 MB
# [Segment 11] GPU Memory End   = 3297.74 MB
# [Segment 11] GPU Peak Memory  = 3299.00 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 12] Training Time = 4.55 sec
# [Segment 12] GPU Memory Start = 3297.74 MB
# [Segment 12] GPU Memory End   = 3298.33 MB
# [Segment 12] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 13] Training Time = 3.91 sec
# [Segment 13] GPU Memory Start = 3298.33 MB
# [Segment 13] GPU Memory End   = 3298.91 MB
# [Segment 13] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 14] Training Time = 3.72 sec
# [Segment 14] GPU Memory Start = 3298.91 MB
# [Segment 14] GPU Memory End   = 3299.50 MB
# [Segment 14] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 15] Training Time = 3.81 sec
# [Segment 15] GPU Memory Start = 3299.50 MB
# [Segment 15] GPU Memory End   = 3300.09 MB
# [Segment 15] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 16] Training Time = 4.53 sec
# [Segment 16] GPU Memory Start = 3300.09 MB
# [Segment 16] GPU Memory End   = 3300.68 MB
# [Segment 16] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 17] Training Time = 4.40 sec
# [Segment 17] GPU Memory Start = 3300.68 MB
# [Segment 17] GPU Memory End   = 3301.27 MB
# [Segment 17] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 18] Training Time = 4.36 sec
# [Segment 18] GPU Memory Start = 3301.27 MB
# [Segment 18] GPU Memory End   = 3301.85 MB
# [Segment 18] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 19] Training Time = 3.74 sec
# [Segment 19] GPU Memory Start = 3301.85 MB
# [Segment 19] GPU Memory End   = 3296.56 MB
# [Segment 19] GPU Peak Memory  = 3302.44 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 20] Training Time = 3.75 sec
# [Segment 20] GPU Memory Start = 3296.56 MB
# [Segment 20] GPU Memory End   = 3297.15 MB
# [Segment 20] GPU Peak Memory  = 3298.41 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 21] Training Time = 4.66 sec
# [Segment 21] GPU Memory Start = 3297.15 MB
# [Segment 21] GPU Memory End   = 3297.74 MB
# [Segment 21] GPU Peak Memory  = 3299.00 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 22] Training Time = 4.24 sec
# [Segment 22] GPU Memory Start = 3297.74 MB
# [Segment 22] GPU Memory End   = 3298.33 MB
# [Segment 22] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 23] Training Time = 3.54 sec
# [Segment 23] GPU Memory Start = 3298.33 MB
# [Segment 23] GPU Memory End   = 3298.91 MB
# [Segment 23] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 24] Training Time = 3.65 sec
# [Segment 24] GPU Memory Start = 3298.91 MB
# [Segment 24] GPU Memory End   = 3299.50 MB
# [Segment 24] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 25] Training Time = 3.90 sec
# [Segment 25] GPU Memory Start = 3299.50 MB
# [Segment 25] GPU Memory End   = 3300.09 MB
# [Segment 25] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 26] Training Time = 4.29 sec
# [Segment 26] GPU Memory Start = 3300.09 MB
# [Segment 26] GPU Memory End   = 3300.68 MB
# [Segment 26] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 27] Training Time = 4.31 sec
# [Segment 27] GPU Memory Start = 3300.68 MB
# [Segment 27] GPU Memory End   = 3301.27 MB
# [Segment 27] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 28] Training Time = 3.99 sec
# [Segment 28] GPU Memory Start = 3301.27 MB
# [Segment 28] GPU Memory End   = 3301.85 MB
# [Segment 28] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 29] Training Time = 4.01 sec
# [Segment 29] GPU Memory Start = 3296.56 MB
# [Segment 29] GPU Memory End   = 3297.15 MB
# [Segment 29] GPU Peak Memory  = 3298.41 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 30] Training Time = 4.01 sec
# [Segment 30] GPU Memory Start = 3297.15 MB
# [Segment 30] GPU Memory End   = 3297.74 MB
# [Segment 30] GPU Peak Memory  = 3299.00 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 31] Training Time = 4.76 sec
# [Segment 31] GPU Memory Start = 3297.74 MB
# [Segment 31] GPU Memory End   = 3298.33 MB
# [Segment 31] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 32] Training Time = 4.10 sec
# [Segment 32] GPU Memory Start = 3298.33 MB
# [Segment 32] GPU Memory End   = 3298.91 MB
# [Segment 32] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 33] Training Time = 4.21 sec
# [Segment 33] GPU Memory Start = 3298.91 MB
# [Segment 33] GPU Memory End   = 3299.50 MB
# [Segment 33] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 34] Training Time = 5.19 sec
# [Segment 34] GPU Memory Start = 3299.50 MB
# [Segment 34] GPU Memory End   = 3300.09 MB
# [Segment 34] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 35] Training Time = 3.52 sec
# [Segment 35] GPU Memory Start = 3300.09 MB
# [Segment 35] GPU Memory End   = 3300.68 MB
# [Segment 35] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 36] Training Time = 4.23 sec
# [Segment 36] GPU Memory Start = 3300.68 MB
# [Segment 36] GPU Memory End   = 3301.27 MB
# [Segment 36] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 37] Training Time = 3.70 sec
# [Segment 37] GPU Memory Start = 3301.27 MB
# [Segment 37] GPU Memory End   = 3301.85 MB
# [Segment 37] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 38] Training Time = 5.64 sec
# [Segment 38] GPU Memory Start = 3301.85 MB
# [Segment 38] GPU Memory End   = 3297.15 MB
# [Segment 38] GPU Peak Memory  = 3302.44 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 39] Training Time = 4.21 sec
# [Segment 39] GPU Memory Start = 3297.15 MB
# [Segment 39] GPU Memory End   = 3297.74 MB
# [Segment 39] GPU Peak Memory  = 3299.00 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 40] Training Time = 2.68 sec
# [Segment 40] GPU Memory Start = 3297.74 MB
# [Segment 40] GPU Memory End   = 3298.33 MB
# [Segment 40] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 41] Training Time = 4.07 sec
# [Segment 41] GPU Memory Start = 3298.33 MB
# [Segment 41] GPU Memory End   = 3298.91 MB
# [Segment 41] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 42] Training Time = 2.19 sec
# [Segment 42] GPU Memory Start = 3298.91 MB
# [Segment 42] GPU Memory End   = 3299.50 MB
# [Segment 42] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 43] Training Time = 4.22 sec
# [Segment 43] GPU Memory Start = 3299.50 MB
# [Segment 43] GPU Memory End   = 3300.09 MB
# [Segment 43] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 44] Training Time = 3.22 sec
# [Segment 44] GPU Memory Start = 3300.09 MB
# [Segment 44] GPU Memory End   = 3300.68 MB
# [Segment 44] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 45] Training Time = 4.00 sec
# [Segment 45] GPU Memory Start = 3300.68 MB
# [Segment 45] GPU Memory End   = 3301.27 MB
# [Segment 45] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 46] Training Time = 3.64 sec
# [Segment 46] GPU Memory Start = 3301.27 MB
# [Segment 46] GPU Memory End   = 3301.85 MB
# [Segment 46] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 47] Training Time = 3.24 sec
# [Segment 47] GPU Memory Start = 3301.85 MB
# [Segment 47] GPU Memory End   = 3302.44 MB
# [Segment 47] GPU Peak Memory  = 3303.70 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 48] Training Time = 2.80 sec
# [Segment 48] GPU Memory Start = 3297.15 MB
# [Segment 48] GPU Memory End   = 3297.74 MB
# [Segment 48] GPU Peak Memory  = 3299.00 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 49] Training Time = 4.41 sec
# [Segment 49] GPU Memory Start = 3297.74 MB
# [Segment 49] GPU Memory End   = 3298.33 MB
# [Segment 49] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 50] Training Time = 3.21 sec
# [Segment 50] GPU Memory Start = 3298.33 MB
# [Segment 50] GPU Memory End   = 3298.91 MB
# [Segment 50] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 51] Training Time = 3.18 sec
# [Segment 51] GPU Memory Start = 3298.91 MB
# [Segment 51] GPU Memory End   = 3299.50 MB
# [Segment 51] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 52] Training Time = 2.26 sec
# [Segment 52] GPU Memory Start = 3299.50 MB
# [Segment 52] GPU Memory End   = 3300.09 MB
# [Segment 52] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 53] Training Time = 3.97 sec
# [Segment 53] GPU Memory Start = 3300.09 MB
# [Segment 53] GPU Memory End   = 3300.68 MB
# [Segment 53] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 54] Training Time = 3.68 sec
# [Segment 54] GPU Memory Start = 3300.68 MB
# [Segment 54] GPU Memory End   = 3301.27 MB
# [Segment 54] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 55] Training Time = 2.80 sec
# [Segment 55] GPU Memory Start = 3301.27 MB
# [Segment 55] GPU Memory End   = 3301.85 MB
# [Segment 55] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 56] Training Time = 3.16 sec
# [Segment 56] GPU Memory Start = 3301.85 MB
# [Segment 56] GPU Memory End   = 3302.44 MB
# [Segment 56] GPU Peak Memory  = 3303.70 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 57] Training Time = 2.99 sec
# [Segment 57] GPU Memory Start = 3302.44 MB
# [Segment 57] GPU Memory End   = 3297.74 MB
# [Segment 57] GPU Peak Memory  = 3303.03 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 58] Training Time = 2.62 sec
# [Segment 58] GPU Memory Start = 3297.74 MB
# [Segment 58] GPU Memory End   = 3298.33 MB
# [Segment 58] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 59] Training Time = 3.73 sec
# [Segment 59] GPU Memory Start = 3298.33 MB
# [Segment 59] GPU Memory End   = 3298.91 MB
# [Segment 59] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 60] Training Time = 4.00 sec
# [Segment 60] GPU Memory Start = 3298.91 MB
# [Segment 60] GPU Memory End   = 3299.50 MB
# [Segment 60] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 61] Training Time = 4.18 sec
# [Segment 61] GPU Memory Start = 3299.50 MB
# [Segment 61] GPU Memory End   = 3300.09 MB
# [Segment 61] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 62] Training Time = 4.59 sec
# [Segment 62] GPU Memory Start = 3300.09 MB
# [Segment 62] GPU Memory End   = 3300.68 MB
# [Segment 62] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 63] Training Time = 4.65 sec
# [Segment 63] GPU Memory Start = 3300.68 MB
# [Segment 63] GPU Memory End   = 3301.27 MB
# [Segment 63] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 64] Training Time = 5.22 sec
# [Segment 64] GPU Memory Start = 3301.27 MB
# [Segment 64] GPU Memory End   = 3301.85 MB
# [Segment 64] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 192,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E/",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 0] Training Time = 5.52 sec
# [Segment 0] GPU Memory Start = 3297.74 MB
# [Segment 0] GPU Memory End   = 3297.74 MB
# [Segment 0] GPU Peak Memory  = 3299.56 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 1] Training Time = 6.01 sec
# [Segment 1] GPU Memory Start = 3297.74 MB
# [Segment 1] GPU Memory End   = 3298.33 MB
# [Segment 1] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 2] Training Time = 6.16 sec
# [Segment 2] GPU Memory Start = 3298.33 MB
# [Segment 2] GPU Memory End   = 3298.91 MB
# [Segment 2] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 3] Training Time = 5.07 sec
# [Segment 3] GPU Memory Start = 3298.91 MB
# [Segment 3] GPU Memory End   = 3297.74 MB
# [Segment 3] GPU Peak Memory  = 3299.56 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 4] Training Time = 6.71 sec
# [Segment 4] GPU Memory Start = 3297.74 MB
# [Segment 4] GPU Memory End   = 3298.33 MB
# [Segment 4] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 5] Training Time = 6.13 sec
# [Segment 5] GPU Memory Start = 3298.33 MB
# [Segment 5] GPU Memory End   = 3298.91 MB
# [Segment 5] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 6] Training Time = 8.52 sec
# [Segment 6] GPU Memory Start = 3298.91 MB
# [Segment 6] GPU Memory End   = 3299.50 MB
# [Segment 6] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 7] Training Time = 8.92 sec
# [Segment 7] GPU Memory Start = 3299.50 MB
# [Segment 7] GPU Memory End   = 3300.09 MB
# [Segment 7] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 8] Training Time = 8.88 sec
# [Segment 8] GPU Memory Start = 3300.09 MB
# [Segment 8] GPU Memory End   = 3300.68 MB
# [Segment 8] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 9] Training Time = 8.54 sec
# [Segment 9] GPU Memory Start = 3300.68 MB
# [Segment 9] GPU Memory End   = 3301.27 MB
# [Segment 9] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 10] Training Time = 8.40 sec
# [Segment 10] GPU Memory Start = 3301.27 MB
# [Segment 10] GPU Memory End   = 3301.85 MB
# [Segment 10] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 11] Training Time = 8.16 sec
# [Segment 11] GPU Memory Start = 3301.85 MB
# [Segment 11] GPU Memory End   = 3302.44 MB
# [Segment 11] GPU Peak Memory  = 3303.70 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 12] Training Time = 9.35 sec
# [Segment 12] GPU Memory Start = 3302.44 MB
# [Segment 12] GPU Memory End   = 3303.03 MB
# [Segment 12] GPU Peak Memory  = 3304.29 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 13] Training Time = 8.32 sec
# [Segment 13] GPU Memory Start = 3296.56 MB
# [Segment 13] GPU Memory End   = 3297.15 MB
# [Segment 13] GPU Peak Memory  = 3298.41 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 14] Training Time = 7.86 sec
# [Segment 14] GPU Memory Start = 3297.15 MB
# [Segment 14] GPU Memory End   = 3297.74 MB
# [Segment 14] GPU Peak Memory  = 3299.00 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 15] Training Time = 7.63 sec
# [Segment 15] GPU Memory Start = 3297.74 MB
# [Segment 15] GPU Memory End   = 3298.33 MB
# [Segment 15] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 16] Training Time = 4.15 sec
# [Segment 16] GPU Memory Start = 3298.33 MB
# [Segment 16] GPU Memory End   = 3298.91 MB
# [Segment 16] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 17] Training Time = 3.97 sec
# [Segment 17] GPU Memory Start = 3298.91 MB
# [Segment 17] GPU Memory End   = 3299.50 MB
# [Segment 17] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 18] Training Time = 4.26 sec
# [Segment 18] GPU Memory Start = 3299.50 MB
# [Segment 18] GPU Memory End   = 3300.09 MB
# [Segment 18] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 19] Training Time = 3.85 sec
# [Segment 19] GPU Memory Start = 3300.09 MB
# [Segment 19] GPU Memory End   = 3300.68 MB
# [Segment 19] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 20] Training Time = 4.17 sec
# [Segment 20] GPU Memory Start = 3300.68 MB
# [Segment 20] GPU Memory End   = 3301.27 MB
# [Segment 20] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 21] Training Time = 9.04 sec
# [Segment 21] GPU Memory Start = 3301.27 MB
# [Segment 21] GPU Memory End   = 3301.85 MB
# [Segment 21] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 22] Training Time = 9.26 sec
# [Segment 22] GPU Memory Start = 3301.85 MB
# [Segment 22] GPU Memory End   = 3297.15 MB
# [Segment 22] GPU Peak Memory  = 3302.44 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 23] Training Time = 9.89 sec
# [Segment 23] GPU Memory Start = 3297.15 MB
# [Segment 23] GPU Memory End   = 3297.74 MB
# [Segment 23] GPU Peak Memory  = 3299.00 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 24] Training Time = 10.32 sec
# [Segment 24] GPU Memory Start = 3297.74 MB
# [Segment 24] GPU Memory End   = 3298.33 MB
# [Segment 24] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 25] Training Time = 10.00 sec
# [Segment 25] GPU Memory Start = 3298.33 MB
# [Segment 25] GPU Memory End   = 3298.91 MB
# [Segment 25] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 26] Training Time = 9.96 sec
# [Segment 26] GPU Memory Start = 3298.91 MB
# [Segment 26] GPU Memory End   = 3299.50 MB
# [Segment 26] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 27] Training Time = 10.10 sec
# [Segment 27] GPU Memory Start = 3299.50 MB
# [Segment 27] GPU Memory End   = 3300.09 MB
# [Segment 27] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 28] Training Time = 9.74 sec
# [Segment 28] GPU Memory Start = 3300.09 MB
# [Segment 28] GPU Memory End   = 3300.68 MB
# [Segment 28] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 29] Training Time = 9.40 sec
# [Segment 29] GPU Memory Start = 3300.68 MB
# [Segment 29] GPU Memory End   = 3301.27 MB
# [Segment 29] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 30] Training Time = 9.66 sec
# [Segment 30] GPU Memory Start = 3301.27 MB
# [Segment 30] GPU Memory End   = 3301.85 MB
# [Segment 30] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 31] Training Time = 9.47 sec
# [Segment 31] GPU Memory Start = 3301.85 MB
# [Segment 31] GPU Memory End   = 3302.44 MB
# [Segment 31] GPU Peak Memory  = 3303.70 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 32] Training Time = 9.57 sec
# [Segment 32] GPU Memory Start = 3297.15 MB
# [Segment 32] GPU Memory End   = 3297.74 MB
# [Segment 32] GPU Peak Memory  = 3299.00 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 33] Training Time = 10.14 sec
# [Segment 33] GPU Memory Start = 3297.74 MB
# [Segment 33] GPU Memory End   = 3298.33 MB
# [Segment 33] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 34] Training Time = 10.19 sec
# [Segment 34] GPU Memory Start = 3298.33 MB
# [Segment 34] GPU Memory End   = 3298.91 MB
# [Segment 34] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 35] Training Time = 10.01 sec
# [Segment 35] GPU Memory Start = 3298.91 MB
# [Segment 35] GPU Memory End   = 3299.50 MB
# [Segment 35] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 36] Training Time = 4.87 sec
# [Segment 36] GPU Memory Start = 3299.50 MB
# [Segment 36] GPU Memory End   = 3300.09 MB
# [Segment 36] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 37] Training Time = 4.36 sec
# [Segment 37] GPU Memory Start = 3300.09 MB
# [Segment 37] GPU Memory End   = 3300.68 MB
# [Segment 37] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 38] Training Time = 4.58 sec
# [Segment 38] GPU Memory Start = 3300.68 MB
# [Segment 38] GPU Memory End   = 3301.27 MB
# [Segment 38] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 39] Training Time = 4.48 sec
# [Segment 39] GPU Memory Start = 3301.27 MB
# [Segment 39] GPU Memory End   = 3301.85 MB
# [Segment 39] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 40] Training Time = 4.15 sec
# [Segment 40] GPU Memory Start = 3301.85 MB
# [Segment 40] GPU Memory End   = 3302.44 MB
# [Segment 40] GPU Peak Memory  = 3303.70 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 41] Training Time = 8.76 sec
# [Segment 41] GPU Memory Start = 3302.44 MB
# [Segment 41] GPU Memory End   = 3297.74 MB
# [Segment 41] GPU Peak Memory  = 3303.03 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 42] Training Time = 9.98 sec
# [Segment 42] GPU Memory Start = 3297.74 MB
# [Segment 42] GPU Memory End   = 3298.33 MB
# [Segment 42] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 43] Training Time = 9.75 sec
# [Segment 43] GPU Memory Start = 3298.33 MB
# [Segment 43] GPU Memory End   = 3298.91 MB
# [Segment 43] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 44] Training Time = 9.95 sec
# [Segment 44] GPU Memory Start = 3298.91 MB
# [Segment 44] GPU Memory End   = 3299.50 MB
# [Segment 44] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 45] Training Time = 9.93 sec
# [Segment 45] GPU Memory Start = 3299.50 MB
# [Segment 45] GPU Memory End   = 3300.09 MB
# [Segment 45] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 46] Training Time = 10.18 sec
# [Segment 46] GPU Memory Start = 3300.09 MB
# [Segment 46] GPU Memory End   = 3300.68 MB
# [Segment 46] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 47] Training Time = 9.65 sec
# [Segment 47] GPU Memory Start = 3300.68 MB
# [Segment 47] GPU Memory End   = 3301.27 MB
# [Segment 47] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 48] Training Time = 10.22 sec
# [Segment 48] GPU Memory Start = 3301.27 MB
# [Segment 48] GPU Memory End   = 3301.85 MB
# [Segment 48] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 49] Training Time = 10.13 sec
# [Segment 49] GPU Memory Start = 3301.85 MB
# [Segment 49] GPU Memory End   = 3302.44 MB
# [Segment 49] GPU Peak Memory  = 3303.70 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 50] Training Time = 9.84 sec
# [Segment 50] GPU Memory Start = 3302.44 MB
# [Segment 50] GPU Memory End   = 3303.03 MB
# [Segment 50] GPU Peak Memory  = 3304.29 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 51] Training Time = 10.07 sec
# [Segment 51] GPU Memory Start = 3297.74 MB
# [Segment 51] GPU Memory End   = 3298.33 MB
# [Segment 51] GPU Peak Memory  = 3299.59 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 52] Training Time = 9.86 sec
# [Segment 52] GPU Memory Start = 3298.33 MB
# [Segment 52] GPU Memory End   = 3298.91 MB
# [Segment 52] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 53] Training Time = 10.13 sec
# [Segment 53] GPU Memory Start = 3298.91 MB
# [Segment 53] GPU Memory End   = 3299.50 MB
# [Segment 53] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 54] Training Time = 9.86 sec
# [Segment 54] GPU Memory Start = 3299.50 MB
# [Segment 54] GPU Memory End   = 3300.09 MB
# [Segment 54] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 55] Training Time = 9.52 sec
# [Segment 55] GPU Memory Start = 3300.09 MB
# [Segment 55] GPU Memory End   = 3300.68 MB
# [Segment 55] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 56] Training Time = 4.62 sec
# [Segment 56] GPU Memory Start = 3300.68 MB
# [Segment 56] GPU Memory End   = 3301.27 MB
# [Segment 56] GPU Peak Memory  = 3302.53 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 57] Training Time = 3.73 sec
# [Segment 57] GPU Memory Start = 3301.27 MB
# [Segment 57] GPU Memory End   = 3301.85 MB
# [Segment 57] GPU Peak Memory  = 3303.11 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 58] Training Time = 3.61 sec
# [Segment 58] GPU Memory Start = 3301.85 MB
# [Segment 58] GPU Memory End   = 3302.44 MB
# [Segment 58] GPU Peak Memory  = 3303.70 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 59] Training Time = 3.82 sec
# [Segment 59] GPU Memory Start = 3302.44 MB
# [Segment 59] GPU Memory End   = 3303.03 MB
# [Segment 59] GPU Peak Memory  = 3304.29 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 60] Training Time = 3.68 sec
# [Segment 60] GPU Memory Start = 3303.03 MB
# [Segment 60] GPU Memory End   = 3298.33 MB
# [Segment 60] GPU Peak Memory  = 3303.62 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 61] Training Time = 4.40 sec
# [Segment 61] GPU Memory Start = 3298.33 MB
# [Segment 61] GPU Memory End   = 3298.91 MB
# [Segment 61] GPU Peak Memory  = 3300.18 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 62] Training Time = 10.07 sec
# [Segment 62] GPU Memory Start = 3298.91 MB
# [Segment 62] GPU Memory End   = 3299.50 MB
# [Segment 62] GPU Peak Memory  = 3300.76 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 63] Training Time = 10.15 sec
# [Segment 63] GPU Memory Start = 3299.50 MB
# [Segment 63] GPU Memory End   = 3300.09 MB
# [Segment 63] GPU Peak Memory  = 3301.35 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 64] Training Time = 10.34 sec
# [Segment 64] GPU Memory Start = 3300.09 MB
# [Segment 64] GPU Memory End   = 3300.68 MB
# [Segment 64] GPU Peak Memory  = 3301.94 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.13566286861896515  MAE:0.2770567536354065
# ▶ seg0  mean  MSE:0.13566286861896515  MAE:0.2770567536354065
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.14346395432949066  MAE:0.27519935369491577
# ▶ seg1  mean  MSE:0.14346395432949066  MAE:0.27519935369491577
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.1382516622543335  MAE:0.27063846588134766
# ▶ seg2  mean  MSE:0.1382516622543335  MAE:0.27063846588134766
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.13917085528373718  MAE:0.2704051434993744
# ▶ seg3  mean  MSE:0.13917085528373718  MAE:0.2704051434993744
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.13617035746574402  MAE:0.27868834137916565
# ▶ seg4  mean  MSE:0.13617035746574402  MAE:0.27868834137916565
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.13578729331493378  MAE:0.269040584564209
# ▶ seg5  mean  MSE:0.13578729331493378  MAE:0.269040584564209
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.1366834044456482  MAE:0.2796509265899658
# ▶ seg6  mean  MSE:0.1366834044456482  MAE:0.2796509265899658
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.13698993623256683  MAE:0.2712741494178772
# ▶ seg7  mean  MSE:0.13698993623256683  MAE:0.2712741494178772
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.15557251870632172  MAE:0.3071799874305725
# ▶ seg8  mean  MSE:0.15557251870632172  MAE:0.3071799874305725
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.1356506496667862  MAE:0.27070409059524536
# ▶ seg9  mean  MSE:0.1356506496667862  MAE:0.27070409059524536
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.14083752036094666  MAE:0.28524959087371826
# ▶ seg10  mean  MSE:0.14083752036094666  MAE:0.28524959087371826
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.1456824392080307  MAE:0.27137237787246704
# ▶ seg11  mean  MSE:0.1456824392080307  MAE:0.27137237787246704
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.13237011432647705  MAE:0.26819896697998047
# ▶ seg46  mean  MSE:0.13237011432647705  MAE:0.26819896697998047
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.1356755942106247  MAE:0.27535802125930786
# ▶ seg47  mean  MSE:0.1356755942106247  MAE:0.27535802125930786
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.13692909479141235  MAE:0.27633634209632874
# ▶ seg48  mean  MSE:0.13692909479141235  MAE:0.27633634209632874
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.14244376122951508  MAE:0.27357757091522217
# ▶ seg49  mean  MSE:0.14244376122951508  MAE:0.27357757091522217
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.13608019053936005  MAE:0.2700210213661194
# ▶ seg50  mean  MSE:0.13608019053936005  MAE:0.2700210213661194
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.13750171661376953  MAE:0.27994298934936523
# ▶ seg51  mean  MSE:0.13750171661376953  MAE:0.27994298934936523
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.13819816708564758  MAE:0.2745467722415924
# ▶ seg52  mean  MSE:0.13819816708564758  MAE:0.2745467722415924
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.14250154793262482  MAE:0.2819400429725647
# ▶ seg53  mean  MSE:0.14250154793262482  MAE:0.2819400429725647
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.14184986054897308  MAE:0.26839444041252136
# ▶ seg54  mean  MSE:0.14184986054897308  MAE:0.26839444041252136
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.14595484733581543  MAE:0.2918838858604431
# ▶ seg55  mean  MSE:0.14595484733581543  MAE:0.2918838858604431
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.13458500802516937  MAE:0.27727869153022766
# ▶ seg56  mean  MSE:0.13458500802516937  MAE:0.27727869153022766
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.1500903218984604  MAE:0.2972424328327179
# ▶ seg57  mean  MSE:0.1500903218984604  MAE:0.2972424328327179
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.14371104538440704  MAE:0.2917202115058899
# ▶ seg58  mean  MSE:0.14371104538440704  MAE:0.2917202115058899
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.1447734236717224  MAE:0.2916608154773712
# ▶ seg59  mean  MSE:0.1447734236717224  MAE:0.2916608154773712
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.1381896585226059  MAE:0.2713295817375183
# ▶ seg60  mean  MSE:0.1381896585226059  MAE:0.2713295817375183
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.13888254761695862  MAE:0.27342450618743896
# ▶ seg61  mean  MSE:0.13888254761695862  MAE:0.27342450618743896
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.1336565911769867  MAE:0.26830729842185974
# ▶ seg62  mean  MSE:0.1336565911769867  MAE:0.26830729842185974
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.13494496047496796  MAE:0.27473413944244385
# ▶ seg63  mean  MSE:0.13494496047496796  MAE:0.27473413944244385
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.1392020285129547  MAE:0.2743294835090637
# ▶ seg64  mean  MSE:0.1392020285129547  MAE:0.2743294835090637
#
# seg10 ch0 MSE : 0.13712585

# %% [markdown]
# # 2nd Inference for Test Set

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 192
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.10931582003831863  MAE:0.24942797422409058
# ▶ seg0  mean  MSE:0.10931582003831863  MAE:0.24942797422409058
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.10116247087717056  MAE:0.23931485414505005
# ▶ seg1  mean  MSE:0.10116247087717056  MAE:0.23931485414505005
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.10991302877664566  MAE:0.24994951486587524
# ▶ seg53  mean  MSE:0.10991302877664566  MAE:0.24994951486587524
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.10457813739776611  MAE:0.24122783541679382
# ▶ seg54  mean  MSE:0.10457813739776611  MAE:0.24122783541679382
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.09547990560531616  MAE:0.2326033115386963
# ▶ seg55  mean  MSE:0.09547990560531616  MAE:0.2326033115386963
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.09824176877737045  MAE:0.23525470495224
# ▶ seg56  mean  MSE:0.09824176877737045  MAE:0.23525470495224
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.09858586639165878  MAE:0.23702479898929596
# ▶ seg57  mean  MSE:0.09858586639165878  MAE:0.23702479898929596
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.1361946165561676  MAE:0.2826947867870331
# ▶ seg58  mean  MSE:0.1361946165561676  MAE:0.2826947867870331
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.1003682091832161  MAE:0.237884521484375
# ▶ seg59  mean  MSE:0.1003682091832161  MAE:0.237884521484375
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.098569855093956  MAE:0.23692509531974792
# ▶ seg60  mean  MSE:0.098569855093956  MAE:0.23692509531974792
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.09610970318317413  MAE:0.23313844203948975
# ▶ seg61  mean  MSE:0.09610970318317413  MAE:0.23313844203948975
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.09671858698129654  MAE:0.23372454941272736
# ▶ seg62  mean  MSE:0.09671858698129654  MAE:0.23372454941272736
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.10439244657754898  MAE:0.24205628037452698
# ▶ seg63  mean  MSE:0.10439244657754898  MAE:0.24205628037452698
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.10464821010828018  MAE:0.24493858218193054
# ▶ seg64  mean  MSE:0.10464821010828018  MAE:0.24493858218193054
#
# seg10 ch0 MSE : 0.112666525

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 192
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.11175928264856339  MAE:0.25108465552330017
# ▶ seg0  mean  MSE:0.11175928264856339  MAE:0.25108465552330017
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.10430122166872025  MAE:0.24212971329689026
# ▶ seg1  mean  MSE:0.10430122166872025  MAE:0.24212971329689026
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.0995672196149826  MAE:0.23861926794052124
# ▶ seg2  mean  MSE:0.0995672196149826  MAE:0.23861926794052124
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.09744966775178909  MAE:0.2359643578529358
# ▶ seg3  mean  MSE:0.09744966775178909  MAE:0.2359643578529358
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.09517430514097214  MAE:0.2311745434999466
# ▶ seg4  mean  MSE:0.09517430514097214  MAE:0.2311745434999466
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.10100860893726349  MAE:0.23965024948120117
# ▶ seg5  mean  MSE:0.10100860893726349  MAE:0.23965024948120117
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.11781817674636841  MAE:0.25824204087257385
# ▶ seg6  mean  MSE:0.11781817674636841  MAE:0.25824204087257385
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.09268948435783386  MAE:0.22819164395332336
# ▶ seg7  mean  MSE:0.09268948435783386  MAE:0.22819164395332336
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.09500554203987122  MAE:0.2333592027425766
# ▶ seg8  mean  MSE:0.09500554203987122  MAE:0.2333592027425766
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.09630078077316284  MAE:0.23456788063049316
# ▶ seg60  mean  MSE:0.09630078077316284  MAE:0.23456788063049316
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.09973663091659546  MAE:0.23739033937454224
# ▶ seg61  mean  MSE:0.09973663091659546  MAE:0.23739033937454224
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.0937122255563736  MAE:0.230590358376503
# ▶ seg62  mean  MSE:0.0937122255563736  MAE:0.230590358376503
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.10065307468175888  MAE:0.24032802879810333
# ▶ seg63  mean  MSE:0.10065307468175888  MAE:0.24032802879810333
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.10241260379552841  MAE:0.24105118215084076
# ▶ seg64  mean  MSE:0.10241260379552841  MAE:0.24105118215084076
#
# seg10 ch0 MSE : 0.10022213

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTm2_train = torch.load("./1st_results_ETTm2/train_1st_results.pt")
results1_ETTm2_val = torch.load("./1st_results_ETTm2/val_1st_results.pt")
results1_ETTm2_test = torch.load("./1st_results_ETTm2/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.148579
#
#   Top  1 | seg 41 | MSE 0.133619 (+0.014959)
#   Top  2 | seg 59 | MSE 0.133788 (+0.014791)
#   Top  3 | seg 14 | MSE 0.134006 (+0.014573)
#   Top  4 | seg 29 | MSE 0.134993 (+0.013585)
#   Top  5 | seg 62 | MSE 0.135416 (+0.013163)
#   Top  6 | seg 09 | MSE 0.135651 (+0.012928)
#   Top  7 | seg 00 | MSE 0.135663 (+0.012916)
#   Top  8 | seg 05 | MSE 0.135787 (+0.012791)
#   Top  9 | seg 04 | MSE 0.136170 (+0.012408)
#   Top 10 | seg 15 | MSE 0.136197 (+0.012382)
#   Top 11 | seg 60 | MSE 0.136412 (+0.012167)
#   Top 12 | seg 38 | MSE 0.136554 (+0.012025)
#   Top 13 | seg 06 | MSE 0.136683 (+0.011895)
#   Top 14 | seg 64 | MSE 0.136752 (+0.011826)
#   Top 15 | seg 52 | MSE 0.136841 (+0.011737)
#   Top 16 | seg 07 | MSE 0.136990 (+0.011589)
#   Top 17 | seg 23 | MSE 0.137018 (+0.011560)
#   Top 18 | seg 46 | MSE 0.137251 (+0.011328)
#   Top 19 | seg 39 | MSE 0.137421 (+0.011157)
#   Top 20 | seg 34 | MSE 0.137720 (+0.010859)
#   Top 21 | seg 25 | MSE 0.137725 (+0.010854)
#   Top 22 | seg 40 | MSE 0.137766 (+0.010812)
#   Top 23 | seg 16 | MSE 0.138250 (+0.010329)
#   Top 24 | seg 02 | MSE 0.138252 (+0.010327)
#   Top 25 | seg 12 | MSE 0.138365 (+0.010214)
#   Top 26 | seg 31 | MSE 0.138418 (+0.010160)
#   Top 27 | seg 32 | MSE 0.138537 (+0.010042)
#   Top 28 | seg 36 | MSE 0.138554 (+0.010025)
#   Top 52 | seg 45 | MSE 0.143012 (+0.005567)
#   Top 53 | seg 58 | MSE 0.143711 (+0.004868)
#   Top 54 | seg 00 | MSE 0.144193 (+0.004386)
#   Top 55 | seg 42 | MSE 0.144327 (+0.004251)
#   Top 56 | seg 24 | MSE 0.144342 (+0.004237)
#   Top 57 | seg 21 | MSE 0.144428 (+0.004151)
#   Top 58 | seg 35 | MSE 0.144504 (+0.004074)
#   Top 59 | seg 59 | MSE 0.144773 (+0.003805)
#   Top 60 | seg 11 | MSE 0.144895 (+0.003684)
#   Top 61 | seg 25 | MSE 0.145605 (+0.002973)
#   Top 62 | seg 55 | MSE 0.145955 (+0.002624)
#   Top 63 | seg 06 | MSE 0.146755 (+0.001823)
#   Top 64 | seg 57 | MSE 0.150090 (-0.001512)
#   Top 65 | seg 01 | MSE 0.151638 (-0.003060)
#
# Saved top segment indices per channel:
# Channel 0: [46, 5, 62, 12, 56, 34, 7, 63, 30, 44, 47, 40, 8, 33, 17, 50, 2, 4, 9, 26, 16, 48, 29, 10, 23, 51, 41, 18, 60, 52, 27, 19, 61, 38, 64, 28, 31, 13, 36, 14, 32, 20, 3, 43, 39, 15, 37, 54, 22, 49, 53, 45, 58, 0, 42, 24, 21, 35, 59, 11, 25, 55, 6, 57, 1]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTm2_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.091373 | MAE : 0.225882
#   — Var / |Corr| / Score —
#    K= 5 | Var=5.328e-03 | |ρ|=0.9860 | S=1.0000
#    K=10 | Var=6.239e-03 | |ρ|=0.9841 | S=0.9212
#    K=15 | Var=6.374e-03 | |ρ|=0.9830 | S=0.8237
#    K=20 | Var=6.881e-03 | |ρ|=0.9820 | S=0.7814
#    K=25 | Var=7.530e-03 | |ρ|=0.9813 | S=0.7831
#    K=30 | Var=8.264e-03 | |ρ|=0.9803 | S=0.7647
#    K=35 | Var=8.486e-03 | |ρ|=0.9795 | S=0.7126 <- pick
#    K=40 | Var=8.620e-03 | |ρ|=0.9797 | S=0.7514
#    K=45 | Var=9.210e-03 | |ρ|=0.9797 | S=0.8196
#    K=50 | Var=9.693e-03 | |ρ|=0.9790 | S=0.8084
#    K=55 | Var=1.024e-02 | |ρ|=0.9782 | S=0.7902
#    K=60 | Var=1.160e-02 | |ρ|=0.9774 | S=0.8698
#    K=65 | Var=1.366e-02 | |ρ|=0.9762 | S=1.0000
# [Var-Corr]  K=35
#   MSE = 0.092082 | Δ = -0.000709 | Δ% = -0.78%
#   MAE = 0.227067 | Δ = -0.001185 | Δ% = -0.52%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.091373
# Ensemble mean MSE : 0.092082
# Average Δ MSE     : -0.000709
# Average Δ MSE (%) : -0.78%
#
# Vanilla  mean MAE : 0.225882
# Ensemble mean MAE : 0.227067
# Average Δ MAE     : -0.001185
# Average Δ MAE (%) : -0.52%

# %% [markdown]
# ## 1E->1E

# %%
results1_ETTm2_test['ES']['mae_test_EES']
# Out:
# 0.22588162124156952

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTm2_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.1   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.091373 | MAE : 0.225882
#   — Var / |Corr| / Score —
#    K= 5 | Var=5.397e-03 | |ρ|=0.9851 | S=1.0059
#    K=10 | Var=4.900e-03 | |ρ|=0.9864 | S=1.1000
#    K=15 | Var=4.914e-03 | |ρ|=0.9863 | S=1.0966
#    K=20 | Var=5.455e-03 | |ρ|=0.9850 | S=0.9952
#    K=25 | Var=5.853e-03 | |ρ|=0.9843 | S=0.9727
#    K=30 | Var=6.040e-03 | |ρ|=0.9839 | S=0.9492
#    K=35 | Var=6.410e-03 | |ρ|=0.9830 | S=0.8790
#    K=40 | Var=6.948e-03 | |ρ|=0.9820 | S=0.8192 <- pick
#    K=45 | Var=7.553e-03 | |ρ|=0.9814 | S=0.8401
#    K=50 | Var=8.148e-03 | |ρ|=0.9813 | S=0.9354
#    K=55 | Var=8.778e-03 | |ρ|=0.9805 | S=0.9302
#    K=60 | Var=9.540e-03 | |ρ|=0.9798 | S=0.9706
#    K=65 | Var=1.047e-02 | |ρ|=0.9789 | S=1.0000
# [Var-Corr]  K=40
#    MSE = 0.092441 | Δ = -0.001068 | Δ% = -1.17%
#    MAE = 0.227531 | Δ = -0.001650 | Δ% = -0.73%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.091373
# Ensemble mean MSE  : 0.092441
# Average Δ MSE      : -0.001068
# Average Δ MSE (%)  : -1.17%
#
# Vanilla  mean MAE  : 0.225882
# Ensemble mean MAE  : 0.227531
# Average Δ MAE      : -0.001650
# Average Δ MAE (%)  : -0.73%
