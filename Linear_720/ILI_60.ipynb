# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(2)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 2
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/national_illness.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#             % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  AGE 5-24  ILITOTAL  \
# date
# 2002-01-01         1.22262          1.16668      582       805      2060
# 2002-01-08         1.33344          1.21650      683       872      2267
# 2002-01-15         1.31929          1.13057      642       878      2176
# 2002-01-22         1.49484          1.25246      728      1045      2599
# 2002-01-29         1.47195          1.30237      823      1189      2907
#
#             NUM. OF PROVIDERS      OT
# date
# 2002-01-01                754  176569
# 2002-01-08                785  186355
# 2002-01-15                831  192469
# 2002-01-22                863  207512
# 2002-01-29                909  223208

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# % WEIGHTED ILI       float64
# %UNWEIGHTED ILI      float64
# AGE 0-4                int64
# AGE 5-24               int64
# ILITOTAL               int64
# NUM. OF PROVIDERS      int64
# OT                     int64
# dtype: object
# shape:  (966, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2002-01-01', '2002-01-08', '2002-01-15', '2002-01-22',
#                '2002-01-29', '2002-02-05', '2002-02-12', '2002-02-19',
#                '2002-02-26', '2002-03-05',
#                ...
#                '2020-04-28', '2020-05-05', '2020-05-12', '2020-05-19',
#                '2020-05-26', '2020-06-02', '2020-06-09', '2020-06-16',
#                '2020-06-23', '2020-06-30'],
#               dtype='datetime64[ns]', name='date', length=966, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model(nn.Module):
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.channels = configs.enc_in

        
        self.attach_pv = getattr(configs, "attach_pv", False)

        
        self.extra_len = self.pred_len // 3

        
        self.seq_len_aug = self.seq_len + (self.extra_len if self.attach_pv else 0)

        self.individual = configs.individual

        
        if self.individual:
            self.Linear = nn.ModuleList()
            for i in range(self.channels):
                self.Linear.append(nn.Linear(self.seq_len_aug, self.pred_len))
        else:
            self.Linear = nn.Linear(self.seq_len_aug, self.pred_len)


    def forward(self, x, ground_truth=None):

        B, L, C = x.size()

        
        
        
        if self.attach_pv and (ground_truth is not None):
            
            gt_part = ground_truth[:, :self.extra_len, :]  

            
            x = torch.cat([x, gt_part], dim=1)

        
        
        
        if self.individual:
            out = torch.zeros([B, self.pred_len, C], dtype=x.dtype).to(x.device)
            for i in range(C):
                out[:, :, i] = self.Linear[i](x[:, :, i])
            return out

        else:
            
            out = self.Linear(x.permute(0, 2, 1))
            return out.permute(0, 2, 1)

# %% [markdown]
# # 데이터 분할/스케일링/시퀀스 데이터 구조화

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len  = 104
pred_len = 60


total_len  = len(target)
num_train  = int(total_len * 0.7)
num_test   = int(total_len * 0.2)
num_val    = total_len - num_train - num_test

border1s = [
    0,
    num_train - seq_len,
    total_len - num_test - seq_len
]
border2s = [
    num_train,
    num_train + num_val,
    total_len
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i : i + seq_len]
        seq_y = data[i + seq_len : i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([513, 104, 1])
# Train Labels:    torch.Size([513, 60, 1])
# Val Sequences:   torch.Size([38, 104, 1])
# Val Labels:      torch.Size([38, 60, 1])
# Test Sequences:  torch.Size([134, 104, 1])
# Test Labels:     torch.Size([134, 60, 1])

# %%
set_seed(42)

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 기본 모델 학습 (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 104
pred_len = 60  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv ):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ILI", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.5256642506403082 | Val Loss: 0.1651492714881897
# Validation loss decreased (inf --> 0.165149).  Saving model ...
# Updating learning rate to 0.01
# Epoch 1 | Train Loss: 0.17426838112228057 | Val Loss: 0.09315236285328865
# Validation loss decreased (0.165149 --> 0.093152).  Saving model ...
# Updating learning rate to 0.005
# Epoch 2 | Train Loss: 0.11484689528451246 | Val Loss: 0.061242906376719475
# Validation loss decreased (0.093152 --> 0.061243).  Saving model ...
# Updating learning rate to 0.0025
# Epoch 3 | Train Loss: 0.11824731002835666 | Val Loss: 0.059586912393569946
# Validation loss decreased (0.061243 --> 0.059587).  Saving model ...
# Updating learning rate to 0.00125
# Epoch 4 | Train Loss: 0.10545653323916827 | Val Loss: 0.048569824546575546
# Validation loss decreased (0.059587 --> 0.048570).  Saving model ...
# Updating learning rate to 0.000625
# Epoch 5 | Train Loss: 0.10039457021390691 | Val Loss: 0.04895210266113281
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0003125
# Epoch 6 | Train Loss: 0.09550980237476966 | Val Loss: 0.05183732882142067
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.00015625
# Epoch 7 | Train Loss: 0.09474934286930982 | Val Loss: 0.05123147927224636
# EarlyStopping counter: 3 out of 3
# Early stopping triggered. Stopping training.

# %% [markdown]
# # 기본 모델 학습 (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 104
pred_len = 60  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ILI", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.4693295499857734 | Val Loss: 0.17921044677495956
# Model saved at epoch 1

# %% [markdown]
# # Test set 추론 및 예측값 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.8783299922943115 | MAE: 0.7900524139404297
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 1.2573890686035156 | MAE: 0.9034676551818848

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %% [markdown]
# ## validation 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.050814833492040634 | MAE: 0.1764773726463318
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.18201786279678345 | MAE: 0.3357134759426117

# %% [markdown]
# ## train 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.1006794199347496 | MAE: 0.2452235370874405
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.19729961454868317 | MAE: 0.3515302240848541

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([513, 104, 1])
# val_sequences shape:  torch.Size([38, 104, 1])
# test_sequences shape:  torch.Size([134, 104, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([513, 60, 1])
# val_pv shape:  torch.Size([38, 60, 1])
# test_pv shape:  torch.Size([134, 60, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([513, 60, 1])
# val_labels shape:  torch.Size([38, 60, 1])
# test_labels shape:  torch.Size([134, 60, 1])

# %% [markdown]
# # Segment Generation Function by Sliding Window

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV (Predictied Value)

# %%
configs.pred_len
# Out:
# 60

# %%
segment_len = configs.pred_len // 3
stride = 1  

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([513, 41, 20, 1]), Val: torch.Size([38, 41, 20, 1]), Test: torch.Size([134, 41, 20, 1])
# [Epoch 1] Train seg shape: torch.Size([513, 41, 20, 1]), Val: torch.Size([38, 41, 20, 1]), Test: torch.Size([134, 41, 20, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ILI'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # Segment 32 - 2차 증강 모델학습 (1 Epoch)

# %%
train_segments_by_epoch = torch.load('./1st_results_ILI/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ILI/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ILI/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo ES

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 104,
    pred_len         = 60,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ILI_E{epo}_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 0] Training Time = 0.07 sec
# [Segment 0] GPU Memory Start = 23.77 MB
# [Segment 0] GPU Memory End   = 23.87 MB
# [Segment 0] GPU Peak Memory  = 24.94 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 1] Training Time = 0.03 sec
# [Segment 1] GPU Memory Start = 23.87 MB
# [Segment 1] GPU Memory End   = 23.90 MB
# [Segment 1] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 2] Training Time = 0.05 sec
# [Segment 2] GPU Memory Start = 23.90 MB
# [Segment 2] GPU Memory End   = 23.93 MB
# [Segment 2] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 3] Training Time = 0.05 sec
# [Segment 3] GPU Memory Start = 23.93 MB
# [Segment 3] GPU Memory End   = 23.96 MB
# [Segment 3] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 4] Training Time = 0.04 sec
# [Segment 4] GPU Memory Start = 23.96 MB
# [Segment 4] GPU Memory End   = 23.87 MB
# [Segment 4] GPU Peak Memory  = 24.95 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 5] Training Time = 0.05 sec
# [Segment 5] GPU Memory Start = 23.87 MB
# [Segment 5] GPU Memory End   = 23.90 MB
# [Segment 5] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 6] Training Time = 0.04 sec
# [Segment 6] GPU Memory Start = 23.90 MB
# [Segment 6] GPU Memory End   = 23.93 MB
# [Segment 6] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 7] Training Time = 0.05 sec
# [Segment 7] GPU Memory Start = 23.93 MB
# [Segment 7] GPU Memory End   = 23.96 MB
# [Segment 7] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 8] Training Time = 0.05 sec
# [Segment 8] GPU Memory Start = 23.96 MB
# [Segment 8] GPU Memory End   = 23.99 MB
# [Segment 8] GPU Peak Memory  = 25.06 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 9] Training Time = 0.04 sec
# [Segment 9] GPU Memory Start = 23.99 MB
# [Segment 9] GPU Memory End   = 24.02 MB
# [Segment 9] GPU Peak Memory  = 25.09 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 10] Training Time = 0.05 sec
# [Segment 10] GPU Memory Start = 24.02 MB
# [Segment 10] GPU Memory End   = 24.04 MB
# [Segment 10] GPU Peak Memory  = 25.12 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 11] Training Time = 0.04 sec
# [Segment 11] GPU Memory Start = 24.04 MB
# [Segment 11] GPU Memory End   = 24.07 MB
# [Segment 11] GPU Peak Memory  = 25.15 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 12] Training Time = 0.05 sec
# [Segment 12] GPU Memory Start = 24.07 MB
# [Segment 12] GPU Memory End   = 24.10 MB
# [Segment 12] GPU Peak Memory  = 25.18 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 13] Training Time = 0.05 sec
# [Segment 13] GPU Memory Start = 24.10 MB
# [Segment 13] GPU Memory End   = 24.13 MB
# [Segment 13] GPU Peak Memory  = 25.20 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 14] Training Time = 0.05 sec
# [Segment 14] GPU Memory Start = 24.13 MB
# [Segment 14] GPU Memory End   = 23.87 MB
# [Segment 14] GPU Peak Memory  = 24.95 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 15] Training Time = 0.04 sec
# [Segment 15] GPU Memory Start = 23.87 MB
# [Segment 15] GPU Memory End   = 23.90 MB
# [Segment 15] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 16] Training Time = 0.04 sec
# [Segment 16] GPU Memory Start = 23.90 MB
# [Segment 16] GPU Memory End   = 23.93 MB
# [Segment 16] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 17] Training Time = 0.04 sec
# [Segment 17] GPU Memory Start = 23.93 MB
# [Segment 17] GPU Memory End   = 23.96 MB
# [Segment 17] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 18] Training Time = 0.04 sec
# [Segment 18] GPU Memory Start = 23.96 MB
# [Segment 18] GPU Memory End   = 23.99 MB
# [Segment 18] GPU Peak Memory  = 25.06 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 19] Training Time = 0.03 sec
# [Segment 19] GPU Memory Start = 23.99 MB
# [Segment 19] GPU Memory End   = 24.02 MB
# [Segment 19] GPU Peak Memory  = 25.09 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 20] Training Time = 0.04 sec
# [Segment 20] GPU Memory Start = 24.02 MB
# [Segment 20] GPU Memory End   = 24.04 MB
# [Segment 20] GPU Peak Memory  = 25.12 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 21] Training Time = 0.04 sec
# [Segment 21] GPU Memory Start = 24.04 MB
# [Segment 21] GPU Memory End   = 24.07 MB
# [Segment 21] GPU Peak Memory  = 25.15 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 22] Training Time = 0.04 sec
# [Segment 22] GPU Memory Start = 24.07 MB
# [Segment 22] GPU Memory End   = 24.10 MB
# [Segment 22] GPU Peak Memory  = 25.18 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 23] Training Time = 0.04 sec
# [Segment 23] GPU Memory Start = 24.10 MB
# [Segment 23] GPU Memory End   = 24.13 MB
# [Segment 23] GPU Peak Memory  = 25.20 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 24] Training Time = 0.06 sec
# [Segment 24] GPU Memory Start = 24.13 MB
# [Segment 24] GPU Memory End   = 23.87 MB
# [Segment 24] GPU Peak Memory  = 24.95 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 25] Training Time = 0.04 sec
# [Segment 25] GPU Memory Start = 23.87 MB
# [Segment 25] GPU Memory End   = 23.90 MB
# [Segment 25] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 26] Training Time = 0.04 sec
# [Segment 26] GPU Memory Start = 23.90 MB
# [Segment 26] GPU Memory End   = 23.93 MB
# [Segment 26] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 27] Training Time = 0.04 sec
# [Segment 27] GPU Memory Start = 23.93 MB
# [Segment 27] GPU Memory End   = 23.96 MB
# [Segment 27] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 28] Training Time = 0.04 sec
# [Segment 28] GPU Memory Start = 23.96 MB
# [Segment 28] GPU Memory End   = 23.99 MB
# [Segment 28] GPU Peak Memory  = 25.06 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 29] Training Time = 0.04 sec
# [Segment 29] GPU Memory Start = 23.99 MB
# [Segment 29] GPU Memory End   = 24.02 MB
# [Segment 29] GPU Peak Memory  = 25.09 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 30] Training Time = 0.04 sec
# [Segment 30] GPU Memory Start = 24.02 MB
# [Segment 30] GPU Memory End   = 24.04 MB
# [Segment 30] GPU Peak Memory  = 25.12 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 31] Training Time = 0.05 sec
# [Segment 31] GPU Memory Start = 24.04 MB
# [Segment 31] GPU Memory End   = 24.07 MB
# [Segment 31] GPU Peak Memory  = 25.15 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 32] Training Time = 0.06 sec
# [Segment 32] GPU Memory Start = 24.07 MB
# [Segment 32] GPU Memory End   = 24.10 MB
# [Segment 32] GPU Peak Memory  = 25.18 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 33] Training Time = 0.06 sec
# [Segment 33] GPU Memory Start = 24.10 MB
# [Segment 33] GPU Memory End   = 24.13 MB
# [Segment 33] GPU Peak Memory  = 25.20 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 34] Training Time = 0.08 sec
# [Segment 34] GPU Memory Start = 24.13 MB
# [Segment 34] GPU Memory End   = 23.87 MB
# [Segment 34] GPU Peak Memory  = 24.95 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 35] Training Time = 0.08 sec
# [Segment 35] GPU Memory Start = 23.87 MB
# [Segment 35] GPU Memory End   = 23.90 MB
# [Segment 35] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 36] Training Time = 0.06 sec
# [Segment 36] GPU Memory Start = 23.90 MB
# [Segment 36] GPU Memory End   = 23.93 MB
# [Segment 36] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 37] Training Time = 0.07 sec
# [Segment 37] GPU Memory Start = 23.93 MB
# [Segment 37] GPU Memory End   = 23.96 MB
# [Segment 37] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 38] Training Time = 0.06 sec
# [Segment 38] GPU Memory Start = 23.96 MB
# [Segment 38] GPU Memory End   = 23.99 MB
# [Segment 38] GPU Peak Memory  = 25.06 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 39] Training Time = 0.05 sec
# [Segment 39] GPU Memory Start = 23.99 MB
# [Segment 39] GPU Memory End   = 24.02 MB
# [Segment 39] GPU Peak Memory  = 25.09 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 40] Training Time = 0.05 sec
# [Segment 40] GPU Memory Start = 24.02 MB
# [Segment 40] GPU Memory End   = 24.04 MB
# [Segment 40] GPU Peak Memory  = 25.12 MB
#
# ============= Done =============

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo 1

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 104 ,
    pred_len         = 60,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ILI_E{epo}_1E/",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters()) 
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 0] Training Time = 0.09 sec
# [Segment 0] GPU Memory Start = 23.87 MB
# [Segment 0] GPU Memory End   = 23.87 MB
# [Segment 0] GPU Peak Memory  = 24.95 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 1] Training Time = 0.05 sec
# [Segment 1] GPU Memory Start = 23.87 MB
# [Segment 1] GPU Memory End   = 23.90 MB
# [Segment 1] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 2] Training Time = 0.05 sec
# [Segment 2] GPU Memory Start = 23.90 MB
# [Segment 2] GPU Memory End   = 23.93 MB
# [Segment 2] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 3] Training Time = 0.04 sec
# [Segment 3] GPU Memory Start = 23.93 MB
# [Segment 3] GPU Memory End   = 23.96 MB
# [Segment 3] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 4] Training Time = 0.04 sec
# [Segment 4] GPU Memory Start = 23.96 MB
# [Segment 4] GPU Memory End   = 23.99 MB
# [Segment 4] GPU Peak Memory  = 25.06 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 5] Training Time = 0.04 sec
# [Segment 5] GPU Memory Start = 23.99 MB
# [Segment 5] GPU Memory End   = 24.02 MB
# [Segment 5] GPU Peak Memory  = 25.09 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 6] Training Time = 0.04 sec
# [Segment 6] GPU Memory Start = 23.87 MB
# [Segment 6] GPU Memory End   = 23.90 MB
# [Segment 6] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 7] Training Time = 0.04 sec
# [Segment 7] GPU Memory Start = 23.90 MB
# [Segment 7] GPU Memory End   = 23.93 MB
# [Segment 7] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 8] Training Time = 0.04 sec
# [Segment 8] GPU Memory Start = 23.93 MB
# [Segment 8] GPU Memory End   = 23.96 MB
# [Segment 8] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 9] Training Time = 0.04 sec
# [Segment 9] GPU Memory Start = 23.96 MB
# [Segment 9] GPU Memory End   = 23.99 MB
# [Segment 9] GPU Peak Memory  = 25.06 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 10] Training Time = 0.06 sec
# [Segment 10] GPU Memory Start = 23.99 MB
# [Segment 10] GPU Memory End   = 24.02 MB
# [Segment 10] GPU Peak Memory  = 25.09 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 11] Training Time = 0.09 sec
# [Segment 11] GPU Memory Start = 24.02 MB
# [Segment 11] GPU Memory End   = 24.04 MB
# [Segment 11] GPU Peak Memory  = 25.12 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 12] Training Time = 0.05 sec
# [Segment 12] GPU Memory Start = 24.04 MB
# [Segment 12] GPU Memory End   = 24.07 MB
# [Segment 12] GPU Peak Memory  = 25.15 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 13] Training Time = 0.04 sec
# [Segment 13] GPU Memory Start = 24.07 MB
# [Segment 13] GPU Memory End   = 24.10 MB
# [Segment 13] GPU Peak Memory  = 25.18 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 14] Training Time = 0.04 sec
# [Segment 14] GPU Memory Start = 24.10 MB
# [Segment 14] GPU Memory End   = 24.13 MB
# [Segment 14] GPU Peak Memory  = 25.20 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 15] Training Time = 0.04 sec
# [Segment 15] GPU Memory Start = 24.13 MB
# [Segment 15] GPU Memory End   = 24.16 MB
# [Segment 15] GPU Peak Memory  = 25.23 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 16] Training Time = 0.04 sec
# [Segment 16] GPU Memory Start = 23.87 MB
# [Segment 16] GPU Memory End   = 23.90 MB
# [Segment 16] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 17] Training Time = 0.04 sec
# [Segment 17] GPU Memory Start = 23.90 MB
# [Segment 17] GPU Memory End   = 23.93 MB
# [Segment 17] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 18] Training Time = 0.04 sec
# [Segment 18] GPU Memory Start = 23.93 MB
# [Segment 18] GPU Memory End   = 23.96 MB
# [Segment 18] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 19] Training Time = 0.04 sec
# [Segment 19] GPU Memory Start = 23.96 MB
# [Segment 19] GPU Memory End   = 23.99 MB
# [Segment 19] GPU Peak Memory  = 25.06 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 20] Training Time = 0.04 sec
# [Segment 20] GPU Memory Start = 23.99 MB
# [Segment 20] GPU Memory End   = 24.02 MB
# [Segment 20] GPU Peak Memory  = 25.09 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 21] Training Time = 0.03 sec
# [Segment 21] GPU Memory Start = 24.02 MB
# [Segment 21] GPU Memory End   = 24.04 MB
# [Segment 21] GPU Peak Memory  = 25.12 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 22] Training Time = 0.04 sec
# [Segment 22] GPU Memory Start = 24.04 MB
# [Segment 22] GPU Memory End   = 24.07 MB
# [Segment 22] GPU Peak Memory  = 25.15 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 23] Training Time = 0.04 sec
# [Segment 23] GPU Memory Start = 24.07 MB
# [Segment 23] GPU Memory End   = 24.10 MB
# [Segment 23] GPU Peak Memory  = 25.18 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 24] Training Time = 0.04 sec
# [Segment 24] GPU Memory Start = 24.10 MB
# [Segment 24] GPU Memory End   = 24.13 MB
# [Segment 24] GPU Peak Memory  = 25.20 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 25] Training Time = 0.04 sec
# [Segment 25] GPU Memory Start = 24.13 MB
# [Segment 25] GPU Memory End   = 24.16 MB
# [Segment 25] GPU Peak Memory  = 25.23 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 26] Training Time = 0.04 sec
# [Segment 26] GPU Memory Start = 23.87 MB
# [Segment 26] GPU Memory End   = 23.90 MB
# [Segment 26] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 27] Training Time = 0.04 sec
# [Segment 27] GPU Memory Start = 23.90 MB
# [Segment 27] GPU Memory End   = 23.93 MB
# [Segment 27] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 28] Training Time = 0.04 sec
# [Segment 28] GPU Memory Start = 23.93 MB
# [Segment 28] GPU Memory End   = 23.96 MB
# [Segment 28] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 29] Training Time = 0.04 sec
# [Segment 29] GPU Memory Start = 23.96 MB
# [Segment 29] GPU Memory End   = 23.99 MB
# [Segment 29] GPU Peak Memory  = 25.06 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 30] Training Time = 0.04 sec
# [Segment 30] GPU Memory Start = 23.99 MB
# [Segment 30] GPU Memory End   = 24.02 MB
# [Segment 30] GPU Peak Memory  = 25.09 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 31] Training Time = 0.04 sec
# [Segment 31] GPU Memory Start = 24.02 MB
# [Segment 31] GPU Memory End   = 24.04 MB
# [Segment 31] GPU Peak Memory  = 25.12 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 32] Training Time = 0.04 sec
# [Segment 32] GPU Memory Start = 24.04 MB
# [Segment 32] GPU Memory End   = 24.07 MB
# [Segment 32] GPU Peak Memory  = 25.15 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 33] Training Time = 0.04 sec
# [Segment 33] GPU Memory Start = 24.07 MB
# [Segment 33] GPU Memory End   = 24.10 MB
# [Segment 33] GPU Peak Memory  = 25.18 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 34] Training Time = 0.03 sec
# [Segment 34] GPU Memory Start = 24.10 MB
# [Segment 34] GPU Memory End   = 24.13 MB
# [Segment 34] GPU Peak Memory  = 25.20 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 35] Training Time = 0.04 sec
# [Segment 35] GPU Memory Start = 24.13 MB
# [Segment 35] GPU Memory End   = 24.16 MB
# [Segment 35] GPU Peak Memory  = 25.23 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 36] Training Time = 0.04 sec
# [Segment 36] GPU Memory Start = 23.87 MB
# [Segment 36] GPU Memory End   = 23.90 MB
# [Segment 36] GPU Peak Memory  = 24.97 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 37] Training Time = 0.04 sec
# [Segment 37] GPU Memory Start = 23.90 MB
# [Segment 37] GPU Memory End   = 23.93 MB
# [Segment 37] GPU Peak Memory  = 25.00 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 38] Training Time = 0.04 sec
# [Segment 38] GPU Memory Start = 23.93 MB
# [Segment 38] GPU Memory End   = 23.96 MB
# [Segment 38] GPU Peak Memory  = 25.03 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 39] Training Time = 0.04 sec
# [Segment 39] GPU Memory Start = 23.96 MB
# [Segment 39] GPU Memory End   = 23.99 MB
# [Segment 39] GPU Peak Memory  = 25.06 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0127 MB, total = 0.2158 MB
#   yb per batch = 0.0073 MB, total = 0.1245 MB
#   pv per batch = 0.0024 MB, total = 0.0415 MB
# [Segment 40] Training Time = 0.04 sec
# [Segment 40] GPU Memory Start = 23.99 MB
# [Segment 40] GPU Memory End   = 24.02 MB
# [Segment 40] GPU Peak Memory  = 25.09 MB
#
# ============= Done =============

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for validation set 얻은 후 에러율 계산

# %%
train_segments_by_epoch = torch.load('./1st_results_ILI/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ILI/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ILI/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 60,
    seq_len          = 104 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ILI_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 41
batch_sz = 32

results2_ILI_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ILI_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ILI_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.22187590599060059  MAE:0.378570556640625
# ▶ seg0  mean  MSE:0.22187590599060059  MAE:0.378570556640625
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.18091875314712524  MAE:0.3431432843208313
# ▶ seg1  mean  MSE:0.18091875314712524  MAE:0.3431432843208313
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.2175428867340088  MAE:0.38030749559402466
# ▶ seg2  mean  MSE:0.2175428867340088  MAE:0.38030749559402466
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.24524883925914764  MAE:0.4028092622756958
# ▶ seg3  mean  MSE:0.24524883925914764  MAE:0.4028092622756958
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.13482296466827393  MAE:0.28505778312683105
# ▶ seg4  mean  MSE:0.13482296466827393  MAE:0.28505778312683105
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.15212345123291016  MAE:0.31313684582710266
# ▶ seg5  mean  MSE:0.15212345123291016  MAE:0.31313684582710266
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.19482946395874023  MAE:0.35159435868263245
# ▶ seg6  mean  MSE:0.19482946395874023  MAE:0.35159435868263245
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.1205119788646698  MAE:0.2703397274017334
# ▶ seg7  mean  MSE:0.1205119788646698  MAE:0.2703397274017334
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.16251316666603088  MAE:0.32073479890823364
# ▶ seg8  mean  MSE:0.16251316666603088  MAE:0.32073479890823364
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.17252454161643982  MAE:0.3313562870025635
# ▶ seg9  mean  MSE:0.17252454161643982  MAE:0.3313562870025635
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.20952290296554565  MAE:0.36651167273521423
# ▶ seg10  mean  MSE:0.20952290296554565  MAE:0.36651167273521423
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.1747911423444748  MAE:0.33506739139556885
# ▶ seg11  mean  MSE:0.1747911423444748  MAE:0.33506739139556885
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.18088190257549286  MAE:0.3410983979701996
# ▶ seg12  mean  MSE:0.18088190257549286  MAE:0.3410983979701996
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.15197445452213287  MAE:0.3149321377277374
# ▶ seg13  mean  MSE:0.15197445452213287  MAE:0.3149321377277374
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.14351686835289001  MAE:0.2945893704891205
# ▶ seg14  mean  MSE:0.14351686835289001  MAE:0.2945893704891205
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.14478547871112823  MAE:0.29800140857696533
# ▶ seg15  mean  MSE:0.14478547871112823  MAE:0.29800140857696533
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.16822825372219086  MAE:0.33071577548980713
# ▶ seg16  mean  MSE:0.16822825372219086  MAE:0.33071577548980713
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.1888570487499237  MAE:0.3449992537498474
# ▶ seg17  mean  MSE:0.1888570487499237  MAE:0.3449992537498474
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.18074999749660492  MAE:0.3303155303001404
# ▶ seg18  mean  MSE:0.18074999749660492  MAE:0.3303155303001404
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.15525886416435242  MAE:0.3119373917579651
# ▶ seg19  mean  MSE:0.15525886416435242  MAE:0.3119373917579651
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.22200965881347656  MAE:0.38316941261291504
# ▶ seg20  mean  MSE:0.22200965881347656  MAE:0.38316941261291504
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.22368331253528595  MAE:0.39026114344596863
# ▶ seg21  mean  MSE:0.22368331253528595  MAE:0.39026114344596863
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.16398809850215912  MAE:0.3252745568752289
# ▶ seg22  mean  MSE:0.16398809850215912  MAE:0.3252745568752289
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.17534218728542328  MAE:0.3341270089149475
# ▶ seg23  mean  MSE:0.17534218728542328  MAE:0.3341270089149475
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.21554571390151978  MAE:0.37744128704071045
# ▶ seg24  mean  MSE:0.21554571390151978  MAE:0.37744128704071045
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.13124693930149078  MAE:0.280379980802536
# ▶ seg25  mean  MSE:0.13124693930149078  MAE:0.280379980802536
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.19281867146492004  MAE:0.3498484492301941
# ▶ seg26  mean  MSE:0.19281867146492004  MAE:0.3498484492301941
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.2049340158700943  MAE:0.35856348276138306
# ▶ seg27  mean  MSE:0.2049340158700943  MAE:0.35856348276138306
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.2130243331193924  MAE:0.38673776388168335
# ▶ seg28  mean  MSE:0.2130243331193924  MAE:0.38673776388168335
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.16991007328033447  MAE:0.3243393301963806
# ▶ seg29  mean  MSE:0.16991007328033447  MAE:0.3243393301963806
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.14844025671482086  MAE:0.29986652731895447
# ▶ seg30  mean  MSE:0.14844025671482086  MAE:0.29986652731895447
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.20511572062969208  MAE:0.3735678791999817
# ▶ seg31  mean  MSE:0.20511572062969208  MAE:0.3735678791999817
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.21272392570972443  MAE:0.36453965306282043
# ▶ seg32  mean  MSE:0.21272392570972443  MAE:0.36453965306282043
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.22454680502414703  MAE:0.3885336220264435
# ▶ seg33  mean  MSE:0.22454680502414703  MAE:0.3885336220264435
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.19697389006614685  MAE:0.36569178104400635
# ▶ seg34  mean  MSE:0.19697389006614685  MAE:0.36569178104400635
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.18788518011569977  MAE:0.34391456842422485
# ▶ seg35  mean  MSE:0.18788518011569977  MAE:0.34391456842422485
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.2295403778553009  MAE:0.392328679561615
# ▶ seg36  mean  MSE:0.2295403778553009  MAE:0.392328679561615
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.22360573709011078  MAE:0.3828563094139099
# ▶ seg37  mean  MSE:0.22360573709011078  MAE:0.3828563094139099
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.16356003284454346  MAE:0.3200666010379791
# ▶ seg38  mean  MSE:0.16356003284454346  MAE:0.3200666010379791
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.16056077182292938  MAE:0.31312042474746704
# ▶ seg39  mean  MSE:0.16056077182292938  MAE:0.31312042474746704
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.1905740350484848  MAE:0.34610098600387573
# ▶ seg40  mean  MSE:0.1905740350484848  MAE:0.34610098600387573
#
# seg10 ch0 MSE : 0.2095229

# %% [markdown]
# ## EPO 1 - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 60,
    seq_len          = 104 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ILI_E1_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 41
batch_sz = 32

results2_ILI_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ILI_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ILI_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.17816834151744843  MAE:0.3271700143814087
# ▶ seg0  mean  MSE:0.17816834151744843  MAE:0.3271700143814087
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.20944474637508392  MAE:0.3783174753189087
# ▶ seg1  mean  MSE:0.20944474637508392  MAE:0.3783174753189087
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.14667601883411407  MAE:0.3023005723953247
# ▶ seg2  mean  MSE:0.14667601883411407  MAE:0.3023005723953247
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.1270628124475479  MAE:0.27728351950645447
# ▶ seg3  mean  MSE:0.1270628124475479  MAE:0.27728351950645447
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.20915371179580688  MAE:0.36857348680496216
# ▶ seg4  mean  MSE:0.20915371179580688  MAE:0.36857348680496216
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.17212842404842377  MAE:0.32312944531440735
# ▶ seg5  mean  MSE:0.17212842404842377  MAE:0.32312944531440735
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.1234874427318573  MAE:0.27843862771987915
# ▶ seg6  mean  MSE:0.1234874427318573  MAE:0.27843862771987915
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.21574892103672028  MAE:0.3736301362514496
# ▶ seg7  mean  MSE:0.21574892103672028  MAE:0.3736301362514496
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.17581701278686523  MAE:0.33689650893211365
# ▶ seg8  mean  MSE:0.17581701278686523  MAE:0.33689650893211365
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.16003340482711792  MAE:0.31742697954177856
# ▶ seg9  mean  MSE:0.16003340482711792  MAE:0.31742697954177856
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.21408364176750183  MAE:0.37446293234825134
# ▶ seg10  mean  MSE:0.21408364176750183  MAE:0.37446293234825134
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.19427362084388733  MAE:0.3492271304130554
# ▶ seg11  mean  MSE:0.19427362084388733  MAE:0.3492271304130554
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.17088426649570465  MAE:0.3250996172428131
# ▶ seg12  mean  MSE:0.17088426649570465  MAE:0.3250996172428131
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.14296108484268188  MAE:0.2983567714691162
# ▶ seg13  mean  MSE:0.14296108484268188  MAE:0.2983567714691162
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.22915363311767578  MAE:0.39154940843582153
# ▶ seg14  mean  MSE:0.22915363311767578  MAE:0.39154940843582153
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.2146591693162918  MAE:0.3815290629863739
# ▶ seg15  mean  MSE:0.2146591693162918  MAE:0.3815290629863739
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.17428061366081238  MAE:0.3284861743450165
# ▶ seg16  mean  MSE:0.17428061366081238  MAE:0.3284861743450165
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.18978257477283478  MAE:0.3399503529071808
# ▶ seg17  mean  MSE:0.18978257477283478  MAE:0.3399503529071808
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.15602052211761475  MAE:0.31355151534080505
# ▶ seg18  mean  MSE:0.15602052211761475  MAE:0.31355151534080505
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.15368066728115082  MAE:0.3078698515892029
# ▶ seg19  mean  MSE:0.15368066728115082  MAE:0.3078698515892029
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.22379903495311737  MAE:0.38700833916664124
# ▶ seg20  mean  MSE:0.22379903495311737  MAE:0.38700833916664124
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.14023490250110626  MAE:0.3000517189502716
# ▶ seg21  mean  MSE:0.14023490250110626  MAE:0.3000517189502716
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.1480884552001953  MAE:0.30610382556915283
# ▶ seg22  mean  MSE:0.1480884552001953  MAE:0.30610382556915283
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.18888679146766663  MAE:0.35533827543258667
# ▶ seg23  mean  MSE:0.18888679146766663  MAE:0.35533827543258667
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.1330644190311432  MAE:0.29082024097442627
# ▶ seg24  mean  MSE:0.1330644190311432  MAE:0.29082024097442627
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.16689112782478333  MAE:0.32876458764076233
# ▶ seg25  mean  MSE:0.16689112782478333  MAE:0.32876458764076233
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.1694142073392868  MAE:0.32915565371513367
# ▶ seg26  mean  MSE:0.1694142073392868  MAE:0.32915565371513367
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.14343534409999847  MAE:0.30918821692466736
# ▶ seg27  mean  MSE:0.14343534409999847  MAE:0.30918821692466736
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.19046802818775177  MAE:0.3524804413318634
# ▶ seg28  mean  MSE:0.19046802818775177  MAE:0.3524804413318634
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.14240974187850952  MAE:0.2970482110977173
# ▶ seg29  mean  MSE:0.14240974187850952  MAE:0.2970482110977173
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.15872825682163239  MAE:0.3184400200843811
# ▶ seg30  mean  MSE:0.15872825682163239  MAE:0.3184400200843811
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.23444829881191254  MAE:0.39666271209716797
# ▶ seg31  mean  MSE:0.23444829881191254  MAE:0.39666271209716797
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.1755463182926178  MAE:0.33342644572257996
# ▶ seg32  mean  MSE:0.1755463182926178  MAE:0.33342644572257996
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.17354074120521545  MAE:0.3356327712535858
# ▶ seg33  mean  MSE:0.17354074120521545  MAE:0.3356327712535858
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.17728807032108307  MAE:0.33949029445648193
# ▶ seg34  mean  MSE:0.17728807032108307  MAE:0.33949029445648193
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.21257269382476807  MAE:0.3710309565067291
# ▶ seg35  mean  MSE:0.21257269382476807  MAE:0.3710309565067291
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.18822698295116425  MAE:0.3553681969642639
# ▶ seg36  mean  MSE:0.18822698295116425  MAE:0.3553681969642639
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.20838221907615662  MAE:0.37681981921195984
# ▶ seg37  mean  MSE:0.20838221907615662  MAE:0.37681981921195984
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.21371185779571533  MAE:0.37642911076545715
# ▶ seg38  mean  MSE:0.21371185779571533  MAE:0.37642911076545715
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.22584961354732513  MAE:0.3864167332649231
# ▶ seg39  mean  MSE:0.22584961354732513  MAE:0.3864167332649231
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.19633059203624725  MAE:0.3584692180156708
# ▶ seg40  mean  MSE:0.19633059203624725  MAE:0.3584692180156708
#
# seg10 ch0 MSE : 0.21408364

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for test set 얻은 후 에러율 계산

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 60
seq_len = 104 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 60,
    seq_len          = 104 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ILI_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 41
batch_sz = 32

results2_ILI_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ILI_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ILI_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:1.3013052940368652  MAE:0.9460909962654114
# ▶ seg0  mean  MSE:1.3013052940368652  MAE:0.9460909962654114
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:1.0913747549057007  MAE:0.8708184957504272
# ▶ seg1  mean  MSE:1.0913747549057007  MAE:0.8708184957504272
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:1.3999589681625366  MAE:1.013801097869873
# ▶ seg2  mean  MSE:1.3999589681625366  MAE:1.013801097869873
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:1.3973989486694336  MAE:0.9587545990943909
# ▶ seg3  mean  MSE:1.3973989486694336  MAE:0.9587545990943909
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.857546865940094  MAE:0.7251672744750977
# ▶ seg4  mean  MSE:0.857546865940094  MAE:0.7251672744750977
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.9810709953308105  MAE:0.8002796173095703
# ▶ seg5  mean  MSE:0.9810709953308105  MAE:0.8002796173095703
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:1.1119725704193115  MAE:0.8407582640647888
# ▶ seg6  mean  MSE:1.1119725704193115  MAE:0.8407582640647888
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:1.0183449983596802  MAE:0.8370444774627686
# ▶ seg7  mean  MSE:1.0183449983596802  MAE:0.8370444774627686
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:1.0201019048690796  MAE:0.810874879360199
# ▶ seg8  mean  MSE:1.0201019048690796  MAE:0.810874879360199
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:1.0613148212432861  MAE:0.8288460373878479
# ▶ seg9  mean  MSE:1.0613148212432861  MAE:0.8288460373878479
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:1.433918833732605  MAE:0.9792815446853638
# ▶ seg10  mean  MSE:1.433918833732605  MAE:0.9792815446853638
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:1.0533605813980103  MAE:0.8254865407943726
# ▶ seg11  mean  MSE:1.0533605813980103  MAE:0.8254865407943726
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:1.2082202434539795  MAE:0.9133542776107788
# ▶ seg12  mean  MSE:1.2082202434539795  MAE:0.9133542776107788
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:1.2353860139846802  MAE:0.9492219090461731
# ▶ seg13  mean  MSE:1.2353860139846802  MAE:0.9492219090461731
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.9021186828613281  MAE:0.7418717741966248
# ▶ seg14  mean  MSE:0.9021186828613281  MAE:0.7418717741966248
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.9437843561172485  MAE:0.7550046443939209
# ▶ seg15  mean  MSE:0.9437843561172485  MAE:0.7550046443939209
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:1.152383804321289  MAE:0.866512656211853
# ▶ seg16  mean  MSE:1.152383804321289  MAE:0.866512656211853
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:1.1382404565811157  MAE:0.9067760109901428
# ▶ seg17  mean  MSE:1.1382404565811157  MAE:0.9067760109901428
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.8560060858726501  MAE:0.690472424030304
# ▶ seg18  mean  MSE:0.8560060858726501  MAE:0.690472424030304
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:1.2860180139541626  MAE:0.9481619000434875
# ▶ seg19  mean  MSE:1.2860180139541626  MAE:0.9481619000434875
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:1.3842887878417969  MAE:0.9662206768989563
# ▶ seg20  mean  MSE:1.3842887878417969  MAE:0.9662206768989563
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:1.532303810119629  MAE:1.0075488090515137
# ▶ seg21  mean  MSE:1.532303810119629  MAE:1.0075488090515137
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:1.001936674118042  MAE:0.7700637578964233
# ▶ seg22  mean  MSE:1.001936674118042  MAE:0.7700637578964233
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:1.0822867155075073  MAE:0.8412761092185974
# ▶ seg23  mean  MSE:1.0822867155075073  MAE:0.8412761092185974
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:1.3713680505752563  MAE:0.9687305688858032
# ▶ seg24  mean  MSE:1.3713680505752563  MAE:0.9687305688858032
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.8643368482589722  MAE:0.7308790683746338
# ▶ seg25  mean  MSE:0.8643368482589722  MAE:0.7308790683746338
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:1.1238911151885986  MAE:0.848095715045929
# ▶ seg26  mean  MSE:1.1238911151885986  MAE:0.848095715045929
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:1.1841331720352173  MAE:0.8411267995834351
# ▶ seg27  mean  MSE:1.1841331720352173  MAE:0.8411267995834351
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:1.5831623077392578  MAE:1.0723999738693237
# ▶ seg28  mean  MSE:1.5831623077392578  MAE:1.0723999738693237
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:1.1922094821929932  MAE:0.8868392705917358
# ▶ seg29  mean  MSE:1.1922094821929932  MAE:0.8868392705917358
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.9066493511199951  MAE:0.7535720467567444
# ▶ seg30  mean  MSE:0.9066493511199951  MAE:0.7535720467567444
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:1.5583053827285767  MAE:1.0671982765197754
# ▶ seg31  mean  MSE:1.5583053827285767  MAE:1.0671982765197754
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:1.1505926847457886  MAE:0.860450029373169
# ▶ seg32  mean  MSE:1.1505926847457886  MAE:0.860450029373169
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:1.411781668663025  MAE:0.9707507491111755
# ▶ seg33  mean  MSE:1.411781668663025  MAE:0.9707507491111755
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:1.479791283607483  MAE:1.0279114246368408
# ▶ seg34  mean  MSE:1.479791283607483  MAE:1.0279114246368408
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:1.1406046152114868  MAE:0.8685842752456665
# ▶ seg35  mean  MSE:1.1406046152114868  MAE:0.8685842752456665
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:1.5704351663589478  MAE:1.029799461364746
# ▶ seg36  mean  MSE:1.5704351663589478  MAE:1.029799461364746
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:1.658661127090454  MAE:1.114430546760559
# ▶ seg37  mean  MSE:1.658661127090454  MAE:1.114430546760559
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:1.0413472652435303  MAE:0.8116685748100281
# ▶ seg38  mean  MSE:1.0413472652435303  MAE:0.8116685748100281
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:1.0862637758255005  MAE:0.851926863193512
# ▶ seg39  mean  MSE:1.0862637758255005  MAE:0.851926863193512
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:1.0763769149780273  MAE:0.8327945470809937
# ▶ seg40  mean  MSE:1.0763769149780273  MAE:0.8327945470809937
#
# seg10 ch0 MSE : 1.4339188

# %% [markdown]
# ## EPO 1 - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 60
seq_len = 104 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv
 

base_cfg = Configs(
    pred_len         = 60,
    seq_len          = 104 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ILI_E1_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 41
batch_sz = 32

results2_ILI_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ILI_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ILI_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:1.0251723527908325  MAE:0.8228331208229065
# ▶ seg0  mean  MSE:1.0251723527908325  MAE:0.8228331208229065
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:1.437612533569336  MAE:1.0290117263793945
# ▶ seg1  mean  MSE:1.437612533569336  MAE:1.0290117263793945
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.8696285486221313  MAE:0.7055355310440063
# ▶ seg2  mean  MSE:0.8696285486221313  MAE:0.7055355310440063
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.8021807670593262  MAE:0.6797270774841309
# ▶ seg3  mean  MSE:0.8021807670593262  MAE:0.6797270774841309
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:1.1007776260375977  MAE:0.8381895422935486
# ▶ seg4  mean  MSE:1.1007776260375977  MAE:0.8381895422935486
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:1.0338598489761353  MAE:0.8090023994445801
# ▶ seg5  mean  MSE:1.0338598489761353  MAE:0.8090023994445801
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:1.0121651887893677  MAE:0.8067810535430908
# ▶ seg6  mean  MSE:1.0121651887893677  MAE:0.8067810535430908
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:1.0685760974884033  MAE:0.8126229047775269
# ▶ seg7  mean  MSE:1.0685760974884033  MAE:0.8126229047775269
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:1.053159475326538  MAE:0.8161959052085876
# ▶ seg8  mean  MSE:1.053159475326538  MAE:0.8161959052085876
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:1.0780460834503174  MAE:0.8350853323936462
# ▶ seg9  mean  MSE:1.0780460834503174  MAE:0.8350853323936462
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:1.355717420578003  MAE:0.9398317337036133
# ▶ seg10  mean  MSE:1.355717420578003  MAE:0.9398317337036133
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:1.1687805652618408  MAE:0.8561501502990723
# ▶ seg11  mean  MSE:1.1687805652618408  MAE:0.8561501502990723
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:1.0189969539642334  MAE:0.8033581972122192
# ▶ seg12  mean  MSE:1.0189969539642334  MAE:0.8033581972122192
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.9959818720817566  MAE:0.7886995077133179
# ▶ seg13  mean  MSE:0.9959818720817566  MAE:0.7886995077133179
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:1.3824049234390259  MAE:0.9622707962989807
# ▶ seg14  mean  MSE:1.3824049234390259  MAE:0.9622707962989807
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:1.4461588859558105  MAE:1.006809115409851
# ▶ seg15  mean  MSE:1.4461588859558105  MAE:1.006809115409851
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:1.0641976594924927  MAE:0.8466809988021851
# ▶ seg16  mean  MSE:1.0641976594924927  MAE:0.8466809988021851
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:1.2079986333847046  MAE:0.9114367365837097
# ▶ seg17  mean  MSE:1.2079986333847046  MAE:0.9114367365837097
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:1.2467917203903198  MAE:0.9162706136703491
# ▶ seg18  mean  MSE:1.2467917203903198  MAE:0.9162706136703491
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.9332389831542969  MAE:0.738202691078186
# ▶ seg19  mean  MSE:0.9332389831542969  MAE:0.738202691078186
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:1.7035987377166748  MAE:1.1107665300369263
# ▶ seg20  mean  MSE:1.7035987377166748  MAE:1.1107665300369263
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:1.1428557634353638  MAE:0.8813371062278748
# ▶ seg21  mean  MSE:1.1428557634353638  MAE:0.8813371062278748
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:1.516678810119629  MAE:1.0640095472335815
# ▶ seg22  mean  MSE:1.516678810119629  MAE:1.0640095472335815
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:1.481603741645813  MAE:1.0304679870605469
# ▶ seg23  mean  MSE:1.481603741645813  MAE:1.0304679870605469
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:1.0347341299057007  MAE:0.8344796299934387
# ▶ seg24  mean  MSE:1.0347341299057007  MAE:0.8344796299934387
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:1.295568823814392  MAE:0.9413479566574097
# ▶ seg25  mean  MSE:1.295568823814392  MAE:0.9413479566574097
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:1.0075085163116455  MAE:0.7991572618484497
# ▶ seg26  mean  MSE:1.0075085163116455  MAE:0.7991572618484497
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:1.1727651357650757  MAE:0.9028993248939514
# ▶ seg27  mean  MSE:1.1727651357650757  MAE:0.9028993248939514
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:1.3633840084075928  MAE:0.951901376247406
# ▶ seg28  mean  MSE:1.3633840084075928  MAE:0.951901376247406
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:1.1407767534255981  MAE:0.8857186436653137
# ▶ seg29  mean  MSE:1.1407767534255981  MAE:0.8857186436653137
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:1.1892503499984741  MAE:0.8901527523994446
# ▶ seg30  mean  MSE:1.1892503499984741  MAE:0.8901527523994446
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:1.680369257926941  MAE:1.1079269647598267
# ▶ seg31  mean  MSE:1.680369257926941  MAE:1.1079269647598267
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:1.3511829376220703  MAE:0.9873164892196655
# ▶ seg32  mean  MSE:1.3511829376220703  MAE:0.9873164892196655
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:1.3683977127075195  MAE:0.9761028289794922
# ▶ seg33  mean  MSE:1.3683977127075195  MAE:0.9761028289794922
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:1.145920753479004  MAE:0.843025803565979
# ▶ seg34  mean  MSE:1.145920753479004  MAE:0.843025803565979
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:1.1185657978057861  MAE:0.8163231611251831
# ▶ seg35  mean  MSE:1.1185657978057861  MAE:0.8163231611251831
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:1.3150652647018433  MAE:0.9532977342605591
# ▶ seg36  mean  MSE:1.3150652647018433  MAE:0.9532977342605591
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:1.6748144626617432  MAE:1.051185965538025
# ▶ seg37  mean  MSE:1.6748144626617432  MAE:1.051185965538025
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:1.2893600463867188  MAE:0.9271960258483887
# ▶ seg38  mean  MSE:1.2893600463867188  MAE:0.9271960258483887
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:1.5111010074615479  MAE:1.0158703327178955
# ▶ seg39  mean  MSE:1.5111010074615479  MAE:1.0158703327178955
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:1.2522159814834595  MAE:0.9130306839942932
# ▶ seg40  mean  MSE:1.2522159814834595  MAE:0.9130306839942932
#
# seg10 ch0 MSE : 1.3557174

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ILI_train = torch.load("./1st_results_ILI/train_1st_results.pt")
results1_ILI_val = torch.load("./1st_results_ILI/val_1st_results.pt")
results1_ILI_test = torch.load("./1st_results_ILI/test_1st_results.pt")

# %% [markdown]
# ### EPO ES - 1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 41
SEG_CNT     = 41
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ILI_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ILI_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ILI_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ILI_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.182018
#
#   Top  1 | seg 07 | MSE 0.120512 (+0.061506)
#   Top  2 | seg 25 | MSE 0.131247 (+0.050771)
#   Top  3 | seg 04 | MSE 0.134823 (+0.047195)
#   Top  4 | seg 14 | MSE 0.143517 (+0.038501)
#   Top  5 | seg 15 | MSE 0.144785 (+0.037232)
#   Top  6 | seg 30 | MSE 0.148440 (+0.033578)
#   Top  7 | seg 13 | MSE 0.151974 (+0.030043)
#   Top  8 | seg 05 | MSE 0.152123 (+0.029894)
#   Top  9 | seg 19 | MSE 0.155259 (+0.026759)
#   Top 10 | seg 39 | MSE 0.160561 (+0.021457)
#   Top 11 | seg 08 | MSE 0.162513 (+0.019505)
#   Top 12 | seg 38 | MSE 0.163560 (+0.018458)
#   Top 13 | seg 22 | MSE 0.163988 (+0.018030)
#   Top 14 | seg 16 | MSE 0.168228 (+0.013790)
#   Top 15 | seg 29 | MSE 0.169910 (+0.012108)
#   Top 16 | seg 09 | MSE 0.172525 (+0.009493)
#   Top 17 | seg 11 | MSE 0.174791 (+0.007227)
#   Top 18 | seg 23 | MSE 0.175342 (+0.006676)
#   Top 19 | seg 18 | MSE 0.180750 (+0.001268)
#   Top 20 | seg 12 | MSE 0.180882 (+0.001136)
#   Top 21 | seg 01 | MSE 0.180919 (+0.001099)
#   Top 22 | seg 35 | MSE 0.187885 (-0.005867)
#   Top 23 | seg 17 | MSE 0.188857 (-0.006839)
#   Top 24 | seg 40 | MSE 0.190574 (-0.008556)
#   Top 25 | seg 26 | MSE 0.192819 (-0.010801)
#   Top 26 | seg 06 | MSE 0.194829 (-0.012812)
#   Top 27 | seg 34 | MSE 0.196974 (-0.014956)
#   Top 28 | seg 27 | MSE 0.204934 (-0.022916)
#   Top 29 | seg 31 | MSE 0.205116 (-0.023098)
#   Top 30 | seg 10 | MSE 0.209523 (-0.027505)
#   Top 31 | seg 32 | MSE 0.212724 (-0.030706)
#   Top 32 | seg 28 | MSE 0.213024 (-0.031006)
#   Top 33 | seg 24 | MSE 0.215546 (-0.033528)
#   Top 34 | seg 02 | MSE 0.217543 (-0.035525)
#   Top 35 | seg 00 | MSE 0.221876 (-0.039858)
#   Top 36 | seg 20 | MSE 0.222010 (-0.039992)
#   Top 37 | seg 37 | MSE 0.223606 (-0.041588)
#   Top 38 | seg 21 | MSE 0.223683 (-0.041665)
#   Top 39 | seg 33 | MSE 0.224547 (-0.042529)
#   Top 40 | seg 36 | MSE 0.229540 (-0.047523)
#   Top 41 | seg 03 | MSE 0.245249 (-0.063231)
#
# Saved top segment indices per channel:
# Channel 0: [7, 25, 4, 14, 15, 30, 13, 5, 19, 39, 8, 38, 22, 16, 29, 9, 11, 23, 18, 12, 1, 35, 17, 40, 26, 6, 34, 27, 31, 10, 32, 28, 24, 2, 0, 20, 37, 21, 33, 36, 3]

# %% [markdown]
# ### EPO 1 - 1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 41
SEG_CNT     = 41
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ILI_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ILI_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ILI_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ILI_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.182018
#
#   Top  1 | seg 06 | MSE 0.123487 (+0.058530)
#   Top  2 | seg 03 | MSE 0.127063 (+0.054955)
#   Top  3 | seg 24 | MSE 0.133064 (+0.048953)
#   Top  4 | seg 21 | MSE 0.140235 (+0.041783)
#   Top  5 | seg 29 | MSE 0.142410 (+0.039608)
#   Top  6 | seg 13 | MSE 0.142961 (+0.039057)
#   Top  7 | seg 27 | MSE 0.143435 (+0.038583)
#   Top  8 | seg 02 | MSE 0.146676 (+0.035342)
#   Top  9 | seg 22 | MSE 0.148088 (+0.033929)
#   Top 10 | seg 19 | MSE 0.153681 (+0.028337)
#   Top 11 | seg 18 | MSE 0.156021 (+0.025997)
#   Top 12 | seg 30 | MSE 0.158728 (+0.023290)
#   Top 13 | seg 09 | MSE 0.160033 (+0.021984)
#   Top 14 | seg 25 | MSE 0.166891 (+0.015127)
#   Top 15 | seg 26 | MSE 0.169414 (+0.012604)
#   Top 16 | seg 12 | MSE 0.170884 (+0.011134)
#   Top 17 | seg 05 | MSE 0.172128 (+0.009889)
#   Top 18 | seg 33 | MSE 0.173541 (+0.008477)
#   Top 19 | seg 16 | MSE 0.174281 (+0.007737)
#   Top 20 | seg 32 | MSE 0.175546 (+0.006472)
#   Top 21 | seg 08 | MSE 0.175817 (+0.006201)
#   Top 22 | seg 34 | MSE 0.177288 (+0.004730)
#   Top 23 | seg 00 | MSE 0.178168 (+0.003850)
#   Top 24 | seg 36 | MSE 0.188227 (-0.006209)
#   Top 25 | seg 23 | MSE 0.188887 (-0.006869)
#   Top 26 | seg 17 | MSE 0.189783 (-0.007765)
#   Top 27 | seg 28 | MSE 0.190468 (-0.008450)
#   Top 28 | seg 11 | MSE 0.194274 (-0.012256)
#   Top 29 | seg 40 | MSE 0.196331 (-0.014313)
#   Top 30 | seg 37 | MSE 0.208382 (-0.026364)
#   Top 31 | seg 04 | MSE 0.209154 (-0.027136)
#   Top 32 | seg 01 | MSE 0.209445 (-0.027427)
#   Top 33 | seg 35 | MSE 0.212573 (-0.030555)
#   Top 34 | seg 38 | MSE 0.213712 (-0.031694)
#   Top 35 | seg 10 | MSE 0.214084 (-0.032066)
#   Top 36 | seg 15 | MSE 0.214659 (-0.032641)
#   Top 37 | seg 07 | MSE 0.215749 (-0.033731)
#   Top 38 | seg 20 | MSE 0.223799 (-0.041781)
#   Top 39 | seg 39 | MSE 0.225850 (-0.043832)
#   Top 40 | seg 14 | MSE 0.229154 (-0.047136)
#   Top 41 | seg 31 | MSE 0.234448 (-0.052430)
#
# Saved top segment indices per channel:
# Channel 0: [6, 3, 24, 21, 29, 13, 27, 2, 22, 19, 18, 30, 9, 25, 26, 12, 5, 33, 16, 32, 8, 34, 0, 36, 23, 17, 28, 11, 40, 37, 4, 1, 35, 38, 10, 15, 7, 20, 39, 14, 31]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## EPO ES - 1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 41
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ILI_test['ES']['mse_test_EES']
    v_mae = results1_ILI_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ILI_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.878330 | MAE : 0.790052
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.504e-01 | |ρ|=0.8062 | S=1.0000
#    K=10 | Var=2.848e-01 | |ρ|=0.7910 | S=1.0866
#    K=15 | Var=3.044e-01 | |ρ|=0.7712 | S=0.9889
#    K=20 | Var=3.154e-01 | |ρ|=0.7665 | S=1.0182
#    K=25 | Var=3.192e-01 | |ρ|=0.7613 | S=0.9809 <- pick
#    K=30 | Var=3.402e-01 | |ρ|=0.7490 | S=0.9950
#    K=35 | Var=3.562e-01 | |ρ|=0.7393 | S=0.9995
#    K=40 | Var=3.691e-01 | |ρ|=0.7311 | S=1.0000
# [Var-Corr]  K=25
#   MSE = 0.746440 | Δ = +0.131890 | Δ% = +15.02%
#   MAE = 0.712403 | Δ = +0.077649 | Δ% = +9.83%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.878330
# Ensemble mean MSE : 0.746440
# Average Δ MSE     : +0.131890
# Average Δ MSE (%) : +15.02%
#
# Vanilla  mean MAE : 0.790052
# Ensemble mean MAE : 0.712403
# Average Δ MAE     : +0.077649
# Average Δ MAE (%) : +9.83%

# %% [markdown]
# ## EPO 1 - 1E

# %%
results1_ILI_test['ES']['mae_test_EES']
# Out:
# 0.7900524139404297

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 41
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ILI_test['ES']['mse_test_EES']
    v_mae = results1_ILI_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ILI_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.1   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.878330 | MAE : 0.790052
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.879e-01 | |ρ|=0.7796 | S=1.1000
#    K=10 | Var=3.057e-01 | |ρ|=0.7792 | S=1.2818
#    K=15 | Var=3.079e-01 | |ρ|=0.7703 | S=1.1354
#    K=20 | Var=3.257e-01 | |ρ|=0.7581 | S=1.0936
#    K=25 | Var=3.392e-01 | |ρ|=0.7491 | S=1.0677
#    K=30 | Var=3.519e-01 | |ρ|=0.7383 | S=0.9968
#    K=35 | Var=3.648e-01 | |ρ|=0.7307 | S=0.9894 <- pick
#    K=40 | Var=3.825e-01 | |ρ|=0.7213 | S=1.0000
# [Var-Corr]  K=35
#    MSE = 0.824600 | Δ = +0.053730 | Δ% = +6.12%
#    MAE = 0.760082 | Δ = +0.029970 | Δ% = +3.79%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.878330
# Ensemble mean MSE  : 0.824600
# Average Δ MSE      : +0.053730
# Average Δ MSE (%)  : +6.12%
#
# Vanilla  mean MAE  : 0.790052
# Ensemble mean MAE  : 0.760082
# Average Δ MAE      : +0.029970
# Average Δ MAE (%)  : +3.79%
