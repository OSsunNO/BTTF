# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(2)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 2
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTh1.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                       HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# date
# 2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (17420, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 01:00:00',
#                '2016-07-01 02:00:00', '2016-07-01 03:00:00',
#                '2016-07-01 04:00:00', '2016-07-01 05:00:00',
#                '2016-07-01 06:00:00', '2016-07-01 07:00:00',
#                '2016-07-01 08:00:00', '2016-07-01 09:00:00',
#                ...
#                '2018-06-26 10:00:00', '2018-06-26 11:00:00',
#                '2018-06-26 12:00:00', '2018-06-26 13:00:00',
#                '2018-06-26 14:00:00', '2018-06-26 15:00:00',
#                '2018-06-26 16:00:00', '2018-06-26 17:00:00',
#                '2018-06-26 18:00:00', '2018-06-26 19:00:00'],
#               dtype='datetime64[ns]', name='date', length=17420, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %%
set_seed(34)

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model(nn.Module):
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.channels = configs.enc_in

        
        self.attach_pv = getattr(configs, "attach_pv", False)

        
        self.extra_len = self.pred_len // 3

        
        self.seq_len_aug = self.seq_len + (self.extra_len if self.attach_pv else 0)

        self.individual = configs.individual

        
        if self.individual:
            self.Linear = nn.ModuleList()
            for i in range(self.channels):
                self.Linear.append(nn.Linear(self.seq_len_aug, self.pred_len))
        else:
            self.Linear = nn.Linear(self.seq_len_aug, self.pred_len)


    def forward(self, x, ground_truth=None):
        B, L, C = x.size()

        
        
        
        if self.attach_pv and (ground_truth is not None):
            
            gt_part = ground_truth[:, :self.extra_len, :]  

            
            x = torch.cat([x, gt_part], dim=1)

        
        
        
        if self.individual:
            out = torch.zeros([B, self.pred_len, C], dtype=x.dtype).to(x.device)
            for i in range(C):
                out[:, :, i] = self.Linear[i](x[:, :, i])
            return out

        else:
            
            out = self.Linear(x.permute(0, 2, 1))
            return out.permute(0, 2, 1)

# %% [markdown]
# # 데이터 분할/스케일링/시퀀스 데이터 구조화

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset

target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 720


border1s = [0, 12 * 30 * 24 - seq_len, 12 * 30 * 24 + 4 * 30 * 24 - seq_len]
border2s = [12 * 30 * 24, 12 * 30 * 24 + 4 * 30 * 24, 12 * 30 * 24 + 8 * 30 * 24]

train = target[border1s[0]:border2s[0]]
val = target[border1s[1]:border2s[1]]
test = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val = scaler.transform(val)
test = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data = create_inout_sequences_univariate(val, seq_len, pred_len)
test_data = create_inout_sequences_univariate(test, seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels = torch.tensor([x[1] for x in test_data]).float().to(device)



print("Train Sequences:", train_sequences.shape)
print("Train Labels:", train_labels.shape)
print("Val Sequences:", val_sequences.shape)
print("Val Labels:", val_labels.shape)
print("Test Sequences:", test_sequences.shape)
print("Test Labels:", test_labels.shape)
# Out:
# Train Sequences: torch.Size([7585, 336, 1])
# Train Labels: torch.Size([7585, 720, 1])
# Val Sequences: torch.Size([2161, 336, 1])
# Val Labels: torch.Size([2161, 720, 1])
# Test Sequences: torch.Size([2161, 336, 1])
# Test Labels: torch.Size([2161, 720, 1])

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 기본 모델 학습 (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_pv=False ) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.01
# Epoch 0 | Train Loss: 0.39589548085917947 | Val Loss: 0.17239858604529323
# Validation loss decreased (inf --> 0.172399).  Saving model ...
# Updating learning rate to 0.005
# Epoch 1 | Train Loss: 0.22500816131589793 | Val Loss: 0.15770857079940684
# Validation loss decreased (0.172399 --> 0.157709).  Saving model ...
# Updating learning rate to 0.0025
# Epoch 2 | Train Loss: 0.2146558586915 | Val Loss: 0.15059540771386204
# Validation loss decreased (0.157709 --> 0.150595).  Saving model ...
# Updating learning rate to 0.00125
# Epoch 3 | Train Loss: 0.20597527498582832 | Val Loss: 0.1489300459404202
# Validation loss decreased (0.150595 --> 0.148930).  Saving model ...
# Updating learning rate to 0.000625
# Epoch 4 | Train Loss: 0.2024981258358775 | Val Loss: 0.1491513680666685
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0003125
# Epoch 5 | Train Loss: 0.20120826895747865 | Val Loss: 0.1486989221371272
# Validation loss decreased (0.148930 --> 0.148699).  Saving model ...
# Updating learning rate to 0.00015625
# Epoch 6 | Train Loss: 0.1999742446326408 | Val Loss: 0.1483408711193239
# Validation loss decreased (0.148699 --> 0.148341).  Saving model ...
# Updating learning rate to 7.8125e-05
# Epoch 7 | Train Loss: 0.2013759259917155 | Val Loss: 0.1482125196386786
# Validation loss decreased (0.148341 --> 0.148213).  Saving model ...
# Updating learning rate to 3.90625e-05
# Epoch 8 | Train Loss: 0.19965822424958735 | Val Loss: 0.14823096322224422
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.953125e-05
# Epoch 9 | Train Loss: 0.19986145104430303 | Val Loss: 0.1483505742953104
# EarlyStopping counter: 2 out of 3

# %% [markdown]
# # 기본 모델 학습 (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.01
# Epoch 0 | Train Loss: 0.3847685579617484 | Val Loss: 0.17035462356665554
# Model saved at epoch 1

# %% [markdown]
# # Test set 추론 및 예측값 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.15983976423740387 | MAE: 0.32571619749069214
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.4137983024120331 | MAE: 0.48014089465141296

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %% [markdown]
# ## validation 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.1479150801897049 | MAE: 0.30725401639938354
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.17027702927589417 | MAE: 0.32904770970344543

# %% [markdown]
# ## train 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.2000921219587326 | MAE: 0.34720462560653687
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.3635292053222656 | MAE: 0.46398478746414185

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([7585, 336, 1])
# val_sequences shape:  torch.Size([2161, 336, 1])
# test_sequences shape:  torch.Size([2161, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([7585, 720, 1])
# val_pv shape:  torch.Size([2161, 720, 1])
# test_pv shape:  torch.Size([2161, 720, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([7585, 720, 1])
# val_labels shape:  torch.Size([2161, 720, 1])
# test_labels shape:  torch.Size([2161, 720, 1])

# %% [markdown]
# # Segment Generation Function by Sliding Window

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV (Predictied Value)

# %%
configs.pred_len
# Out:
# 720

# %%
segment_len = configs.pred_len // 3
stride = 8

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([7585, 61, 240, 1]), Val: torch.Size([2161, 61, 240, 1]), Test: torch.Size([2161, 61, 240, 1])
# [Epoch 1] Train seg shape: torch.Size([7585, 61, 240, 1]), Val: torch.Size([2161, 61, 240, 1]), Test: torch.Size([2161, 61, 240, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTh1'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # Segment 32 - 2차 증강 모델학습 (1 Epoch)

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo ES

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters()) 
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 0] Training Time = 1.16 sec
# [Segment 0] GPU Memory Start = 12228.21 MB
# [Segment 0] GPU Memory End   = 11521.61 MB
# [Segment 0] GPU Peak Memory  = 12228.21 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 1] Training Time = 1.06 sec
# [Segment 1] GPU Memory Start = 11521.61 MB
# [Segment 1] GPU Memory End   = 11523.81 MB
# [Segment 1] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 2] Training Time = 0.58 sec
# [Segment 2] GPU Memory Start = 11523.81 MB
# [Segment 2] GPU Memory End   = 11526.01 MB
# [Segment 2] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 3] Training Time = 0.57 sec
# [Segment 3] GPU Memory Start = 11526.01 MB
# [Segment 3] GPU Memory End   = 11528.20 MB
# [Segment 3] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 4] Training Time = 0.89 sec
# [Segment 4] GPU Memory Start = 11528.20 MB
# [Segment 4] GPU Memory End   = 11530.40 MB
# [Segment 4] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 5] Training Time = 1.08 sec
# [Segment 5] GPU Memory Start = 11530.40 MB
# [Segment 5] GPU Memory End   = 11532.59 MB
# [Segment 5] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 6] Training Time = 0.57 sec
# [Segment 6] GPU Memory Start = 11532.59 MB
# [Segment 6] GPU Memory End   = 11534.79 MB
# [Segment 6] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 7] Training Time = 0.56 sec
# [Segment 7] GPU Memory Start = 11534.79 MB
# [Segment 7] GPU Memory End   = 11536.99 MB
# [Segment 7] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 8] Training Time = 0.80 sec
# [Segment 8] GPU Memory Start = 11536.99 MB
# [Segment 8] GPU Memory End   = 11539.18 MB
# [Segment 8] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 9] Training Time = 0.80 sec
# [Segment 9] GPU Memory Start = 11539.18 MB
# [Segment 9] GPU Memory End   = 11541.38 MB
# [Segment 9] GPU Peak Memory  = 11543.90 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 10] Training Time = 1.02 sec
# [Segment 10] GPU Memory Start = 11541.38 MB
# [Segment 10] GPU Memory End   = 11521.61 MB
# [Segment 10] GPU Peak Memory  = 11541.38 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 11] Training Time = 0.55 sec
# [Segment 11] GPU Memory Start = 11521.61 MB
# [Segment 11] GPU Memory End   = 11523.81 MB
# [Segment 11] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 12] Training Time = 0.55 sec
# [Segment 12] GPU Memory Start = 11523.81 MB
# [Segment 12] GPU Memory End   = 11526.01 MB
# [Segment 12] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 13] Training Time = 1.05 sec
# [Segment 13] GPU Memory Start = 11526.01 MB
# [Segment 13] GPU Memory End   = 11528.20 MB
# [Segment 13] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 14] Training Time = 0.56 sec
# [Segment 14] GPU Memory Start = 11528.20 MB
# [Segment 14] GPU Memory End   = 11530.40 MB
# [Segment 14] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 15] Training Time = 0.55 sec
# [Segment 15] GPU Memory Start = 11530.40 MB
# [Segment 15] GPU Memory End   = 11532.59 MB
# [Segment 15] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 16] Training Time = 0.55 sec
# [Segment 16] GPU Memory Start = 11532.59 MB
# [Segment 16] GPU Memory End   = 11534.79 MB
# [Segment 16] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 17] Training Time = 0.87 sec
# [Segment 17] GPU Memory Start = 11534.79 MB
# [Segment 17] GPU Memory End   = 11536.99 MB
# [Segment 17] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 18] Training Time = 0.57 sec
# [Segment 18] GPU Memory Start = 11536.99 MB
# [Segment 18] GPU Memory End   = 11539.18 MB
# [Segment 18] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 19] Training Time = 1.00 sec
# [Segment 19] GPU Memory Start = 11539.18 MB
# [Segment 19] GPU Memory End   = 11541.38 MB
# [Segment 19] GPU Peak Memory  = 11543.90 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 20] Training Time = 0.57 sec
# [Segment 20] GPU Memory Start = 11541.38 MB
# [Segment 20] GPU Memory End   = 11521.61 MB
# [Segment 20] GPU Peak Memory  = 11541.38 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 21] Training Time = 1.03 sec
# [Segment 21] GPU Memory Start = 11521.61 MB
# [Segment 21] GPU Memory End   = 11523.81 MB
# [Segment 21] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 22] Training Time = 0.57 sec
# [Segment 22] GPU Memory Start = 11523.81 MB
# [Segment 22] GPU Memory End   = 11526.01 MB
# [Segment 22] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 23] Training Time = 0.97 sec
# [Segment 23] GPU Memory Start = 11526.01 MB
# [Segment 23] GPU Memory End   = 11528.20 MB
# [Segment 23] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 24] Training Time = 0.56 sec
# [Segment 24] GPU Memory Start = 11528.20 MB
# [Segment 24] GPU Memory End   = 11530.40 MB
# [Segment 24] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 25] Training Time = 0.96 sec
# [Segment 25] GPU Memory Start = 11530.40 MB
# [Segment 25] GPU Memory End   = 11532.59 MB
# [Segment 25] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 26] Training Time = 0.56 sec
# [Segment 26] GPU Memory Start = 11532.59 MB
# [Segment 26] GPU Memory End   = 11534.79 MB
# [Segment 26] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 27] Training Time = 1.04 sec
# [Segment 27] GPU Memory Start = 11534.79 MB
# [Segment 27] GPU Memory End   = 11536.99 MB
# [Segment 27] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 28] Training Time = 0.99 sec
# [Segment 28] GPU Memory Start = 11536.99 MB
# [Segment 28] GPU Memory End   = 11539.18 MB
# [Segment 28] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 29] Training Time = 1.04 sec
# [Segment 29] GPU Memory Start = 11539.18 MB
# [Segment 29] GPU Memory End   = 11541.38 MB
# [Segment 29] GPU Peak Memory  = 11543.90 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 30] Training Time = 1.33 sec
# [Segment 30] GPU Memory Start = 11541.38 MB
# [Segment 30] GPU Memory End   = 11521.61 MB
# [Segment 30] GPU Peak Memory  = 11541.38 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 31] Training Time = 0.57 sec
# [Segment 31] GPU Memory Start = 11521.61 MB
# [Segment 31] GPU Memory End   = 11523.81 MB
# [Segment 31] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 32] Training Time = 0.58 sec
# [Segment 32] GPU Memory Start = 11523.81 MB
# [Segment 32] GPU Memory End   = 11526.01 MB
# [Segment 32] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 33] Training Time = 0.57 sec
# [Segment 33] GPU Memory Start = 11526.01 MB
# [Segment 33] GPU Memory End   = 11528.20 MB
# [Segment 33] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 34] Training Time = 0.57 sec
# [Segment 34] GPU Memory Start = 11528.20 MB
# [Segment 34] GPU Memory End   = 11521.61 MB
# [Segment 34] GPU Peak Memory  = 11530.40 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 35] Training Time = 0.56 sec
# [Segment 35] GPU Memory Start = 11521.61 MB
# [Segment 35] GPU Memory End   = 11523.81 MB
# [Segment 35] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 36] Training Time = 0.99 sec
# [Segment 36] GPU Memory Start = 11523.81 MB
# [Segment 36] GPU Memory End   = 11526.01 MB
# [Segment 36] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 37] Training Time = 0.58 sec
# [Segment 37] GPU Memory Start = 11526.01 MB
# [Segment 37] GPU Memory End   = 11528.20 MB
# [Segment 37] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 38] Training Time = 0.94 sec
# [Segment 38] GPU Memory Start = 11528.20 MB
# [Segment 38] GPU Memory End   = 11530.40 MB
# [Segment 38] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 39] Training Time = 0.57 sec
# [Segment 39] GPU Memory Start = 11530.40 MB
# [Segment 39] GPU Memory End   = 11532.59 MB
# [Segment 39] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 40] Training Time = 0.55 sec
# [Segment 40] GPU Memory Start = 11532.59 MB
# [Segment 40] GPU Memory End   = 11534.79 MB
# [Segment 40] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 41] Training Time = 0.84 sec
# [Segment 41] GPU Memory Start = 11534.79 MB
# [Segment 41] GPU Memory End   = 11536.99 MB
# [Segment 41] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 42] Training Time = 0.57 sec
# [Segment 42] GPU Memory Start = 11536.99 MB
# [Segment 42] GPU Memory End   = 11539.18 MB
# [Segment 42] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 43] Training Time = 0.57 sec
# [Segment 43] GPU Memory Start = 11521.61 MB
# [Segment 43] GPU Memory End   = 11523.81 MB
# [Segment 43] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 44] Training Time = 0.56 sec
# [Segment 44] GPU Memory Start = 11523.81 MB
# [Segment 44] GPU Memory End   = 11526.01 MB
# [Segment 44] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 45] Training Time = 0.56 sec
# [Segment 45] GPU Memory Start = 11526.01 MB
# [Segment 45] GPU Memory End   = 11528.20 MB
# [Segment 45] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 46] Training Time = 0.56 sec
# [Segment 46] GPU Memory Start = 11528.20 MB
# [Segment 46] GPU Memory End   = 11530.40 MB
# [Segment 46] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 47] Training Time = 0.54 sec
# [Segment 47] GPU Memory Start = 11530.40 MB
# [Segment 47] GPU Memory End   = 11532.59 MB
# [Segment 47] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 48] Training Time = 0.55 sec
# [Segment 48] GPU Memory Start = 11532.59 MB
# [Segment 48] GPU Memory End   = 11534.79 MB
# [Segment 48] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 49] Training Time = 0.56 sec
# [Segment 49] GPU Memory Start = 11534.79 MB
# [Segment 49] GPU Memory End   = 11536.99 MB
# [Segment 49] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 50] Training Time = 0.90 sec
# [Segment 50] GPU Memory Start = 11536.99 MB
# [Segment 50] GPU Memory End   = 11539.18 MB
# [Segment 50] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 51] Training Time = 0.55 sec
# [Segment 51] GPU Memory Start = 11539.18 MB
# [Segment 51] GPU Memory End   = 11541.38 MB
# [Segment 51] GPU Peak Memory  = 11543.90 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 52] Training Time = 0.56 sec
# [Segment 52] GPU Memory Start = 11541.38 MB
# [Segment 52] GPU Memory End   = 11543.58 MB
# [Segment 52] GPU Peak Memory  = 11546.10 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 53] Training Time = 0.56 sec
# [Segment 53] GPU Memory Start = 11521.61 MB
# [Segment 53] GPU Memory End   = 11523.81 MB
# [Segment 53] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 54] Training Time = 0.56 sec
# [Segment 54] GPU Memory Start = 11523.81 MB
# [Segment 54] GPU Memory End   = 11526.01 MB
# [Segment 54] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 55] Training Time = 0.56 sec
# [Segment 55] GPU Memory Start = 11526.01 MB
# [Segment 55] GPU Memory End   = 11528.20 MB
# [Segment 55] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 56] Training Time = 0.55 sec
# [Segment 56] GPU Memory Start = 11528.20 MB
# [Segment 56] GPU Memory End   = 11530.40 MB
# [Segment 56] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 57] Training Time = 0.65 sec
# [Segment 57] GPU Memory Start = 11530.40 MB
# [Segment 57] GPU Memory End   = 11532.59 MB
# [Segment 57] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 58] Training Time = 1.06 sec
# [Segment 58] GPU Memory Start = 11532.59 MB
# [Segment 58] GPU Memory End   = 11534.79 MB
# [Segment 58] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 59] Training Time = 0.57 sec
# [Segment 59] GPU Memory Start = 11534.79 MB
# [Segment 59] GPU Memory End   = 11536.99 MB
# [Segment 59] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 60] Training Time = 0.56 sec
# [Segment 60] GPU Memory Start = 11536.99 MB
# [Segment 60] GPU Memory End   = 11539.18 MB
# [Segment 60] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo 1

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E/",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters()) 
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 0] Training Time = 1.09 sec
# [Segment 0] GPU Memory Start = 11521.61 MB
# [Segment 0] GPU Memory End   = 11521.61 MB
# [Segment 0] GPU Peak Memory  = 11525.21 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 1] Training Time = 0.77 sec
# [Segment 1] GPU Memory Start = 11521.61 MB
# [Segment 1] GPU Memory End   = 11523.81 MB
# [Segment 1] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 2] Training Time = 0.57 sec
# [Segment 2] GPU Memory Start = 11523.81 MB
# [Segment 2] GPU Memory End   = 11526.01 MB
# [Segment 2] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 3] Training Time = 0.55 sec
# [Segment 3] GPU Memory Start = 11526.01 MB
# [Segment 3] GPU Memory End   = 11528.20 MB
# [Segment 3] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 4] Training Time = 0.85 sec
# [Segment 4] GPU Memory Start = 11528.20 MB
# [Segment 4] GPU Memory End   = 11530.40 MB
# [Segment 4] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 5] Training Time = 0.66 sec
# [Segment 5] GPU Memory Start = 11530.40 MB
# [Segment 5] GPU Memory End   = 11532.59 MB
# [Segment 5] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 6] Training Time = 0.56 sec
# [Segment 6] GPU Memory Start = 11521.61 MB
# [Segment 6] GPU Memory End   = 11523.81 MB
# [Segment 6] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 7] Training Time = 0.56 sec
# [Segment 7] GPU Memory Start = 11523.81 MB
# [Segment 7] GPU Memory End   = 11526.01 MB
# [Segment 7] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 8] Training Time = 0.99 sec
# [Segment 8] GPU Memory Start = 11526.01 MB
# [Segment 8] GPU Memory End   = 11528.20 MB
# [Segment 8] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 9] Training Time = 0.57 sec
# [Segment 9] GPU Memory Start = 11528.20 MB
# [Segment 9] GPU Memory End   = 11530.40 MB
# [Segment 9] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 10] Training Time = 0.56 sec
# [Segment 10] GPU Memory Start = 11530.40 MB
# [Segment 10] GPU Memory End   = 11532.59 MB
# [Segment 10] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 11] Training Time = 0.56 sec
# [Segment 11] GPU Memory Start = 11532.59 MB
# [Segment 11] GPU Memory End   = 11534.79 MB
# [Segment 11] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 12] Training Time = 1.09 sec
# [Segment 12] GPU Memory Start = 11534.79 MB
# [Segment 12] GPU Memory End   = 11536.99 MB
# [Segment 12] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 13] Training Time = 0.56 sec
# [Segment 13] GPU Memory Start = 11536.99 MB
# [Segment 13] GPU Memory End   = 11539.18 MB
# [Segment 13] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 14] Training Time = 0.55 sec
# [Segment 14] GPU Memory Start = 11539.18 MB
# [Segment 14] GPU Memory End   = 11541.38 MB
# [Segment 14] GPU Peak Memory  = 11543.90 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 15] Training Time = 0.55 sec
# [Segment 15] GPU Memory Start = 11541.38 MB
# [Segment 15] GPU Memory End   = 11543.58 MB
# [Segment 15] GPU Peak Memory  = 11546.10 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 16] Training Time = 0.56 sec
# [Segment 16] GPU Memory Start = 11521.61 MB
# [Segment 16] GPU Memory End   = 11523.81 MB
# [Segment 16] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 17] Training Time = 0.56 sec
# [Segment 17] GPU Memory Start = 11523.81 MB
# [Segment 17] GPU Memory End   = 11526.01 MB
# [Segment 17] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 18] Training Time = 1.07 sec
# [Segment 18] GPU Memory Start = 11526.01 MB
# [Segment 18] GPU Memory End   = 11528.20 MB
# [Segment 18] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 19] Training Time = 0.56 sec
# [Segment 19] GPU Memory Start = 11528.20 MB
# [Segment 19] GPU Memory End   = 11530.40 MB
# [Segment 19] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 20] Training Time = 0.55 sec
# [Segment 20] GPU Memory Start = 11530.40 MB
# [Segment 20] GPU Memory End   = 11532.59 MB
# [Segment 20] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 21] Training Time = 0.56 sec
# [Segment 21] GPU Memory Start = 11532.59 MB
# [Segment 21] GPU Memory End   = 11534.79 MB
# [Segment 21] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 22] Training Time = 0.55 sec
# [Segment 22] GPU Memory Start = 11534.79 MB
# [Segment 22] GPU Memory End   = 11536.99 MB
# [Segment 22] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 23] Training Time = 0.56 sec
# [Segment 23] GPU Memory Start = 11536.99 MB
# [Segment 23] GPU Memory End   = 11539.18 MB
# [Segment 23] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 24] Training Time = 0.57 sec
# [Segment 24] GPU Memory Start = 11539.18 MB
# [Segment 24] GPU Memory End   = 11541.38 MB
# [Segment 24] GPU Peak Memory  = 11543.90 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 25] Training Time = 0.56 sec
# [Segment 25] GPU Memory Start = 11541.38 MB
# [Segment 25] GPU Memory End   = 11543.58 MB
# [Segment 25] GPU Peak Memory  = 11546.10 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 26] Training Time = 0.56 sec
# [Segment 26] GPU Memory Start = 11521.61 MB
# [Segment 26] GPU Memory End   = 11523.81 MB
# [Segment 26] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 27] Training Time = 0.56 sec
# [Segment 27] GPU Memory Start = 11523.81 MB
# [Segment 27] GPU Memory End   = 11526.01 MB
# [Segment 27] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 28] Training Time = 0.56 sec
# [Segment 28] GPU Memory Start = 11526.01 MB
# [Segment 28] GPU Memory End   = 11528.20 MB
# [Segment 28] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 29] Training Time = 0.56 sec
# [Segment 29] GPU Memory Start = 11528.20 MB
# [Segment 29] GPU Memory End   = 11530.40 MB
# [Segment 29] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 30] Training Time = 0.51 sec
# [Segment 30] GPU Memory Start = 11530.40 MB
# [Segment 30] GPU Memory End   = 11532.59 MB
# [Segment 30] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 31] Training Time = 0.55 sec
# [Segment 31] GPU Memory Start = 11532.59 MB
# [Segment 31] GPU Memory End   = 11534.79 MB
# [Segment 31] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 32] Training Time = 0.94 sec
# [Segment 32] GPU Memory Start = 11534.79 MB
# [Segment 32] GPU Memory End   = 11536.99 MB
# [Segment 32] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 33] Training Time = 0.72 sec
# [Segment 33] GPU Memory Start = 11536.99 MB
# [Segment 33] GPU Memory End   = 11539.18 MB
# [Segment 33] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 34] Training Time = 0.57 sec
# [Segment 34] GPU Memory Start = 11539.18 MB
# [Segment 34] GPU Memory End   = 11541.38 MB
# [Segment 34] GPU Peak Memory  = 11543.90 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 35] Training Time = 0.55 sec
# [Segment 35] GPU Memory Start = 11541.38 MB
# [Segment 35] GPU Memory End   = 11543.58 MB
# [Segment 35] GPU Peak Memory  = 11546.10 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 36] Training Time = 0.56 sec
# [Segment 36] GPU Memory Start = 11521.61 MB
# [Segment 36] GPU Memory End   = 11523.81 MB
# [Segment 36] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 37] Training Time = 0.54 sec
# [Segment 37] GPU Memory Start = 11523.81 MB
# [Segment 37] GPU Memory End   = 11526.01 MB
# [Segment 37] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 38] Training Time = 0.93 sec
# [Segment 38] GPU Memory Start = 11526.01 MB
# [Segment 38] GPU Memory End   = 11528.20 MB
# [Segment 38] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 39] Training Time = 0.57 sec
# [Segment 39] GPU Memory Start = 11528.20 MB
# [Segment 39] GPU Memory End   = 11530.40 MB
# [Segment 39] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 40] Training Time = 0.57 sec
# [Segment 40] GPU Memory Start = 11530.40 MB
# [Segment 40] GPU Memory End   = 11532.59 MB
# [Segment 40] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 41] Training Time = 0.56 sec
# [Segment 41] GPU Memory Start = 11532.59 MB
# [Segment 41] GPU Memory End   = 11534.79 MB
# [Segment 41] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 42] Training Time = 0.57 sec
# [Segment 42] GPU Memory Start = 11534.79 MB
# [Segment 42] GPU Memory End   = 11536.99 MB
# [Segment 42] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 43] Training Time = 0.56 sec
# [Segment 43] GPU Memory Start = 11536.99 MB
# [Segment 43] GPU Memory End   = 11539.18 MB
# [Segment 43] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 44] Training Time = 1.12 sec
# [Segment 44] GPU Memory Start = 11539.18 MB
# [Segment 44] GPU Memory End   = 11541.38 MB
# [Segment 44] GPU Peak Memory  = 11543.90 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 45] Training Time = 0.57 sec
# [Segment 45] GPU Memory Start = 11541.38 MB
# [Segment 45] GPU Memory End   = 11543.58 MB
# [Segment 45] GPU Peak Memory  = 11546.10 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 46] Training Time = 0.58 sec
# [Segment 46] GPU Memory Start = 11521.61 MB
# [Segment 46] GPU Memory End   = 11523.81 MB
# [Segment 46] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 47] Training Time = 0.57 sec
# [Segment 47] GPU Memory Start = 11523.81 MB
# [Segment 47] GPU Memory End   = 11526.01 MB
# [Segment 47] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 48] Training Time = 0.57 sec
# [Segment 48] GPU Memory Start = 11526.01 MB
# [Segment 48] GPU Memory End   = 11528.20 MB
# [Segment 48] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 49] Training Time = 0.57 sec
# [Segment 49] GPU Memory Start = 11528.20 MB
# [Segment 49] GPU Memory End   = 11530.40 MB
# [Segment 49] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 50] Training Time = 0.58 sec
# [Segment 50] GPU Memory Start = 11530.40 MB
# [Segment 50] GPU Memory End   = 11532.59 MB
# [Segment 50] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 51] Training Time = 0.58 sec
# [Segment 51] GPU Memory Start = 11532.59 MB
# [Segment 51] GPU Memory End   = 11534.79 MB
# [Segment 51] GPU Peak Memory  = 11537.31 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 52] Training Time = 0.58 sec
# [Segment 52] GPU Memory Start = 11534.79 MB
# [Segment 52] GPU Memory End   = 11536.99 MB
# [Segment 52] GPU Peak Memory  = 11539.51 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 53] Training Time = 0.58 sec
# [Segment 53] GPU Memory Start = 11536.99 MB
# [Segment 53] GPU Memory End   = 11539.18 MB
# [Segment 53] GPU Peak Memory  = 11541.70 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 54] Training Time = 0.58 sec
# [Segment 54] GPU Memory Start = 11539.18 MB
# [Segment 54] GPU Memory End   = 11541.38 MB
# [Segment 54] GPU Peak Memory  = 11543.90 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 55] Training Time = 0.63 sec
# [Segment 55] GPU Memory Start = 11541.38 MB
# [Segment 55] GPU Memory End   = 11543.58 MB
# [Segment 55] GPU Peak Memory  = 11546.10 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 56] Training Time = 0.58 sec
# [Segment 56] GPU Memory Start = 11521.61 MB
# [Segment 56] GPU Memory End   = 11523.81 MB
# [Segment 56] GPU Peak Memory  = 11526.33 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 57] Training Time = 0.57 sec
# [Segment 57] GPU Memory Start = 11523.81 MB
# [Segment 57] GPU Memory End   = 11526.01 MB
# [Segment 57] GPU Peak Memory  = 11528.52 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 58] Training Time = 0.58 sec
# [Segment 58] GPU Memory Start = 11526.01 MB
# [Segment 58] GPU Memory End   = 11528.20 MB
# [Segment 58] GPU Peak Memory  = 11530.72 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 59] Training Time = 0.57 sec
# [Segment 59] GPU Memory Start = 11528.20 MB
# [Segment 59] GPU Memory End   = 11530.40 MB
# [Segment 59] GPU Peak Memory  = 11532.92 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 60] Training Time = 0.57 sec
# [Segment 60] GPU Memory Start = 11530.40 MB
# [Segment 60] GPU Memory End   = 11532.59 MB
# [Segment 60] GPU Peak Memory  = 11535.11 MB
#
# ============= Done =============

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for validation set 얻은 후 에러율 계산

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTh1_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.1686493158340454  MAE:0.3269718587398529
# ▶ seg0  mean  MSE:0.1686493158340454  MAE:0.3269718587398529
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.16039034724235535  MAE:0.3201616704463959
# ▶ seg1  mean  MSE:0.16039034724235535  MAE:0.3201616704463959
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.1634020060300827  MAE:0.3225190043449402
# ▶ seg2  mean  MSE:0.1634020060300827  MAE:0.3225190043449402
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.16799762845039368  MAE:0.3251192569732666
# ▶ seg3  mean  MSE:0.16799762845039368  MAE:0.3251192569732666
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.16326220333576202  MAE:0.3231688141822815
# ▶ seg4  mean  MSE:0.16326220333576202  MAE:0.3231688141822815
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.1536875218153  MAE:0.31325194239616394
# ▶ seg5  mean  MSE:0.1536875218153  MAE:0.31325194239616394
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.2963586151599884  MAE:0.42142152786254883
# ▶ seg6  mean  MSE:0.2963586151599884  MAE:0.42142152786254883
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.3351248800754547  MAE:0.44573158025741577
# ▶ seg7  mean  MSE:0.3351248800754547  MAE:0.44573158025741577
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.15844008326530457  MAE:0.3178156614303589
# ▶ seg8  mean  MSE:0.15844008326530457  MAE:0.3178156614303589
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.1617332249879837  MAE:0.31965136528015137
# ▶ seg9  mean  MSE:0.1617332249879837  MAE:0.31965136528015137
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.1580781489610672  MAE:0.318119615316391
# ▶ seg10  mean  MSE:0.1580781489610672  MAE:0.318119615316391
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.16224493086338043  MAE:0.32291093468666077
# ▶ seg50  mean  MSE:0.16224493086338043  MAE:0.32291093468666077
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.22069162130355835  MAE:0.3730827569961548
# ▶ seg51  mean  MSE:0.22069162130355835  MAE:0.3730827569961548
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.15609809756278992  MAE:0.3157813549041748
# ▶ seg52  mean  MSE:0.15609809756278992  MAE:0.3157813549041748
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.1618983894586563  MAE:0.3222995400428772
# ▶ seg53  mean  MSE:0.1618983894586563  MAE:0.3222995400428772
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.1597607284784317  MAE:0.32001829147338867
# ▶ seg54  mean  MSE:0.1597607284784317  MAE:0.32001829147338867
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.16033867001533508  MAE:0.3227962255477905
# ▶ seg55  mean  MSE:0.16033867001533508  MAE:0.3227962255477905
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.16577814519405365  MAE:0.3256567418575287
# ▶ seg56  mean  MSE:0.16577814519405365  MAE:0.3256567418575287
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.15807142853736877  MAE:0.3183332681655884
# ▶ seg57  mean  MSE:0.15807142853736877  MAE:0.3183332681655884
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.15639042854309082  MAE:0.31698423624038696
# ▶ seg58  mean  MSE:0.15639042854309082  MAE:0.31698423624038696
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.17019999027252197  MAE:0.32844921946525574
# ▶ seg59  mean  MSE:0.17019999027252197  MAE:0.32844921946525574
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.1571163684129715  MAE:0.3179114758968353
# ▶ seg60  mean  MSE:0.1571163684129715  MAE:0.3179114758968353
#
# seg10 ch0 MSE : 0.20923804

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for test set 얻은 후 에러율 계산

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 720  
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTh1_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.29009708762168884  MAE:0.4307290315628052
# ▶ seg0  mean  MSE:0.29009708762168884  MAE:0.4307290315628052
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.31653958559036255  MAE:0.44688403606414795
# ▶ seg1  mean  MSE:0.31653958559036255  MAE:0.44688403606414795
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.5309799909591675  MAE:0.6250512003898621
# ▶ seg2  mean  MSE:0.5309799909591675  MAE:0.6250512003898621
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.5903711915016174  MAE:0.6478066444396973
# ▶ seg3  mean  MSE:0.5903711915016174  MAE:0.6478066444396973
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.3414864242076874  MAE:0.4572628140449524
# ▶ seg4  mean  MSE:0.3414864242076874  MAE:0.4572628140449524
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.3043651580810547  MAE:0.4461054801940918
# ▶ seg5  mean  MSE:0.3043651580810547  MAE:0.4461054801940918
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:1.6651875972747803  MAE:1.0573687553405762
# ▶ seg6  mean  MSE:1.6651875972747803  MAE:1.0573687553405762
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:2.1415228843688965  MAE:1.2476094961166382
# ▶ seg7  mean  MSE:2.1415228843688965  MAE:1.2476094961166382
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.2603243887424469  MAE:0.4041152596473694
# ▶ seg8  mean  MSE:0.2603243887424469  MAE:0.4041152596473694
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.29725366830825806  MAE:0.4303414523601532
# ▶ seg9  mean  MSE:0.29725366830825806  MAE:0.4303414523601532
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.22464631497859955  MAE:0.3816035985946655
# ▶ seg10  mean  MSE:0.22464631497859955  MAE:0.3816035985946655
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.30746591091156006  MAE:0.4367299973964691
# ▶ seg37  mean  MSE:0.30746591091156006  MAE:0.4367299973964691
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.21464012563228607  MAE:0.3720276355743408
# ▶ seg38  mean  MSE:0.21464012563228607  MAE:0.3720276355743408
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.4442691504955292  MAE:0.5232144594192505
# ▶ seg39  mean  MSE:0.4442691504955292  MAE:0.5232144594192505
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.29700490832328796  MAE:0.4203249514102936
# ▶ seg40  mean  MSE:0.29700490832328796  MAE:0.4203249514102936
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.7232316136360168  MAE:0.7104964256286621
# ▶ seg41  mean  MSE:0.7232316136360168  MAE:0.7104964256286621
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.535719096660614  MAE:0.613548994064331
# ▶ seg42  mean  MSE:0.535719096660614  MAE:0.613548994064331
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.48165184259414673  MAE:0.5647769570350647
# ▶ seg43  mean  MSE:0.48165184259414673  MAE:0.5647769570350647
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:1.036943793296814  MAE:0.8623597025871277
# ▶ seg44  mean  MSE:1.036943793296814  MAE:0.8623597025871277
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.5685611963272095  MAE:0.5888209939002991
# ▶ seg45  mean  MSE:0.5685611963272095  MAE:0.5888209939002991
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.21774239838123322  MAE:0.3743324279785156
# ▶ seg46  mean  MSE:0.21774239838123322  MAE:0.3743324279785156
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.19221846759319305  MAE:0.34928029775619507
# ▶ seg47  mean  MSE:0.19221846759319305  MAE:0.34928029775619507
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.44378066062927246  MAE:0.5199288725852966
# ▶ seg48  mean  MSE:0.44378066062927246  MAE:0.5199288725852966
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.5490692853927612  MAE:0.5513824820518494
# ▶ seg49  mean  MSE:0.5490692853927612  MAE:0.5513824820518494
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.4740283787250519  MAE:0.5214982628822327
# ▶ seg50  mean  MSE:0.4740283787250519  MAE:0.5214982628822327
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.3955581784248352  MAE:0.4999418258666992
# ▶ seg51  mean  MSE:0.3955581784248352  MAE:0.4999418258666992
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:2.0076794624328613  MAE:1.1853688955307007
# ▶ seg52  mean  MSE:2.0076794624328613  MAE:1.1853688955307007
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.28595128655433655  MAE:0.44014063477516174
# ▶ seg53  mean  MSE:0.28595128655433655  MAE:0.44014063477516174
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.22534167766571045  MAE:0.37937065958976746
# ▶ seg54  mean  MSE:0.22534167766571045  MAE:0.37937065958976746
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.5512540936470032  MAE:0.6327435374259949
# ▶ seg55  mean  MSE:0.5512540936470032  MAE:0.6327435374259949
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.2909885346889496  MAE:0.43480440974235535
# ▶ seg56  mean  MSE:0.2909885346889496  MAE:0.43480440974235535
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.30563199520111084  MAE:0.44702640175819397
# ▶ seg57  mean  MSE:0.30563199520111084  MAE:0.44702640175819397
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.3064648509025574  MAE:0.43221956491470337
# ▶ seg58  mean  MSE:0.3064648509025574  MAE:0.43221956491470337
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.4798111021518707  MAE:0.5649785399436951
# ▶ seg59  mean  MSE:0.4798111021518707  MAE:0.5649785399436951
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.2542684078216553  MAE:0.40045151114463806
# ▶ seg60  mean  MSE:0.2542684078216553  MAE:0.40045151114463806
#
# seg10 ch0 MSE : 0.22464631

# %% [markdown]
# ## EPO 1 - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 720
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_E1_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTh1_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ET
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.38511693477630615  MAE:0.49337461590766907
# ▶ seg50  mean  MSE:0.38511693477630615  MAE:0.49337461590766907
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.9663140773773193  MAE:0.789882242679596
# ▶ seg51  mean  MSE:0.9663140773773193  MAE:0.789882242679596
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.29757142066955566  MAE:0.4461546540260315
# ▶ seg52  mean  MSE:0.29757142066955566  MAE:0.4461546540260315
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.3593173623085022  MAE:0.48835623264312744
# ▶ seg53  mean  MSE:0.3593173623085022  MAE:0.48835623264312744
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.34997811913490295  MAE:0.4936550259590149
# ▶ seg54  mean  MSE:0.34997811913490295  MAE:0.4936550259590149
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.26493608951568604  MAE:0.4099911153316498
# ▶ seg55  mean  MSE:0.26493608951568604  MAE:0.4099911153316498
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.25900328159332275  MAE:0.40163907408714294
# ▶ seg56  mean  MSE:0.25900328159332275  MAE:0.40163907408714294
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.3127574324607849  MAE:0.4412080645561218
# ▶ seg57  mean  MSE:0.3127574324607849  MAE:0.4412080645561218
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.25000396370887756  MAE:0.39668527245521545
# ▶ seg58  mean  MSE:0.25000396370887756  MAE:0.39668527245521545
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.46414947509765625  MAE:0.5559108257293701
# ▶ seg59  mean  MSE:0.46414947509765625  MAE:0.5559108257293701
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.25213950872421265  MAE:0.4018937349319458
# ▶ seg60  mean  MSE:0.25213950872421265  MAE:0.4018937349319458
#
# seg10 ch0 MSE : 1.4379377

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTh1_train = torch.load("./1st_results_ETTh1/train_1st_results.pt")
results1_ETTh1_val = torch.load("./1st_results_ETTh1/val_1st_results.pt")
results1_ETTh1_test = torch.load("./1st_results_ETTh1/test_1st_results.pt")

# %% [markdown]
# ### EPO ES - 1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 61
SEG_CNT     = 61
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.170277
#
#   Top  1 | seg 05 | MSE 0.153688 (+0.016590)
#   Top  2 | seg 13 | MSE 0.154965 (+0.015312)
#   Top  3 | seg 53 | MSE 0.154990 (+0.015287)
#   Top  4 | seg 22 | MSE 0.155764 (+0.014513)
#   Top  5 | seg 25 | MSE 0.155914 (+0.014363)
#   Top  6 | seg 12 | MSE 0.155930 (+0.014347)
#   Top  7 | seg 47 | MSE 0.156595 (+0.013682)
#   Top  8 | seg 27 | MSE 0.156824 (+0.013453)
#   Top  9 | seg 38 | MSE 0.156958 (+0.013319)
#   Top 10 | seg 17 | MSE 0.157868 (+0.012409)
#   Top 11 | seg 10 | MSE 0.158078 (+0.012199)
#   Top 12 | seg 46 | MSE 0.158083 (+0.012194)
#   Top 13 | seg 57 | MSE 0.158124 (+0.012153)
#   Top 14 | seg 08 | MSE 0.158440 (+0.011837)
#   Top 15 | seg 58 | MSE 0.158754 (+0.011523)
#   Top 16 | seg 60 | MSE 0.159158 (+0.011119)
#   Top 17 | seg 33 | MSE 0.159293 (+0.010984)
#   Top 18 | seg 31 | MSE 0.159619 (+0.010658)
E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 61
SEG_CNT     = 61
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.170277
#
#   Top  1 | seg 52 | MSE 0.156098 (+0.014179)
#   Top  2 | seg 58 | MSE 0.156390 (+0.013887)
#   Top  3 | seg 11 | MSE 0.157058 (+0.013219)
#   Top  4 | seg 60 | MSE 0.157116 (+0.013161)
#   Top  5 | seg 15 | MSE 0.157601 (+0.012676)
#   Top  6 | seg 13 | MSE 0.157842 (+0.012435)
#   Top  7 | seg 57 | MSE 0.158071 (+0.012206)
#   Top  8 | seg 29 | MSE 0.158636 (+0.011641)
#   Top  9 | seg 54 | MSE 0.159761 (+0.010516)
#   Top 10 | seg 40 | MSE 0.160141 (+0.010136)
#   Top 11 | seg 38 | MSE 0.160249 (+0.010028)
#   Top 12 | seg 55 | MSE 0.160339 (+0.009938)
#   Top 13 | seg 25 | MSE 0.161173 (+0.009104)
#   Top 14 | seg 45 | MSE 0.161836 (+0.008441)
#   Top 15 | seg 53 | MSE 0.161898 (+0.008379)
#   Top 16 | seg 08 | MSE 0.162002 (+0.008275)
#   Top 17 | seg 47 | MSE 0.162182 (+0.008095)
#   Top 18 | seg 50 | MSE 0.162245 (+0.008032)
#   Top 19 | seg 27 | MSE 0.162295 (+0.007982)
#   Top 20 | seg 19 | MSE 0.163104 (+0.007173)
#   Top 21 | seg 24 | MSE 0.163140 (+0.007137)
#   Top 22 | seg 39 | MSE 0.163292 (+0.006985)
#   Top 23 | seg 03 | MSE 0.163705 (+0.006572)
#   Top 24 | seg 22 | MSE 0.163755 (+0.006522)
#   Top 25 | seg 43 | MSE 0.163909 (+0.006368)
#   Top 26 | seg 46 | MSE 0.164248 (+0.006029)
#   Top 27 | seg 30 | MSE 0.164558 (+0.005719)
#   Top 28 | seg 42 | MSE 0.164921 (+0.005356)
#   Top 29 | seg 17 | MSE 0.165114 (+0.005163)
#   Top 30 | seg 26 | MSE 0.165309 (+0.004968)
#   Top 31 | seg 01 | MSE 0.165619 (+0.004658)
#   Top 32 | seg 56 | MSE 0.165778 (+0.004499)
#   Top 33 | seg 14 | MSE 0.166416 (+0.003861)
#   Top 34 | seg 09 | MSE 0.166900 (+0.003377)
#   Top 35 | seg 05 | MSE 0.167703 (+0.002574)
#   Top 36 | seg 00 | MSE 0.168017 (+0.002260)
#   Top 37 | seg 35 | MSE 0.170064 (+0.000213)
#   Top 38 | seg 59 | MSE 0.170200 (+0.000077)
#   Top 39 | seg 41 | MSE 0.170546 (-0.000269)
#   Top 40 | seg 16 | MSE 0.170653 (-0.000376)
#   Top 41 | seg 18 | MSE 0.172330 (-0.002053)
#   Top 42 | seg 32 | MSE 0.175569 (-0.005292)
#   Top 43 | seg 37 | MSE 0.176139 (-0.005862)
#   Top 44 | seg 33 | MSE 0.176755 (-0.006478)
#   Top 45 | seg 12 | MSE 0.177068 (-0.006791)
#   Top 46 | seg 04 | MSE 0.178534 (-0.008257)
#   Top 47 | seg 06 | MSE 0.180819 (-0.010542)
#   Top 48 | seg 28 | MSE 0.184907 (-0.014630)
#   Top 49 | seg 20 | MSE 0.188968 (-0.018691)
#   Top 50 | seg 21 | MSE 0.195496 (-0.025219)
#   Top 51 | seg 02 | MSE 0.200371 (-0.030094)
#   Top 52 | seg 23 | MSE 0.201566 (-0.031289)
#   Top 53 | seg 49 | MSE 0.204722 (-0.034445)
#   Top 54 | seg 31 | MSE 0.208361 (-0.038084)
#   Top 55 | seg 10 | MSE 0.209238 (-0.038961)
#   Top 56 | seg 51 | MSE 0.220692 (-0.050415)
#   Top 57 | seg 36 | MSE 0.236453 (-0.066176)
#   Top 58 | seg 34 | MSE 0.265368 (-0.095090)
#   Top 59 | seg 48 | MSE 0.301549 (-0.131272)
#   Top 60 | seg 44 | MSE 0.314818 (-0.144541)
#   Top 61 | seg 07 | MSE 0.364727 (-0.194450)
#
# Saved top segment indices per channel:
# Channel 0: [52, 58, 11, 60, 15, 13, 57, 29, 54, 40, 38, 55, 25, 45, 53, 8, 47, 50, 27, 19, 24, 39, 3, 22, 43, 46, 30, 42, 17, 26, 1, 56, 14, 9, 5, 0, 35, 59, 41, 16, 18, 32, 37, 33, 12, 4, 6, 28, 20, 21, 2, 23, 49, 31, 10, 51, 36, 34, 48, 44, 7]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## EPO ES - 1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTh1_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.159840 | MAE : 0.325716
#   — Var / |Corr| / Score —
#    K= 5 | Var=9.633e-02 | |ρ|=0.4654 | S=1.0000
#    K=10 | Var=1.205e-01 | |ρ|=0.4077 | S=0.8007
#    K=15 | Var=1.269e-01 | |ρ|=0.3753 | S=0.6611
#    K=20 | Var=1.340e-01 | |ρ|=0.3721 | S=0.6726
#    K=25 | Var=1.406e-01 | |ρ|=0.3582 | S=0.6277
#    K=30 | Var=1.521e-01 | |ρ|=0.3380 | S=0.5695
#    K=35 | Var=1.630e-01 | |ρ|=0.3239 | S=0.5408
#    K=40 | Var=1.754e-01 | |ρ|=0.3123 | S=0.5306 <- pick
#    K=45 | Var=1.863e-01 | |ρ|=0.3070 | S=0.5462
#    K=50 | Var=2.009e-01 | |ρ|=0.2932 | S=0.5332
#    K=55 | Var=2.246e-01 | |ρ|=0.2805 | S=0.5618
#    K=60 | Var=3.510e-01 | |ρ|=0.2691 | S=1.0000
# [Var-Corr]  K=40
#   MSE = 0.153472 | Δ = +0.006368 | Δ% = +3.98%
#   MAE = 0.317458 | Δ = +0.008258 | Δ% = +2.54%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.159840
# Ensemble mean MSE : 0.153472
# Average Δ MSE     : +0.006368
# Average Δ MSE (%) : +3.98%
#
# Vanilla  mean MAE : 0.325716
# Ensemble mean MAE : 0.317458
# Average Δ MAE     : +0.008258
# Average Δ MAE (%) : +2.54%

# %% [markdown]
# ## EPO 1 - 1E

# %%
results1_ETTh1_test['ES']['mae_test_EES']
# Out:
# 0.32571619749069214

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTh1_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.35   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.159840 | MAE : 0.325716
#   — Var / |Corr| / Score —
#    K= 5 | Var=1.185e-01 | |ρ|=0.3616 | S=1.3500
#    K=10 | Var=1.424e-01 | |ρ|=0.3346 | S=1.0614
#    K=15 | Var=1.525e-01 | |ρ|=0.3335 | S=1.0785
#    K=20 | Var=1.655e-01 | |ρ|=0.3139 | S=0.8557
#    K=25 | Var=1.707e-01 | |ρ|=0.3095 | S=0.8131
#    K=30 | Var=1.788e-01 | |ρ|=0.3068 | S=0.8024
#    K=35 | Var=1.891e-01 | |ρ|=0.3001 | S=0.7435
#    K=40 | Var=2.013e-01 | |ρ|=0.2940 | S=0.7003
#    K=45 | Var=2.222e-01 | |ρ|=0.2934 | S=0.7581
#    K=50 | Var=2.519e-01 | |ρ|=0.2733 | S=0.5817 <- pick
#    K=55 | Var=3.059e-01 | |ρ|=0.2627 | S=0.6100
#    K=60 | Var=4.341e-01 | |ρ|=0.2615 | S=1.0000
# [Var-Corr]  K=50
#    MSE = 0.166458 | Δ = -0.006618 | Δ% = -4.14%
#    MAE = 0.332201 | Δ = -0.006485 | Δ% = -1.99%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.159840
# Ensemble mean MSE  : 0.166458
# Average Δ MSE      : -0.006618
# Average Δ MSE (%)  : -4.14%
#
# Vanilla  mean MAE  : 0.325716
# Ensemble mean MAE  : 0.332201
# Average Δ MAE      : -0.006485
# Average Δ MAE (%)  : -1.99%
