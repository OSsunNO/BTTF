# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(2)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 2
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTm2.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                           HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# date
# 2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 2016-07-01 00:15:00  39.622002  11.309  35.543999  8.551  3.209  1.258
# 2016-07-01 00:30:00  38.868000  10.555  34.365002  7.586  4.435  1.258
# 2016-07-01 00:45:00  35.518002   9.214  32.569000  8.712  4.435  1.215
# 2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
#
#                             OT
# date
# 2016-07-01 00:00:00  38.661999
# 2016-07-01 00:15:00  38.223000
# 2016-07-01 00:30:00  37.344002
# 2016-07-01 00:45:00  37.124001
# 2016-07-01 01:00:00  37.124001

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (69680, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 00:15:00',
#                '2016-07-01 00:30:00', '2016-07-01 00:45:00',
#                '2016-07-01 01:00:00', '2016-07-01 01:15:00',
#                '2016-07-01 01:30:00', '2016-07-01 01:45:00',
#                '2016-07-01 02:00:00', '2016-07-01 02:15:00',
#                ...
#                '2018-06-26 17:30:00', '2018-06-26 17:45:00',
#                '2018-06-26 18:00:00', '2018-06-26 18:15:00',
#                '2018-06-26 18:30:00', '2018-06-26 18:45:00',
#                '2018-06-26 19:00:00', '2018-06-26 19:15:00',
#                '2018-06-26 19:30:00', '2018-06-26 19:45:00'],
#               dtype='datetime64[ns]', name='date', length=69680, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model(nn.Module):
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.channels = configs.enc_in

        
        self.attach_pv = getattr(configs, "attach_pv", False)

        
        self.extra_len = self.pred_len // 3

        
        self.seq_len_aug = self.seq_len + (self.extra_len if self.attach_pv else 0)

        self.individual = configs.individual

        
        if self.individual:
            self.Linear = nn.ModuleList()
            for i in range(self.channels):
                self.Linear.append(nn.Linear(self.seq_len_aug, self.pred_len))
        else:
            self.Linear = nn.Linear(self.seq_len_aug, self.pred_len)


    def forward(self, x, ground_truth=None):
        B, L, C = x.size()

        
        
        
        if self.attach_pv and (ground_truth is not None):
            
            gt_part = ground_truth[:, :self.extra_len, :]  

            
            x = torch.cat([x, gt_part], dim=1)

        
        
        
        if self.individual:
            out = torch.zeros([B, self.pred_len, C], dtype=x.dtype).to(x.device)
            for i in range(C):
                out[:, :, i] = self.Linear[i](x[:, :, i])
            return out

        else:
            
            out = self.Linear(x.permute(0, 2, 1))
            return out.permute(0, 2, 1)

# %% [markdown]
# # 데이터 분할/스케일링/시퀀스 데이터 구조화

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 720




train_points = 12 * 30 * 24 * 4
val_points   = 4  * 30 * 24 * 4
test_points  = 4  * 30 * 24 * 4

border1s = [
    0,
    train_points - seq_len,
    train_points + val_points - seq_len
]
border2s = [
    train_points,
    train_points + val_points,
    train_points + val_points + test_points
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([33505, 336, 1])
# Train Labels:    torch.Size([33505, 720, 1])
# Val Sequences:   torch.Size([10801, 336, 1])
# Val Labels:      torch.Size([10801, 720, 1])
# Test Sequences:  torch.Size([10801, 336, 1])
# Test Labels:     torch.Size([10801, 720, 1])

# %%
set_seed(43)

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 기본 모델 학습 (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.4340982665485553 | Val Loss: 5.56921197229324
# Validation loss decreased (inf --> 5.569212).  Saving model ...
# Updating learning rate to 0.01
# Epoch 1 | Train Loss: 0.3102468265547552 | Val Loss: 1.0494516195740395
# Validation loss decreased (5.569212 --> 1.049452).  Saving model ...
# Updating learning rate to 0.005
# Epoch 2 | Train Loss: 0.25388674814794354 | Val Loss: 0.2974285761654906
# Validation loss decreased (1.049452 --> 0.297429).  Saving model ...
# Updating learning rate to 0.0025
# Epoch 3 | Train Loss: 0.24215908891713347 | Val Loss: 0.2636351671466637
# Validation loss decreased (0.297429 --> 0.263635).  Saving model ...
# Updating learning rate to 0.00125
# Epoch 4 | Train Loss: 0.23420414694705766 | Val Loss: 0.22053144174523254
# Validation loss decreased (0.263635 --> 0.220531).  Saving model ...
# Updating learning rate to 0.000625
# Epoch 5 | Train Loss: 0.22999691800392083 | Val Loss: 0.21528081809165034
# Validation loss decreased (0.220531 --> 0.215281).  Saving model ...
# Updating learning rate to 0.0003125
# Epoch 6 | Train Loss: 0.22772322538244816 | Val Loss: 0.21213618503916545
# Validation loss decreased (0.215281 --> 0.212136).  Saving model ...
# Updating learning rate to 0.00015625
# Epoch 7 | Train Loss: 0.2282691208489296 | Val Loss: 0.21395917525570068
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.8125e-05
# Epoch 8 | Train Loss: 0.22539679737377713 | Val Loss: 0.20678308500340703
# Validation loss decreased (0.212136 --> 0.206783).  Saving model ...
# Updating learning rate to 3.90625e-05
# Epoch 9 | Train Loss: 0.22447030621630545 | Val Loss: 0.20557924929851965
# Validation loss decreased (0.206783 --> 0.205579).  Saving model ...

# %% [markdown]
# # 기본 모델 학습 (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_pv=False ) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.44227799933887163 | Val Loss: 0.5392219851002891
# Model saved at epoch 1

# %% [markdown]
# # Test set 추론 및 예측값 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.1770598143339157 | MAE: 0.3224932849407196
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.533134400844574 | MAE: 0.5626861453056335

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %% [markdown]
# ## validation 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.20577837526798248 | MAE: 0.3629492223262787
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.5398600697517395 | MAE: 0.5724331736564636

# %% [markdown]
# ## train 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.22429081797599792 | MAE: 0.35538992285728455
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.47324562072753906 | MAE: 0.5329793691635132

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([33505, 336, 1])
# val_sequences shape:  torch.Size([10801, 336, 1])
# test_sequences shape:  torch.Size([10801, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([33505, 720, 1])
# val_pv shape:  torch.Size([10801, 720, 1])
# test_pv shape:  torch.Size([10801, 720, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([33505, 720, 1])
# val_labels shape:  torch.Size([10801, 720, 1])
# test_labels shape:  torch.Size([10801, 720, 1])

# %% [markdown]
# # Segment Generation Function by Sliding Window

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV (Predictied Value)

# %%
configs.pred_len
# Out:
# 720

# %%
segment_len = configs.pred_len // 3
stride = 8

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([33505, 61, 240, 1]), Val: torch.Size([10801, 61, 240, 1]), Test: torch.Size([10801, 61, 240, 1])
# [Epoch 1] Train seg shape: torch.Size([33505, 61, 240, 1]), Val: torch.Size([10801, 61, 240, 1]), Test: torch.Size([10801, 61, 240, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTm2'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # Segment 32 - 2차 증강 모델학습 (1 Epoch)

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo ES

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 0] Training Time = 5.05 sec
# [Segment 0] GPU Memory Start = 12563.86 MB
# [Segment 0] GPU Memory End   = 9490.26 MB
# [Segment 0] GPU Peak Memory  = 12565.83 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 1] Training Time = 4.83 sec
# [Segment 1] GPU Memory Start = 9490.26 MB
# [Segment 1] GPU Memory End   = 9491.85 MB
# [Segment 1] GPU Peak Memory  = 9493.75 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 2] Training Time = 2.44 sec
# [Segment 2] GPU Memory Start = 9491.85 MB
# [Segment 2] GPU Memory End   = 9493.43 MB
# [Segment 2] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 3] Training Time = 4.73 sec
# [Segment 3] GPU Memory Start = 9493.43 MB
# [Segment 3] GPU Memory End   = 9495.02 MB
# [Segment 3] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 4] Training Time = 2.37 sec
# [Segment 4] GPU Memory Start = 9495.02 MB
# [Segment 4] GPU Memory End   = 9496.60 MB
# [Segment 4] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 5] Training Time = 4.62 sec
# [Segment 5] GPU Memory Start = 9496.60 MB
# [Segment 5] GPU Memory End   = 9498.19 MB
# [Segment 5] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 6] Training Time = 4.75 sec
# [Segment 6] GPU Memory Start = 9498.19 MB
# [Segment 6] GPU Memory End   = 9499.77 MB
# [Segment 6] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 7] Training Time = 3.90 sec
# [Segment 7] GPU Memory Start = 9499.77 MB
# [Segment 7] GPU Memory End   = 9501.36 MB
# [Segment 7] GPU Peak Memory  = 9503.26 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 8] Training Time = 4.82 sec
# [Segment 8] GPU Memory Start = 9501.36 MB
# [Segment 8] GPU Memory End   = 9502.94 MB
# [Segment 8] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 9] Training Time = 2.39 sec
# [Segment 9] GPU Memory Start = 9502.94 MB
# [Segment 9] GPU Memory End   = 9504.53 MB
# [Segment 9] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 10] Training Time = 4.77 sec
# [Segment 10] GPU Memory Start = 9489.87 MB
# [Segment 10] GPU Memory End   = 9491.85 MB
# [Segment 10] GPU Peak Memory  = 9493.75 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 11] Training Time = 4.33 sec
# [Segment 11] GPU Memory Start = 9491.85 MB
# [Segment 11] GPU Memory End   = 9493.43 MB
# [Segment 11] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 12] Training Time = 3.46 sec
# [Segment 12] GPU Memory Start = 9493.43 MB
# [Segment 12] GPU Memory End   = 9495.02 MB
# [Segment 12] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 13] Training Time = 4.88 sec
# [Segment 13] GPU Memory Start = 9495.02 MB
# [Segment 13] GPU Memory End   = 9496.60 MB
# [Segment 13] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 14] Training Time = 4.59 sec
# [Segment 14] GPU Memory Start = 9496.60 MB
# [Segment 14] GPU Memory End   = 9498.19 MB
# [Segment 14] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 15] Training Time = 4.84 sec
# [Segment 15] GPU Memory Start = 9498.19 MB
# [Segment 15] GPU Memory End   = 9499.77 MB
# [Segment 15] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 16] Training Time = 4.01 sec
# [Segment 16] GPU Memory Start = 9499.77 MB
# [Segment 16] GPU Memory End   = 9500.77 MB
# [Segment 16] GPU Peak Memory  = 9502.76 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 17] Training Time = 4.72 sec
# [Segment 17] GPU Memory Start = 9500.77 MB
# [Segment 17] GPU Memory End   = 9502.94 MB
# [Segment 17] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 18] Training Time = 4.61 sec
# [Segment 18] GPU Memory Start = 9502.94 MB
# [Segment 18] GPU Memory End   = 9504.53 MB
# [Segment 18] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 19] Training Time = 4.80 sec
# [Segment 19] GPU Memory Start = 9504.53 MB
# [Segment 19] GPU Memory End   = 9506.11 MB
# [Segment 19] GPU Peak Memory  = 9508.02 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 20] Training Time = 4.71 sec
# [Segment 20] GPU Memory Start = 9491.45 MB
# [Segment 20] GPU Memory End   = 9493.43 MB
# [Segment 20] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 21] Training Time = 4.20 sec
# [Segment 21] GPU Memory Start = 9493.43 MB
# [Segment 21] GPU Memory End   = 9495.02 MB
# [Segment 21] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 22] Training Time = 4.77 sec
# [Segment 22] GPU Memory Start = 9495.02 MB
# [Segment 22] GPU Memory End   = 9496.60 MB
# [Segment 22] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 23] Training Time = 4.27 sec
# [Segment 23] GPU Memory Start = 9496.60 MB
# [Segment 23] GPU Memory End   = 9498.19 MB
# [Segment 23] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 24] Training Time = 4.76 sec
# [Segment 24] GPU Memory Start = 9498.19 MB
# [Segment 24] GPU Memory End   = 9499.77 MB
# [Segment 24] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 25] Training Time = 4.82 sec
# [Segment 25] GPU Memory Start = 9499.77 MB
# [Segment 25] GPU Memory End   = 9501.36 MB
# [Segment 25] GPU Peak Memory  = 9503.26 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 26] Training Time = 4.40 sec
# [Segment 26] GPU Memory Start = 9501.36 MB
# [Segment 26] GPU Memory End   = 9502.35 MB
# [Segment 26] GPU Peak Memory  = 9504.34 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 27] Training Time = 2.47 sec
# [Segment 27] GPU Memory Start = 9502.35 MB
# [Segment 27] GPU Memory End   = 9504.13 MB
# [Segment 27] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 28] Training Time = 4.72 sec
# [Segment 28] GPU Memory Start = 9504.13 MB
# [Segment 28] GPU Memory End   = 9506.11 MB
# [Segment 28] GPU Peak Memory  = 9508.02 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 29] Training Time = 3.63 sec
# [Segment 29] GPU Memory Start = 9506.11 MB
# [Segment 29] GPU Memory End   = 9507.70 MB
# [Segment 29] GPU Peak Memory  = 9509.60 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 30] Training Time = 3.70 sec
# [Segment 30] GPU Memory Start = 9491.45 MB
# [Segment 30] GPU Memory End   = 9492.84 MB
# [Segment 30] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 31] Training Time = 4.81 sec
# [Segment 31] GPU Memory Start = 9492.84 MB
# [Segment 31] GPU Memory End   = 9495.02 MB
# [Segment 31] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 32] Training Time = 4.44 sec
# [Segment 32] GPU Memory Start = 9495.02 MB
# [Segment 32] GPU Memory End   = 9496.60 MB
# [Segment 32] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 33] Training Time = 4.70 sec
# [Segment 33] GPU Memory Start = 9496.60 MB
# [Segment 33] GPU Memory End   = 9498.19 MB
# [Segment 33] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 34] Training Time = 4.71 sec
# [Segment 34] GPU Memory Start = 9498.19 MB
# [Segment 34] GPU Memory End   = 9499.77 MB
# [Segment 34] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 35] Training Time = 4.69 sec
# [Segment 35] GPU Memory Start = 9499.77 MB
# [Segment 35] GPU Memory End   = 9501.36 MB
# [Segment 35] GPU Peak Memory  = 9503.26 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 36] Training Time = 2.41 sec
# [Segment 36] GPU Memory Start = 9501.36 MB
# [Segment 36] GPU Memory End   = 9502.94 MB
# [Segment 36] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 37] Training Time = 2.41 sec
# [Segment 37] GPU Memory Start = 9502.94 MB
# [Segment 37] GPU Memory End   = 9504.53 MB
# [Segment 37] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 38] Training Time = 4.79 sec
# [Segment 38] GPU Memory Start = 9504.53 MB
# [Segment 38] GPU Memory End   = 9505.72 MB
# [Segment 38] GPU Peak Memory  = 9508.02 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 39] Training Time = 2.42 sec
# [Segment 39] GPU Memory Start = 9505.72 MB
# [Segment 39] GPU Memory End   = 9507.70 MB
# [Segment 39] GPU Peak Memory  = 9509.60 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 40] Training Time = 4.81 sec
# [Segment 40] GPU Memory Start = 9491.26 MB
# [Segment 40] GPU Memory End   = 9493.43 MB
# [Segment 40] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 41] Training Time = 4.76 sec
# [Segment 41] GPU Memory Start = 9493.43 MB
# [Segment 41] GPU Memory End   = 9495.02 MB
# [Segment 41] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 42] Training Time = 4.83 sec
# [Segment 42] GPU Memory Start = 9495.02 MB
# [Segment 42] GPU Memory End   = 9496.60 MB
# [Segment 42] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 43] Training Time = 4.77 sec
# [Segment 43] GPU Memory Start = 9496.60 MB
# [Segment 43] GPU Memory End   = 9498.19 MB
# [Segment 43] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 44] Training Time = 4.71 sec
# [Segment 44] GPU Memory Start = 9498.19 MB
# [Segment 44] GPU Memory End   = 9499.77 MB
# [Segment 44] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 45] Training Time = 2.59 sec
# [Segment 45] GPU Memory Start = 9499.77 MB
# [Segment 45] GPU Memory End   = 9500.77 MB
# [Segment 45] GPU Peak Memory  = 9502.76 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 46] Training Time = 4.70 sec
# [Segment 46] GPU Memory Start = 9500.77 MB
# [Segment 46] GPU Memory End   = 9502.94 MB
# [Segment 46] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 47] Training Time = 4.68 sec
# [Segment 47] GPU Memory Start = 9502.94 MB
# [Segment 47] GPU Memory End   = 9504.53 MB
# [Segment 47] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 48] Training Time = 4.87 sec
# [Segment 48] GPU Memory Start = 9504.53 MB
# [Segment 48] GPU Memory End   = 9506.11 MB
# [Segment 48] GPU Peak Memory  = 9508.02 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 49] Training Time = 2.46 sec
# [Segment 49] GPU Memory Start = 9506.11 MB
# [Segment 49] GPU Memory End   = 9507.70 MB
# [Segment 49] GPU Peak Memory  = 9509.60 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 50] Training Time = 3.10 sec
# [Segment 50] GPU Memory Start = 9491.45 MB
# [Segment 50] GPU Memory End   = 9493.43 MB
# [Segment 50] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 51] Training Time = 4.78 sec
# [Segment 51] GPU Memory Start = 9493.43 MB
# [Segment 51] GPU Memory End   = 9495.02 MB
# [Segment 51] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 52] Training Time = 4.69 sec
# [Segment 52] GPU Memory Start = 9495.02 MB
# [Segment 52] GPU Memory End   = 9496.60 MB
# [Segment 52] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 53] Training Time = 4.87 sec
# [Segment 53] GPU Memory Start = 9496.60 MB
# [Segment 53] GPU Memory End   = 9498.19 MB
# [Segment 53] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 54] Training Time = 4.79 sec
# [Segment 54] GPU Memory Start = 9498.19 MB
# [Segment 54] GPU Memory End   = 9499.77 MB
# [Segment 54] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 55] Training Time = 4.79 sec
# [Segment 55] GPU Memory Start = 9499.77 MB
# [Segment 55] GPU Memory End   = 9501.36 MB
# [Segment 55] GPU Peak Memory  = 9503.26 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 56] Training Time = 4.49 sec
# [Segment 56] GPU Memory Start = 9501.36 MB
# [Segment 56] GPU Memory End   = 9502.94 MB
# [Segment 56] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 57] Training Time = 4.35 sec
# [Segment 57] GPU Memory Start = 9502.94 MB
# [Segment 57] GPU Memory End   = 9503.94 MB
# [Segment 57] GPU Peak Memory  = 9505.93 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 58] Training Time = 4.87 sec
# [Segment 58] GPU Memory Start = 9503.94 MB
# [Segment 58] GPU Memory End   = 9505.72 MB
# [Segment 58] GPU Peak Memory  = 9508.02 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 59] Training Time = 4.75 sec
# [Segment 59] GPU Memory Start = 9505.72 MB
# [Segment 59] GPU Memory End   = 9507.70 MB
# [Segment 59] GPU Peak Memory  = 9509.60 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 60] Training Time = 4.77 sec
# [Segment 60] GPU Memory Start = 9491.85 MB
# [Segment 60] GPU Memory End   = 9493.43 MB
# [Segment 60] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo 1

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E/",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 0] Training Time = 4.89 sec
# [Segment 0] GPU Memory Start = 9493.43 MB
# [Segment 0] GPU Memory End   = 9491.85 MB
# [Segment 0] GPU Peak Memory  = 9494.83 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 1] Training Time = 4.84 sec
# [Segment 1] GPU Memory Start = 9491.85 MB
# [Segment 1] GPU Memory End   = 9493.43 MB
# [Segment 1] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 2] Training Time = 3.71 sec
# [Segment 2] GPU Memory Start = 9493.43 MB
# [Segment 2] GPU Memory End   = 9495.02 MB
# [Segment 2] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 3] Training Time = 4.67 sec
# [Segment 3] GPU Memory Start = 9495.02 MB
# [Segment 3] GPU Memory End   = 9496.60 MB
# [Segment 3] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 4] Training Time = 4.79 sec
# [Segment 4] GPU Memory Start = 9496.60 MB
# [Segment 4] GPU Memory End   = 9498.19 MB
# [Segment 4] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 5] Training Time = 4.74 sec
# [Segment 5] GPU Memory Start = 9498.19 MB
# [Segment 5] GPU Memory End   = 9499.77 MB
# [Segment 5] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 6] Training Time = 4.70 sec
# [Segment 6] GPU Memory Start = 9499.77 MB
# [Segment 6] GPU Memory End   = 9500.77 MB
# [Segment 6] GPU Peak Memory  = 9502.76 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 7] Training Time = 4.78 sec
# [Segment 7] GPU Memory Start = 9500.77 MB
# [Segment 7] GPU Memory End   = 9502.94 MB
# [Segment 7] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 8] Training Time = 4.62 sec
# [Segment 8] GPU Memory Start = 9502.94 MB
# [Segment 8] GPU Memory End   = 9504.53 MB
# [Segment 8] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 9] Training Time = 4.74 sec
# [Segment 9] GPU Memory Start = 9504.53 MB
# [Segment 9] GPU Memory End   = 9506.11 MB
# [Segment 9] GPU Peak Memory  = 9508.02 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 10] Training Time = 4.68 sec
# [Segment 10] GPU Memory Start = 9506.11 MB
# [Segment 10] GPU Memory End   = 9491.85 MB
# [Segment 10] GPU Peak Memory  = 9506.11 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 11] Training Time = 4.57 sec
# [Segment 11] GPU Memory Start = 9491.85 MB
# [Segment 11] GPU Memory End   = 9493.43 MB
# [Segment 11] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 12] Training Time = 4.73 sec
# [Segment 12] GPU Memory Start = 9493.43 MB
# [Segment 12] GPU Memory End   = 9495.02 MB
# [Segment 12] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 13] Training Time = 4.72 sec
# [Segment 13] GPU Memory Start = 9495.02 MB
# [Segment 13] GPU Memory End   = 9496.60 MB
# [Segment 13] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 14] Training Time = 4.81 sec
# [Segment 14] GPU Memory Start = 9496.60 MB
# [Segment 14] GPU Memory End   = 9498.19 MB
# [Segment 14] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 15] Training Time = 4.36 sec
# [Segment 15] GPU Memory Start = 9498.19 MB
# [Segment 15] GPU Memory End   = 9499.77 MB
# [Segment 15] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 16] Training Time = 4.88 sec
# [Segment 16] GPU Memory Start = 9499.77 MB
# [Segment 16] GPU Memory End   = 9500.77 MB
# [Segment 16] GPU Peak Memory  = 9502.76 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 17] Training Time = 4.80 sec
# [Segment 17] GPU Memory Start = 9500.77 MB
# [Segment 17] GPU Memory End   = 9502.55 MB
# [Segment 17] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 18] Training Time = 4.77 sec
# [Segment 18] GPU Memory Start = 9502.55 MB
# [Segment 18] GPU Memory End   = 9504.53 MB
# [Segment 18] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 19] Training Time = 3.75 sec
# [Segment 19] GPU Memory Start = 9504.53 MB
# [Segment 19] GPU Memory End   = 9506.11 MB
# [Segment 19] GPU Peak Memory  = 9508.02 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 20] Training Time = 3.48 sec
# [Segment 20] GPU Memory Start = 9506.11 MB
# [Segment 20] GPU Memory End   = 9491.85 MB
# [Segment 20] GPU Peak Memory  = 9506.11 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 21] Training Time = 4.68 sec
# [Segment 21] GPU Memory Start = 9491.85 MB
# [Segment 21] GPU Memory End   = 9493.43 MB
# [Segment 21] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 22] Training Time = 4.69 sec
# [Segment 22] GPU Memory Start = 9493.43 MB
# [Segment 22] GPU Memory End   = 9495.02 MB
# [Segment 22] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 23] Training Time = 4.78 sec
# [Segment 23] GPU Memory Start = 9495.02 MB
# [Segment 23] GPU Memory End   = 9496.60 MB
# [Segment 23] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 24] Training Time = 2.34 sec
# [Segment 24] GPU Memory Start = 9496.60 MB
# [Segment 24] GPU Memory End   = 9498.19 MB
# [Segment 24] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 25] Training Time = 2.40 sec
# [Segment 25] GPU Memory Start = 9498.19 MB
# [Segment 25] GPU Memory End   = 9499.77 MB
# [Segment 25] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 26] Training Time = 4.55 sec
# [Segment 26] GPU Memory Start = 9499.77 MB
# [Segment 26] GPU Memory End   = 9500.77 MB
# [Segment 26] GPU Peak Memory  = 9502.76 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 27] Training Time = 4.79 sec
# [Segment 27] GPU Memory Start = 9500.77 MB
# [Segment 27] GPU Memory End   = 9502.55 MB
# [Segment 27] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 28] Training Time = 4.85 sec
# [Segment 28] GPU Memory Start = 9502.55 MB
# [Segment 28] GPU Memory End   = 9504.53 MB
# [Segment 28] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 29] Training Time = 4.73 sec
# [Segment 29] GPU Memory Start = 9504.53 MB
# [Segment 29] GPU Memory End   = 9506.11 MB
# [Segment 29] GPU Peak Memory  = 9508.02 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 30] Training Time = 4.68 sec
# [Segment 30] GPU Memory Start = 9506.11 MB
# [Segment 30] GPU Memory End   = 9490.26 MB
# [Segment 30] GPU Peak Memory  = 9506.11 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 31] Training Time = 4.95 sec
# [Segment 31] GPU Memory Start = 9490.26 MB
# [Segment 31] GPU Memory End   = 9491.85 MB
# [Segment 31] GPU Peak Memory  = 9493.75 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 32] Training Time = 4.76 sec
# [Segment 32] GPU Memory Start = 9491.85 MB
# [Segment 32] GPU Memory End   = 9493.43 MB
# [Segment 32] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 33] Training Time = 2.70 sec
# [Segment 33] GPU Memory Start = 9493.43 MB
# [Segment 33] GPU Memory End   = 9495.02 MB
# [Segment 33] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 34] Training Time = 3.12 sec
# [Segment 34] GPU Memory Start = 9495.02 MB
# [Segment 34] GPU Memory End   = 9496.60 MB
# [Segment 34] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 35] Training Time = 4.91 sec
# [Segment 35] GPU Memory Start = 9496.60 MB
# [Segment 35] GPU Memory End   = 9498.19 MB
# [Segment 35] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 36] Training Time = 3.79 sec
# [Segment 36] GPU Memory Start = 9498.19 MB
# [Segment 36] GPU Memory End   = 9499.77 MB
# [Segment 36] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 37] Training Time = 4.68 sec
# [Segment 37] GPU Memory Start = 9499.77 MB
# [Segment 37] GPU Memory End   = 9501.36 MB
# [Segment 37] GPU Peak Memory  = 9503.26 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 38] Training Time = 4.86 sec
# [Segment 38] GPU Memory Start = 9501.36 MB
# [Segment 38] GPU Memory End   = 9502.94 MB
# [Segment 38] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 39] Training Time = 2.47 sec
# [Segment 39] GPU Memory Start = 9502.94 MB
# [Segment 39] GPU Memory End   = 9504.53 MB
# [Segment 39] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 40] Training Time = 4.56 sec
# [Segment 40] GPU Memory Start = 9504.53 MB
# [Segment 40] GPU Memory End   = 9490.26 MB
# [Segment 40] GPU Peak Memory  = 9504.53 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 41] Training Time = 4.76 sec
# [Segment 41] GPU Memory Start = 9490.26 MB
# [Segment 41] GPU Memory End   = 9491.85 MB
# [Segment 41] GPU Peak Memory  = 9493.75 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 42] Training Time = 4.87 sec
# [Segment 42] GPU Memory Start = 9491.85 MB
# [Segment 42] GPU Memory End   = 9493.43 MB
# [Segment 42] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 43] Training Time = 4.57 sec
# [Segment 43] GPU Memory Start = 9493.43 MB
# [Segment 43] GPU Memory End   = 9495.02 MB
# [Segment 43] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 44] Training Time = 4.83 sec
# [Segment 44] GPU Memory Start = 9495.02 MB
# [Segment 44] GPU Memory End   = 9496.60 MB
# [Segment 44] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 45] Training Time = 2.40 sec
# [Segment 45] GPU Memory Start = 9496.60 MB
# [Segment 45] GPU Memory End   = 9498.19 MB
# [Segment 45] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 46] Training Time = 4.58 sec
# [Segment 46] GPU Memory Start = 9498.19 MB
# [Segment 46] GPU Memory End   = 9499.77 MB
# [Segment 46] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 47] Training Time = 4.87 sec
# [Segment 47] GPU Memory Start = 9499.77 MB
# [Segment 47] GPU Memory End   = 9501.36 MB
# [Segment 47] GPU Peak Memory  = 9503.26 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 48] Training Time = 2.46 sec
# [Segment 48] GPU Memory Start = 9501.36 MB
# [Segment 48] GPU Memory End   = 9502.94 MB
# [Segment 48] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 49] Training Time = 4.64 sec
# [Segment 49] GPU Memory Start = 9502.94 MB
# [Segment 49] GPU Memory End   = 9504.53 MB
# [Segment 49] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 50] Training Time = 4.91 sec
# [Segment 50] GPU Memory Start = 9504.53 MB
# [Segment 50] GPU Memory End   = 9490.26 MB
# [Segment 50] GPU Peak Memory  = 9504.53 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 51] Training Time = 2.48 sec
# [Segment 51] GPU Memory Start = 9490.26 MB
# [Segment 51] GPU Memory End   = 9491.85 MB
# [Segment 51] GPU Peak Memory  = 9493.75 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 52] Training Time = 4.77 sec
# [Segment 52] GPU Memory Start = 9491.85 MB
# [Segment 52] GPU Memory End   = 9493.43 MB
# [Segment 52] GPU Peak Memory  = 9495.34 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 53] Training Time = 4.79 sec
# [Segment 53] GPU Memory Start = 9493.43 MB
# [Segment 53] GPU Memory End   = 9495.02 MB
# [Segment 53] GPU Peak Memory  = 9496.92 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 54] Training Time = 3.99 sec
# [Segment 54] GPU Memory Start = 9495.02 MB
# [Segment 54] GPU Memory End   = 9496.60 MB
# [Segment 54] GPU Peak Memory  = 9498.51 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 55] Training Time = 4.82 sec
# [Segment 55] GPU Memory Start = 9496.60 MB
# [Segment 55] GPU Memory End   = 9498.19 MB
# [Segment 55] GPU Peak Memory  = 9500.09 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 56] Training Time = 4.77 sec
# [Segment 56] GPU Memory Start = 9498.19 MB
# [Segment 56] GPU Memory End   = 9499.77 MB
# [Segment 56] GPU Peak Memory  = 9501.68 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 57] Training Time = 3.84 sec
# [Segment 57] GPU Memory Start = 9499.77 MB
# [Segment 57] GPU Memory End   = 9501.36 MB
# [Segment 57] GPU Peak Memory  = 9503.26 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 58] Training Time = 4.00 sec
# [Segment 58] GPU Memory Start = 9501.36 MB
# [Segment 58] GPU Memory End   = 9502.94 MB
# [Segment 58] GPU Peak Memory  = 9504.85 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 59] Training Time = 4.75 sec
# [Segment 59] GPU Memory Start = 9502.94 MB
# [Segment 59] GPU Memory End   = 9504.53 MB
# [Segment 59] GPU Peak Memory  = 9506.43 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 60] Training Time = 4.78 sec
# [Segment 60] GPU Memory Start = 9504.53 MB
# [Segment 60] GPU Memory End   = 9490.26 MB
# [Segment 60] GPU Peak Memory  = 9504.53 MB
#
# ============= Done =============

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for validation set 얻은 후 에러율 계산

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTm2_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.8509591817855835  MAE:0.6921248435974121
# ▶ seg0  mean  MSE:0.8509591817855835  MAE:0.6921248435974121
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.7230947613716125  MAE:0.6246002912521362
# ▶ seg1  mean  MSE:0.7230947613716125  MAE:0.6246002912521362
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.9121847152709961  MAE:0.6835283637046814
# ▶ seg2  mean  MSE:0.9121847152709961  MAE:0.6835283637046814
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.7351676821708679  MAE:0.6821576952934265
# ▶ seg3  mean  MSE:0.7351676821708679  MAE:0.6821576952934265
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.6495333313941956  MAE:0.6065824627876282
# ▶ seg4  mean  MSE:0.6495333313941956  MAE:0.6065824627876282
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.7158353328704834  MAE:0.6434903144836426
# ▶ seg5  mean  MSE:0.7158353328704834  MAE:0.6434903144836426
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:1.4386755228042603  MAE:0.8476791977882385
# ▶ seg6  mean  MSE:1.4386755228042603  MAE:0.8476791977882385
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.677058219909668  MAE:0.6034601330757141
# ▶ seg59  mean  MSE:0.677058219909668  MAE:0.6034601330757141
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.43915051221847534  MAE:0.5177876949310303
# ▶ seg60  mean  MSE:0.43915051221847534  MAE:0.5177876949310303
#
# seg10 ch0 MSE : 0.6639625

# %% [markdown]
# ## EPO 1 - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_E1_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTm2_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.6260522603988647  MAE:0.604278564453125
# ▶ seg0  mean  MSE:0.6260522603988647  MAE:0.604278564453125
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.43507784605026245  MAE:0.5095483064651489
# ▶ seg1  mean  MSE:0.43507784605026245  MAE:0.5095483064651489
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.7473491430282593  MAE:0.6714474558830261
# ▶ seg2  mean  MSE:0.7473491430282593  MAE:0.6714474558830261
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.5899470448493958  MAE:0.5969234704971313
# ▶ seg3  mean  MSE:0.5899470448493958  MAE:0.5969234704971313
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.6228287816047668  MAE:0.6028724908828735
# ▶ seg4  mean  MSE:0.6228287816047668  MAE:0.6028724908828735
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:1.0401597023010254  MAE:0.7738639116287231
# ▶ seg5  mean  MSE:1.0401597023010254  MAE:0.7738639116287231
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.432468444108963  MAE:0.5240259170532227
# ▶ seg6  mean  MSE:0.432468444108963  MAE:0.5240259170532227
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.7810766696929932  MAE:0.6701800227165222
# ▶ seg7  mean  MSE:0.7810766696929932  MAE:0.6701800227165222
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.5547239780426025  MAE:0.5744047164916992
# ▶ seg8  mean  MSE:0.5547239780426025  MAE:0.5744047164916992
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.5991164445877075  MAE:0.5879017114639282
# ▶ seg9  mean  MSE:0.5991164445877075  MAE:0.5879017114639282
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.9674929976463318  MAE:0.7301027774810791
# ▶ seg10  mean  MSE:0.9674929976463318  MAE:0.7301027774810791
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:1.4823938608169556  MAE:0.8592849969863892
# ▶ seg11  mean  MSE:1.4823938608169556  MAE:0.8592849969863892
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.7135849595069885  MAE:0.6710933446884155
# ▶ seg12  mean  MSE:0.7135849595069885  MAE:0.6710933446884155
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.3460158705711365  MAE:0.46235477924346924
# ▶ seg13  mean  MSE:0.3460158705711365  MAE:0.46235477924346924
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:1.120940089225769  MAE:0.8064112663269043
# ▶ seg14  mean  MSE:1.120940089225769  MAE:0.8064112663269043
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.41754665970802307  MAE:0.5022417306900024
# ▶ seg15  mean  MSE:0.41754665970802307  MAE:0.5022417306900024
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:2.584826707839966  MAE:1.191748857498169
# ▶ seg16  mean  MSE:2.584826707839966  MAE:1.191748857498169
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.5553491711616516  MAE:0.5816890597343445
# ▶ seg17  mean  MSE:0.5553491711616516  MAE:0.5816890597343445
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.9899311065673828  MAE:0.7449291348457336
# ▶ seg18  mean  MSE:0.9899311065673828  MAE:0.7449291348457336
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:1.2998565435409546  MAE:0.8889243006706238
# ▶ seg19  mean  MSE:1.2998565435409546  MAE:0.8889243006706238
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.37176090478897095  MAE:0.4846659004688263
# ▶ seg20  mean  MSE:0.37176090478897095  MAE:0.4846659004688263
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:5.051734924316406  MAE:1.5955450534820557
# ▶ seg48  mean  MSE:5.051734924316406  MAE:1.5955450534820557
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:2.0647783279418945  MAE:1.0010024309158325
# ▶ seg49  mean  MSE:2.0647783279418945  MAE:1.0010024309158325
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.5420332551002502  MAE:0.5654258728027344
# ▶ seg50  mean  MSE:0.5420332551002502  MAE:0.5654258728027344
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.7472056150436401  MAE:0.6531690955162048
# ▶ seg51  mean  MSE:0.7472056150436401  MAE:0.6531690955162048
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.6059476733207703  MAE:0.6006064414978027
# ▶ seg52  mean  MSE:0.6059476733207703  MAE:0.6006064414978027
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.5771384835243225  MAE:0.5838757157325745
# ▶ seg53  mean  MSE:0.5771384835243225  MAE:0.5838757157325745
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.6825700998306274  MAE:0.6349631547927856
# ▶ seg54  mean  MSE:0.6825700998306274  MAE:0.6349631547927856
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:2.327655076980591  MAE:1.192225694656372
# ▶ seg55  mean  MSE:2.327655076980591  MAE:1.192225694656372
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.7388674020767212  MAE:0.6517775058746338
# ▶ seg56  mean  MSE:0.7388674020767212  MAE:0.6517775058746338
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.6300285458564758  MAE:0.6023949980735779
# ▶ seg57  mean  MSE:0.6300285458564758  MAE:0.6023949980735779
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.8545427918434143  MAE:0.6956359148025513
# ▶ seg58  mean  MSE:0.8545427918434143  MAE:0.6956359148025513
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:2.061767578125  MAE:1.0536812543869019
# ▶ seg59  mean  MSE:2.061767578125  MAE:1.0536812543869019
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.5631458759307861  MAE:0.5705362558364868
# ▶ seg60  mean  MSE:0.5631458759307861  MAE:0.5705362558364868
#
# seg10 ch0 MSE : 0.967493

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for test set 얻은 후 에러율 계산

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 720
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTm2_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.9480488300323486  MAE:0.7241501808166504
# ▶ seg0  mean  MSE:0.9480488300323486  MAE:0.7241501808166504
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.888033926486969  MAE:0.685975968837738
# ▶ seg1  mean  MSE:0.888033926486969  MAE:0.685975968837738
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:1.0899767875671387  MAE:0.7405802011489868
# ▶ seg2  mean  MSE:1.0899767875671387  MAE:0.7405802011489868
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.9324143528938293  MAE:0.7884328961372375
# ▶ seg3  mean  MSE:0.9324143528938293  MAE:0.7884328961372375
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.7580467462539673  MAE:0.6524690985679626
# ▶ seg4  mean  MSE:0.7580467462539673  MAE:0.6524690985679626
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.9070973992347717  MAE:0.7218082547187805
# ▶ seg5  mean  MSE:0.9070973992347717  MAE:0.7218082547187805
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:1.6613507270812988  MAE:0.8872100114822388
# ▶ seg6  mean  MSE:1.6613507270812988  MAE:0.8872100114822388
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.7483863234519958  MAE:0.6341939568519592
# ▶ seg7  mean  MSE:0.7483863234519958  MAE:0.6341939568519592
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.7351478934288025  MAE:0.6395865678787231
# ▶ seg8  mean  MSE:0.7351478934288025  MAE:0.6395865678787231
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0
 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 720
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_E1_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTm2_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.7073999643325806  MAE:0.6273135542869568
# ▶ seg0  mean  MSE:0.7073999643325806  MAE:0.6273135542869568
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.4474320113658905  MAE:0.5171027183532715
# ▶ seg1  mean  MSE:0.4474320113658905  MAE:0.5171027183532715
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.9888288974761963  MAE:0.7853627800941467
# ▶ seg2  mean  MSE:0.9888288974761963  MAE:0.7853627800941467
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.8064419627189636  MAE:0.7060946822166443
# ▶ seg3  mean  MSE:0.8064419627189636  MAE:0.7060946822166443
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.8726105093955994  MAE:0.7165462374687195
# ▶ seg4  mean  MSE:0.8726105093955994  MAE:0.7165462374687195
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:1.394362449645996  MAE:0.9021331667900085
# ▶ seg5  mean  MSE:1.394362449645996  MAE:0.9021331667900085
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.5220008492469788  MAE:0.5654972791671753
# ▶ seg6  mean  MSE:0.5220008492469788  MAE:0.5654972791671753
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.9868797063827515  MAE:0.7569570541381836
# ▶ seg7  mean  MSE:0.9868797063827515  MAE:0.7569570541381836
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.6173354387283325  MAE:0.591813862323761
# ▶ seg8  mean  MSE:0.6173354387283325  MAE:0.591813862323761
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.8247174620628357  MAE:0.6758009195327759
# ▶ seg9  mean  MSE:0.8247174620628357  MAE:0.6758009195327759
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:1.156613826751709  MAE:0.7887118458747864
# ▶ seg10  mean  MSE:1.156613826751709  MAE:0.7887118458747864
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:2.105679988861084  MAE:1.0251939296722412
# ▶ seg11  mean  MSE:2.105679988861084  MAE:1.0251939296722412
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.934979259967804  MAE:0.7850737571716309
# ▶ seg12  mean  MSE:0.934979259967804  MAE:0.7850737571716309
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.37435275316238403  MAE:0.47438398003578186
# ▶ seg13  mean  MSE:0.37435275316238403  MAE:0.47438398003578186
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:1.4171828031539917  MAE:0.907228410243988
# ▶ seg14  mean  MSE:1.4171828031539917  MAE:0.907228410243988
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.5194796323776245  MAE:0.56032395362854
# ▶ seg15  mean  MSE:0.5194796323776245  MAE:0.56032395362854
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:3.4361066818237305  MAE:1.3694120645523071
# ▶ seg16  mean  MSE:3.4361066818237305  MAE:1.3694120645523071
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.7715322971343994  MAE:0.6926552057266235
# ▶ seg17  mean  MSE:0.7715322971343994  MAE:0.6926552057266235
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:1.1620032787322998  MAE:0.7968875765800476
# ▶ seg18  mean  MSE:1.1620032787322998  MAE:0.7968875765800476
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:1.6203933954238892  MAE:0.9817902445793152
# ▶ seg19  mean  MSE:1.6203933954238892  MAE:0.9817902445793152
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.3954832851886749  MAE:0.49343225359916687
# ▶ seg20  mean  MSE:0.3954832851886749  MAE:0.49343225359916687
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.5218497514724731  MAE:0.5383176803588867
# ▶ seg21  mean  MSE:0.5218497514724731  MAE:0.5383176803588867
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:2.044116973876953  MAE:1.1289985179901123
# ▶ seg22  mean  MSE:2.044116973876953  MAE:1.1289985179901123
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:2.6648011207580566  MAE:1.1447830200195312
# ▶ seg49  mean  MSE:2.6648011207580566  MAE:1.1447830200195312
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.5970577597618103  MAE:0.5944586992263794
# ▶ seg50  mean  MSE:0.5970577597618103  MAE:0.5944586992263794
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.9266605973243713  MAE:0.7242618203163147
# ▶ seg51  mean  MSE:0.9266605973243713  MAE:0.7242618203163147
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.6874449253082275  MAE:0.6326651573181152
# ▶ seg52  mean  MSE:0.6874449253082275  MAE:0.6326651573181152
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.6068403720855713  MAE:0.5882328152656555
# ▶ seg53  mean  MSE:0.6068403720855713  MAE:0.5882328152656555
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.7565580606460571  MAE:0.668464183807373
# ▶ seg54  mean  MSE:0.7565580606460571  MAE:0.668464183807373
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:2.7728941440582275  MAE:1.2875851392745972
# ▶ seg55  mean  MSE:2.7728941440582275  MAE:1.2875851392745972
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.8753581643104553  MAE:0.7029014825820923
# ▶ seg56  mean  MSE:0.8753581643104553  MAE:0.7029014825820923
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.71608966588974  MAE:0.6364021301269531
# ▶ seg57  mean  MSE:0.71608966588974  MAE:0.6364021301269531
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:1.0536822080612183  MAE:0.7715575098991394
# ▶ seg58  mean  MSE:1.0536822080612183  MAE:0.7715575098991394
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:2.6670618057250977  MAE:1.2229554653167725
# ▶ seg59  mean  MSE:2.6670618057250977  MAE:1.2229554653167725
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.6166814565658569  MAE:0.587308943271637
# ▶ seg60  mean  MSE:0.6166814565658569  MAE:0.587308943271637
#
# seg10 ch0 MSE : 1.1566138

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTm2_train = torch.load("./1st_results_ETTm2/train_1st_results.pt")
results1_ETTm2_val = torch.load("./1st_results_ETTm2/val_1st_results.pt")
results1_ETTm2_test = torch.load("./1st_results_ETTm2/test_1st_results.pt")

# %% [markdown]
# ### EPO ES - 1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 61
SEG_CNT     = 61
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.539860
#
#   Top  1 | seg 44 | MSE 0.362418 (+0.177442)
#   Top  2 | seg 32 | MSE 0.384436 (+0.155424)
#   Top  3 | seg 30 | MSE 0.392435 (+0.147425)
#   Top  4 | seg 11 | MSE 0.425396 (+0.114464)
#   Top  5 | seg 60 | MSE 0.439151 (+0.100710)
#   Top  6 | seg 36 | MSE 0.440178 (+0.099682)
#   Top  7 | seg 25 | MSE 0.456513 (+0.083347)
#   Top  8 | seg 43 | MSE 0.462054 (+0.077806)
#   Top  9 | seg 45 | MSE 0.475869 (+0.063991)
#   Top 10 | seg 49 | MSE 0.499986 (+0.039874)
#   Top 11 | seg 57 | MSE 0.502790 (+0.037071)
#   Top 12 | seg 56 | MSE 0.531549 (+0.008311)
#   Top 13 | seg 13 | MSE 0.532097 (+0.007764)
#   Top 14 | seg 20 | MSE 0.543392 (-0.003532)
#   Top 15 | seg 16 | MSE 0.547151 (-0.007291)
#   Top 16 | seg 23 | MSE 0.558063 (-0.018203)
#   Top 17 | seg 19 | MSE 0.559029 (-0.019169)
#   Top 18 | seg 31 | MSE 0.572526 (-0.032666)
#   Top 19 | seg 09 | MSE 0.589727 (-0.049867)
#   Top 20 | seg 21 | MSE 0.613455 (-0.073595)
#   Top 21 | seg 28 | MSE 0.629895 (-0.090034)
#   Top 22 | seg 27 | MSE 0.635541 (-0.095681)
#   Top 23 | seg 51 | MSE 0.643629 (-0.103769)
#   Top 24 | seg 24 | MSE 0.649039 (-0.109179)
#   Top 25 | seg 04 | MSE 0.649533 (-0.109673)
#   Top 26 | seg 10 | MSE 0.663962 (-0.124102)
#   Top 27 | seg 59 | MSE 0.677058 (-0.137198)
#   Top 28 | seg 48 | MSE 0.678343 (-0.138483)
#   Top 29 | seg 07 | MSE 0.698016 (-0.158156)
#   Top 30 | seg 08 | MSE 0.698136 (-0.158276)
#   Top 31 | seg 05 | MSE 0.715835 (-0.175975)
#   Top 32 | seg 01 | MSE 0.723095 (-0.183235)
#   Top 33 | seg 55 | MSE 0.729120 (-0.189260)
#   Top 34 | seg 03 | MSE 0.735168 (-0.195308)
#   Top 35 | seg 33 | MSE 0.741258 (-0.201397)
#   Top 36 | seg 39 | MSE 0.742936 (-0.203076)
#   Top 37 | seg 35 | MSE 0.806349 (-0.266489)
#   Top 38 | seg 14 | MSE 0.831945 (-0.292085)
#   Top 39 | seg 17 | MSE 0.836638 (-0.296778)
#   Top 40 | seg 00 | MSE 0.850959 (-0.311099)
#   Top 41 | seg 29 | MSE 0.856733 (-0.316873)
#   Top 42 | seg 42 | MSE 0.872031 (-0.332171)
#   Top 43 | seg 26 | MSE 0.894021 (-0.354161)
#   Top 44 | seg 02 | MSE 0.912185 (-0.372325)
#   Top 45 | seg 50 | MSE 0.912203 (-0.372343)
#   Top 46 | seg 18 | MSE 1.082977 (-0.543117)
#   Top 47 | seg 47 | MSE 1.151300 (-0.611440)
#   Top 48 | seg 38 | MSE 1.154417 (-0.614557)
#   Top 49 | seg 34 | MSE 1.164643 (-0.624783)
#   Top 50 | seg 41 | MSE 1.248406 (-0.708546)
#   Top 51 | seg 46 | MSE 1.316014 (-0.776154)
#   Top 52 | seg 54 | MSE 1.319810 (-0.779950)
#   Top 53 | seg 40 | MSE 1.365697 (-0.825837)
#   Top 54 | seg 06 | MSE 1.438676 (-0.898815)
#   Top 55 | seg 53 | MSE 1.443058 (-0.903198)
#   Top 56 | seg 52 | MSE 1.462955 (-0.923095)
#   Top 57 | seg 58 | MSE 1.520935 (-0.981075)
#   Top 58 | seg 37 | MSE 1.667568 (-1.127708)
#   Top 59 | seg 12 | MSE 1.928209 (-1.388349)
#   Top 60 | seg 15 | MSE 2.011639 (-1.471779)
#   Top 61 | seg 22 | MSE 6.272986 (-5.733126)
#
# Saved top segment indices per channel:
# Channel 0: [44, 32, 30, 11, 60, 36, 25, 43, 45, 49, 57, 56, 13, 20, 16, 23, 19, 31, 9, 21, 28, 27, 51, 24, 4, 10, 59, 48, 7, 8, 5, 1, 55, 3, 33, 39, 35, 14, 17, 0, 29, 42, 26, 2, 50, 18, 47, 38, 34, 41, 46, 54, 40, 6, 53, 52, 58, 37, 12, 15, 22]

# %% [markdown]
# ### EPO 1 - 1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 61
SEG_CNT     = 61
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.539860
#
#   Top  1 | seg 13 | MSE 0.346016 (+0.193844)
#   Top  2 | seg 27 | MSE 0.354540 (+0.185320)
#   Top  3 | seg 20 | MSE 0.371761 (+0.168099)
#   Top  4 | seg 15 | MSE 0.417547 (+0.122313)
#   Top  5 | seg 06 | MSE 0.432468 (+0.107392)
#   Top  6 | seg 01 | MSE 0.435078 (+0.104782)
#   Top  7 | seg 38 | MSE 0.440679 (+0.099181)
#   Top  8 | seg 33 | MSE 0.462865 (+0.076995)
#   Top  9 | seg 21 | MSE 0.475669 (+0.064191)
#   Top 10 | seg 42 | MSE 0.477588 (+0.062272)
#   Top 11 | seg 47 | MSE 0.531092 (+0.008768)
#   Top 12 | seg 45 | MSE 0.534630 (+0.005230)
#   Top 13 | seg 44 | MSE 0.539060 (+0.000800)
#   Top 14 | seg 50 | MSE 0.542033 (-0.002173)
#   Top 15 | seg 08 | MSE 0.554724 (-0.014864)
#   Top 16 | seg 17 | MSE 0.555349 (-0.015489)
#   Top 17 | seg 43 | MSE 0.559241 (-0.019381)
#   Top 18 | seg 60 | MSE 0.563146 (-0.023286)
#   Top 19 | seg 53 | MSE 0.577138 (-0.037278)
#   Top 20 | seg 03 | MSE 0.589947 (-0.050087)
#   Top 21 | seg 37 | MSE 0.592608 (-0.052748)
#   Top 22 | seg 09 | MSE 0.599116 (-0.059256)
#   Top 23 | seg 28 | MSE 0.599772 (-0.059912)
#   Top 24 | seg 52 | MSE 0.605948 (-0.066088)
#   Top 25 | seg 04 | MSE 0.622829 (-0.082969)
#   Top 26 | seg 00 | MSE 0.626052 (-0.086192)
#   Top 27 | seg 57 | MSE 0.630029 (-0.090168)
#   Top 28 | seg 29 | MSE 0.647809 (-0.107949)
#   Top 29 | seg 41 | MSE 0.660732 (-0.120871)
#   Top 30 | seg 26 | MSE 0.665281 (-0.125421)
#   Top 31 | seg 40 | MSE 0.670830 (-0.130970)
#   Top 32 | seg 32 | MSE 0.678172 (-0.138312)
#   Top 33 | seg 54 | MSE 0.682570 (-0.142710)
#   Top 34 | seg 12 | MSE 0.713585 (-0.173725)
#   Top 35 | seg 56 | MSE 0.738867 (-0.199007)
#   Top 36 | seg 51 | MSE 0.747206 (-0.207346)
#   Top 37 | seg 02 | MSE 0.747349 (-0.207489)
#   Top 38 | seg 35 | MSE 0.749215 (-0.209355)
#   Top 39 | seg 07 | MSE 0.781077 (-0.241217)
#   Top 40 | seg 46 | MSE 0.841832 (-0.301972)
#   Top 41 | seg 30 | MSE 0.842086 (-0.302226)
#   Top 42 | seg 39 | MSE 0.850592 (-0.310732)
#   Top 43 | seg 58 | MSE 0.854543 (-0.314683)
#   Top 44 | seg 25 | MSE 0.938503 (-0.398643)
#   Top 45 | seg 10 | MSE 0.967493 (-0.427633)
#   Top 46 | seg 34 | MSE 0.981014 (-0.441154)
#   Top 47 | seg 18 | MSE 0.989931 (-0.450071)
#   Top 48 | seg 05 | MSE 1.040160 (-0.500300)
#   Top 49 | seg 24 | MSE 1.079894 (-0.540034)
#   Top 50 | seg 14 | MSE 1.120940 (-0.581080)
#   Top 51 | seg 19 | MSE 1.299857 (-0.759996)
#   Top 52 | seg 31 | MSE 1.314338 (-0.774478)
#   Top 53 | seg 11 | MSE 1.482394 (-0.942534)
#   Top 54 | seg 22 | MSE 1.605353 (-1.065493)
#   Top 55 | seg 59 | MSE 2.061768 (-1.521908)
#   Top 56 | seg 49 | MSE 2.064778 (-1.524918)
#   Top 57 | seg 55 | MSE 2.327655 (-1.787795)
#   Top 58 | seg 36 | MSE 2.450632 (-1.910772)
#   Top 59 | seg 23 | MSE 2.476820 (-1.936960)
#   Top 60 | seg 16 | MSE 2.584827 (-2.044967)
#   Top 61 | seg 48 | MSE 5.051735 (-4.511875)
#
# Saved top segment indices per channel:
# Channel 0: [13, 27, 20, 15, 6, 1, 38, 33, 21, 42, 47, 45, 44, 50, 8, 17, 43, 60, 53, 3, 37, 9, 28, 52, 4, 0, 57, 29, 41, 26, 40, 32, 54, 12, 56, 51, 2, 35, 7, 46, 30, 39, 58, 25, 10, 34, 18, 5, 24, 14, 19, 31, 11, 22, 59, 49, 55, 36, 23, 16, 48]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## EPO ES - 1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTm2_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.177060 | MAE : 0.322493
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.642e-01 | |ρ|=0.6073 | S=1.0000
#    K=10 | Var=2.931e-01 | |ρ|=0.5699 | S=0.8973
#    K=15 | Var=3.275e-01 | |ρ|=0.5315 | S=0.8006
#    K=20 | Var=3.579e-01 | |ρ|=0.5156 | S=0.7902
#    K=25 | Var=3.930e-01 | |ρ|=0.4973 | S=0.7786
#    K=30 | Var=4.286e-01 | |ρ|=0.4807 | S=0.7746
#    K=35 | Var=4.704e-01 | |ρ|=0.4491 | S=0.7199
#    K=40 | Var=5.131e-01 | |ρ|=0.4208 | S=0.6806 <- pick
#    K=45 | Var=5.482e-01 | |ρ|=0.4092 | S=0.6966
#    K=50 | Var=6.195e-01 | |ρ|=0.3857 | S=0.7298
#    K=55 | Var=7.040e-01 | |ρ|=0.3672 | S=0.8076
#    K=60 | Var=8.088e-01 | |ρ|=0.3736 | S=1.0268
# [Var-Corr]  K=40
#   MSE = 0.181938 | Δ = -0.004879 | Δ% = -2.76%
#   MAE = 0.327557 | Δ = -0.005064 | Δ% = -1.57%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.177060
# Ensemble mean MSE : 0.181938
# Average Δ MSE     : -0.004879
# Average Δ MSE (%) : -2.76%
#
# Vanilla  mean MAE : 0.322493
# Ensemble mean MAE : 0.327557
# Average Δ MAE     : -0.005064
# Average Δ MAE (%) : -1.57%

# %% [markdown]
# ## EPO 1 - 1E

# %%
results1_ETTm2_test['ES']['mae_test_EES']
# Out:
# 0.3224932849407196

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTm2_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.1   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.177060 | MAE : 0.322493
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.371e-01 | |ρ|=0.5346 | S=1.1000
#    K=10 | Var=3.029e-01 | |ρ|=0.5275 | S=1.1474
#    K=15 | Var=3.529e-01 | |ρ|=0.4972 | S=1.0113
#    K=20 | Var=3.964e-01 | |ρ|=0.4690 | S=0.8792
#    K=25 | Var=4.366e-01 | |ρ|=0.4484 | S=0.7957
#    K=30 | Var=4.659e-01 | |ρ|=0.4526 | S=0.8678
#    K=35 | Var=4.915e-01 | |ρ|=0.4451 | S=0.8534
#    K=40 | Var=5.295e-01 | |ρ|=0.4253 | S=0.7720
#    K=45 | Var=5.768e-01 | |ρ|=0.4075 | S=0.7182 <- pick
#    K=50 | Var=6.310e-01 | |ρ|=0.3960 | S=0.7184
#    K=55 | Var=7.380e-01 | |ρ|=0.3758 | S=0.7356
#    K=60 | Var=9.180e-01 | |ρ|=0.3765 | S=1.0047
# [Var-Corr]  K=45
#    MSE = 0.179800 | Δ = -0.002740 | Δ% = -1.55%
#    MAE = 0.327397 | Δ = -0.004904 | Δ% = -1.52%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.177060
# Ensemble mean MSE  : 0.179800
# Average Δ MSE      : -0.002740
# Average Δ MSE (%)  : -1.55%
#
# Vanilla  mean MAE  : 0.322493
# Ensemble mean MAE  : 0.327397
# Average Δ MAE      : -0.004904
# Average Δ MAE (%)  : -1.52%
