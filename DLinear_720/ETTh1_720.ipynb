# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(3)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 3
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTh1.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                       HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# date
# 2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (17420, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 01:00:00',
#                '2016-07-01 02:00:00', '2016-07-01 03:00:00',
#                '2016-07-01 04:00:00', '2016-07-01 05:00:00',
#                '2016-07-01 06:00:00', '2016-07-01 07:00:00',
#                '2016-07-01 08:00:00', '2016-07-01 09:00:00',
#                ...
#                '2018-06-26 10:00:00', '2018-06-26 11:00:00',
#                '2018-06-26 12:00:00', '2018-06-26 13:00:00',
#                '2018-06-26 14:00:00', '2018-06-26 15:00:00',
#                '2018-06-26 16:00:00', '2018-06-26 17:00:00',
#                '2018-06-26 18:00:00', '2018-06-26 19:00:00'],
#               dtype='datetime64[ns]', name='date', length=17420, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %%
set_seed(25)

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Decomposition-Linear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.individual = configs.individual
        self.channels = configs.enc_in
        self.attach_to_trend = configs.attach_to_trend
        self.attach_to_seasonal = configs.attach_to_seasonal
        

        
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        

        
        self.seq_len_trend = self.seq_len + (self.pred_len // 3) if self.attach_to_trend else self.seq_len
        self.seq_len_seasonal = self.seq_len + (self.pred_len // 3) if self.attach_to_seasonal else self.seq_len

        
        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))

                
                
                
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            
            
            
            

    def forward(self, x, ground_truth=None):
        
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if ground_truth is not None:
            kernel_size = 25
            self.decompsition = series_decomp(kernel_size)
            ground_truth_seasonal, ground_truth_trend = self.decompsition(ground_truth)

            
            if self.seq_len_seasonal > self.seq_len:
                ground_truth_seasonal=ground_truth_seasonal.permute(0, 2, 1)
                
                seasonal_init = torch.cat([seasonal_init, ground_truth_seasonal], dim=2)
            if self.seq_len_trend > self.seq_len:
                ground_truth_trend=ground_truth_trend.permute(0, 2, 1)
                
                trend_init = torch.cat([trend_init, ground_truth_trend], dim=2)
        
        
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset

target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 720


border1s = [0, 12 * 30 * 24 - seq_len, 12 * 30 * 24 + 4 * 30 * 24 - seq_len]
border2s = [12 * 30 * 24, 12 * 30 * 24 + 4 * 30 * 24, 12 * 30 * 24 + 8 * 30 * 24]

train = target[border1s[0]:border2s[0]]
val = target[border1s[1]:border2s[1]]
test = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val = scaler.transform(val)
test = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data = create_inout_sequences_univariate(val, seq_len, pred_len)
test_data = create_inout_sequences_univariate(test, seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels = torch.tensor([x[1] for x in test_data]).float().to(device)



print("Train Sequences:", train_sequences.shape)
print("Train Labels:", train_labels.shape)
print("Val Sequences:", val_sequences.shape)
print("Val Labels:", val_labels.shape)
print("Test Sequences:", test_sequences.shape)
print("Test Labels:", test_labels.shape)
# Out:
# Train Sequences: torch.Size([7585, 336, 1])
# Train Labels: torch.Size([7585, 720, 1])
# Val Sequences: torch.Size([2161, 336, 1])
# Val Labels: torch.Size([2161, 720, 1])
# Test Sequences: torch.Size([2161, 336, 1])
# Test Labels: torch.Size([2161, 720, 1])

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.01
# Epoch 0 | Train Loss: 0.37037693345997513 | Val Loss: 0.17347535458119476
# Validation loss decreased (inf --> 0.173475).  Saving model ...
# Updating learning rate to 0.005
# Epoch 1 | Train Loss: 0.23547880877466762 | Val Loss: 0.16105514742872296
# Validation loss decreased (0.173475 --> 0.161055).  Saving model ...
# Updating learning rate to 0.0025
# Epoch 2 | Train Loss: 0.22276547732723861 | Val Loss: 0.1573166351984529
# Validation loss decreased (0.161055 --> 0.157317).  Saving model ...
# Updating learning rate to 0.00125
# Epoch 3 | Train Loss: 0.2122295055569721 | Val Loss: 0.1507768254069721
# Validation loss decreased (0.157317 --> 0.150777).  Saving model ...
# Updating learning rate to 0.000625
# Epoch 4 | Train Loss: 0.20458590120327572 | Val Loss: 0.14896614498951855
# Validation loss decreased (0.150777 --> 0.148966).  Saving model ...
# Updating learning rate to 0.0003125
# Epoch 5 | Train Loss: 0.2000615510682599 | Val Loss: 0.14779940389973276
# Validation loss decreased (0.148966 --> 0.147799).  Saving model ...
# Updating learning rate to 0.00015625
# Epoch 6 | Train Loss: 0.19936248152947225 | Val Loss: 0.14766251909382203
# Validation loss decreased (0.147799 --> 0.147663).  Saving model ...
# Updating learning rate to 7.8125e-05
# Epoch 7 | Train Loss: 0.19767044653662114 | Val Loss: 0.14775471893303535
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.90625e-05
# Epoch 8 | Train Loss: 0.19690223576641885 | Val Loss: 0.147945798933506
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.953125e-05
# Epoch 9 | Train Loss: 0.19714915912066186 | Val Loss: 0.14755144846789978
# Validation loss decreased (0.147663 --> 0.147551).  Saving model ...

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.01
# Epoch 0 | Train Loss: 0.3783992580255541 | Val Loss: 0.17495854582418413
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.1866481751203537 | MAE: 0.3569643199443817
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.39879268407821655 | MAE: 0.5142671465873718

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.14722725749015808 | MAE: 0.306052029132843
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.17448563873767853 | MAE: 0.33365708589553833

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.19710345566272736 | MAE: 0.34426769614219666
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.3177146911621094 | MAE: 0.43968573212623596

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([7585, 336, 1])
# val_sequences shape:  torch.Size([2161, 336, 1])
# test_sequences shape:  torch.Size([2161, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([7585, 720, 1])
# val_pv shape:  torch.Size([2161, 720, 1])
# test_pv shape:  torch.Size([2161, 720, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([7585, 720, 1])
# val_labels shape:  torch.Size([2161, 720, 1])
# test_labels shape:  torch.Size([2161, 720, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 720

# %%
segment_len = configs.pred_len // 3
stride = 8

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([7585, 61, 240, 1]), Val: torch.Size([2161, 61, 240, 1]), Test: torch.Size([2161, 61, 240, 1])
# [Epoch 1] Train seg shape: torch.Size([7585, 61, 240, 1]), Val: torch.Size([2161, 61, 240, 1]), Test: torch.Size([2161, 61, 240, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTh1'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 0] Training Time = 1.33 sec
# [Segment 0] GPU Memory Start = 2069.60 MB
# [Segment 0] GPU Memory End   = 2081.24 MB
# [Segment 0] GPU Peak Memory  = 2084.74 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 1] Training Time = 1.52 sec
# [Segment 1] GPU Memory Start = 2081.24 MB
# [Segment 1] GPU Memory End   = 2084.41 MB
# [Segment 1] GPU Peak Memory  = 2087.91 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 2] Training Time = 0.94 sec
# [Segment 2] GPU Memory Start = 2084.41 MB
# [Segment 2] GPU Memory End   = 2080.44 MB
# [Segment 2] GPU Peak Memory  = 2087.58 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 3] Training Time = 1.32 sec
# [Segment 3] GPU Memory Start = 2080.44 MB
# [Segment 3] GPU Memory End   = 2084.41 MB
# [Segment 3] GPU Peak Memory  = 2087.91 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 4] Training Time = 0.92 sec
# [Segment 4] GPU Memory Start = 2084.41 MB
# [Segment 4] GPU Memory End   = 2087.58 MB
# [Segment 4] GPU Peak Memory  = 2091.08 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 5] Training Time = 1.33 sec
# [Segment 5] GPU Memory Start = 2087.58 MB
# [Segment 5] GPU Memory End   = 2090.75 MB
# [Segment 5] GPU Peak Memory  = 2094.25 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 6] Training Time = 1.30 sec
# [Segment 6] GPU Memory Start = 2090.75 MB
# [Segment 6] GPU Memory End   = 2093.92 MB
# [Segment 6] GPU Peak Memory  = 2097.42 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 7] Training Time = 1.41 sec
# [Segment 7] GPU Memory Start = 2093.92 MB
# [Segment 7] GPU Memory End   = 2097.09 MB
# [Segment 7] GPU Peak Memory  = 2100.59 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 8] Training Time = 1.27 sec
# [Segment 8] GPU Memory Start = 2097.09 MB
# [Segment 8] GPU Memory End   = 2099.46 MB
# [Segment 8] GPU Peak Memory  = 2103.76 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 9] Training Time = 0.57 sec
# [Segment 9] GPU Memory Start = 2099.46 MB
# [Segment 9] GPU Memory End   = 2103.43 MB
# [Segment 9] GPU Peak Memory  = 2106.93 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 10] Training Time = 1.03 sec
# [Segment 10] GPU Memory Start = 2103.43 MB
# [Segment 10] GPU Memory End   = 2106.60 MB
# [Segment 10] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 11] Training Time = 0.59 sec
# [Segment 11] GPU Memory Start = 2106.60 MB
# [Segment 11] GPU Memory End   = 2109.77 MB
# [Segment 11] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 12] Training Time = 1.24 sec
# [Segment 12] GPU Memory Start = 2080.44 MB
# [Segment 12] GPU Memory End   = 2084.41 MB
# [Segment 12] GPU Peak Memory  = 2087.91 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 13] Training Time = 0.75 sec
# [Segment 13] GPU Memory Start = 2084.41 MB
# [Segment 13] GPU Memory End   = 2087.58 MB
# [Segment 13] GPU Peak Memory  = 2091.08 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 14] Training Time = 1.32 sec
# [Segment 14] GPU Memory Start = 2087.58 MB
# [Segment 14] GPU Memory End   = 2090.75 MB
# [Segment 14] GPU Peak Memory  = 2094.25 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 15] Training Time = 1.37 sec
# [Segment 15] GPU Memory Start = 2090.75 MB
# [Segment 15] GPU Memory End   = 2093.92 MB
# [Segment 15] GPU Peak Memory  = 2097.42 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 16] Training Time = 0.85 sec
# [Segment 16] GPU Memory Start = 2093.92 MB
# [Segment 16] GPU Memory End   = 2097.09 MB
# [Segment 16] GPU Peak Memory  = 2100.59 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 17] Training Time = 1.51 sec
# [Segment 17] GPU Memory Start = 2097.09 MB
# [Segment 17] GPU Memory End   = 2100.26 MB
# [Segment 17] GPU Peak Memory  = 2103.76 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 18] Training Time = 1.27 sec
# [Segment 18] GPU Memory Start = 2100.26 MB
# [Segment 18] GPU Memory End   = 2103.43 MB
# [Segment 18] GPU Peak Memory  = 2106.93 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 19] Training Time = 1.03 sec
# [Segment 19] GPU Memory Start = 2103.43 MB
# [Segment 19] GPU Memory End   = 2106.60 MB
# [Segment 19] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 20] Training Time = 1.53 sec
# [Segment 20] GPU Memory Start = 2106.60 MB
# [Segment 20] GPU Memory End   = 2109.77 MB
# [Segment 20] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 21] Training Time = 1.39 sec
# [Segment 21] GPU Memory Start = 2109.77 MB
# [Segment 21] GPU Memory End   = 2083.61 MB
# [Segment 21] GPU Peak Memory  = 2112.94 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 22] Training Time = 1.09 sec
# [Segment 22] GPU Memory Start = 2083.61 MB
# [Segment 22] GPU Memory End   = 2086.78 MB
# [Segment 22] GPU Peak Memory  = 2090.28 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 23] Training Time = 1.51 sec
# [Segment 23] GPU Memory Start = 2086.78 MB
# [Segment 23] GPU Memory End   = 2089.95 MB
# [Segment 23] GPU Peak Memory  = 2093.45 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 24] Training Time = 1.45 sec
# [Segment 24] GPU Memory Start = 2089.95 MB
# [Segment 24] GPU Memory End   = 2093.12 MB
# [Segment 24] GPU Peak Memory  = 2096.62 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 25] Training Time = 1.24 sec
# [Segment 25] GPU Memory Start = 2093.12 MB
# [Segment 25] GPU Memory End   = 2096.29 MB
# [Segment 25] GPU Peak Memory  = 2099.79 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 26] Training Time = 1.24 sec
# [Segment 26] GPU Memory Start = 2096.29 MB
# [Segment 26] GPU Memory End   = 2099.46 MB
# [Segment 26] GPU Peak Memory  = 2102.96 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 27] Training Time = 1.13 sec
# [Segment 27] GPU Memory Start = 2099.46 MB
# [Segment 27] GPU Memory End   = 2102.63 MB
# [Segment 27] GPU Peak Memory  = 2106.12 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 28] Training Time = 1.12 sec
# [Segment 28] GPU Memory Start = 2102.63 MB
# [Segment 28] GPU Memory End   = 2105.80 MB
# [Segment 28] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 29] Training Time = 1.43 sec
# [Segment 29] GPU Memory Start = 2105.80 MB
# [Segment 29] GPU Memory End   = 2109.77 MB
# [Segment 29] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 30] Training Time = 1.31 sec
# [Segment 30] GPU Memory Start = 2109.77 MB
# [Segment 30] GPU Memory End   = 2112.94 MB
# [Segment 30] GPU Peak Memory  = 2116.44 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 31] Training Time = 1.36 sec
# [Segment 31] GPU Memory Start = 2083.61 MB
# [Segment 31] GPU Memory End   = 2086.78 MB
# [Segment 31] GPU Peak Memory  = 2090.28 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 32] Training Time = 0.95 sec
# [Segment 32] GPU Memory Start = 2086.78 MB
# [Segment 32] GPU Memory End   = 2089.95 MB
# [Segment 32] GPU Peak Memory  = 2093.45 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 33] Training Time = 0.78 sec
# [Segment 33] GPU Memory Start = 2089.95 MB
# [Segment 33] GPU Memory End   = 2093.12 MB
# [Segment 33] GPU Peak Memory  = 2096.62 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 34] Training Time = 0.49 sec
# [Segment 34] GPU Memory Start = 2093.12 MB
# [Segment 34] GPU Memory End   = 2096.29 MB
# [Segment 34] GPU Peak Memory  = 2099.79 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 35] Training Time = 0.61 sec
# [Segment 35] GPU Memory Start = 2096.29 MB
# [Segment 35] GPU Memory End   = 2099.46 MB
# [Segment 35] GPU Peak Memory  = 2102.96 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 36] Training Time = 0.91 sec
# [Segment 36] GPU Memory Start = 2099.46 MB
# [Segment 36] GPU Memory End   = 2103.43 MB
# [Segment 36] GPU Peak Memory  = 2106.93 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 37] Training Time = 0.84 sec
# [Segment 37] GPU Memory Start = 2103.43 MB
# [Segment 37] GPU Memory End   = 2106.60 MB
# [Segment 37] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 38] Training Time = 0.78 sec
# [Segment 38] GPU Memory Start = 2106.60 MB
# [Segment 38] GPU Memory End   = 2109.77 MB
# [Segment 38] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 39] Training Time = 0.84 sec
# [Segment 39] GPU Memory Start = 2109.77 MB
# [Segment 39] GPU Memory End   = 2112.94 MB
# [Segment 39] GPU Peak Memory  = 2116.44 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 40] Training Time = 0.86 sec
# [Segment 40] GPU Memory Start = 2112.94 MB
# [Segment 40] GPU Memory End   = 2086.78 MB
# [Segment 40] GPU Peak Memory  = 2116.11 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 41] Training Time = 1.18 sec
# [Segment 41] GPU Memory Start = 2086.78 MB
# [Segment 41] GPU Memory End   = 2089.95 MB
# [Segment 41] GPU Peak Memory  = 2093.45 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 42] Training Time = 1.35 sec
# [Segment 42] GPU Memory Start = 2089.95 MB
# [Segment 42] GPU Memory End   = 2093.12 MB
# [Segment 42] GPU Peak Memory  = 2096.62 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 43] Training Time = 0.72 sec
# [Segment 43] GPU Memory Start = 2093.12 MB
# [Segment 43] GPU Memory End   = 2096.29 MB
# [Segment 43] GPU Peak Memory  = 2099.79 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 44] Training Time = 0.78 sec
# [Segment 44] GPU Memory Start = 2096.29 MB
# [Segment 44] GPU Memory End   = 2099.46 MB
# [Segment 44] GPU Peak Memory  = 2102.96 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 45] Training Time = 0.49 sec
# [Segment 45] GPU Memory Start = 2099.46 MB
# [Segment 45] GPU Memory End   = 2102.63 MB
# [Segment 45] GPU Peak Memory  = 2106.12 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 46] Training Time = 0.94 sec
# [Segment 46] GPU Memory Start = 2102.63 MB
# [Segment 46] GPU Memory End   = 2105.80 MB
# [Segment 46] GPU Peak Memory  = 2109.29 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 47] Training Time = 0.92 sec
# [Segment 47] GPU Memory Start = 2105.80 MB
# [Segment 47] GPU Memory End   = 2108.97 MB
# [Segment 47] GPU Peak Memory  = 2112.46 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 48] Training Time = 0.76 sec
# [Segment 48] GPU Memory Start = 2108.97 MB
# [Segment 48] GPU Memory End   = 2112.14 MB
# [Segment 48] GPU Peak Memory  = 2115.63 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 49] Training Time = 0.81 sec
# [Segment 49] GPU Memory Start = 2112.14 MB
# [Segment 49] GPU Memory End   = 2115.31 MB
# [Segment 49] GPU Peak Memory  = 2118.80 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 50] Training Time = 0.85 sec
# [Segment 50] GPU Memory Start = 2086.78 MB
# [Segment 50] GPU Memory End   = 2089.95 MB
# [Segment 50] GPU Peak Memory  = 2093.45 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 51] Training Time = 1.38 sec
# [Segment 51] GPU Memory Start = 2089.95 MB
# [Segment 51] GPU Memory End   = 2093.92 MB
# [Segment 51] GPU Peak Memory  = 2097.42 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 52] Training Time = 1.57 sec
# [Segment 52] GPU Memory Start = 2093.92 MB
# [Segment 52] GPU Memory End   = 2097.09 MB
# [Segment 52] GPU Peak Memory  = 2100.59 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 53] Training Time = 1.34 sec
# [Segment 53] GPU Memory Start = 2097.09 MB
# [Segment 53] GPU Memory End   = 2099.46 MB
# [Segment 53] GPU Peak Memory  = 2103.76 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 54] Training Time = 1.54 sec
# [Segment 54] GPU Memory Start = 2099.46 MB
# [Segment 54] GPU Memory End   = 2103.43 MB
# [Segment 54] GPU Peak Memory  = 2106.93 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 55] Training Time = 1.57 sec
# [Segment 55] GPU Memory Start = 2103.43 MB
# [Segment 55] GPU Memory End   = 2106.60 MB
# [Segment 55] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 56] Training Time = 1.48 sec
# [Segment 56] GPU Memory Start = 2106.60 MB
# [Segment 56] GPU Memory End   = 2109.77 MB
# [Segment 56] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 57] Training Time = 1.31 sec
# [Segment 57] GPU Memory Start = 2109.77 MB
# [Segment 57] GPU Memory End   = 2112.94 MB
# [Segment 57] GPU Peak Memory  = 2116.44 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 58] Training Time = 1.41 sec
# [Segment 58] GPU Memory Start = 2112.94 MB
# [Segment 58] GPU Memory End   = 2116.11 MB
# [Segment 58] GPU Peak Memory  = 2119.61 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 59] Training Time = 0.99 sec
# [Segment 59] GPU Memory Start = 2116.11 MB
# [Segment 59] GPU Memory End   = 2089.95 MB
# [Segment 59] GPU Peak Memory  = 2119.28 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 60] Training Time = 1.23 sec
# [Segment 60] GPU Memory Start = 2089.95 MB
# [Segment 60] GPU Memory End   = 2093.92 MB
# [Segment 60] GPU Peak Memory  = 2097.42 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E/",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 0] Training Time = 0.91 sec
# [Segment 0] GPU Memory Start = 2090.75 MB
# [Segment 0] GPU Memory End   = 2089.95 MB
# [Segment 0] GPU Peak Memory  = 2095.54 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 1] Training Time = 1.10 sec
# [Segment 1] GPU Memory Start = 2089.95 MB
# [Segment 1] GPU Memory End   = 2093.92 MB
# [Segment 1] GPU Peak Memory  = 2097.42 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 2] Training Time = 0.71 sec
# [Segment 2] GPU Memory Start = 2093.92 MB
# [Segment 2] GPU Memory End   = 2097.09 MB
# [Segment 2] GPU Peak Memory  = 2100.59 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 3] Training Time = 0.67 sec
# [Segment 3] GPU Memory Start = 2097.09 MB
# [Segment 3] GPU Memory End   = 2100.26 MB
# [Segment 3] GPU Peak Memory  = 2103.76 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 4] Training Time = 0.60 sec
# [Segment 4] GPU Memory Start = 2100.26 MB
# [Segment 4] GPU Memory End   = 2089.95 MB
# [Segment 4] GPU Peak Memory  = 2103.43 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 5] Training Time = 0.75 sec
# [Segment 5] GPU Memory Start = 2089.95 MB
# [Segment 5] GPU Memory End   = 2093.12 MB
# [Segment 5] GPU Peak Memory  = 2097.42 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 6] Training Time = 0.84 sec
# [Segment 6] GPU Memory Start = 2093.12 MB
# [Segment 6] GPU Memory End   = 2097.09 MB
# [Segment 6] GPU Peak Memory  = 2100.59 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 7] Training Time = 0.78 sec
# [Segment 7] GPU Memory Start = 2097.09 MB
# [Segment 7] GPU Memory End   = 2100.26 MB
# [Segment 7] GPU Peak Memory  = 2103.76 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 8] Training Time = 0.83 sec
# [Segment 8] GPU Memory Start = 2100.26 MB
# [Segment 8] GPU Memory End   = 2103.43 MB
# [Segment 8] GPU Peak Memory  = 2106.93 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 9] Training Time = 1.09 sec
# [Segment 9] GPU Memory Start = 2103.43 MB
# [Segment 9] GPU Memory End   = 2106.60 MB
# [Segment 9] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 10] Training Time = 1.48 sec
# [Segment 10] GPU Memory Start = 2106.60 MB
# [Segment 10] GPU Memory End   = 2109.77 MB
# [Segment 10] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 11] Training Time = 1.29 sec
# [Segment 11] GPU Memory Start = 2109.77 MB
# [Segment 11] GPU Memory End   = 2112.94 MB
# [Segment 11] GPU Peak Memory  = 2116.44 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 12] Training Time = 1.23 sec
# [Segment 12] GPU Memory Start = 2112.94 MB
# [Segment 12] GPU Memory End   = 2116.11 MB
# [Segment 12] GPU Peak Memory  = 2119.61 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 13] Training Time = 0.92 sec
# [Segment 13] GPU Memory Start = 2116.11 MB
# [Segment 13] GPU Memory End   = 2119.28 MB
# [Segment 13] GPU Peak Memory  = 2122.78 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 14] Training Time = 0.81 sec
# [Segment 14] GPU Memory Start = 2089.95 MB
# [Segment 14] GPU Memory End   = 2093.12 MB
# [Segment 14] GPU Peak Memory  = 2096.62 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 15] Training Time = 1.06 sec
# [Segment 15] GPU Memory Start = 2093.12 MB
# [Segment 15] GPU Memory End   = 2097.09 MB
# [Segment 15] GPU Peak Memory  = 2100.59 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 16] Training Time = 0.60 sec
# [Segment 16] GPU Memory Start = 2097.09 MB
# [Segment 16] GPU Memory End   = 2100.26 MB
# [Segment 16] GPU Peak Memory  = 2103.76 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 17] Training Time = 0.74 sec
# [Segment 17] GPU Memory Start = 2100.26 MB
# [Segment 17] GPU Memory End   = 2102.63 MB
# [Segment 17] GPU Peak Memory  = 2106.93 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 18] Training Time = 0.83 sec
# [Segment 18] GPU Memory Start = 2102.63 MB
# [Segment 18] GPU Memory End   = 2106.60 MB
# [Segment 18] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 19] Training Time = 0.76 sec
# [Segment 19] GPU Memory Start = 2106.60 MB
# [Segment 19] GPU Memory End   = 2109.77 MB
# [Segment 19] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 20] Training Time = 0.96 sec
# [Segment 20] GPU Memory Start = 2109.77 MB
# [Segment 20] GPU Memory End   = 2112.94 MB
# [Segment 20] GPU Peak Memory  = 2116.44 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 21] Training Time = 0.69 sec
# [Segment 21] GPU Memory Start = 2112.94 MB
# [Segment 21] GPU Memory End   = 2116.11 MB
# [Segment 21] GPU Peak Memory  = 2119.61 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 22] Training Time = 1.26 sec
# [Segment 22] GPU Memory Start = 2116.11 MB
# [Segment 22] GPU Memory End   = 2119.28 MB
# [Segment 22] GPU Peak Memory  = 2122.78 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 23] Training Time = 1.45 sec
# [Segment 23] GPU Memory Start = 2119.28 MB
# [Segment 23] GPU Memory End   = 2080.44 MB
# [Segment 23] GPU Peak Memory  = 2122.45 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 24] Training Time = 1.28 sec
# [Segment 24] GPU Memory Start = 2080.44 MB
# [Segment 24] GPU Memory End   = 2084.41 MB
# [Segment 24] GPU Peak Memory  = 2087.91 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 25] Training Time = 1.37 sec
# [Segment 25] GPU Memory Start = 2084.41 MB
# [Segment 25] GPU Memory End   = 2087.58 MB
# [Segment 25] GPU Peak Memory  = 2091.08 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 26] Training Time = 1.41 sec
# [Segment 26] GPU Memory Start = 2087.58 MB
# [Segment 26] GPU Memory End   = 2090.75 MB
# [Segment 26] GPU Peak Memory  = 2094.25 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 27] Training Time = 0.71 sec
# [Segment 27] GPU Memory Start = 2090.75 MB
# [Segment 27] GPU Memory End   = 2093.92 MB
# [Segment 27] GPU Peak Memory  = 2097.42 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 28] Training Time = 0.71 sec
# [Segment 28] GPU Memory Start = 2093.92 MB
# [Segment 28] GPU Memory End   = 2097.09 MB
# [Segment 28] GPU Peak Memory  = 2100.59 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 29] Training Time = 1.18 sec
# [Segment 29] GPU Memory Start = 2097.09 MB
# [Segment 29] GPU Memory End   = 2100.26 MB
# [Segment 29] GPU Peak Memory  = 2103.76 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 30] Training Time = 1.01 sec
# [Segment 30] GPU Memory Start = 2100.26 MB
# [Segment 30] GPU Memory End   = 2103.43 MB
# [Segment 30] GPU Peak Memory  = 2106.93 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 31] Training Time = 0.95 sec
# [Segment 31] GPU Memory Start = 2103.43 MB
# [Segment 31] GPU Memory End   = 2106.60 MB
# [Segment 31] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 32] Training Time = 1.13 sec
# [Segment 32] GPU Memory Start = 2106.60 MB
# [Segment 32] GPU Memory End   = 2109.77 MB
# [Segment 32] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 33] Training Time = 1.33 sec
# [Segment 33] GPU Memory Start = 2080.44 MB
# [Segment 33] GPU Memory End   = 2083.61 MB
# [Segment 33] GPU Peak Memory  = 2087.91 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 34] Training Time = 0.53 sec
# [Segment 34] GPU Memory Start = 2083.61 MB
# [Segment 34] GPU Memory End   = 2087.58 MB
# [Segment 34] GPU Peak Memory  = 2091.08 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 35] Training Time = 1.21 sec
# [Segment 35] GPU Memory Start = 2087.58 MB
# [Segment 35] GPU Memory End   = 2090.75 MB
# [Segment 35] GPU Peak Memory  = 2094.25 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 36] Training Time = 0.55 sec
# [Segment 36] GPU Memory Start = 2090.75 MB
# [Segment 36] GPU Memory End   = 2093.92 MB
# [Segment 36] GPU Peak Memory  = 2097.42 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 37] Training Time = 0.53 sec
# [Segment 37] GPU Memory Start = 2093.92 MB
# [Segment 37] GPU Memory End   = 2097.09 MB
# [Segment 37] GPU Peak Memory  = 2100.59 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 38] Training Time = 0.58 sec
# [Segment 38] GPU Memory Start = 2097.09 MB
# [Segment 38] GPU Memory End   = 2100.26 MB
# [Segment 38] GPU Peak Memory  = 2103.76 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 39] Training Time = 0.64 sec
# [Segment 39] GPU Memory Start = 2100.26 MB
# [Segment 39] GPU Memory End   = 2103.43 MB
# [Segment 39] GPU Peak Memory  = 2106.93 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 40] Training Time = 0.54 sec
# [Segment 40] GPU Memory Start = 2103.43 MB
# [Segment 40] GPU Memory End   = 2106.60 MB
# [Segment 40] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 41] Training Time = 1.26 sec
# [Segment 41] GPU Memory Start = 2106.60 MB
# [Segment 41] GPU Memory End   = 2109.77 MB
# [Segment 41] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 42] Training Time = 0.57 sec
# [Segment 42] GPU Memory Start = 2109.77 MB
# [Segment 42] GPU Memory End   = 2083.61 MB
# [Segment 42] GPU Peak Memory  = 2112.94 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 43] Training Time = 0.54 sec
# [Segment 43] GPU Memory Start = 2083.61 MB
# [Segment 43] GPU Memory End   = 2086.78 MB
# [Segment 43] GPU Peak Memory  = 2090.28 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 44] Training Time = 1.21 sec
# [Segment 44] GPU Memory Start = 2086.78 MB
# [Segment 44] GPU Memory End   = 2089.95 MB
# [Segment 44] GPU Peak Memory  = 2093.45 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 45] Training Time = 0.54 sec
# [Segment 45] GPU Memory Start = 2089.95 MB
# [Segment 45] GPU Memory End   = 2093.12 MB
# [Segment 45] GPU Peak Memory  = 2096.62 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 46] Training Time = 1.34 sec
# [Segment 46] GPU Memory Start = 2093.12 MB
# [Segment 46] GPU Memory End   = 2096.29 MB
# [Segment 46] GPU Peak Memory  = 2099.79 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 47] Training Time = 0.61 sec
# [Segment 47] GPU Memory Start = 2096.29 MB
# [Segment 47] GPU Memory End   = 2099.46 MB
# [Segment 47] GPU Peak Memory  = 2102.96 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 48] Training Time = 0.54 sec
# [Segment 48] GPU Memory Start = 2099.46 MB
# [Segment 48] GPU Memory End   = 2102.63 MB
# [Segment 48] GPU Peak Memory  = 2106.12 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 49] Training Time = 0.54 sec
# [Segment 49] GPU Memory Start = 2102.63 MB
# [Segment 49] GPU Memory End   = 2105.80 MB
# [Segment 49] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 50] Training Time = 0.54 sec
# [Segment 50] GPU Memory Start = 2105.80 MB
# [Segment 50] GPU Memory End   = 2109.77 MB
# [Segment 50] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 51] Training Time = 0.54 sec
# [Segment 51] GPU Memory Start = 2109.77 MB
# [Segment 51] GPU Memory End   = 2112.94 MB
# [Segment 51] GPU Peak Memory  = 2116.44 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 52] Training Time = 0.54 sec
# [Segment 52] GPU Memory Start = 2083.61 MB
# [Segment 52] GPU Memory End   = 2086.78 MB
# [Segment 52] GPU Peak Memory  = 2090.28 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 53] Training Time = 1.27 sec
# [Segment 53] GPU Memory Start = 2086.78 MB
# [Segment 53] GPU Memory End   = 2089.95 MB
# [Segment 53] GPU Peak Memory  = 2093.45 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 54] Training Time = 1.25 sec
# [Segment 54] GPU Memory Start = 2089.95 MB
# [Segment 54] GPU Memory End   = 2093.12 MB
# [Segment 54] GPU Peak Memory  = 2096.62 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 55] Training Time = 0.54 sec
# [Segment 55] GPU Memory Start = 2093.12 MB
# [Segment 55] GPU Memory End   = 2096.29 MB
# [Segment 55] GPU Peak Memory  = 2099.79 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 56] Training Time = 0.54 sec
# [Segment 56] GPU Memory Start = 2096.29 MB
# [Segment 56] GPU Memory End   = 2100.26 MB
# [Segment 56] GPU Peak Memory  = 2103.76 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 57] Training Time = 0.67 sec
# [Segment 57] GPU Memory Start = 2100.26 MB
# [Segment 57] GPU Memory End   = 2103.43 MB
# [Segment 57] GPU Peak Memory  = 2106.93 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 58] Training Time = 0.57 sec
# [Segment 58] GPU Memory Start = 2103.43 MB
# [Segment 58] GPU Memory End   = 2106.60 MB
# [Segment 58] GPU Peak Memory  = 2110.10 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 59] Training Time = 0.54 sec
# [Segment 59] GPU Memory Start = 2106.60 MB
# [Segment 59] GPU Memory End   = 2109.77 MB
# [Segment 59] GPU Peak Memory  = 2113.27 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 9.7617 MB
#   yb per batch = 0.0879 MB, total = 20.9180 MB
#   pv per batch = 0.0293 MB, total = 6.9727 MB
# [Segment 60] Training Time = 1.14 sec
# [Segment 60] GPU Memory Start = 2109.77 MB
# [Segment 60] GPU Memory End   = 2112.94 MB
# [Segment 60] GPU Peak Memory  = 2116.44 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTh1_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.17735622823238373  MAE:0.33574244379997253
# ▶ seg0  mean  MSE:0.17735622823238373  MAE:0.33574244379997253
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.17701883614063263  MAE:0.3352760970592499
# ▶ seg1  mean  MSE:0.17701883614063263  MAE:0.3352760970592499
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.18474765121936798  MAE:0.3409755825996399
# ▶ seg2  mean  MSE:0.18474765121936798  MAE:0.3409755825996399
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.16211320459842682  MAE:0.321548193693161
# ▶ seg3  mean  MSE:0.16211320459842682  MAE:0.321548193693161
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.1910255253314972  MAE:0.3464618921279907
# ▶ seg4  mean  MSE:0.1910255253314972  MAE:0.3464618921279907
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.2909650206565857  MAE:0.4194073975086212
# ▶ seg5  mean  MSE:0.2909650206565857  MAE:0.4194073975086212
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.1756107658147812  MAE:0.3343595862388611
# ▶ seg6  mean  MSE:0.1756107658147812  MAE:0.3343595862388611
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.16656669974327087  MAE:0.3273201584815979
# ▶ seg7  mean  MSE:0.16656669974327087  MAE:0.3273201584815979
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.2426702082157135  MAE:0.3883219063282013
# ▶ seg8  mean  MSE:0.2426702082157135  MAE:0.3883219063282013
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.16625159978866577  MAE:0.3260866403579712
# ▶ seg9  mean  MSE:0.16625159978866577  MAE:0.3260866403579712
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.16560997068881989  MAE:0.32433536648750305
# ▶ seg10  mean  MSE:0.16560997068881989  MAE:0.32433536648750305
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.19296495616436005  MAE:0.34855613112449646
# ▶ seg11  mean  MSE:0.19296495616436005  MAE:0.34855613112449646
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.17339889705181122  MAE:0.3312404453754425
# ▶ seg12  mean  MSE:0.17339889705181122  MAE:0.3312404453754425
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.17689909040927887  MAE:0.335945725440979
# ▶ seg13  mean  MSE:0.17689909040927887  MAE:0.335945725440979
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.18559889495372772  MAE:0.341920405626297
# ▶ seg14  mean  MSE:0.18559889495372772  MAE:0.341920405626297
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.17574970424175262  MAE:0.3348059356212616
# ▶ seg15  mean  MSE:0.17574970424175262  MAE:0.3348059356212616
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.17764858901500702  MAE:0.33514076471328735
# ▶ seg16  mean  MSE:0.17764858901500702  MAE:0.33514076471328735
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.1778731793165207  MAE:0.33657804131507874
# ▶ seg17  mean  MSE:0.1778731793165207  MAE:0.33657804131507874
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.16252553462982178  MAE:0.3232623338699341
# ▶ seg18  mean  MSE:0.16252553462982178  MAE:0.3232623338699341
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.18031394481658936  MAE:0.33829396963119507
# ▶ seg19  mean  MSE:0.18031394481658936  MAE:0.33829396963119507
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.17017436027526855  MAE:0.3282868564128876
# ▶ seg20  mean  MSE:0.17017436027526855  MAE:0.3282868564128876
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.17447762191295624  MAE:0.3319122791290283
# ▶ seg21  mean  MSE:0.17447762191295624  MAE:0.3319122791290283
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.16949234902858734  MAE:0.3286031186580658
# ▶ seg22  mean  MSE:0.16949234902858734  MAE:0.3286031186580658
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.1798161417245865  MAE:0.337569922208786
# ▶ seg23  mean  MSE:0.1798161417245865  MAE:0.337569922208786
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.19071418046951294  MAE:0.34667205810546875
# ▶ seg24  mean  MSE:0.19071418046951294  MAE:0.34667205810546875
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.16863256692886353  MAE:0.32718220353126526
# ▶ seg25  mean  MSE:0.16863256692886353  MAE:0.32718220353126526
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.17486558854579926  MAE:0.3325531780719757
# ▶ seg26  mean  MSE:0.17486558854579926  MAE:0.3325531780719757
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.16996847093105316  MAE:0.32762610912323
# ▶ seg27  mean  MSE:0.16996847093105316  MAE:0.32762610912323
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.17640914022922516  MAE:0.33647608757019043
# ▶ seg28  mean  MSE:0.17640914022922516  MAE:0.33647608757019043
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.17902906239032745  MAE:0.3385598361492157
# ▶ seg29  mean  MSE:0.17902906239032745  MAE:0.3385598361492157
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.17659738659858704  MAE:0.33766114711761475
# ▶ seg30  mean  MSE:0.17659738659858704  MAE:0.33766114711761475
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.16160157322883606  MAE:0.32122692465782166
# ▶ seg31  mean  MSE:0.16160157322883606  MAE:0.32122692465782166
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.19894179701805115  MAE:0.3539634943008423
# ▶ seg32  mean  MSE:0.19894179701805115  MAE:0.3539634943008423
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.17053042352199554  MAE:0.32883626222610474
# ▶ seg33  mean  MSE:0.17053042352199554  MAE:0.32883626222610474
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.17352719604969025  MAE:0.3312063217163086
# ▶ seg34  mean  MSE:0.17352719604969025  MAE:0.3312063217163086
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.16963541507720947  MAE:0.3283635377883911
# ▶ seg35  mean  MSE:0.16963541507720947  MAE:0.3283635377883911
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.2556041479110718  MAE:0.4044114649295807
# ▶ seg36  mean  MSE:0.2556041479110718  MAE:0.4044114649295807
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.1690385788679123  MAE:0.32982832193374634
# ▶ seg37  mean  MSE:0.1690385788679123  MAE:0.32982832193374634
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.19681264460086823  MAE:0.3515772819519043
# ▶ seg38  mean  MSE:0.19681264460086823  MAE:0.3515772819519043
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.16342034935951233  MAE:0.3236950933933258
# ▶ seg39  mean  MSE:0.16342034935951233  MAE:0.3236950933933258
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.1808653473854065  MAE:0.3373475670814514
# ▶ seg40  mean  MSE:0.1808653473854065  MAE:0.3373475670814514
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.17049962282180786  MAE:0.32842546701431274
# ▶ seg41  mean  MSE:0.17049962282180786  MAE:0.32842546701431274
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.17080864310264587  MAE:0.3318316638469696
# ▶ seg42  mean  MSE:0.17080864310264587  MAE:0.3318316638469696
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.1854727417230606  MAE:0.34376755356788635
# ▶ seg43  mean  MSE:0.1854727417230606  MAE:0.34376755356788635
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.2973616123199463  MAE:0.4256073832511902
# ▶ seg44  mean  MSE:0.2973616123199463  MAE:0.4256073832511902
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.16233091056346893  MAE:0.32306212186813354
# ▶ seg45  mean  MSE:0.16233091056346893  MAE:0.32306212186813354
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.1641879826784134  MAE:0.3242378234863281
# ▶ seg46  mean  MSE:0.1641879826784134  MAE:0.3242378234863281
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.16829034686088562  MAE:0.3287718594074249
# ▶ seg47  mean  MSE:0.16829034686088562  MAE:0.3287718594074249
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.16732850670814514  MAE:0.32712018489837646
# ▶ seg48  mean  MSE:0.16732850670814514  MAE:0.32712018489837646
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.18491323292255402  MAE:0.3410429060459137
# ▶ seg49  mean  MSE:0.18491323292255402  MAE:0.3410429060459137
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.1668630689382553  MAE:0.3269333839416504
# ▶ seg50  mean  MSE:0.1668630689382553  MAE:0.3269333839416504
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.19992323219776154  MAE:0.3552941381931305
# ▶ seg51  mean  MSE:0.19992323219776154  MAE:0.3552941381931305
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.16276732087135315  MAE:0.3212184011936188
# ▶ seg52  mean  MSE:0.16276732087135315  MAE:0.3212184011936188
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.16466791927814484  MAE:0.32580891251564026
# ▶ seg53  mean  MSE:0.16466791927814484  MAE:0.32580891251564026
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.17658677697181702  MAE:0.3351075351238251
# ▶ seg54  mean  MSE:0.17658677697181702  MAE:0.3351075351238251
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.1708614081144333  MAE:0.33041754364967346
# ▶ seg55  mean  MSE:0.1708614081144333  MAE:0.33041754364967346
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.17439500987529755  MAE:0.3321537375450134
# ▶ seg56  mean  MSE:0.17439500987529755  MAE:0.3321537375450134
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.16174852848052979  MAE:0.32128870487213135
# ▶ seg57  mean  MSE:0.16174852848052979  MAE:0.32128870487213135
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.19335976243019104  MAE:0.348976194858551
# ▶ seg58  mean  MSE:0.19335976243019104  MAE:0.348976194858551
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.18431922793388367  MAE:0.34159472584724426
# ▶ seg59  mean  MSE:0.18431922793388367  MAE:0.34159472584724426
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.17692285776138306  MAE:0.33675506711006165
# ▶ seg60  mean  MSE:0.17692285776138306  MAE:0.33675506711006165
#
# seg10 ch0 MSE : 0.16560997

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTh1_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.17225120961666107  MAE:0.33059316873550415
# ▶ seg0  mean  MSE:0.17225120961666107  MAE:0.33059316873550415
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.17362557351589203  MAE:0.3335557281970978
# ▶ seg1  mean  MSE:0.17362557351589203  MAE:0.3335557281970978
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.16759444773197174  MAE:0.32827576994895935
# ▶ seg2  mean  MSE:0.16759444773197174  MAE:0.32827576994895935
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.18152733147144318  MAE:0.33878397941589355
# ▶ seg3  mean  MSE:0.18152733147144318  MAE:0.33878397941589355
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.1787632703781128  MAE:0.337838739156723
# ▶ seg4  mean  MSE:0.1787632703781128  MAE:0.337838739156723
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.16583581268787384  MAE:0.3250774145126343
# ▶ seg5  mean  MSE:0.16583581268787384  MAE:0.3250774145126343
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.17560040950775146  MAE:0.3336039185523987
# ▶ seg6  mean  MSE:0.17560040950775146  MAE:0.3336039185523987
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.1640847772359848  MAE:0.32519790530204773
# ▶ seg7  mean  MSE:0.1640847772359848  MAE:0.32519790530204773
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.19048991799354553  MAE:0.3478466868400574
# ▶ seg8  mean  MSE:0.19048991799354553  MAE:0.3478466868400574
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.1699734479188919  MAE:0.3270002603530884
# ▶ seg9  mean  MSE:0.1699734479188919  MAE:0.3270002603530884
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.17212975025177002  MAE:0.33059611916542053
# ▶ seg10  mean  MSE:0.17212975025177002  MAE:0.33059611916542053
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.1705167144536972  MAE:0.32998815178871155
# ▶ seg11  mean  MSE:0.1705167144536972  MAE:0.32998815178871155
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.16770735383033752  MAE:0.32654643058776855
# ▶ seg12  mean  MSE:0.16770735383033752  MAE:0.32654643058776855
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.16499893367290497  MAE:0.3247506618499756
# ▶ seg13  mean  MSE:0.16499893367290497  MAE:0.3247506618499756
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.16427236795425415  MAE:0.32291993498802185
# ▶ seg14  mean  MSE:0.16427236795425415  MAE:0.32291993498802185
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.17201144993305206  MAE:0.33114153146743774
# ▶ seg15  mean  MSE:0.17201144993305206  MAE:0.33114153146743774
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.16569723188877106  MAE:0.3260767459869385
# ▶ seg16  mean  MSE:0.16569723188877106  MAE:0.3260767459869385
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.170965775847435  MAE:0.3300337791442871
# ▶ seg17  mean  MSE:0.170965775847435  MAE:0.3300337791442871
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.21156524121761322  MAE:0.3642602264881134
# ▶ seg18  mean  MSE:0.21156524121761322  MAE:0.3642602264881134
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.165538489818573  MAE:0.3250499367713928
# ▶ seg19  mean  MSE:0.165538489818573  MAE:0.3250499367713928
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.1644432097673416  MAE:0.32389089465141296
# ▶ seg20  mean  MSE:0.1644432097673416  MAE:0.32389089465141296
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.17440402507781982  MAE:0.33200696110725403
# ▶ seg21  mean  MSE:0.17440402507781982  MAE:0.33200696110725403
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.18238770961761475  MAE:0.3395495116710663
# ▶ seg22  mean  MSE:0.18238770961761475  MAE:0.3395495116710663
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.16735926270484924  MAE:0.3255070447921753
# ▶ seg23  mean  MSE:0.16735926270484924  MAE:0.3255070447921753
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.17122961580753326  MAE:0.3316076397895813
# ▶ seg24  mean  MSE:0.17122961580753326  MAE:0.3316076397895813
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.22320719063282013  MAE:0.3745265305042267
# ▶ seg25  mean  MSE:0.22320719063282013  MAE:0.3745265305042267
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.1728191375732422  MAE:0.3300975561141968
# ▶ seg26  mean  MSE:0.1728191375732422  MAE:0.3300975561141968
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.1633886694908142  MAE:0.32249152660369873
# ▶ seg27  mean  MSE:0.1633886694908142  MAE:0.32249152660369873
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.1670031100511551  MAE:0.3263031244277954
# ▶ seg28  mean  MSE:0.1670031100511551  MAE:0.3263031244277954
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.16982389986515045  MAE:0.32813507318496704
# ▶ seg29  mean  MSE:0.16982389986515045  MAE:0.32813507318496704
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.16468003392219543  MAE:0.32462191581726074
# ▶ seg30  mean  MSE:0.16468003392219543  MAE:0.32462191581726074
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.16236186027526855  MAE:0.3230088949203491
# ▶ seg31  mean  MSE:0.16236186027526855  MAE:0.3230088949203491
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.1904487907886505  MAE:0.3443547189235687
# ▶ seg32  mean  MSE:0.1904487907886505  MAE:0.3443547189235687
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.17281422019004822  MAE:0.3331755995750427
# ▶ seg33  mean  MSE:0.17281422019004822  MAE:0.3331755995750427
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.17001044750213623  MAE:0.32898789644241333
# ▶ seg34  mean  MSE:0.17001044750213623  MAE:0.32898789644241333
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.16624578833580017  MAE:0.3275338113307953
# ▶ seg35  mean  MSE:0.16624578833580017  MAE:0.3275338113307953
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.18708591163158417  MAE:0.3442128598690033
# ▶ seg36  mean  MSE:0.18708591163158417  MAE:0.3442128598690033
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.2763439416885376  MAE:0.41353070735931396
# ▶ seg37  mean  MSE:0.2763439416885376  MAE:0.41353070735931396
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.1770852953195572  MAE:0.3356076180934906
# ▶ seg38  mean  MSE:0.1770852953195572  MAE:0.3356076180934906
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.16417168080806732  MAE:0.3233795166015625
# ▶ seg39  mean  MSE:0.16417168080806732  MAE:0.3233795166015625
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.233059361577034  MAE:0.38324812054634094
# ▶ seg40  mean  MSE:0.233059361577034  MAE:0.38324812054634094
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.16344685852527618  MAE:0.32256144285202026
# ▶ seg41  mean  MSE:0.16344685852527618  MAE:0.32256144285202026
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.19001051783561707  MAE:0.34520620107650757
# ▶ seg42  mean  MSE:0.19001051783561707  MAE:0.34520620107650757
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.18576829135417938  MAE:0.3434981405735016
# ▶ seg43  mean  MSE:0.18576829135417938  MAE:0.3434981405735016
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.17227795720100403  MAE:0.32986342906951904
# ▶ seg44  mean  MSE:0.17227795720100403  MAE:0.32986342906951904
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.1681663542985916  MAE:0.32970723509788513
# ▶ seg45  mean  MSE:0.1681663542985916  MAE:0.32970723509788513
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.17380085587501526  MAE:0.33266839385032654
# ▶ seg46  mean  MSE:0.17380085587501526  MAE:0.33266839385032654
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.22101129591464996  MAE:0.3733798861503601
# ▶ seg47  mean  MSE:0.22101129591464996  MAE:0.3733798861503601
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.17372839152812958  MAE:0.33076050877571106
# ▶ seg48  mean  MSE:0.17372839152812958  MAE:0.33076050877571106
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.17782065272331238  MAE:0.3392447829246521
# ▶ seg49  mean  MSE:0.17782065272331238  MAE:0.3392447829246521
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.17003262042999268  MAE:0.33028385043144226
# ▶ seg50  mean  MSE:0.17003262042999268  MAE:0.33028385043144226
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.17772763967514038  MAE:0.33555367588996887
# ▶ seg51  mean  MSE:0.17772763967514038  MAE:0.33555367588996887
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.18082933127880096  MAE:0.3408801853656769
# ▶ seg52  mean  MSE:0.18082933127880096  MAE:0.3408801853656769
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.17942409217357635  MAE:0.33823060989379883
# ▶ seg53  mean  MSE:0.17942409217357635  MAE:0.33823060989379883
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.16579020023345947  MAE:0.32651570439338684
# ▶ seg54  mean  MSE:0.16579020023345947  MAE:0.32651570439338684
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.19938036799430847  MAE:0.3564643859863281
# ▶ seg55  mean  MSE:0.19938036799430847  MAE:0.3564643859863281
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.16984045505523682  MAE:0.3313538134098053
# ▶ seg56  mean  MSE:0.16984045505523682  MAE:0.3313538134098053
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.1608317494392395  MAE:0.3188612163066864
# ▶ seg57  mean  MSE:0.1608317494392395  MAE:0.3188612163066864
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.20154711604118347  MAE:0.3556647002696991
# ▶ seg58  mean  MSE:0.20154711604118347  MAE:0.3556647002696991
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.17556016147136688  MAE:0.3336944878101349
# ▶ seg59  mean  MSE:0.17556016147136688  MAE:0.3336944878101349
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.19132259488105774  MAE:0.3474990725517273
# ▶ seg60  mean  MSE:0.19132259488105774  MAE:0.3474990725517273
#
# seg10 ch0 MSE : 0.17212975

# %% [markdown]
# # 2nd Inference for Test Set

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 720  
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTh1_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.23920132219791412  MAE:0.38279324769973755
# ▶ seg0  mean  MSE:0.23920132219791412  MAE:0.38279324769973755
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.28928619623184204  MAE:0.43001803755760193
# ▶ seg1  mean  MSE:0.28928619623184204  MAE:0.43001803755760193
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.857151210308075  MAE:0.8113281726837158
# ▶ seg2  mean  MSE:0.857151210308075  MAE:0.8113281726837158
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.27398696541786194  MAE:0.4191349446773529
# ▶ seg3  mean  MSE:0.27398696541786194  MAE:0.4191349446773529
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.8108953237533569  MAE:0.7165887355804443
# ▶ seg4  mean  MSE:0.8108953237533569  MAE:0.7165887355804443
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:1.5399351119995117  MAE:1.0338444709777832
# ▶ seg5  mean  MSE:1.5399351119995117  MAE:1.0338444709777832
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.29943597316741943  MAE:0.43638715147972107
# ▶ seg6  mean  MSE:0.29943597316741943  MAE:0.43638715147972107
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.30558910965919495  MAE:0.44247740507125854
# ▶ seg7  mean  MSE:0.30558910965919495  MAE:0.44247740507125854
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:1.029771327972412  MAE:0.779842734336853
# ▶ seg8  mean  MSE:1.029771327972412  MAE:0.779842734336853
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.23191243410110474  MAE:0.38689252734184265
# ▶ seg9  mean  MSE:0.23191243410110474  MAE:0.38689252734184265
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.24961011111736298  MAE:0.39179855585098267
# ▶ seg10  mean  MSE:0.24961011111736298  MAE:0.39179855585098267
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.8196120858192444  MAE:0.7291843295097351
# ▶ seg11  mean  MSE:0.8196120858192444  MAE:0.7291843295097351
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.4752649962902069  MAE:0.5663410425186157
# ▶ seg12  mean  MSE:0.4752649962902069  MAE:0.5663410425186157
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.5391085743904114  MAE:0.6123114228248596
# ▶ seg13  mean  MSE:0.5391085743904114  MAE:0.6123114228248596
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.6072046756744385  MAE:0.6287534832954407
# ▶ seg14  mean  MSE:0.6072046756744385  MAE:0.6287534832954407
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.661990761756897  MAE:0.7227621674537659
# ▶ seg15  mean  MSE:0.661990761756897  MAE:0.7227621674537659
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.3935835659503937  MAE:0.5043094158172607
# ▶ seg16  mean  MSE:0.3935835659503937  MAE:0.5043094158172607
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.41937771439552307  MAE:0.506698727607727
# ▶ seg17  mean  MSE:0.41937771439552307  MAE:0.506698727607727
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.24109229445457458  MAE:0.39363881945610046
# ▶ seg18  mean  MSE:0.24109229445457458  MAE:0.39363881945610046
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.33263808488845825  MAE:0.4544147551059723
# ▶ seg19  mean  MSE:0.33263808488845825  MAE:0.4544147551059723
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.2780608832836151  MAE:0.4229537546634674
# ▶ seg20  mean  MSE:0.2780608832836151  MAE:0.4229537546634674
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.4935269355773926  MAE:0.5755091309547424
# ▶ seg21  mean  MSE:0.4935269355773926  MAE:0.5755091309547424
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.33609238266944885  MAE:0.4614947736263275
# ▶ seg22  mean  MSE:0.33609238266944885  MAE:0.4614947736263275
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.3521650433540344  MAE:0.4714851677417755
# ▶ seg23  mean  MSE:0.3521650433540344  MAE:0.4714851677417755
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.913791835308075  MAE:0.801706075668335
# ▶ seg24  mean  MSE:0.913791835308075  MAE:0.801706075668335
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.42566290497779846  MAE:0.5240764021873474
# ▶ seg25  mean  MSE:0.42566290497779846  MAE:0.5240764021873474
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.37094002962112427  MAE:0.4865175485610962
# ▶ seg26  mean  MSE:0.37094002962112427  MAE:0.4865175485610962
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.4633414149284363  MAE:0.5455649495124817
# ▶ seg27  mean  MSE:0.4633414149284363  MAE:0.5455649495124817
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.2745393216609955  MAE:0.40219512581825256
# ▶ seg28  mean  MSE:0.2745393216609955  MAE:0.40219512581825256
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.4521927833557129  MAE:0.5530036687850952
# ▶ seg29  mean  MSE:0.4521927833557129  MAE:0.5530036687850952
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.28386715054512024  MAE:0.4167671203613281
# ▶ seg30  mean  MSE:0.28386715054512024  MAE:0.4167671203613281
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.26190704107284546  MAE:0.4110359847545624
# ▶ seg31  mean  MSE:0.26190704107284546  MAE:0.4110359847545624
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:1.0228607654571533  MAE:0.8145979642868042
# ▶ seg32  mean  MSE:1.0228607654571533  MAE:0.8145979642868042
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.44802987575531006  MAE:0.5471463203430176
# ▶ seg33  mean  MSE:0.44802987575531006  MAE:0.5471463203430176
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.46104884147644043  MAE:0.556043267250061
# ▶ seg34  mean  MSE:0.46104884147644043  MAE:0.556043267250061
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.4696865975856781  MAE:0.5877683162689209
# ▶ seg35  mean  MSE:0.4696865975856781  MAE:0.5877683162689209
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:2.0825798511505127  MAE:1.2892847061157227
# ▶ seg36  mean  MSE:2.0825798511505127  MAE:1.2892847061157227
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.3990442454814911  MAE:0.52387934923172
# ▶ seg37  mean  MSE:0.3990442454814911  MAE:0.52387934923172
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.9427676796913147  MAE:0.8388426303863525
# ▶ seg38  mean  MSE:0.9427676796913147  MAE:0.8388426303863525
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.19937163591384888  MAE:0.3562837541103363
# ▶ seg39  mean  MSE:0.19937163591384888  MAE:0.3562837541103363
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.7768825888633728  MAE:0.7439388632774353
# ▶ seg40  mean  MSE:0.7768825888633728  MAE:0.7439388632774353
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.34339067339897156  MAE:0.47380223870277405
# ▶ seg41  mean  MSE:0.34339067339897156  MAE:0.47380223870277405
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.2550004720687866  MAE:0.39590728282928467
# ▶ seg42  mean  MSE:0.2550004720687866  MAE:0.39590728282928467
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.3796781897544861  MAE:0.47876641154289246
# ▶ seg43  mean  MSE:0.3796781897544861  MAE:0.47876641154289246
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:1.71148681640625  MAE:1.1424919366836548
# ▶ seg44  mean  MSE:1.71148681640625  MAE:1.1424919366836548
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.3351898789405823  MAE:0.47540274262428284
# ▶ seg45  mean  MSE:0.3351898789405823  MAE:0.47540274262428284
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.3218833804130554  MAE:0.45625364780426025
# ▶ seg46  mean  MSE:0.3218833804130554  MAE:0.45625364780426025
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.33073487877845764  MAE:0.4596349000930786
# ▶ seg47  mean  MSE:0.33073487877845764  MAE:0.4596349000930786
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.3051287531852722  MAE:0.4385644495487213
# ▶ seg48  mean  MSE:0.3051287531852722  MAE:0.4385644495487213
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.6599516272544861  MAE:0.6490494608879089
# ▶ seg49  mean  MSE:0.6599516272544861  MAE:0.6490494608879089
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.26480919122695923  MAE:0.39947158098220825
# ▶ seg50  mean  MSE:0.26480919122695923  MAE:0.39947158098220825
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:1.1263298988342285  MAE:0.9372408390045166
# ▶ seg51  mean  MSE:1.1263298988342285  MAE:0.9372408390045166
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.3314356505870819  MAE:0.47943738102912903
# ▶ seg52  mean  MSE:0.3314356505870819  MAE:0.47943738102912903
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.2612394094467163  MAE:0.4111264646053314
# ▶ seg53  mean  MSE:0.2612394094467163  MAE:0.4111264646053314
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.2937646806240082  MAE:0.4306890070438385
# ▶ seg54  mean  MSE:0.2937646806240082  MAE:0.4306890070438385
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.3247990012168884  MAE:0.4516310393810272
# ▶ seg55  mean  MSE:0.3247990012168884  MAE:0.4516310393810272
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.47431787848472595  MAE:0.5789043307304382
# ▶ seg56  mean  MSE:0.47431787848472595  MAE:0.5789043307304382
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.3168955445289612  MAE:0.44843053817749023
# ▶ seg57  mean  MSE:0.3168955445289612  MAE:0.44843053817749023
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.9066765904426575  MAE:0.8205649256706238
# ▶ seg58  mean  MSE:0.9066765904426575  MAE:0.8205649256706238
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.7669885754585266  MAE:0.7525619864463806
# ▶ seg59  mean  MSE:0.7669885754585266  MAE:0.7525619864463806
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.4224507808685303  MAE:0.5258212685585022
# ▶ seg60  mean  MSE:0.4224507808685303  MAE:0.5258212685585022
#
# seg10 ch0 MSE : 0.24961011

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 720
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTh1_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.39688342809677124  MAE:0.5077597498893738
# ▶ seg0  mean  MSE:0.39688342809677124  MAE:0.5077597498893738
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.2993054986000061  MAE:0.4352715313434601
# ▶ seg1  mean  MSE:0.2993054986000061  MAE:0.4352715313434601
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.3066619038581848  MAE:0.4457959830760956
# ▶ seg2  mean  MSE:0.3066619038581848  MAE:0.4457959830760956
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.7652001976966858  MAE:0.7490431070327759
# ▶ seg3  mean  MSE:0.7652001976966858  MAE:0.7490431070327759
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.31360363960266113  MAE:0.44309496879577637
# ▶ seg4  mean  MSE:0.31360363960266113  MAE:0.44309496879577637
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.3545518219470978  MAE:0.47088149189949036
# ▶ seg5  mean  MSE:0.3545518219470978  MAE:0.47088149189949036
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.5789463520050049  MAE:0.5926640629768372
# ▶ seg6  mean  MSE:0.5789463520050049  MAE:0.5926640629768372
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.2228745073080063  MAE:0.3735336363315582
# ▶ seg7  mean  MSE:0.2228745073080063  MAE:0.3735336363315582
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.3174692392349243  MAE:0.44013655185699463
# ▶ seg8  mean  MSE:0.3174692392349243  MAE:0.44013655185699463
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.48358723521232605  MAE:0.5774721503257751
# ▶ seg9  mean  MSE:0.48358723521232605  MAE:0.5774721503257751
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.4025256633758545  MAE:0.5223799347877502
# ▶ seg10  mean  MSE:0.4025256633758545  MAE:0.5223799347877502
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.28178566694259644  MAE:0.4233728349208832
# ▶ seg11  mean  MSE:0.28178566694259644  MAE:0.4233728349208832
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.3985292315483093  MAE:0.5116294026374817
# ▶ seg12  mean  MSE:0.3985292315483093  MAE:0.5116294026374817
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.19174602627754211  MAE:0.3480130732059479
# ▶ seg13  mean  MSE:0.19174602627754211  MAE:0.3480130732059479
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.3457154333591461  MAE:0.47644829750061035
# ▶ seg14  mean  MSE:0.3457154333591461  MAE:0.47644829750061035
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.5744972825050354  MAE:0.6574358940124512
# ▶ seg15  mean  MSE:0.5744972825050354  MAE:0.6574358940124512
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.32830241322517395  MAE:0.4620130658149719
# ▶ seg16  mean  MSE:0.32830241322517395  MAE:0.4620130658149719
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.3422529399394989  MAE:0.4666453003883362
# ▶ seg17  mean  MSE:0.3422529399394989  MAE:0.4666453003883362
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:1.3322874307632446  MAE:1.0214446783065796
# ▶ seg18  mean  MSE:1.3322874307632446  MAE:1.0214446783065796
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.37296417355537415  MAE:0.49982184171676636
# ▶ seg19  mean  MSE:0.37296417355537415  MAE:0.49982184171676636
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.3420688807964325  MAE:0.4640789330005646
# ▶ seg20  mean  MSE:0.3420688807964325  MAE:0.4640789330005646
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.39345014095306396  MAE:0.46812504529953003
# ▶ seg21  mean  MSE:0.39345014095306396  MAE:0.46812504529953003
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.7502577900886536  MAE:0.7190343737602234
# ▶ seg22  mean  MSE:0.7502577900886536  MAE:0.7190343737602234
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.3797183632850647  MAE:0.5138604640960693
# ▶ seg23  mean  MSE:0.3797183632850647  MAE:0.5138604640960693
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.2364860475063324  MAE:0.38188302516937256
# ▶ seg24  mean  MSE:0.2364860475063324  MAE:0.38188302516937256
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:1.004409909248352  MAE:0.795307993888855
# ▶ seg25  mean  MSE:1.004409909248352  MAE:0.795307993888855
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.4572296142578125  MAE:0.5696399211883545
# ▶ seg26  mean  MSE:0.4572296142578125  MAE:0.5696399211883545
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.25688183307647705  MAE:0.4092444181442261
# ▶ seg27  mean  MSE:0.25688183307647705  MAE:0.4092444181442261
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.32864052057266235  MAE:0.4576801359653473
# ▶ seg28  mean  MSE:0.32864052057266235  MAE:0.4576801359653473
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.43557271361351013  MAE:0.5461778044700623
# ▶ seg29  mean  MSE:0.43557271361351013  MAE:0.5461778044700623
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.3641592264175415  MAE:0.49067357182502747
# ▶ seg30  mean  MSE:0.3641592264175415  MAE:0.49067357182502747
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.20792163908481598  MAE:0.36592766642570496
# ▶ seg31  mean  MSE:0.20792163908481598  MAE:0.36592766642570496
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.492236465215683  MAE:0.5526107549667358
# ▶ seg32  mean  MSE:0.492236465215683  MAE:0.5526107549667358
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.22447951138019562  MAE:0.3771873712539673
# ▶ seg33  mean  MSE:0.22447951138019562  MAE:0.3771873712539673
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.23013705015182495  MAE:0.3798704743385315
# ▶ seg34  mean  MSE:0.23013705015182495  MAE:0.3798704743385315
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.2176593840122223  MAE:0.3680141270160675
# ▶ seg35  mean  MSE:0.2176593840122223  MAE:0.3680141270160675
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.8307905197143555  MAE:0.7482726573944092
# ▶ seg36  mean  MSE:0.8307905197143555  MAE:0.7482726573944092
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:1.4670116901397705  MAE:1.0137752294540405
# ▶ seg37  mean  MSE:1.4670116901397705  MAE:1.0137752294540405
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.4589483141899109  MAE:0.5048210620880127
# ▶ seg38  mean  MSE:0.4589483141899109  MAE:0.5048210620880127
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.24699299037456512  MAE:0.39462921023368835
# ▶ seg39  mean  MSE:0.24699299037456512  MAE:0.39462921023368835
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.9787555932998657  MAE:0.7980469465255737
# ▶ seg40  mean  MSE:0.9787555932998657  MAE:0.7980469465255737
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.3884645700454712  MAE:0.51677006483078
# ▶ seg41  mean  MSE:0.3884645700454712  MAE:0.51677006483078
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.7500228881835938  MAE:0.7006182074546814
# ▶ seg42  mean  MSE:0.7500228881835938  MAE:0.7006182074546814
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.6885603070259094  MAE:0.7079526782035828
# ▶ seg43  mean  MSE:0.6885603070259094  MAE:0.7079526782035828
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.3192604184150696  MAE:0.445602685213089
# ▶ seg44  mean  MSE:0.3192604184150696  MAE:0.445602685213089
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.288065642118454  MAE:0.4255291819572449
# ▶ seg45  mean  MSE:0.288065642118454  MAE:0.4255291819572449
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.24475699663162231  MAE:0.40482085943222046
# ▶ seg46  mean  MSE:0.24475699663162231  MAE:0.40482085943222046
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:1.0853544473648071  MAE:0.8238606452941895
# ▶ seg47  mean  MSE:1.0853544473648071  MAE:0.8238606452941895
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.48797211050987244  MAE:0.5569005608558655
# ▶ seg48  mean  MSE:0.48797211050987244  MAE:0.5569005608558655
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.5756325721740723  MAE:0.605991542339325
# ▶ seg49  mean  MSE:0.5756325721740723  MAE:0.605991542339325
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.322807252407074  MAE:0.4624433219432831
# ▶ seg50  mean  MSE:0.322807252407074  MAE:0.4624433219432831
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.38084861636161804  MAE:0.49018362164497375
# ▶ seg51  mean  MSE:0.38084861636161804  MAE:0.49018362164497375
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.45285189151763916  MAE:0.555919349193573
# ▶ seg52  mean  MSE:0.45285189151763916  MAE:0.555919349193573
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.6323187947273254  MAE:0.6653239727020264
# ▶ seg53  mean  MSE:0.6323187947273254  MAE:0.6653239727020264
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.22155915200710297  MAE:0.37307167053222656
# ▶ seg54  mean  MSE:0.22155915200710297  MAE:0.37307167053222656
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:1.046665906906128  MAE:0.8722726702690125
# ▶ seg55  mean  MSE:1.046665906906128  MAE:0.8722726702690125
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.2610301673412323  MAE:0.4064160883426666
# ▶ seg56  mean  MSE:0.2610301673412323  MAE:0.4064160883426666
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.3455088436603546  MAE:0.49619048833847046
# ▶ seg57  mean  MSE:0.3455088436603546  MAE:0.49619048833847046
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.5091495513916016  MAE:0.5656874775886536
# ▶ seg58  mean  MSE:0.5091495513916016  MAE:0.5656874775886536
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.5227571725845337  MAE:0.6074556708335876
# ▶ seg59  mean  MSE:0.5227571725845337  MAE:0.6074556708335876
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.8921411633491516  MAE:0.8059121966362
# ▶ seg60  mean  MSE:0.8921411633491516  MAE:0.8059121966362
#
# seg10 ch0 MSE : 0.40252566

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTh1_train = torch.load("./1st_results_ETTh1/train_1st_results.pt")
results1_ETTh1_val = torch.load("./1st_results_ETTh1/val_1st_results.pt")
results1_ETTh1_test = torch.load("./1st_results_ETTh1/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 61
SEG_CNT     = 61
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.174486
#
#   Top  1 | seg 31 | MSE 0.161602 (+0.012884)
#   Top  2 | seg 57 | MSE 0.161749 (+0.012737)
#   Top  3 | seg 03 | MSE 0.162113 (+0.012372)
#   Top  4 | seg 45 | MSE 0.162331 (+0.012155)
#   Top  5 | seg 18 | MSE 0.162526 (+0.011960)
#   Top  6 | seg 52 | MSE 0.162767 (+0.011718)
#   Top  7 | seg 39 | MSE 0.163420 (+0.011065)
#   Top  8 | seg 46 | MSE 0.164188 (+0.010298)
#   Top  9 | seg 53 | MSE 0.164668 (+0.009818)
#   Top 10 | seg 10 | MSE 0.165610 (+0.008876)
#   Top 11 | seg 09 | MSE 0.166252 (+0.008234)
#   Top 12 | seg 07 | MSE 0.166567 (+0.007919)
#   Top 13 | seg 50 | MSE 0.166863 (+0.007623)
#   Top 14 | seg 48 | MSE 0.167329 (+0.007157)
#   Top 15 | seg 47 | MSE 0.168290 (+0.006195)
#   Top 16 | seg 25 | MSE 0.168633 (+0.005853)
#   Top 17 | seg 37 | MSE 0.169039 (+0.005447)
#   Top 18 | seg 22 | MSE 0.169492 (+0.004993)
#   Top 19 | seg 35 | MSE 0.169635 (+0.004850)
#   Top 20 | seg 27 | MSE 0.169968 (+0.004517)
#   Top 21 | seg 20 | MSE 0.170174 (+0.004311)
#   Top 22 | seg 41 | MSE 0.170500 (+0.003986)
#   Top 23 | seg 33 | MSE 0.170530 (+0.003955)
#   Top 24 | seg 42 | MSE 0.170809 (+0.003677)
#   Top 25 | seg 55 | MSE 0.170861 (+0.003624)
#   Top 26 | seg 12 | MSE 0.173399 (+0.001087)
#   Top 27 | seg 34 | MSE 0.173527 (+0.000958)
#   Top 28 | seg 56 | MSE 0.174395 (+0.000091)
#   Top 29 | seg 21 | MSE 0.174478 (+0.000008)
#   Top 30 | seg 26 | MSE 0.174866 (-0.000380)
#   Top 31 | seg 06 | MSE 0.175611 (-0.001125)
#   Top 32 | seg 15 | MSE 0.175750 (-0.001264)
#   Top 33 | seg 28 | MSE 0.176409 (-0.001924)
#   Top 34 | seg 54 | MSE 0.176587 (-0.002101)
#   Top 35 | seg 30 | MSE 0.176597 (-0.002112)
#   Top 36 | seg 13 | MSE 0.176899 (-0.002413)
#   Top 37 | seg 60 | MSE 0.176923 (-0.002437)
#   Top 38 | seg 01 | MSE 0.177019 (-0.002533)
#   Top 39 | seg 00 | MSE 0.177356 (-0.002871)
#   Top 40 | seg 16 | MSE 0.177649 (-0.003163)
#   Top 41 | seg 17 | MSE 0.177873 (-0.003388)
#   Top 42 | seg 29 | MSE 0.179029 (-0.004543)
#   Top 43 | seg 23 | MSE 0.179816 (-0.005331)
#   Top 44 | seg 19 | MSE 0.180314 (-0.005828)
#   Top 45 | seg 40 | MSE 0.180865 (-0.006380)
#   Top 46 | seg 59 | MSE 0.184319 (-0.009834)
#   Top 47 | seg 02 | MSE 0.184748 (-0.010262)
#   Top 48 | seg 49 | MSE 0.184913 (-0.010428)
#   Top 49 | seg 43 | MSE 0.185473 (-0.010987)
#   Top 50 | seg 14 | MSE 0.185599 (-0.011113)
#   Top 51 | seg 24 | MSE 0.190714 (-0.016229)
#   Top 52 | seg 04 | MSE 0.191026 (-0.016540)
#   Top 53 | seg 11 | MSE 0.192965 (-0.018479)
#   Top 54 | seg 58 | MSE 0.193360 (-0.018874)
#   Top 55 | seg 38 | MSE 0.196813 (-0.022327)
#   Top 56 | seg 32 | MSE 0.198942 (-0.024456)
#   Top 57 | seg 51 | MSE 0.199923 (-0.025438)
#   Top 58 | seg 08 | MSE 0.242670 (-0.068185)
#   Top 59 | seg 36 | MSE 0.255604 (-0.081119)
#   Top 60 | seg 05 | MSE 0.290965 (-0.116479)
#   Top 61 | seg 44 | MSE 0.297362 (-0.122876)
#
# Saved top segment indices per channel:
# Channel 0: [31, 57, 3, 45, 18, 52, 39, 46, 53, 10, 9, 7, 50, 48, 47, 25, 37, 22, 35, 27, 20, 41, 33, 42, 55, 12, 34, 56, 21, 26, 6, 15, 28, 54, 30, 13, 60, 1, 0, 16, 17, 29, 23, 19, 40, 59, 2, 49, 43, 14, 24, 4, 11, 58, 38, 32, 51, 8, 36, 5, 44]

# %% [markdown]
# ### 1E->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 61
SEG_CNT     = 61
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.174486
#
#   Top  1 | seg 57 | MSE 0.160832 (+0.013654)
#   Top  2 | seg 31 | MSE 0.162362 (+0.012124)
#   Top  3 | seg 27 | MSE 0.163389 (+0.011097)
#   Top  4 | seg 41 | MSE 0.163447 (+0.011039)
#   Top  5 | seg 07 | MSE 0.164085 (+0.010401)
#   Top  6 | seg 39 | MSE 0.164172 (+0.010314)
#   Top  7 | seg 14 | MSE 0.164272 (+0.010213)
#   Top  8 | seg 20 | MSE 0.164443 (+0.010042)
#   Top  9 | seg 30 | MSE 0.164680 (+0.009806)
#   Top 10 | seg 13 | MSE 0.164999 (+0.009487)
#   Top 11 | seg 19 | MSE 0.165538 (+0.008947)
#   Top 12 | seg 16 | MSE 0.165697 (+0.008788)
#   Top 13 | seg 54 | MSE 0.165790 (+0.008695)
#   Top 14 | seg 05 | MSE 0.165836 (+0.008650)
#   Top 15 | seg 35 | MSE 0.166246 (+0.008240)
#   Top 16 | seg 28 | MSE 0.167003 (+0.007483)
#   Top 17 | seg 23 | MSE 0.167359 (+0.007126)
#   Top 18 | seg 02 | MSE 0.167594 (+0.006891)
#   Top 19 | seg 12 | MSE 0.167707 (+0.006778)
#   Top 20 | seg 45 | MSE 0.168166 (+0.006319)
#   Top 21 | seg 29 | MSE 0.169824 (+0.004662)
#   Top 22 | seg 56 | MSE 0.169840 (+0.004645)
#   Top 23 | seg 09 | MSE 0.169973 (+0.004512)
#   Top 24 | seg 34 | MSE 0.170010 (+0.004475)
#   Top 25 | seg 50 | MSE 0.170033 (+0.004453)
#   Top 26 | seg 11 | MSE 0.170517 (+0.003969)
#   Top 27 | seg 17 | MSE 0.170966 (+0.003520)
#   Top 28 | seg 24 | MSE 0.171230 (+0.003256)
#   Top 29 | seg 15 | MSE 0.172011 (+0.002474)
#   Top 30 | seg 10 | MSE 0.172130 (+0.002356)
#   Top 31 | seg 00 | MSE 0.172251 (+0.002234)
#   Top 32 | seg 44 | MSE 0.172278 (+0.002208)
#   Top 33 | seg 33 | MSE 0.172814 (+0.001671)
#   Top 34 | seg 26 | MSE 0.172819 (+0.001667)
#   Top 35 | seg 01 | MSE 0.173626 (+0.000860)
#   Top 36 | seg 48 | MSE 0.173728 (+0.000757)
#   Top 37 | seg 46 | MSE 0.173801 (+0.000685)
#   Top 38 | seg 21 | MSE 0.174404 (+0.000082)
#   Top 39 | seg 59 | MSE 0.175560 (-0.001075)
#   Top 40 | seg 06 | MSE 0.175600 (-0.001115)
#   Top 41 | seg 38 | MSE 0.177085 (-0.002600)
#   Top 42 | seg 51 | MSE 0.177728 (-0.003242)
#   Top 43 | seg 49 | MSE 0.177821 (-0.003335)
#   Top 44 | seg 04 | MSE 0.178763 (-0.004278)
#   Top 45 | seg 53 | MSE 0.179424 (-0.004938)
#   Top 46 | seg 52 | MSE 0.180829 (-0.006344)
#   Top 47 | seg 03 | MSE 0.181527 (-0.007042)
#   Top 48 | seg 22 | MSE 0.182388 (-0.007902)
#   Top 49 | seg 43 | MSE 0.185768 (-0.011283)
#   Top 50 | seg 36 | MSE 0.187086 (-0.012600)
#   Top 51 | seg 42 | MSE 0.190011 (-0.015525)
#   Top 52 | seg 32 | MSE 0.190449 (-0.015963)
#   Top 53 | seg 08 | MSE 0.190490 (-0.016004)
#   Top 54 | seg 60 | MSE 0.191323 (-0.016837)
#   Top 55 | seg 55 | MSE 0.199380 (-0.024895)
#   Top 56 | seg 58 | MSE 0.201547 (-0.027061)
#   Top 57 | seg 18 | MSE 0.211565 (-0.037080)
#   Top 58 | seg 47 | MSE 0.221011 (-0.046526)
#   Top 59 | seg 25 | MSE 0.223207 (-0.048722)
#   Top 60 | seg 40 | MSE 0.233059 (-0.058574)
#   Top 61 | seg 37 | MSE 0.276344 (-0.101858)
#
# Saved top segment indices per channel:
# Channel 0: [57, 31, 27, 41, 7, 39, 14, 20, 30, 13, 19, 16, 54, 5, 35, 28, 23, 2, 12, 45, 29, 56, 9, 34, 50, 11, 17, 24, 15, 10, 0, 44, 33, 26, 1, 48, 46, 21, 59, 6, 38, 51, 49, 4, 53, 52, 3, 22, 43, 36, 42, 32, 8, 60, 55, 58, 18, 47, 25, 40, 37]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTh1_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.186648 | MAE : 0.356964
#   — Var / |Corr| / Score —
#    K= 5 | Var=1.487e-01 | |ρ|=0.2799 | S=0.3637 <- pick
#    K=10 | Var=1.413e-01 | |ρ|=0.3281 | S=1.0000
#    K=15 | Var=1.552e-01 | |ρ|=0.3098 | S=0.8185
#    K=20 | Var=1.648e-01 | |ρ|=0.2935 | S=0.6407
#    K=25 | Var=1.695e-01 | |ρ|=0.2983 | S=0.7342
#    K=30 | Var=1.745e-01 | |ρ|=0.2899 | S=0.6430
#    K=35 | Var=1.945e-01 | |ρ|=0.2920 | S=0.7808
#    K=40 | Var=2.011e-01 | |ρ|=0.2879 | S=0.7583
#    K=45 | Var=2.135e-01 | |ρ|=0.2796 | S=0.7082
#    K=50 | Var=2.310e-01 | |ρ|=0.2748 | S=0.7364
#    K=55 | Var=2.502e-01 | |ρ|=0.2653 | S=0.7063
#    K=60 | Var=3.266e-01 | |ρ|=0.2569 | S=1.0000
# [Var-Corr]  K=5
#   MSE = 0.166853 | Δ = +0.019795 | Δ% = +10.61%
#   MAE = 0.330356 | Δ = +0.026609 | Δ% = +7.45%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.186648
# Ensemble mean MSE : 0.166853
# Average Δ MSE     : +0.019795
# Average Δ MSE (%) : +10.61%
#
# Vanilla  mean MAE : 0.356964
# Ensemble mean MAE : 0.330356
# Average Δ MAE     : +0.026609
# Average Δ MAE (%) : +7.45%

# %% [markdown]
# ## 1E->1E

# %%
results1_ETTh1_test['ES']['mae_test_EES']
# Out:
# 0.3569643199443817

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTh1_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.35   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.186648 | MAE : 0.356964
#   — Var / |Corr| / Score —
#    K= 5 | Var=1.421e-01 | |ρ|=0.3717 | S=1.3068
#    K=10 | Var=1.410e-01 | |ρ|=0.3759 | S=1.3500
#    K=15 | Var=1.505e-01 | |ρ|=0.3636 | S=1.2640
#    K=20 | Var=1.542e-01 | |ρ|=0.3524 | S=1.1547
#    K=25 | Var=1.669e-01 | |ρ|=0.3357 | S=1.0366
#    K=30 | Var=1.744e-01 | |ρ|=0.3242 | S=0.9473
#    K=35 | Var=1.797e-01 | |ρ|=0.3216 | S=0.9496
#    K=40 | Var=1.868e-01 | |ρ|=0.3076 | S=0.8277
#    K=45 | Var=1.998e-01 | |ρ|=0.2952 | S=0.7633
#    K=50 | Var=2.185e-01 | |ρ|=0.2782 | S=0.6784 <- pick
#    K=55 | Var=2.468e-01 | |ρ|=0.2719 | S=0.7812
#    K=60 | Var=3.011e-01 | |ρ|=0.2617 | S=1.0000
# [Var-Corr]  K=50
#    MSE = 0.174940 | Δ = +0.011708 | Δ% = +6.27%
#    MAE = 0.344372 | Δ = +0.012592 | Δ% = +3.53%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.186648
# Ensemble mean MSE  : 0.174940
# Average Δ MSE      : +0.011708
# Average Δ MSE (%)  : +6.27%
#
# Vanilla  mean MAE  : 0.356964
# Ensemble mean MAE  : 0.344372
# Average Δ MAE      : +0.012592
# Average Δ MAE (%)  : +3.53%
