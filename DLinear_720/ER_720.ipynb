# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(2)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 2
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/exchange_rate.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                  0       1         2         3         4         5         6  \
# date
# 1990-01-01  0.7855  1.6110  0.861698  0.634196  0.211242  0.006838  0.525486
# 1990-01-02  0.7818  1.6100  0.861104  0.633513  0.211242  0.006863  0.523972
# 1990-01-03  0.7867  1.6293  0.861030  0.648508  0.211242  0.006975  0.526316
# 1990-01-04  0.7860  1.6370  0.862069  0.650618  0.211242  0.006953  0.523834
# 1990-01-05  0.7849  1.6530  0.861995  0.656254  0.211242  0.006940  0.527426
#
#                 OT
# date
# 1990-01-01  0.5930
# 1990-01-02  0.5940
# 1990-01-03  0.5973
# 1990-01-04  0.5970
# 1990-01-05  0.5985

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# OT    float64
# dtype: object
# shape:  (7588, 8)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2010-10-01', '2010-10-02', '2010-10-03', '2010-10-04',
#                '2010-10-05', '2010-10-06', '2010-10-07', '2010-10-08',
#                '2010-10-09', '2010-10-10'],
#               dtype='datetime64[ns]', name='date', length=7588, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %%
set_seed(24)

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Decomposition-Linear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.individual = configs.individual
        self.channels = configs.enc_in
        self.attach_to_trend = configs.attach_to_trend
        self.attach_to_seasonal = configs.attach_to_seasonal
        

        
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        

        
        self.seq_len_trend = self.seq_len + (self.pred_len // 3) if self.attach_to_trend else self.seq_len
        self.seq_len_seasonal = self.seq_len + (self.pred_len // 3) if self.attach_to_seasonal else self.seq_len

        
        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))

                
                
                
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            
            
            
            

    def forward(self, x, ground_truth=None):
        
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if ground_truth is not None:
            kernel_size = 25
            self.decompsition = series_decomp(kernel_size)
            ground_truth_seasonal, ground_truth_trend = self.decompsition(ground_truth)

            
            if self.seq_len_seasonal > self.seq_len:
                ground_truth_seasonal=ground_truth_seasonal.permute(0, 2, 1)
                
                seasonal_init = torch.cat([seasonal_init, ground_truth_seasonal], dim=2)
            if self.seq_len_trend > self.seq_len:
                ground_truth_trend=ground_truth_trend.permute(0, 2, 1)
                
                trend_init = torch.cat([trend_init, ground_truth_trend], dim=2)
        
        
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len  = 336
pred_len = 720


total_len  = len(target)
num_train  = int(total_len * 0.7)
num_test   = int(total_len * 0.2)
num_val    = total_len - num_train - num_test

border1s = [
    0,
    num_train - seq_len,
    total_len - num_test - seq_len
]
border2s = [
    num_train,
    num_train + num_val,
    total_len
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i : i + seq_len]
        seq_y = data[i + seq_len : i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([4256, 336, 1])
# Train Labels:    torch.Size([4256, 720, 1])
# Val Sequences:   torch.Size([41, 336, 1])
# Val Labels:      torch.Size([41, 720, 1])
# Test Sequences:  torch.Size([798, 336, 1])
# Test Labels:     torch.Size([798, 720, 1])

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ER", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.6667852744572145 | Val Loss: 2.9030054807662964
# Validation loss decreased (inf --> 2.903005).  Saving model ...
# Updating learning rate to 0.0005
# Epoch 1 | Train Loss: 0.602331334935095 | Val Loss: 2.8943114280700684
# Validation loss decreased (2.903005 --> 2.894311).  Saving model ...
# Updating learning rate to 0.00025
# Epoch 2 | Train Loss: 0.5968736414622543 | Val Loss: 2.798292875289917
# Validation loss decreased (2.894311 --> 2.798293).  Saving model ...
# Updating learning rate to 0.000125
# Epoch 3 | Train Loss: 0.593730598464048 | Val Loss: 3.1455615758895874
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# Epoch 4 | Train Loss: 0.5907987734877077 | Val Loss: 2.8321943283081055
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# Epoch 5 | Train Loss: 0.5899430833812943 | Val Loss: 2.803488850593567
# EarlyStopping counter: 3 out of 3
# Early stopping triggered. Stopping training.

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ER", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.669462353663337 | Val Loss: 2.8203999996185303
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 1.2502894401550293 | MAE: 0.8794910907745361
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 1.129124402999878 | MAE: 0.8372719883918762

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 2.821479082107544 | MAE: 1.5375075340270996
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 2.8124725818634033 | MAE: 1.548557162284851

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.5919852256774902 | MAE: 0.5864490866661072
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.608103334903717 | MAE: 0.6019628047943115

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([4256, 336, 1])
# val_sequences shape:  torch.Size([41, 336, 1])
# test_sequences shape:  torch.Size([798, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([4256, 720, 1])
# val_pv shape:  torch.Size([41, 720, 1])
# test_pv shape:  torch.Size([798, 720, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([4256, 720, 1])
# val_labels shape:  torch.Size([41, 720, 1])
# test_labels shape:  torch.Size([798, 720, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 720

# %%
segment_len = configs.pred_len // 3
stride = 8

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([4256, 61, 240, 1]), Val: torch.Size([41, 61, 240, 1]), Test: torch.Size([798, 61, 240, 1])
# [Epoch 1] Train seg shape: torch.Size([4256, 61, 240, 1]), Val: torch.Size([41, 61, 240, 1]), Test: torch.Size([798, 61, 240, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ER'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ER/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ER/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ER/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ER_E{epo}_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 0] Training Time = 0.43 sec
# [Segment 0] GPU Memory Start = 900.82 MB
# [Segment 0] GPU Memory End   = 912.94 MB
# [Segment 0] GPU Peak Memory  = 916.11 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 1] Training Time = 0.46 sec
# [Segment 1] GPU Memory Start = 912.94 MB
# [Segment 1] GPU Memory End   = 912.94 MB
# [Segment 1] GPU Peak Memory  = 917.66 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 2] Training Time = 0.39 sec
# [Segment 2] GPU Memory Start = 912.94 MB
# [Segment 2] GPU Memory End   = 916.11 MB
# [Segment 2] GPU Peak Memory  = 919.28 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 3] Training Time = 0.47 sec
# [Segment 3] GPU Memory Start = 916.11 MB
# [Segment 3] GPU Memory End   = 919.28 MB
# [Segment 3] GPU Peak Memory  = 922.45 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 4] Training Time = 0.38 sec
# [Segment 4] GPU Memory Start = 919.28 MB
# [Segment 4] GPU Memory End   = 922.45 MB
# [Segment 4] GPU Peak Memory  = 925.62 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 5] Training Time = 0.40 sec
# [Segment 5] GPU Memory Start = 922.45 MB
# [Segment 5] GPU Memory End   = 925.62 MB
# [Segment 5] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 6] Training Time = 0.33 sec
# [Segment 6] GPU Memory Start = 925.62 MB
# [Segment 6] GPU Memory End   = 928.79 MB
# [Segment 6] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 7] Training Time = 0.30 sec
# [Segment 7] GPU Memory Start = 928.79 MB
# [Segment 7] GPU Memory End   = 931.96 MB
# [Segment 7] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 8] Training Time = 0.35 sec
# [Segment 8] GPU Memory Start = 931.96 MB
# [Segment 8] GPU Memory End   = 935.13 MB
# [Segment 8] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 9] Training Time = 0.42 sec
# [Segment 9] GPU Memory Start = 935.13 MB
# [Segment 9] GPU Memory End   = 938.30 MB
# [Segment 9] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 10] Training Time = 0.30 sec
# [Segment 10] GPU Memory Start = 938.30 MB
# [Segment 10] GPU Memory End   = 941.47 MB
# [Segment 10] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 11] Training Time = 0.46 sec
# [Segment 11] GPU Memory Start = 912.94 MB
# [Segment 11] GPU Memory End   = 916.11 MB
# [Segment 11] GPU Peak Memory  = 919.28 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 12] Training Time = 0.51 sec
# [Segment 12] GPU Memory Start = 916.11 MB
# [Segment 12] GPU Memory End   = 919.28 MB
# [Segment 12] GPU Peak Memory  = 922.45 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 13] Training Time = 0.33 sec
# [Segment 13] GPU Memory Start = 919.28 MB
# [Segment 13] GPU Memory End   = 922.45 MB
# [Segment 13] GPU Peak Memory  = 925.62 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 14] Training Time = 0.22 sec
# [Segment 14] GPU Memory Start = 922.45 MB
# [Segment 14] GPU Memory End   = 925.62 MB
# [Segment 14] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 15] Training Time = 0.24 sec
# [Segment 15] GPU Memory Start = 925.62 MB
# [Segment 15] GPU Memory End   = 928.79 MB
# [Segment 15] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 16] Training Time = 0.23 sec
# [Segment 16] GPU Memory Start = 928.79 MB
# [Segment 16] GPU Memory End   = 931.96 MB
# [Segment 16] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 17] Training Time = 0.49 sec
# [Segment 17] GPU Memory Start = 931.96 MB
# [Segment 17] GPU Memory End   = 935.13 MB
# [Segment 17] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 18] Training Time = 0.45 sec
# [Segment 18] GPU Memory Start = 935.13 MB
# [Segment 18] GPU Memory End   = 938.30 MB
# [Segment 18] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 19] Training Time = 0.37 sec
# [Segment 19] GPU Memory Start = 938.30 MB
# [Segment 19] GPU Memory End   = 941.47 MB
# [Segment 19] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 20] Training Time = 0.41 sec
# [Segment 20] GPU Memory Start = 941.47 MB
# [Segment 20] GPU Memory End   = 916.11 MB
# [Segment 20] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 21] Training Time = 0.53 sec
# [Segment 21] GPU Memory Start = 916.11 MB
# [Segment 21] GPU Memory End   = 919.28 MB
# [Segment 21] GPU Peak Memory  = 922.45 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 22] Training Time = 0.53 sec
# [Segment 22] GPU Memory Start = 919.28 MB
# [Segment 22] GPU Memory End   = 922.45 MB
# [Segment 22] GPU Peak Memory  = 925.62 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 23] Training Time = 0.73 sec
# [Segment 23] GPU Memory Start = 922.45 MB
# [Segment 23] GPU Memory End   = 925.62 MB
# [Segment 23] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 24] Training Time = 0.50 sec
# [Segment 24] GPU Memory Start = 925.62 MB
# [Segment 24] GPU Memory End   = 928.79 MB
# [Segment 24] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 25] Training Time = 0.44 sec
# [Segment 25] GPU Memory Start = 928.79 MB
# [Segment 25] GPU Memory End   = 931.96 MB
# [Segment 25] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 26] Training Time = 0.80 sec
# [Segment 26] GPU Memory Start = 931.96 MB
# [Segment 26] GPU Memory End   = 935.13 MB
# [Segment 26] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 27] Training Time = 0.45 sec
# [Segment 27] GPU Memory Start = 935.13 MB
# [Segment 27] GPU Memory End   = 938.30 MB
# [Segment 27] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 28] Training Time = 0.79 sec
# [Segment 28] GPU Memory Start = 938.30 MB
# [Segment 28] GPU Memory End   = 941.47 MB
# [Segment 28] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 29] Training Time = 0.90 sec
# [Segment 29] GPU Memory Start = 941.47 MB
# [Segment 29] GPU Memory End   = 944.64 MB
# [Segment 29] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 30] Training Time = 0.88 sec
# [Segment 30] GPU Memory Start = 916.11 MB
# [Segment 30] GPU Memory End   = 919.28 MB
# [Segment 30] GPU Peak Memory  = 922.45 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 31] Training Time = 0.87 sec
# [Segment 31] GPU Memory Start = 919.28 MB
# [Segment 31] GPU Memory End   = 922.45 MB
# [Segment 31] GPU Peak Memory  = 925.62 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 32] Training Time = 0.86 sec
# [Segment 32] GPU Memory Start = 922.45 MB
# [Segment 32] GPU Memory End   = 925.62 MB
# [Segment 32] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 33] Training Time = 0.91 sec
# [Segment 33] GPU Memory Start = 925.62 MB
# [Segment 33] GPU Memory End   = 928.79 MB
# [Segment 33] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 34] Training Time = 0.78 sec
# [Segment 34] GPU Memory Start = 928.79 MB
# [Segment 34] GPU Memory End   = 931.96 MB
# [Segment 34] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 35] Training Time = 0.52 sec
# [Segment 35] GPU Memory Start = 931.96 MB
# [Segment 35] GPU Memory End   = 935.13 MB
# [Segment 35] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 36] Training Time = 0.73 sec
# [Segment 36] GPU Memory Start = 935.13 MB
# [Segment 36] GPU Memory End   = 938.30 MB
# [Segment 36] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 37] Training Time = 0.88 sec
# [Segment 37] GPU Memory Start = 938.30 MB
# [Segment 37] GPU Memory End   = 941.47 MB
# [Segment 37] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 38] Training Time = 0.97 sec
# [Segment 38] GPU Memory Start = 941.47 MB
# [Segment 38] GPU Memory End   = 944.64 MB
# [Segment 38] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 39] Training Time = 0.76 sec
# [Segment 39] GPU Memory Start = 944.64 MB
# [Segment 39] GPU Memory End   = 919.28 MB
# [Segment 39] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 40] Training Time = 0.92 sec
# [Segment 40] GPU Memory Start = 919.28 MB
# [Segment 40] GPU Memory End   = 922.45 MB
# [Segment 40] GPU Peak Memory  = 925.62 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 41] Training Time = 0.61 sec
# [Segment 41] GPU Memory Start = 922.45 MB
# [Segment 41] GPU Memory End   = 925.62 MB
# [Segment 41] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 42] Training Time = 0.79 sec
# [Segment 42] GPU Memory Start = 925.62 MB
# [Segment 42] GPU Memory End   = 928.79 MB
# [Segment 42] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 43] Training Time = 0.43 sec
# [Segment 43] GPU Memory Start = 928.79 MB
# [Segment 43] GPU Memory End   = 931.96 MB
# [Segment 43] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 44] Training Time = 0.33 sec
# [Segment 44] GPU Memory Start = 931.96 MB
# [Segment 44] GPU Memory End   = 935.13 MB
# [Segment 44] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 45] Training Time = 0.86 sec
# [Segment 45] GPU Memory Start = 935.13 MB
# [Segment 45] GPU Memory End   = 938.30 MB
# [Segment 45] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 46] Training Time = 0.32 sec
# [Segment 46] GPU Memory Start = 938.30 MB
# [Segment 46] GPU Memory End   = 941.47 MB
# [Segment 46] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 47] Training Time = 0.42 sec
# [Segment 47] GPU Memory Start = 941.47 MB
# [Segment 47] GPU Memory End   = 944.64 MB
# [Segment 47] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 48] Training Time = 0.38 sec
# [Segment 48] GPU Memory Start = 944.64 MB
# [Segment 48] GPU Memory End   = 947.81 MB
# [Segment 48] GPU Peak Memory  = 950.98 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 49] Training Time = 0.69 sec
# [Segment 49] GPU Memory Start = 919.28 MB
# [Segment 49] GPU Memory End   = 922.45 MB
# [Segment 49] GPU Peak Memory  = 925.62 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 50] Training Time = 0.81 sec
# [Segment 50] GPU Memory Start = 922.45 MB
# [Segment 50] GPU Memory End   = 925.62 MB
# [Segment 50] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 51] Training Time = 0.47 sec
# [Segment 51] GPU Memory Start = 925.62 MB
# [Segment 51] GPU Memory End   = 928.79 MB
# [Segment 51] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 52] Training Time = 0.71 sec
# [Segment 52] GPU Memory Start = 928.79 MB
# [Segment 52] GPU Memory End   = 931.96 MB
# [Segment 52] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 53] Training Time = 0.40 sec
# [Segment 53] GPU Memory Start = 931.96 MB
# [Segment 53] GPU Memory End   = 935.13 MB
# [Segment 53] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 54] Training Time = 0.40 sec
# [Segment 54] GPU Memory Start = 935.13 MB
# [Segment 54] GPU Memory End   = 938.30 MB
# [Segment 54] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 55] Training Time = 0.51 sec
# [Segment 55] GPU Memory Start = 938.30 MB
# [Segment 55] GPU Memory End   = 941.47 MB
# [Segment 55] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 56] Training Time = 0.36 sec
# [Segment 56] GPU Memory Start = 941.47 MB
# [Segment 56] GPU Memory End   = 944.64 MB
# [Segment 56] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 57] Training Time = 0.67 sec
# [Segment 57] GPU Memory Start = 944.64 MB
# [Segment 57] GPU Memory End   = 947.81 MB
# [Segment 57] GPU Peak Memory  = 950.98 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 58] Training Time = 0.73 sec
# [Segment 58] GPU Memory Start = 947.81 MB
# [Segment 58] GPU Memory End   = 922.45 MB
# [Segment 58] GPU Peak Memory  = 950.98 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 59] Training Time = 0.72 sec
# [Segment 59] GPU Memory Start = 922.45 MB
# [Segment 59] GPU Memory End   = 925.62 MB
# [Segment 59] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 60] Training Time = 0.67 sec
# [Segment 60] GPU Memory Start = 925.62 MB
# [Segment 60] GPU Memory End   = 928.79 MB
# [Segment 60] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ER_E{epo}_1E/",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 0] Training Time = 0.78 sec
# [Segment 0] GPU Memory Start = 922.45 MB
# [Segment 0] GPU Memory End   = 922.45 MB
# [Segment 0] GPU Peak Memory  = 927.17 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 1] Training Time = 0.52 sec
# [Segment 1] GPU Memory Start = 922.45 MB
# [Segment 1] GPU Memory End   = 925.62 MB
# [Segment 1] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 2] Training Time = 0.67 sec
# [Segment 2] GPU Memory Start = 925.62 MB
# [Segment 2] GPU Memory End   = 928.79 MB
# [Segment 2] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 3] Training Time = 0.63 sec
# [Segment 3] GPU Memory Start = 928.79 MB
# [Segment 3] GPU Memory End   = 931.96 MB
# [Segment 3] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 4] Training Time = 0.88 sec
# [Segment 4] GPU Memory Start = 931.96 MB
# [Segment 4] GPU Memory End   = 922.45 MB
# [Segment 4] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 5] Training Time = 0.58 sec
# [Segment 5] GPU Memory Start = 922.45 MB
# [Segment 5] GPU Memory End   = 925.62 MB
# [Segment 5] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 6] Training Time = 0.75 sec
# [Segment 6] GPU Memory Start = 925.62 MB
# [Segment 6] GPU Memory End   = 928.79 MB
# [Segment 6] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 7] Training Time = 0.87 sec
# [Segment 7] GPU Memory Start = 928.79 MB
# [Segment 7] GPU Memory End   = 931.96 MB
# [Segment 7] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 8] Training Time = 0.72 sec
# [Segment 8] GPU Memory Start = 931.96 MB
# [Segment 8] GPU Memory End   = 935.13 MB
# [Segment 8] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 9] Training Time = 0.81 sec
# [Segment 9] GPU Memory Start = 935.13 MB
# [Segment 9] GPU Memory End   = 938.30 MB
# [Segment 9] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 10] Training Time = 0.80 sec
# [Segment 10] GPU Memory Start = 938.30 MB
# [Segment 10] GPU Memory End   = 941.47 MB
# [Segment 10] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 11] Training Time = 0.93 sec
# [Segment 11] GPU Memory Start = 941.47 MB
# [Segment 11] GPU Memory End   = 944.64 MB
# [Segment 11] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 12] Training Time = 0.41 sec
# [Segment 12] GPU Memory Start = 944.64 MB
# [Segment 12] GPU Memory End   = 947.81 MB
# [Segment 12] GPU Peak Memory  = 950.98 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 13] Training Time = 0.71 sec
# [Segment 13] GPU Memory Start = 947.81 MB
# [Segment 13] GPU Memory End   = 950.98 MB
# [Segment 13] GPU Peak Memory  = 954.15 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 14] Training Time = 0.84 sec
# [Segment 14] GPU Memory Start = 922.45 MB
# [Segment 14] GPU Memory End   = 925.62 MB
# [Segment 14] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 15] Training Time = 0.59 sec
# [Segment 15] GPU Memory Start = 925.62 MB
# [Segment 15] GPU Memory End   = 928.79 MB
# [Segment 15] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 16] Training Time = 0.39 sec
# [Segment 16] GPU Memory Start = 928.79 MB
# [Segment 16] GPU Memory End   = 931.96 MB
# [Segment 16] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 17] Training Time = 0.47 sec
# [Segment 17] GPU Memory Start = 931.96 MB
# [Segment 17] GPU Memory End   = 935.13 MB
# [Segment 17] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 18] Training Time = 0.50 sec
# [Segment 18] GPU Memory Start = 935.13 MB
# [Segment 18] GPU Memory End   = 938.30 MB
# [Segment 18] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 19] Training Time = 0.85 sec
# [Segment 19] GPU Memory Start = 938.30 MB
# [Segment 19] GPU Memory End   = 941.47 MB
# [Segment 19] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 20] Training Time = 0.84 sec
# [Segment 20] GPU Memory Start = 941.47 MB
# [Segment 20] GPU Memory End   = 944.64 MB
# [Segment 20] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 21] Training Time = 0.59 sec
# [Segment 21] GPU Memory Start = 944.64 MB
# [Segment 21] GPU Memory End   = 947.81 MB
# [Segment 21] GPU Peak Memory  = 950.98 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 22] Training Time = 0.76 sec
# [Segment 22] GPU Memory Start = 947.81 MB
# [Segment 22] GPU Memory End   = 950.98 MB
# [Segment 22] GPU Peak Memory  = 954.15 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 23] Training Time = 0.52 sec
# [Segment 23] GPU Memory Start = 950.98 MB
# [Segment 23] GPU Memory End   = 925.62 MB
# [Segment 23] GPU Peak Memory  = 954.15 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 24] Training Time = 0.85 sec
# [Segment 24] GPU Memory Start = 925.62 MB
# [Segment 24] GPU Memory End   = 928.79 MB
# [Segment 24] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 25] Training Time = 0.68 sec
# [Segment 25] GPU Memory Start = 928.79 MB
# [Segment 25] GPU Memory End   = 931.96 MB
# [Segment 25] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 26] Training Time = 0.67 sec
# [Segment 26] GPU Memory Start = 931.96 MB
# [Segment 26] GPU Memory End   = 935.13 MB
# [Segment 26] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 27] Training Time = 0.38 sec
# [Segment 27] GPU Memory Start = 935.13 MB
# [Segment 27] GPU Memory End   = 938.30 MB
# [Segment 27] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 28] Training Time = 0.33 sec
# [Segment 28] GPU Memory Start = 938.30 MB
# [Segment 28] GPU Memory End   = 941.47 MB
# [Segment 28] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 29] Training Time = 0.36 sec
# [Segment 29] GPU Memory Start = 941.47 MB
# [Segment 29] GPU Memory End   = 944.64 MB
# [Segment 29] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 30] Training Time = 0.67 sec
# [Segment 30] GPU Memory Start = 944.64 MB
# [Segment 30] GPU Memory End   = 947.81 MB
# [Segment 30] GPU Peak Memory  = 950.98 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 31] Training Time = 0.68 sec
# [Segment 31] GPU Memory Start = 947.81 MB
# [Segment 31] GPU Memory End   = 950.98 MB
# [Segment 31] GPU Peak Memory  = 954.15 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 32] Training Time = 0.86 sec
# [Segment 32] GPU Memory Start = 950.98 MB
# [Segment 32] GPU Memory End   = 954.15 MB
# [Segment 32] GPU Peak Memory  = 957.32 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 33] Training Time = 0.68 sec
# [Segment 33] GPU Memory Start = 925.62 MB
# [Segment 33] GPU Memory End   = 928.79 MB
# [Segment 33] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 34] Training Time = 0.39 sec
# [Segment 34] GPU Memory Start = 928.79 MB
# [Segment 34] GPU Memory End   = 931.96 MB
# [Segment 34] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 35] Training Time = 0.76 sec
# [Segment 35] GPU Memory Start = 931.96 MB
# [Segment 35] GPU Memory End   = 935.13 MB
# [Segment 35] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 36] Training Time = 0.61 sec
# [Segment 36] GPU Memory Start = 935.13 MB
# [Segment 36] GPU Memory End   = 938.30 MB
# [Segment 36] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 37] Training Time = 0.31 sec
# [Segment 37] GPU Memory Start = 938.30 MB
# [Segment 37] GPU Memory End   = 941.47 MB
# [Segment 37] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 38] Training Time = 0.31 sec
# [Segment 38] GPU Memory Start = 941.47 MB
# [Segment 38] GPU Memory End   = 944.64 MB
# [Segment 38] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 39] Training Time = 0.31 sec
# [Segment 39] GPU Memory Start = 944.64 MB
# [Segment 39] GPU Memory End   = 947.81 MB
# [Segment 39] GPU Peak Memory  = 950.98 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 40] Training Time = 0.31 sec
# [Segment 40] GPU Memory Start = 947.81 MB
# [Segment 40] GPU Memory End   = 950.98 MB
# [Segment 40] GPU Peak Memory  = 954.15 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 41] Training Time = 0.33 sec
# [Segment 41] GPU Memory Start = 950.98 MB
# [Segment 41] GPU Memory End   = 954.15 MB
# [Segment 41] GPU Peak Memory  = 957.32 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 42] Training Time = 0.74 sec
# [Segment 42] GPU Memory Start = 954.15 MB
# [Segment 42] GPU Memory End   = 928.79 MB
# [Segment 42] GPU Peak Memory  = 957.32 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 43] Training Time = 0.57 sec
# [Segment 43] GPU Memory Start = 928.79 MB
# [Segment 43] GPU Memory End   = 931.96 MB
# [Segment 43] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 44] Training Time = 0.50 sec
# [Segment 44] GPU Memory Start = 931.96 MB
# [Segment 44] GPU Memory End   = 935.13 MB
# [Segment 44] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 45] Training Time = 0.71 sec
# [Segment 45] GPU Memory Start = 935.13 MB
# [Segment 45] GPU Memory End   = 938.30 MB
# [Segment 45] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 46] Training Time = 0.42 sec
# [Segment 46] GPU Memory Start = 938.30 MB
# [Segment 46] GPU Memory End   = 941.47 MB
# [Segment 46] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 47] Training Time = 0.67 sec
# [Segment 47] GPU Memory Start = 941.47 MB
# [Segment 47] GPU Memory End   = 944.64 MB
# [Segment 47] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 48] Training Time = 0.39 sec
# [Segment 48] GPU Memory Start = 944.64 MB
# [Segment 48] GPU Memory End   = 947.81 MB
# [Segment 48] GPU Peak Memory  = 950.98 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 49] Training Time = 0.39 sec
# [Segment 49] GPU Memory Start = 947.81 MB
# [Segment 49] GPU Memory End   = 950.98 MB
# [Segment 49] GPU Peak Memory  = 954.15 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 50] Training Time = 0.75 sec
# [Segment 50] GPU Memory Start = 950.98 MB
# [Segment 50] GPU Memory End   = 954.15 MB
# [Segment 50] GPU Peak Memory  = 957.32 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 51] Training Time = 0.82 sec
# [Segment 51] GPU Memory Start = 954.15 MB
# [Segment 51] GPU Memory End   = 957.32 MB
# [Segment 51] GPU Peak Memory  = 960.49 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 52] Training Time = 0.80 sec
# [Segment 52] GPU Memory Start = 916.11 MB
# [Segment 52] GPU Memory End   = 919.28 MB
# [Segment 52] GPU Peak Memory  = 922.45 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 53] Training Time = 0.39 sec
# [Segment 53] GPU Memory Start = 919.28 MB
# [Segment 53] GPU Memory End   = 922.45 MB
# [Segment 53] GPU Peak Memory  = 925.62 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 54] Training Time = 0.39 sec
# [Segment 54] GPU Memory Start = 922.45 MB
# [Segment 54] GPU Memory End   = 925.62 MB
# [Segment 54] GPU Peak Memory  = 928.79 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 55] Training Time = 0.71 sec
# [Segment 55] GPU Memory Start = 925.62 MB
# [Segment 55] GPU Memory End   = 928.79 MB
# [Segment 55] GPU Peak Memory  = 931.96 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 56] Training Time = 0.69 sec
# [Segment 56] GPU Memory Start = 928.79 MB
# [Segment 56] GPU Memory End   = 931.96 MB
# [Segment 56] GPU Peak Memory  = 935.13 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 57] Training Time = 0.81 sec
# [Segment 57] GPU Memory Start = 931.96 MB
# [Segment 57] GPU Memory End   = 935.13 MB
# [Segment 57] GPU Peak Memory  = 938.30 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 58] Training Time = 0.62 sec
# [Segment 58] GPU Memory Start = 935.13 MB
# [Segment 58] GPU Memory End   = 938.30 MB
# [Segment 58] GPU Peak Memory  = 941.47 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 59] Training Time = 0.79 sec
# [Segment 59] GPU Memory Start = 938.30 MB
# [Segment 59] GPU Memory End   = 941.47 MB
# [Segment 59] GPU Peak Memory  = 944.64 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.4551 MB
#   yb per batch = 0.0879 MB, total = 11.6895 MB
#   pv per batch = 0.0293 MB, total = 3.8965 MB
# [Segment 60] Training Time = 0.39 sec
# [Segment 60] GPU Memory Start = 941.47 MB
# [Segment 60] GPU Memory End   = 944.64 MB
# [Segment 60] GPU Peak Memory  = 947.81 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ER/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ER/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ER/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ER_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:2.9874963760375977  MAE:1.5658378601074219
# ▶ seg0  mean  MSE:2.9874963760375977  MAE:1.5658378601074219
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:3.0822064876556396  MAE:1.5882242918014526
# ▶ seg1  mean  MSE:3.0822064876556396  MAE:1.5882242918014526
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:2.7914395332336426  MAE:1.5333950519561768
# ▶ seg2  mean  MSE:2.7914395332336426  MAE:1.5333950519561768
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:2.8824315071105957  MAE:1.5408192873001099
# ▶ seg3  mean  MSE:2.8824315071105957  MAE:1.5408192873001099
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:2.8808093070983887  MAE:1.5451956987380981
# ▶ seg4  mean  MSE:2.8808093070983887  MAE:1.5451956987380981
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:3.051833391189575  MAE:1.589316964149475
# ▶ seg5  mean  MSE:3.051833391189575  MAE:1.589316964149475
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:2.6843619346618652  MAE:1.4918181896209717
# ▶ seg6  mean  MSE:2.6843619346618652  MAE:1.4918181896209717
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:3.251586437225342  MAE:1.636399507522583
# ▶ seg7  mean  MSE:3.251586437225342  MAE:1.636399507522583
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:2.9518373012542725  MAE:1.5750075578689575
# ▶ seg8  mean  MSE:2.9518373012542725  MAE:1.5750075578689575
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:3.1328554153442383  MAE:1.6167067289352417
# ▶ seg9  mean  MSE:3.1328554153442383  MAE:1.6167067289352417
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:3.003880500793457  MAE:1.5848215818405151
# ▶ seg10  mean  MSE:3.003880500793457  MAE:1.5848215818405151
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:2.832000255584717  MAE:1.5340417623519897
# ▶ seg11  mean  MSE:2.832000255584717  MAE:1.5340417623519897
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:2.7476961612701416  MAE:1.5238080024719238
# ▶ seg12  mean  MSE:2.7476961612701416  MAE:1.5238080024719238
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:2.964745283126831  MAE:1.5622646808624268
# ▶ seg13  mean  MSE:2.964745283126831  MAE:1.5622646808624268
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:2.8317055702209473  MAE:1.5300663709640503
# ▶ seg14  mean  MSE:2.8317055702209473  MAE:1.5300663709640503
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:3.250514030456543  MAE:1.644579529762268
# ▶ seg15  mean  MSE:3.250514030456543  MAE:1.644579529762268
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:2.6794991493225098  MAE:1.476374864578247
# ▶ seg16  mean  MSE:2.6794991493225098  MAE:1.476374864578247
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:2.6937689781188965  MAE:1.487877368927002
# ▶ seg17  mean  MSE:2.6937689781188965  MAE:1.487877368927002
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:2.9261868000030518  MAE:1.5646194219589233
# ▶ seg18  mean  MSE:2.9261868000030518  MAE:1.5646194219589233
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:3.18487548828125  MAE:1.6260465383529663
# ▶ seg19  mean  MSE:3.18487548828125  MAE:1.6260465383529663
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:3.477574110031128  MAE:1.6926169395446777
# ▶ seg20  mean  MSE:3.477574110031128  MAE:1.6926169395446777
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:2.931676149368286  MAE:1.5489673614501953
# ▶ seg21  mean  MSE:2.931676149368286  MAE:1.5489673614501953
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:2.807140350341797  MAE:1.5237900018692017
# ▶ seg22  mean  MSE:2.807140350341797  MAE:1.5237900018692017
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:2.9373726844787598  MAE:1.5659452676773071
# ▶ seg23  mean  MSE:2.9373726844787598  MAE:1.5659452676773071
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:2.9495437145233154  MAE:1.5673104524612427
# ▶ seg24  mean  MSE:2.9495437145233154  MAE:1.5673104524612427
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:2.7704150676727295  MAE:1.517232060432434
# ▶ seg25  mean  MSE:2.7704150676727295  MAE:1.517232060432434
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:2.85752272605896  MAE:1.5255711078643799
# ▶ seg26  mean  MSE:2.85752272605896  MAE:1.5255711078643799
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:2.5705394744873047  MAE:1.4513918161392212
# ▶ seg27  mean  MSE:2.5705394744873047  MAE:1.4513918161392212
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:3.039905309677124  MAE:1.5969572067260742
# ▶ seg28  mean  MSE:3.039905309677124  MAE:1.5969572067260742
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:2.9012038707733154  MAE:1.5427231788635254
# ▶ seg29  mean  MSE:2.9012038707733154  MAE:1.5427231788635254
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:2.5800368785858154  MAE:1.4483976364135742
# ▶ seg30  mean  MSE:2.5800368785858154  MAE:1.4483976364135742
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:3.028578042984009  MAE:1.5885199308395386
# ▶ seg31  mean  MSE:3.028578042984009  MAE:1.5885199308395386
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:2.884242296218872  MAE:1.556901454925537
# ▶ seg32  mean  MSE:2.884242296218872  MAE:1.556901454925537
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:2.905165672302246  MAE:1.546641230583191
# ▶ seg33  mean  MSE:2.905165672302246  MAE:1.546641230583191
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:2.7485647201538086  MAE:1.5223579406738281
# ▶ seg34  mean  MSE:2.7485647201538086  MAE:1.5223579406738281
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:2.1505794525146484  MAE:1.3343160152435303
# ▶ seg35  mean  MSE:2.1505794525146484  MAE:1.3343160152435303
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:2.3356590270996094  MAE:1.3952819108963013
# ▶ seg36  mean  MSE:2.3356590270996094  MAE:1.3952819108963013
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:3.2392923831939697  MAE:1.6386935710906982
# ▶ seg37  mean  MSE:3.2392923831939697  MAE:1.6386935710906982
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:2.487938165664673  MAE:1.4380717277526855
# ▶ seg38  mean  MSE:2.487938165664673  MAE:1.4380717277526855
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:2.3807578086853027  MAE:1.3988579511642456
# ▶ seg39  mean  MSE:2.3807578086853027  MAE:1.3988579511642456
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:2.4327125549316406  MAE:1.4308432340621948
# ▶ seg40  mean  MSE:2.4327125549316406  MAE:1.4308432340621948
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:2.3680901527404785  MAE:1.397414207458496
# ▶ seg41  mean  MSE:2.3680901527404785  MAE:1.397414207458496
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:2.6858601570129395  MAE:1.491942286491394
# ▶ seg42  mean  MSE:2.6858601570129395  MAE:1.491942286491394
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:2.292008399963379  MAE:1.379477620124817
# ▶ seg43  mean  MSE:2.292008399963379  MAE:1.379477620124817
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:2.557680606842041  MAE:1.4463796615600586
# ▶ seg44  mean  MSE:2.557680606842041  MAE:1.4463796615600586
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:2.708785057067871  MAE:1.4978708028793335
# ▶ seg45  mean  MSE:2.708785057067871  MAE:1.4978708028793335
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:2.486219882965088  MAE:1.4327555894851685
# ▶ seg46  mean  MSE:2.486219882965088  MAE:1.4327555894851685
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:2.6748979091644287  MAE:1.4757806062698364
# ▶ seg47  mean  MSE:2.6748979091644287  MAE:1.4757806062698364
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:2.9990432262420654  MAE:1.5618449449539185
# ▶ seg48  mean  MSE:2.9990432262420654  MAE:1.5618449449539185
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:3.146946430206299  MAE:1.599453330039978
# ▶ seg49  mean  MSE:3.146946430206299  MAE:1.599453330039978
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:2.7513880729675293  MAE:1.515876054763794
# ▶ seg50  mean  MSE:2.7513880729675293  MAE:1.515876054763794
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:2.168795585632324  MAE:1.3295966386795044
# ▶ seg51  mean  MSE:2.168795585632324  MAE:1.3295966386795044
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:2.4947524070739746  MAE:1.436977744102478
# ▶ seg52  mean  MSE:2.4947524070739746  MAE:1.436977744102478
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:2.8654489517211914  MAE:1.5283914804458618
# ▶ seg53  mean  MSE:2.8654489517211914  MAE:1.5283914804458618
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:2.4397473335266113  MAE:1.4183454513549805
# ▶ seg54  mean  MSE:2.4397473335266113  MAE:1.4183454513549805
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:2.8693947792053223  MAE:1.5249557495117188
# ▶ seg55  mean  MSE:2.8693947792053223  MAE:1.5249557495117188
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:2.7904086112976074  MAE:1.513710618019104
# ▶ seg56  mean  MSE:2.7904086112976074  MAE:1.513710618019104
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:2.9049997329711914  MAE:1.541335105895996
# ▶ seg57  mean  MSE:2.9049997329711914  MAE:1.541335105895996
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:2.6613128185272217  MAE:1.4810149669647217
# ▶ seg58  mean  MSE:2.6613128185272217  MAE:1.4810149669647217
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:2.796494960784912  MAE:1.5141602754592896
# ▶ seg59  mean  MSE:2.796494960784912  MAE:1.5141602754592896
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:2.7828760147094727  MAE:1.5119884014129639
# ▶ seg60  mean  MSE:2.7828760147094727  MAE:1.5119884014129639
#
# seg10 ch0 MSE : 3.0038805

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ER_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:2.847043752670288  MAE:1.5503157377243042
# ▶ seg0  mean  MSE:2.847043752670288  MAE:1.5503157377243042
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:3.094935894012451  MAE:1.6186411380767822
# ▶ seg1  mean  MSE:3.094935894012451  MAE:1.6186411380767822
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:2.931551694869995  MAE:1.5630570650100708
# ▶ seg2  mean  MSE:2.931551694869995  MAE:1.5630570650100708
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:3.187904119491577  MAE:1.6294028759002686
# ▶ seg3  mean  MSE:3.187904119491577  MAE:1.6294028759002686
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:2.731562852859497  MAE:1.5013866424560547
# ▶ seg4  mean  MSE:2.731562852859497  MAE:1.5013866424560547
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:2.791175365447998  MAE:1.532204508781433
# ▶ seg5  mean  MSE:2.791175365447998  MAE:1.532204508781433
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:3.296172618865967  MAE:1.6593701839447021
# ▶ seg6  mean  MSE:3.296172618865967  MAE:1.6593701839447021
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:2.4710965156555176  MAE:1.438579797744751
# ▶ seg7  mean  MSE:2.4710965156555176  MAE:1.438579797744751
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:2.890151262283325  MAE:1.5685094594955444
# ▶ seg8  mean  MSE:2.890151262283325  MAE:1.5685094594955444
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:2.6117019653320312  MAE:1.4833317995071411
# ▶ seg9  mean  MSE:2.6117019653320312  MAE:1.4833317995071411
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:2.8334898948669434  MAE:1.544634222984314
# ▶ seg10  mean  MSE:2.8334898948669434  MAE:1.544634222984314
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:2.7119638919830322  MAE:1.492762565612793
# ▶ seg11  mean  MSE:2.7119638919830322  MAE:1.492762565612793
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:3.267939567565918  MAE:1.65341055393219
# ▶ seg12  mean  MSE:3.267939567565918  MAE:1.65341055393219
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:3.0271899700164795  MAE:1.5846140384674072
# ▶ seg13  mean  MSE:3.0271899700164795  MAE:1.5846140384674072
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:2.6491451263427734  MAE:1.4943946599960327
# ▶ seg14  mean  MSE:2.6491451263427734  MAE:1.4943946599960327
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:3.0582759380340576  MAE:1.6178758144378662
# ▶ seg15  mean  MSE:3.0582759380340576  MAE:1.6178758144378662
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:3.1667323112487793  MAE:1.6333237886428833
# ▶ seg16  mean  MSE:3.1667323112487793  MAE:1.6333237886428833
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:2.973564624786377  MAE:1.5871169567108154
# ▶ seg17  mean  MSE:2.973564624786377  MAE:1.5871169567108154
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:3.037428617477417  MAE:1.5996134281158447
# ▶ seg18  mean  MSE:3.037428617477417  MAE:1.5996134281158447
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:3.406378984451294  MAE:1.6911273002624512
# ▶ seg19  mean  MSE:3.406378984451294  MAE:1.6911273002624512
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:3.089341402053833  MAE:1.595638632774353
# ▶ seg20  mean  MSE:3.089341402053833  MAE:1.595638632774353
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:3.25138783454895  MAE:1.650635838508606
# ▶ seg21  mean  MSE:3.25138783454895  MAE:1.650635838508606
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:2.8423092365264893  MAE:1.5390321016311646
# ▶ seg22  mean  MSE:2.8423092365264893  MAE:1.5390321016311646
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:2.7474286556243896  MAE:1.5016604661941528
# ▶ seg23  mean  MSE:2.7474286556243896  MAE:1.5016604661941528
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:3.0860931873321533  MAE:1.6243395805358887
# ▶ seg24  mean  MSE:3.0860931873321533  MAE:1.6243395805358887
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:2.5467519760131836  MAE:1.4611915349960327
# ▶ seg25  mean  MSE:2.5467519760131836  MAE:1.4611915349960327
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:3.4282376766204834  MAE:1.6838268041610718
# ▶ seg26  mean  MSE:3.4282376766204834  MAE:1.6838268041610718
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:2.6648805141448975  MAE:1.4814198017120361
# ▶ seg27  mean  MSE:2.6648805141448975  MAE:1.4814198017120361
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:2.6551551818847656  MAE:1.5010738372802734
# ▶ seg28  mean  MSE:2.6551551818847656  MAE:1.5010738372802734
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:2.6144654750823975  MAE:1.4742661714553833
# ▶ seg29  mean  MSE:2.6144654750823975  MAE:1.4742661714553833
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:3.1740996837615967  MAE:1.6213796138763428
# ▶ seg30  mean  MSE:3.1740996837615967  MAE:1.6213796138763428
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:2.877605438232422  MAE:1.5538371801376343
# ▶ seg31  mean  MSE:2.877605438232422  MAE:1.5538371801376343
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:2.7969894409179688  MAE:1.5314728021621704
# ▶ seg32  mean  MSE:2.7969894409179688  MAE:1.5314728021621704
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:2.226980686187744  MAE:1.3542028665542603
# ▶ seg33  mean  MSE:2.226980686187744  MAE:1.3542028665542603
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:2.76082706451416  MAE:1.5186219215393066
# ▶ seg34  mean  MSE:2.76082706451416  MAE:1.5186219215393066
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:2.82131290435791  MAE:1.5468474626541138
# ▶ seg35  mean  MSE:2.82131290435791  MAE:1.5468474626541138
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:2.4560787677764893  MAE:1.435310959815979
# ▶ seg36  mean  MSE:2.4560787677764893  MAE:1.435310959815979
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:2.4130122661590576  MAE:1.4236412048339844
# ▶ seg37  mean  MSE:2.4130122661590576  MAE:1.4236412048339844
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:2.3376688957214355  MAE:1.3887423276901245
# ▶ seg38  mean  MSE:2.3376688957214355  MAE:1.3887423276901245
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:2.869175910949707  MAE:1.5507320165634155
# ▶ seg39  mean  MSE:2.869175910949707  MAE:1.5507320165634155
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:2.6736905574798584  MAE:1.4903892278671265
# ▶ seg40  mean  MSE:2.6736905574798584  MAE:1.4903892278671265
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:2.895998239517212  MAE:1.5617517232894897
# ▶ seg41  mean  MSE:2.895998239517212  MAE:1.5617517232894897
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:2.377492666244507  MAE:1.3891570568084717
# ▶ seg42  mean  MSE:2.377492666244507  MAE:1.3891570568084717
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:3.226771354675293  MAE:1.654106855392456
# ▶ seg43  mean  MSE:3.226771354675293  MAE:1.654106855392456
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:2.60506010055542  MAE:1.4808114767074585
# ▶ seg44  mean  MSE:2.60506010055542  MAE:1.4808114767074585
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:2.6517584323883057  MAE:1.4920623302459717
# ▶ seg45  mean  MSE:2.6517584323883057  MAE:1.4920623302459717
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:2.5806822776794434  MAE:1.4668774604797363
# ▶ seg46  mean  MSE:2.5806822776794434  MAE:1.4668774604797363
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:2.3560733795166016  MAE:1.3926392793655396
# ▶ seg47  mean  MSE:2.3560733795166016  MAE:1.3926392793655396
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:3.2316927909851074  MAE:1.6303843259811401
# ▶ seg48  mean  MSE:3.2316927909851074  MAE:1.6303843259811401
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:2.8044161796569824  MAE:1.5195876359939575
# ▶ seg49  mean  MSE:2.8044161796569824  MAE:1.5195876359939575
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:3.4425628185272217  MAE:1.6781373023986816
# ▶ seg50  mean  MSE:3.4425628185272217  MAE:1.6781373023986816
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:2.8488106727600098  MAE:1.5347042083740234
# ▶ seg51  mean  MSE:2.8488106727600098  MAE:1.5347042083740234
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:2.4838457107543945  MAE:1.4291410446166992
# ▶ seg52  mean  MSE:2.4838457107543945  MAE:1.4291410446166992
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:3.0525496006011963  MAE:1.6018978357315063
# ▶ seg53  mean  MSE:3.0525496006011963  MAE:1.6018978357315063
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:2.7300357818603516  MAE:1.5054396390914917
# ▶ seg54  mean  MSE:2.7300357818603516  MAE:1.5054396390914917
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:2.3320910930633545  MAE:1.3876134157180786
# ▶ seg55  mean  MSE:2.3320910930633545  MAE:1.3876134157180786
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:2.790637254714966  MAE:1.5108070373535156
# ▶ seg56  mean  MSE:2.790637254714966  MAE:1.5108070373535156
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:3.163224935531616  MAE:1.6237974166870117
# ▶ seg57  mean  MSE:3.163224935531616  MAE:1.6237974166870117
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:2.856018543243408  MAE:1.5473333597183228
# ▶ seg58  mean  MSE:2.856018543243408  MAE:1.5473333597183228
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:2.7063963413238525  MAE:1.4961541891098022
# ▶ seg59  mean  MSE:2.7063963413238525  MAE:1.4961541891098022
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:3.064683198928833  MAE:1.614811897277832
# ▶ seg60  mean  MSE:3.064683198928833  MAE:1.614811897277832
#
# seg10 ch0 MSE : 2.83349

# %% [markdown]
# # 2nd Inference for Test Set

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 720
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ER_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:1.4671940803527832  MAE:0.9530590772628784
# ▶ seg0  mean  MSE:1.4671940803527832  MAE:0.9530590772628784
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:1.6236211061477661  MAE:1.0103800296783447
# ▶ seg1  mean  MSE:1.6236211061477661  MAE:1.0103800296783447
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:1.181715726852417  MAE:0.8507741689682007
# ▶ seg2  mean  MSE:1.181715726852417  MAE:0.8507741689682007
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:1.3495397567749023  MAE:0.9146645069122314
# ▶ seg3  mean  MSE:1.3495397567749023  MAE:0.9146645069122314
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:1.2739530801773071  MAE:0.8879501223564148
# ▶ seg4  mean  MSE:1.2739530801773071  MAE:0.8879501223564148
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:1.5308109521865845  MAE:0.9818216562271118
# ▶ seg5  mean  MSE:1.5308109521865845  MAE:0.9818216562271118
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:1.0882568359375  MAE:0.8185438513755798
# ▶ seg6  mean  MSE:1.0882568359375  MAE:0.8185438513755798
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:1.7744865417480469  MAE:1.0611779689788818
# ▶ seg7  mean  MSE:1.7744865417480469  MAE:1.0611779689788818
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:1.3033214807510376  MAE:0.9027541279792786
# ▶ seg8  mean  MSE:1.3033214807510376  MAE:0.9027541279792786
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:1.535271406173706  MAE:0.983726441860199
# ▶ seg9  mean  MSE:1.535271406173706  MAE:0.983726441860199
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:1.3672242164611816  MAE:0.9321229457855225
# ▶ seg10  mean  MSE:1.3672242164611816  MAE:0.9321229457855225
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:1.2250146865844727  MAE:0.8673022985458374
# ▶ seg11  mean  MSE:1.2250146865844727  MAE:0.8673022985458374
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:1.202506184577942  MAE:0.8640996217727661
# ▶ seg12  mean  MSE:1.202506184577942  MAE:0.8640996217727661
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:1.4312618970870972  MAE:0.9455568194389343
# ▶ seg13  mean  MSE:1.4312618970870972  MAE:0.9455568194389343
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:1.2906783819198608  MAE:0.8880860805511475
# ▶ seg14  mean  MSE:1.2906783819198608  MAE:0.8880860805511475
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:1.8451865911483765  MAE:1.0902485847473145
# ▶ seg15  mean  MSE:1.8451865911483765  MAE:1.0902485847473145
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:1.156558871269226  MAE:0.841046154499054
# ▶ seg16  mean  MSE:1.156558871269226  MAE:0.841046154499054
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:1.166171669960022  MAE:0.8471540808677673
# ▶ seg17  mean  MSE:1.166171669960022  MAE:0.8471540808677673
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:1.3577923774719238  MAE:0.9269834756851196
# ▶ seg18  mean  MSE:1.3577923774719238  MAE:0.9269834756851196
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:1.7214010953903198  MAE:1.051717758178711
# ▶ seg19  mean  MSE:1.7214010953903198  MAE:1.051717758178711
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:2.083653211593628  MAE:1.171061635017395
# ▶ seg20  mean  MSE:2.083653211593628  MAE:1.171061635017395
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:1.4048213958740234  MAE:0.9350351691246033
# ▶ seg21  mean  MSE:1.4048213958740234  MAE:0.9350351691246033
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:1.2564587593078613  MAE:0.8779689073562622
# ▶ seg22  mean  MSE:1.2564587593078613  MAE:0.8779689073562622
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:1.5145646333694458  MAE:0.9835957884788513
# ▶ seg23  mean  MSE:1.5145646333694458  MAE:0.9835957884788513
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:1.530403971672058  MAE:0.9864388704299927
# ▶ seg24  mean  MSE:1.530403971672058  MAE:0.9864388704299927
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:1.2945432662963867  MAE:0.8971847295761108
# ▶ seg25  mean  MSE:1.2945432662963867  MAE:0.8971847295761108
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:1.4651353359222412  MAE:0.951884388923645
# ▶ seg26  mean  MSE:1.4651353359222412  MAE:0.951884388923645
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:1.1252163648605347  MAE:0.8290311694145203
# ▶ seg27  mean  MSE:1.1252163648605347  MAE:0.8290311694145203
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:1.6403160095214844  MAE:1.0335005521774292
# ▶ seg28  mean  MSE:1.6403160095214844  MAE:1.0335005521774292
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:1.5708060264587402  MAE:0.9965826869010925
# ▶ seg29  mean  MSE:1.5708060264587402  MAE:0.9965826869010925
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:1.229865550994873  MAE:0.8685373663902283
# ▶ seg30  mean  MSE:1.229865550994873  MAE:0.8685373663902283
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:1.7949823141098022  MAE:1.085578441619873
# ▶ seg31  mean  MSE:1.7949823141098022  MAE:1.085578441619873
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:1.5507121086120605  MAE:1.005430817604065
# ▶ seg32  mean  MSE:1.5507121086120605  MAE:1.005430817604065
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:1.5640268325805664  MAE:1.0012437105178833
# ▶ seg33  mean  MSE:1.5640268325805664  MAE:1.0012437105178833
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:1.342063307762146  MAE:0.9285658001899719
# ▶ seg34  mean  MSE:1.342063307762146  MAE:0.9285658001899719
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.789951741695404  MAE:0.6866859793663025
# ▶ seg35  mean  MSE:0.789951741695404  MAE:0.6866859793663025
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.9374629259109497  MAE:0.7495977878570557
# ▶ seg36  mean  MSE:0.9374629259109497  MAE:0.7495977878570557
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:2.1078994274139404  MAE:1.1934518814086914
# ▶ seg37  mean  MSE:2.1078994274139404  MAE:1.1934518814086914
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:1.0838227272033691  MAE:0.8144034743309021
# ▶ seg38  mean  MSE:1.0838227272033691  MAE:0.8144034743309021
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.9925562739372253  MAE:0.7816811800003052
# ▶ seg39  mean  MSE:0.9925562739372253  MAE:0.7816811800003052
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:1.0377238988876343  MAE:0.8078002333641052
# ▶ seg40  mean  MSE:1.0377238988876343  MAE:0.8078002333641052
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.9730404615402222  MAE:0.7775073647499084
# ▶ seg41  mean  MSE:0.9730404615402222  MAE:0.7775073647499084
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:1.2728426456451416  MAE:0.8934112787246704
# ▶ seg42  mean  MSE:1.2728426456451416  MAE:0.8934112787246704
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.8887197971343994  MAE:0.733788788318634
# ▶ seg43  mean  MSE:0.8887197971343994  MAE:0.733788788318634
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:1.2236807346343994  MAE:0.8689103126525879
# ▶ seg44  mean  MSE:1.2236807346343994  MAE:0.8689103126525879
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:1.393903136253357  MAE:0.9452722668647766
# ▶ seg45  mean  MSE:1.393903136253357  MAE:0.9452722668647766
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:1.1329408884048462  MAE:0.8432283997535706
# ▶ seg46  mean  MSE:1.1329408884048462  MAE:0.8432283997535706
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:1.3435057401657104  MAE:0.9198147058486938
# ▶ seg47  mean  MSE:1.3435057401657104  MAE:0.9198147058486938
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:1.8199396133422852  MAE:1.0837002992630005
# ▶ seg48  mean  MSE:1.8199396133422852  MAE:1.0837002992630005
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:2.0711398124694824  MAE:1.162266492843628
# ▶ seg49  mean  MSE:2.0711398124694824  MAE:1.162266492843628
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:1.4677133560180664  MAE:0.9731568694114685
# ▶ seg50  mean  MSE:1.4677133560180664  MAE:0.9731568694114685
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.875535786151886  MAE:0.7333017587661743
# ▶ seg51  mean  MSE:0.875535786151886  MAE:0.7333017587661743
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:1.1706970930099487  MAE:0.8559257388114929
# ▶ seg52  mean  MSE:1.1706970930099487  MAE:0.8559257388114929
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:1.637386679649353  MAE:1.0203806161880493
# ▶ seg53  mean  MSE:1.637386679649353  MAE:1.0203806161880493
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:1.0964521169662476  MAE:0.8313419818878174
# ▶ seg54  mean  MSE:1.0964521169662476  MAE:0.8313419818878174
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:1.6129474639892578  MAE:1.0141699314117432
# ▶ seg55  mean  MSE:1.6129474639892578  MAE:1.0141699314117432
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:1.427074670791626  MAE:0.9515246152877808
# ▶ seg56  mean  MSE:1.427074670791626  MAE:0.9515246152877808
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:1.5775682926177979  MAE:1.0047273635864258
# ▶ seg57  mean  MSE:1.5775682926177979  MAE:1.0047273635864258
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:1.234845519065857  MAE:0.8809760808944702
# ▶ seg58  mean  MSE:1.234845519065857  MAE:0.8809760808944702
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:1.3899853229522705  MAE:0.937641441822052
# ▶ seg59  mean  MSE:1.3899853229522705  MAE:0.937641441822052
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:1.42257559299469  MAE:0.9501794576644897
# ▶ seg60  mean  MSE:1.42257559299469  MAE:0.9501794576644897
#
# seg10 ch0 MSE : 1.3672242

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 720
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ER_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:1.2264543771743774  MAE:0.8780356645584106
# ▶ seg0  mean  MSE:1.2264543771743774  MAE:0.8780356645584106
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:1.400291919708252  MAE:0.9451783895492554
# ▶ seg1  mean  MSE:1.400291919708252  MAE:0.9451783895492554
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:1.3234249353408813  MAE:0.8907818794250488
# ▶ seg2  mean  MSE:1.3234249353408813  MAE:0.8907818794250488
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:1.703515648841858  MAE:1.0486620664596558
# ▶ seg3  mean  MSE:1.703515648841858  MAE:1.0486620664596558
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:1.0507829189300537  MAE:0.7997484803199768
# ▶ seg4  mean  MSE:1.0507829189300537  MAE:0.7997484803199768
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:1.1502058506011963  MAE:0.842217206954956
# ▶ seg5  mean  MSE:1.1502058506011963  MAE:0.842217206954956
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:1.7563626766204834  MAE:1.0611894130706787
# ▶ seg6  mean  MSE:1.7563626766204834  MAE:1.0611894130706787
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.8553141951560974  MAE:0.7216385006904602
# ▶ seg7  mean  MSE:0.8553141951560974  MAE:0.7216385006904602
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:1.2066622972488403  MAE:0.8702520728111267
# ▶ seg8  mean  MSE:1.2066622972488403  MAE:0.8702520728111267
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.9495850205421448  MAE:0.758897066116333
# ▶ seg9  mean  MSE:0.9495850205421448  MAE:0.758897066116333
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:1.2133331298828125  MAE:0.8661428093910217
# ▶ seg10  mean  MSE:1.2133331298828125  MAE:0.8661428093910217
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:1.1859867572784424  MAE:0.8528974056243896
# ▶ seg11  mean  MSE:1.1859867572784424  MAE:0.8528974056243896
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:1.7062489986419678  MAE:1.051999568939209
# ▶ seg12  mean  MSE:1.7062489986419678  MAE:1.051999568939209
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:1.4156279563903809  MAE:0.9414807558059692
# ▶ seg13  mean  MSE:1.4156279563903809  MAE:0.9414807558059692
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.924669086933136  MAE:0.7511361241340637
# ▶ seg14  mean  MSE:0.924669086933136  MAE:0.7511361241340637
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:1.360008716583252  MAE:0.9386684894561768
# ▶ seg15  mean  MSE:1.360008716583252  MAE:0.9386684894561768
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:1.6398677825927734  MAE:1.02909517288208
# ▶ seg16  mean  MSE:1.6398677825927734  MAE:1.02909517288208
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:1.2495837211608887  MAE:0.880783200263977
# ▶ seg17  mean  MSE:1.2495837211608887  MAE:0.880783200263977
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:1.4179954528808594  MAE:0.9468815326690674
# ▶ seg18  mean  MSE:1.4179954528808594  MAE:0.9468815326690674
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:1.874459981918335  MAE:1.105178952217102
# ▶ seg19  mean  MSE:1.874459981918335  MAE:1.105178952217102
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:1.499552845954895  MAE:0.9627504944801331
# ▶ seg20  mean  MSE:1.499552845954895  MAE:0.9627504944801331
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:1.7381776571273804  MAE:1.062662959098816
# ▶ seg21  mean  MSE:1.7381776571273804  MAE:1.062662959098816
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:1.2715293169021606  MAE:0.8922330141067505
# ▶ seg22  mean  MSE:1.2715293169021606  MAE:0.8922330141067505
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:1.2298402786254883  MAE:0.8704372644424438
# ▶ seg23  mean  MSE:1.2298402786254883  MAE:0.8704372644424438
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:1.5798802375793457  MAE:1.0230299234390259
# ▶ seg24  mean  MSE:1.5798802375793457  MAE:1.0230299234390259
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.9187982082366943  MAE:0.7484951019287109
# ▶ seg25  mean  MSE:0.9187982082366943  MAE:0.7484951019287109
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:2.0650475025177  MAE:1.1614627838134766
# ▶ seg26  mean  MSE:2.0650475025177  MAE:1.1614627838134766
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:1.1008641719818115  MAE:0.8209762573242188
# ▶ seg27  mean  MSE:1.1008641719818115  MAE:0.8209762573242188
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:1.0533182621002197  MAE:0.8017898201942444
# ▶ seg28  mean  MSE:1.0533182621002197  MAE:0.8017898201942444
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:1.0543252229690552  MAE:0.8062970042228699
# ▶ seg29  mean  MSE:1.0543252229690552  MAE:0.8062970042228699
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:1.7034152746200562  MAE:1.045371413230896
# ▶ seg30  mean  MSE:1.7034152746200562  MAE:1.045371413230896
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:1.3447864055633545  MAE:0.9214066863059998
# ▶ seg31  mean  MSE:1.3447864055633545  MAE:0.9214066863059998
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:1.2246211767196655  MAE:0.8724262118339539
# ▶ seg32  mean  MSE:1.2246211767196655  MAE:0.8724262118339539
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.7724519371986389  MAE:0.6777979135513306
# ▶ seg33  mean  MSE:0.7724519371986389  MAE:0.6777979135513306
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:1.2182433605194092  MAE:0.8704631328582764
# ▶ seg34  mean  MSE:1.2182433605194092  MAE:0.8704631328582764
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:1.3491312265396118  MAE:0.9301692843437195
# ▶ seg35  mean  MSE:1.3491312265396118  MAE:0.9301692843437195
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.8915928602218628  MAE:0.738425612449646
# ▶ seg36  mean  MSE:0.8915928602218628  MAE:0.738425612449646
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.8517166972160339  MAE:0.7194177508354187
# ▶ seg37  mean  MSE:0.8517166972160339  MAE:0.7194177508354187
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.8261632323265076  MAE:0.7058742642402649
# ▶ seg38  mean  MSE:0.8261632323265076  MAE:0.7058742642402649
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:1.3547406196594238  MAE:0.9276098012924194
# ▶ seg39  mean  MSE:1.3547406196594238  MAE:0.9276098012924194
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:1.1466686725616455  MAE:0.8463870882987976
# ▶ seg40  mean  MSE:1.1466686725616455  MAE:0.8463870882987976
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:1.399766445159912  MAE:0.9483367800712585
# ▶ seg41  mean  MSE:1.399766445159912  MAE:0.9483367800712585
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.953580915927887  MAE:0.7628475427627563
# ▶ seg42  mean  MSE:0.953580915927887  MAE:0.7628475427627563
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:1.8562229871749878  MAE:1.1206109523773193
# ▶ seg43  mean  MSE:1.8562229871749878  MAE:1.1206109523773193
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:1.0964984893798828  MAE:0.8189208507537842
# ▶ seg44  mean  MSE:1.0964984893798828  MAE:0.8189208507537842
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:1.1514877080917358  MAE:0.8438501358032227
# ▶ seg45  mean  MSE:1.1514877080917358  MAE:0.8438501358032227
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:1.1149952411651611  MAE:0.8366971015930176
# ▶ seg46  mean  MSE:1.1149952411651611  MAE:0.8366971015930176
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.938144862651825  MAE:0.7557542324066162
# ▶ seg47  mean  MSE:0.938144862651825  MAE:0.7557542324066162
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:1.9652659893035889  MAE:1.1293095350265503
# ▶ seg48  mean  MSE:1.9652659893035889  MAE:1.1293095350265503
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:1.370115041732788  MAE:0.9299706220626831
# ▶ seg49  mean  MSE:1.370115041732788  MAE:0.9299706220626831
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:2.300771474838257  MAE:1.2351891994476318
# ▶ seg50  mean  MSE:2.300771474838257  MAE:1.2351891994476318
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:1.4651987552642822  MAE:0.9678933620452881
# ▶ seg51  mean  MSE:1.4651987552642822  MAE:0.9678933620452881
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:1.0290186405181885  MAE:0.8010604977607727
# ▶ seg52  mean  MSE:1.0290186405181885  MAE:0.8010604977607727
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:1.7065503597259521  MAE:1.0630451440811157
# ▶ seg53  mean  MSE:1.7065503597259521  MAE:1.0630451440811157
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:1.3005101680755615  MAE:0.9092729091644287
# ▶ seg54  mean  MSE:1.3005101680755615  MAE:0.9092729091644287
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.8993977904319763  MAE:0.7476102709770203
# ▶ seg55  mean  MSE:0.8993977904319763  MAE:0.7476102709770203
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:1.4034093618392944  MAE:0.9401566982269287
# ▶ seg56  mean  MSE:1.4034093618392944  MAE:0.9401566982269287
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:1.7614001035690308  MAE:1.0727051496505737
# ▶ seg57  mean  MSE:1.7614001035690308  MAE:1.0727051496505737
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:1.3944249153137207  MAE:0.9388425350189209
# ▶ seg58  mean  MSE:1.3944249153137207  MAE:0.9388425350189209
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:1.1942142248153687  MAE:0.865166962146759
# ▶ seg59  mean  MSE:1.1942142248153687  MAE:0.865166962146759
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:1.5927507877349854  MAE:1.0228660106658936
# ▶ seg60  mean  MSE:1.5927507877349854  MAE:1.0228660106658936
#
# seg10 ch0 MSE : 1.2133331

# %% [markdown]
# # Rank Models (by 2nd alidation performance)

# %%
results1_ER_train = torch.load("./1st_results_ER/train_1st_results.pt")
results1_ER_val = torch.load("./1st_results_ER/val_1st_results.pt")
results1_ER_test = torch.load("./1st_results_ER/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 61
SEG_CNT     = 61
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ER_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ER_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ER_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ER_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 2.812473
#
#   Top  1 | seg 35 | MSE 2.150579 (+0.661893)
#   Top  2 | seg 51 | MSE 2.168796 (+0.643677)
#   Top  3 | seg 43 | MSE 2.292008 (+0.520464)
#   Top  4 | seg 36 | MSE 2.335659 (+0.476814)
#   Top  5 | seg 41 | MSE 2.368090 (+0.444382)
#   Top  6 | seg 39 | MSE 2.380758 (+0.431715)
#   Top  7 | seg 40 | MSE 2.432713 (+0.379760)
#   Top  8 | seg 54 | MSE 2.439747 (+0.372725)
#   Top  9 | seg 46 | MSE 2.486220 (+0.326253)
#   Top 10 | seg 38 | MSE 2.487938 (+0.324534)
#   Top 11 | seg 52 | MSE 2.494752 (+0.317720)
#   Top 12 | seg 44 | MSE 2.557681 (+0.254792)
#   Top 13 | seg 27 | MSE 2.570539 (+0.241933)
#   Top 14 | seg 30 | MSE 2.580037 (+0.232436)
#   Top 15 | seg 58 | MSE 2.661313 (+0.151160)
#   Top 16 | seg 47 | MSE 2.674898 (+0.137575)
#   Top 17 | seg 16 | MSE 2.679499 (+0.132973)
#   Top 18 | seg 06 | MSE 2.684362 (+0.128111)
#   Top 19 | seg 42 | MSE 2.685860 (+0.126612)
#   Top 20 | seg 17 | MSE 2.693769 (+0.118704)
#   Top 21 | seg 45 | MSE 2.708785 (+0.103688)
#   Top 22 | seg 12 | MSE 2.747696 (+0.064776)
#   Top 23 | seg 34 | MSE 2.748565 (+0.063908)
#   Top 24 | seg 50 | MSE 2.751388 (+0.061085)
#   Top 25 | seg 25 | MSE 2.770415 (+0.042058)
#   Top 26 | seg 60 | MSE 2.782876 (+0.029597)
#   Top 27 | seg 56 | MSE 2.790409 (+0.022064)
#   Top 28 | seg 02 | MSE 2.791440 (+0.021033)
#   Top 29 | seg 59 | MSE 2.796495 (+0.015978)
#   Top 30 | seg 22 | MSE 2.807140 (+0.005332)
#   Top 31 | seg 14 | MSE 2.831706 (-0.019233)
#   Top 32 | seg 11 | MSE 2.832000 (-0.019528)
#   Top 33 | seg 26 | MSE 2.857523 (-0.045050)
#   Top 34 | seg 53 | MSE 2.865449 (-0.052976)
#   Top 35 | seg 55 | MSE 2.869395 (-0.056922)
#   Top 36 | seg 04 | MSE 2.880809 (-0.068337)
#   Top 37 | seg 03 | MSE 2.882432 (-0.069959)
#   Top 38 | seg 32 | MSE 2.884242 (-0.071770)
#   Top 39 | seg 29 | MSE 2.901204 (-0.088731)
#   Top 40 | seg 57 | MSE 2.905000 (-0.092527)
#   Top 41 | seg 33 | MSE 2.905166 (-0.092693)
#   Top 42 | seg 18 | MSE 2.926187 (-0.113714)
#   Top 43 | seg 21 | MSE 2.931676 (-0.119204)
#   Top 44 | seg 23 | MSE 2.937373 (-0.124900)
#   Top 45 | seg 24 | MSE 2.949544 (-0.137071)
#   Top 46 | seg 08 | MSE 2.951837 (-0.139365)
#   Top 47 | seg 13 | MSE 2.964745 (-0.152273)
#   Top 48 | seg 00 | MSE 2.987496 (-0.175024)
#   Top 49 | seg 48 | MSE 2.999043 (-0.186571)
#   Top 50 | seg 10 | MSE 3.003881 (-0.191408)
#   Top 51 | seg 31 | MSE 3.028578 (-0.216105)
#   Top 52 | seg 28 | MSE 3.039905 (-0.227433)
#   Top 53 | seg 05 | MSE 3.051833 (-0.239361)
#   Top 54 | seg 01 | MSE 3.082206 (-0.269734)
#   Top 55 | seg 09 | MSE 3.132855 (-0.320383)
#   Top 56 | seg 49 | MSE 3.146946 (-0.334474)
#   Top 57 | seg 19 | MSE 3.184875 (-0.372403)
#   Top 58 | seg 37 | MSE 3.239292 (-0.426820)
#   Top 59 | seg 15 | MSE 3.250514 (-0.438041)
#   Top 60 | seg 07 | MSE 3.251586 (-0.439114)
#   Top 61 | seg 20 | MSE 3.477574 (-0.665102)
#
# Saved top segment indices per channel:
# Channel 0: [35, 51, 43, 36, 41, 39, 40, 54, 46, 38, 52, 44, 27, 30, 58, 47, 16, 6, 42, 17, 45, 12, 34, 50, 25, 60, 56, 2, 59, 22, 14, 11, 26, 53, 55, 4, 3, 32, 29, 57, 33, 18, 21, 23, 24, 8, 13, 0, 48, 10, 31, 28, 5, 1, 9, 49, 19, 37, 15, 7, 20]

# %% [markdown]
# ### 1E->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 61
SEG_CNT     = 61
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ER_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ER_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ER_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ER_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 2.812473
#
#   Top  1 | seg 33 | MSE 2.226981 (+0.585492)
#   Top  2 | seg 55 | MSE 2.332091 (+0.480381)
#   Top  3 | seg 38 | MSE 2.337669 (+0.474804)
#   Top  4 | seg 47 | MSE 2.356073 (+0.456399)
#   Top  5 | seg 42 | MSE 2.377493 (+0.434980)
#   Top  6 | seg 37 | MSE 2.413012 (+0.399460)
#   Top  7 | seg 36 | MSE 2.456079 (+0.356394)
#   Top  8 | seg 07 | MSE 2.471097 (+0.341376)
#   Top  9 | seg 52 | MSE 2.483846 (+0.328627)
#   Top 10 | seg 25 | MSE 2.546752 (+0.265721)
#   Top 11 | seg 46 | MSE 2.580682 (+0.231790)
#   Top 12 | seg 44 | MSE 2.605060 (+0.207412)
#   Top 13 | seg 09 | MSE 2.611702 (+0.200771)
#   Top 14 | seg 29 | MSE 2.614465 (+0.198007)
#   Top 15 | seg 14 | MSE 2.649145 (+0.163327)
#   Top 16 | seg 45 | MSE 2.651758 (+0.160714)
#   Top 17 | seg 28 | MSE 2.655155 (+0.157317)
#   Top 18 | seg 27 | MSE 2.664881 (+0.147592)
#   Top 19 | seg 40 | MSE 2.673691 (+0.138782)
#   Top 20 | seg 59 | MSE 2.706396 (+0.106076)
#   Top 21 | seg 11 | MSE 2.711964 (+0.100509)
#   Top 22 | seg 54 | MSE 2.730036 (+0.082437)
#   Top 23 | seg 04 | MSE 2.731563 (+0.080910)
#   Top 24 | seg 23 | MSE 2.747429 (+0.065044)
#   Top 25 | seg 34 | MSE 2.760827 (+0.051646)
#   Top 26 | seg 56 | MSE 2.790637 (+0.021835)
#   Top 27 | seg 05 | MSE 2.791175 (+0.021297)
#   Top 28 | seg 32 | MSE 2.796989 (+0.015483)
#   Top 29 | seg 49 | MSE 2.804416 (+0.008056)
#   Top 30 | seg 35 | MSE 2.821313 (-0.008840)
#   Top 31 | seg 10 | MSE 2.833490 (-0.021017)
#   Top 32 | seg 22 | MSE 2.842309 (-0.029837)
#   Top 33 | seg 00 | MSE 2.847044 (-0.034571)
#   Top 34 | seg 51 | MSE 2.848811 (-0.036338)
#   Top 35 | seg 58 | MSE 2.856019 (-0.043546)
#   Top 36 | seg 39 | MSE 2.869176 (-0.056703)
#   Top 37 | seg 31 | MSE 2.877605 (-0.065133)
#   Top 38 | seg 08 | MSE 2.890151 (-0.077679)
#   Top 39 | seg 41 | MSE 2.895998 (-0.083526)
#   Top 40 | seg 02 | MSE 2.931552 (-0.119079)
#   Top 41 | seg 17 | MSE 2.973565 (-0.161092)
#   Top 42 | seg 13 | MSE 3.027190 (-0.214717)
#   Top 43 | seg 18 | MSE 3.037429 (-0.224956)
#   Top 44 | seg 53 | MSE 3.052550 (-0.240077)
#   Top 45 | seg 15 | MSE 3.058276 (-0.245803)
#   Top 46 | seg 60 | MSE 3.064683 (-0.252211)
#   Top 47 | seg 24 | MSE 3.086093 (-0.273621)
#   Top 48 | seg 20 | MSE 3.089341 (-0.276869)
#   Top 49 | seg 01 | MSE 3.094936 (-0.282463)
#   Top 50 | seg 57 | MSE 3.163225 (-0.350752)
#   Top 51 | seg 16 | MSE 3.166732 (-0.354260)
#   Top 52 | seg 30 | MSE 3.174100 (-0.361627)
#   Top 53 | seg 03 | MSE 3.187904 (-0.375432)
#   Top 54 | seg 43 | MSE 3.226771 (-0.414299)
#   Top 55 | seg 48 | MSE 3.231693 (-0.419220)
#   Top 56 | seg 21 | MSE 3.251388 (-0.438915)
#   Top 57 | seg 12 | MSE 3.267940 (-0.455467)
#   Top 58 | seg 06 | MSE 3.296173 (-0.483700)
#   Top 59 | seg 19 | MSE 3.406379 (-0.593906)
#   Top 60 | seg 26 | MSE 3.428238 (-0.615765)
#   Top 61 | seg 50 | MSE 3.442563 (-0.630090)
#
# Saved top segment indices per channel:
# Channel 0: [33, 55, 38, 47, 42, 37, 36, 7, 52, 25, 46, 44, 9, 29, 14, 45, 28, 27, 40, 59, 11, 54, 4, 23, 34, 56, 5, 32, 49, 35, 10, 22, 0, 51, 58, 39, 31, 8, 41, 2, 17, 13, 18, 53, 15, 60, 24, 20, 1, 57, 16, 30, 3, 43, 48, 21, 12, 6, 19, 26, 50]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ER_test['ES']['mse_test_EES']
    v_mae = results1_ER_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ER_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 1.250289 | MAE : 0.879491
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.113e-02 | |ρ|=0.9729 | S=0.0000 <- pick
#    K=10 | Var=2.445e-02 | |ρ|=0.9752 | S=0.6192
#    K=15 | Var=2.770e-02 | |ρ|=0.9770 | S=1.1482
#    K=20 | Var=2.885e-02 | |ρ|=0.9775 | S=1.2939
#    K=25 | Var=3.315e-02 | |ρ|=0.9761 | S=1.1750
#    K=30 | Var=3.297e-02 | |ρ|=0.9767 | S=1.3052
#    K=35 | Var=3.542e-02 | |ρ|=0.9769 | S=1.4436
#    K=40 | Var=3.650e-02 | |ρ|=0.9774 | S=1.5901
#    K=45 | Var=3.653e-02 | |ρ|=0.9777 | S=1.6568
#    K=50 | Var=3.739e-02 | |ρ|=0.9775 | S=1.6497
#    K=55 | Var=3.925e-02 | |ρ|=0.9772 | S=1.6728
#    K=60 | Var=4.457e-02 | |ρ|=0.9773 | S=1.9179
# [Var-Corr]  K=5
#   MSE = 0.876035 | Δ = +0.374254 | Δ% = +29.93%
#   MAE = 0.728074 | Δ = +0.151418 | Δ% = +17.22%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 1.250289
# Ensemble mean MSE : 0.876035
# Average Δ MSE     : +0.374254
# Average Δ MSE (%) : +29.93%
#
# Vanilla  mean MAE : 0.879491
# Ensemble mean MAE : 0.728074
# Average Δ MAE     : +0.151418
# Average Δ MAE (%) : +17.22%

# %% [markdown]
# ## 1E->1E

# %%
results1_ER_test['ES']['mae_test_EES']
# Out:
# 0.8794910907745361

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ER_test['ES']['mse_test_EES']
    v_mae = results1_ER_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ER_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.35   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 1.250289 | MAE : 0.879491
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.387e-02 | |ρ|=0.9748 | S=0.0893 <- pick
#    K=10 | Var=2.101e-02 | |ρ|=0.9770 | S=1.2833
#    K=15 | Var=2.454e-02 | |ρ|=0.9759 | S=0.7609
#    K=20 | Var=2.710e-02 | |ρ|=0.9762 | S=0.9982
#    K=25 | Var=2.954e-02 | |ρ|=0.9771 | S=1.6161
#    K=30 | Var=3.273e-02 | |ρ|=0.9771 | S=1.6826
#    K=35 | Var=3.464e-02 | |ρ|=0.9766 | S=1.4620
#    K=40 | Var=3.650e-02 | |ρ|=0.9750 | S=0.5561
#    K=45 | Var=3.858e-02 | |ρ|=0.9752 | S=0.7804
#    K=50 | Var=4.279e-02 | |ρ|=0.9750 | S=0.7850
#    K=55 | Var=4.893e-02 | |ρ|=0.9749 | S=0.8910
#    K=60 | Var=5.307e-02 | |ρ|=0.9757 | S=1.5039
# [Var-Corr]  K=5
#    MSE = 0.858851 | Δ = +0.391438 | Δ% = +31.31%
#    MAE = 0.723231 | Δ = +0.156260 | Δ% = +17.77%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 1.250289
# Ensemble mean MSE  : 0.858851
# Average Δ MSE      : +0.391438
# Average Δ MSE (%)  : +31.31%
#
# Vanilla  mean MAE  : 0.879491
# Ensemble mean MAE  : 0.723231
# Average Δ MAE      : +0.156260
# Average Δ MAE (%)  : +17.77%
