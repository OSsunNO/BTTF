# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(2)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 2
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTm2.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                           HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# date
# 2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 2016-07-01 00:15:00  39.622002  11.309  35.543999  8.551  3.209  1.258
# 2016-07-01 00:30:00  38.868000  10.555  34.365002  7.586  4.435  1.258
# 2016-07-01 00:45:00  35.518002   9.214  32.569000  8.712  4.435  1.215
# 2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
#
#                             OT
# date
# 2016-07-01 00:00:00  38.661999
# 2016-07-01 00:15:00  38.223000
# 2016-07-01 00:30:00  37.344002
# 2016-07-01 00:45:00  37.124001
# 2016-07-01 01:00:00  37.124001

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (69680, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 00:15:00',
#                '2016-07-01 00:30:00', '2016-07-01 00:45:00',
#                '2016-07-01 01:00:00', '2016-07-01 01:15:00',
#                '2016-07-01 01:30:00', '2016-07-01 01:45:00',
#                '2016-07-01 02:00:00', '2016-07-01 02:15:00',
#                ...
#                '2018-06-26 17:30:00', '2018-06-26 17:45:00',
#                '2018-06-26 18:00:00', '2018-06-26 18:15:00',
#                '2018-06-26 18:30:00', '2018-06-26 18:45:00',
#                '2018-06-26 19:00:00', '2018-06-26 19:15:00',
#                '2018-06-26 19:30:00', '2018-06-26 19:45:00'],
#               dtype='datetime64[ns]', name='date', length=69680, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Decomposition-Linear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.individual = configs.individual
        self.channels = configs.enc_in
        self.attach_to_trend = configs.attach_to_trend
        self.attach_to_seasonal = configs.attach_to_seasonal
        

        
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        

        
        self.seq_len_trend = self.seq_len + (self.pred_len // 3) if self.attach_to_trend else self.seq_len
        self.seq_len_seasonal = self.seq_len + (self.pred_len // 3) if self.attach_to_seasonal else self.seq_len

        
        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))

                
                
                
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            
            
            
            

    def forward(self, x, ground_truth=None):
        
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if ground_truth is not None:
            kernel_size = 25
            self.decompsition = series_decomp(kernel_size)
            ground_truth_seasonal, ground_truth_trend = self.decompsition(ground_truth)

            
            if self.seq_len_seasonal > self.seq_len:
                ground_truth_seasonal=ground_truth_seasonal.permute(0, 2, 1)
                
                seasonal_init = torch.cat([seasonal_init, ground_truth_seasonal], dim=2)
            if self.seq_len_trend > self.seq_len:
                ground_truth_trend=ground_truth_trend.permute(0, 2, 1)
                
                trend_init = torch.cat([trend_init, ground_truth_trend], dim=2)
        
        
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 720




train_points = 12 * 30 * 24 * 4
val_points   = 4  * 30 * 24 * 4
test_points  = 4  * 30 * 24 * 4

border1s = [
    0,
    train_points - seq_len,
    train_points + val_points - seq_len
]
border2s = [
    train_points,
    train_points + val_points,
    train_points + val_points + test_points
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([33505, 336, 1])
# Train Labels:    torch.Size([33505, 720, 1])
# Val Sequences:   torch.Size([10801, 336, 1])
# Val Labels:      torch.Size([10801, 720, 1])
# Test Sequences:  torch.Size([10801, 336, 1])
# Test Labels:     torch.Size([10801, 720, 1])

# %%
set_seed(43)

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.47214864973576015 | Val Loss: 1.3901644716336883
# Validation loss decreased (inf --> 1.390164).  Saving model ...
# Updating learning rate to 0.01
# Epoch 1 | Train Loss: 0.292829732929591 | Val Loss: 0.34401373698557974
# Validation loss decreased (1.390164 --> 0.344014).  Saving model ...
# Updating learning rate to 0.005
# Epoch 2 | Train Loss: 0.2564261208451886 | Val Loss: 0.26895973930609296
# Validation loss decreased (0.344014 --> 0.268960).  Saving model ...
# Updating learning rate to 0.0025
# Epoch 3 | Train Loss: 0.24226890895373493 | Val Loss: 0.23350960673136117
# Validation loss decreased (0.268960 --> 0.233510).  Saving model ...
# Updating learning rate to 0.00125
# Epoch 4 | Train Loss: 0.23480689322277334 | Val Loss: 0.21900851121888712
# Validation loss decreased (0.233510 --> 0.219009).  Saving model ...
# Updating learning rate to 0.000625
# Epoch 5 | Train Loss: 0.22989839310437896 | Val Loss: 0.2110058720493634
# Validation loss decreased (0.219009 --> 0.211006).  Saving model ...
# Updating learning rate to 0.0003125
# Epoch 6 | Train Loss: 0.22763311188980823 | Val Loss: 0.20946409804581184
# Validation loss decreased (0.211006 --> 0.209464).  Saving model ...
# Updating learning rate to 0.00015625
# Epoch 7 | Train Loss: 0.22546881114537934 | Val Loss: 0.20806296318549022
# Validation loss decreased (0.209464 --> 0.208063).  Saving model ...
# Updating learning rate to 7.8125e-05
# Epoch 8 | Train Loss: 0.22445079288978614 | Val Loss: 0.20492137257648996
# Validation loss decreased (0.208063 --> 0.204921).  Saving model ...
# Updating learning rate to 3.90625e-05
# Epoch 9 | Train Loss: 0.22403906699525947 | Val Loss: 0.20502078470349663
# EarlyStopping counter: 1 out of 3

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 720  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.4353269063476615 | Val Loss: 0.8532416385835444
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.1740427017211914 | MAE: 0.32007578015327454
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.9815829396247864 | MAE: 0.7437691688537598

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.20511701703071594 | MAE: 0.3613194525241852
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.8541549444198608 | MAE: 0.6968115568161011

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.22415073215961456 | MAE: 0.3540865480899811
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.7794201374053955 | MAE: 0.6680173277854919

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([33505, 336, 1])
# val_sequences shape:  torch.Size([10801, 336, 1])
# test_sequences shape:  torch.Size([10801, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([33505, 720, 1])
# val_pv shape:  torch.Size([10801, 720, 1])
# test_pv shape:  torch.Size([10801, 720, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([33505, 720, 1])
# val_labels shape:  torch.Size([10801, 720, 1])
# test_labels shape:  torch.Size([10801, 720, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 720

# %%
segment_len = configs.pred_len // 3
stride = 8

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([33505, 61, 240, 1]), Val: torch.Size([10801, 61, 240, 1]), Test: torch.Size([10801, 61, 240, 1])
# [Epoch 1] Train seg shape: torch.Size([33505, 61, 240, 1]), Val: torch.Size([10801, 61, 240, 1]), Test: torch.Size([10801, 61, 240, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTm2'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 0] Training Time = 9.55 sec
# [Segment 0] GPU Memory Start = 12568.48 MB
# [Segment 0] GPU Memory End   = 9500.30 MB
# [Segment 0] GPU Peak Memory  = 12568.48 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 1] Training Time = 9.01 sec
# [Segment 1] GPU Memory Start = 9500.30 MB
# [Segment 1] GPU Memory End   = 9503.47 MB
# [Segment 1] GPU Peak Memory  = 9506.97 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 2] Training Time = 8.66 sec
# [Segment 2] GPU Memory Start = 9503.47 MB
# [Segment 2] GPU Memory End   = 9506.64 MB
# [Segment 2] GPU Peak Memory  = 9510.14 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 3] Training Time = 8.65 sec
# [Segment 3] GPU Memory Start = 9506.64 MB
# [Segment 3] GPU Memory End   = 9509.81 MB
# [Segment 3] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 4] Training Time = 8.63 sec
# [Segment 4] GPU Memory Start = 9509.81 MB
# [Segment 4] GPU Memory End   = 9512.98 MB
# [Segment 4] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 5] Training Time = 8.89 sec
# [Segment 5] GPU Memory Start = 9512.98 MB
# [Segment 5] GPU Memory End   = 9516.15 MB
# [Segment 5] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 6] Training Time = 8.26 sec
# [Segment 6] GPU Memory Start = 9516.15 MB
# [Segment 6] GPU Memory End   = 9519.32 MB
# [Segment 6] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 7] Training Time = 7.58 sec
# [Segment 7] GPU Memory Start = 9519.32 MB
# [Segment 7] GPU Memory End   = 9522.49 MB
# [Segment 7] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 8] Training Time = 7.84 sec
# [Segment 8] GPU Memory Start = 9522.49 MB
# [Segment 8] GPU Memory End   = 9525.66 MB
# [Segment 8] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 9] Training Time = 7.74 sec
# [Segment 9] GPU Memory Start = 9525.66 MB
# [Segment 9] GPU Memory End   = 9500.30 MB
# [Segment 9] GPU Peak Memory  = 9528.83 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 10] Training Time = 8.39 sec
# [Segment 10] GPU Memory Start = 9500.30 MB
# [Segment 10] GPU Memory End   = 9503.47 MB
# [Segment 10] GPU Peak Memory  = 9506.97 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 11] Training Time = 7.91 sec
# [Segment 11] GPU Memory Start = 9503.47 MB
# [Segment 11] GPU Memory End   = 9506.64 MB
# [Segment 11] GPU Peak Memory  = 9510.14 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 12] Training Time = 8.56 sec
# [Segment 12] GPU Memory Start = 9506.64 MB
# [Segment 12] GPU Memory End   = 9509.81 MB
# [Segment 12] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 13] Training Time = 9.02 sec
# [Segment 13] GPU Memory Start = 9509.81 MB
# [Segment 13] GPU Memory End   = 9512.98 MB
# [Segment 13] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 14] Training Time = 9.04 sec
# [Segment 14] GPU Memory Start = 9512.98 MB
# [Segment 14] GPU Memory End   = 9516.15 MB
# [Segment 14] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 15] Training Time = 5.78 sec
# [Segment 15] GPU Memory Start = 9516.15 MB
# [Segment 15] GPU Memory End   = 9519.32 MB
# [Segment 15] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 16] Training Time = 4.09 sec
# [Segment 16] GPU Memory Start = 9519.32 MB
# [Segment 16] GPU Memory End   = 9522.49 MB
# [Segment 16] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 17] Training Time = 4.04 sec
# [Segment 17] GPU Memory Start = 9522.49 MB
# [Segment 17] GPU Memory End   = 9525.66 MB
# [Segment 17] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 18] Training Time = 4.16 sec
# [Segment 18] GPU Memory Start = 9525.66 MB
# [Segment 18] GPU Memory End   = 9528.83 MB
# [Segment 18] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 19] Training Time = 4.37 sec
# [Segment 19] GPU Memory Start = 9500.30 MB
# [Segment 19] GPU Memory End   = 9503.47 MB
# [Segment 19] GPU Peak Memory  = 9506.97 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 20] Training Time = 5.21 sec
# [Segment 20] GPU Memory Start = 9503.47 MB
# [Segment 20] GPU Memory End   = 9506.64 MB
# [Segment 20] GPU Peak Memory  = 9510.14 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 21] Training Time = 8.79 sec
# [Segment 21] GPU Memory Start = 9506.64 MB
# [Segment 21] GPU Memory End   = 9509.81 MB
# [Segment 21] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 22] Training Time = 8.79 sec
# [Segment 22] GPU Memory Start = 9509.81 MB
# [Segment 22] GPU Memory End   = 9512.98 MB
# [Segment 22] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 23] Training Time = 8.60 sec
# [Segment 23] GPU Memory Start = 9512.98 MB
# [Segment 23] GPU Memory End   = 9516.15 MB
# [Segment 23] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 24] Training Time = 8.75 sec
# [Segment 24] GPU Memory Start = 9516.15 MB
# [Segment 24] GPU Memory End   = 9519.32 MB
# [Segment 24] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 25] Training Time = 8.69 sec
# [Segment 25] GPU Memory Start = 9519.32 MB
# [Segment 25] GPU Memory End   = 9522.49 MB
# [Segment 25] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 26] Training Time = 8.97 sec
# [Segment 26] GPU Memory Start = 9522.49 MB
# [Segment 26] GPU Memory End   = 9525.66 MB
# [Segment 26] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 27] Training Time = 8.88 sec
# [Segment 27] GPU Memory Start = 9525.66 MB
# [Segment 27] GPU Memory End   = 9528.83 MB
# [Segment 27] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 28] Training Time = 8.70 sec
# [Segment 28] GPU Memory Start = 9528.83 MB
# [Segment 28] GPU Memory End   = 9503.47 MB
# [Segment 28] GPU Peak Memory  = 9532.00 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 29] Training Time = 8.68 sec
# [Segment 29] GPU Memory Start = 9503.47 MB
# [Segment 29] GPU Memory End   = 9506.64 MB
# [Segment 29] GPU Peak Memory  = 9510.14 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 30] Training Time = 8.24 sec
# [Segment 30] GPU Memory Start = 9506.64 MB
# [Segment 30] GPU Memory End   = 9509.81 MB
# [Segment 30] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 31] Training Time = 9.05 sec
# [Segment 31] GPU Memory Start = 9509.81 MB
# [Segment 31] GPU Memory End   = 9512.98 MB
# [Segment 31] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 32] Training Time = 9.08 sec
# [Segment 32] GPU Memory Start = 9512.98 MB
# [Segment 32] GPU Memory End   = 9516.15 MB
# [Segment 32] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 33] Training Time = 8.67 sec
# [Segment 33] GPU Memory Start = 9516.15 MB
# [Segment 33] GPU Memory End   = 9519.32 MB
# [Segment 33] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 34] Training Time = 8.90 sec
# [Segment 34] GPU Memory Start = 9519.32 MB
# [Segment 34] GPU Memory End   = 9522.49 MB
# [Segment 34] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 35] Training Time = 7.96 sec
# [Segment 35] GPU Memory Start = 9522.49 MB
# [Segment 35] GPU Memory End   = 9525.66 MB
# [Segment 35] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 36] Training Time = 8.12 sec
# [Segment 36] GPU Memory Start = 9525.66 MB
# [Segment 36] GPU Memory End   = 9528.25 MB
# [Segment 36] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 37] Training Time = 7.15 sec
# [Segment 37] GPU Memory Start = 9528.25 MB
# [Segment 37] GPU Memory End   = 9532.00 MB
# [Segment 37] GPU Peak Memory  = 9535.50 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 38] Training Time = 3.35 sec
# [Segment 38] GPU Memory Start = 9503.47 MB
# [Segment 38] GPU Memory End   = 9506.64 MB
# [Segment 38] GPU Peak Memory  = 9510.14 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 39] Training Time = 3.42 sec
# [Segment 39] GPU Memory Start = 9506.64 MB
# [Segment 39] GPU Memory End   = 9509.81 MB
# [Segment 39] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 40] Training Time = 3.45 sec
# [Segment 40] GPU Memory Start = 9509.81 MB
# [Segment 40] GPU Memory End   = 9512.98 MB
# [Segment 40] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 41] Training Time = 3.41 sec
# [Segment 41] GPU Memory Start = 9512.98 MB
# [Segment 41] GPU Memory End   = 9516.15 MB
# [Segment 41] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 42] Training Time = 3.41 sec
# [Segment 42] GPU Memory Start = 9516.15 MB
# [Segment 42] GPU Memory End   = 9519.32 MB
# [Segment 42] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 43] Training Time = 3.26 sec
# [Segment 43] GPU Memory Start = 9519.32 MB
# [Segment 43] GPU Memory End   = 9522.49 MB
# [Segment 43] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 44] Training Time = 8.27 sec
# [Segment 44] GPU Memory Start = 9522.49 MB
# [Segment 44] GPU Memory End   = 9525.66 MB
# [Segment 44] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 45] Training Time = 9.09 sec
# [Segment 45] GPU Memory Start = 9525.66 MB
# [Segment 45] GPU Memory End   = 9528.83 MB
# [Segment 45] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 46] Training Time = 8.97 sec
# [Segment 46] GPU Memory Start = 9528.83 MB
# [Segment 46] GPU Memory End   = 9532.00 MB
# [Segment 46] GPU Peak Memory  = 9535.50 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 47] Training Time = 8.86 sec
# [Segment 47] GPU Memory Start = 9532.00 MB
# [Segment 47] GPU Memory End   = 9506.64 MB
# [Segment 47] GPU Peak Memory  = 9535.17 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 48] Training Time = 8.71 sec
# [Segment 48] GPU Memory Start = 9506.64 MB
# [Segment 48] GPU Memory End   = 9509.81 MB
# [Segment 48] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 49] Training Time = 7.41 sec
# [Segment 49] GPU Memory Start = 9509.81 MB
# [Segment 49] GPU Memory End   = 9512.98 MB
# [Segment 49] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 50] Training Time = 7.46 sec
# [Segment 50] GPU Memory Start = 9512.98 MB
# [Segment 50] GPU Memory End   = 9516.15 MB
# [Segment 50] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 51] Training Time = 8.01 sec
# [Segment 51] GPU Memory Start = 9516.15 MB
# [Segment 51] GPU Memory End   = 9519.32 MB
# [Segment 51] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 52] Training Time = 7.71 sec
# [Segment 52] GPU Memory Start = 9519.32 MB
# [Segment 52] GPU Memory End   = 9522.49 MB
# [Segment 52] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 53] Training Time = 7.61 sec
# [Segment 53] GPU Memory Start = 9522.49 MB
# [Segment 53] GPU Memory End   = 9525.66 MB
# [Segment 53] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 54] Training Time = 7.55 sec
# [Segment 54] GPU Memory Start = 9525.66 MB
# [Segment 54] GPU Memory End   = 9528.83 MB
# [Segment 54] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 55] Training Time = 7.77 sec
# [Segment 55] GPU Memory Start = 9528.83 MB
# [Segment 55] GPU Memory End   = 9532.00 MB
# [Segment 55] GPU Peak Memory  = 9535.50 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 56] Training Time = 7.75 sec
# [Segment 56] GPU Memory Start = 9532.00 MB
# [Segment 56] GPU Memory End   = 9535.17 MB
# [Segment 56] GPU Peak Memory  = 9538.67 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 57] Training Time = 7.65 sec
# [Segment 57] GPU Memory Start = 9506.64 MB
# [Segment 57] GPU Memory End   = 9509.81 MB
# [Segment 57] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 58] Training Time = 7.43 sec
# [Segment 58] GPU Memory Start = 9509.81 MB
# [Segment 58] GPU Memory End   = 9512.98 MB
# [Segment 58] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 59] Training Time = 7.72 sec
# [Segment 59] GPU Memory Start = 9512.98 MB
# [Segment 59] GPU Memory End   = 9516.15 MB
# [Segment 59] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 60] Training Time = 7.66 sec
# [Segment 60] GPU Memory Start = 9516.15 MB
# [Segment 60] GPU Memory End   = 9519.32 MB
# [Segment 60] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 720,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E/",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 0] Training Time = 7.26 sec
# [Segment 0] GPU Memory Start = 9509.81 MB
# [Segment 0] GPU Memory End   = 9509.81 MB
# [Segment 0] GPU Peak Memory  = 9514.60 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 1] Training Time = 3.21 sec
# [Segment 1] GPU Memory Start = 9509.81 MB
# [Segment 1] GPU Memory End   = 9512.98 MB
# [Segment 1] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 2] Training Time = 3.19 sec
# [Segment 2] GPU Memory Start = 9512.98 MB
# [Segment 2] GPU Memory End   = 9516.15 MB
# [Segment 2] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 3] Training Time = 3.37 sec
# [Segment 3] GPU Memory Start = 9516.15 MB
# [Segment 3] GPU Memory End   = 9519.32 MB
# [Segment 3] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 4] Training Time = 3.29 sec
# [Segment 4] GPU Memory Start = 9519.32 MB
# [Segment 4] GPU Memory End   = 9509.81 MB
# [Segment 4] GPU Peak Memory  = 9522.49 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 5] Training Time = 3.01 sec
# [Segment 5] GPU Memory Start = 9509.81 MB
# [Segment 5] GPU Memory End   = 9512.98 MB
# [Segment 5] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 6] Training Time = 3.23 sec
# [Segment 6] GPU Memory Start = 9512.98 MB
# [Segment 6] GPU Memory End   = 9516.15 MB
# [Segment 6] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 7] Training Time = 7.20 sec
# [Segment 7] GPU Memory Start = 9516.15 MB
# [Segment 7] GPU Memory End   = 9519.32 MB
# [Segment 7] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 8] Training Time = 7.82 sec
# [Segment 8] GPU Memory Start = 9519.32 MB
# [Segment 8] GPU Memory End   = 9522.49 MB
# [Segment 8] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 9] Training Time = 7.81 sec
# [Segment 9] GPU Memory Start = 9522.49 MB
# [Segment 9] GPU Memory End   = 9525.66 MB
# [Segment 9] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 10] Training Time = 7.63 sec
# [Segment 10] GPU Memory Start = 9525.66 MB
# [Segment 10] GPU Memory End   = 9528.83 MB
# [Segment 10] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 11] Training Time = 7.71 sec
# [Segment 11] GPU Memory Start = 9528.83 MB
# [Segment 11] GPU Memory End   = 9532.00 MB
# [Segment 11] GPU Peak Memory  = 9535.50 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 12] Training Time = 7.38 sec
# [Segment 12] GPU Memory Start = 9532.00 MB
# [Segment 12] GPU Memory End   = 9535.17 MB
# [Segment 12] GPU Peak Memory  = 9538.67 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 13] Training Time = 7.58 sec
# [Segment 13] GPU Memory Start = 9535.17 MB
# [Segment 13] GPU Memory End   = 9538.34 MB
# [Segment 13] GPU Peak Memory  = 9541.84 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 14] Training Time = 7.71 sec
# [Segment 14] GPU Memory Start = 9509.81 MB
# [Segment 14] GPU Memory End   = 9512.98 MB
# [Segment 14] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 15] Training Time = 7.73 sec
# [Segment 15] GPU Memory Start = 9512.98 MB
# [Segment 15] GPU Memory End   = 9516.15 MB
# [Segment 15] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 16] Training Time = 7.58 sec
# [Segment 16] GPU Memory Start = 9516.15 MB
# [Segment 16] GPU Memory End   = 9519.32 MB
# [Segment 16] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 17] Training Time = 7.83 sec
# [Segment 17] GPU Memory Start = 9519.32 MB
# [Segment 17] GPU Memory End   = 9522.49 MB
# [Segment 17] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 18] Training Time = 7.66 sec
# [Segment 18] GPU Memory Start = 9522.49 MB
# [Segment 18] GPU Memory End   = 9525.66 MB
# [Segment 18] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 19] Training Time = 7.57 sec
# [Segment 19] GPU Memory Start = 9525.66 MB
# [Segment 19] GPU Memory End   = 9528.83 MB
# [Segment 19] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 20] Training Time = 7.58 sec
# [Segment 20] GPU Memory Start = 9528.83 MB
# [Segment 20] GPU Memory End   = 9532.00 MB
# [Segment 20] GPU Peak Memory  = 9535.50 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 21] Training Time = 7.79 sec
# [Segment 21] GPU Memory Start = 9532.00 MB
# [Segment 21] GPU Memory End   = 9535.17 MB
# [Segment 21] GPU Peak Memory  = 9538.67 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 22] Training Time = 7.83 sec
# [Segment 22] GPU Memory Start = 9535.17 MB
# [Segment 22] GPU Memory End   = 9538.34 MB
# [Segment 22] GPU Peak Memory  = 9541.84 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 23] Training Time = 8.40 sec
# [Segment 23] GPU Memory Start = 9538.34 MB
# [Segment 23] GPU Memory End   = 9500.30 MB
# [Segment 23] GPU Peak Memory  = 9541.51 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 24] Training Time = 8.39 sec
# [Segment 24] GPU Memory Start = 9500.30 MB
# [Segment 24] GPU Memory End   = 9503.47 MB
# [Segment 24] GPU Peak Memory  = 9506.97 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 25] Training Time = 4.89 sec
# [Segment 25] GPU Memory Start = 9503.47 MB
# [Segment 25] GPU Memory End   = 9506.64 MB
# [Segment 25] GPU Peak Memory  = 9510.14 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 26] Training Time = 4.03 sec
# [Segment 26] GPU Memory Start = 9506.64 MB
# [Segment 26] GPU Memory End   = 9509.81 MB
# [Segment 26] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 27] Training Time = 4.16 sec
# [Segment 27] GPU Memory Start = 9509.81 MB
# [Segment 27] GPU Memory End   = 9512.98 MB
# [Segment 27] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 28] Training Time = 3.62 sec
# [Segment 28] GPU Memory Start = 9512.98 MB
# [Segment 28] GPU Memory End   = 9516.15 MB
# [Segment 28] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 29] Training Time = 3.75 sec
# [Segment 29] GPU Memory Start = 9516.15 MB
# [Segment 29] GPU Memory End   = 9519.32 MB
# [Segment 29] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 30] Training Time = 5.58 sec
# [Segment 30] GPU Memory Start = 9519.32 MB
# [Segment 30] GPU Memory End   = 9522.49 MB
# [Segment 30] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 31] Training Time = 8.41 sec
# [Segment 31] GPU Memory Start = 9522.49 MB
# [Segment 31] GPU Memory End   = 9525.66 MB
# [Segment 31] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 32] Training Time = 8.59 sec
# [Segment 32] GPU Memory Start = 9525.66 MB
# [Segment 32] GPU Memory End   = 9528.83 MB
# [Segment 32] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 33] Training Time = 8.33 sec
# [Segment 33] GPU Memory Start = 9500.30 MB
# [Segment 33] GPU Memory End   = 9503.47 MB
# [Segment 33] GPU Peak Memory  = 9506.97 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 34] Training Time = 8.80 sec
# [Segment 34] GPU Memory Start = 9503.47 MB
# [Segment 34] GPU Memory End   = 9506.64 MB
# [Segment 34] GPU Peak Memory  = 9510.14 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 35] Training Time = 8.71 sec
# [Segment 35] GPU Memory Start = 9506.64 MB
# [Segment 35] GPU Memory End   = 9509.81 MB
# [Segment 35] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 36] Training Time = 8.79 sec
# [Segment 36] GPU Memory Start = 9509.81 MB
# [Segment 36] GPU Memory End   = 9512.98 MB
# [Segment 36] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 37] Training Time = 8.75 sec
# [Segment 37] GPU Memory Start = 9512.98 MB
# [Segment 37] GPU Memory End   = 9516.15 MB
# [Segment 37] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 38] Training Time = 8.44 sec
# [Segment 38] GPU Memory Start = 9516.15 MB
# [Segment 38] GPU Memory End   = 9519.32 MB
# [Segment 38] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 39] Training Time = 8.64 sec
# [Segment 39] GPU Memory Start = 9519.32 MB
# [Segment 39] GPU Memory End   = 9522.49 MB
# [Segment 39] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 40] Training Time = 8.65 sec
# [Segment 40] GPU Memory Start = 9522.49 MB
# [Segment 40] GPU Memory End   = 9525.66 MB
# [Segment 40] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 41] Training Time = 8.75 sec
# [Segment 41] GPU Memory Start = 9525.66 MB
# [Segment 41] GPU Memory End   = 9528.83 MB
# [Segment 41] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 42] Training Time = 8.55 sec
# [Segment 42] GPU Memory Start = 9528.83 MB
# [Segment 42] GPU Memory End   = 9503.47 MB
# [Segment 42] GPU Peak Memory  = 9532.00 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 43] Training Time = 8.64 sec
# [Segment 43] GPU Memory Start = 9503.47 MB
# [Segment 43] GPU Memory End   = 9506.64 MB
# [Segment 43] GPU Peak Memory  = 9510.14 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 44] Training Time = 8.54 sec
# [Segment 44] GPU Memory Start = 9506.64 MB
# [Segment 44] GPU Memory End   = 9509.81 MB
# [Segment 44] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 45] Training Time = 8.65 sec
# [Segment 45] GPU Memory Start = 9509.81 MB
# [Segment 45] GPU Memory End   = 9512.98 MB
# [Segment 45] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 46] Training Time = 8.78 sec
# [Segment 46] GPU Memory Start = 9512.98 MB
# [Segment 46] GPU Memory End   = 9516.15 MB
# [Segment 46] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 47] Training Time = 4.98 sec
# [Segment 47] GPU Memory Start = 9516.15 MB
# [Segment 47] GPU Memory End   = 9519.32 MB
# [Segment 47] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 48] Training Time = 3.88 sec
# [Segment 48] GPU Memory Start = 9519.32 MB
# [Segment 48] GPU Memory End   = 9522.49 MB
# [Segment 48] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 49] Training Time = 4.32 sec
# [Segment 49] GPU Memory Start = 9522.49 MB
# [Segment 49] GPU Memory End   = 9525.66 MB
# [Segment 49] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 50] Training Time = 4.13 sec
# [Segment 50] GPU Memory Start = 9525.66 MB
# [Segment 50] GPU Memory End   = 9528.25 MB
# [Segment 50] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 51] Training Time = 4.08 sec
# [Segment 51] GPU Memory Start = 9528.25 MB
# [Segment 51] GPU Memory End   = 9532.00 MB
# [Segment 51] GPU Peak Memory  = 9535.50 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 52] Training Time = 5.44 sec
# [Segment 52] GPU Memory Start = 9503.47 MB
# [Segment 52] GPU Memory End   = 9506.64 MB
# [Segment 52] GPU Peak Memory  = 9510.14 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 53] Training Time = 4.26 sec
# [Segment 53] GPU Memory Start = 9506.64 MB
# [Segment 53] GPU Memory End   = 9509.81 MB
# [Segment 53] GPU Peak Memory  = 9513.31 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 54] Training Time = 4.73 sec
# [Segment 54] GPU Memory Start = 9509.81 MB
# [Segment 54] GPU Memory End   = 9512.98 MB
# [Segment 54] GPU Peak Memory  = 9516.48 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 55] Training Time = 5.16 sec
# [Segment 55] GPU Memory Start = 9512.98 MB
# [Segment 55] GPU Memory End   = 9516.15 MB
# [Segment 55] GPU Peak Memory  = 9519.65 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 56] Training Time = 6.28 sec
# [Segment 56] GPU Memory Start = 9516.15 MB
# [Segment 56] GPU Memory End   = 9519.32 MB
# [Segment 56] GPU Peak Memory  = 9522.82 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 57] Training Time = 5.62 sec
# [Segment 57] GPU Memory Start = 9519.32 MB
# [Segment 57] GPU Memory End   = 9522.49 MB
# [Segment 57] GPU Peak Memory  = 9525.99 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 58] Training Time = 8.48 sec
# [Segment 58] GPU Memory Start = 9522.49 MB
# [Segment 58] GPU Memory End   = 9525.66 MB
# [Segment 58] GPU Peak Memory  = 9529.16 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 59] Training Time = 8.70 sec
# [Segment 59] GPU Memory Start = 9525.66 MB
# [Segment 59] GPU Memory End   = 9528.83 MB
# [Segment 59] GPU Peak Memory  = 9532.33 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 42.9844 MB
#   yb per batch = 0.0879 MB, total = 92.1094 MB
#   pv per batch = 0.0293 MB, total = 30.7031 MB
# [Segment 60] Training Time = 7.91 sec
# [Segment 60] GPU Memory Start = 9528.83 MB
# [Segment 60] GPU Memory End   = 9532.00 MB
# [Segment 60] GPU Peak Memory  = 9535.50 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 720,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 61
batch_sz = 32

results2_ETTm2_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.47017261385917664  MAE:0.5236861705780029
# ▶ seg0  mean  MSE:0.47017261385917664  MAE:0.5236861705780029
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.41884714365005493  MAE:0.4978894889354706
# ▶ seg1  mean  MSE:0.41884714365005493  MAE:0.4978894889354706
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:1.224120855331421  MAE:0.8298520445823669
# ▶ seg2  mean  MSE:1.224120855331421  MAE:0.8298520445823669
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:2.438250780105591  MAE:1.1814796924591064
# ▶ seg3  mean  MSE:2.438250780105591  MAE:1.1814796924591064
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:1.6625107526779175  MAE:0.9814893007278442
# ▶ seg4  mean  MSE:1.6625107526779175  MAE:0.9814893007278442
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.6398612856864929  MAE:0.6131270527839661
# ▶ seg5  mean  MSE:0.6398612856864929  MAE:0.6131270527839661
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.49486300349235535  MAE:0.5438603162765503
# ▶ seg6  mean  MSE:0.49486300349235535  MAE:0.5438603162765503
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.9422203302383423  MAE:0.7267451882362366
# ▶ seg7  mean  MSE:0.9422203302383423  MAE:0.7267451882362366
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.7914402484893799  MAE:0.6710678935050964
# ▶ seg8  mean  MSE:0.7914402484893799  MAE:0.6710678935050964
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.7062349915504456  MAE:0.6474413275718689
# ▶ seg9  mean  MSE:0.7062349915504456  MAE:0.6474413275718689
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.8955215811729431  MAE:0.705944836139679
# ▶ seg10  mean  MSE:0.8955215811729431  MAE:0.705944836139679
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.6064409017562866  MAE:0.5881631374359131
# ▶ seg11  mean  MSE:0.6064409017562866  MAE:0.5881631374359131
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.76462322473526  MAE:0.6604639291763306
# ▶ seg12  mean  MSE:0.76462322473526  MAE:0.6604639291763306
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:1.1696557998657227  MAE:0.8103220462799072
# ▶ seg13  mean  MSE:1.1696557998657227  MAE:0.8103220462799072
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.3993762731552124  MAE:0.49187609553337097
# ▶ seg14  mean  MSE:0.3993762731552124  MAE:0.49187609553337097
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.37279531359672546  MAE:0.48502010107040405
# ▶ seg15  mean  MSE:0.37279531359672546  MAE:0.48502010107040405
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.7913140058517456  MAE:0.6778966784477234
# ▶ seg52  mean  MSE:0.7913140058517456  MAE:0.6778966784477234
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.5782272815704346  MAE:0.568885862827301
# ▶ seg53  mean  MSE:0.5782272815704346  MAE:0.568885862827301
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:1.0394771099090576  MAE:0.7610755562782288
# ▶ seg54  mean  MSE:1.0394771099090576  MAE:0.7610755562782288
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:2.3798093795776367  MAE:1.17270028591156
# ▶ seg55  mean  MSE:2.3798093795776367  MAE:1.17270028591156
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:2.091501235961914  MAE:1.0560771226882935
# ▶ seg56  mean  MSE:2.091501235961914  MAE:1.0560771226882935
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:1.4631118774414062  MAE:0.9173754453659058
# ▶ seg57  mean  MSE:1.4631118774414062  MAE:0.9173754453659058
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:5.224157810211182  MAE:1.916405200958252
# ▶ seg58  mean  MSE:5.224157810211182  MAE:1.916405200958252
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.7950900197029114  MAE:0.6554170250892639
# ▶ seg59  mean  MSE:0.7950900197029114  MAE:0.6554170250892639
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:15.623425483703613  MAE:2.8954899311065674
# ▶ seg60  mean  MSE:15.623425483703613  MAE:2.8954899311065674
#
# seg10 ch0 MSE : 1.39512

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTm2_train = torch.load("./1st_results_ETTm2/train_1st_results.pt")
results1_ETTm2_val = torch.load("./1st_results_ETTm2/val_1st_results.pt")
results1_ETTm2_test = torch.load("./1st_results_ETTm2/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 61
SEG_CNT     = 61
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.854155
#
#   Top  1 | seg 47 | MSE 0.353815 (+0.500340)
#   Top  2 | seg 15 | MSE 0.372795 (+0.481360)
#   Top  3 | seg 22 | MSE 0.389085 (+0.465070)
#   Top  4 | seg 14 | MSE 0.399376 (+0.454779)
#   Top  5 | seg 33 | MSE 0.401871 (+0.452284)
#   Top  6 | seg 32 | MSE 0.410394 (+0.443761)
#   Top  7 | seg 48 | MSE 0.411937 (+0.442218)
#   Top  8 | seg 59 | MSE 0.412487 (+0.441668)
#   Top  9 | seg 01 | MSE 0.418847 (+0.435308)
#   Top 10 | seg 46 | MSE 0.451851 (+0.402304)
#   Top 11 | seg 20 | MSE 0.453971 (+0.400184)
#   Top 12 | seg 00 | MSE 0.470173 (+0.383982)
#   Top 13 | seg 06 | MSE 0.494863 (+0.359292)
#   Top 14 | seg 24 | MSE 0.507584 (+0.346571)
#   Top 15 | seg 60 | MSE 0.508875 (+0.345280)
#   Top 16 | seg 17 | MSE 0.519086 (+0.335069)
#   Top 17 | seg 25 | MSE 0.574247 (+0.279908)
#   Top 18 | seg 52 | MSE 0.577332 (+0.276823)
#   Top 19 | seg 58 | MSE 0.589977 (+0.264178)
#   Top 20 | seg 40 | MSE 0.604104 (+0.250050)
#   Top 21 | seg 11 | MSE 0.606441 (+0.247714)
#   Top 48 | seg 26 | MSE 1.599609 (-0.745454)
#   Top 49 | seg 56 | MSE 1.820153 (-0.965998)
#   Top 50 | seg 55 | MSE 1.865097 (-1.010942)
#   Top 51 | seg 17 | MSE 1.879864 (-1.025709)
#   Top 52 | seg 43 | MSE 2.069982 (-1.215827)
#   Top 53 | seg 49 | MSE 2.112400 (-1.258245)
#   Top 54 | seg 01 | MSE 2.184854 (-1.330699)
#   Top 55 | seg 48 | MSE 2.680450 (-1.826295)
#   Top 56 | seg 23 | MSE 2.893287 (-2.039132)
#   Top 57 | seg 12 | MSE 3.263930 (-2.409775)
#   Top 58 | seg 04 | MSE 3.407174 (-2.553019)
#   Top 59 | seg 32 | MSE 3.850786 (-2.996632)
#   Top 60 | seg 58 | MSE 3.980308 (-3.126153)
#   Top 61 | seg 60 | MSE 12.204560 (-11.350405)
#
# Saved top segment indices per channel:
# Channel 0: [33, 40, 18, 14, 50, 28, 11, 6, 53, 5, 51, 0, 41, 45, 36, 3, 59, 22, 46, 13, 8, 39, 7, 52, 47, 20, 16, 34, 37, 54, 24, 9, 31, 2, 35, 44, 21, 27, 19, 57, 15, 30, 10, 38, 42, 25, 29, 26, 56, 55, 17, 43, 49, 1, 48, 23, 12, 4, 32, 58, 60]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTm2_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.174043 | MAE : 0.320076
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.677e-01 | |ρ|=0.5335 | S=0.7895
#    K=10 | Var=2.531e-01 | |ρ|=0.5664 | S=0.9521
#    K=15 | Var=2.775e-01 | |ρ|=0.5750 | S=1.0354
#    K=20 | Var=3.383e-01 | |ρ|=0.5221 | S=0.8285
#    K=25 | Var=3.708e-01 | |ρ|=0.5120 | S=0.8200
#    K=30 | Var=4.097e-01 | |ρ|=0.5037 | S=0.8303
#    K=35 | Var=4.511e-01 | |ρ|=0.5023 | S=0.8822
#    K=40 | Var=5.136e-01 | |ρ|=0.4731 | S=0.8105
#    K=45 | Var=5.682e-01 | |ρ|=0.4621 | S=0.8289
#    K=50 | Var=6.429e-01 | |ρ|=0.4316 | S=0.7674 <- pick
#    K=55 | Var=7.703e-01 | |ρ|=0.4112 | S=0.8390
#    K=60 | Var=9.408e-01 | |ρ|=0.3956 | S=1.0000
# [Var-Corr]  K=50
#   MSE = 0.185620 | Δ = -0.011578 | Δ% = -6.65%
#   MAE = 0.336041 | Δ = -0.015966 | Δ% = -4.99%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.174043
# Ensemble mean MSE : 0.185620
# Average Δ MSE     : -0.011578
# Average Δ MSE (%) : -6.65%
#
# Vanilla  mean MAE : 0.320076
# Ensemble mean MAE : 0.336041
# Average Δ MAE     : -0.015966
# Average Δ MAE (%) : -4.99%

# %% [markdown]
# ## 1E->1E

# %%
results1_ETTm2_test['ES']['mae_test_EES']
# Out:
# 0.32007578015327454

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 61
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTm2_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.1   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.174043 | MAE : 0.320076
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.693e-01 | |ρ|=0.5705 | S=1.1000
#    K=10 | Var=3.362e-01 | |ρ|=0.5558 | S=1.0993
#    K=15 | Var=4.053e-01 | |ρ|=0.5151 | S=0.9834
#    K=20 | Var=4.641e-01 | |ρ|=0.4650 | S=0.8148
#    K=25 | Var=5.090e-01 | |ρ|=0.4572 | S=0.8241
#    K=30 | Var=5.718e-01 | |ρ|=0.4239 | S=0.7354
#    K=35 | Var=6.263e-01 | |ρ|=0.3996 | S=0.6789
#    K=40 | Var=6.936e-01 | |ρ|=0.3709 | S=0.6157 <- pick
#    K=45 | Var=7.661e-01 | |ρ|=0.3729 | S=0.6964
#    K=50 | Var=8.696e-01 | |ρ|=0.3518 | S=0.7032
#    K=55 | Var=1.018e+00 | |ρ|=0.3451 | S=0.8194
#    K=60 | Var=1.282e+00 | |ρ|=0.3274 | S=1.0000
# [Var-Corr]  K=40
#    MSE = 0.186557 | Δ = -0.012515 | Δ% = -7.19%
#    MAE = 0.332080 | Δ = -0.012004 | Δ% = -3.75%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.174043
# Ensemble mean MSE  : 0.186557
# Average Δ MSE      : -0.012515
# Average Δ MSE (%)  : -7.19%
#
# Vanilla  mean MAE  : 0.320076
# Ensemble mean MAE  : 0.332080
# Average Δ MAE      : -0.012004
# Average Δ MAE (%)  : -3.75%
