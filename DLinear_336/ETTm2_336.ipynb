# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(3)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 3
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTm2.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                           HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# date
# 2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 2016-07-01 00:15:00  39.622002  11.309  35.543999  8.551  3.209  1.258
# 2016-07-01 00:30:00  38.868000  10.555  34.365002  7.586  4.435  1.258
# 2016-07-01 00:45:00  35.518002   9.214  32.569000  8.712  4.435  1.215
# 2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
#
#                             OT
# date
# 2016-07-01 00:00:00  38.661999
# 2016-07-01 00:15:00  38.223000
# 2016-07-01 00:30:00  37.344002
# 2016-07-01 00:45:00  37.124001
# 2016-07-01 01:00:00  37.124001

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (69680, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 00:15:00',
#                '2016-07-01 00:30:00', '2016-07-01 00:45:00',
#                '2016-07-01 01:00:00', '2016-07-01 01:15:00',
#                '2016-07-01 01:30:00', '2016-07-01 01:45:00',
#                '2016-07-01 02:00:00', '2016-07-01 02:15:00',
#                ...
#                '2018-06-26 17:30:00', '2018-06-26 17:45:00',
#                '2018-06-26 18:00:00', '2018-06-26 18:15:00',
#                '2018-06-26 18:30:00', '2018-06-26 18:45:00',
#                '2018-06-26 19:00:00', '2018-06-26 19:15:00',
#                '2018-06-26 19:30:00', '2018-06-26 19:45:00'],
#               dtype='datetime64[ns]', name='date', length=69680, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Decomposition-Linear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.individual = configs.individual
        self.channels = configs.enc_in
        self.attach_to_trend = configs.attach_to_trend
        self.attach_to_seasonal = configs.attach_to_seasonal
        

        
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        

        
        self.seq_len_trend = self.seq_len + (self.pred_len // 3) if self.attach_to_trend else self.seq_len
        self.seq_len_seasonal = self.seq_len + (self.pred_len // 3) if self.attach_to_seasonal else self.seq_len

        
        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))

                
                
                
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            
            
            
            

    def forward(self, x, ground_truth=None):
        
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if ground_truth is not None:
            kernel_size = 25
            self.decompsition = series_decomp(kernel_size)
            ground_truth_seasonal, ground_truth_trend = self.decompsition(ground_truth)

            
            if self.seq_len_seasonal > self.seq_len:
                ground_truth_seasonal=ground_truth_seasonal.permute(0, 2, 1)
                
                seasonal_init = torch.cat([seasonal_init, ground_truth_seasonal], dim=2)
            if self.seq_len_trend > self.seq_len:
                ground_truth_trend=ground_truth_trend.permute(0, 2, 1)
                
                trend_init = torch.cat([trend_init, ground_truth_trend], dim=2)
        
        
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 336




train_points = 12 * 30 * 24 * 4
val_points   = 4  * 30 * 24 * 4
test_points  = 4  * 30 * 24 * 4

border1s = [
    0,
    train_points - seq_len,
    train_points + val_points - seq_len
]
border2s = [
    train_points,
    train_points + val_points,
    train_points + val_points + test_points
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([33889, 336, 1])
# Train Labels:    torch.Size([33889, 336, 1])
# Val Sequences:   torch.Size([11185, 336, 1])
# Val Labels:      torch.Size([11185, 336, 1])
# Test Sequences:  torch.Size([11185, 336, 1])
# Test Labels:     torch.Size([11185, 336, 1])

# %%
set_seed(43)

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.39073987032444973 | Val Loss: 0.6985291379477296
# Validation loss decreased (inf --> 0.698529).  Saving model ...
# Updating learning rate to 0.01
# Epoch 1 | Train Loss: 0.22799163176765982 | Val Loss: 0.9768945653310844
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.005
# Epoch 2 | Train Loss: 0.20740368601707918 | Val Loss: 0.3685051675140858
# Validation loss decreased (0.698529 --> 0.368505).  Saving model ...
# Updating learning rate to 0.0025
# Epoch 3 | Train Loss: 0.19266288872316198 | Val Loss: 0.1910475862052824
# Validation loss decreased (0.368505 --> 0.191048).  Saving model ...
# Updating learning rate to 0.00125
# Epoch 4 | Train Loss: 0.18145695734979972 | Val Loss: 0.19404145391391855
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000625
# Epoch 5 | Train Loss: 0.17832627050438019 | Val Loss: 0.2148685178373541
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0003125
# Epoch 6 | Train Loss: 0.17655200227603035 | Val Loss: 0.17419709737279584
# Validation loss decreased (0.191048 --> 0.174197).  Saving model ...
# Updating learning rate to 0.00015625
# Epoch 7 | Train Loss: 0.17550074982474434 | Val Loss: 0.17314538793106166
# Validation loss decreased (0.174197 --> 0.173145).  Saving model ...
# Updating learning rate to 7.8125e-05
# Epoch 8 | Train Loss: 0.17395518434075816 | Val Loss: 0.17040999460034073
# Validation loss decreased (0.173145 --> 0.170410).  Saving model ...
# Updating learning rate to 3.90625e-05
# Epoch 9 | Train Loss: 0.17342868527081215 | Val Loss: 0.17097573150215403
# EarlyStopping counter: 1 out of 3

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.399221660484964 | Val Loss: 0.5770114834606648
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.11894708126783371 | MAE: 0.26126450300216675
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.5090018510818481 | MAE: 0.5415194034576416

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.17051784694194794 | MAE: 0.3140697479248047
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.5775970220565796 | MAE: 0.5731700658798218

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.17339102923870087 | MAE: 0.30469655990600586
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.48846179246902466 | MAE: 0.5254870653152466

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([33889, 336, 1])
# val_sequences shape:  torch.Size([11185, 336, 1])
# test_sequences shape:  torch.Size([11185, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([33889, 336, 1])
# val_pv shape:  torch.Size([11185, 336, 1])
# test_pv shape:  torch.Size([11185, 336, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([33889, 336, 1])
# val_labels shape:  torch.Size([11185, 336, 1])
# test_labels shape:  torch.Size([11185, 336, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 336

# %%
segment_len = configs.pred_len // 3
stride = 4

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([33889, 57, 112, 1]), Val: torch.Size([11185, 57, 112, 1]), Test: torch.Size([11185, 57, 112, 1])
# [Epoch 1] Train seg shape: torch.Size([33889, 57, 112, 1]), Val: torch.Size([11185, 57, 112, 1]), Test: torch.Size([11185, 57, 112, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTm2'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 0] Training Time = 2.68 sec
# [Segment 0] GPU Memory Start = 5649.03 MB
# [Segment 0] GPU Memory End   = 4282.00 MB
# [Segment 0] GPU Peak Memory  = 5649.03 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 1] Training Time = 2.01 sec
# [Segment 1] GPU Memory Start = 4282.00 MB
# [Segment 1] GPU Memory End   = 4283.15 MB
# [Segment 1] GPU Peak Memory  = 4284.62 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 2] Training Time = 2.05 sec
# [Segment 2] GPU Memory Start = 4283.15 MB
# [Segment 2] GPU Memory End   = 4284.30 MB
# [Segment 2] GPU Peak Memory  = 4285.78 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 3] Training Time = 2.40 sec
# [Segment 3] GPU Memory Start = 4284.30 MB
# [Segment 3] GPU Memory End   = 4285.46 MB
# [Segment 3] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 4] Training Time = 2.44 sec
# [Segment 4] GPU Memory Start = 4285.46 MB
# [Segment 4] GPU Memory End   = 4286.61 MB
# [Segment 4] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 5] Training Time = 2.00 sec
# [Segment 5] GPU Memory Start = 4286.61 MB
# [Segment 5] GPU Memory End   = 4287.76 MB
# [Segment 5] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 6] Training Time = 2.48 sec
# [Segment 6] GPU Memory Start = 4287.76 MB
# [Segment 6] GPU Memory End   = 4288.91 MB
# [Segment 6] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 7] Training Time = 2.18 sec
# [Segment 7] GPU Memory Start = 4288.91 MB
# [Segment 7] GPU Memory End   = 4290.06 MB
# [Segment 7] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 8] Training Time = 2.48 sec
# [Segment 8] GPU Memory Start = 4290.06 MB
# [Segment 8] GPU Memory End   = 4291.21 MB
# [Segment 8] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 9] Training Time = 2.26 sec
# [Segment 9] GPU Memory Start = 4291.21 MB
# [Segment 9] GPU Memory End   = 4292.36 MB
# [Segment 9] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 10] Training Time = 2.20 sec
# [Segment 10] GPU Memory Start = 4282.00 MB
# [Segment 10] GPU Memory End   = 4283.15 MB
# [Segment 10] GPU Peak Memory  = 4284.62 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 11] Training Time = 3.00 sec
# [Segment 11] GPU Memory Start = 4283.15 MB
# [Segment 11] GPU Memory End   = 4284.30 MB
# [Segment 11] GPU Peak Memory  = 4285.78 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 12] Training Time = 2.75 sec
# [Segment 12] GPU Memory Start = 4284.30 MB
# [Segment 12] GPU Memory End   = 4285.46 MB
# [Segment 12] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 13] Training Time = 2.50 sec
# [Segment 13] GPU Memory Start = 4285.46 MB
# [Segment 13] GPU Memory End   = 4286.61 MB
# [Segment 13] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 14] Training Time = 2.24 sec
# [Segment 14] GPU Memory Start = 4286.61 MB
# [Segment 14] GPU Memory End   = 4287.76 MB
# [Segment 14] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 15] Training Time = 2.29 sec
# [Segment 15] GPU Memory Start = 4287.76 MB
# [Segment 15] GPU Memory End   = 4288.91 MB
# [Segment 15] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 16] Training Time = 2.11 sec
# [Segment 16] GPU Memory Start = 4288.91 MB
# [Segment 16] GPU Memory End   = 4290.06 MB
# [Segment 16] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 17] Training Time = 2.75 sec
# [Segment 17] GPU Memory Start = 4290.06 MB
# [Segment 17] GPU Memory End   = 4291.21 MB
# [Segment 17] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 18] Training Time = 2.85 sec
# [Segment 18] GPU Memory Start = 4291.21 MB
# [Segment 18] GPU Memory End   = 4292.36 MB
# [Segment 18] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 19] Training Time = 3.78 sec
# [Segment 19] GPU Memory Start = 4292.36 MB
# [Segment 19] GPU Memory End   = 4282.00 MB
# [Segment 19] GPU Peak Memory  = 4293.52 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 20] Training Time = 3.21 sec
# [Segment 20] GPU Memory Start = 4282.00 MB
# [Segment 20] GPU Memory End   = 4283.15 MB
# [Segment 20] GPU Peak Memory  = 4284.62 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 21] Training Time = 3.69 sec
# [Segment 21] GPU Memory Start = 4283.15 MB
# [Segment 21] GPU Memory End   = 4284.30 MB
# [Segment 21] GPU Peak Memory  = 4285.78 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 22] Training Time = 3.07 sec
# [Segment 22] GPU Memory Start = 4284.30 MB
# [Segment 22] GPU Memory End   = 4285.46 MB
# [Segment 22] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 23] Training Time = 2.00 sec
# [Segment 23] GPU Memory Start = 4285.46 MB
# [Segment 23] GPU Memory End   = 4286.61 MB
# [Segment 23] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 24] Training Time = 4.22 sec
# [Segment 24] GPU Memory Start = 4286.61 MB
# [Segment 24] GPU Memory End   = 4287.76 MB
# [Segment 24] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 25] Training Time = 3.91 sec
# [Segment 25] GPU Memory Start = 4287.76 MB
# [Segment 25] GPU Memory End   = 4288.91 MB
# [Segment 25] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 26] Training Time = 2.90 sec
# [Segment 26] GPU Memory Start = 4288.91 MB
# [Segment 26] GPU Memory End   = 4290.06 MB
# [Segment 26] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 27] Training Time = 3.92 sec
# [Segment 27] GPU Memory Start = 4290.06 MB
# [Segment 27] GPU Memory End   = 4291.21 MB
# [Segment 27] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 28] Training Time = 3.78 sec
# [Segment 28] GPU Memory Start = 4291.21 MB
# [Segment 28] GPU Memory End   = 4292.36 MB
# [Segment 28] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 29] Training Time = 3.21 sec
# [Segment 29] GPU Memory Start = 4282.00 MB
# [Segment 29] GPU Memory End   = 4283.15 MB
# [Segment 29] GPU Peak Memory  = 4284.62 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 30] Training Time = 3.81 sec
# [Segment 30] GPU Memory Start = 4283.15 MB
# [Segment 30] GPU Memory End   = 4284.30 MB
# [Segment 30] GPU Peak Memory  = 4285.78 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 31] Training Time = 3.70 sec
# [Segment 31] GPU Memory Start = 4284.30 MB
# [Segment 31] GPU Memory End   = 4285.46 MB
# [Segment 31] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 32] Training Time = 2.75 sec
# [Segment 32] GPU Memory Start = 4285.46 MB
# [Segment 32] GPU Memory End   = 4286.61 MB
# [Segment 32] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 33] Training Time = 3.53 sec
# [Segment 33] GPU Memory Start = 4286.61 MB
# [Segment 33] GPU Memory End   = 4287.76 MB
# [Segment 33] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 34] Training Time = 3.82 sec
# [Segment 34] GPU Memory Start = 4287.76 MB
# [Segment 34] GPU Memory End   = 4288.91 MB
# [Segment 34] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 35] Training Time = 2.72 sec
# [Segment 35] GPU Memory Start = 4288.91 MB
# [Segment 35] GPU Memory End   = 4290.06 MB
# [Segment 35] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 36] Training Time = 2.32 sec
# [Segment 36] GPU Memory Start = 4290.06 MB
# [Segment 36] GPU Memory End   = 4291.21 MB
# [Segment 36] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 37] Training Time = 2.37 sec
# [Segment 37] GPU Memory Start = 4291.21 MB
# [Segment 37] GPU Memory End   = 4292.36 MB
# [Segment 37] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 38] Training Time = 2.49 sec
# [Segment 38] GPU Memory Start = 4292.36 MB
# [Segment 38] GPU Memory End   = 4283.15 MB
# [Segment 38] GPU Peak Memory  = 4293.52 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 39] Training Time = 2.08 sec
# [Segment 39] GPU Memory Start = 4283.15 MB
# [Segment 39] GPU Memory End   = 4284.30 MB
# [Segment 39] GPU Peak Memory  = 4285.78 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 40] Training Time = 1.98 sec
# [Segment 40] GPU Memory Start = 4284.30 MB
# [Segment 40] GPU Memory End   = 4285.46 MB
# [Segment 40] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 41] Training Time = 2.22 sec
# [Segment 41] GPU Memory Start = 4285.46 MB
# [Segment 41] GPU Memory End   = 4286.61 MB
# [Segment 41] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 42] Training Time = 2.31 sec
# [Segment 42] GPU Memory Start = 4286.61 MB
# [Segment 42] GPU Memory End   = 4287.76 MB
# [Segment 42] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 43] Training Time = 2.28 sec
# [Segment 43] GPU Memory Start = 4287.76 MB
# [Segment 43] GPU Memory End   = 4288.91 MB
# [Segment 43] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 44] Training Time = 1.92 sec
# [Segment 44] GPU Memory Start = 4288.91 MB
# [Segment 44] GPU Memory End   = 4290.06 MB
# [Segment 44] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 45] Training Time = 3.06 sec
# [Segment 45] GPU Memory Start = 4290.06 MB
# [Segment 45] GPU Memory End   = 4291.21 MB
# [Segment 45] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 46] Training Time = 2.26 sec
# [Segment 46] GPU Memory Start = 4291.21 MB
# [Segment 46] GPU Memory End   = 4292.36 MB
# [Segment 46] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 47] Training Time = 3.44 sec
# [Segment 47] GPU Memory Start = 4292.36 MB
# [Segment 47] GPU Memory End   = 4293.52 MB
# [Segment 47] GPU Peak Memory  = 4294.99 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 48] Training Time = 3.61 sec
# [Segment 48] GPU Memory Start = 4283.15 MB
# [Segment 48] GPU Memory End   = 4284.30 MB
# [Segment 48] GPU Peak Memory  = 4285.78 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 49] Training Time = 3.37 sec
# [Segment 49] GPU Memory Start = 4284.30 MB
# [Segment 49] GPU Memory End   = 4285.46 MB
# [Segment 49] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 50] Training Time = 3.12 sec
# [Segment 50] GPU Memory Start = 4285.46 MB
# [Segment 50] GPU Memory End   = 4286.61 MB
# [Segment 50] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 51] Training Time = 3.23 sec
# [Segment 51] GPU Memory Start = 4286.61 MB
# [Segment 51] GPU Memory End   = 4287.76 MB
# [Segment 51] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 52] Training Time = 3.31 sec
# [Segment 52] GPU Memory Start = 4287.76 MB
# [Segment 52] GPU Memory End   = 4288.91 MB
# [Segment 52] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 53] Training Time = 3.58 sec
# [Segment 53] GPU Memory Start = 4288.91 MB
# [Segment 53] GPU Memory End   = 4290.06 MB
# [Segment 53] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 54] Training Time = 3.28 sec
# [Segment 54] GPU Memory Start = 4290.06 MB
# [Segment 54] GPU Memory End   = 4291.21 MB
# [Segment 54] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 55] Training Time = 3.60 sec
# [Segment 55] GPU Memory Start = 4291.21 MB
# [Segment 55] GPU Memory End   = 4292.36 MB
# [Segment 55] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 56] Training Time = 3.36 sec
# [Segment 56] GPU Memory Start = 4292.36 MB
# [Segment 56] GPU Memory End   = 4293.52 MB
# [Segment 56] GPU Peak Memory  = 4294.99 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E/",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 0] Training Time = 4.83 sec
# [Segment 0] GPU Memory Start = 4284.30 MB
# [Segment 0] GPU Memory End   = 4284.30 MB
# [Segment 0] GPU Peak Memory  = 4286.81 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 1] Training Time = 4.01 sec
# [Segment 1] GPU Memory Start = 4284.30 MB
# [Segment 1] GPU Memory End   = 4285.46 MB
# [Segment 1] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 2] Training Time = 4.28 sec
# [Segment 2] GPU Memory Start = 4285.46 MB
# [Segment 2] GPU Memory End   = 4284.30 MB
# [Segment 2] GPU Peak Memory  = 4286.81 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 3] Training Time = 5.12 sec
# [Segment 3] GPU Memory Start = 4284.30 MB
# [Segment 3] GPU Memory End   = 4285.46 MB
# [Segment 3] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 4] Training Time = 5.75 sec
# [Segment 4] GPU Memory Start = 4285.46 MB
# [Segment 4] GPU Memory End   = 4286.61 MB
# [Segment 4] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 5] Training Time = 4.40 sec
# [Segment 5] GPU Memory Start = 4286.61 MB
# [Segment 5] GPU Memory End   = 4287.76 MB
# [Segment 5] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 6] Training Time = 5.35 sec
# [Segment 6] GPU Memory Start = 4287.76 MB
# [Segment 6] GPU Memory End   = 4288.91 MB
# [Segment 6] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 7] Training Time = 5.71 sec
# [Segment 7] GPU Memory Start = 4288.91 MB
# [Segment 7] GPU Memory End   = 4290.06 MB
# [Segment 7] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 8] Training Time = 5.03 sec
# [Segment 8] GPU Memory Start = 4290.06 MB
# [Segment 8] GPU Memory End   = 4291.21 MB
# [Segment 8] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 9] Training Time = 5.26 sec
# [Segment 9] GPU Memory Start = 4291.21 MB
# [Segment 9] GPU Memory End   = 4292.36 MB
# [Segment 9] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 10] Training Time = 5.22 sec
# [Segment 10] GPU Memory Start = 4292.36 MB
# [Segment 10] GPU Memory End   = 4293.52 MB
# [Segment 10] GPU Peak Memory  = 4294.99 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 11] Training Time = 4.93 sec
# [Segment 11] GPU Memory Start = 4293.52 MB
# [Segment 11] GPU Memory End   = 4294.67 MB
# [Segment 11] GPU Peak Memory  = 4296.14 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 12] Training Time = 5.16 sec
# [Segment 12] GPU Memory Start = 4284.30 MB
# [Segment 12] GPU Memory End   = 4285.46 MB
# [Segment 12] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 13] Training Time = 6.10 sec
# [Segment 13] GPU Memory Start = 4285.46 MB
# [Segment 13] GPU Memory End   = 4286.61 MB
# [Segment 13] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 14] Training Time = 5.58 sec
# [Segment 14] GPU Memory Start = 4286.61 MB
# [Segment 14] GPU Memory End   = 4287.76 MB
# [Segment 14] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 15] Training Time = 4.93 sec
# [Segment 15] GPU Memory Start = 4287.76 MB
# [Segment 15] GPU Memory End   = 4288.91 MB
# [Segment 15] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 16] Training Time = 4.25 sec
# [Segment 16] GPU Memory Start = 4288.91 MB
# [Segment 16] GPU Memory End   = 4290.06 MB
# [Segment 16] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 17] Training Time = 4.83 sec
# [Segment 17] GPU Memory Start = 4290.06 MB
# [Segment 17] GPU Memory End   = 4291.21 MB
# [Segment 17] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 18] Training Time = 5.52 sec
# [Segment 18] GPU Memory Start = 4291.21 MB
# [Segment 18] GPU Memory End   = 4292.36 MB
# [Segment 18] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 19] Training Time = 2.98 sec
# [Segment 19] GPU Memory Start = 4292.36 MB
# [Segment 19] GPU Memory End   = 4293.52 MB
# [Segment 19] GPU Peak Memory  = 4294.99 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 20] Training Time = 2.74 sec
# [Segment 20] GPU Memory Start = 4293.52 MB
# [Segment 20] GPU Memory End   = 4294.67 MB
# [Segment 20] GPU Peak Memory  = 4296.14 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 21] Training Time = 2.93 sec
# [Segment 21] GPU Memory Start = 4294.67 MB
# [Segment 21] GPU Memory End   = 4285.46 MB
# [Segment 21] GPU Peak Memory  = 4295.82 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 22] Training Time = 2.94 sec
# [Segment 22] GPU Memory Start = 4285.46 MB
# [Segment 22] GPU Memory End   = 4286.61 MB
# [Segment 22] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 23] Training Time = 2.75 sec
# [Segment 23] GPU Memory Start = 4286.61 MB
# [Segment 23] GPU Memory End   = 4287.76 MB
# [Segment 23] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 24] Training Time = 2.91 sec
# [Segment 24] GPU Memory Start = 4287.76 MB
# [Segment 24] GPU Memory End   = 4288.91 MB
# [Segment 24] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 25] Training Time = 2.75 sec
# [Segment 25] GPU Memory Start = 4288.91 MB
# [Segment 25] GPU Memory End   = 4290.06 MB
# [Segment 25] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 26] Training Time = 5.18 sec
# [Segment 26] GPU Memory Start = 4290.06 MB
# [Segment 26] GPU Memory End   = 4291.21 MB
# [Segment 26] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 27] Training Time = 5.60 sec
# [Segment 27] GPU Memory Start = 4291.21 MB
# [Segment 27] GPU Memory End   = 4292.36 MB
# [Segment 27] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 28] Training Time = 6.03 sec
# [Segment 28] GPU Memory Start = 4292.36 MB
# [Segment 28] GPU Memory End   = 4293.52 MB
# [Segment 28] GPU Peak Memory  = 4294.99 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 29] Training Time = 6.47 sec
# [Segment 29] GPU Memory Start = 4293.52 MB
# [Segment 29] GPU Memory End   = 4294.67 MB
# [Segment 29] GPU Peak Memory  = 4296.14 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 30] Training Time = 6.38 sec
# [Segment 30] GPU Memory Start = 4294.67 MB
# [Segment 30] GPU Memory End   = 4295.82 MB
# [Segment 30] GPU Peak Memory  = 4297.29 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 31] Training Time = 6.45 sec
# [Segment 31] GPU Memory Start = 4282.00 MB
# [Segment 31] GPU Memory End   = 4283.15 MB
# [Segment 31] GPU Peak Memory  = 4284.62 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 32] Training Time = 6.41 sec
# [Segment 32] GPU Memory Start = 4283.15 MB
# [Segment 32] GPU Memory End   = 4284.30 MB
# [Segment 32] GPU Peak Memory  = 4285.78 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 33] Training Time = 6.16 sec
# [Segment 33] GPU Memory Start = 4284.30 MB
# [Segment 33] GPU Memory End   = 4285.46 MB
# [Segment 33] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 34] Training Time = 6.43 sec
# [Segment 34] GPU Memory Start = 4285.46 MB
# [Segment 34] GPU Memory End   = 4286.61 MB
# [Segment 34] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 35] Training Time = 6.56 sec
# [Segment 35] GPU Memory Start = 4286.61 MB
# [Segment 35] GPU Memory End   = 4287.76 MB
# [Segment 35] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 36] Training Time = 6.56 sec
# [Segment 36] GPU Memory Start = 4287.76 MB
# [Segment 36] GPU Memory End   = 4288.91 MB
# [Segment 36] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 37] Training Time = 6.47 sec
# [Segment 37] GPU Memory Start = 4288.91 MB
# [Segment 37] GPU Memory End   = 4290.06 MB
# [Segment 37] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 38] Training Time = 5.76 sec
# [Segment 38] GPU Memory Start = 4290.06 MB
# [Segment 38] GPU Memory End   = 4291.21 MB
# [Segment 38] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 39] Training Time = 6.05 sec
# [Segment 39] GPU Memory Start = 4291.21 MB
# [Segment 39] GPU Memory End   = 4292.36 MB
# [Segment 39] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 40] Training Time = 6.10 sec
# [Segment 40] GPU Memory Start = 4292.36 MB
# [Segment 40] GPU Memory End   = 4283.15 MB
# [Segment 40] GPU Peak Memory  = 4293.52 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 41] Training Time = 5.93 sec
# [Segment 41] GPU Memory Start = 4283.15 MB
# [Segment 41] GPU Memory End   = 4284.30 MB
# [Segment 41] GPU Peak Memory  = 4285.78 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 42] Training Time = 5.98 sec
# [Segment 42] GPU Memory Start = 4284.30 MB
# [Segment 42] GPU Memory End   = 4285.46 MB
# [Segment 42] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 43] Training Time = 5.66 sec
# [Segment 43] GPU Memory Start = 4285.46 MB
# [Segment 43] GPU Memory End   = 4286.61 MB
# [Segment 43] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 44] Training Time = 6.00 sec
# [Segment 44] GPU Memory Start = 4286.61 MB
# [Segment 44] GPU Memory End   = 4287.76 MB
# [Segment 44] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 45] Training Time = 6.05 sec
# [Segment 45] GPU Memory Start = 4287.76 MB
# [Segment 45] GPU Memory End   = 4288.91 MB
# [Segment 45] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 46] Training Time = 6.45 sec
# [Segment 46] GPU Memory Start = 4288.91 MB
# [Segment 46] GPU Memory End   = 4290.06 MB
# [Segment 46] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 47] Training Time = 6.78 sec
# [Segment 47] GPU Memory Start = 4290.06 MB
# [Segment 47] GPU Memory End   = 4291.21 MB
# [Segment 47] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 48] Training Time = 6.62 sec
# [Segment 48] GPU Memory Start = 4291.21 MB
# [Segment 48] GPU Memory End   = 4292.36 MB
# [Segment 48] GPU Peak Memory  = 4293.84 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 49] Training Time = 5.92 sec
# [Segment 49] GPU Memory Start = 4292.36 MB
# [Segment 49] GPU Memory End   = 4293.52 MB
# [Segment 49] GPU Peak Memory  = 4294.99 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 50] Training Time = 2.88 sec
# [Segment 50] GPU Memory Start = 4283.15 MB
# [Segment 50] GPU Memory End   = 4284.30 MB
# [Segment 50] GPU Peak Memory  = 4285.78 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 51] Training Time = 2.77 sec
# [Segment 51] GPU Memory Start = 4284.30 MB
# [Segment 51] GPU Memory End   = 4285.46 MB
# [Segment 51] GPU Peak Memory  = 4286.93 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 52] Training Time = 2.68 sec
# [Segment 52] GPU Memory Start = 4285.46 MB
# [Segment 52] GPU Memory End   = 4286.61 MB
# [Segment 52] GPU Peak Memory  = 4288.08 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 53] Training Time = 3.03 sec
# [Segment 53] GPU Memory Start = 4286.61 MB
# [Segment 53] GPU Memory End   = 4287.76 MB
# [Segment 53] GPU Peak Memory  = 4289.23 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 54] Training Time = 2.90 sec
# [Segment 54] GPU Memory Start = 4287.76 MB
# [Segment 54] GPU Memory End   = 4288.91 MB
# [Segment 54] GPU Peak Memory  = 4290.38 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 55] Training Time = 2.78 sec
# [Segment 55] GPU Memory Start = 4288.91 MB
# [Segment 55] GPU Memory End   = 4290.06 MB
# [Segment 55] GPU Peak Memory  = 4291.53 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 56] Training Time = 2.91 sec
# [Segment 56] GPU Memory Start = 4290.06 MB
# [Segment 56] GPU Memory End   = 4291.21 MB
# [Segment 56] GPU Peak Memory  = 4292.68 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ETTm2_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.3669124245643616  MAE:0.46884068846702576
# ▶ seg0  mean  MSE:0.3669124245643616  MAE:0.46884068846702576
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.33846908807754517  MAE:0.4454842507839203
# ▶ seg1  mean  MSE:0.33846908807754517  MAE:0.4454842507839203
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.6847611665725708  MAE:0.6242201924324036
# ▶ seg2  mean  MSE:0.6847611665725708  MAE:0.6242201924324036
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:1.0921530723571777  MAE:0.800290048122406
# ▶ seg3  mean  MSE:1.0921530723571777  MAE:0.800290048122406
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.6718527674674988  MAE:0.6208670735359192
# ▶ seg4  mean  MSE:0.6718527674674988  MAE:0.6208670735359192
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.5667615532875061  MAE:0.5800216197967529
# ▶ seg5  mean  MSE:0.5667615532875061  MAE:0.5800216197967529
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.5227470397949219  MAE:0.5354649424552917
# ▶ seg6  mean  MSE:0.5227470397949219  MAE:0.5354649424552917
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.9915357232093811  MAE:0.7695995569229126
# ▶ seg7  mean  MSE:0.9915357232093811  MAE:0.7695995569229126
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.9132165312767029  MAE:0.7164486050605774
# ▶ seg8  mean  MSE:0.9132165312767029  MAE:0.7164486050605774
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.33867761492729187  MAE:0.4501749277114868
# ▶ seg9  mean  MSE:0.33867761492729187  MAE:0.4501749277114868
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.46878984570503235  MAE:0.5279221534729004
# ▶ seg10  mean  MSE:0.46878984570503235  MAE:0.5279221534729004
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.6104776859283447  MAE:0.5684162974357605
# ▶ seg11  mean  MSE:0.6104776859283447  MAE:0.5684162974357605
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:1.0165399312973022  MAE:0.7683089375495911
# ▶ seg12  mean  MSE:1.0165399312973022  MAE:0.7683089375495911
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:1.9281872510910034  MAE:1.0900790691375732
# ▶ seg13  mean  MSE:1.9281872510910034  MAE:1.0900790691375732
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.6356757283210754  MAE:0.6012411117553711
# ▶ seg14  mean  MSE:0.6356757283210754  MAE:0.6012411117553711
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.6049819588661194  MAE:0.589317262172699
# ▶ seg41  mean  MSE:0.6049819588661194  MAE:0.589317262172699
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.4776683747768402  MAE:0.5167844891548157
# ▶ seg42  mean  MSE:0.4776683747768402  MAE:0.5167844891548157
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.48956719040870667  MAE:0.5506199598312378
# ▶ seg43  mean  MSE:0.48956719040870667  MAE:0.5506199598312378
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.5635088682174683  MAE:0.5807549357414246
# ▶ seg44  mean  MSE:0.5635088682174683  MAE:0.5807549357414246
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.41045552492141724  MAE:0.4975210130214691
# ▶ seg45  mean  MSE:0.41045552492141724  MAE:0.4975210130214691
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.5644318461418152  MAE:0.5943779945373535
# ▶ seg46  mean  MSE:0.5644318461418152  MAE:0.5943779945373535
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.5362180471420288  MAE:0.5492989420890808
# ▶ seg47  mean  MSE:0.5362180471420288  MAE:0.5492989420890808
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.2893863022327423  MAE:0.41814982891082764
# ▶ seg48  mean  MSE:0.2893863022327423  MAE:0.41814982891082764
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.33616524934768677  MAE:0.4441099464893341
# ▶ seg49  mean  MSE:0.33616524934768677  MAE:0.4441099464893341
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.4541376531124115  MAE:0.5165187120437622
# ▶ seg50  mean  MSE:0.4541376531124115  MAE:0.5165187120437622
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.38343310356140137  MAE:0.47792983055114746
# ▶ seg51  mean  MSE:0.38343310356140137  MAE:0.47792983055114746
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.5944172739982605  MAE:0.5839698314666748
# ▶ seg52  mean  MSE:0.5944172739982605  MAE:0.5839698314666748
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:2.398242473602295  MAE:1.0644636154174805
# ▶ seg53  mean  MSE:2.398242473602295  MAE:1.0644636154174805
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:1.2156721353530884  MAE:0.8062731027603149
# ▶ seg54  mean  MSE:1.2156721353530884  MAE:0.8062731027603149
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:1.2949576377868652  MAE:0.8350955247879028
# ▶ seg55  mean  MSE:1.2949576377868652  MAE:0.8350955247879028
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:1.011502742767334  MAE:0.7604488134384155
# ▶ seg56  mean  MSE:1.011502742767334  MAE:0.7604488134384155
#
# seg10 ch0 MSE : 0.46878985

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ETTm2_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.6822207570075989  MAE:0.6091182231903076
# ▶ seg0  mean  MSE:0.6822207570075989  MAE:0.6091182231903076
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.47951948642730713  MAE:0.51523357629776
# ▶ seg1  mean  MSE:0.47951948642730713  MAE:0.51523357629776
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.7337758541107178  MAE:0.628127932548523
# ▶ seg2  mean  MSE:0.7337758541107178  MAE:0.628127932548523
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.6648446917533875  MAE:0.5845053195953369
# ▶ seg3  mean  MSE:0.6648446917533875  MAE:0.5845053195953369
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.5603228211402893  MAE:0.5626655220985413
# ▶ seg4  mean  MSE:0.5603228211402893  MAE:0.5626655220985413
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.71852707862854  MAE:0.6331582069396973
# ▶ seg5  mean  MSE:0.71852707862854  MAE:0.6331582069396973
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.489473819732666  MAE:0.5336753726005554
# ▶ seg6  mean  MSE:0.489473819732666  MAE:0.5336753726005554
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.9465146660804749  MAE:0.7142019867897034
# ▶ seg40  mean  MSE:0.9465146660804749  MAE:0.7142019867897034
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.5701058506965637  MAE:0.5906085968017578
# ▶ seg41  mean  MSE:0.5701058506965637  MAE:0.5906085968017578
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.19237186014652252  MAE:0.3413945734500885
# ▶ seg42  mean  MSE:0.19237186014652252  MAE:0.3413945734500885
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.8970018625259399  MAE:0.7668787837028503
# ▶ seg43  mean  MSE:0.8970018625259399  MAE:0.7668787837028503
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.834347665309906  MAE:0.6774331331253052
# ▶ seg44  mean  MSE:0.834347665309906  MAE:0.6774331331253052
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:1.0187721252441406  MAE:0.7667824029922485
# ▶ seg45  mean  MSE:1.0187721252441406  MAE:0.7667824029922485
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:2.795614004135132  MAE:1.231902003288269
# ▶ seg46  mean  MSE:2.795614004135132  MAE:1.231902003288269
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.41667085886001587  MAE:0.4974592626094818
# ▶ seg47  mean  MSE:0.41667085886001587  MAE:0.4974592626094818
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.7789996266365051  MAE:0.6717134118080139
# ▶ seg48  mean  MSE:0.7789996266365051  MAE:0.6717134118080139
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.7066808342933655  MAE:0.6351514458656311
# ▶ seg49  mean  MSE:0.7066808342933655  MAE:0.6351514458656311
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.5112648010253906  MAE:0.5558336973190308
# ▶ seg50  mean  MSE:0.5112648010253906  MAE:0.5558336973190308
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.6961541771888733  MAE:0.6660729050636292
# ▶ seg51  mean  MSE:0.6961541771888733  MAE:0.6660729050636292
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.5207502841949463  MAE:0.5568597912788391
# ▶ seg52  mean  MSE:0.5207502841949463  MAE:0.5568597912788391
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.5913599133491516  MAE:0.586346447467804
# ▶ seg53  mean  MSE:0.5913599133491516  MAE:0.586346447467804
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:1.249565839767456  MAE:0.8436310291290283
# ▶ seg54  mean  MSE:1.249565839767456  MAE:0.8436310291290283
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.6095998883247375  MAE:0.604669988155365
# ▶ seg55  mean  MSE:0.6095998883247375  MAE:0.604669988155365
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:2.917541265487671  MAE:1.214374303817749
# ▶ seg56  mean  MSE:2.917541265487671  MAE:1.214374303817749
#
# seg10 ch0 MSE : 0.4012096

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTm2_train = torch.load("./1st_results_ETTm2/train_1st_results.pt")
results1_ETTm2_val = torch.load("./1st_results_ETTm2/val_1st_results.pt")
results1_ETTm2_test = torch.load("./1st_results_ETTm2/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 57
SEG_CNT     = 57
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.577597
#
#   Top  1 | seg 37 | MSE 0.243404 (+0.334193)
#   Top  2 | seg 24 | MSE 0.264937 (+0.312660)
#   Top  3 | seg 48 | MSE 0.289386 (+0.288211)
#   Top  4 | seg 17 | MSE 0.296655 (+0.280942)
#   Top  5 | seg 19 | MSE 0.303001 (+0.274596)
#   Top  6 | seg 16 | MSE 0.315056 (+0.262541)
#   Top  7 | seg 28 | MSE 0.317392 (+0.260205)
#   Top  8 | seg 49 | MSE 0.336165 (+0.241432)
# Saved top segment indices per channel:
# Channel 0: [37, 24, 48, 17, 19, 16, 28, 49, 1, 9, 0, 51, 45, 23, 50, 18, 10, 42, 43, 29, 30, 40, 27, 6, 31, 47, 44, 46, 5, 35, 52, 41, 32, 11, 14, 38, 4, 2, 34, 33, 26, 36, 8, 25, 7, 56, 12, 3, 20, 54, 55, 15, 13, 53, 21, 39, 22]

# %% [markdown]
# ### 1E->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 57
SEG_CNT     = 57
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.577597
#
#   Top  1 | seg 42 | MSE 0.223379 (+0.354218)
#   Top  2 | seg 37 | MSE 0.277333 (+0.300264)
#   Top  3 | seg 31 | MSE 0.313819 (+0.263778)
#   Top  4 | seg 30 | MSE 0.326562 (+0.251035)
#   Top  5 | seg 22 | MSE 0.346464 (+0.231133)
#   Top  6 | seg 35 | MSE 0.364915 (+0.212683)
#   Top  7 | seg 36 | MSE 0.384541 (+0.193056)
#   Top  8 | seg 08 | MSE 0.405435 (+0.172162)
#   Top  9 | seg 47 | MSE 0.416124 (+0.161473)
#   Top 10 | seg 16 | MSE 0.422431 (+0.155166)
#   Top 11 | seg 07 | MSE 0.425837 (+0.151760)
#   Top 12 | seg 15 | MSE 0.438962 (+0.138635)
#   Top 13 | seg 28 | MSE 0.444183 (+0.133414)
#   Top 14 | seg 41 | MSE 0.458549 (+0.119048)
#   Top 15 | seg 01 | MSE 0.479519 (+0.098078)
#   Top 16 | seg 52 | MSE 0.480357 (+0.097240)
#   Top 17 | seg 10 | MSE 0.481513 (+0.096084)
#   Top 18 | seg 50 | MSE 0.485333 (+0.092264)
#   Top 19 | seg 06 | MSE 0.489474 (+0.088123)
#   Top 20 | seg 23 | MSE 0.505124 (+0.072473)
#   Top 21 | seg 13 | MSE 0.521805 (+0.055792)
#   Top 22 | seg 29 | MSE 0.526278 (+0.051319)
#   Top 23 | seg 04 | MSE 0.560323 (+0.017274)
#   Top 24 | seg 55 | MSE 0.560327 (+0.017270)
#   Top 25 | seg 24 | MSE 0.562057 (+0.015540)
#   Top 26 | seg 38 | MSE 0.565366 (+0.012231)
#   Top 27 | seg 17 | MSE 0.577005 (+0.000592)
#   Top 28 | seg 53 | MSE 0.588454 (-0.010857)
#   Top 29 | seg 14 | MSE 0.599940 (-0.022343)
#   Top 30 | seg 34 | MSE 0.602723 (-0.025126)
#   Top 31 | seg 49 | MSE 0.622519 (-0.044922)
#   Top 32 | seg 51 | MSE 0.631933 (-0.054336)
#   Top 33 | seg 03 | MSE 0.664845 (-0.087248)
#   Top 34 | seg 00 | MSE 0.682221 (-0.104624)
#   Top 35 | seg 21 | MSE 0.691981 (-0.114384)
#   Top 36 | seg 48 | MSE 0.697401 (-0.119804)
#   Top 37 | seg 05 | MSE 0.718527 (-0.140930)
#   Top 38 | seg 02 | MSE 0.733776 (-0.156179)
#   Top 39 | seg 44 | MSE 0.754773 (-0.177176)
#   Top 40 | seg 43 | MSE 0.759536 (-0.181939)
#   Top 41 | seg 40 | MSE 0.869146 (-0.291549)
#   Top 42 | seg 18 | MSE 0.881085 (-0.303488)
#   Top 43 | seg 27 | MSE 0.903955 (-0.326357)
#   Top 44 | seg 54 | MSE 0.924704 (-0.347107)
#   Top 45 | seg 45 | MSE 0.963749 (-0.386152)
#   Top 46 | seg 33 | MSE 1.172567 (-0.594970)
#   Top 47 | seg 25 | MSE 1.187517 (-0.609920)
#   Top 48 | seg 39 | MSE 1.209984 (-0.632387)
#   Top 49 | seg 12 | MSE 1.418848 (-0.841251)
#   Top 50 | seg 09 | MSE 1.653730 (-1.076133)
#   Top 51 | seg 32 | MSE 1.790557 (-1.212960)
#   Top 52 | seg 20 | MSE 1.976963 (-1.399366)
#   Top 53 | seg 11 | MSE 1.999108 (-1.421511)
#   Top 54 | seg 26 | MSE 2.062613 (-1.485016)
#   Top 55 | seg 46 | MSE 2.196145 (-1.618548)
#   Top 56 | seg 56 | MSE 2.422390 (-1.844793)
#   Top 57 | seg 19 | MSE 4.649888 (-4.072291)
#
# Saved top segment indices per channel:
# Channel 0: [42, 37, 31, 30, 22, 35, 36, 8, 47, 16, 7, 15, 28, 41, 1, 52, 10, 50, 6, 23, 13, 29, 4, 55, 24, 38, 17, 53, 14, 34, 49, 51, 3, 0, 21, 48, 5, 2, 44, 43, 40, 18, 27, 54, 45, 33, 25, 39, 12, 9, 32, 20, 11, 26, 46, 56, 19]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTm2_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.118947 | MAE : 0.261265
#   — Var / |Corr| / Score —
#    K= 5 | Var=1.474e-01 | |ρ|=0.6980 | S=1.0000
#    K=10 | Var=1.792e-01 | |ρ|=0.6780 | S=0.9717
#    K=15 | Var=2.240e-01 | |ρ|=0.6366 | S=0.8737
#    K=20 | Var=2.677e-01 | |ρ|=0.6119 | S=0.8471
#    K=25 | Var=3.037e-01 | |ρ|=0.5814 | S=0.7807
#    K=30 | Var=3.390e-01 | |ρ|=0.5483 | S=0.7016 <- pick
#    K=35 | Var=3.693e-01 | |ρ|=0.5447 | S=0.7423
#    K=40 | Var=4.129e-01 | |ρ|=0.5245 | S=0.7352
#    K=45 | Var=4.738e-01 | |ρ|=0.4974 | S=0.7302
#    K=50 | Var=5.412e-01 | |ρ|=0.4904 | S=0.8255
#    K=55 | Var=6.823e-01 | |ρ|=0.4700 | S=1.0000
# [Var-Corr]  K=30
#   MSE = 0.122476 | Δ = -0.003529 | Δ% = -2.97%
#   MAE = 0.266560 | Δ = -0.005296 | Δ% = -2.03%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.118947
# Ensemble mean MSE : 0.122476
# Average Δ MSE     : -0.003529
# Average Δ MSE (%) : -2.97%
#
# Vanilla  mean MAE : 0.261265
# Ensemble mean MAE : 0.266560
# Average Δ MAE     : -0.005296
# Average Δ MAE (%) : -2.03%

# %% [markdown]
# ## 1E->1E

# %%
results1_ETTm2_test['ES']['mae_test_EES']
# Out:
# 0.26126450300216675

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTm2_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.1   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.118947 | MAE : 0.261265
#   — Var / |Corr| / Score —
#    K= 5 | Var=1.633e-01 | |ρ|=0.7325 | S=1.1000
#    K=10 | Var=2.426e-01 | |ρ|=0.6354 | S=0.8769
#    K=15 | Var=2.831e-01 | |ρ|=0.5968 | S=0.8032
#    K=20 | Var=3.069e-01 | |ρ|=0.5799 | S=0.7811
#    K=25 | Var=3.417e-01 | |ρ|=0.5528 | S=0.7402
#    K=30 | Var=3.737e-01 | |ρ|=0.5231 | S=0.6850
#    K=35 | Var=4.058e-01 | |ρ|=0.5140 | S=0.7055
#    K=40 | Var=4.458e-01 | |ρ|=0.4899 | S=0.6846 <- pick
#    K=45 | Var=5.036e-01 | |ρ|=0.4686 | S=0.7037
#    K=50 | Var=5.959e-01 | |ρ|=0.4639 | S=0.8419
#    K=55 | Var=7.566e-01 | |ρ|=0.4332 | S=1.0000
# [Var-Corr]  K=40
#    MSE = 0.124272 | Δ = -0.005324 | Δ% = -4.48%
#    MAE = 0.267268 | Δ = -0.006004 | Δ% = -2.30%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.118947
# Ensemble mean MSE  : 0.124272
# Average Δ MSE      : -0.005324
# Average Δ MSE (%)  : -4.48%
#
# Vanilla  mean MAE  : 0.261265
# Ensemble mean MAE  : 0.267268
# Average Δ MAE      : -0.006004
# Average Δ MAE (%)  : -2.30%
