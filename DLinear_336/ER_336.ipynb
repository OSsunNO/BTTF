# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(2)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 2
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/exchange_rate.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                  0       1         2         3         4         5         6  \
# date
# 1990-01-01  0.7855  1.6110  0.861698  0.634196  0.211242  0.006838  0.525486
# 1990-01-02  0.7818  1.6100  0.861104  0.633513  0.211242  0.006863  0.523972
# 1990-01-03  0.7867  1.6293  0.861030  0.648508  0.211242  0.006975  0.526316
# 1990-01-04  0.7860  1.6370  0.862069  0.650618  0.211242  0.006953  0.523834
# 1990-01-05  0.7849  1.6530  0.861995  0.656254  0.211242  0.006940  0.527426
#
#                 OT
# date
# 1990-01-01  0.5930
# 1990-01-02  0.5940
# 1990-01-03  0.5973
# 1990-01-04  0.5970
# 1990-01-05  0.5985

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# OT    float64
# dtype: object
# shape:  (7588, 8)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2010-10-01', '2010-10-02', '2010-10-03', '2010-10-04',
#                '2010-10-05', '2010-10-06', '2010-10-07', '2010-10-08',
#                '2010-10-09', '2010-10-10'],
#               dtype='datetime64[ns]', name='date', length=7588, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %%
set_seed(24)

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Decomposition-Linear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.individual = configs.individual
        self.channels = configs.enc_in
        self.attach_to_trend = configs.attach_to_trend
        self.attach_to_seasonal = configs.attach_to_seasonal
        

        
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        

        
        self.seq_len_trend = self.seq_len + (self.pred_len // 3) if self.attach_to_trend else self.seq_len
        self.seq_len_seasonal = self.seq_len + (self.pred_len // 3) if self.attach_to_seasonal else self.seq_len

        
        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))

                
                
                
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            
            
            
            

    def forward(self, x, ground_truth=None):
        
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if ground_truth is not None:
            kernel_size = 25
            self.decompsition = series_decomp(kernel_size)
            ground_truth_seasonal, ground_truth_trend = self.decompsition(ground_truth)

            
            if self.seq_len_seasonal > self.seq_len:
                ground_truth_seasonal=ground_truth_seasonal.permute(0, 2, 1)
                
                seasonal_init = torch.cat([seasonal_init, ground_truth_seasonal], dim=2)
            if self.seq_len_trend > self.seq_len:
                ground_truth_trend=ground_truth_trend.permute(0, 2, 1)
                
                trend_init = torch.cat([trend_init, ground_truth_trend], dim=2)
        
        
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len  = 336
pred_len = 336


total_len  = len(target)
num_train  = int(total_len * 0.7)
num_test   = int(total_len * 0.2)
num_val    = total_len - num_train - num_test

border1s = [
    0,
    num_train - seq_len,
    total_len - num_test - seq_len
]
border2s = [
    num_train,
    num_train + num_val,
    total_len
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i : i + seq_len]
        seq_y = data[i + seq_len : i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([4640, 336, 1])
# Train Labels:    torch.Size([4640, 336, 1])
# Val Sequences:   torch.Size([425, 336, 1])
# Val Labels:      torch.Size([425, 336, 1])
# Test Sequences:  torch.Size([1182, 336, 1])
# Test Labels:     torch.Size([1182, 336, 1])

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ER", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.5504678999555522 | Val Loss: 0.532709671982697
# Validation loss decreased (inf --> 0.532710).  Saving model ...
# Updating learning rate to 0.0005
# Epoch 1 | Train Loss: 0.4664951377901538 | Val Loss: 0.6658745471920285
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00025
# Epoch 2 | Train Loss: 0.45578078072646566 | Val Loss: 0.6269557039652552
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.000125
# Epoch 3 | Train Loss: 0.4487764584607091 | Val Loss: 0.7484359081302371
# EarlyStopping counter: 3 out of 3
# Early stopping triggered. Stopping training.

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ER", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.5303110638569142 | Val Loss: 0.9471917918750218
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.33387142419815063 | MAE: 0.4766378402709961
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.6600522398948669 | MAE: 0.6091523766517639

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.550879716873169 | MAE: 0.6119998693466187
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.9707456827163696 | MAE: 0.8048748970031738

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.48590922355651855 | MAE: 0.5118297338485718
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.4796741008758545 | MAE: 0.5062559247016907

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([4640, 336, 1])
# val_sequences shape:  torch.Size([425, 336, 1])
# test_sequences shape:  torch.Size([1182, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([4640, 336, 1])
# val_pv shape:  torch.Size([425, 336, 1])
# test_pv shape:  torch.Size([1182, 336, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([4640, 336, 1])
# val_labels shape:  torch.Size([425, 336, 1])
# test_labels shape:  torch.Size([1182, 336, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 336

# %%
segment_len = configs.pred_len // 3
stride = 4

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([4640, 57, 112, 1]), Val: torch.Size([425, 57, 112, 1]), Test: torch.Size([1182, 57, 112, 1])
# [Epoch 1] Train seg shape: torch.Size([4640, 57, 112, 1]), Val: torch.Size([425, 57, 112, 1]), Test: torch.Size([1182, 57, 112, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ER'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ER/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ER/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ER/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ER_E{epo}_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 0] Training Time = 0.83 sec
# [Segment 0] GPU Memory Start = 493.11 MB
# [Segment 0] GPU Memory End   = 497.03 MB
# [Segment 0] GPU Peak Memory  = 498.33 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 1] Training Time = 0.84 sec
# [Segment 1] GPU Memory Start = 497.03 MB
# [Segment 1] GPU Memory End   = 497.03 MB
# [Segment 1] GPU Peak Memory  = 499.48 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 2] Training Time = 0.48 sec
# [Segment 2] GPU Memory Start = 497.03 MB
# [Segment 2] GPU Memory End   = 498.18 MB
# [Segment 2] GPU Peak Memory  = 499.48 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 3] Training Time = 0.74 sec
# [Segment 3] GPU Memory Start = 498.18 MB
# [Segment 3] GPU Memory End   = 499.33 MB
# [Segment 3] GPU Peak Memory  = 500.63 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 4] Training Time = 0.37 sec
# [Segment 4] GPU Memory Start = 499.33 MB
# [Segment 4] GPU Memory End   = 500.48 MB
# [Segment 4] GPU Peak Memory  = 501.78 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 5] Training Time = 0.60 sec
# [Segment 5] GPU Memory Start = 500.48 MB
# [Segment 5] GPU Memory End   = 501.64 MB
# [Segment 5] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 6] Training Time = 0.49 sec
# [Segment 6] GPU Memory Start = 501.64 MB
# [Segment 6] GPU Memory End   = 502.79 MB
# [Segment 6] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 7] Training Time = 0.47 sec
# [Segment 7] GPU Memory Start = 502.79 MB
# [Segment 7] GPU Memory End   = 503.94 MB
# [Segment 7] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 8] Training Time = 0.29 sec
# [Segment 8] GPU Memory Start = 503.94 MB
# [Segment 8] GPU Memory End   = 505.09 MB
# [Segment 8] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 9] Training Time = 0.42 sec
# [Segment 9] GPU Memory Start = 505.09 MB
# [Segment 9] GPU Memory End   = 506.24 MB
# [Segment 9] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 10] Training Time = 0.68 sec
# [Segment 10] GPU Memory Start = 506.24 MB
# [Segment 10] GPU Memory End   = 507.39 MB
# [Segment 10] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 11] Training Time = 0.38 sec
# [Segment 11] GPU Memory Start = 497.03 MB
# [Segment 11] GPU Memory End   = 498.18 MB
# [Segment 11] GPU Peak Memory  = 499.48 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 12] Training Time = 0.32 sec
# [Segment 12] GPU Memory Start = 498.18 MB
# [Segment 12] GPU Memory End   = 499.33 MB
# [Segment 12] GPU Peak Memory  = 500.63 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 13] Training Time = 0.74 sec
# [Segment 13] GPU Memory Start = 499.33 MB
# [Segment 13] GPU Memory End   = 500.48 MB
# [Segment 13] GPU Peak Memory  = 501.78 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 14] Training Time = 0.70 sec
# [Segment 14] GPU Memory Start = 500.48 MB
# [Segment 14] GPU Memory End   = 501.64 MB
# [Segment 14] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 15] Training Time = 0.33 sec
# [Segment 15] GPU Memory Start = 501.64 MB
# [Segment 15] GPU Memory End   = 502.79 MB
# [Segment 15] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 16] Training Time = 0.34 sec
# [Segment 16] GPU Memory Start = 502.79 MB
# [Segment 16] GPU Memory End   = 503.94 MB
# [Segment 16] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 17] Training Time = 0.78 sec
# [Segment 17] GPU Memory Start = 503.94 MB
# [Segment 17] GPU Memory End   = 505.09 MB
# [Segment 17] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 18] Training Time = 0.60 sec
# [Segment 18] GPU Memory Start = 505.09 MB
# [Segment 18] GPU Memory End   = 506.24 MB
# [Segment 18] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 19] Training Time = 0.38 sec
# [Segment 19] GPU Memory Start = 506.24 MB
# [Segment 19] GPU Memory End   = 507.39 MB
# [Segment 19] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 20] Training Time = 0.78 sec
# [Segment 20] GPU Memory Start = 507.39 MB
# [Segment 20] GPU Memory End   = 498.18 MB
# [Segment 20] GPU Peak Memory  = 508.54 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 21] Training Time = 0.69 sec
# [Segment 21] GPU Memory Start = 498.18 MB
# [Segment 21] GPU Memory End   = 499.33 MB
# [Segment 21] GPU Peak Memory  = 500.63 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 22] Training Time = 0.50 sec
# [Segment 22] GPU Memory Start = 499.33 MB
# [Segment 22] GPU Memory End   = 500.48 MB
# [Segment 22] GPU Peak Memory  = 501.78 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 23] Training Time = 0.39 sec
# [Segment 23] GPU Memory Start = 500.48 MB
# [Segment 23] GPU Memory End   = 501.64 MB
# [Segment 23] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 24] Training Time = 0.63 sec
# [Segment 24] GPU Memory Start = 501.64 MB
# [Segment 24] GPU Memory End   = 502.79 MB
# [Segment 24] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 25] Training Time = 0.31 sec
# [Segment 25] GPU Memory Start = 502.79 MB
# [Segment 25] GPU Memory End   = 503.94 MB
# [Segment 25] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 26] Training Time = 0.28 sec
# [Segment 26] GPU Memory Start = 503.94 MB
# [Segment 26] GPU Memory End   = 505.09 MB
# [Segment 26] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 27] Training Time = 0.29 sec
# [Segment 27] GPU Memory Start = 505.09 MB
# [Segment 27] GPU Memory End   = 506.24 MB
# [Segment 27] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 28] Training Time = 0.28 sec
# [Segment 28] GPU Memory Start = 506.24 MB
# [Segment 28] GPU Memory End   = 507.39 MB
# [Segment 28] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 29] Training Time = 0.28 sec
# [Segment 29] GPU Memory Start = 507.39 MB
# [Segment 29] GPU Memory End   = 508.54 MB
# [Segment 29] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 30] Training Time = 0.27 sec
# [Segment 30] GPU Memory Start = 498.18 MB
# [Segment 30] GPU Memory End   = 499.33 MB
# [Segment 30] GPU Peak Memory  = 500.63 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 31] Training Time = 0.34 sec
# [Segment 31] GPU Memory Start = 499.33 MB
# [Segment 31] GPU Memory End   = 500.48 MB
# [Segment 31] GPU Peak Memory  = 501.78 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 32] Training Time = 0.29 sec
# [Segment 32] GPU Memory Start = 500.48 MB
# [Segment 32] GPU Memory End   = 501.64 MB
# [Segment 32] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 33] Training Time = 0.69 sec
# [Segment 33] GPU Memory Start = 501.64 MB
# [Segment 33] GPU Memory End   = 502.79 MB
# [Segment 33] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 34] Training Time = 0.89 sec
# [Segment 34] GPU Memory Start = 502.79 MB
# [Segment 34] GPU Memory End   = 503.94 MB
# [Segment 34] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 35] Training Time = 0.80 sec
# [Segment 35] GPU Memory Start = 503.94 MB
# [Segment 35] GPU Memory End   = 505.09 MB
# [Segment 35] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 36] Training Time = 0.90 sec
# [Segment 36] GPU Memory Start = 505.09 MB
# [Segment 36] GPU Memory End   = 506.24 MB
# [Segment 36] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 37] Training Time = 0.83 sec
# [Segment 37] GPU Memory Start = 506.24 MB
# [Segment 37] GPU Memory End   = 507.39 MB
# [Segment 37] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 38] Training Time = 0.51 sec
# [Segment 38] GPU Memory Start = 507.39 MB
# [Segment 38] GPU Memory End   = 508.54 MB
# [Segment 38] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 39] Training Time = 0.89 sec
# [Segment 39] GPU Memory Start = 508.54 MB
# [Segment 39] GPU Memory End   = 499.33 MB
# [Segment 39] GPU Peak Memory  = 509.69 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 40] Training Time = 0.82 sec
# [Segment 40] GPU Memory Start = 499.33 MB
# [Segment 40] GPU Memory End   = 500.48 MB
# [Segment 40] GPU Peak Memory  = 501.78 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 41] Training Time = 0.78 sec
# [Segment 41] GPU Memory Start = 500.48 MB
# [Segment 41] GPU Memory End   = 501.64 MB
# [Segment 41] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 42] Training Time = 0.97 sec
# [Segment 42] GPU Memory Start = 501.64 MB
# [Segment 42] GPU Memory End   = 502.79 MB
# [Segment 42] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 43] Training Time = 0.73 sec
# [Segment 43] GPU Memory Start = 502.79 MB
# [Segment 43] GPU Memory End   = 503.94 MB
# [Segment 43] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 44] Training Time = 0.90 sec
# [Segment 44] GPU Memory Start = 503.94 MB
# [Segment 44] GPU Memory End   = 505.09 MB
# [Segment 44] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 45] Training Time = 0.73 sec
# [Segment 45] GPU Memory Start = 505.09 MB
# [Segment 45] GPU Memory End   = 506.24 MB
# [Segment 45] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 46] Training Time = 0.81 sec
# [Segment 46] GPU Memory Start = 506.24 MB
# [Segment 46] GPU Memory End   = 507.39 MB
# [Segment 46] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 47] Training Time = 0.33 sec
# [Segment 47] GPU Memory Start = 507.39 MB
# [Segment 47] GPU Memory End   = 508.54 MB
# [Segment 47] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 48] Training Time = 0.32 sec
# [Segment 48] GPU Memory Start = 508.54 MB
# [Segment 48] GPU Memory End   = 509.69 MB
# [Segment 48] GPU Peak Memory  = 511.00 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 49] Training Time = 0.33 sec
# [Segment 49] GPU Memory Start = 499.33 MB
# [Segment 49] GPU Memory End   = 500.48 MB
# [Segment 49] GPU Peak Memory  = 501.78 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 50] Training Time = 0.34 sec
# [Segment 50] GPU Memory Start = 500.48 MB
# [Segment 50] GPU Memory End   = 501.64 MB
# [Segment 50] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 51] Training Time = 0.58 sec
# [Segment 51] GPU Memory Start = 501.64 MB
# [Segment 51] GPU Memory End   = 502.79 MB
# [Segment 51] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 52] Training Time = 0.52 sec
# [Segment 52] GPU Memory Start = 502.79 MB
# [Segment 52] GPU Memory End   = 503.94 MB
# [Segment 52] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 53] Training Time = 0.33 sec
# [Segment 53] GPU Memory Start = 503.94 MB
# [Segment 53] GPU Memory End   = 505.09 MB
# [Segment 53] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 54] Training Time = 0.33 sec
# [Segment 54] GPU Memory Start = 505.09 MB
# [Segment 54] GPU Memory End   = 506.24 MB
# [Segment 54] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 55] Training Time = 0.33 sec
# [Segment 55] GPU Memory Start = 506.24 MB
# [Segment 55] GPU Memory End   = 507.39 MB
# [Segment 55] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 56] Training Time = 0.33 sec
# [Segment 56] GPU Memory Start = 507.39 MB
# [Segment 56] GPU Memory End   = 508.54 MB
# [Segment 56] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ER_E{epo}_1E/",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 0] Training Time = 0.77 sec
# [Segment 0] GPU Memory Start = 500.48 MB
# [Segment 0] GPU Memory End   = 500.48 MB
# [Segment 0] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 1] Training Time = 0.32 sec
# [Segment 1] GPU Memory Start = 500.48 MB
# [Segment 1] GPU Memory End   = 501.64 MB
# [Segment 1] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 2] Training Time = 0.53 sec
# [Segment 2] GPU Memory Start = 501.64 MB
# [Segment 2] GPU Memory End   = 502.79 MB
# [Segment 2] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 3] Training Time = 0.33 sec
# [Segment 3] GPU Memory Start = 502.79 MB
# [Segment 3] GPU Memory End   = 500.48 MB
# [Segment 3] GPU Peak Memory  = 503.94 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 4] Training Time = 0.33 sec
# [Segment 4] GPU Memory Start = 500.48 MB
# [Segment 4] GPU Memory End   = 501.64 MB
# [Segment 4] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 5] Training Time = 0.32 sec
# [Segment 5] GPU Memory Start = 501.64 MB
# [Segment 5] GPU Memory End   = 502.79 MB
# [Segment 5] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 6] Training Time = 0.62 sec
# [Segment 6] GPU Memory Start = 502.79 MB
# [Segment 6] GPU Memory End   = 503.94 MB
# [Segment 6] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 7] Training Time = 0.71 sec
# [Segment 7] GPU Memory Start = 503.94 MB
# [Segment 7] GPU Memory End   = 505.09 MB
# [Segment 7] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 8] Training Time = 0.32 sec
# [Segment 8] GPU Memory Start = 505.09 MB
# [Segment 8] GPU Memory End   = 506.24 MB
# [Segment 8] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 9] Training Time = 0.57 sec
# [Segment 9] GPU Memory Start = 506.24 MB
# [Segment 9] GPU Memory End   = 507.39 MB
# [Segment 9] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 10] Training Time = 0.33 sec
# [Segment 10] GPU Memory Start = 507.39 MB
# [Segment 10] GPU Memory End   = 508.54 MB
# [Segment 10] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 11] Training Time = 0.81 sec
# [Segment 11] GPU Memory Start = 508.54 MB
# [Segment 11] GPU Memory End   = 509.69 MB
# [Segment 11] GPU Peak Memory  = 511.00 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 12] Training Time = 0.39 sec
# [Segment 12] GPU Memory Start = 509.69 MB
# [Segment 12] GPU Memory End   = 510.85 MB
# [Segment 12] GPU Peak Memory  = 512.15 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 13] Training Time = 0.71 sec
# [Segment 13] GPU Memory Start = 500.48 MB
# [Segment 13] GPU Memory End   = 501.64 MB
# [Segment 13] GPU Peak Memory  = 502.94 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 14] Training Time = 0.40 sec
# [Segment 14] GPU Memory Start = 501.64 MB
# [Segment 14] GPU Memory End   = 502.79 MB
# [Segment 14] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 15] Training Time = 0.33 sec
# [Segment 15] GPU Memory Start = 502.79 MB
# [Segment 15] GPU Memory End   = 503.94 MB
# [Segment 15] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 16] Training Time = 0.33 sec
# [Segment 16] GPU Memory Start = 503.94 MB
# [Segment 16] GPU Memory End   = 505.09 MB
# [Segment 16] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 17] Training Time = 0.31 sec
# [Segment 17] GPU Memory Start = 505.09 MB
# [Segment 17] GPU Memory End   = 506.24 MB
# [Segment 17] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 18] Training Time = 0.49 sec
# [Segment 18] GPU Memory Start = 506.24 MB
# [Segment 18] GPU Memory End   = 507.39 MB
# [Segment 18] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 19] Training Time = 0.32 sec
# [Segment 19] GPU Memory Start = 507.39 MB
# [Segment 19] GPU Memory End   = 508.54 MB
# [Segment 19] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 20] Training Time = 0.33 sec
# [Segment 20] GPU Memory Start = 508.54 MB
# [Segment 20] GPU Memory End   = 509.69 MB
# [Segment 20] GPU Peak Memory  = 511.00 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 21] Training Time = 0.45 sec
# [Segment 21] GPU Memory Start = 509.69 MB
# [Segment 21] GPU Memory End   = 510.85 MB
# [Segment 21] GPU Peak Memory  = 512.15 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 22] Training Time = 0.33 sec
# [Segment 22] GPU Memory Start = 510.85 MB
# [Segment 22] GPU Memory End   = 501.64 MB
# [Segment 22] GPU Peak Memory  = 512.00 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 23] Training Time = 0.33 sec
# [Segment 23] GPU Memory Start = 501.64 MB
# [Segment 23] GPU Memory End   = 502.79 MB
# [Segment 23] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 24] Training Time = 0.80 sec
# [Segment 24] GPU Memory Start = 502.79 MB
# [Segment 24] GPU Memory End   = 503.94 MB
# [Segment 24] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 25] Training Time = 0.75 sec
# [Segment 25] GPU Memory Start = 503.94 MB
# [Segment 25] GPU Memory End   = 505.09 MB
# [Segment 25] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 26] Training Time = 0.52 sec
# [Segment 26] GPU Memory Start = 505.09 MB
# [Segment 26] GPU Memory End   = 506.24 MB
# [Segment 26] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 27] Training Time = 0.70 sec
# [Segment 27] GPU Memory Start = 506.24 MB
# [Segment 27] GPU Memory End   = 507.39 MB
# [Segment 27] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 28] Training Time = 0.82 sec
# [Segment 28] GPU Memory Start = 507.39 MB
# [Segment 28] GPU Memory End   = 508.54 MB
# [Segment 28] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 29] Training Time = 0.63 sec
# [Segment 29] GPU Memory Start = 508.54 MB
# [Segment 29] GPU Memory End   = 509.69 MB
# [Segment 29] GPU Peak Memory  = 511.00 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 30] Training Time = 0.83 sec
# [Segment 30] GPU Memory Start = 509.69 MB
# [Segment 30] GPU Memory End   = 510.85 MB
# [Segment 30] GPU Peak Memory  = 512.15 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 31] Training Time = 0.33 sec
# [Segment 31] GPU Memory Start = 510.85 MB
# [Segment 31] GPU Memory End   = 512.00 MB
# [Segment 31] GPU Peak Memory  = 513.30 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 32] Training Time = 0.33 sec
# [Segment 32] GPU Memory Start = 501.64 MB
# [Segment 32] GPU Memory End   = 502.79 MB
# [Segment 32] GPU Peak Memory  = 504.09 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 33] Training Time = 0.70 sec
# [Segment 33] GPU Memory Start = 502.79 MB
# [Segment 33] GPU Memory End   = 503.94 MB
# [Segment 33] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 34] Training Time = 0.70 sec
# [Segment 34] GPU Memory Start = 503.94 MB
# [Segment 34] GPU Memory End   = 505.09 MB
# [Segment 34] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 35] Training Time = 0.43 sec
# [Segment 35] GPU Memory Start = 505.09 MB
# [Segment 35] GPU Memory End   = 506.24 MB
# [Segment 35] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 36] Training Time = 0.33 sec
# [Segment 36] GPU Memory Start = 506.24 MB
# [Segment 36] GPU Memory End   = 507.39 MB
# [Segment 36] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 37] Training Time = 0.33 sec
# [Segment 37] GPU Memory Start = 507.39 MB
# [Segment 37] GPU Memory End   = 508.54 MB
# [Segment 37] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 38] Training Time = 0.33 sec
# [Segment 38] GPU Memory Start = 508.54 MB
# [Segment 38] GPU Memory End   = 509.69 MB
# [Segment 38] GPU Peak Memory  = 511.00 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 39] Training Time = 0.45 sec
# [Segment 39] GPU Memory Start = 509.69 MB
# [Segment 39] GPU Memory End   = 510.85 MB
# [Segment 39] GPU Peak Memory  = 512.15 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 40] Training Time = 0.48 sec
# [Segment 40] GPU Memory Start = 510.85 MB
# [Segment 40] GPU Memory End   = 512.00 MB
# [Segment 40] GPU Peak Memory  = 513.30 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 41] Training Time = 0.36 sec
# [Segment 41] GPU Memory Start = 512.00 MB
# [Segment 41] GPU Memory End   = 502.79 MB
# [Segment 41] GPU Peak Memory  = 513.15 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 42] Training Time = 0.36 sec
# [Segment 42] GPU Memory Start = 502.79 MB
# [Segment 42] GPU Memory End   = 503.94 MB
# [Segment 42] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 43] Training Time = 0.36 sec
# [Segment 43] GPU Memory Start = 503.94 MB
# [Segment 43] GPU Memory End   = 505.09 MB
# [Segment 43] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 44] Training Time = 0.43 sec
# [Segment 44] GPU Memory Start = 505.09 MB
# [Segment 44] GPU Memory End   = 506.24 MB
# [Segment 44] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 45] Training Time = 0.56 sec
# [Segment 45] GPU Memory Start = 506.24 MB
# [Segment 45] GPU Memory End   = 507.39 MB
# [Segment 45] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 46] Training Time = 0.34 sec
# [Segment 46] GPU Memory Start = 507.39 MB
# [Segment 46] GPU Memory End   = 508.54 MB
# [Segment 46] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 47] Training Time = 0.40 sec
# [Segment 47] GPU Memory Start = 508.54 MB
# [Segment 47] GPU Memory End   = 509.69 MB
# [Segment 47] GPU Peak Memory  = 511.00 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 48] Training Time = 0.35 sec
# [Segment 48] GPU Memory Start = 509.69 MB
# [Segment 48] GPU Memory End   = 510.85 MB
# [Segment 48] GPU Peak Memory  = 512.15 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 49] Training Time = 0.31 sec
# [Segment 49] GPU Memory Start = 510.85 MB
# [Segment 49] GPU Memory End   = 512.00 MB
# [Segment 49] GPU Peak Memory  = 513.30 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 50] Training Time = 0.37 sec
# [Segment 50] GPU Memory Start = 512.00 MB
# [Segment 50] GPU Memory End   = 513.15 MB
# [Segment 50] GPU Peak Memory  = 514.45 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 51] Training Time = 0.33 sec
# [Segment 51] GPU Memory Start = 502.79 MB
# [Segment 51] GPU Memory End   = 503.94 MB
# [Segment 51] GPU Peak Memory  = 505.24 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 52] Training Time = 0.39 sec
# [Segment 52] GPU Memory Start = 503.94 MB
# [Segment 52] GPU Memory End   = 505.09 MB
# [Segment 52] GPU Peak Memory  = 506.39 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 53] Training Time = 0.33 sec
# [Segment 53] GPU Memory Start = 505.09 MB
# [Segment 53] GPU Memory End   = 506.24 MB
# [Segment 53] GPU Peak Memory  = 507.54 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 54] Training Time = 0.33 sec
# [Segment 54] GPU Memory Start = 506.24 MB
# [Segment 54] GPU Memory End   = 507.39 MB
# [Segment 54] GPU Peak Memory  = 508.69 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 55] Training Time = 0.74 sec
# [Segment 55] GPU Memory Start = 507.39 MB
# [Segment 55] GPU Memory End   = 508.54 MB
# [Segment 55] GPU Peak Memory  = 509.84 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 56] Training Time = 0.90 sec
# [Segment 56] GPU Memory Start = 508.54 MB
# [Segment 56] GPU Memory End   = 509.69 MB
# [Segment 56] GPU Peak Memory  = 511.00 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ER/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ER/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ER/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ER_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.7748057842254639  MAE:0.7378027439117432
# ▶ seg0  mean  MSE:0.7748057842254639  MAE:0.7378027439117432
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.8050317764282227  MAE:0.7569007873535156
# ▶ seg1  mean  MSE:0.8050317764282227  MAE:0.7569007873535156
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.685623824596405  MAE:0.6882999539375305
# ▶ seg2  mean  MSE:0.685623824596405  MAE:0.6882999539375305
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.8057820796966553  MAE:0.7473331093788147
# ▶ seg3  mean  MSE:0.8057820796966553  MAE:0.7473331093788147
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.8098480701446533  MAE:0.761300802230835
# ▶ seg4  mean  MSE:0.8098480701446533  MAE:0.761300802230835
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.7312417030334473  MAE:0.71917325258255
# ▶ seg5  mean  MSE:0.7312417030334473  MAE:0.71917325258255
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.9050754904747009  MAE:0.8049262762069702
# ▶ seg6  mean  MSE:0.9050754904747009  MAE:0.8049262762069702
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.6838515996932983  MAE:0.677312433719635
# ▶ seg7  mean  MSE:0.6838515996932983  MAE:0.677312433719635
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.630180299282074  MAE:0.6531838774681091
# ▶ seg8  mean  MSE:0.630180299282074  MAE:0.6531838774681091
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:1.0255496501922607  MAE:0.8623210787773132
# ▶ seg9  mean  MSE:1.0255496501922607  MAE:0.8623210787773132
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.46467846632003784  MAE:0.5495551228523254
# ▶ seg10  mean  MSE:0.46467846632003784  MAE:0.5495551228523254
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:1.0605251789093018  MAE:0.8797163367271423
# ▶ seg11  mean  MSE:1.0605251789093018  MAE:0.8797163367271423
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.6037937998771667  MAE:0.6310542821884155
# ▶ seg12  mean  MSE:0.6037937998771667  MAE:0.6310542821884155
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.8325093984603882  MAE:0.7731078267097473
# ▶ seg13  mean  MSE:0.8325093984603882  MAE:0.7731078267097473
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.7627386450767517  MAE:0.7229217290878296
# ▶ seg14  mean  MSE:0.7627386450767517  MAE:0.7229217290878296
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.6106336712837219  MAE:0.6445499062538147
# ▶ seg15  mean  MSE:0.6106336712837219  MAE:0.6445499062538147
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.800114095211029  MAE:0.7453303933143616
# ▶ seg16  mean  MSE:0.800114095211029  MAE:0.7453303933143616
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.8570410013198853  MAE:0.7782168984413147
# ▶ seg17  mean  MSE:0.8570410013198853  MAE:0.7782168984413147
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.819706916809082  MAE:0.7553901076316833
# ▶ seg18  mean  MSE:0.819706916809082  MAE:0.7553901076316833
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.5857282876968384  MAE:0.6271613836288452
# ▶ seg19  mean  MSE:0.5857282876968384  MAE:0.6271613836288452
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:1.0938165187835693  MAE:0.8765777349472046
# ▶ seg20  mean  MSE:1.0938165187835693  MAE:0.8765777349472046
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.6278586983680725  MAE:0.6601633429527283
# ▶ seg21  mean  MSE:0.6278586983680725  MAE:0.6601633429527283
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.8414888978004456  MAE:0.7643256783485413
# ▶ seg22  mean  MSE:0.8414888978004456  MAE:0.7643256783485413
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.6725262403488159  MAE:0.6598913669586182
# ▶ seg23  mean  MSE:0.6725262403488159  MAE:0.6598913669586182
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.7127902507781982  MAE:0.7097383737564087
# ▶ seg24  mean  MSE:0.7127902507781982  MAE:0.7097383737564087
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.7235103845596313  MAE:0.6993608474731445
# ▶ seg25  mean  MSE:0.7235103845596313  MAE:0.6993608474731445
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.8383347988128662  MAE:0.7667025327682495
# ▶ seg26  mean  MSE:0.8383347988128662  MAE:0.7667025327682495
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.7298378944396973  MAE:0.7058485150337219
# ▶ seg27  mean  MSE:0.7298378944396973  MAE:0.7058485150337219
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.7435305118560791  MAE:0.7116057872772217
# ▶ seg28  mean  MSE:0.7435305118560791  MAE:0.7116057872772217
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.6451690793037415  MAE:0.659191370010376
# ▶ seg29  mean  MSE:0.6451690793037415  MAE:0.659191370010376
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.7648539543151855  MAE:0.7320840954780579
# ▶ seg30  mean  MSE:0.7648539543151855  MAE:0.7320840954780579
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.6180822253227234  MAE:0.6429381966590881
# ▶ seg31  mean  MSE:0.6180822253227234  MAE:0.6429381966590881
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.8690862059593201  MAE:0.7805346846580505
# ▶ seg32  mean  MSE:0.8690862059593201  MAE:0.7805346846580505
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.8493338227272034  MAE:0.7716664671897888
# ▶ seg33  mean  MSE:0.8493338227272034  MAE:0.7716664671897888
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.5457326173782349  MAE:0.596457302570343
# ▶ seg34  mean  MSE:0.5457326173782349  MAE:0.596457302570343
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.7994742393493652  MAE:0.7440900802612305
# ▶ seg35  mean  MSE:0.7994742393493652  MAE:0.7440900802612305
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.6076228022575378  MAE:0.6419234275817871
# ▶ seg36  mean  MSE:0.6076228022575378  MAE:0.6419234275817871
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.6448630094528198  MAE:0.6637133359909058
# ▶ seg37  mean  MSE:0.6448630094528198  MAE:0.6637133359909058
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.736514151096344  MAE:0.7190894484519958
# ▶ seg38  mean  MSE:0.736514151096344  MAE:0.7190894484519958
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.7026126980781555  MAE:0.6959043145179749
# ▶ seg39  mean  MSE:0.7026126980781555  MAE:0.6959043145179749
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.7651087045669556  MAE:0.7299322485923767
# ▶ seg40  mean  MSE:0.7651087045669556  MAE:0.7299322485923767
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.6922493577003479  MAE:0.6822406053543091
# ▶ seg41  mean  MSE:0.6922493577003479  MAE:0.6822406053543091
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.6660307049751282  MAE:0.6824543476104736
# ▶ seg42  mean  MSE:0.6660307049751282  MAE:0.6824543476104736
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.8664905428886414  MAE:0.7735920548439026
# ▶ seg43  mean  MSE:0.8664905428886414  MAE:0.7735920548439026
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.6137816905975342  MAE:0.6453777551651001
# ▶ seg44  mean  MSE:0.6137816905975342  MAE:0.6453777551651001
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.6786045432090759  MAE:0.6741776466369629
# ▶ seg45  mean  MSE:0.6786045432090759  MAE:0.6741776466369629
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.8358392715454102  MAE:0.7688354849815369
# ▶ seg46  mean  MSE:0.8358392715454102  MAE:0.7688354849815369
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.8724294900894165  MAE:0.7892590761184692
# ▶ seg47  mean  MSE:0.8724294900894165  MAE:0.7892590761184692
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.7777717709541321  MAE:0.7347739934921265
# ▶ seg48  mean  MSE:0.7777717709541321  MAE:0.7347739934921265
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.5034089088439941  MAE:0.5734686255455017
# ▶ seg49  mean  MSE:0.5034089088439941  MAE:0.5734686255455017
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.6310275197029114  MAE:0.6642360091209412
# ▶ seg50  mean  MSE:0.6310275197029114  MAE:0.6642360091209412
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.6489577293395996  MAE:0.6652624011039734
# ▶ seg51  mean  MSE:0.6489577293395996  MAE:0.6652624011039734
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.8353372812271118  MAE:0.7556700706481934
# ▶ seg52  mean  MSE:0.8353372812271118  MAE:0.7556700706481934
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.8713960647583008  MAE:0.7638319134712219
# ▶ seg53  mean  MSE:0.8713960647583008  MAE:0.7638319134712219
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.7366287112236023  MAE:0.709745466709137
# ▶ seg54  mean  MSE:0.7366287112236023  MAE:0.709745466709137
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.9051374197006226  MAE:0.8059284090995789
# ▶ seg55  mean  MSE:0.9051374197006226  MAE:0.8059284090995789
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.7204734683036804  MAE:0.7014576196670532
# ▶ seg56  mean  MSE:0.7204734683036804  MAE:0.7014576196670532
#
# seg10 ch0 MSE : 0.46467847

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ER_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:1.1252784729003906  MAE:0.9166330695152283
# ▶ seg0  mean  MSE:1.1252784729003906  MAE:0.9166330695152283
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.6514539122581482  MAE:0.6724375486373901
# ▶ seg1  mean  MSE:0.6514539122581482  MAE:0.6724375486373901
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.6468861103057861  MAE:0.6675268411636353
# ▶ seg2  mean  MSE:0.6468861103057861  MAE:0.6675268411636353
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.9691358208656311  MAE:0.8347978591918945
# ▶ seg3  mean  MSE:0.9691358208656311  MAE:0.8347978591918945
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.7452409267425537  MAE:0.714730441570282
# ▶ seg4  mean  MSE:0.7452409267425537  MAE:0.714730441570282
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.7170066833496094  MAE:0.7079368829727173
# ▶ seg5  mean  MSE:0.7170066833496094  MAE:0.7079368829727173
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:1.2329801321029663  MAE:0.9607205390930176
# ▶ seg6  mean  MSE:1.2329801321029663  MAE:0.9607205390930176
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.7852659821510315  MAE:0.7595878839492798
# ▶ seg7  mean  MSE:0.7852659821510315  MAE:0.7595878839492798
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.7657918930053711  MAE:0.7241112589836121
# ▶ seg8  mean  MSE:0.7657918930053711  MAE:0.7241112589836121
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.8274509906768799  MAE:0.7608445882797241
# ▶ seg9  mean  MSE:0.8274509906768799  MAE:0.7608445882797241
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.7841745615005493  MAE:0.7487521767616272
# ▶ seg10  mean  MSE:0.7841745615005493  MAE:0.7487521767616272
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.7469313740730286  MAE:0.7205922603607178
# ▶ seg11  mean  MSE:0.7469313740730286  MAE:0.7205922603607178
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.7532879114151001  MAE:0.7202939987182617
# ▶ seg12  mean  MSE:0.7532879114151001  MAE:0.7202939987182617
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.7377609014511108  MAE:0.7176010608673096
# ▶ seg13  mean  MSE:0.7377609014511108  MAE:0.7176010608673096
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.6925931572914124  MAE:0.6779172420501709
# ▶ seg14  mean  MSE:0.6925931572914124  MAE:0.6779172420501709
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.8642995953559875  MAE:0.7812209129333496
# ▶ seg15  mean  MSE:0.8642995953559875  MAE:0.7812209129333496
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.6692235469818115  MAE:0.6760450601577759
# ▶ seg16  mean  MSE:0.6692235469818115  MAE:0.6760450601577759
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.8861584067344666  MAE:0.7841032147407532
# ▶ seg17  mean  MSE:0.8861584067344666  MAE:0.7841032147407532
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.7886458039283752  MAE:0.7512328028678894
# ▶ seg18  mean  MSE:0.7886458039283752  MAE:0.7512328028678894
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.6721298098564148  MAE:0.6843289732933044
# ▶ seg19  mean  MSE:0.6721298098564148  MAE:0.6843289732933044
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.8371398448944092  MAE:0.7746521234512329
# ▶ seg20  mean  MSE:0.8371398448944092  MAE:0.7746521234512329
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.9005955457687378  MAE:0.7808018922805786
# ▶ seg21  mean  MSE:0.9005955457687378  MAE:0.7808018922805786
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.5771177411079407  MAE:0.6208569407463074
# ▶ seg22  mean  MSE:0.5771177411079407  MAE:0.6208569407463074
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.7479734420776367  MAE:0.7203081250190735
# ▶ seg23  mean  MSE:0.7479734420776367  MAE:0.7203081250190735
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.6381027102470398  MAE:0.6675754189491272
# ▶ seg24  mean  MSE:0.6381027102470398  MAE:0.6675754189491272
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.8701424598693848  MAE:0.7859317064285278
# ▶ seg25  mean  MSE:0.8701424598693848  MAE:0.7859317064285278
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.7464381456375122  MAE:0.7126666307449341
# ▶ seg26  mean  MSE:0.7464381456375122  MAE:0.7126666307449341
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.8754166960716248  MAE:0.7755448818206787
# ▶ seg27  mean  MSE:0.8754166960716248  MAE:0.7755448818206787
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.8094215393066406  MAE:0.7432956695556641
# ▶ seg28  mean  MSE:0.8094215393066406  MAE:0.7432956695556641
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.5674018263816833  MAE:0.6207205057144165
# ▶ seg29  mean  MSE:0.5674018263816833  MAE:0.6207205057144165
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.6366835236549377  MAE:0.6629983186721802
# ▶ seg30  mean  MSE:0.6366835236549377  MAE:0.6629983186721802
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.8523090481758118  MAE:0.7700656652450562
# ▶ seg31  mean  MSE:0.8523090481758118  MAE:0.7700656652450562
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.8916724324226379  MAE:0.7837373614311218
# ▶ seg32  mean  MSE:0.8916724324226379  MAE:0.7837373614311218
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.7231541275978088  MAE:0.7081233859062195
# ▶ seg33  mean  MSE:0.7231541275978088  MAE:0.7081233859062195
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.853410005569458  MAE:0.7805066108703613
# ▶ seg34  mean  MSE:0.853410005569458  MAE:0.7805066108703613
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.8298959136009216  MAE:0.7761460542678833
# ▶ seg35  mean  MSE:0.8298959136009216  MAE:0.7761460542678833
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.8938259482383728  MAE:0.7946312427520752
# ▶ seg36  mean  MSE:0.8938259482383728  MAE:0.7946312427520752
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.8290432691574097  MAE:0.7675306797027588
# ▶ seg37  mean  MSE:0.8290432691574097  MAE:0.7675306797027588
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.6431047916412354  MAE:0.6593582630157471
# ▶ seg38  mean  MSE:0.6431047916412354  MAE:0.6593582630157471
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.702763020992279  MAE:0.6996921896934509
# ▶ seg39  mean  MSE:0.702763020992279  MAE:0.6996921896934509
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:1.0833971500396729  MAE:0.8902411460876465
# ▶ seg40  mean  MSE:1.0833971500396729  MAE:0.8902411460876465
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.6928770542144775  MAE:0.687870442867279
# ▶ seg41  mean  MSE:0.6928770542144775  MAE:0.687870442867279
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.8294293284416199  MAE:0.7570887804031372
# ▶ seg42  mean  MSE:0.8294293284416199  MAE:0.7570887804031372
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:1.0638259649276733  MAE:0.863131582736969
# ▶ seg43  mean  MSE:1.0638259649276733  MAE:0.863131582736969
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.6103613972663879  MAE:0.6388871073722839
# ▶ seg44  mean  MSE:0.6103613972663879  MAE:0.6388871073722839
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.7393862009048462  MAE:0.7168937921524048
# ▶ seg45  mean  MSE:0.7393862009048462  MAE:0.7168937921524048
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.9121711254119873  MAE:0.799920916557312
# ▶ seg46  mean  MSE:0.9121711254119873  MAE:0.799920916557312
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.539513111114502  MAE:0.5947136282920837
# ▶ seg47  mean  MSE:0.539513111114502  MAE:0.5947136282920837
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.852031946182251  MAE:0.7627980709075928
# ▶ seg48  mean  MSE:0.852031946182251  MAE:0.7627980709075928
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.5915100574493408  MAE:0.6292288899421692
# ▶ seg49  mean  MSE:0.5915100574493408  MAE:0.6292288899421692
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.7327728271484375  MAE:0.7130672335624695
# ▶ seg50  mean  MSE:0.7327728271484375  MAE:0.7130672335624695
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:1.015349268913269  MAE:0.8482756018638611
# ▶ seg51  mean  MSE:1.015349268913269  MAE:0.8482756018638611
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.6776466965675354  MAE:0.6847691535949707
# ▶ seg52  mean  MSE:0.6776466965675354  MAE:0.6847691535949707
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.6197819113731384  MAE:0.6510403156280518
# ▶ seg53  mean  MSE:0.6197819113731384  MAE:0.6510403156280518
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.780354380607605  MAE:0.7275606989860535
# ▶ seg54  mean  MSE:0.780354380607605  MAE:0.7275606989860535
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.8324520587921143  MAE:0.774707555770874
# ▶ seg55  mean  MSE:0.8324520587921143  MAE:0.774707555770874
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.477094829082489  MAE:0.5634785294532776
# ▶ seg56  mean  MSE:0.477094829082489  MAE:0.5634785294532776
#
# seg10 ch0 MSE : 0.78417456

# %% [markdown]
# # 2nd Inference for Test Set

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 336
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ER_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.43933171033859253  MAE:0.521840512752533
# ▶ seg0  mean  MSE:0.43933171033859253  MAE:0.521840512752533
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.42627158761024475  MAE:0.5189960598945618
# ▶ seg1  mean  MSE:0.42627158761024475  MAE:0.5189960598945618
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.39546260237693787  MAE:0.4974868595600128
# ▶ seg2  mean  MSE:0.39546260237693787  MAE:0.4974868595600128
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.48108166456222534  MAE:0.5389847755432129
# ▶ seg3  mean  MSE:0.48108166456222534  MAE:0.5389847755432129
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.4584062099456787  MAE:0.5402812361717224
# ▶ seg4  mean  MSE:0.4584062099456787  MAE:0.5402812361717224
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.3960871994495392  MAE:0.5104967355728149
# ▶ seg5  mean  MSE:0.3960871994495392  MAE:0.5104967355728149
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.5333629250526428  MAE:0.5677080154418945
# ▶ seg6  mean  MSE:0.5333629250526428  MAE:0.5677080154418945
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.39820703864097595  MAE:0.4922160506248474
# ▶ seg7  mean  MSE:0.39820703864097595  MAE:0.4922160506248474
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.33722901344299316  MAE:0.4713056683540344
# ▶ seg8  mean  MSE:0.33722901344299316  MAE:0.4713056683540344
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.6463853120803833  MAE:0.62848961353302
# ▶ seg9  mean  MSE:0.6463853120803833  MAE:0.62848961353302
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.33198225498199463  MAE:0.46258801221847534
# ▶ seg10  mean  MSE:0.33198225498199463  MAE:0.46258801221847534
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.6606584787368774  MAE:0.6325424313545227
# ▶ seg11  mean  MSE:0.6606584787368774  MAE:0.6325424313545227
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.3559008240699768  MAE:0.4751904010772705
# ▶ seg12  mean  MSE:0.3559008240699768  MAE:0.4751904010772705
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.49464845657348633  MAE:0.5556271076202393
# ▶ seg13  mean  MSE:0.49464845657348633  MAE:0.5556271076202393
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.47535011172294617  MAE:0.5328593254089355
# ▶ seg14  mean  MSE:0.47535011172294617  MAE:0.5328593254089355
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.3440573513507843  MAE:0.4775458574295044
# ▶ seg15  mean  MSE:0.3440573513507843  MAE:0.4775458574295044
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.4655517637729645  MAE:0.530199408531189
# ▶ seg16  mean  MSE:0.4655517637729645  MAE:0.530199408531189
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.5232475399971008  MAE:0.5610520839691162
# ▶ seg17  mean  MSE:0.5232475399971008  MAE:0.5610520839691162
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.4294198155403137  MAE:0.5090776085853577
# ▶ seg18  mean  MSE:0.4294198155403137  MAE:0.5090776085853577
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.33213719725608826  MAE:0.4662187993526459
# ▶ seg19  mean  MSE:0.33213719725608826  MAE:0.4662187993526459
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.666368305683136  MAE:0.6205609440803528
# ▶ seg20  mean  MSE:0.666368305683136  MAE:0.6205609440803528
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.3527940809726715  MAE:0.4912216067314148
# ▶ seg21  mean  MSE:0.3527940809726715  MAE:0.4912216067314148
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.47892269492149353  MAE:0.5315688848495483
# ▶ seg22  mean  MSE:0.47892269492149353  MAE:0.5315688848495483
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.42066383361816406  MAE:0.5078908801078796
# ▶ seg23  mean  MSE:0.42066383361816406  MAE:0.5078908801078796
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.40706372261047363  MAE:0.5208966135978699
# ▶ seg24  mean  MSE:0.40706372261047363  MAE:0.5208966135978699
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.40341052412986755  MAE:0.4974120557308197
# ▶ seg25  mean  MSE:0.40341052412986755  MAE:0.4974120557308197
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.48818856477737427  MAE:0.5428321957588196
# ▶ seg26  mean  MSE:0.48818856477737427  MAE:0.5428321957588196
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.4078842103481293  MAE:0.4995206594467163
# ▶ seg27  mean  MSE:0.4078842103481293  MAE:0.4995206594467163
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.43238627910614014  MAE:0.5127359628677368
# ▶ seg28  mean  MSE:0.43238627910614014  MAE:0.5127359628677368
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.36195701360702515  MAE:0.4822421073913574
# ▶ seg29  mean  MSE:0.36195701360702515  MAE:0.4822421073913574
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.4218500554561615  MAE:0.5156118869781494
# ▶ seg30  mean  MSE:0.4218500554561615  MAE:0.5156118869781494
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.3379410207271576  MAE:0.46992379426956177
# ▶ seg31  mean  MSE:0.3379410207271576  MAE:0.46992379426956177
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.4822978973388672  MAE:0.5378772616386414
# ▶ seg32  mean  MSE:0.4822978973388672  MAE:0.5378772616386414
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.44989529252052307  MAE:0.5205694437026978
# ▶ seg33  mean  MSE:0.44989529252052307  MAE:0.5205694437026978
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.3592252731323242  MAE:0.4894444942474365
# ▶ seg34  mean  MSE:0.3592252731323242  MAE:0.4894444942474365
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.47969892621040344  MAE:0.5353254079818726
# ▶ seg35  mean  MSE:0.47969892621040344  MAE:0.5353254079818726
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.3526749908924103  MAE:0.4818134009838104
# ▶ seg36  mean  MSE:0.3526749908924103  MAE:0.4818134009838104
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.3860452175140381  MAE:0.5007182955741882
# ▶ seg37  mean  MSE:0.3860452175140381  MAE:0.5007182955741882
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.39333394169807434  MAE:0.5064275860786438
# ▶ seg38  mean  MSE:0.39333394169807434  MAE:0.5064275860786438
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.4028053283691406  MAE:0.49975448846817017
# ▶ seg39  mean  MSE:0.4028053283691406  MAE:0.49975448846817017
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.4375598430633545  MAE:0.5189563632011414
# ▶ seg40  mean  MSE:0.4375598430633545  MAE:0.5189563632011414
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.3863082528114319  MAE:0.48706966638565063
# ▶ seg41  mean  MSE:0.3863082528114319  MAE:0.48706966638565063
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.3992200195789337  MAE:0.5157879590988159
# ▶ seg42  mean  MSE:0.3992200195789337  MAE:0.5157879590988159
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.5240252017974854  MAE:0.5551586151123047
# ▶ seg43  mean  MSE:0.5240252017974854  MAE:0.5551586151123047
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.3354108929634094  MAE:0.46967941522598267
# ▶ seg44  mean  MSE:0.3354108929634094  MAE:0.46967941522598267
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.374295175075531  MAE:0.4837087392807007
# ▶ seg45  mean  MSE:0.374295175075531  MAE:0.4837087392807007
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.5146872997283936  MAE:0.5617280602455139
# ▶ seg46  mean  MSE:0.5146872997283936  MAE:0.5617280602455139
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.4853930175304413  MAE:0.5440065264701843
# ▶ seg47  mean  MSE:0.4853930175304413  MAE:0.5440065264701843
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.46236807107925415  MAE:0.5296584367752075
# ▶ seg48  mean  MSE:0.46236807107925415  MAE:0.5296584367752075
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.3236222267150879  MAE:0.46264851093292236
# ▶ seg49  mean  MSE:0.3236222267150879  MAE:0.46264851093292236
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.38492900133132935  MAE:0.510818600654602
# ▶ seg50  mean  MSE:0.38492900133132935  MAE:0.510818600654602
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.3445824384689331  MAE:0.47458308935165405
# ▶ seg51  mean  MSE:0.3445824384689331  MAE:0.47458308935165405
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.5448349118232727  MAE:0.562799334526062
# ▶ seg52  mean  MSE:0.5448349118232727  MAE:0.562799334526062
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.5675044655799866  MAE:0.5665623545646667
# ▶ seg53  mean  MSE:0.5675044655799866  MAE:0.5665623545646667
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.375299870967865  MAE:0.4809800088405609
# ▶ seg54  mean  MSE:0.375299870967865  MAE:0.4809800088405609
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.518438994884491  MAE:0.5600646734237671
# ▶ seg55  mean  MSE:0.518438994884491  MAE:0.5600646734237671
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.40586498379707336  MAE:0.4947853684425354
# ▶ seg56  mean  MSE:0.40586498379707336  MAE:0.4947853684425354
#
# seg10 ch0 MSE : 0.33198225

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 336
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ER_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.7250621914863586  MAE:0.6784420013427734
# ▶ seg0  mean  MSE:0.7250621914863586  MAE:0.6784420013427734
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.38513174653053284  MAE:0.5079655647277832
# ▶ seg1  mean  MSE:0.38513174653053284  MAE:0.5079655647277832
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.3489549458026886  MAE:0.47924575209617615
# ▶ seg2  mean  MSE:0.3489549458026886  MAE:0.47924575209617615
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.5707553625106812  MAE:0.5905255079269409
# ▶ seg3  mean  MSE:0.5707553625106812  MAE:0.5905255079269409
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.41384750604629517  MAE:0.5014108419418335
# ▶ seg4  mean  MSE:0.41384750604629517  MAE:0.5014108419418335
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.38789233565330505  MAE:0.5050868988037109
# ▶ seg5  mean  MSE:0.38789233565330505  MAE:0.5050868988037109
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.8194288611412048  MAE:0.7199457883834839
# ▶ seg6  mean  MSE:0.8194288611412048  MAE:0.7199457883834839
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.41904303431510925  MAE:0.5353603959083557
# ▶ seg7  mean  MSE:0.41904303431510925  MAE:0.5353603959083557
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.4182746112346649  MAE:0.5022251009941101
# ▶ seg8  mean  MSE:0.4182746112346649  MAE:0.5022251009941101
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.5464614629745483  MAE:0.5758141875267029
# ▶ seg9  mean  MSE:0.5464614629745483  MAE:0.5758141875267029
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.4672127366065979  MAE:0.5556837320327759
# ▶ seg10  mean  MSE:0.4672127366065979  MAE:0.5556837320327759
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.4124918580055237  MAE:0.5086240768432617
# ▶ seg11  mean  MSE:0.4124918580055237  MAE:0.5086240768432617
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.4514608383178711  MAE:0.522180438041687
# ▶ seg12  mean  MSE:0.4514608383178711  MAE:0.522180438041687
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.4690288305282593  MAE:0.5445447564125061
# ▶ seg13  mean  MSE:0.4690288305282593  MAE:0.5445447564125061
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.40404847264289856  MAE:0.49318745732307434
# ▶ seg14  mean  MSE:0.40404847264289856  MAE:0.49318745732307434
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.5172255635261536  MAE:0.5569895505905151
# ▶ seg15  mean  MSE:0.5172255635261536  MAE:0.5569895505905151
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.36475321650505066  MAE:0.48367732763290405
# ▶ seg16  mean  MSE:0.36475321650505066  MAE:0.48367732763290405
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.5407552719116211  MAE:0.5643113851547241
# ▶ seg17  mean  MSE:0.5407552719116211  MAE:0.5643113851547241
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.49981406331062317  MAE:0.5702273845672607
# ▶ seg18  mean  MSE:0.49981406331062317  MAE:0.5702273845672607
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.35969945788383484  MAE:0.4895358085632324
# ▶ seg19  mean  MSE:0.35969945788383484  MAE:0.4895358085632324
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.49436089396476746  MAE:0.5604199767112732
# ▶ seg20  mean  MSE:0.49436089396476746  MAE:0.5604199767112732
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.5214874148368835  MAE:0.5429517030715942
# ▶ seg21  mean  MSE:0.5214874148368835  MAE:0.5429517030715942
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.32732880115509033  MAE:0.4659321904182434
# ▶ seg22  mean  MSE:0.32732880115509033  MAE:0.4659321904182434
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.3739945888519287  MAE:0.48714232444763184
# ▶ seg23  mean  MSE:0.3739945888519287  MAE:0.48714232444763184
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.3785814344882965  MAE:0.5110830664634705
# ▶ seg24  mean  MSE:0.3785814344882965  MAE:0.5110830664634705
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.518134355545044  MAE:0.558529257774353
# ▶ seg25  mean  MSE:0.518134355545044  MAE:0.558529257774353
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.4245983362197876  MAE:0.5050254464149475
# ▶ seg26  mean  MSE:0.4245983362197876  MAE:0.5050254464149475
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.5266969799995422  MAE:0.5501111149787903
# ▶ seg27  mean  MSE:0.5266969799995422  MAE:0.5501111149787903
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.4710078239440918  MAE:0.5237864851951599
# ▶ seg28  mean  MSE:0.4710078239440918  MAE:0.5237864851951599
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.32685086131095886  MAE:0.4692506790161133
# ▶ seg29  mean  MSE:0.32685086131095886  MAE:0.4692506790161133
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.3558622896671295  MAE:0.48693278431892395
# ▶ seg30  mean  MSE:0.3558622896671295  MAE:0.48693278431892395
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.5170407891273499  MAE:0.5541069507598877
# ▶ seg31  mean  MSE:0.5170407891273499  MAE:0.5541069507598877
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.6144635081291199  MAE:0.597722589969635
# ▶ seg32  mean  MSE:0.6144635081291199  MAE:0.597722589969635
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.39339131116867065  MAE:0.49782225489616394
# ▶ seg33  mean  MSE:0.39339131116867065  MAE:0.49782225489616394
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.5233981013298035  MAE:0.5789750218391418
# ▶ seg34  mean  MSE:0.5233981013298035  MAE:0.5789750218391418
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.4929683208465576  MAE:0.5642839670181274
# ▶ seg35  mean  MSE:0.4929683208465576  MAE:0.5642839670181274
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.5330621004104614  MAE:0.5634309649467468
# ▶ seg36  mean  MSE:0.5330621004104614  MAE:0.5634309649467468
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.43601974844932556  MAE:0.5174741744995117
# ▶ seg37  mean  MSE:0.43601974844932556  MAE:0.5174741744995117
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.3718956708908081  MAE:0.48635369539260864
# ▶ seg38  mean  MSE:0.3718956708908081  MAE:0.48635369539260864
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.41444462537765503  MAE:0.5183999538421631
# ▶ seg39  mean  MSE:0.41444462537765503  MAE:0.5183999538421631
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.7931035161018372  MAE:0.7047972083091736
# ▶ seg40  mean  MSE:0.7931035161018372  MAE:0.7047972083091736
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.4050191640853882  MAE:0.5009158849716187
# ▶ seg41  mean  MSE:0.4050191640853882  MAE:0.5009158849716187
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.4784598648548126  MAE:0.5314472913742065
# ▶ seg42  mean  MSE:0.4784598648548126  MAE:0.5314472913742065
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.6853049397468567  MAE:0.6292956471443176
# ▶ seg43  mean  MSE:0.6853049397468567  MAE:0.6292956471443176
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.3435877859592438  MAE:0.47510871291160583
# ▶ seg44  mean  MSE:0.3435877859592438  MAE:0.47510871291160583
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.410346657037735  MAE:0.5052562952041626
# ▶ seg45  mean  MSE:0.410346657037735  MAE:0.5052562952041626
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.5380507707595825  MAE:0.5646985173225403
# ▶ seg46  mean  MSE:0.5380507707595825  MAE:0.5646985173225403
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.3355920612812042  MAE:0.46849045157432556
# ▶ seg47  mean  MSE:0.3355920612812042  MAE:0.46849045157432556
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.4818606376647949  MAE:0.5254820585250854
# ▶ seg48  mean  MSE:0.4818606376647949  MAE:0.5254820585250854
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.3254041373729706  MAE:0.46241477131843567
# ▶ seg49  mean  MSE:0.3254041373729706  MAE:0.46241477131843567
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.40395545959472656  MAE:0.5036905407905579
# ▶ seg50  mean  MSE:0.40395545959472656  MAE:0.5036905407905579
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.666605532169342  MAE:0.6265531778335571
# ▶ seg51  mean  MSE:0.666605532169342  MAE:0.6265531778335571
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.3668055534362793  MAE:0.4846315085887909
# ▶ seg52  mean  MSE:0.3668055534362793  MAE:0.4846315085887909
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.33753472566604614  MAE:0.47370925545692444
# ▶ seg53  mean  MSE:0.33753472566604614  MAE:0.47370925545692444
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.42061519622802734  MAE:0.49906277656555176
# ▶ seg54  mean  MSE:0.42061519622802734  MAE:0.49906277656555176
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.4828447997570038  MAE:0.5594062805175781
# ▶ seg55  mean  MSE:0.4828447997570038  MAE:0.5594062805175781
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.3128010630607605  MAE:0.45830413699150085
# ▶ seg56  mean  MSE:0.3128010630607605  MAE:0.45830413699150085
#
# seg10 ch0 MSE : 0.46721274

# %% [markdown]
# # Rank Models (by 2nd alidation performance)

# %%
results1_ER_train = torch.load("./1st_results_ER/train_1st_results.pt")
results1_ER_val = torch.load("./1st_results_ER/val_1st_results.pt")
results1_ER_test = torch.load("./1st_results_ER/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 57
SEG_CNT     = 57
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ER_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ER_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ER_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ER_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.970746
#
#   Top  1 | seg 10 | MSE 0.464678 (+0.506067)
#   Top  2 | seg 49 | MSE 0.503409 (+0.467337)
#   Top  3 | seg 34 | MSE 0.545733 (+0.425013)
#   Top  4 | seg 19 | MSE 0.585728 (+0.385017)
#   Top  5 | seg 12 | MSE 0.603794 (+0.366952)
#   Top  6 | seg 36 | MSE 0.607623 (+0.363123)
#   Top  7 | seg 15 | MSE 0.610634 (+0.360112)
#   Top  8 | seg 44 | MSE 0.613782 (+0.356964)
#   Top  9 | seg 31 | MSE 0.618082 (+0.352663)
#   Top 10 | seg 21 | MSE 0.627859 (+0.342887)
#   Top 11 | seg 08 | MSE 0.630180 (+0.340565)
#   Top 12 | seg 50 | MSE 0.631028 (+0.339718)
#   Top 13 | seg 37 | MSE 0.644863 (+0.325883)
#   Top 14 | seg 29 | MSE 0.645169 (+0.325577)
#   Top 15 | seg 51 | MSE 0.648958 (+0.321788)
#   Top 16 | seg 42 | MSE 0.666031 (+0.304715)
#   Top 17 | seg 23 | MSE 0.672526 (+0.298219)
#   Top 18 | seg 45 | MSE 0.678605 (+0.292141)
#   Top 19 | seg 07 | MSE 0.683852 (+0.286894)
#   Top 20 | seg 02 | MSE 0.685624 (+0.285122)
#   Top 21 | seg 41 | MSE 0.692249 (+0.278496)
#   Top 22 | seg 39 | MSE 0.702613 (+0.268133)
#   Top 23 | seg 24 | MSE 0.712790 (+0.257955)
#   Top 24 | seg 56 | MSE 0.720473 (+0.250272)
#   Top 25 | seg 25 | MSE 0.723510 (+0.247235)
#   Top 26 | seg 27 | MSE 0.729838 (+0.240908)
#   Top 27 | seg 05 | MSE 0.731242 (+0.239504)
#   Top 28 | seg 38 | MSE 0.736514 (+0.234232)
#   Top 29 | seg 54 | MSE 0.736629 (+0.234117)
#   Top 30 | seg 28 | MSE 0.743531 (+0.227215)
#   Top 31 | seg 14 | MSE 0.762739 (+0.208007)
#   Top 32 | seg 30 | MSE 0.764854 (+0.205892)
#   Top 33 | seg 40 | MSE 0.765109 (+0.205637)
#   Top 34 | seg 00 | MSE 0.774806 (+0.195940)
#   Top 35 | seg 48 | MSE 0.777772 (+0.192974)
#   Top 36 | seg 35 | MSE 0.799474 (+0.171271)
#   Top 37 | seg 16 | MSE 0.800114 (+0.170632)
#   Top 38 | seg 01 | MSE 0.805032 (+0.165714)
#   Top 39 | seg 03 | MSE 0.805782 (+0.164964)
#   Top 40 | seg 04 | MSE 0.809848 (+0.160898)
#   Top 41 | seg 18 | MSE 0.819707 (+0.151039)
#   Top 42 | seg 13 | MSE 0.832509 (+0.138236)
#   Top 43 | seg 52 | MSE 0.835337 (+0.135408)
#   Top 44 | seg 46 | MSE 0.835839 (+0.134906)
#   Top 45 | seg 26 | MSE 0.838335 (+0.132411)
#   Top 46 | seg 22 | MSE 0.841489 (+0.129257)
#   Top 47 | seg 33 | MSE 0.849334 (+0.121412)
#   Top 48 | seg 17 | MSE 0.857041 (+0.113705)
#   Top 49 | seg 43 | MSE 0.866491 (+0.104255)
#   Top 50 | seg 32 | MSE 0.869086 (+0.101659)
#   Top 51 | seg 53 | MSE 0.871396 (+0.099350)
#   Top 52 | seg 47 | MSE 0.872429 (+0.098316)
#   Top 53 | seg 06 | MSE 0.905075 (+0.065670)
#   Top 54 | seg 55 | MSE 0.905137 (+0.065608)
#   Top 55 | seg 09 | MSE 1.025550 (-0.054804)
#   Top 56 | seg 11 | MSE 1.060525 (-0.089779)
#   Top 57 | seg 20 | MSE 1.093817 (-0.123071)
#
# Saved top segment indices per channel:
# Channel 0: [10, 49, 34, 19, 12, 36, 15, 44, 31, 21, 8, 50, 37, 29, 51, 42, 23, 45, 7, 2, 41, 39, 24, 56, 25, 27, 5, 38, 54, 28, 14, 30, 40, 0, 48, 35, 16, 1, 3, 4, 18, 13, 52, 46, 26, 22, 33, 17, 43, 32, 53, 47, 6, 55, 9, 11, 20]

# %% [markdown]
# ### 1E->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 57
SEG_CNT     = 57
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ER_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ER_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ER_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ER_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.970746
#
#   Top  1 | seg 56 | MSE 0.477095 (+0.493651)
#   Top  2 | seg 47 | MSE 0.539513 (+0.431233)
#   Top  3 | seg 29 | MSE 0.567402 (+0.403344)
#   Top  4 | seg 22 | MSE 0.577118 (+0.393628)
#   Top  5 | seg 49 | MSE 0.591510 (+0.379236)
#   Top  6 | seg 44 | MSE 0.610361 (+0.360384)
#   Top  7 | seg 53 | MSE 0.619782 (+0.350964)
#   Top  8 | seg 30 | MSE 0.636684 (+0.334062)
#   Top  9 | seg 24 | MSE 0.638103 (+0.332643)
#   Top 10 | seg 38 | MSE 0.643105 (+0.327641)
#   Top 11 | seg 02 | MSE 0.646886 (+0.323860)
#   Top 12 | seg 01 | MSE 0.651454 (+0.319292)
#   Top 13 | seg 16 | MSE 0.669224 (+0.301522)
#   Top 14 | seg 19 | MSE 0.672130 (+0.298616)
#   Top 15 | seg 52 | MSE 0.677647 (+0.293099)
#   Top 16 | seg 14 | MSE 0.692593 (+0.278153)
#   Top 17 | seg 41 | MSE 0.692877 (+0.277869)
#   Top 18 | seg 39 | MSE 0.702763 (+0.267983)
#   Top 19 | seg 05 | MSE 0.717007 (+0.253739)
#   Top 20 | seg 33 | MSE 0.723154 (+0.247592)
#   Top 21 | seg 50 | MSE 0.732773 (+0.237973)
#   Top 22 | seg 13 | MSE 0.737761 (+0.232985)
#   Top 23 | seg 45 | MSE 0.739386 (+0.231359)
#   Top 24 | seg 04 | MSE 0.745241 (+0.225505)
#   Top 25 | seg 26 | MSE 0.746438 (+0.224308)
#   Top 26 | seg 11 | MSE 0.746931 (+0.223814)
#   Top 27 | seg 23 | MSE 0.747973 (+0.222772)
#   Top 28 | seg 12 | MSE 0.753288 (+0.217458)
#   Top 29 | seg 08 | MSE 0.765792 (+0.204954)
#   Top 30 | seg 54 | MSE 0.780354 (+0.190391)
#   Top 31 | seg 10 | MSE 0.784175 (+0.186571)
#   Top 32 | seg 07 | MSE 0.785266 (+0.185480)
#   Top 33 | seg 18 | MSE 0.788646 (+0.182100)
#   Top 34 | seg 28 | MSE 0.809422 (+0.161324)
#   Top 35 | seg 09 | MSE 0.827451 (+0.143295)
#   Top 36 | seg 37 | MSE 0.829043 (+0.141702)
#   Top 37 | seg 42 | MSE 0.829429 (+0.141316)
#   Top 38 | seg 35 | MSE 0.829896 (+0.140850)
#   Top 39 | seg 55 | MSE 0.832452 (+0.138294)
#   Top 40 | seg 20 | MSE 0.837140 (+0.133606)
#   Top 41 | seg 48 | MSE 0.852032 (+0.118714)
#   Top 42 | seg 31 | MSE 0.852309 (+0.118437)
#   Top 43 | seg 34 | MSE 0.853410 (+0.117336)
#   Top 44 | seg 15 | MSE 0.864300 (+0.106446)
#   Top 45 | seg 25 | MSE 0.870142 (+0.100603)
#   Top 46 | seg 27 | MSE 0.875417 (+0.095329)
#   Top 47 | seg 17 | MSE 0.886158 (+0.084587)
#   Top 48 | seg 32 | MSE 0.891672 (+0.079073)
#   Top 49 | seg 36 | MSE 0.893826 (+0.076920)
#   Top 50 | seg 21 | MSE 0.900596 (+0.070150)
#   Top 51 | seg 46 | MSE 0.912171 (+0.058575)
#   Top 52 | seg 03 | MSE 0.969136 (+0.001610)
#   Top 53 | seg 51 | MSE 1.015349 (-0.044604)
#   Top 54 | seg 43 | MSE 1.063826 (-0.093080)
#   Top 55 | seg 40 | MSE 1.083397 (-0.112651)
#   Top 56 | seg 00 | MSE 1.125278 (-0.154533)
#   Top 57 | seg 06 | MSE 1.232980 (-0.262234)
#
# Saved top segment indices per channel:
# Channel 0: [56, 47, 29, 22, 49, 44, 53, 30, 24, 38, 2, 1, 16, 19, 52, 14, 41, 39, 5, 33, 50, 13, 45, 4, 26, 11, 23, 12, 8, 54, 10, 7, 18, 28, 9, 37, 42, 35, 55, 20, 48, 31, 34, 15, 25, 27, 17, 32, 36, 21, 46, 3, 51, 43, 40, 0, 6]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ER_test['ES']['mse_test_EES']
    v_mae = results1_ER_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ER_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.333871 | MAE : 0.476638
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.845e-02 | |ρ|=0.9609 | S=0.7462
#    K=10 | Var=2.672e-02 | |ρ|=0.9627 | S=1.0473
#    K=15 | Var=2.641e-02 | |ρ|=0.9626 | S=0.9797
#    K=20 | Var=2.894e-02 | |ρ|=0.9595 | S=0.3766 <- pick
#    K=25 | Var=2.840e-02 | |ρ|=0.9599 | S=0.4333
#    K=30 | Var=2.792e-02 | |ρ|=0.9603 | S=0.4693
#    K=35 | Var=2.862e-02 | |ρ|=0.9613 | S=0.9168
#    K=40 | Var=2.951e-02 | |ρ|=0.9611 | S=0.9615
#    K=45 | Var=3.081e-02 | |ρ|=0.9611 | S=1.1606
#    K=50 | Var=3.102e-02 | |ρ|=0.9609 | S=1.1245
#    K=55 | Var=3.315e-02 | |ρ|=0.9598 | S=1.1140
# [Var-Corr]  K=20
#   MSE = 0.333919 | Δ = -0.000048 | Δ% = -0.01%
#   MAE = 0.466822 | Δ = +0.009816 | Δ% = +2.06%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.333871
# Ensemble mean MSE : 0.333919
# Average Δ MSE     : -0.000048
# Average Δ MSE (%) : -0.01%
#
# Vanilla  mean MAE : 0.476638
# Ensemble mean MAE : 0.466822
# Average Δ MAE     : +0.009816
# Average Δ MAE (%) : +2.06%

# %% [markdown]
# ## 1E->1E

# %%
results1_ER_test['ES']['mae_test_EES']
# Out:
# 0.4766378402709961

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ER_test['ES']['mse_test_EES']
    v_mae = results1_ER_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ER_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.35   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.333871 | MAE : 0.476638
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.163e-02 | |ρ|=0.9571 | S=0.6134 <- pick
#    K=10 | Var=2.429e-02 | |ρ|=0.9607 | S=1.1574
#    K=15 | Var=2.238e-02 | |ρ|=0.9640 | S=1.3949
#    K=20 | Var=2.414e-02 | |ρ|=0.9624 | S=1.3291
#    K=25 | Var=2.501e-02 | |ρ|=0.9626 | S=1.4044
#    K=30 | Var=2.487e-02 | |ρ|=0.9616 | S=1.2867
#    K=35 | Var=2.947e-02 | |ρ|=0.9561 | S=0.9846
#    K=40 | Var=3.020e-02 | |ρ|=0.9568 | S=1.1047
#    K=45 | Var=3.169e-02 | |ρ|=0.9553 | S=1.0326
#    K=50 | Var=3.370e-02 | |ρ|=0.9534 | S=0.9445
#    K=55 | Var=3.823e-02 | |ρ|=0.9513 | S=1.0000
# [Var-Corr]  K=5
#    MSE = 0.308289 | Δ = +0.025582 | Δ% = +7.66%
#    MAE = 0.454370 | Δ = +0.022268 | Δ% = +4.67%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.333871
# Ensemble mean MSE  : 0.308289
# Average Δ MSE      : +0.025582
# Average Δ MSE (%)  : +7.66%
#
# Vanilla  mean MAE  : 0.476638
# Ensemble mean MAE  : 0.454370
# Average Δ MAE      : +0.022268
# Average Δ MAE (%)  : +4.67%
