# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(2)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 2
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/exchange_rate.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                  0       1         2         3         4         5         6  \
# date
# 1990-01-01  0.7855  1.6110  0.861698  0.634196  0.211242  0.006838  0.525486
# 1990-01-02  0.7818  1.6100  0.861104  0.633513  0.211242  0.006863  0.523972
# 1990-01-03  0.7867  1.6293  0.861030  0.648508  0.211242  0.006975  0.526316
# 1990-01-04  0.7860  1.6370  0.862069  0.650618  0.211242  0.006953  0.523834
# 1990-01-05  0.7849  1.6530  0.861995  0.656254  0.211242  0.006940  0.527426
#
#                 OT
# date
# 1990-01-01  0.5930
# 1990-01-02  0.5940
# 1990-01-03  0.5973
# 1990-01-04  0.5970
# 1990-01-05  0.5985

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# OT    float64
# dtype: object
# shape:  (7588, 8)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2010-10-01', '2010-10-02', '2010-10-03', '2010-10-04',
#                '2010-10-05', '2010-10-06', '2010-10-07', '2010-10-08',
#                '2010-10-09', '2010-10-10'],
#               dtype='datetime64[ns]', name='date', length=7588, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %%
set_seed(23)

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model(nn.Module):
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.channels = configs.enc_in

        
        self.attach_pv = getattr(configs, "attach_pv", False)

        
        self.extra_len = self.pred_len // 3

        
        self.seq_len_aug = self.seq_len + (self.extra_len if self.attach_pv else 0)

        self.individual = configs.individual

        
        if self.individual:
            self.Linear = nn.ModuleList()
            for i in range(self.channels):
                self.Linear.append(nn.Linear(self.seq_len_aug, self.pred_len))
        else:
            self.Linear = nn.Linear(self.seq_len_aug, self.pred_len)


    def forward(self, x, ground_truth=None):
        B, L, C = x.size()

        
        
        
        if self.attach_pv and (ground_truth is not None):
            
            gt_part = ground_truth[:, :self.extra_len, :]  

            
            x = torch.cat([x, gt_part], dim=1)

        
        
        
        if self.individual:
            out = torch.zeros([B, self.pred_len, C], dtype=x.dtype).to(x.device)
            for i in range(C):
                out[:, :, i] = self.Linear[i](x[:, :, i])
            return out

        else:
            
            out = self.Linear(x.permute(0, 2, 1))
            return out.permute(0, 2, 1)

# %% [markdown]
# # 데이터 분할/스케일링/시퀀스 데이터 구조화

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len  = 336
pred_len = 336


total_len  = len(target)
num_train  = int(total_len * 0.7)
num_test   = int(total_len * 0.2)
num_val    = total_len - num_train - num_test

border1s = [
    0,
    num_train - seq_len,
    total_len - num_test - seq_len
]
border2s = [
    num_train,
    num_train + num_val,
    total_len
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i : i + seq_len]
        seq_y = data[i + seq_len : i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([4640, 336, 1])
# Train Labels:    torch.Size([4640, 336, 1])
# Val Sequences:   torch.Size([425, 336, 1])
# Val Labels:      torch.Size([425, 336, 1])
# Test Sequences:  torch.Size([1182, 336, 1])
# Test Labels:     torch.Size([1182, 336, 1])

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 기본 모델 학습 (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ER", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.5340225042967961 | Val Loss: 0.9914929100445339
# Validation loss decreased (inf --> 0.991493).  Saving model ...
# Updating learning rate to 0.0005
# Epoch 1 | Train Loss: 0.46989837001109946 | Val Loss: 0.798351566706385
# Validation loss decreased (0.991493 --> 0.798352).  Saving model ...
# Updating learning rate to 0.00025
# Epoch 2 | Train Loss: 0.4550233291140918 | Val Loss: 0.7880746360336032
# Validation loss decreased (0.798352 --> 0.788075).  Saving model ...
# Updating learning rate to 0.000125
# Epoch 3 | Train Loss: 0.4521327386642324 | Val Loss: 0.8658930148397174
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-05
# Epoch 4 | Train Loss: 0.4501476409106419 | Val Loss: 0.8220927992037365
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-05
# Epoch 5 | Train Loss: 0.4486278412670925 | Val Loss: 0.7866680920124054
# Validation loss decreased (0.788075 --> 0.786668).  Saving model ...
# Updating learning rate to 1.5625e-05
# Epoch 6 | Train Loss: 0.4481910423985843 | Val Loss: 0.7461274723921504
# Validation loss decreased (0.786668 --> 0.746127).  Saving model ...
# Updating learning rate to 7.8125e-06
# Epoch 7 | Train Loss: 0.4477969292936654 | Val Loss: 0.7654407886522157
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.90625e-06
# Epoch 8 | Train Loss: 0.4477166252917257 | Val Loss: 0.7686667729701314
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.953125e-06
# Epoch 9 | Train Loss: 0.4475931445072437 | Val Loss: 0.7648709097078868
# EarlyStopping counter: 3 out of 3
# Early stopping triggered. Stopping training.

# %% [markdown]
# # 기본 모델 학습 (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ER", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.5317143670443831 | Val Loss: 1.0131149355854308
# Model saved at epoch 1

# %% [markdown]
# # Test set 추론 및 예측값 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.4275839030742645 | MAE: 0.512901782989502
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.6698463559150696 | MAE: 0.6427668333053589

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %% [markdown]
# ## validation 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.7732888460159302 | MAE: 0.7334914803504944
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 1.049376368522644 | MAE: 0.880126953125

# %% [markdown]
# ## train 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.44775834679603577 | MAE: 0.5014232993125916
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.47281354665756226 | MAE: 0.515205979347229

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([4640, 336, 1])
# val_sequences shape:  torch.Size([425, 336, 1])
# test_sequences shape:  torch.Size([1182, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([4640, 336, 1])
# val_pv shape:  torch.Size([425, 336, 1])
# test_pv shape:  torch.Size([1182, 336, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([4640, 336, 1])
# val_labels shape:  torch.Size([425, 336, 1])
# test_labels shape:  torch.Size([1182, 336, 1])

# %% [markdown]
# # Segment Generation Function by Sliding Window

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV (Predictied Value)

# %%
configs.pred_len
# Out:
# 336

# %%
segment_len = configs.pred_len // 3
stride = 4

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([4640, 57, 112, 1]), Val: torch.Size([425, 57, 112, 1]), Test: torch.Size([1182, 57, 112, 1])
# [Epoch 1] Train seg shape: torch.Size([4640, 57, 112, 1]), Val: torch.Size([425, 57, 112, 1]), Test: torch.Size([1182, 57, 112, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ER'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # Segment 32 - 2차 증강 모델학습 (1 Epoch)

# %%
train_segments_by_epoch = torch.load('./1st_results_ER/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ER/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ER/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo ES

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ER_E{epo}_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 0] Training Time = 0.73 sec
# [Segment 0] GPU Memory Start = 1511.91 MB
# [Segment 0] GPU Memory End   = 1345.86 MB
# [Segment 0] GPU Peak Memory  = 1511.91 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 1] Training Time = 0.60 sec
# [Segment 1] GPU Memory Start = 1345.86 MB
# [Segment 1] GPU Memory End   = 1346.44 MB
# [Segment 1] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 2] Training Time = 0.33 sec
# [Segment 2] GPU Memory Start = 1346.44 MB
# [Segment 2] GPU Memory End   = 1347.02 MB
# [Segment 2] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 3] Training Time = 0.44 sec
# [Segment 3] GPU Memory Start = 1347.02 MB
# [Segment 3] GPU Memory End   = 1347.59 MB
# [Segment 3] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 4] Training Time = 0.33 sec
# [Segment 4] GPU Memory Start = 1347.59 MB
# [Segment 4] GPU Memory End   = 1348.17 MB
# [Segment 4] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 5] Training Time = 0.33 sec
# [Segment 5] GPU Memory Start = 1348.17 MB
# [Segment 5] GPU Memory End   = 1348.74 MB
# [Segment 5] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 6] Training Time = 0.32 sec
# [Segment 6] GPU Memory Start = 1348.74 MB
# [Segment 6] GPU Memory End   = 1349.32 MB
# [Segment 6] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 7] Training Time = 0.34 sec
# [Segment 7] GPU Memory Start = 1349.32 MB
# [Segment 7] GPU Memory End   = 1349.89 MB
# [Segment 7] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 8] Training Time = 0.33 sec
# [Segment 8] GPU Memory Start = 1349.89 MB
# [Segment 8] GPU Memory End   = 1350.47 MB
# [Segment 8] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 9] Training Time = 0.59 sec
# [Segment 9] GPU Memory Start = 1350.47 MB
# [Segment 9] GPU Memory End   = 1351.04 MB
# [Segment 9] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 10] Training Time = 0.35 sec
# [Segment 10] GPU Memory Start = 1351.04 MB
# [Segment 10] GPU Memory End   = 1345.86 MB
# [Segment 10] GPU Peak Memory  = 1351.04 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 11] Training Time = 0.34 sec
# [Segment 11] GPU Memory Start = 1345.86 MB
# [Segment 11] GPU Memory End   = 1346.44 MB
# [Segment 11] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 12] Training Time = 0.33 sec
# [Segment 12] GPU Memory Start = 1346.44 MB
# [Segment 12] GPU Memory End   = 1347.02 MB
# [Segment 12] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 13] Training Time = 0.34 sec
# [Segment 13] GPU Memory Start = 1347.02 MB
# [Segment 13] GPU Memory End   = 1347.59 MB
# [Segment 13] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 14] Training Time = 0.34 sec
# [Segment 14] GPU Memory Start = 1347.59 MB
# [Segment 14] GPU Memory End   = 1348.17 MB
# [Segment 14] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 15] Training Time = 0.34 sec
# [Segment 15] GPU Memory Start = 1348.17 MB
# [Segment 15] GPU Memory End   = 1348.74 MB
# [Segment 15] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 16] Training Time = 0.34 sec
# [Segment 16] GPU Memory Start = 1348.74 MB
# [Segment 16] GPU Memory End   = 1349.32 MB
# [Segment 16] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 17] Training Time = 0.33 sec
# [Segment 17] GPU Memory Start = 1349.32 MB
# [Segment 17] GPU Memory End   = 1349.89 MB
# [Segment 17] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 18] Training Time = 0.33 sec
# [Segment 18] GPU Memory Start = 1349.89 MB
# [Segment 18] GPU Memory End   = 1350.47 MB
# [Segment 18] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 19] Training Time = 0.33 sec
# [Segment 19] GPU Memory Start = 1350.47 MB
# [Segment 19] GPU Memory End   = 1351.04 MB
# [Segment 19] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 20] Training Time = 0.32 sec
# [Segment 20] GPU Memory Start = 1351.04 MB
# [Segment 20] GPU Memory End   = 1345.86 MB
# [Segment 20] GPU Peak Memory  = 1351.04 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 21] Training Time = 0.33 sec
# [Segment 21] GPU Memory Start = 1345.86 MB
# [Segment 21] GPU Memory End   = 1346.44 MB
# [Segment 21] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 22] Training Time = 0.34 sec
# [Segment 22] GPU Memory Start = 1346.44 MB
# [Segment 22] GPU Memory End   = 1347.02 MB
# [Segment 22] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 23] Training Time = 0.34 sec
# [Segment 23] GPU Memory Start = 1347.02 MB
# [Segment 23] GPU Memory End   = 1347.59 MB
# [Segment 23] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 24] Training Time = 0.50 sec
# [Segment 24] GPU Memory Start = 1347.59 MB
# [Segment 24] GPU Memory End   = 1348.17 MB
# [Segment 24] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 25] Training Time = 0.48 sec
# [Segment 25] GPU Memory Start = 1348.17 MB
# [Segment 25] GPU Memory End   = 1348.74 MB
# [Segment 25] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 26] Training Time = 0.33 sec
# [Segment 26] GPU Memory Start = 1348.74 MB
# [Segment 26] GPU Memory End   = 1349.32 MB
# [Segment 26] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 27] Training Time = 0.33 sec
# [Segment 27] GPU Memory Start = 1349.32 MB
# [Segment 27] GPU Memory End   = 1349.89 MB
# [Segment 27] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 28] Training Time = 0.33 sec
# [Segment 28] GPU Memory Start = 1349.89 MB
# [Segment 28] GPU Memory End   = 1350.47 MB
# [Segment 28] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 29] Training Time = 0.49 sec
# [Segment 29] GPU Memory Start = 1350.47 MB
# [Segment 29] GPU Memory End   = 1351.04 MB
# [Segment 29] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 30] Training Time = 0.33 sec
# [Segment 30] GPU Memory Start = 1351.04 MB
# [Segment 30] GPU Memory End   = 1345.86 MB
# [Segment 30] GPU Peak Memory  = 1351.04 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 31] Training Time = 0.32 sec
# [Segment 31] GPU Memory Start = 1345.86 MB
# [Segment 31] GPU Memory End   = 1346.44 MB
# [Segment 31] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 32] Training Time = 0.32 sec
# [Segment 32] GPU Memory Start = 1346.44 MB
# [Segment 32] GPU Memory End   = 1347.02 MB
# [Segment 32] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 33] Training Time = 0.68 sec
# [Segment 33] GPU Memory Start = 1347.02 MB
# [Segment 33] GPU Memory End   = 1347.59 MB
# [Segment 33] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 34] Training Time = 0.33 sec
# [Segment 34] GPU Memory Start = 1347.59 MB
# [Segment 34] GPU Memory End   = 1348.17 MB
# [Segment 34] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 35] Training Time = 0.33 sec
# [Segment 35] GPU Memory Start = 1348.17 MB
# [Segment 35] GPU Memory End   = 1348.74 MB
# [Segment 35] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 36] Training Time = 0.33 sec
# [Segment 36] GPU Memory Start = 1348.74 MB
# [Segment 36] GPU Memory End   = 1349.32 MB
# [Segment 36] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 37] Training Time = 0.33 sec
# [Segment 37] GPU Memory Start = 1349.32 MB
# [Segment 37] GPU Memory End   = 1349.89 MB
# [Segment 37] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 38] Training Time = 0.65 sec
# [Segment 38] GPU Memory Start = 1349.89 MB
# [Segment 38] GPU Memory End   = 1350.47 MB
# [Segment 38] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 39] Training Time = 0.33 sec
# [Segment 39] GPU Memory Start = 1350.47 MB
# [Segment 39] GPU Memory End   = 1351.04 MB
# [Segment 39] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 40] Training Time = 0.33 sec
# [Segment 40] GPU Memory Start = 1351.04 MB
# [Segment 40] GPU Memory End   = 1345.86 MB
# [Segment 40] GPU Peak Memory  = 1351.04 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 41] Training Time = 0.33 sec
# [Segment 41] GPU Memory Start = 1345.86 MB
# [Segment 41] GPU Memory End   = 1346.44 MB
# [Segment 41] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 42] Training Time = 0.33 sec
# [Segment 42] GPU Memory Start = 1346.44 MB
# [Segment 42] GPU Memory End   = 1347.02 MB
# [Segment 42] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 43] Training Time = 0.33 sec
# [Segment 43] GPU Memory Start = 1347.02 MB
# [Segment 43] GPU Memory End   = 1347.59 MB
# [Segment 43] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 44] Training Time = 0.33 sec
# [Segment 44] GPU Memory Start = 1347.59 MB
# [Segment 44] GPU Memory End   = 1348.17 MB
# [Segment 44] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 45] Training Time = 0.41 sec
# [Segment 45] GPU Memory Start = 1348.17 MB
# [Segment 45] GPU Memory End   = 1348.74 MB
# [Segment 45] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 46] Training Time = 0.33 sec
# [Segment 46] GPU Memory Start = 1348.74 MB
# [Segment 46] GPU Memory End   = 1349.32 MB
# [Segment 46] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 47] Training Time = 0.33 sec
# [Segment 47] GPU Memory Start = 1349.32 MB
# [Segment 47] GPU Memory End   = 1349.89 MB
# [Segment 47] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 48] Training Time = 0.53 sec
# [Segment 48] GPU Memory Start = 1349.89 MB
# [Segment 48] GPU Memory End   = 1350.47 MB
# [Segment 48] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 49] Training Time = 0.32 sec
# [Segment 49] GPU Memory Start = 1350.47 MB
# [Segment 49] GPU Memory End   = 1351.04 MB
# [Segment 49] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 50] Training Time = 0.33 sec
# [Segment 50] GPU Memory Start = 1351.04 MB
# [Segment 50] GPU Memory End   = 1345.86 MB
# [Segment 50] GPU Peak Memory  = 1351.04 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 51] Training Time = 0.33 sec
# [Segment 51] GPU Memory Start = 1345.86 MB
# [Segment 51] GPU Memory End   = 1346.44 MB
# [Segment 51] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 52] Training Time = 0.33 sec
# [Segment 52] GPU Memory Start = 1346.44 MB
# [Segment 52] GPU Memory End   = 1347.02 MB
# [Segment 52] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 53] Training Time = 0.37 sec
# [Segment 53] GPU Memory Start = 1347.02 MB
# [Segment 53] GPU Memory End   = 1347.59 MB
# [Segment 53] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 54] Training Time = 0.32 sec
# [Segment 54] GPU Memory Start = 1347.59 MB
# [Segment 54] GPU Memory End   = 1348.17 MB
# [Segment 54] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 55] Training Time = 0.33 sec
# [Segment 55] GPU Memory Start = 1348.17 MB
# [Segment 55] GPU Memory End   = 1348.74 MB
# [Segment 55] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 56] Training Time = 0.33 sec
# [Segment 56] GPU Memory Start = 1348.74 MB
# [Segment 56] GPU Memory End   = 1349.32 MB
# [Segment 56] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo 1

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ER_E{epo}_1E/",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters()) 
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 0] Training Time = 0.68 sec
# [Segment 0] GPU Memory Start = 1345.86 MB
# [Segment 0] GPU Memory End   = 1345.86 MB
# [Segment 0] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 1] Training Time = 0.37 sec
# [Segment 1] GPU Memory Start = 1345.86 MB
# [Segment 1] GPU Memory End   = 1346.44 MB
# [Segment 1] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 2] Training Time = 0.33 sec
# [Segment 2] GPU Memory Start = 1346.44 MB
# [Segment 2] GPU Memory End   = 1347.02 MB
# [Segment 2] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 3] Training Time = 0.33 sec
# [Segment 3] GPU Memory Start = 1347.02 MB
# [Segment 3] GPU Memory End   = 1347.59 MB
# [Segment 3] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 4] Training Time = 0.62 sec
# [Segment 4] GPU Memory Start = 1347.59 MB
# [Segment 4] GPU Memory End   = 1348.17 MB
# [Segment 4] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 5] Training Time = 0.34 sec
# [Segment 5] GPU Memory Start = 1348.17 MB
# [Segment 5] GPU Memory End   = 1348.74 MB
# [Segment 5] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 6] Training Time = 0.34 sec
# [Segment 6] GPU Memory Start = 1345.86 MB
# [Segment 6] GPU Memory End   = 1346.44 MB
# [Segment 6] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 7] Training Time = 0.33 sec
# [Segment 7] GPU Memory Start = 1346.44 MB
# [Segment 7] GPU Memory End   = 1347.02 MB
# [Segment 7] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 8] Training Time = 0.37 sec
# [Segment 8] GPU Memory Start = 1347.02 MB
# [Segment 8] GPU Memory End   = 1347.59 MB
# [Segment 8] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 9] Training Time = 0.32 sec
# [Segment 9] GPU Memory Start = 1347.59 MB
# [Segment 9] GPU Memory End   = 1348.17 MB
# [Segment 9] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 10] Training Time = 0.32 sec
# [Segment 10] GPU Memory Start = 1348.17 MB
# [Segment 10] GPU Memory End   = 1348.74 MB
# [Segment 10] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 11] Training Time = 0.64 sec
# [Segment 11] GPU Memory Start = 1348.74 MB
# [Segment 11] GPU Memory End   = 1349.32 MB
# [Segment 11] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 12] Training Time = 0.35 sec
# [Segment 12] GPU Memory Start = 1349.32 MB
# [Segment 12] GPU Memory End   = 1349.89 MB
# [Segment 12] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 13] Training Time = 0.34 sec
# [Segment 13] GPU Memory Start = 1349.89 MB
# [Segment 13] GPU Memory End   = 1350.47 MB
# [Segment 13] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 14] Training Time = 0.35 sec
# [Segment 14] GPU Memory Start = 1350.47 MB
# [Segment 14] GPU Memory End   = 1351.04 MB
# [Segment 14] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 15] Training Time = 0.35 sec
# [Segment 15] GPU Memory Start = 1351.04 MB
# [Segment 15] GPU Memory End   = 1351.62 MB
# [Segment 15] GPU Peak Memory  = 1352.80 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 16] Training Time = 0.34 sec
# [Segment 16] GPU Memory Start = 1345.86 MB
# [Segment 16] GPU Memory End   = 1346.44 MB
# [Segment 16] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 17] Training Time = 0.34 sec
# [Segment 17] GPU Memory Start = 1346.44 MB
# [Segment 17] GPU Memory End   = 1347.02 MB
# [Segment 17] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 18] Training Time = 0.57 sec
# [Segment 18] GPU Memory Start = 1347.02 MB
# [Segment 18] GPU Memory End   = 1347.59 MB
# [Segment 18] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 19] Training Time = 0.35 sec
# [Segment 19] GPU Memory Start = 1347.59 MB
# [Segment 19] GPU Memory End   = 1348.17 MB
# [Segment 19] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 20] Training Time = 0.41 sec
# [Segment 20] GPU Memory Start = 1348.17 MB
# [Segment 20] GPU Memory End   = 1348.74 MB
# [Segment 20] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 21] Training Time = 0.62 sec
# [Segment 21] GPU Memory Start = 1348.74 MB
# [Segment 21] GPU Memory End   = 1349.32 MB
# [Segment 21] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 22] Training Time = 0.35 sec
# [Segment 22] GPU Memory Start = 1349.32 MB
# [Segment 22] GPU Memory End   = 1349.89 MB
# [Segment 22] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 23] Training Time = 0.34 sec
# [Segment 23] GPU Memory Start = 1349.89 MB
# [Segment 23] GPU Memory End   = 1350.47 MB
# [Segment 23] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 24] Training Time = 0.34 sec
# [Segment 24] GPU Memory Start = 1350.47 MB
# [Segment 24] GPU Memory End   = 1351.04 MB
# [Segment 24] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 25] Training Time = 0.34 sec
# [Segment 25] GPU Memory Start = 1351.04 MB
# [Segment 25] GPU Memory End   = 1351.62 MB
# [Segment 25] GPU Peak Memory  = 1352.80 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 26] Training Time = 0.34 sec
# [Segment 26] GPU Memory Start = 1345.86 MB
# [Segment 26] GPU Memory End   = 1346.44 MB
# [Segment 26] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 27] Training Time = 0.34 sec
# [Segment 27] GPU Memory Start = 1346.44 MB
# [Segment 27] GPU Memory End   = 1347.02 MB
# [Segment 27] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 28] Training Time = 0.34 sec
# [Segment 28] GPU Memory Start = 1347.02 MB
# [Segment 28] GPU Memory End   = 1347.59 MB
# [Segment 28] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 29] Training Time = 0.35 sec
# [Segment 29] GPU Memory Start = 1347.59 MB
# [Segment 29] GPU Memory End   = 1348.17 MB
# [Segment 29] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 30] Training Time = 0.34 sec
# [Segment 30] GPU Memory Start = 1348.17 MB
# [Segment 30] GPU Memory End   = 1348.74 MB
# [Segment 30] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 31] Training Time = 0.34 sec
# [Segment 31] GPU Memory Start = 1348.74 MB
# [Segment 31] GPU Memory End   = 1349.32 MB
# [Segment 31] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 32] Training Time = 0.34 sec
# [Segment 32] GPU Memory Start = 1349.32 MB
# [Segment 32] GPU Memory End   = 1349.89 MB
# [Segment 32] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 33] Training Time = 0.34 sec
# [Segment 33] GPU Memory Start = 1349.89 MB
# [Segment 33] GPU Memory End   = 1350.47 MB
# [Segment 33] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 34] Training Time = 0.34 sec
# [Segment 34] GPU Memory Start = 1350.47 MB
# [Segment 34] GPU Memory End   = 1351.04 MB
# [Segment 34] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 35] Training Time = 0.34 sec
# [Segment 35] GPU Memory Start = 1351.04 MB
# [Segment 35] GPU Memory End   = 1351.62 MB
# [Segment 35] GPU Peak Memory  = 1352.80 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 36] Training Time = 0.43 sec
# [Segment 36] GPU Memory Start = 1345.86 MB
# [Segment 36] GPU Memory End   = 1346.44 MB
# [Segment 36] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 37] Training Time = 0.34 sec
# [Segment 37] GPU Memory Start = 1346.44 MB
# [Segment 37] GPU Memory End   = 1347.02 MB
# [Segment 37] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 38] Training Time = 0.34 sec
# [Segment 38] GPU Memory Start = 1347.02 MB
# [Segment 38] GPU Memory End   = 1347.59 MB
# [Segment 38] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 39] Training Time = 0.34 sec
# [Segment 39] GPU Memory Start = 1347.59 MB
# [Segment 39] GPU Memory End   = 1348.17 MB
# [Segment 39] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 40] Training Time = 0.66 sec
# [Segment 40] GPU Memory Start = 1348.17 MB
# [Segment 40] GPU Memory End   = 1348.74 MB
# [Segment 40] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 41] Training Time = 0.33 sec
# [Segment 41] GPU Memory Start = 1348.74 MB
# [Segment 41] GPU Memory End   = 1349.32 MB
# [Segment 41] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 42] Training Time = 0.47 sec
# [Segment 42] GPU Memory Start = 1349.32 MB
# [Segment 42] GPU Memory End   = 1349.89 MB
# [Segment 42] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 43] Training Time = 0.34 sec
# [Segment 43] GPU Memory Start = 1349.89 MB
# [Segment 43] GPU Memory End   = 1350.47 MB
# [Segment 43] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 44] Training Time = 0.41 sec
# [Segment 44] GPU Memory Start = 1350.47 MB
# [Segment 44] GPU Memory End   = 1351.04 MB
# [Segment 44] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 45] Training Time = 0.33 sec
# [Segment 45] GPU Memory Start = 1351.04 MB
# [Segment 45] GPU Memory End   = 1351.62 MB
# [Segment 45] GPU Peak Memory  = 1352.80 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 46] Training Time = 0.34 sec
# [Segment 46] GPU Memory Start = 1345.86 MB
# [Segment 46] GPU Memory End   = 1346.44 MB
# [Segment 46] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 47] Training Time = 0.34 sec
# [Segment 47] GPU Memory Start = 1346.44 MB
# [Segment 47] GPU Memory End   = 1347.02 MB
# [Segment 47] GPU Peak Memory  = 1348.19 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 48] Training Time = 0.34 sec
# [Segment 48] GPU Memory Start = 1347.02 MB
# [Segment 48] GPU Memory End   = 1347.59 MB
# [Segment 48] GPU Peak Memory  = 1348.77 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 49] Training Time = 0.35 sec
# [Segment 49] GPU Memory Start = 1347.59 MB
# [Segment 49] GPU Memory End   = 1348.17 MB
# [Segment 49] GPU Peak Memory  = 1349.34 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 50] Training Time = 0.34 sec
# [Segment 50] GPU Memory Start = 1348.17 MB
# [Segment 50] GPU Memory End   = 1348.74 MB
# [Segment 50] GPU Peak Memory  = 1349.92 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 51] Training Time = 0.33 sec
# [Segment 51] GPU Memory Start = 1348.74 MB
# [Segment 51] GPU Memory End   = 1349.32 MB
# [Segment 51] GPU Peak Memory  = 1350.50 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 52] Training Time = 0.34 sec
# [Segment 52] GPU Memory Start = 1349.32 MB
# [Segment 52] GPU Memory End   = 1349.89 MB
# [Segment 52] GPU Peak Memory  = 1351.07 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 53] Training Time = 0.34 sec
# [Segment 53] GPU Memory Start = 1349.89 MB
# [Segment 53] GPU Memory End   = 1350.47 MB
# [Segment 53] GPU Peak Memory  = 1351.65 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 54] Training Time = 0.34 sec
# [Segment 54] GPU Memory Start = 1350.47 MB
# [Segment 54] GPU Memory End   = 1351.04 MB
# [Segment 54] GPU Peak Memory  = 1352.22 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 55] Training Time = 0.33 sec
# [Segment 55] GPU Memory Start = 1351.04 MB
# [Segment 55] GPU Memory End   = 1351.62 MB
# [Segment 55] GPU Peak Memory  = 1352.80 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 5.9473 MB
#   yb per batch = 0.0410 MB, total = 5.9473 MB
#   pv per batch = 0.0137 MB, total = 1.9824 MB
# [Segment 56] Training Time = 0.55 sec
# [Segment 56] GPU Memory Start = 1345.86 MB
# [Segment 56] GPU Memory End   = 1346.44 MB
# [Segment 56] GPU Peak Memory  = 1347.62 MB
#
# ============= Done =============

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for validation set 얻은 후 에러율 계산

# %%
train_segments_by_epoch = torch.load('./1st_results_ER/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ER/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ER/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ER_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.5213548541069031  MAE:0.5920009016990662
# ▶ seg0  mean  MSE:0.5213548541069031  MAE:0.5920009016990662
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.7101553082466125  MAE:0.6963046789169312
# ▶ seg1  mean  MSE:0.7101553082466125  MAE:0.6963046789169312
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.9965845942497253  MAE:0.8318064212799072
# ▶ seg2  mean  MSE:0.9965845942497253  MAE:0.8318064212799072
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.6182958483695984  MAE:0.6485163569450378
# ▶ seg3  mean  MSE:0.6182958483695984  MAE:0.6485163569450378
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.9456847310066223  MAE:0.8188828825950623
# ▶ seg4  mean  MSE:0.9456847310066223  MAE:0.8188828825950623
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.9170646071434021  MAE:0.8193905353546143
# ▶ seg5  mean  MSE:0.9170646071434021  MAE:0.8193905353546143
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:1.2742295265197754  MAE:0.9582012891769409
# ▶ seg6  mean  MSE:1.2742295265197754  MAE:0.9582012891769409
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.8483017086982727  MAE:0.7661426067352295
# ▶ seg7  mean  MSE:0.8483017086982727  MAE:0.7661426067352295
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.5430043339729309  MAE:0.5990065932273865
# ▶ seg8  mean  MSE:0.5430043339729309  MAE:0.5990065932273865
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:1.039014220237732  MAE:0.8490909934043884
# ▶ seg9  mean  MSE:1.039014220237732  MAE:0.8490909934043884
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.7510323524475098  MAE:0.7163282036781311
# ▶ seg10  mean  MSE:0.7510323524475098  MAE:0.7163282036781311
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.7234430313110352  MAE:0.6957336664199829
# ▶ seg11  mean  MSE:0.7234430313110352  MAE:0.6957336664199829
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.7015812397003174  MAE:0.6854712963104248
# ▶ seg12  mean  MSE:0.7015812397003174  MAE:0.6854712963104248
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.7143397927284241  MAE:0.7042723894119263
# ▶ seg13  mean  MSE:0.7143397927284241  MAE:0.7042723894119263
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.5265395641326904  MAE:0.5834445953369141
# ▶ seg14  mean  MSE:0.5265395641326904  MAE:0.5834445953369141
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.7516781091690063  MAE:0.7206247448921204
# ▶ seg15  mean  MSE:0.7516781091690063  MAE:0.7206247448921204
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.7724942564964294  MAE:0.7279963493347168
# ▶ seg16  mean  MSE:0.7724942564964294  MAE:0.7279963493347168
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.8210902214050293  MAE:0.7537786364555359
# ▶ seg17  mean  MSE:0.8210902214050293  MAE:0.7537786364555359
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.7997328639030457  MAE:0.7504397630691528
# ▶ seg18  mean  MSE:0.7997328639030457  MAE:0.7504397630691528
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.8112342953681946  MAE:0.7523583173751831
# ▶ seg19  mean  MSE:0.8112342953681946  MAE:0.7523583173751831
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.4872910678386688  MAE:0.5712858438491821
# ▶ seg45  mean  MSE:0.4872910678386688  MAE:0.5712858438491821
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.986940860748291  MAE:0.8372334837913513
# ▶ seg46  mean  MSE:0.986940860748291  MAE:0.8372334837913513
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.8158739805221558  MAE:0.7414183020591736
# ▶ seg47  mean  MSE:0.8158739805221558  MAE:0.7414183020591736
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.8414150476455688  MAE:0.7579813599586487
# ▶ seg48  mean  MSE:0.8414150476455688  MAE:0.7579813599586487
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.881978452205658  MAE:0.778443455696106
# ▶ seg49  mean  MSE:0.881978452205658  MAE:0.778443455696106
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.7372006773948669  MAE:0.706214964389801
# ▶ seg50  mean  MSE:0.7372006773948669  MAE:0.706214964389801
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.6915645599365234  MAE:0.6851084232330322
# ▶ seg51  mean  MSE:0.6915645599365234  MAE:0.6851084232330322
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.7780864834785461  MAE:0.7190834283828735
# ▶ seg52  mean  MSE:0.7780864834785461  MAE:0.7190834283828735
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.7235550880432129  MAE:0.7030722498893738
# ▶ seg53  mean  MSE:0.7235550880432129  MAE:0.7030722498893738
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.9150182008743286  MAE:0.7967627644538879
# ▶ seg54  mean  MSE:0.9150182008743286  MAE:0.7967627644538879
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.6466432213783264  MAE:0.6578397750854492
# ▶ seg55  mean  MSE:0.6466432213783264  MAE:0.6578397750854492
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.9602903127670288  MAE:0.8240644335746765
# ▶ seg56  mean  MSE:0.9602903127670288  MAE:0.8240644335746765
#
# seg10 ch0 MSE : 0.75103235

# %% [markdown]
# ## EPO 1 - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_E1_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ER_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.7957842350006104  MAE:0.754594087600708
# ▶ seg0  mean  MSE:0.7957842350006104  MAE:0.754594087600708
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.7021665573120117  MAE:0.7029781341552734
# ▶ seg1  mean  MSE:0.7021665573120117  MAE:0.7029781341552734
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.7734004855155945  MAE:0.7259132266044617
# ▶ seg2  mean  MSE:0.7734004855155945  MAE:0.7259132266044617
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.9190059304237366  MAE:0.8104861378669739
# ▶ seg3  mean  MSE:0.9190059304237366  MAE:0.8104861378669739
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.7969421744346619  MAE:0.7602499127388
# ▶ seg4  mean  MSE:0.7969421744346619  MAE:0.7602499127388
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.7673737406730652  MAE:0.7296603322029114
# ▶ seg5  mean  MSE:0.7673737406730652  MAE:0.7296603322029114
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.7195113301277161  MAE:0.7068763375282288
# ▶ seg6  mean  MSE:0.7195113301277161  MAE:0.7068763375282288
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.8167014122009277  MAE:0.7645173668861389
# ▶ seg7  mean  MSE:0.8167014122009277  MAE:0.7645173668861389
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.7555059790611267  MAE:0.732734203338623
# ▶ seg8  mean  MSE:0.7555059790611267  MAE:0.732734203338623
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:1.0178602933883667  MAE:0.8704816102981567
# ▶ seg9  mean  MSE:1.0178602933883667  MAE:0.8704816102981567
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.9063530564308167  MAE:0.7968648672103882
# ▶ seg36  mean  MSE:0.9063530564308167  MAE:0.7968648672103882
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.7402274012565613  MAE:0.7146875858306885
# ▶ seg37  mean  MSE:0.7402274012565613  MAE:0.7146875858306885
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.8226239681243896  MAE:0.7656887769699097
# ▶ seg38  mean  MSE:0.8226239681243896  MAE:0.7656887769699097
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.5931715369224548  MAE:0.6349588632583618
# ▶ seg39  mean  MSE:0.5931715369224548  MAE:0.6349588632583618
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.528624415397644  MAE:0.5921908020973206
# ▶ seg40  mean  MSE:0.528624415397644  MAE:0.5921908020973206
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.7716488242149353  MAE:0.7212351560592651
# ▶ seg41  mean  MSE:0.7716488242149353  MAE:0.7212351560592651
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.9735450744628906  MAE:0.8274914622306824
# ▶ seg42  mean  MSE:0.9735450744628906  MAE:0.8274914622306824
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.9223278760910034  MAE:0.8125895857810974
# ▶ seg43  mean  MSE:0.9223278760910034  MAE:0.8125895857810974
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.912973165512085  MAE:0.8228818774223328
# ▶ seg44  mean  MSE:0.912973165512085  MAE:0.8228818774223328
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:1.3206015825271606  MAE:0.9897826910018921
# ▶ seg45  mean  MSE:1.3206015825271606  MAE:0.9897826910018921
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.695231556892395  MAE:0.6907511353492737
# ▶ seg46  mean  MSE:0.695231556892395  MAE:0.6907511353492737
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.6417249441146851  MAE:0.6514887809753418
# ▶ seg47  mean  MSE:0.6417249441146851  MAE:0.6514887809753418
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.7826834321022034  MAE:0.7363169193267822
# ▶ seg48  mean  MSE:0.7826834321022034  MAE:0.7363169193267822
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.7187942862510681  MAE:0.7135916948318481
# ▶ seg49  mean  MSE:0.7187942862510681  MAE:0.7135916948318481
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.8254953622817993  MAE:0.7696053981781006
# ▶ seg50  mean  MSE:0.8254953622817993  MAE:0.7696053981781006
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.7169477343559265  MAE:0.6967301368713379
# ▶ seg51  mean  MSE:0.7169477343559265  MAE:0.6967301368713379
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.7299851775169373  MAE:0.7209715247154236
# ▶ seg52  mean  MSE:0.7299851775169373  MAE:0.7209715247154236
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.5740724802017212  MAE:0.6289291381835938
# ▶ seg53  mean  MSE:0.5740724802017212  MAE:0.6289291381835938
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.8151063919067383  MAE:0.7470377087593079
# ▶ seg54  mean  MSE:0.8151063919067383  MAE:0.7470377087593079
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:1.0228750705718994  MAE:0.8513178825378418
# ▶ seg55  mean  MSE:1.0228750705718994  MAE:0.8513178825378418
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.8772149085998535  MAE:0.7908630967140198
# ▶ seg56  mean  MSE:0.8772149085998535  MAE:0.7908630967140198
#
# seg10 ch0 MSE : 0.77255267

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for test set 얻은 후 에러율 계산

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 336
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ER_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.3839368224143982  MAE:0.4943857192993164
# ▶ seg51  mean  MSE:0.3839368224143982  MAE:0.4943857192993164
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.44963037967681885  MAE:0.515658974647522
# ▶ seg52  mean  MSE:0.44963037967681885  MAE:0.515658974647522
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.40801751613616943  MAE:0.5038355588912964
# ▶ seg53  mean  MSE:0.40801751613616943  MAE:0.5038355588912964
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.5453307628631592  MAE:0.5651465654373169
# ▶ seg54  mean  MSE:0.5453307628631592  MAE:0.5651465654373169
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.4044938385486603  MAE:0.5040501952171326
# ▶ seg55  mean  MSE:0.4044938385486603  MAE:0.5040501952171326
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.626833975315094  MAE:0.6150352358818054
# ▶ seg56  mean  MSE:0.626833975315094  MAE:0.6150352358818054
#
# seg10 ch0 MSE : 0.4061893

# %% [markdown]
# ## EPO 1 - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 336
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_E1_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ER_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.41102635860443115  MAE:0.5117227435112
# ▶ seg0  mean  MSE:0.41102635860443115  MAE:0.5117227435112
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.364205002784729  MAE:0.4923405349254608
# ▶ seg1  mean  MSE:0.364205002784729  MAE:0.4923405349254608
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.4594067931175232  MAE:0.5203003883361816
# ▶ seg2  mean  MSE:0.4594067931175232  MAE:0.5203003883361816
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.5019160509109497  MAE:0.5475428700447083
# ▶ seg3  mean  MSE:0.5019160509109497  MAE:0.5475428700447083
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.4262775182723999  MAE:0.5287734866142273
# ▶ seg4  mean  MSE:0.4262775182723999  MAE:0.5287734866142273
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.4215741753578186  MAE:0.5090141892433167
# ▶ seg5  mean  MSE:0.4215741753578186  MAE:0.5090141892433167
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.388286828994751  MAE:0.49393120408058167
# ▶ seg6  mean  MSE:0.388286828994751  MAE:0.49393120408058167
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.4371110200881958  MAE:0.5249033570289612
# ▶ seg7  mean  MSE:0.4371110200881958  MAE:0.5249033570289612
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.4044509828090668  MAE:0.5132593512535095
# ▶ seg8  mean  MSE:0.4044509828090668  MAE:0.5132593512535095
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.5719044804573059  MAE:0.6008251309394836
# ▶ seg9  mean  MSE:0.5719044804573059  MAE:0.6008251309394836
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.4383890628814697  MAE:0.5207405686378479
# ▶ seg10  mean  MSE:0.4383890628814697  MAE:0.5207405686378479
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.4424160122871399  MAE:0.5149626135826111
# ▶ seg11  mean  MSE:0.4424160122871399  MAE:0.5149626135826111
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.46169552206993103  MAE:0.5457535982131958
# ▶ seg12  mean  MSE:0.46169552206993103  MAE:0.5457535982131958
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.8675016760826111  MAE:0.7482296824455261
# ▶ seg13  mean  MSE:0.8675016760826111  MAE:0.7482296824455261
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.4755147695541382  MAE:0.5487344264984131
# ▶ seg14  mean  MSE:0.4755147695541382  MAE:0.5487344264984131
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.5412175059318542  MAE:0.5701321363449097
# ▶ seg15  mean  MSE:0.5412175059318542  MAE:0.5701321363449097
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.6163557171821594  MAE:0.6006340384483337
# ▶ seg42  mean  MSE:0.6163557171821594  MAE:0.6006340384483337
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.5716119408607483  MAE:0.5886111259460449
# ▶ seg43  mean  MSE:0.5716119408607483  MAE:0.5886111259460449
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.4815662205219269  MAE:0.5596651434898376
# ▶ seg44  mean  MSE:0.4815662205219269  MAE:0.5596651434898376
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.998846709728241  MAE:0.7993977069854736
# ▶ seg45  mean  MSE:0.998846709728241  MAE:0.7993977069854736
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.4007693827152252  MAE:0.498991459608078
# ▶ seg46  mean  MSE:0.4007693827152252  MAE:0.498991459608078
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.3834201395511627  MAE:0.4879114627838135
# ▶ seg47  mean  MSE:0.3834201395511627  MAE:0.4879114627838135
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.4772549569606781  MAE:0.536998450756073
# ▶ seg48  mean  MSE:0.4772549569606781  MAE:0.536998450756073
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.3880327045917511  MAE:0.5058832764625549
# ▶ seg49  mean  MSE:0.3880327045917511  MAE:0.5058832764625549
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.4589654803276062  MAE:0.5348015427589417
# ▶ seg50  mean  MSE:0.4589654803276062  MAE:0.5348015427589417
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.4477940499782562  MAE:0.5180522203445435
# ▶ seg51  mean  MSE:0.4477940499782562  MAE:0.5180522203445435
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.42843306064605713  MAE:0.5312891602516174
# ▶ seg52  mean  MSE:0.42843306064605713  MAE:0.5312891602516174
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.3304566442966461  MAE:0.47712504863739014
# ▶ seg53  mean  MSE:0.3304566442966461  MAE:0.47712504863739014
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.4465024471282959  MAE:0.511772632598877
# ▶ seg54  mean  MSE:0.4465024471282959  MAE:0.511772632598877
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.6453876495361328  MAE:0.6150715947151184
# ▶ seg55  mean  MSE:0.6453876495361328  MAE:0.6150715947151184
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.49956122040748596  MAE:0.5526204705238342
# ▶ seg56  mean  MSE:0.49956122040748596  MAE:0.5526204705238342
#
# seg10 ch0 MSE : 0.43838906

# %% [markdown]
# # Rank Models (by 2nd alidation performance)

# %%
results1_ER_train = torch.load("./1st_results_ER/train_1st_results.pt")
results1_ER_val = torch.load("./1st_results_ER/val_1st_results.pt")
results1_ER_test = torch.load("./1st_results_ER/test_1st_results.pt")

# %% [markdown]
# ### EPO ES - 1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 57
SEG_CNT     = 57
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ER_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ER_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ER_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ER_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 1.049376
#
#   Top  1 | seg 45 | MSE 0.487291 (+0.562085)
#   Top  2 | seg 00 | MSE 0.521355 (+0.528022)
#   Top  3 | seg 14 | MSE 0.526540 (+0.522837)
#   Top  4 | seg 37 | MSE 0.529014 (+0.520362)
#   Top  5 | seg 08 | MSE 0.543004 (+0.506372)
#   Top  6 | seg 21 | MSE 0.604795 (+0.444581)
#   Top  7 | seg 03 | MSE 0.618296 (+0.431081)
#   Top  8 | seg 34 | MSE 0.624556 (+0.424820)
#   Top  9 | seg 42 | MSE 0.627235 (+0.422142)
#   Top 10 | seg 55 | MSE 0.646643 (+0.402733)
#   Top 41 | seg 22 | MSE 0.866868 (+0.182508)
#   Top 42 | seg 56 | MSE 0.877215 (+0.172161)
#   Top 43 | seg 15 | MSE 0.883731 (+0.165646)
#   Top 44 | seg 36 | MSE 0.906353 (+0.143023)
#   Top 45 | seg 44 | MSE 0.912973 (+0.136403)
#   Top 46 | seg 23 | MSE 0.916767 (+0.132609)
#   Top 47 | seg 03 | MSE 0.919006 (+0.130370)
#   Top 48 | seg 43 | MSE 0.922328 (+0.127048)
#   Top 49 | seg 35 | MSE 0.942899 (+0.106477)
#   Top 50 | seg 21 | MSE 0.971132 (+0.078245)
#   Top 51 | seg 42 | MSE 0.973545 (+0.075831)
#   Top 52 | seg 09 | MSE 1.017860 (+0.031516)
#   Top 53 | seg 55 | MSE 1.022875 (+0.026501)
#   Top 54 | seg 30 | MSE 1.035420 (+0.013956)
#   Top 55 | seg 20 | MSE 1.105520 (-0.056143)
#   Top 56 | seg 13 | MSE 1.306224 (-0.256848)
#   Top 57 | seg 45 | MSE 1.320602 (-0.271225)
#
# Saved top segment indices per channel:
# Channel 0: [16, 24, 40, 25, 53, 39, 47, 19, 46, 33, 27, 29, 1, 51, 49, 6, 52, 31, 37, 26, 8, 34, 5, 41, 10, 2, 48, 18, 14, 12, 0, 4, 17, 11, 54, 7, 38, 50, 32, 28, 22, 56, 15, 36, 44, 23, 3, 43, 35, 21, 42, 9, 55, 30, 20, 13, 45]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## EPO ES - 1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ER_test['ES']['mse_test_EES']
    v_mae = results1_ER_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ER_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.427584 | MAE : 0.512902
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.307e-02 | |ρ|=0.9563 | S=0.7816 <- pick
#    K=10 | Var=2.616e-02 | |ρ|=0.9582 | S=1.1701
#    K=15 | Var=2.928e-02 | |ρ|=0.9562 | S=1.1161
#    K=20 | Var=3.017e-02 | |ρ|=0.9561 | S=1.1522
#    K=25 | Var=3.066e-02 | |ρ|=0.9537 | S=0.9071
#    K=30 | Var=3.176e-02 | |ρ|=0.9541 | S=1.0179
#    K=35 | Var=3.120e-02 | |ρ|=0.9544 | S=1.0151
#    K=40 | Var=3.216e-02 | |ρ|=0.9533 | S=0.9507
#    K=45 | Var=3.477e-02 | |ρ|=0.9530 | S=1.0608
#    K=50 | Var=3.818e-02 | |ρ|=0.9522 | S=1.1511
#    K=55 | Var=4.126e-02 | |ρ|=0.9493 | S=1.0000
# [Var-Corr]  K=5
#   MSE = 0.309068 | Δ = +0.118516 | Δ% = +27.72%
#   MAE = 0.457067 | Δ = +0.055835 | Δ% = +10.89%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.427584
# Ensemble mean MSE : 0.309068
# Average Δ MSE     : +0.118516
# Average Δ MSE (%) : +27.72%
#
# Vanilla  mean MAE : 0.512902
# Ensemble mean MAE : 0.457067
# Average Δ MAE     : +0.055835
# Average Δ MAE (%) : +10.89%

# %% [markdown]
# ## EPO 1 - 1E

# %%
results1_ER_test['ES']['mae_test_EES']
# Out:
# 0.512901782989502

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ER_test['ES']['mse_test_EES']
    v_mae = results1_ER_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ER_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.35   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.427584 | MAE : 0.512902
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.119e-02 | |ρ|=0.9620 | S=1.3500
#    K=10 | Var=3.324e-02 | |ρ|=0.9554 | S=1.3281
#    K=15 | Var=3.349e-02 | |ρ|=0.9542 | S=1.2094
#    K=20 | Var=3.286e-02 | |ρ|=0.9558 | S=1.3521
#    K=25 | Var=3.243e-02 | |ρ|=0.9540 | S=1.1349
#    K=30 | Var=3.323e-02 | |ρ|=0.9544 | S=1.2243
#    K=35 | Var=3.230e-02 | |ρ|=0.9534 | S=1.0643
#    K=40 | Var=3.147e-02 | |ρ|=0.9547 | S=1.1548
#    K=45 | Var=3.325e-02 | |ρ|=0.9533 | S=1.1046
#    K=50 | Var=3.455e-02 | |ρ|=0.9522 | S=1.0598
#    K=55 | Var=3.894e-02 | |ρ|=0.9493 | S=1.0000 <- pick
# [Var-Corr]  K=55
#    MSE = 0.415818 | Δ = +0.011766 | Δ% = +2.75%
#    MAE = 0.507091 | Δ = +0.005811 | Δ% = +1.13%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.427584
# Ensemble mean MSE  : 0.415818
# Average Δ MSE      : +0.011766
# Average Δ MSE (%)  : +2.75%
#
# Vanilla  mean MAE  : 0.512902
# Ensemble mean MAE  : 0.507091
# Average Δ MAE      : +0.005811
# Average Δ MAE (%)  : +1.13%
