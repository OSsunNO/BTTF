# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(3)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 3
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTh1.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                       HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# date
# 2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (17420, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 01:00:00',
#                '2016-07-01 02:00:00', '2016-07-01 03:00:00',
#                '2016-07-01 04:00:00', '2016-07-01 05:00:00',
#                '2016-07-01 06:00:00', '2016-07-01 07:00:00',
#                '2016-07-01 08:00:00', '2016-07-01 09:00:00',
#                ...
#                '2018-06-26 10:00:00', '2018-06-26 11:00:00',
#                '2018-06-26 12:00:00', '2018-06-26 13:00:00',
#                '2018-06-26 14:00:00', '2018-06-26 15:00:00',
#                '2018-06-26 16:00:00', '2018-06-26 17:00:00',
#                '2018-06-26 18:00:00', '2018-06-26 19:00:00'],
#               dtype='datetime64[ns]', name='date', length=17420, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %%
set_seed(43)

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model(nn.Module):
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.channels = configs.enc_in

        
        self.attach_pv = getattr(configs, "attach_pv", False)

        
        self.extra_len = self.pred_len // 3

        
        self.seq_len_aug = self.seq_len + (self.extra_len if self.attach_pv else 0)

        self.individual = configs.individual

        
        if self.individual:
            self.Linear = nn.ModuleList()
            for i in range(self.channels):
                self.Linear.append(nn.Linear(self.seq_len_aug, self.pred_len))
        else:
            self.Linear = nn.Linear(self.seq_len_aug, self.pred_len)


    def forward(self, x, ground_truth=None):
        B, L, C = x.size()

        
        
        
        if self.attach_pv and (ground_truth is not None):
            
            gt_part = ground_truth[:, :self.extra_len, :]  

            
            x = torch.cat([x, gt_part], dim=1)

        
        
        
        if self.individual:
            out = torch.zeros([B, self.pred_len, C], dtype=x.dtype).to(x.device)
            for i in range(C):
                out[:, :, i] = self.Linear[i](x[:, :, i])
            return out

        else:
            
            out = self.Linear(x.permute(0, 2, 1))
            return out.permute(0, 2, 1)

# %% [markdown]
# # 데이터 분할/스케일링/시퀀스 데이터 구조화

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset

target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 336


border1s = [0, 12 * 30 * 24 - seq_len, 12 * 30 * 24 + 4 * 30 * 24 - seq_len]
border2s = [12 * 30 * 24, 12 * 30 * 24 + 4 * 30 * 24, 12 * 30 * 24 + 8 * 30 * 24]

train = target[border1s[0]:border2s[0]]
val = target[border1s[1]:border2s[1]]
test = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val = scaler.transform(val)
test = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data = create_inout_sequences_univariate(val, seq_len, pred_len)
test_data = create_inout_sequences_univariate(test, seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels = torch.tensor([x[1] for x in test_data]).float().to(device)



print("Train Sequences:", train_sequences.shape)
print("Train Labels:", train_labels.shape)
print("Val Sequences:", val_sequences.shape)
print("Val Labels:", val_labels.shape)
print("Test Sequences:", test_sequences.shape)
print("Test Labels:", test_labels.shape)
# Out:
# Train Sequences: torch.Size([7969, 336, 1])
# Train Labels: torch.Size([7969, 336, 1])
# Val Sequences: torch.Size([2545, 336, 1])
# Val Labels: torch.Size([2545, 336, 1])
# Test Sequences: torch.Size([2545, 336, 1])
# Test Labels: torch.Size([2545, 336, 1])

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 기본 모델 학습 (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_pv=False ) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.01
# Epoch 0 | Train Loss: 0.3256917342543602 | Val Loss: 0.16495719305239617
# Validation loss decreased (inf --> 0.164957).  Saving model ...
# Updating learning rate to 0.005
# Epoch 1 | Train Loss: 0.2065488387644291 | Val Loss: 0.13485039942897856
# Validation loss decreased (0.164957 --> 0.134850).  Saving model ...
# Updating learning rate to 0.0025
# Epoch 2 | Train Loss: 0.1905098653435707 | Val Loss: 0.13227371033281088
# Validation loss decreased (0.134850 --> 0.132274).  Saving model ...
# Updating learning rate to 0.00125
# Epoch 3 | Train Loss: 0.18475932478904725 | Val Loss: 0.1289858073927462
# Validation loss decreased (0.132274 --> 0.128986).  Saving model ...
# Updating learning rate to 0.000625
# Epoch 4 | Train Loss: 0.18051247799396514 | Val Loss: 0.12680491423234344
# Validation loss decreased (0.128986 --> 0.126805).  Saving model ...
# Updating learning rate to 0.0003125
# Epoch 5 | Train Loss: 0.1782925278544426 | Val Loss: 0.12737935641780496
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00015625
# Epoch 6 | Train Loss: 0.17728929828107357 | Val Loss: 0.12656563920900227
# Validation loss decreased (0.126805 --> 0.126566).  Saving model ...
# Updating learning rate to 7.8125e-05
# Epoch 7 | Train Loss: 0.17666759067773818 | Val Loss: 0.12584193581715225
# Validation loss decreased (0.126566 --> 0.125842).  Saving model ...
# Updating learning rate to 3.90625e-05
# Epoch 8 | Train Loss: 0.17615232065320016 | Val Loss: 0.12662967946380377
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.953125e-05
# Epoch 9 | Train Loss: 0.17634858793020247 | Val Loss: 0.12620265767909586
# EarlyStopping counter: 2 out of 3

# %% [markdown]
# # 기본 모델 학습 (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.005, lradj='type1',  patience=3, save_path="./model_ETTh1", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.01
# Epoch 0 | Train Loss: 0.31221688002347947 | Val Loss: 0.13923521642573178
# Model saved at epoch 1

# %% [markdown]
# # Test set 추론 및 예측값 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.09764723479747772 | MAE: 0.24433156847953796
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.25504210591316223 | MAE: 0.3939995765686035

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %% [markdown]
# ## validation 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.12586383521556854 | MAE: 0.2828407287597656
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.13948515057563782 | MAE: 0.2981945276260376

# %% [markdown]
# ## train 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.1764906942844391 | MAE: 0.3237796723842621
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.28346341848373413 | MAE: 0.41277626156806946

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([7969, 336, 1])
# val_sequences shape:  torch.Size([2545, 336, 1])
# test_sequences shape:  torch.Size([2545, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([7969, 336, 1])
# val_pv shape:  torch.Size([2545, 336, 1])
# test_pv shape:  torch.Size([2545, 336, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([7969, 336, 1])
# val_labels shape:  torch.Size([2545, 336, 1])
# test_labels shape:  torch.Size([2545, 336, 1])

# %% [markdown]
# # Segment Generation Function by Sliding Window

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV (Predictied Value)

# %%
configs.pred_len
# Out:
# 336

# %%
segment_len = configs.pred_len // 3
stride = 4

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([7969, 57, 112, 1]), Val: torch.Size([2545, 57, 112, 1]), Test: torch.Size([2545, 57, 112, 1])
# [Epoch 1] Train seg shape: torch.Size([7969, 57, 112, 1]), Val: torch.Size([2545, 57, 112, 1]), Test: torch.Size([2545, 57, 112, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTh1'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # Segment 32 - 2차 증강 모델학습 (1 Epoch)

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo ES

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters()) 
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 0] Training Time = 1.21 sec
# [Segment 0] GPU Memory Start = 3397.43 MB
# [Segment 0] GPU Memory End   = 3051.50 MB
# [Segment 0] GPU Peak Memory  = 3397.43 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 1] Training Time = 0.57 sec
# [Segment 1] GPU Memory Start = 3051.50 MB
# [Segment 1] GPU Memory End   = 3052.07 MB
# [Segment 1] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 2] Training Time = 0.58 sec
# [Segment 2] GPU Memory Start = 3052.07 MB
# [Segment 2] GPU Memory End   = 3052.65 MB
# [Segment 2] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 3] Training Time = 0.61 sec
# [Segment 3] GPU Memory Start = 3052.65 MB
# [Segment 3] GPU Memory End   = 3053.22 MB
# [Segment 3] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 4] Training Time = 0.60 sec
# [Segment 4] GPU Memory Start = 3053.22 MB
# [Segment 4] GPU Memory End   = 3053.80 MB
# [Segment 4] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 5] Training Time = 0.59 sec
# [Segment 5] GPU Memory Start = 3053.80 MB
# [Segment 5] GPU Memory End   = 3054.38 MB
# [Segment 5] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 6] Training Time = 0.58 sec
# [Segment 6] GPU Memory Start = 3054.38 MB
# [Segment 6] GPU Memory End   = 3054.95 MB
# [Segment 6] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 7] Training Time = 0.56 sec
# [Segment 7] GPU Memory Start = 3054.95 MB
# [Segment 7] GPU Memory End   = 3055.53 MB
# [Segment 7] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 8] Training Time = 0.93 sec
# [Segment 8] GPU Memory Start = 3055.53 MB
# [Segment 8] GPU Memory End   = 3056.10 MB
# [Segment 8] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 9] Training Time = 0.82 sec
# [Segment 9] GPU Memory Start = 3056.10 MB
# [Segment 9] GPU Memory End   = 3056.68 MB
# [Segment 9] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 10] Training Time = 0.58 sec
# [Segment 10] GPU Memory Start = 3051.50 MB
# [Segment 10] GPU Memory End   = 3052.07 MB
# [Segment 10] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 11] Training Time = 0.96 sec
# [Segment 11] GPU Memory Start = 3052.07 MB
# [Segment 11] GPU Memory End   = 3052.65 MB
# [Segment 11] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 12] Training Time = 0.60 sec
# [Segment 12] GPU Memory Start = 3052.65 MB
# [Segment 12] GPU Memory End   = 3053.22 MB
# [Segment 12] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 13] Training Time = 1.01 sec
# [Segment 13] GPU Memory Start = 3053.22 MB
# [Segment 13] GPU Memory End   = 3053.80 MB
# [Segment 13] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 14] Training Time = 0.89 sec
# [Segment 14] GPU Memory Start = 3053.80 MB
# [Segment 14] GPU Memory End   = 3054.38 MB
# [Segment 14] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 15] Training Time = 0.59 sec
# [Segment 15] GPU Memory Start = 3054.38 MB
# [Segment 15] GPU Memory End   = 3054.95 MB
# [Segment 15] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 16] Training Time = 1.11 sec
# [Segment 16] GPU Memory Start = 3054.95 MB
# [Segment 16] GPU Memory End   = 3055.53 MB
# [Segment 16] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 17] Training Time = 0.59 sec
# [Segment 17] GPU Memory Start = 3055.53 MB
# [Segment 17] GPU Memory End   = 3056.10 MB
# [Segment 17] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 18] Training Time = 0.60 sec
# [Segment 18] GPU Memory Start = 3056.10 MB
# [Segment 18] GPU Memory End   = 3056.68 MB
# [Segment 18] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 19] Training Time = 0.96 sec
# [Segment 19] GPU Memory Start = 3056.68 MB
# [Segment 19] GPU Memory End   = 3057.25 MB
# [Segment 19] GPU Peak Memory  = 3058.60 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 20] Training Time = 0.97 sec
# [Segment 20] GPU Memory Start = 3051.50 MB
# [Segment 20] GPU Memory End   = 3052.07 MB
# [Segment 20] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 21] Training Time = 0.60 sec
# [Segment 21] GPU Memory Start = 3052.07 MB
# [Segment 21] GPU Memory End   = 3052.65 MB
# [Segment 21] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 22] Training Time = 0.72 sec
# [Segment 22] GPU Memory Start = 3052.65 MB
# [Segment 22] GPU Memory End   = 3053.22 MB
# [Segment 22] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 23] Training Time = 0.58 sec
# [Segment 23] GPU Memory Start = 3053.22 MB
# [Segment 23] GPU Memory End   = 3053.80 MB
# [Segment 23] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 24] Training Time = 0.80 sec
# [Segment 24] GPU Memory Start = 3053.80 MB
# [Segment 24] GPU Memory End   = 3054.38 MB
# [Segment 24] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 25] Training Time = 0.60 sec
# [Segment 25] GPU Memory Start = 3054.38 MB
# [Segment 25] GPU Memory End   = 3054.95 MB
# [Segment 25] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 26] Training Time = 0.69 sec
# [Segment 26] GPU Memory Start = 3054.95 MB
# [Segment 26] GPU Memory End   = 3055.53 MB
# [Segment 26] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 27] Training Time = 0.57 sec
# [Segment 27] GPU Memory Start = 3055.53 MB
# [Segment 27] GPU Memory End   = 3056.10 MB
# [Segment 27] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 28] Training Time = 0.58 sec
# [Segment 28] GPU Memory Start = 3056.10 MB
# [Segment 28] GPU Memory End   = 3056.68 MB
# [Segment 28] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 29] Training Time = 0.60 sec
# [Segment 29] GPU Memory Start = 3056.68 MB
# [Segment 29] GPU Memory End   = 3057.25 MB
# [Segment 29] GPU Peak Memory  = 3058.60 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 30] Training Time = 0.59 sec
# [Segment 30] GPU Memory Start = 3051.50 MB
# [Segment 30] GPU Memory End   = 3052.07 MB
# [Segment 30] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 31] Training Time = 0.60 sec
# [Segment 31] GPU Memory Start = 3052.07 MB
# [Segment 31] GPU Memory End   = 3052.65 MB
# [Segment 31] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 32] Training Time = 1.05 sec
# [Segment 32] GPU Memory Start = 3052.65 MB
# [Segment 32] GPU Memory End   = 3053.22 MB
# [Segment 32] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 33] Training Time = 0.95 sec
# [Segment 33] GPU Memory Start = 3053.22 MB
# [Segment 33] GPU Memory End   = 3053.80 MB
# [Segment 33] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 34] Training Time = 1.15 sec
# [Segment 34] GPU Memory Start = 3053.80 MB
# [Segment 34] GPU Memory End   = 3054.38 MB
# [Segment 34] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 35] Training Time = 0.63 sec
# [Segment 35] GPU Memory Start = 3054.38 MB
# [Segment 35] GPU Memory End   = 3054.95 MB
# [Segment 35] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 36] Training Time = 0.57 sec
# [Segment 36] GPU Memory Start = 3054.95 MB
# [Segment 36] GPU Memory End   = 3055.53 MB
# [Segment 36] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 37] Training Time = 0.57 sec
# [Segment 37] GPU Memory Start = 3055.53 MB
# [Segment 37] GPU Memory End   = 3056.10 MB
# [Segment 37] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 38] Training Time = 0.57 sec
# [Segment 38] GPU Memory Start = 3056.10 MB
# [Segment 38] GPU Memory End   = 3056.68 MB
# [Segment 38] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 39] Training Time = 0.57 sec
# [Segment 39] GPU Memory Start = 3056.68 MB
# [Segment 39] GPU Memory End   = 3051.50 MB
# [Segment 39] GPU Peak Memory  = 3057.25 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 40] Training Time = 1.03 sec
# [Segment 40] GPU Memory Start = 3051.50 MB
# [Segment 40] GPU Memory End   = 3052.07 MB
# [Segment 40] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 41] Training Time = 1.14 sec
# [Segment 41] GPU Memory Start = 3052.07 MB
# [Segment 41] GPU Memory End   = 3052.65 MB
# [Segment 41] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 42] Training Time = 0.59 sec
# [Segment 42] GPU Memory Start = 3052.65 MB
# [Segment 42] GPU Memory End   = 3053.22 MB
# [Segment 42] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 43] Training Time = 1.11 sec
# [Segment 43] GPU Memory Start = 3053.22 MB
# [Segment 43] GPU Memory End   = 3053.80 MB
# [Segment 43] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 44] Training Time = 0.59 sec
# [Segment 44] GPU Memory Start = 3053.80 MB
# [Segment 44] GPU Memory End   = 3054.38 MB
# [Segment 44] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 45] Training Time = 0.58 sec
# [Segment 45] GPU Memory Start = 3054.38 MB
# [Segment 45] GPU Memory End   = 3054.95 MB
# [Segment 45] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 46] Training Time = 0.58 sec
# [Segment 46] GPU Memory Start = 3054.95 MB
# [Segment 46] GPU Memory End   = 3055.53 MB
# [Segment 46] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 47] Training Time = 0.58 sec
# [Segment 47] GPU Memory Start = 3055.53 MB
# [Segment 47] GPU Memory End   = 3056.10 MB
# [Segment 47] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 48] Training Time = 0.62 sec
# [Segment 48] GPU Memory Start = 3056.10 MB
# [Segment 48] GPU Memory End   = 3056.68 MB
# [Segment 48] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 49] Training Time = 0.62 sec
# [Segment 49] GPU Memory Start = 3056.68 MB
# [Segment 49] GPU Memory End   = 3051.50 MB
# [Segment 49] GPU Peak Memory  = 3056.68 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 50] Training Time = 0.91 sec
# [Segment 50] GPU Memory Start = 3051.50 MB
# [Segment 50] GPU Memory End   = 3052.07 MB
# [Segment 50] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 51] Training Time = 0.80 sec
# [Segment 51] GPU Memory Start = 3052.07 MB
# [Segment 51] GPU Memory End   = 3052.65 MB
# [Segment 51] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 52] Training Time = 0.93 sec
# [Segment 52] GPU Memory Start = 3052.65 MB
# [Segment 52] GPU Memory End   = 3053.22 MB
# [Segment 52] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 53] Training Time = 1.07 sec
# [Segment 53] GPU Memory Start = 3053.22 MB
# [Segment 53] GPU Memory End   = 3053.80 MB
# [Segment 53] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 54] Training Time = 0.59 sec
# [Segment 54] GPU Memory Start = 3053.80 MB
# [Segment 54] GPU Memory End   = 3054.38 MB
# [Segment 54] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 55] Training Time = 0.56 sec
# [Segment 55] GPU Memory Start = 3054.38 MB
# [Segment 55] GPU Memory End   = 3054.95 MB
# [Segment 55] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 56] Training Time = 0.56 sec
# [Segment 56] GPU Memory Start = 3054.95 MB
# [Segment 56] GPU Memory End   = 3055.53 MB
# [Segment 56] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo 1

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTh1_E{epo}_1E/",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters()) 
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 0] Training Time = 1.13 sec
# [Segment 0] GPU Memory Start = 3051.50 MB
# [Segment 0] GPU Memory End   = 3051.50 MB
# [Segment 0] GPU Peak Memory  = 3053.30 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 1] Training Time = 0.95 sec
# [Segment 1] GPU Memory Start = 3051.50 MB
# [Segment 1] GPU Memory End   = 3052.07 MB
# [Segment 1] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 2] Training Time = 0.58 sec
# [Segment 2] GPU Memory Start = 3052.07 MB
# [Segment 2] GPU Memory End   = 3052.65 MB
# [Segment 2] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 3] Training Time = 0.67 sec
# [Segment 3] GPU Memory Start = 3052.65 MB
# [Segment 3] GPU Memory End   = 3053.22 MB
# [Segment 3] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 4] Training Time = 0.56 sec
# [Segment 4] GPU Memory Start = 3053.22 MB
# [Segment 4] GPU Memory End   = 3053.80 MB
# [Segment 4] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 5] Training Time = 1.03 sec
# [Segment 5] GPU Memory Start = 3053.80 MB
# [Segment 5] GPU Memory End   = 3054.38 MB
# [Segment 5] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 6] Training Time = 0.58 sec
# [Segment 6] GPU Memory Start = 3051.50 MB
# [Segment 6] GPU Memory End   = 3052.07 MB
# [Segment 6] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 7] Training Time = 0.72 sec
# [Segment 7] GPU Memory Start = 3052.07 MB
# [Segment 7] GPU Memory End   = 3052.65 MB
# [Segment 7] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 8] Training Time = 0.56 sec
# [Segment 8] GPU Memory Start = 3052.65 MB
# [Segment 8] GPU Memory End   = 3053.22 MB
# [Segment 8] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 9] Training Time = 1.02 sec
# [Segment 9] GPU Memory Start = 3053.22 MB
# [Segment 9] GPU Memory End   = 3053.80 MB
# [Segment 9] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 10] Training Time = 0.84 sec
# [Segment 10] GPU Memory Start = 3053.80 MB
# [Segment 10] GPU Memory End   = 3054.38 MB
# [Segment 10] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 11] Training Time = 0.55 sec
# [Segment 11] GPU Memory Start = 3054.38 MB
# [Segment 11] GPU Memory End   = 3054.95 MB
# [Segment 11] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 12] Training Time = 0.56 sec
# [Segment 12] GPU Memory Start = 3054.95 MB
# [Segment 12] GPU Memory End   = 3055.53 MB
# [Segment 12] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 13] Training Time = 0.94 sec
# [Segment 13] GPU Memory Start = 3055.53 MB
# [Segment 13] GPU Memory End   = 3056.10 MB
# [Segment 13] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 14] Training Time = 0.55 sec
# [Segment 14] GPU Memory Start = 3056.10 MB
# [Segment 14] GPU Memory End   = 3056.68 MB
# [Segment 14] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 15] Training Time = 0.56 sec
# [Segment 15] GPU Memory Start = 3056.68 MB
# [Segment 15] GPU Memory End   = 3057.25 MB
# [Segment 15] GPU Peak Memory  = 3058.60 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 16] Training Time = 0.56 sec
# [Segment 16] GPU Memory Start = 3051.50 MB
# [Segment 16] GPU Memory End   = 3052.07 MB
# [Segment 16] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 17] Training Time = 0.56 sec
# [Segment 17] GPU Memory Start = 3052.07 MB
# [Segment 17] GPU Memory End   = 3052.65 MB
# [Segment 17] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 18] Training Time = 0.56 sec
# [Segment 18] GPU Memory Start = 3052.65 MB
# [Segment 18] GPU Memory End   = 3053.22 MB
# [Segment 18] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 19] Training Time = 0.56 sec
# [Segment 19] GPU Memory Start = 3053.22 MB
# [Segment 19] GPU Memory End   = 3053.80 MB
# [Segment 19] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 20] Training Time = 0.56 sec
# [Segment 20] GPU Memory Start = 3053.80 MB
# [Segment 20] GPU Memory End   = 3054.38 MB
# [Segment 20] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 21] Training Time = 0.56 sec
# [Segment 21] GPU Memory Start = 3054.38 MB
# [Segment 21] GPU Memory End   = 3054.95 MB
# [Segment 21] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 22] Training Time = 0.73 sec
# [Segment 22] GPU Memory Start = 3054.95 MB
# [Segment 22] GPU Memory End   = 3055.53 MB
# [Segment 22] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 23] Training Time = 0.56 sec
# [Segment 23] GPU Memory Start = 3055.53 MB
# [Segment 23] GPU Memory End   = 3056.10 MB
# [Segment 23] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 24] Training Time = 0.78 sec
# [Segment 24] GPU Memory Start = 3056.10 MB
# [Segment 24] GPU Memory End   = 3056.68 MB
# [Segment 24] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 25] Training Time = 0.57 sec
# [Segment 25] GPU Memory Start = 3056.68 MB
# [Segment 25] GPU Memory End   = 3057.25 MB
# [Segment 25] GPU Peak Memory  = 3058.60 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 26] Training Time = 1.09 sec
# [Segment 26] GPU Memory Start = 3051.50 MB
# [Segment 26] GPU Memory End   = 3052.07 MB
# [Segment 26] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 27] Training Time = 0.56 sec
# [Segment 27] GPU Memory Start = 3052.07 MB
# [Segment 27] GPU Memory End   = 3052.65 MB
# [Segment 27] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 28] Training Time = 0.56 sec
# [Segment 28] GPU Memory Start = 3052.65 MB
# [Segment 28] GPU Memory End   = 3053.22 MB
# [Segment 28] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 29] Training Time = 0.56 sec
# [Segment 29] GPU Memory Start = 3053.22 MB
# [Segment 29] GPU Memory End   = 3053.80 MB
# [Segment 29] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 30] Training Time = 1.05 sec
# [Segment 30] GPU Memory Start = 3053.80 MB
# [Segment 30] GPU Memory End   = 3054.38 MB
# [Segment 30] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 31] Training Time = 0.59 sec
# [Segment 31] GPU Memory Start = 3054.38 MB
# [Segment 31] GPU Memory End   = 3054.95 MB
# [Segment 31] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 32] Training Time = 0.58 sec
# [Segment 32] GPU Memory Start = 3054.95 MB
# [Segment 32] GPU Memory End   = 3055.53 MB
# [Segment 32] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 33] Training Time = 1.10 sec
# [Segment 33] GPU Memory Start = 3055.53 MB
# [Segment 33] GPU Memory End   = 3056.10 MB
# [Segment 33] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 34] Training Time = 0.57 sec
# [Segment 34] GPU Memory Start = 3056.10 MB
# [Segment 34] GPU Memory End   = 3056.68 MB
# [Segment 34] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 35] Training Time = 1.08 sec
# [Segment 35] GPU Memory Start = 3056.68 MB
# [Segment 35] GPU Memory End   = 3057.25 MB
# [Segment 35] GPU Peak Memory  = 3058.60 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 36] Training Time = 1.10 sec
# [Segment 36] GPU Memory Start = 3051.50 MB
# [Segment 36] GPU Memory End   = 3052.07 MB
# [Segment 36] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 37] Training Time = 0.56 sec
# [Segment 37] GPU Memory Start = 3052.07 MB
# [Segment 37] GPU Memory End   = 3052.65 MB
# [Segment 37] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 38] Training Time = 0.56 sec
# [Segment 38] GPU Memory Start = 3052.65 MB
# [Segment 38] GPU Memory End   = 3053.22 MB
# [Segment 38] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 39] Training Time = 1.16 sec
# [Segment 39] GPU Memory Start = 3053.22 MB
# [Segment 39] GPU Memory End   = 3053.80 MB
# [Segment 39] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 40] Training Time = 0.57 sec
# [Segment 40] GPU Memory Start = 3053.80 MB
# [Segment 40] GPU Memory End   = 3054.38 MB
# [Segment 40] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 41] Training Time = 0.56 sec
# [Segment 41] GPU Memory Start = 3054.38 MB
# [Segment 41] GPU Memory End   = 3054.95 MB
# [Segment 41] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 42] Training Time = 0.57 sec
# [Segment 42] GPU Memory Start = 3054.95 MB
# [Segment 42] GPU Memory End   = 3055.53 MB
# [Segment 42] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 43] Training Time = 0.58 sec
# [Segment 43] GPU Memory Start = 3055.53 MB
# [Segment 43] GPU Memory End   = 3056.10 MB
# [Segment 43] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 44] Training Time = 1.10 sec
# [Segment 44] GPU Memory Start = 3056.10 MB
# [Segment 44] GPU Memory End   = 3056.68 MB
# [Segment 44] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 45] Training Time = 0.70 sec
# [Segment 45] GPU Memory Start = 3056.68 MB
# [Segment 45] GPU Memory End   = 3057.25 MB
# [Segment 45] GPU Peak Memory  = 3058.60 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 46] Training Time = 0.57 sec
# [Segment 46] GPU Memory Start = 3051.50 MB
# [Segment 46] GPU Memory End   = 3052.07 MB
# [Segment 46] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 47] Training Time = 0.57 sec
# [Segment 47] GPU Memory Start = 3052.07 MB
# [Segment 47] GPU Memory End   = 3052.65 MB
# [Segment 47] GPU Peak Memory  = 3054.00 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 48] Training Time = 0.76 sec
# [Segment 48] GPU Memory Start = 3052.65 MB
# [Segment 48] GPU Memory End   = 3053.22 MB
# [Segment 48] GPU Peak Memory  = 3054.57 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 49] Training Time = 0.74 sec
# [Segment 49] GPU Memory Start = 3053.22 MB
# [Segment 49] GPU Memory End   = 3053.80 MB
# [Segment 49] GPU Peak Memory  = 3055.15 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 50] Training Time = 0.56 sec
# [Segment 50] GPU Memory Start = 3053.80 MB
# [Segment 50] GPU Memory End   = 3054.38 MB
# [Segment 50] GPU Peak Memory  = 3055.72 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 51] Training Time = 0.56 sec
# [Segment 51] GPU Memory Start = 3054.38 MB
# [Segment 51] GPU Memory End   = 3054.95 MB
# [Segment 51] GPU Peak Memory  = 3056.30 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 52] Training Time = 0.57 sec
# [Segment 52] GPU Memory Start = 3054.95 MB
# [Segment 52] GPU Memory End   = 3055.53 MB
# [Segment 52] GPU Peak Memory  = 3056.88 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 53] Training Time = 0.90 sec
# [Segment 53] GPU Memory Start = 3055.53 MB
# [Segment 53] GPU Memory End   = 3056.10 MB
# [Segment 53] GPU Peak Memory  = 3057.45 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 54] Training Time = 1.01 sec
# [Segment 54] GPU Memory Start = 3056.10 MB
# [Segment 54] GPU Memory End   = 3056.68 MB
# [Segment 54] GPU Peak Memory  = 3058.03 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 55] Training Time = 0.56 sec
# [Segment 55] GPU Memory Start = 3056.68 MB
# [Segment 55] GPU Memory End   = 3057.25 MB
# [Segment 55] GPU Peak Memory  = 3058.60 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 10.2539 MB
#   yb per batch = 0.0410 MB, total = 10.2539 MB
#   pv per batch = 0.0137 MB, total = 3.4180 MB
# [Segment 56] Training Time = 0.57 sec
# [Segment 56] GPU Memory Start = 3051.50 MB
# [Segment 56] GPU Memory End   = 3052.07 MB
# [Segment 56] GPU Peak Memory  = 3053.42 MB
#
# ============= Done =============

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for validation set 얻은 후 에러율 계산

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTh1/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTh1/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTh1/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ETTh1_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.15643441677093506  MAE:0.31378406286239624
# ▶ seg0  mean  MSE:0.15643441677093506  MAE:0.31378406286239624
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.14862342178821564  MAE:0.30520695447921753
# ▶ seg1  mean  MSE:0.14862342178821564  MAE:0.30520695447921753
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.14237643778324127  MAE:0.30014702677726746
# ▶ seg2  mean  MSE:0.14237643778324127  MAE:0.30014702677726746
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.15044032037258148  MAE:0.3075781464576721
# ▶ seg3  mean  MSE:0.15044032037258148  MAE:0.3075781464576721
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.13871772587299347  MAE:0.297578364610672
# ▶ seg4  mean  MSE:0.13871772587299347  MAE:0.297578364610672
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.14904074370861053  MAE:0.3059958219528198
# ▶ seg5  mean  MSE:0.14904074370861053  MAE:0.3059958219528198
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.15639115869998932  MAE:0.3142489492893219
# ▶ seg6  mean  MSE:0.15639115869998932  MAE:0.3142489492893219
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.13950270414352417  MAE:0.2987215518951416
# ▶ seg7  mean  MSE:0.13950270414352417  MAE:0.2987215518951416
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.17651835083961487  MAE:0.33421504497528076
# ▶ seg8  mean  MSE:0.17651835083961487  MAE:0.33421504497528076
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.14302989840507507  MAE:0.3025362491607666
# ▶ seg9  mean  MSE:0.14302989840507507  MAE:0.3025362491607666
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.14152169227600098  MAE:0.29974454641342163
# ▶ seg10  mean  MSE:0.14152169227600098  MAE:0.29974454641342163
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.1355653703212738  MAE:0.29477792978286743
# ▶ seg11  mean  MSE:0.1355653703212738  MAE:0.29477792978286743
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.15299715101718903  MAE:0.309356689453125
# ▶ seg12  mean  MSE:0.15299715101718903  MAE:0.309356689453125
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.14756867289543152  MAE:0.30699506402015686
# ▶ seg13  mean  MSE:0.14756867289543152  MAE:0.30699506402015686
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.1377178132534027  MAE:0.2953554689884186
# ▶ seg14  mean  MSE:0.1377178132534027  MAE:0.2953554689884186
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.16500191390514374  MAE:0.3204801380634308
# ▶ seg15  mean  MSE:0.16500191390514374  MAE:0.3204801380634308
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.17160412669181824  MAE:0.3281616270542145
# ▶ seg16  mean  MSE:0.17160412669181824  MAE:0.3281616270542145
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.13955210149288177  MAE:0.2979067862033844
# ▶ seg17  mean  MSE:0.13955210149288177  MAE:0.2979067862033844
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.14419656991958618  MAE:0.3025238513946533
# ▶ seg18  mean  MSE:0.14419656991958618  MAE:0.3025238513946533
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.14619097113609314  MAE:0.30484437942504883
# ▶ seg19  mean  MSE:0.14619097113609314  MAE:0.30484437942504883
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.16848284006118774  MAE:0.32704922556877136
# ▶ seg20  mean  MSE:0.16848284006118774  MAE:0.32704922556877136
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.14556655287742615  MAE:0.3046271800994873
# ▶ seg21  mean  MSE:0.14556655287742615  MAE:0.3046271800994873
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.15608510375022888  MAE:0.31470540165901184
# ▶ seg37  mean  MSE:0.15608510375022888  MAE:0.31470540165901184
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.1544768512248993  MAE:0.31315362453460693
# ▶ seg38  mean  MSE:0.1544768512248993  MAE:0.31315362453460693
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.1342298984527588  MAE:0.2909308671951294
# ▶ seg39  mean  MSE:0.1342298984527588  MAE:0.2909308671951294
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.15425214171409607  MAE:0.3124336302280426
# ▶ seg40  mean  MSE:0.15425214171409607  MAE:0.3124336302280426
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.15287122130393982  MAE:0.31178078055381775
# ▶ seg41  mean  MSE:0.15287122130393982  MAE:0.31178078055381775
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.14735643565654755  MAE:0.30372458696365356
# ▶ seg42  mean  MSE:0.14735643565654755  MAE:0.30372458696365356
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.137491837143898  MAE:0.2954082787036896
# ▶ seg43  mean  MSE:0.137491837143898  MAE:0.2954082787036896
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.1469622105360031  MAE:0.30480003356933594
# ▶ seg44  mean  MSE:0.1469622105360031  MAE:0.30480003356933594
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.13295122981071472  MAE:0.2919082045555115
# ▶ seg45  mean  MSE:0.13295122981071472  MAE:0.2919082045555115
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.13518425822257996  MAE:0.2944987714290619
# ▶ seg46  mean  MSE:0.13518425822257996  MAE:0.2944987714290619
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.14082542061805725  MAE:0.2978036105632782
# ▶ seg47  mean  MSE:0.14082542061805725  MAE:0.2978036105632782
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.13509592413902283  MAE:0.2932106554508209
# ▶ seg48  mean  MSE:0.13509592413902283  MAE:0.2932106554508209
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.18904204666614532  MAE:0.34648397564888
# ▶ seg49  mean  MSE:0.18904204666614532  MAE:0.34648397564888
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.1320648193359375  MAE:0.289286732673645
# ▶ seg50  mean  MSE:0.1320648193359375  MAE:0.289286732673645
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.14784106612205505  MAE:0.3052956461906433
# ▶ seg51  mean  MSE:0.14784106612205505  MAE:0.3052956461906433
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.1477643996477127  MAE:0.3057679235935211
# ▶ seg52  mean  MSE:0.1477643996477127  MAE:0.3057679235935211
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.1358575075864792  MAE:0.2948895990848541
# ▶ seg53  mean  MSE:0.1358575075864792  MAE:0.2948895990848541
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.15303264558315277  MAE:0.30999961495399475
# ▶ seg54  mean  MSE:0.15303264558315277  MAE:0.30999961495399475
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.2695901095867157  MAE:0.41620054841041565
# ▶ seg55  mean  MSE:0.2695901095867157  MAE:0.41620054841041565
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.17391647398471832  MAE:0.33052635192871094
# ▶ seg56  mean  MSE:0.17391647398471832  MAE:0.33052635192871094
#
# seg10 ch0 MSE : 0.14134406

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for test set 얻은 후 에러율 계산

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 336
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ETTh1_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.45406368374824524  MAE:0.5256308913230896
# ▶ seg0  mean  MSE:0.45406368374824524  MAE:0.5256308913230896
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.3565090298652649  MAE:0.4800020158290863
# ▶ seg1  mean  MSE:0.3565090298652649  MAE:0.4800020158290863
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.15546615421772003  MAE:0.31384530663490295
# ▶ seg52  mean  MSE:0.15546615421772003  MAE:0.31384530663490295
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.45277905464172363  MAE:0.5302703976631165
# ▶ seg53  mean  MSE:0.45277905464172363  MAE:0.5302703976631165
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.23218479752540588  MAE:0.37742218375205994
# ▶ seg54  mean  MSE:0.23218479752540588  MAE:0.37742218375205994
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.24203285574913025  MAE:0.37846142053604126
# ▶ seg55  mean  MSE:0.24203285574913025  MAE:0.37846142053604126
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.2317131906747818  MAE:0.3754126727581024
# ▶ seg56  mean  MSE:0.2317131906747818  MAE:0.3754126727581024
#
# seg10 ch0 MSE : 0.27147496

# %% [markdown]
# ## EPO 1 - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 336
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTh1_E1_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ETTh1_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTh1_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTh1_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.36447593569755554  MAE:0.4821341335773468
# ▶ seg0  mean  MSE:0.36447593569755554  MAE:0.4821341335773468
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.33786433935165405  MAE:0.46373850107192993
# ▶ seg1  mean  MSE:0.33786433935165405  MAE:0.46373850107192993
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.20143267512321472  MAE:0.3486133813858032
# ▶ seg2  mean  MSE:0.20143267512321472  MAE:0.3486133813858032
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.2715578079223633  MAE:0.41618040204048157
# ▶ seg3  mean  MSE:0.2715578079223633  MAE:0.41618040204048157
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:1.6346062421798706  MAE:1.1180757284164429
# ▶ seg4  mean  MSE:1.6346062421798706  MAE:1.1180757284164429
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.24103373289108276  MAE:0.3938291668891907
# ▶ seg5  mean  MSE:0.24103373289108276  MAE:0.3938291668891907
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.1835269033908844  MAE:0.33824241161346436
# ▶ seg6  mean  MSE:0.1835269033908844  MAE:0.33824241161346436
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.24445700645446777  MAE:0.38509872555732727
# ▶ seg7  mean  MSE:0.24445700645446777  MAE:0.38509872555732727
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.17936928570270538  MAE:0.3335774540901184
# ▶ seg8  mean  MSE:0.17936928570270538  MAE:0.3335774540901184
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.24505528807640076  MAE:0.39175283908843994
# ▶ seg9  mean  MSE:0.24505528807640076  MAE:0.39175283908843994
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.24182340502738953  MAE:0.3843238651752472
# ▶ seg10  mean  MSE:0.24182340502738953  MAE:0.3843238651752472
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.17091621458530426  MAE:0.32592546939849854
# ▶ seg11  mean  MSE:0.17091621458530426  MAE:0.32592546939849854
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:1.4322261810302734  MAE:0.9980748891830444
# ▶ seg12  mean  MSE:1.4322261810302734  MAE:0.9980748891830444
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.1638830602169037  MAE:0.32064464688301086
# ▶ seg13  mean  MSE:0.1638830602169037  MAE:0.32064464688301086
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.3802073895931244  MAE:0.5030210614204407
# ▶ seg14  mean  MSE:0.3802073895931244  MAE:0.5030210614204407
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.4819703996181488  MAE:0.5622740983963013
# ▶ seg15  mean  MSE:0.4819703996181488  MAE:0.5622740983963013
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.21389470994472504  MAE:0.3715316951274872
# ▶ seg16  mean  MSE:0.21389470994472504  MAE:0.3715316951274872
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.21521291136741638  MAE:0.3662818968296051
# ▶ seg43  mean  MSE:0.21521291136741638  MAE:0.3662818968296051
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.2856253683567047  MAE:0.43490836024284363
# ▶ seg44  mean  MSE:0.2856253683567047  MAE:0.43490836024284363
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.1544933021068573  MAE:0.31203702092170715
# ▶ seg45  mean  MSE:0.1544933021068573  MAE:0.31203702092170715
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.20013515651226044  MAE:0.35226985812187195
# ▶ seg46  mean  MSE:0.20013515651226044  MAE:0.35226985812187195
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.22403764724731445  MAE:0.37428998947143555
# ▶ seg47  mean  MSE:0.22403764724731445  MAE:0.37428998947143555
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.19699932634830475  MAE:0.3538071811199188
# ▶ seg48  mean  MSE:0.19699932634830475  MAE:0.3538071811199188
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.8858287930488586  MAE:0.7812467217445374
# ▶ seg49  mean  MSE:0.8858287930488586  MAE:0.7812467217445374
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.1476316899061203  MAE:0.29980161786079407
# ▶ seg50  mean  MSE:0.1476316899061203  MAE:0.29980161786079407
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.3123474717140198  MAE:0.43771958351135254
# ▶ seg51  mean  MSE:0.3123474717140198  MAE:0.43771958351135254
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.3138905167579651  MAE:0.44166579842567444
# ▶ seg52  mean  MSE:0.3138905167579651  MAE:0.44166579842567444
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.23141628503799438  MAE:0.3774234652519226
# ▶ seg53  mean  MSE:0.23141628503799438  MAE:0.3774234652519226
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.3704703748226166  MAE:0.48256710171699524
# ▶ seg54  mean  MSE:0.3704703748226166  MAE:0.48256710171699524
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:1.8640261888504028  MAE:1.1639230251312256
# ▶ seg55  mean  MSE:1.8640261888504028  MAE:1.1639230251312256
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.6687500476837158  MAE:0.6656271815299988
# ▶ seg56  mean  MSE:0.6687500476837158  MAE:0.6656271815299988
#
# seg10 ch0 MSE : 0.2418234

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTh1_train = torch.load("./1st_results_ETTh1/train_1st_results.pt")
results1_ETTh1_val = torch.load("./1st_results_ETTh1/val_1st_results.pt")
results1_ETTh1_test = torch.load("./1st_results_ETTh1/test_1st_results.pt")

# %% [markdown]
# ### EPO ES - 1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 57
SEG_CNT     = 57
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.139485
#
#   Top  1 | seg 49 | MSE 0.130660 (+0.008825)
#   Top  2 | seg 52 | MSE 0.133210 (+0.006275)
#   Top  3 | seg 37 | MSE 0.135098 (+0.004387)
#   Top  4 | seg 30 | MSE 0.135289 (+0.004196)
#   Top  5 | seg 36 | MSE 0.135541 (+0.003944)
#   Top  6 | seg 11 | MSE 0.135565 (+0.003920)
#   Top  7 | seg 34 | MSE 0.135996 (+0.003489)
#   Top  8 | seg 43 | MSE 0.136545 (+0.002940)
#   Top  9 | seg 54 | MSE 0.136753 (+0.002732)
#   Top 10 | seg 51 | MSE 0.137481 (+0.002004)
#   Top 11 | seg 29 | MSE 0.137573 (+0.001912)
#   Top 12 | seg 14 | MSE 0.137718 (+0.001767)
#   Top 13 | seg 24 | MSE 0.138036 (+0.001449)
#   Top 14 | seg 56 | MSE 0.138524 (+0.000961)
#   Top 15 | seg 04 | MSE 0.138718 (+0.000767)
#   Top 16 | seg 55 | MSE 0.138719 (+0.000766)
#   Top 17 | seg 45 | MSE 0.138964 (+0.000521)
#   Top 18 | seg 46 | MSE 0.139010 (+0.000475)
#   Top 19 | seg 07 | MSE 0.139503 (-0.000018)
#   Top 20 | seg 33 | MSE 0.139545 (-0.000059)
#   Top 21 | seg 17 | MSE 0.139552 (-0.000067)
#   Top 22 | seg 22 | MSE 0.139576 (-0.000091)
#   Top 23 | seg 50 | MSE 0.139729 (-0.000244)
#   Top 24 | seg 35 | MSE 0.140205 (-0.000720)
#   Top 25 | seg 28 | MSE 0.140441 (-0.000956)
#   Top 26 | seg 10 | MSE 0.141522 (-0.002037)
#   Top 27 | seg 48 | MSE 0.141706 (-0.002220)
#   Top 28 | seg 02 | MSE 0.142376 (-0.002891)
#   Top 29 | seg 09 | MSE 0.143030 (-0.003545)
#   Top 30 | seg 31 | MSE 0.143928 (-0.004443)
#   Top 31 | seg 18 | MSE 0.144197 (-0.004711)
#   Top 32 | seg 21 | MSE 0.145567 (-0.006081)
#   Top 33 | seg 19 | MSE 0.146191 (-0.006706)
#   Top 34 | seg 27 | MSE 0.146597 (-0.007111)
#   Top 35 | seg 23 | MSE 0.146862 (-0.007376)
#   Top 36 | seg 13 | MSE 0.147569 (-0.008084)
#   Top 37 | seg 01 | MSE 0.148623 (-0.009138)
#   Top 38 | seg 05 | MSE 0.149041 (-0.009556)
#   Top 39 | seg 03 | MSE 0.150440 (-0.010955)
#   Top 40 | seg 38 | MSE 0.151519 (-0.012034)
#   Top 41 | seg 12 | MSE 0.152997 (-0.013512)
#   Top 42 | seg 06 | MSE 0.156391 (-0.016906)
#   Top 43 | seg 00 | MSE 0.156434 (-0.016949)
#   Top 44 | seg 44 | MSE 0.158768 (-0.019283)
#   Top 45 | seg 26 | MSE 0.159743 (-0.020258)
#   Top 46 | seg 53 | MSE 0.161007 (-0.021522)
#   Top 47 | seg 25 | MSE 0.164438 (-0.024953)
#   Top 48 | seg 15 | MSE 0.165002 (-0.025517)
#   Top 49 | seg 41 | MSE 0.166953 (-0.027468)
#   Top 50 | seg 20 | MSE 0.168483 (-0.028998)
#   Top 51 | seg 40 | MSE 0.169520 (-0.030035)
#   Top 52 | seg 32 | MSE 0.170141 (-0.030656)
#   Top 53 | seg 16 | MSE 0.171604 (-0.032119)
#   Top 54 | seg 08 | MSE 0.176518 (-0.037033)
#   Top 55 | seg 39 | MSE 0.199826 (-0.060341)
#   Top 56 | seg 47 | MSE 0.253142 (-0.113657)
#   Top 57 | seg 42 | MSE 0.315674 (-0.176188)
#
# Saved top segment indices per channel:
# Channel 0: [49, 52, 37, 30, 36, 11, 34, 43, 54, 51, 29, 14, 24, 56, 4, 55, 45, 46, 7, 33, 17, 22, 50, 35, 28, 10, 48, 2, 9, 31, 18, 21, 19, 27, 23, 13, 1, 5, 3, 38, 12, 6, 0, 44, 26, 53, 25, 15, 41, 20, 40, 32, 16, 8, 39, 47, 42]

# %% [markdown]
# ### EPO 1 - 1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 57
SEG_CNT     = 57
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTh1_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTh1_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTh1_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.139485
#
#   Top  1 | seg 50 | MSE 0.132065 (+0.007420)
#   Top  2 | seg 31 | MSE 0.132613 (+0.006872)
#   Top  3 | seg 45 | MSE 0.132951 (+0.006534)
#   Top  4 | seg 11 | MSE 0.133254 (+0.006231)
#   Top  5 | seg 08 | MSE 0.133644 (+0.005842)
#   Top  6 | seg 13 | MSE 0.133907 (+0.005578)
#   Top  7 | seg 39 | MSE 0.134230 (+0.005255)
#   Top  8 | seg 22 | MSE 0.134746 (+0.004739)
#   Top  9 | seg 48 | MSE 0.135096 (+0.004389)
#   Top 10 | seg 46 | MSE 0.135184 (+0.004301)
#   Top 11 | seg 35 | MSE 0.135631 (+0.003855)
#   Top 12 | seg 53 | MSE 0.135858 (+0.003628)
#   Top 13 | seg 06 | MSE 0.136250 (+0.003235)
#   Top 14 | seg 33 | MSE 0.136895 (+0.002590)
#   Top 15 | seg 43 | MSE 0.137492 (+0.001993)
#   Top 16 | seg 02 | MSE 0.137572 (+0.001913)
#   Top 17 | seg 17 | MSE 0.138689 (+0.000796)
#   Top 18 | seg 24 | MSE 0.139039 (+0.000446)
#   Top 19 | seg 09 | MSE 0.139364 (+0.000121)
#   Top 20 | seg 07 | MSE 0.139402 (+0.000083)
#   Top 21 | seg 05 | MSE 0.139670 (-0.000184)
#   Top 22 | seg 30 | MSE 0.140094 (-0.000609)
#   Top 23 | seg 27 | MSE 0.140282 (-0.000797)
#   Top 24 | seg 16 | MSE 0.140493 (-0.001008)
#   Top 25 | seg 19 | MSE 0.140502 (-0.001017)
#   Top 26 | seg 03 | MSE 0.140757 (-0.001272)
#   Top 27 | seg 47 | MSE 0.140825 (-0.001340)
#   Top 28 | seg 36 | MSE 0.140861 (-0.001375)
#   Top 29 | seg 28 | MSE 0.140897 (-0.001412)
#   Top 30 | seg 10 | MSE 0.141344 (-0.001859)
#   Top 31 | seg 29 | MSE 0.143927 (-0.004442)
#   Top 32 | seg 32 | MSE 0.144817 (-0.005332)
#   Top 33 | seg 18 | MSE 0.145930 (-0.006444)
#   Top 34 | seg 34 | MSE 0.146872 (-0.007387)
#   Top 35 | seg 01 | MSE 0.146881 (-0.007395)
#   Top 36 | seg 44 | MSE 0.146962 (-0.007477)
#   Top 37 | seg 42 | MSE 0.147356 (-0.007871)
#   Top 38 | seg 52 | MSE 0.147764 (-0.008279)
#   Top 39 | seg 51 | MSE 0.147841 (-0.008356)
#   Top 40 | seg 25 | MSE 0.149132 (-0.009646)
#   Top 41 | seg 00 | MSE 0.149270 (-0.009785)
#   Top 42 | seg 14 | MSE 0.150598 (-0.011113)
#   Top 43 | seg 41 | MSE 0.152871 (-0.013386)
#   Top 44 | seg 54 | MSE 0.153033 (-0.013547)
#   Top 45 | seg 40 | MSE 0.154252 (-0.014767)
#   Top 46 | seg 38 | MSE 0.154477 (-0.014992)
#   Top 47 | seg 37 | MSE 0.156085 (-0.016600)
#   Top 48 | seg 21 | MSE 0.156227 (-0.016742)
#   Top 49 | seg 15 | MSE 0.157195 (-0.017710)
#   Top 50 | seg 20 | MSE 0.161427 (-0.021942)
#   Top 51 | seg 26 | MSE 0.163989 (-0.024504)
#   Top 52 | seg 56 | MSE 0.173916 (-0.034431)
#   Top 53 | seg 49 | MSE 0.189042 (-0.049557)
#   Top 54 | seg 12 | MSE 0.231147 (-0.091662)
#   Top 55 | seg 04 | MSE 0.250611 (-0.111126)
#   Top 56 | seg 23 | MSE 0.260767 (-0.121281)
#   Top 57 | seg 55 | MSE 0.269590 (-0.130105)
#
# Saved top segment indices per channel:
# Channel 0: [50, 31, 45, 11, 8, 13, 39, 22, 48, 46, 35, 53, 6, 33, 43, 2, 17, 24, 9, 7, 5, 30, 27, 16, 19, 3, 47, 36, 28, 10, 29, 32, 18, 34, 1, 44, 42, 52, 51, 25, 0, 14, 41, 54, 40, 38, 37, 21, 15, 20, 26, 56, 49, 12, 4, 23, 55]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## EPO ES - 1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTh1_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.097647 | MAE : 0.244332
#   — Var / |Corr| / Score —
#    K= 5 | Var=1.058e-01 | |ρ|=0.5533 | S=1.0000
#    K=10 | Var=1.178e-01 | |ρ|=0.5131 | S=0.9070
#    K=15 | Var=1.249e-01 | |ρ|=0.4723 | S=0.7719
#    K=20 | Var=1.325e-01 | |ρ|=0.4529 | S=0.7416
#    K=25 | Var=1.347e-01 | |ρ|=0.4475 | S=0.7336
#    K=30 | Var=1.440e-01 | |ρ|=0.4241 | S=0.6980 <- pick
#    K=35 | Var=1.547e-01 | |ρ|=0.4073 | S=0.7037
#    K=40 | Var=1.706e-01 | |ρ|=0.3928 | S=0.7620
#    K=45 | Var=1.901e-01 | |ρ|=0.3755 | S=0.8351
#    K=50 | Var=2.083e-01 | |ρ|=0.3557 | S=0.8865
#    K=55 | Var=2.323e-01 | |ρ|=0.3394 | S=1.0000
# [Var-Corr]  K=30
#   MSE = 0.086665 | Δ = +0.010982 | Δ% = +11.25%
#   MAE = 0.233699 | Δ = +0.010633 | Δ% = +4.35%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.097647
# Ensemble mean MSE : 0.086665
# Average Δ MSE     : +0.010982
# Average Δ MSE (%) : +11.25%
#
# Vanilla  mean MAE : 0.244332
# Ensemble mean MAE : 0.233699
# Average Δ MAE     : +0.010633
# Average Δ MAE (%) : +4.35%

# %% [markdown]
# ## EPO 1 - 1E

# %%
results1_ETTh1_test['ES']['mae_test_EES']
# Out:
# 0.24433156847953796

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTh1_test['ES']['mse_test_EES']
    v_mae = results1_ETTh1_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTh1_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.35   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.097647 | MAE : 0.244332
#   — Var / |Corr| / Score —
#    K= 5 | Var=7.990e-02 | |ρ|=0.5915 | S=1.3500
#    K=10 | Var=9.231e-02 | |ρ|=0.5474 | S=1.1754
#    K=15 | Var=1.018e-01 | |ρ|=0.5312 | S=1.1414
#    K=20 | Var=1.149e-01 | |ρ|=0.5055 | S=1.0763
#    K=25 | Var=1.258e-01 | |ρ|=0.4900 | S=1.0545
#    K=30 | Var=1.329e-01 | |ρ|=0.4645 | S=0.9532
#    K=35 | Var=1.452e-01 | |ρ|=0.4415 | S=0.8978
#    K=40 | Var=1.575e-01 | |ρ|=0.4269 | S=0.8903
#    K=45 | Var=1.696e-01 | |ρ|=0.4079 | S=0.8573
#    K=50 | Var=1.867e-01 | |ρ|=0.3849 | S=0.8311 <- pick
#    K=55 | Var=2.425e-01 | |ρ|=0.3543 | S=1.0000
# [Var-Corr]  K=50
#    MSE = 0.092087 | Δ = +0.005561 | Δ% = +5.69%
#    MAE = 0.238316 | Δ = +0.006015 | Δ% = +2.46%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.097647
# Ensemble mean MSE  : 0.092087
# Average Δ MSE      : +0.005561
# Average Δ MSE (%)  : +5.69%
#
# Vanilla  mean MAE  : 0.244332
# Ensemble mean MAE  : 0.238316
# Average Δ MAE      : +0.006015
# Average Δ MAE (%)  : +2.46%
