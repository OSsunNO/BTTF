# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(3)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 3
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTm2.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                           HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# date
# 2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 2016-07-01 00:15:00  39.622002  11.309  35.543999  8.551  3.209  1.258
# 2016-07-01 00:30:00  38.868000  10.555  34.365002  7.586  4.435  1.258
# 2016-07-01 00:45:00  35.518002   9.214  32.569000  8.712  4.435  1.215
# 2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
#
#                             OT
# date
# 2016-07-01 00:00:00  38.661999
# 2016-07-01 00:15:00  38.223000
# 2016-07-01 00:30:00  37.344002
# 2016-07-01 00:45:00  37.124001
# 2016-07-01 01:00:00  37.124001

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (69680, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 00:15:00',
#                '2016-07-01 00:30:00', '2016-07-01 00:45:00',
#                '2016-07-01 01:00:00', '2016-07-01 01:15:00',
#                '2016-07-01 01:30:00', '2016-07-01 01:45:00',
#                '2016-07-01 02:00:00', '2016-07-01 02:15:00',
#                ...
#                '2018-06-26 17:30:00', '2018-06-26 17:45:00',
#                '2018-06-26 18:00:00', '2018-06-26 18:15:00',
#                '2018-06-26 18:30:00', '2018-06-26 18:45:00',
#                '2018-06-26 19:00:00', '2018-06-26 19:15:00',
#                '2018-06-26 19:30:00', '2018-06-26 19:45:00'],
#               dtype='datetime64[ns]', name='date', length=69680, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model(nn.Module):
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.channels = configs.enc_in

        
        self.attach_pv = getattr(configs, "attach_pv", False)

        
        self.extra_len = self.pred_len // 3

        
        self.seq_len_aug = self.seq_len + (self.extra_len if self.attach_pv else 0)

        self.individual = configs.individual

        
        if self.individual:
            self.Linear = nn.ModuleList()
            for i in range(self.channels):
                self.Linear.append(nn.Linear(self.seq_len_aug, self.pred_len))
        else:
            self.Linear = nn.Linear(self.seq_len_aug, self.pred_len)


    def forward(self, x, ground_truth=None):
        B, L, C = x.size()

        
        
        
        if self.attach_pv and (ground_truth is not None):
            
            gt_part = ground_truth[:, :self.extra_len, :]  

            
            x = torch.cat([x, gt_part], dim=1)

        
        
        
        if self.individual:
            out = torch.zeros([B, self.pred_len, C], dtype=x.dtype).to(x.device)
            for i in range(C):
                out[:, :, i] = self.Linear[i](x[:, :, i])
            return out

        else:
            
            out = self.Linear(x.permute(0, 2, 1))
            return out.permute(0, 2, 1)

# %% [markdown]
# # 데이터 분할/스케일링/시퀀스 데이터 구조화

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 336




train_points = 12 * 30 * 24 * 4
val_points   = 4  * 30 * 24 * 4
test_points  = 4  * 30 * 24 * 4

border1s = [
    0,
    train_points - seq_len,
    train_points + val_points - seq_len
]
border2s = [
    train_points,
    train_points + val_points,
    train_points + val_points + test_points
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([33889, 336, 1])
# Train Labels:    torch.Size([33889, 336, 1])
# Val Sequences:   torch.Size([11185, 336, 1])
# Val Labels:      torch.Size([11185, 336, 1])
# Test Sequences:  torch.Size([11185, 336, 1])
# Test Labels:     torch.Size([11185, 336, 1])

# %%
set_seed(51)

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 기본 모델 학습 (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.3495680556333852 | Val Loss: 1.1362635461028132
# Validation loss decreased (inf --> 1.136264).  Saving model ...
# Updating learning rate to 0.01
# Epoch 1 | Train Loss: 0.22795245783087217 | Val Loss: 0.6295731546570148
# Validation loss decreased (1.136264 --> 0.629573).  Saving model ...
# Updating learning rate to 0.005
# Epoch 2 | Train Loss: 0.20097167388588752 | Val Loss: 0.20278818270989826
# Validation loss decreased (0.629573 --> 0.202788).  Saving model ...
# Updating learning rate to 0.0025
# Epoch 3 | Train Loss: 0.1886901004556215 | Val Loss: 0.19714851565659047
# Validation loss decreased (0.202788 --> 0.197149).  Saving model ...
# Updating learning rate to 0.00125
# Epoch 4 | Train Loss: 0.18212078947503613 | Val Loss: 0.24450075997305767
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000625
# Epoch 5 | Train Loss: 0.17971112446964913 | Val Loss: 0.17142750462783235
# Validation loss decreased (0.197149 --> 0.171428).  Saving model ...
# Updating learning rate to 0.0003125
# Epoch 6 | Train Loss: 0.1762843354833576 | Val Loss: 0.17296029384647096
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00015625
# Epoch 7 | Train Loss: 0.17512861428395757 | Val Loss: 0.17283636406064035
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.8125e-05
# Epoch 8 | Train Loss: 0.1750269763031096 | Val Loss: 0.17055274483614735
# Validation loss decreased (0.171428 --> 0.170553).  Saving model ...
# Updating learning rate to 3.90625e-05
# Epoch 9 | Train Loss: 0.17406097829060735 | Val Loss: 0.1715733028163335
# EarlyStopping counter: 1 out of 3

# %% [markdown]
# # 기본 모델 학습 (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 336  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv
   

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.01, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.02
# Epoch 0 | Train Loss: 0.3737598374415681 | Val Loss: 0.8536631271722062
# Model saved at epoch 1

# %% [markdown]
# # Test set 추론 및 예측값 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.12325192987918854 | MAE: 0.26583945751190186
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.9312962889671326 | MAE: 0.701378583908081

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %% [markdown]
# ## validation 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.17066240310668945 | MAE: 0.31655868887901306
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.8545898199081421 | MAE: 0.6798710823059082

# %% [markdown]
# ## train 셋 예측값 획득 및 구조화

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.174107164144516 | MAE: 0.30735868215560913
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.7409433722496033 | MAE: 0.6294335722923279

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([33889, 336, 1])
# val_sequences shape:  torch.Size([11185, 336, 1])
# test_sequences shape:  torch.Size([11185, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([33889, 336, 1])
# val_pv shape:  torch.Size([11185, 336, 1])
# test_pv shape:  torch.Size([11185, 336, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([33889, 336, 1])
# val_labels shape:  torch.Size([11185, 336, 1])
# test_labels shape:  torch.Size([11185, 336, 1])

# %% [markdown]
# # Segment Generation Function by Sliding Window

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV (Predictied Value)

# %%
configs.pred_len
# Out:
# 336

# %%
segment_len = configs.pred_len // 3
stride = 4

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([33889, 57, 112, 1]), Val: torch.Size([11185, 57, 112, 1]), Test: torch.Size([11185, 57, 112, 1])
# [Epoch 1] Train seg shape: torch.Size([33889, 57, 112, 1]), Val: torch.Size([11185, 57, 112, 1]), Test: torch.Size([11185, 57, 112, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTm2'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # Segment 32 - 2차 증강 모델학습 (1 Epoch)

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo ES

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 0] Training Time = 4.87 sec
# [Segment 0] GPU Memory Start = 19901.39 MB
# [Segment 0] GPU Memory End   = 18530.12 MB
# [Segment 0] GPU Peak Memory  = 19902.72 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 1] Training Time = 4.69 sec
# [Segment 1] GPU Memory Start = 18530.12 MB
# [Segment 1] GPU Memory End   = 18530.69 MB
# [Segment 1] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 2] Training Time = 4.98 sec
# [Segment 2] GPU Memory Start = 18530.69 MB
# [Segment 2] GPU Memory End   = 18531.27 MB
# [Segment 2] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 3] Training Time = 4.89 sec
# [Segment 3] GPU Memory Start = 18531.27 MB
# [Segment 3] GPU Memory End   = 18531.84 MB
# [Segment 3] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 4] Training Time = 4.60 sec
# [Segment 4] GPU Memory Start = 18531.84 MB
# [Segment 4] GPU Memory End   = 18532.42 MB
# [Segment 4] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 5] Training Time = 2.39 sec
# [Segment 5] GPU Memory Start = 18532.42 MB
# [Segment 5] GPU Memory End   = 18532.99 MB
# [Segment 5] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 6] Training Time = 4.33 sec
# [Segment 6] GPU Memory Start = 18532.99 MB
# [Segment 6] GPU Memory End   = 18533.57 MB
# [Segment 6] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 7] Training Time = 4.59 sec
# [Segment 7] GPU Memory Start = 18533.57 MB
# [Segment 7] GPU Memory End   = 18534.15 MB
# [Segment 7] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 8] Training Time = 4.84 sec
# [Segment 8] GPU Memory Start = 18534.15 MB
# [Segment 8] GPU Memory End   = 18534.72 MB
# [Segment 8] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 9] Training Time = 5.02 sec
# [Segment 9] GPU Memory Start = 18534.72 MB
# [Segment 9] GPU Memory End   = 18535.30 MB
# [Segment 9] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 10] Training Time = 3.82 sec
# [Segment 10] GPU Memory Start = 18535.30 MB
# [Segment 10] GPU Memory End   = 18530.12 MB
# [Segment 10] GPU Peak Memory  = 18535.30 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 11] Training Time = 4.54 sec
# [Segment 11] GPU Memory Start = 18530.12 MB
# [Segment 11] GPU Memory End   = 18530.69 MB
# [Segment 11] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 12] Training Time = 4.77 sec
# [Segment 12] GPU Memory Start = 18530.69 MB
# [Segment 12] GPU Memory End   = 18531.27 MB
# [Segment 12] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 13] Training Time = 4.77 sec
# [Segment 13] GPU Memory Start = 18531.27 MB
# [Segment 13] GPU Memory End   = 18531.84 MB
# [Segment 13] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 14] Training Time = 4.81 sec
# [Segment 14] GPU Memory Start = 18531.84 MB
# [Segment 14] GPU Memory End   = 18532.42 MB
# [Segment 14] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 15] Training Time = 4.31 sec
# [Segment 15] GPU Memory Start = 18532.42 MB
# [Segment 15] GPU Memory End   = 18532.99 MB
# [Segment 15] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 16] Training Time = 3.76 sec
# [Segment 16] GPU Memory Start = 18532.99 MB
# [Segment 16] GPU Memory End   = 18533.57 MB
# [Segment 16] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 17] Training Time = 4.27 sec
# [Segment 17] GPU Memory Start = 18533.57 MB
# [Segment 17] GPU Memory End   = 18534.15 MB
# [Segment 17] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 18] Training Time = 4.42 sec
# [Segment 18] GPU Memory Start = 18534.15 MB
# [Segment 18] GPU Memory End   = 18534.72 MB
# [Segment 18] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 19] Training Time = 4.78 sec
# [Segment 19] GPU Memory Start = 18534.72 MB
# [Segment 19] GPU Memory End   = 18535.30 MB
# [Segment 19] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 20] Training Time = 3.80 sec
# [Segment 20] GPU Memory Start = 18535.30 MB
# [Segment 20] GPU Memory End   = 18530.12 MB
# [Segment 20] GPU Peak Memory  = 18535.30 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 21] Training Time = 2.43 sec
# [Segment 21] GPU Memory Start = 18530.12 MB
# [Segment 21] GPU Memory End   = 18530.69 MB
# [Segment 21] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 22] Training Time = 2.80 sec
# [Segment 22] GPU Memory Start = 18530.69 MB
# [Segment 22] GPU Memory End   = 18531.27 MB
# [Segment 22] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 23] Training Time = 2.91 sec
# [Segment 23] GPU Memory Start = 18531.27 MB
# [Segment 23] GPU Memory End   = 18531.84 MB
# [Segment 23] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 24] Training Time = 2.79 sec
# [Segment 24] GPU Memory Start = 18531.84 MB
# [Segment 24] GPU Memory End   = 18532.42 MB
# [Segment 24] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 25] Training Time = 2.84 sec
# [Segment 25] GPU Memory Start = 18532.42 MB
# [Segment 25] GPU Memory End   = 18532.99 MB
# [Segment 25] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 26] Training Time = 3.58 sec
# [Segment 26] GPU Memory Start = 18532.99 MB
# [Segment 26] GPU Memory End   = 18533.57 MB
# [Segment 26] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 27] Training Time = 3.31 sec
# [Segment 27] GPU Memory Start = 18533.57 MB
# [Segment 27] GPU Memory End   = 18534.15 MB
# [Segment 27] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 28] Training Time = 3.43 sec
# [Segment 28] GPU Memory Start = 18534.15 MB
# [Segment 28] GPU Memory End   = 18534.72 MB
# [Segment 28] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 29] Training Time = 3.39 sec
# [Segment 29] GPU Memory Start = 18534.72 MB
# [Segment 29] GPU Memory End   = 18535.30 MB
# [Segment 29] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 30] Training Time = 3.05 sec
# [Segment 30] GPU Memory Start = 18535.30 MB
# [Segment 30] GPU Memory End   = 18530.12 MB
# [Segment 30] GPU Peak Memory  = 18535.30 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 31] Training Time = 2.64 sec
# [Segment 31] GPU Memory Start = 18530.12 MB
# [Segment 31] GPU Memory End   = 18530.69 MB
# [Segment 31] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 32] Training Time = 2.88 sec
# [Segment 32] GPU Memory Start = 18530.69 MB
# [Segment 32] GPU Memory End   = 18531.27 MB
# [Segment 32] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 33] Training Time = 4.44 sec
# [Segment 33] GPU Memory Start = 18531.27 MB
# [Segment 33] GPU Memory End   = 18531.84 MB
# [Segment 33] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 34] Training Time = 4.78 sec
# [Segment 34] GPU Memory Start = 18531.84 MB
# [Segment 34] GPU Memory End   = 18532.42 MB
# [Segment 34] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 35] Training Time = 4.71 sec
# [Segment 35] GPU Memory Start = 18532.42 MB
# [Segment 35] GPU Memory End   = 18532.99 MB
# [Segment 35] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 36] Training Time = 4.72 sec
# [Segment 36] GPU Memory Start = 18532.99 MB
# [Segment 36] GPU Memory End   = 18533.57 MB
# [Segment 36] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 37] Training Time = 4.33 sec
# [Segment 37] GPU Memory Start = 18533.57 MB
# [Segment 37] GPU Memory End   = 18534.15 MB
# [Segment 37] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 38] Training Time = 4.74 sec
# [Segment 38] GPU Memory Start = 18534.15 MB
# [Segment 38] GPU Memory End   = 18534.72 MB
# [Segment 38] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 39] Training Time = 4.61 sec
# [Segment 39] GPU Memory Start = 18534.72 MB
# [Segment 39] GPU Memory End   = 18535.30 MB
# [Segment 39] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 40] Training Time = 2.39 sec
# [Segment 40] GPU Memory Start = 18535.30 MB
# [Segment 40] GPU Memory End   = 18530.12 MB
# [Segment 40] GPU Peak Memory  = 18535.30 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 41] Training Time = 4.38 sec
# [Segment 41] GPU Memory Start = 18530.12 MB
# [Segment 41] GPU Memory End   = 18530.69 MB
# [Segment 41] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 42] Training Time = 4.69 sec
# [Segment 42] GPU Memory Start = 18530.69 MB
# [Segment 42] GPU Memory End   = 18531.27 MB
# [Segment 42] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 43] Training Time = 4.61 sec
# [Segment 43] GPU Memory Start = 18531.27 MB
# [Segment 43] GPU Memory End   = 18531.84 MB
# [Segment 43] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 44] Training Time = 4.58 sec
# [Segment 44] GPU Memory Start = 18531.84 MB
# [Segment 44] GPU Memory End   = 18532.42 MB
# [Segment 44] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 45] Training Time = 5.03 sec
# [Segment 45] GPU Memory Start = 18532.42 MB
# [Segment 45] GPU Memory End   = 18532.99 MB
# [Segment 45] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 46] Training Time = 4.94 sec
# [Segment 46] GPU Memory Start = 18532.99 MB
# [Segment 46] GPU Memory End   = 18533.57 MB
# [Segment 46] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 47] Training Time = 3.97 sec
# [Segment 47] GPU Memory Start = 18533.57 MB
# [Segment 47] GPU Memory End   = 18534.15 MB
# [Segment 47] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 48] Training Time = 4.83 sec
# [Segment 48] GPU Memory Start = 18534.15 MB
# [Segment 48] GPU Memory End   = 18534.72 MB
# [Segment 48] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 49] Training Time = 3.86 sec
# [Segment 49] GPU Memory Start = 18534.72 MB
# [Segment 49] GPU Memory End   = 18535.30 MB
# [Segment 49] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 50] Training Time = 4.78 sec
# [Segment 50] GPU Memory Start = 18535.30 MB
# [Segment 50] GPU Memory End   = 18530.12 MB
# [Segment 50] GPU Peak Memory  = 18535.30 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 51] Training Time = 4.86 sec
# [Segment 51] GPU Memory Start = 18530.12 MB
# [Segment 51] GPU Memory End   = 18530.69 MB
# [Segment 51] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 52] Training Time = 4.97 sec
# [Segment 52] GPU Memory Start = 18530.69 MB
# [Segment 52] GPU Memory End   = 18531.27 MB
# [Segment 52] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 53] Training Time = 4.80 sec
# [Segment 53] GPU Memory Start = 18531.27 MB
# [Segment 53] GPU Memory End   = 18531.84 MB
# [Segment 53] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 54] Training Time = 4.22 sec
# [Segment 54] GPU Memory Start = 18531.84 MB
# [Segment 54] GPU Memory End   = 18532.42 MB
# [Segment 54] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 55] Training Time = 4.38 sec
# [Segment 55] GPU Memory Start = 18532.42 MB
# [Segment 55] GPU Memory End   = 18532.99 MB
# [Segment 55] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 56] Training Time = 4.74 sec
# [Segment 56] GPU Memory Start = 18532.99 MB
# [Segment 56] GPU Memory End   = 18533.57 MB
# [Segment 56] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============

# %% [markdown]
# ## UF->1E setting 2차 학습 - 1차 Epo 1

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E/",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters()) 
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 0] Training Time = 4.78 sec
# [Segment 0] GPU Memory Start = 18530.12 MB
# [Segment 0] GPU Memory End   = 18530.12 MB
# [Segment 0] GPU Peak Memory  = 18531.92 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 1] Training Time = 4.07 sec
# [Segment 1] GPU Memory Start = 18530.12 MB
# [Segment 1] GPU Memory End   = 18530.69 MB
# [Segment 1] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 2] Training Time = 4.45 sec
# [Segment 2] GPU Memory Start = 18530.69 MB
# [Segment 2] GPU Memory End   = 18531.27 MB
# [Segment 2] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 3] Training Time = 3.98 sec
# [Segment 3] GPU Memory Start = 18531.27 MB
# [Segment 3] GPU Memory End   = 18531.84 MB
# [Segment 3] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 4] Training Time = 4.69 sec
# [Segment 4] GPU Memory Start = 18531.84 MB
# [Segment 4] GPU Memory End   = 18532.42 MB
# [Segment 4] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 5] Training Time = 4.79 sec
# [Segment 5] GPU Memory Start = 18532.42 MB
# [Segment 5] GPU Memory End   = 18532.99 MB
# [Segment 5] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 6] Training Time = 2.47 sec
# [Segment 6] GPU Memory Start = 18530.12 MB
# [Segment 6] GPU Memory End   = 18530.69 MB
# [Segment 6] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 7] Training Time = 3.72 sec
# [Segment 7] GPU Memory Start = 18530.69 MB
# [Segment 7] GPU Memory End   = 18531.27 MB
# [Segment 7] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 8] Training Time = 3.47 sec
# [Segment 8] GPU Memory Start = 18531.27 MB
# [Segment 8] GPU Memory End   = 18531.84 MB
# [Segment 8] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 9] Training Time = 2.55 sec
# [Segment 9] GPU Memory Start = 18531.84 MB
# [Segment 9] GPU Memory End   = 18532.42 MB
# [Segment 9] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 10] Training Time = 4.96 sec
# [Segment 10] GPU Memory Start = 18532.42 MB
# [Segment 10] GPU Memory End   = 18532.99 MB
# [Segment 10] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 11] Training Time = 4.79 sec
# [Segment 11] GPU Memory Start = 18532.99 MB
# [Segment 11] GPU Memory End   = 18533.57 MB
# [Segment 11] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 12] Training Time = 4.73 sec
# [Segment 12] GPU Memory Start = 18533.57 MB
# [Segment 12] GPU Memory End   = 18534.15 MB
# [Segment 12] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 13] Training Time = 5.06 sec
# [Segment 13] GPU Memory Start = 18534.15 MB
# [Segment 13] GPU Memory End   = 18534.72 MB
# [Segment 13] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 14] Training Time = 4.50 sec
# [Segment 14] GPU Memory Start = 18534.72 MB
# [Segment 14] GPU Memory End   = 18535.30 MB
# [Segment 14] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 15] Training Time = 4.88 sec
# [Segment 15] GPU Memory Start = 18535.30 MB
# [Segment 15] GPU Memory End   = 18535.87 MB
# [Segment 15] GPU Peak Memory  = 18537.22 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 16] Training Time = 4.99 sec
# [Segment 16] GPU Memory Start = 18530.12 MB
# [Segment 16] GPU Memory End   = 18530.69 MB
# [Segment 16] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 17] Training Time = 2.77 sec
# [Segment 17] GPU Memory Start = 18530.69 MB
# [Segment 17] GPU Memory End   = 18531.27 MB
# [Segment 17] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 18] Training Time = 4.93 sec
# [Segment 18] GPU Memory Start = 18531.27 MB
# [Segment 18] GPU Memory End   = 18531.84 MB
# [Segment 18] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 19] Training Time = 4.40 sec
# [Segment 19] GPU Memory Start = 18531.84 MB
# [Segment 19] GPU Memory End   = 18532.42 MB
# [Segment 19] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 20] Training Time = 4.97 sec
# [Segment 20] GPU Memory Start = 18532.42 MB
# [Segment 20] GPU Memory End   = 18532.99 MB
# [Segment 20] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 21] Training Time = 4.78 sec
# [Segment 21] GPU Memory Start = 18532.99 MB
# [Segment 21] GPU Memory End   = 18533.57 MB
# [Segment 21] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 22] Training Time = 4.57 sec
# [Segment 22] GPU Memory Start = 18533.57 MB
# [Segment 22] GPU Memory End   = 18534.15 MB
# [Segment 22] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 23] Training Time = 4.84 sec
# [Segment 23] GPU Memory Start = 18534.15 MB
# [Segment 23] GPU Memory End   = 18534.72 MB
# [Segment 23] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 24] Training Time = 4.66 sec
# [Segment 24] GPU Memory Start = 18534.72 MB
# [Segment 24] GPU Memory End   = 18535.30 MB
# [Segment 24] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 25] Training Time = 4.43 sec
# [Segment 25] GPU Memory Start = 18535.30 MB
# [Segment 25] GPU Memory End   = 18535.87 MB
# [Segment 25] GPU Peak Memory  = 18537.22 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 26] Training Time = 3.86 sec
# [Segment 26] GPU Memory Start = 18530.12 MB
# [Segment 26] GPU Memory End   = 18530.69 MB
# [Segment 26] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 27] Training Time = 4.93 sec
# [Segment 27] GPU Memory Start = 18530.69 MB
# [Segment 27] GPU Memory End   = 18531.27 MB
# [Segment 27] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 28] Training Time = 4.54 sec
# [Segment 28] GPU Memory Start = 18531.27 MB
# [Segment 28] GPU Memory End   = 18531.84 MB
# [Segment 28] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 29] Training Time = 2.50 sec
# [Segment 29] GPU Memory Start = 18531.84 MB
# [Segment 29] GPU Memory End   = 18532.42 MB
# [Segment 29] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 30] Training Time = 4.77 sec
# [Segment 30] GPU Memory Start = 18532.42 MB
# [Segment 30] GPU Memory End   = 18532.99 MB
# [Segment 30] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 31] Training Time = 4.78 sec
# [Segment 31] GPU Memory Start = 18532.99 MB
# [Segment 31] GPU Memory End   = 18533.57 MB
# [Segment 31] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 32] Training Time = 4.82 sec
# [Segment 32] GPU Memory Start = 18533.57 MB
# [Segment 32] GPU Memory End   = 18534.15 MB
# [Segment 32] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 33] Training Time = 2.61 sec
# [Segment 33] GPU Memory Start = 18534.15 MB
# [Segment 33] GPU Memory End   = 18534.72 MB
# [Segment 33] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 34] Training Time = 4.80 sec
# [Segment 34] GPU Memory Start = 18534.72 MB
# [Segment 34] GPU Memory End   = 18535.30 MB
# [Segment 34] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 35] Training Time = 4.84 sec
# [Segment 35] GPU Memory Start = 18535.30 MB
# [Segment 35] GPU Memory End   = 18535.87 MB
# [Segment 35] GPU Peak Memory  = 18537.22 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 36] Training Time = 4.62 sec
# [Segment 36] GPU Memory Start = 18530.12 MB
# [Segment 36] GPU Memory End   = 18530.69 MB
# [Segment 36] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 37] Training Time = 4.80 sec
# [Segment 37] GPU Memory Start = 18530.69 MB
# [Segment 37] GPU Memory End   = 18531.27 MB
# [Segment 37] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 38] Training Time = 2.62 sec
# [Segment 38] GPU Memory Start = 18531.27 MB
# [Segment 38] GPU Memory End   = 18531.84 MB
# [Segment 38] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 39] Training Time = 3.82 sec
# [Segment 39] GPU Memory Start = 18531.84 MB
# [Segment 39] GPU Memory End   = 18532.42 MB
# [Segment 39] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 40] Training Time = 3.74 sec
# [Segment 40] GPU Memory Start = 18532.42 MB
# [Segment 40] GPU Memory End   = 18532.99 MB
# [Segment 40] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 41] Training Time = 2.56 sec
# [Segment 41] GPU Memory Start = 18532.99 MB
# [Segment 41] GPU Memory End   = 18533.57 MB
# [Segment 41] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 42] Training Time = 3.44 sec
# [Segment 42] GPU Memory Start = 18533.57 MB
# [Segment 42] GPU Memory End   = 18534.15 MB
# [Segment 42] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 43] Training Time = 4.92 sec
# [Segment 43] GPU Memory Start = 18534.15 MB
# [Segment 43] GPU Memory End   = 18534.72 MB
# [Segment 43] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 44] Training Time = 4.40 sec
# [Segment 44] GPU Memory Start = 18534.72 MB
# [Segment 44] GPU Memory End   = 18535.30 MB
# [Segment 44] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 45] Training Time = 4.83 sec
# [Segment 45] GPU Memory Start = 18535.30 MB
# [Segment 45] GPU Memory End   = 18535.87 MB
# [Segment 45] GPU Peak Memory  = 18537.22 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 46] Training Time = 4.85 sec
# [Segment 46] GPU Memory Start = 18530.12 MB
# [Segment 46] GPU Memory End   = 18530.69 MB
# [Segment 46] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 47] Training Time = 4.57 sec
# [Segment 47] GPU Memory Start = 18530.69 MB
# [Segment 47] GPU Memory End   = 18531.27 MB
# [Segment 47] GPU Peak Memory  = 18532.62 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 48] Training Time = 4.81 sec
# [Segment 48] GPU Memory Start = 18531.27 MB
# [Segment 48] GPU Memory End   = 18531.84 MB
# [Segment 48] GPU Peak Memory  = 18533.19 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 49] Training Time = 4.81 sec
# [Segment 49] GPU Memory Start = 18531.84 MB
# [Segment 49] GPU Memory End   = 18532.42 MB
# [Segment 49] GPU Peak Memory  = 18533.77 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 50] Training Time = 4.24 sec
# [Segment 50] GPU Memory Start = 18532.42 MB
# [Segment 50] GPU Memory End   = 18532.99 MB
# [Segment 50] GPU Peak Memory  = 18534.34 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 51] Training Time = 4.40 sec
# [Segment 51] GPU Memory Start = 18532.99 MB
# [Segment 51] GPU Memory End   = 18533.57 MB
# [Segment 51] GPU Peak Memory  = 18534.92 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 52] Training Time = 4.72 sec
# [Segment 52] GPU Memory Start = 18533.57 MB
# [Segment 52] GPU Memory End   = 18534.15 MB
# [Segment 52] GPU Peak Memory  = 18535.50 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 53] Training Time = 4.95 sec
# [Segment 53] GPU Memory Start = 18534.15 MB
# [Segment 53] GPU Memory End   = 18534.72 MB
# [Segment 53] GPU Peak Memory  = 18536.07 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 54] Training Time = 4.81 sec
# [Segment 54] GPU Memory Start = 18534.72 MB
# [Segment 54] GPU Memory End   = 18535.30 MB
# [Segment 54] GPU Peak Memory  = 18536.65 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 55] Training Time = 4.75 sec
# [Segment 55] GPU Memory Start = 18535.30 MB
# [Segment 55] GPU Memory End   = 18535.87 MB
# [Segment 55] GPU Peak Memory  = 18537.22 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.4766 MB
#   yb per batch = 0.0410 MB, total = 43.4766 MB
#   pv per batch = 0.0137 MB, total = 14.4922 MB
# [Segment 56] Training Time = 4.33 sec
# [Segment 56] GPU Memory Start = 18530.12 MB
# [Segment 56] GPU Memory End   = 18530.69 MB
# [Segment 56] GPU Peak Memory  = 18532.04 MB
#
# ============= Done =============

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for validation set 얻은 후 에러율 계산

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ETTm2_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.4853605628013611  MAE:0.5349438190460205
# ▶ seg0  mean  MSE:0.4853605628013611  MAE:0.5349438190460205
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.6880589723587036  MAE:0.6283502578735352
# ▶ seg1  mean  MSE:0.6880589723587036  MAE:0.6283502578735352
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.6778345108032227  MAE:0.6301026344299316
# ▶ seg2  mean  MSE:0.6778345108032227  MAE:0.6301026344299316
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.9019739627838135  MAE:0.7163739204406738
# ▶ seg3  mean  MSE:0.9019739627838135  MAE:0.7163739204406738
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.5919530987739563  MAE:0.5725847482681274
# ▶ seg4  mean  MSE:0.5919530987739563  MAE:0.5725847482681274
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:1.192676067352295  MAE:0.8273643255233765
# ▶ seg5  mean  MSE:1.192676067352295  MAE:0.8273643255233765
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.5917906165122986  MAE:0.5611886978149414
# ▶ seg6  mean  MSE:0.5917906165122986  MAE:0.5611886978149414
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.6948242783546448  MAE:0.6144593358039856
# ▶ seg7  mean  MSE:0.6948242783546448  MAE:0.6144593358039856
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.696133017539978  MAE:0.6318017244338989
# ▶ seg8  mean  MSE:0.696133017539978  MAE:0.6318017244338989
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.3736255168914795  MAE:0.46783944964408875
# ▶ seg9  mean  MSE:0.3736255168914795  MAE:0.46783944964408875
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.618280827999115  MAE:0.5974360704421997
# ▶ seg10  mean  MSE:0.618280827999115  MAE:0.5974360704421997
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:1.121895432472229  MAE:0.7540215849876404
# ▶ seg11  mean  MSE:1.121895432472229  MAE:0.7540215849876404
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.4573098123073578  MAE:0.5345339775085449
# ▶ seg12  mean  MSE:0.4573098123073578  MAE:0.5345339775085449
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.4712478518486023  MAE:0.5264394879341125
# ▶ seg13  mean  MSE:0.4712478518486023  MAE:0.5264394879341125
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.3654111921787262  MAE:0.45226752758026123
# ▶ seg14  mean  MSE:0.3654111921787262  MAE:0.45226752758026123
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.6317223906517029  MAE:0.6173781156539917
# ▶ seg15  mean  MSE:0.6317223906517029  MAE:0.6173781156539917
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.8658033013343811  MAE:0.680732786655426
# ▶ seg16  mean  MSE:0.8658033013343811  MAE:0.680732786655426
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.6681113243103027  MAE:0.6025221347808838
# ▶ seg17  mean  MSE:0.6681113243103027  MAE:0.6025221347808838
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.4830702245235443  MAE:0.5482305884361267
# ▶ seg18  mean  MSE:0.4830702245235443  MAE:0.5482305884361267
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:1.1161649227142334  MAE:0.779563307762146
# ▶ seg19  mean  MSE:1.1161649227142334  MAE:0.779563307762146
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:1.7359977960586548  MAE:0.8512552976608276
# ▶ seg36  mean  MSE:1.7359977960586548  MAE:0.8512552976608276
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.647620439529419  MAE:0.586660623550415
# ▶ seg37  mean  MSE:0.647620439529419  MAE:0.586660623550415
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:1.063366174697876  MAE:0.7607265710830688
# ▶ seg38  mean  MSE:1.063366174697876  MAE:0.7607265710830688
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:1.0382068157196045  MAE:0.8142392039299011
# ▶ seg39  mean  MSE:1.0382068157196045  MAE:0.8142392039299011
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.5440129041671753  MAE:0.5634621977806091
# ▶ seg40  mean  MSE:0.5440129041671753  MAE:0.5634621977806091
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.3162546753883362  MAE:0.43121305108070374
# ▶ seg41  mean  MSE:0.3162546753883362  MAE:0.43121305108070374
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:1.2256253957748413  MAE:0.8502501845359802
# ▶ seg42  mean  MSE:1.2256253957748413  MAE:0.8502501845359802
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.5706654191017151  MAE:0.5984002351760864
# ▶ seg43  mean  MSE:0.5706654191017151  MAE:0.5984002351760864
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.3333032727241516  MAE:0.44058409333229065
# ▶ seg44  mean  MSE:0.3333032727241516  MAE:0.44058409333229065
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.29585030674934387  MAE:0.4142870306968689
# ▶ seg45  mean  MSE:0.29585030674934387  MAE:0.4142870306968689
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:2.5150041580200195  MAE:1.1844158172607422
# ▶ seg46  mean  MSE:2.5150041580200195  MAE:1.1844158172607422
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:1.1439579725265503  MAE:0.7993781566619873
# ▶ seg47  mean  MSE:1.1439579725265503  MAE:0.7993781566619873
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.31236857175827026  MAE:0.4383317530155182
# ▶ seg48  mean  MSE:0.31236857175827026  MAE:0.4383317530155182
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:1.4984979629516602  MAE:0.8892263174057007
# ▶ seg49  mean  MSE:1.4984979629516602  MAE:0.8892263174057007
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.6559627652168274  MAE:0.6086224317550659
# ▶ seg50  mean  MSE:0.6559627652168274  MAE:0.6086224317550659
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.5975419878959656  MAE:0.5773460865020752
# ▶ seg51  mean  MSE:0.5975419878959656  MAE:0.5773460865020752
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:1.1593692302703857  MAE:0.7670992016792297
# ▶ seg52  mean  MSE:1.1593692302703857  MAE:0.7670992016792297
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.3664912283420563  MAE:0.46285054087638855
# ▶ seg53  mean  MSE:0.3664912283420563  MAE:0.46285054087638855
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.4066650867462158  MAE:0.4964607059955597
# ▶ seg54  mean  MSE:0.4066650867462158  MAE:0.4964607059955597
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.6899982690811157  MAE:0.6080819368362427
# ▶ seg55  mean  MSE:0.6899982690811157  MAE:0.6080819368362427
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.32874351739883423  MAE:0.4437120854854584
# ▶ seg56  mean  MSE:0.32874351739883423  MAE:0.4437120854854584
#
# seg10 ch0 MSE : 0.7560352

# %% [markdown]
# # 모든 증강 모델 2차 예측값 for test set 얻은 후 에러율 계산

# %% [markdown]
# ## EPO ES - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 336
seq_len = 336


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ETTm2_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.4737723469734192  MAE:0.527855634689331
# ▶ seg0  mean  MSE:0.4737723469734192  MAE:0.527855634689331
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.8215294480323792  MAE:0.7394680976867676
# ▶ seg52  mean  MSE:0.8215294480323792  MAE:0.7394680976867676
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.6598657965660095  MAE:0.6309396624565125
# ▶ seg53  mean  MSE:0.6598657965660095  MAE:0.6309396624565125
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.41217562556266785  MAE:0.4847148358821869
# ▶ seg54  mean  MSE:0.41217562556266785  MAE:0.4847148358821869
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:5.3225555419921875  MAE:1.9962944984436035
# ▶ seg55  mean  MSE:5.3225555419921875  MAE:1.9962944984436035
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.5184293389320374  MAE:0.5660033226013184
# ▶ seg56  mean  MSE:0.5184293389320374  MAE:0.5660033226013184
#
# seg10 ch0 MSE : 0.6280724

# %% [markdown]
# ## EPO 1 - 1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 336
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 336,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.01,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_E1_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### pv//3

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 57
batch_sz = 32

results2_ETTm2_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.4659694731235504  MAE:0.5210269689559937
# ▶ seg0  mean  MSE:0.4659694731235504  MAE:0.5210269689559937
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.4603959321975708  MAE:0.5183796882629395
# ▶ seg1  mean  MSE:0.4603959321975708  MAE:0.5183796882629395
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:1.891669750213623  MAE:1.0665526390075684
# ▶ seg2  mean  MSE:1.891669750213623  MAE:1.0665526390075684
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:1.6818573474884033  MAE:1.0426760911941528
# ▶ seg3  mean  MSE:1.6818573474884033  MAE:1.0426760911941528
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.8081653714179993  MAE:0.6212201118469238
# ▶ seg4  mean  MSE:0.8081653714179993  MAE:0.6212201118469238
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:1.1960070133209229  MAE:0.851862907409668
# ▶ seg5  mean  MSE:1.1960070133209229  MAE:0.851862907409668
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.3264526128768921  MAE:0.42815160751342773
# ▶ seg6  mean  MSE:0.3264526128768921  MAE:0.42815160751342773
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:1.6858800649642944  MAE:0.939689040184021
# ▶ seg7  mean  MSE:1.6858800649642944  MAE:0.939689040184021
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.5685756206512451  MAE:0.5994356274604797
# ▶ seg8  mean  MSE:0.5685756206512451  MAE:0.5994356274604797
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:1.0598458051681519  MAE:0.7778245806694031
# ▶ seg9  mean  MSE:1.0598458051681519  MAE:0.7778245806694031
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.7792631983757019  MAE:0.6609128713607788
# ▶ seg10  mean  MSE:0.7792631983757019  MAE:0.6609128713607788
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.5023356676101685  MAE:0.5403285026550293
# ▶ seg11  mean  MSE:0.5023356676101685  MAE:0.5403285026550293
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:1.3136335611343384  MAE:0.8475969433784485
# ▶ seg12  mean  MSE:1.3136335611343384  MAE:0.8475969433784485
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.5758719444274902  MAE:0.6211908459663391
# ▶ seg13  mean  MSE:0.5758719444274902  MAE:0.6211908459663391
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.7997556924819946  MAE:0.6469367146492004
# ▶ seg14  mean  MSE:0.7997556924819946  MAE:0.6469367146492004
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.43524226546287537  MAE:0.5039612054824829
# ▶ seg15  mean  MSE:0.43524226546287537  MAE:0.5039612054824829
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:1.386090874671936  MAE:0.9052956700325012
# ▶ seg42  mean  MSE:1.386090874671936  MAE:0.9052956700325012
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.7504990100860596  MAE:0.7056615948677063
# ▶ seg43  mean  MSE:0.7504990100860596  MAE:0.7056615948677063
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.29592570662498474  MAE:0.41537466645240784
# ▶ seg44  mean  MSE:0.29592570662498474  MAE:0.41537466645240784
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.2713503837585449  MAE:0.38940930366516113
# ▶ seg45  mean  MSE:0.2713503837585449  MAE:0.38940930366516113
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:3.561039447784424  MAE:1.4649015665054321
# ▶ seg46  mean  MSE:3.561039447784424  MAE:1.4649015665054321
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:1.2901533842086792  MAE:0.8451982736587524
# ▶ seg47  mean  MSE:1.2901533842086792  MAE:0.8451982736587524
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.3213256597518921  MAE:0.4301750361919403
# ▶ seg48  mean  MSE:0.3213256597518921  MAE:0.4301750361919403
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:1.7542825937271118  MAE:0.9648619890213013
# ▶ seg49  mean  MSE:1.7542825937271118  MAE:0.9648619890213013
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.7830337285995483  MAE:0.6614390015602112
# ▶ seg50  mean  MSE:0.7830337285995483  MAE:0.6614390015602112
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.6105339527130127  MAE:0.5749711394309998
# ▶ seg51  mean  MSE:0.6105339527130127  MAE:0.5749711394309998
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:1.5276460647583008  MAE:0.888511598110199
# ▶ seg52  mean  MSE:1.5276460647583008  MAE:0.888511598110199
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.3430328369140625  MAE:0.44310691952705383
# ▶ seg53  mean  MSE:0.3430328369140625  MAE:0.44310691952705383
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.4631987512111664  MAE:0.5248425006866455
# ▶ seg54  mean  MSE:0.4631987512111664  MAE:0.5248425006866455
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.8241133689880371  MAE:0.6593868136405945
# ▶ seg55  mean  MSE:0.8241133689880371  MAE:0.6593868136405945
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.31454741954803467  MAE:0.4360085427761078
# ▶ seg56  mean  MSE:0.31454741954803467  MAE:0.4360085427761078
#
# seg10 ch0 MSE : 0.7792632

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTm2_train = torch.load("./1st_results_ETTm2/train_1st_results.pt")
results1_ETTm2_val = torch.load("./1st_results_ETTm2/val_1st_results.pt")
results1_ETTm2_test = torch.load("./1st_results_ETTm2/test_1st_results.pt")

# %% [markdown]
# ### EPO ES - 1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 57
SEG_CNT     = 57
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.854590
#
#   Top  1 | seg 34 | MSE 0.249097 (+0.605493)
#   Top  2 | seg 20 | MSE 0.255594 (+0.598996)
#   Top  3 | seg 48 | MSE 0.279644 (+0.574946)
#   Top  4 | seg 45 | MSE 0.302214 (+0.552376)
#   Top  5 | seg 38 | MSE 0.318019 (+0.536571)
#   Top  6 | seg 24 | MSE 0.343790 (+0.510800)
#   Top  7 | seg 35 | MSE 0.361030 (+0.493560)
#   Top  8 | seg 14 | MSE 0.365411 (+0.489179)
#   Top  9 | seg 43 | MSE 0.365441 (+0.489149)
E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 57
SEG_CNT     = 57
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.854590
#
#   Top  1 | seg 24 | MSE 0.292902 (+0.561688)
#   Top  2 | seg 45 | MSE 0.295850 (+0.558740)
#   Top  3 | seg 48 | MSE 0.312369 (+0.542221)
#   Top  4 | seg 41 | MSE 0.316255 (+0.538335)
#   Top  5 | seg 56 | MSE 0.328744 (+0.525846)
#   Top  6 | seg 44 | MSE 0.333303 (+0.521287)
#   Top  7 | seg 06 | MSE 0.334089 (+0.520501)
#   Top  8 | seg 20 | MSE 0.351249 (+0.503340)
#   Top  9 | seg 53 | MSE 0.366491 (+0.488099)
#   Top 10 | seg 54 | MSE 0.406665 (+0.447925)
#   Top 11 | seg 31 | MSE 0.414683 (+0.439907)
#   Top 12 | seg 23 | MSE 0.419858 (+0.434732)
#   Top 13 | seg 35 | MSE 0.420196 (+0.434393)
#   Top 14 | seg 01 | MSE 0.437105 (+0.417485)
#   Top 15 | seg 29 | MSE 0.440632 (+0.413958)
#   Top 16 | seg 17 | MSE 0.440727 (+0.413863)
#   Top 17 | seg 15 | MSE 0.440876 (+0.413714)
#   Top 18 | seg 26 | MSE 0.443332 (+0.411257)
#   Top 19 | seg 21 | MSE 0.444904 (+0.409686)
#   Top 20 | seg 13 | MSE 0.446816 (+0.407774)
#   Top 21 | seg 18 | MSE 0.456998 (+0.397592)
#   Top 22 | seg 08 | MSE 0.458211 (+0.396379)
#   Top 23 | seg 30 | MSE 0.470451 (+0.384138)
#   Top 24 | seg 33 | MSE 0.476078 (+0.378512)
#   Top 25 | seg 00 | MSE 0.506360 (+0.348230)
#   Top 26 | seg 25 | MSE 0.517942 (+0.336648)
#   Top 27 | seg 11 | MSE 0.519669 (+0.334921)
#   Top 28 | seg 40 | MSE 0.544013 (+0.310577)
#   Top 29 | seg 43 | MSE 0.570665 (+0.283924)
#   Top 30 | seg 16 | MSE 0.571706 (+0.282883)
#   Top 31 | seg 51 | MSE 0.597542 (+0.257048)
#   Top 32 | seg 37 | MSE 0.647620 (+0.206969)
#   Top 33 | seg 50 | MSE 0.655963 (+0.198627)
#   Top 34 | seg 19 | MSE 0.657909 (+0.196680)
#   Top 35 | seg 04 | MSE 0.659472 (+0.195117)
#   Top 36 | seg 55 | MSE 0.689998 (+0.164592)
#   Top 37 | seg 14 | MSE 0.735310 (+0.119279)
#   Top 38 | seg 10 | MSE 0.756035 (+0.098555)
#   Top 39 | seg 34 | MSE 0.899596 (-0.045006)
#   Top 40 | seg 12 | MSE 0.913053 (-0.058463)
#   Top 41 | seg 05 | MSE 0.932516 (-0.077926)
#   Top 42 | seg 09 | MSE 0.939097 (-0.084507)
#   Top 43 | seg 22 | MSE 0.974702 (-0.120113)
#   Top 44 | seg 39 | MSE 1.038207 (-0.183617)
#   Top 45 | seg 38 | MSE 1.063366 (-0.208776)
#   Top 46 | seg 27 | MSE 1.102193 (-0.247603)
#   Top 47 | seg 47 | MSE 1.143958 (-0.289368)
#   Top 48 | seg 52 | MSE 1.159369 (-0.304779)
#   Top 49 | seg 28 | MSE 1.188911 (-0.334322)
#   Top 50 | seg 03 | MSE 1.192837 (-0.338247)
#   Top 51 | seg 42 | MSE 1.225625 (-0.371036)
#   Top 52 | seg 07 | MSE 1.264968 (-0.410378)
#   Top 53 | seg 49 | MSE 1.498498 (-0.643908)
#   Top 54 | seg 02 | MSE 1.616893 (-0.762303)
#   Top 55 | seg 36 | MSE 1.735998 (-0.881408)
#   Top 56 | seg 46 | MSE 2.515004 (-1.660414)
#   Top 57 | seg 32 | MSE 3.125731 (-2.271141)
#
# Saved top segment indices per channel:
# Channel 0: [24, 45, 48, 41, 56, 44, 6, 20, 53, 54, 31, 23, 35, 1, 29, 17, 15, 26, 21, 13, 18, 8, 30, 33, 0, 25, 11, 40, 43, 16, 51, 37, 50, 19, 4, 55, 14, 10, 34, 12, 5, 9, 22, 39, 38, 27, 47, 52, 28, 3, 42, 7, 49, 2, 36, 46, 32]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## EPO ES - 1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTm2_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.123252 | MAE : 0.265839
#   — Var / |Corr| / Score —
#    K= 5 | Var=1.568e-01 | |ρ|=0.6776 | S=1.0000
#    K=10 | Var=2.088e-01 | |ρ|=0.6087 | S=0.7850
#    K=15 | Var=2.343e-01 | |ρ|=0.6097 | S=0.8413
#    K=20 | Var=2.672e-01 | |ρ|=0.5657 | S=0.7033
#    K=25 | Var=2.997e-01 | |ρ|=0.5606 | S=0.7451
#    K=30 | Var=3.364e-01 | |ρ|=0.5339 | S=0.6950 <- pick
#    K=35 | Var=3.744e-01 | |ρ|=0.5318 | S=0.7623
#    K=40 | Var=4.071e-01 | |ρ|=0.5201 | S=0.7740
#    K=45 | Var=4.557e-01 | |ρ|=0.5144 | S=0.8459
#    K=50 | Var=5.294e-01 | |ρ|=0.4921 | S=0.8909
#    K=55 | Var=6.514e-01 | |ρ|=0.4625 | S=1.0000
# [Var-Corr]  K=30
#   MSE = 0.133515 | Δ = -0.010263 | Δ% = -8.33%
#   MAE = 0.280794 | Δ = -0.014954 | Δ% = -5.63%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.123252
# Ensemble mean MSE : 0.133515
# Average Δ MSE     : -0.010263
# Average Δ MSE (%) : -8.33%
#
# Vanilla  mean MAE : 0.265839
# Ensemble mean MAE : 0.280794
# Average Δ MAE     : -0.014954
# Average Δ MAE (%) : -5.63%

# %% [markdown]
# ## EPO 1 - 1E

# %%
results1_ETTm2_test['ES']['mae_test_EES']
# Out:
# 0.26583945751190186

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 57
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTm2_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.1   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.123252 | MAE : 0.265839
#   — Var / |Corr| / Score —
#    K= 5 | Var=1.369e-01 | |ρ|=0.7432 | S=1.1000
#    K=10 | Var=1.983e-01 | |ρ|=0.6676 | S=0.9098
#    K=15 | Var=2.342e-01 | |ρ|=0.6349 | S=0.8442
#    K=20 | Var=2.841e-01 | |ρ|=0.6028 | S=0.8062
#    K=25 | Var=3.038e-01 | |ρ|=0.5875 | S=0.7806
#    K=30 | Var=3.329e-01 | |ρ|=0.5865 | S=0.8285
#    K=35 | Var=3.813e-01 | |ρ|=0.5469 | S=0.7580
#    K=40 | Var=4.408e-01 | |ρ|=0.5184 | S=0.7509 <- pick
#    K=45 | Var=5.194e-01 | |ρ|=0.4862 | S=0.7635
#    K=50 | Var=6.034e-01 | |ρ|=0.4765 | S=0.8748
#    K=55 | Var=6.983e-01 | |ρ|=0.4654 | S=1.0000
# [Var-Corr]  K=40
#    MSE = 0.121083 | Δ = +0.002169 | Δ% = +1.76%
#    MAE = 0.264163 | Δ = +0.001677 | Δ% = +0.63%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.123252
# Ensemble mean MSE  : 0.121083
# Average Δ MSE      : +0.002169
# Average Δ MSE (%)  : +1.76%
#
# Vanilla  mean MAE  : 0.265839
# Ensemble mean MAE  : 0.264163
# Average Δ MAE      : +0.001677
# Average Δ MAE (%)  : +0.63%
