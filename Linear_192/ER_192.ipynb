# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(3)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 3
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/exchange_rate.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                  0       1         2         3         4         5         6  \
# date
# 1990-01-01  0.7855  1.6110  0.861698  0.634196  0.211242  0.006838  0.525486
# 1990-01-02  0.7818  1.6100  0.861104  0.633513  0.211242  0.006863  0.523972
# 1990-01-03  0.7867  1.6293  0.861030  0.648508  0.211242  0.006975  0.526316
# 1990-01-04  0.7860  1.6370  0.862069  0.650618  0.211242  0.006953  0.523834
# 1990-01-05  0.7849  1.6530  0.861995  0.656254  0.211242  0.006940  0.527426
#
#                 OT
# date
# 1990-01-01  0.5930
# 1990-01-02  0.5940
# 1990-01-03  0.5973
# 1990-01-04  0.5970
# 1990-01-05  0.5985

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# OT    float64
# dtype: object
# shape:  (7588, 8)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2010-10-01', '2010-10-02', '2010-10-03', '2010-10-04',
#                '2010-10-05', '2010-10-06', '2010-10-07', '2010-10-08',
#                '2010-10-09', '2010-10-10'],
#               dtype='datetime64[ns]', name='date', length=7588, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %%
set_seed(32)

# %% [markdown]
# # Model Modification for Linear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model(nn.Module):
    """
    Linear model with prediction-based augmentation (attach_pv)
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.channels = configs.enc_in

        
        self.attach_pv = getattr(configs, "attach_pv", False)

        
        self.extra_len = self.pred_len // 3

        
        self.seq_len_aug = self.seq_len + (self.extra_len if self.attach_pv else 0)

        self.individual = configs.individual

        
        if self.individual:
            self.Linear = nn.ModuleList()
            for i in range(self.channels):
                self.Linear.append(nn.Linear(self.seq_len_aug, self.pred_len))
        else:
            self.Linear = nn.Linear(self.seq_len_aug, self.pred_len)


    def forward(self, x, ground_truth=None):
        """
        x: [B, L, C]
        ground_truth: [B, L_gt, C] or None
        """
        B, L, C = x.size()

        
        
        
        if self.attach_pv and (ground_truth is not None):
            
            gt_part = ground_truth[:, :self.extra_len, :]  

            
            x = torch.cat([x, gt_part], dim=1)

        
        
        
        if self.individual:
            out = torch.zeros([B, self.pred_len, C], dtype=x.dtype).to(x.device)
            for i in range(C):
                out[:, :, i] = self.Linear[i](x[:, :, i])
            return out

        else:
            
            out = self.Linear(x.permute(0, 2, 1))
            return out.permute(0, 2, 1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len  = 336
pred_len = 192


total_len  = len(target)
num_train  = int(total_len * 0.7)
num_test   = int(total_len * 0.2)
num_val    = total_len - num_train - num_test

border1s = [
    0,
    num_train - seq_len,
    total_len - num_test - seq_len
]
border2s = [
    num_train,
    num_train + num_val,
    total_len
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i : i + seq_len]
        seq_y = data[i + seq_len : i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([4784, 336, 1])
# Train Labels:    torch.Size([4784, 192, 1])
# Val Sequences:   torch.Size([569, 336, 1])
# Val Labels:      torch.Size([569, 192, 1])
# Test Sequences:  torch.Size([1326, 336, 1])
# Test Labels:     torch.Size([1326, 192, 1])

# %%
batch_size = 8


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 192  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ER", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.31144522816989334 | Val Loss: 0.39468193737169105
# Validation loss decreased (inf --> 0.394682).  Saving model ...
# Updating learning rate to 0.0005
# Epoch 1 | Train Loss: 0.26353655418499455 | Val Loss: 0.2520958605325884
# Validation loss decreased (0.394682 --> 0.252096).  Saving model ...
# Updating learning rate to 0.00025
# Epoch 2 | Train Loss: 0.253635898724597 | Val Loss: 0.3993514604452584
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# Epoch 3 | Train Loss: 0.24737652785527867 | Val Loss: 0.4048067604502042
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-05
# Epoch 4 | Train Loss: 0.24584665136991138 | Val Loss: 0.3734254739764664
# EarlyStopping counter: 3 out of 3
# Early stopping triggered. Stopping training.

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 192  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.0005, lradj='type1',  patience=3, save_path="./model_ER", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.001
# Epoch 0 | Train Loss: 0.3098741509518695 | Val Loss: 0.2880229469285243
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.247290700674057 | MAE: 0.3810746669769287
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.24187155067920685 | MAE: 0.3850845992565155

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.24920719861984253 | MAE: 0.3966204524040222
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.28840944170951843 | MAE: 0.4366037845611572

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.2861335277557373 | MAE: 0.376138299703598
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.28305527567863464 | MAE: 0.37394461035728455

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([4784, 336, 1])
# val_sequences shape:  torch.Size([569, 336, 1])
# test_sequences shape:  torch.Size([1326, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([4784, 192, 1])
# val_pv shape:  torch.Size([569, 192, 1])
# test_pv shape:  torch.Size([1326, 192, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([4784, 192, 1])
# val_labels shape:  torch.Size([569, 192, 1])
# test_labels shape:  torch.Size([1326, 192, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 192

# %%
segment_len = configs.pred_len // 3
stride = 2

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([4784, 65, 64, 1]), Val: torch.Size([569, 65, 64, 1]), Test: torch.Size([1326, 65, 64, 1])
# [Epoch 1] Train seg shape: torch.Size([4784, 65, 64, 1]), Val: torch.Size([569, 65, 64, 1]), Test: torch.Size([1326, 65, 64, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ER'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ER/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ER/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ER/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 192,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ER_E{epo}_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=8, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=8, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 0] Training Time = 2.43 sec
# [Segment 0] GPU Memory Start = 1510.08 MB
# [Segment 0] GPU Memory End   = 1392.12 MB
# [Segment 0] GPU Peak Memory  = 1510.08 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 1] Training Time = 2.38 sec
# [Segment 1] GPU Memory Start = 1392.12 MB
# [Segment 1] GPU Memory End   = 1392.42 MB
# [Segment 1] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 2] Training Time = 1.74 sec
# [Segment 2] GPU Memory Start = 1392.42 MB
# [Segment 2] GPU Memory End   = 1392.71 MB
# [Segment 2] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 3] Training Time = 1.82 sec
# [Segment 3] GPU Memory Start = 1392.71 MB
# [Segment 3] GPU Memory End   = 1393.00 MB
# [Segment 3] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 4] Training Time = 1.73 sec
# [Segment 4] GPU Memory Start = 1393.00 MB
# [Segment 4] GPU Memory End   = 1393.30 MB
# [Segment 4] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 5] Training Time = 2.37 sec
# [Segment 5] GPU Memory Start = 1393.30 MB
# [Segment 5] GPU Memory End   = 1393.59 MB
# [Segment 5] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 6] Training Time = 1.28 sec
# [Segment 6] GPU Memory Start = 1393.59 MB
# [Segment 6] GPU Memory End   = 1393.89 MB
# [Segment 6] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 7] Training Time = 2.27 sec
# [Segment 7] GPU Memory Start = 1393.89 MB
# [Segment 7] GPU Memory End   = 1394.18 MB
# [Segment 7] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 8] Training Time = 2.34 sec
# [Segment 8] GPU Memory Start = 1394.18 MB
# [Segment 8] GPU Memory End   = 1394.47 MB
# [Segment 8] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 9] Training Time = 1.90 sec
# [Segment 9] GPU Memory Start = 1394.47 MB
# [Segment 9] GPU Memory End   = 1394.77 MB
# [Segment 9] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 10] Training Time = 2.10 sec
# [Segment 10] GPU Memory Start = 1394.77 MB
# [Segment 10] GPU Memory End   = 1392.12 MB
# [Segment 10] GPU Peak Memory  = 1394.77 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 11] Training Time = 2.38 sec
# [Segment 11] GPU Memory Start = 1392.12 MB
# [Segment 11] GPU Memory End   = 1392.42 MB
# [Segment 11] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 12] Training Time = 1.92 sec
# [Segment 12] GPU Memory Start = 1392.42 MB
# [Segment 12] GPU Memory End   = 1392.71 MB
# [Segment 12] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 13] Training Time = 1.39 sec
# [Segment 13] GPU Memory Start = 1392.71 MB
# [Segment 13] GPU Memory End   = 1393.00 MB
# [Segment 13] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 14] Training Time = 2.44 sec
# [Segment 14] GPU Memory Start = 1393.00 MB
# [Segment 14] GPU Memory End   = 1393.30 MB
# [Segment 14] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 15] Training Time = 2.41 sec
# [Segment 15] GPU Memory Start = 1393.30 MB
# [Segment 15] GPU Memory End   = 1393.59 MB
# [Segment 15] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 16] Training Time = 2.02 sec
# [Segment 16] GPU Memory Start = 1393.59 MB
# [Segment 16] GPU Memory End   = 1393.89 MB
# [Segment 16] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 17] Training Time = 2.22 sec
# [Segment 17] GPU Memory Start = 1393.89 MB
# [Segment 17] GPU Memory End   = 1394.18 MB
# [Segment 17] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 18] Training Time = 2.31 sec
# [Segment 18] GPU Memory Start = 1394.18 MB
# [Segment 18] GPU Memory End   = 1394.47 MB
# [Segment 18] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 19] Training Time = 2.21 sec
# [Segment 19] GPU Memory Start = 1394.47 MB
# [Segment 19] GPU Memory End   = 1394.77 MB
# [Segment 19] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 20] Training Time = 2.22 sec
# [Segment 20] GPU Memory Start = 1394.77 MB
# [Segment 20] GPU Memory End   = 1392.12 MB
# [Segment 20] GPU Peak Memory  = 1394.77 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 21] Training Time = 2.29 sec
# [Segment 21] GPU Memory Start = 1392.12 MB
# [Segment 21] GPU Memory End   = 1392.42 MB
# [Segment 21] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 22] Training Time = 2.36 sec
# [Segment 22] GPU Memory Start = 1392.42 MB
# [Segment 22] GPU Memory End   = 1392.71 MB
# [Segment 22] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 23] Training Time = 2.37 sec
# [Segment 23] GPU Memory Start = 1392.71 MB
# [Segment 23] GPU Memory End   = 1393.00 MB
# [Segment 23] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 24] Training Time = 1.30 sec
# [Segment 24] GPU Memory Start = 1393.00 MB
# [Segment 24] GPU Memory End   = 1393.30 MB
# [Segment 24] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 25] Training Time = 1.44 sec
# [Segment 25] GPU Memory Start = 1393.30 MB
# [Segment 25] GPU Memory End   = 1393.59 MB
# [Segment 25] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 26] Training Time = 1.22 sec
# [Segment 26] GPU Memory Start = 1393.59 MB
# [Segment 26] GPU Memory End   = 1393.89 MB
# [Segment 26] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 27] Training Time = 1.23 sec
# [Segment 27] GPU Memory Start = 1393.89 MB
# [Segment 27] GPU Memory End   = 1394.18 MB
# [Segment 27] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 28] Training Time = 1.47 sec
# [Segment 28] GPU Memory Start = 1394.18 MB
# [Segment 28] GPU Memory End   = 1394.47 MB
# [Segment 28] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 29] Training Time = 1.99 sec
# [Segment 29] GPU Memory Start = 1394.47 MB
# [Segment 29] GPU Memory End   = 1394.77 MB
# [Segment 29] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 30] Training Time = 2.46 sec
# [Segment 30] GPU Memory Start = 1394.77 MB
# [Segment 30] GPU Memory End   = 1392.12 MB
# [Segment 30] GPU Peak Memory  = 1394.77 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 31] Training Time = 2.36 sec
# [Segment 31] GPU Memory Start = 1392.12 MB
# [Segment 31] GPU Memory End   = 1392.42 MB
# [Segment 31] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 32] Training Time = 1.30 sec
# [Segment 32] GPU Memory Start = 1392.42 MB
# [Segment 32] GPU Memory End   = 1392.71 MB
# [Segment 32] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 33] Training Time = 1.31 sec
# [Segment 33] GPU Memory Start = 1392.71 MB
# [Segment 33] GPU Memory End   = 1393.00 MB
# [Segment 33] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 34] Training Time = 1.40 sec
# [Segment 34] GPU Memory Start = 1393.00 MB
# [Segment 34] GPU Memory End   = 1393.30 MB
# [Segment 34] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 35] Training Time = 1.89 sec
# [Segment 35] GPU Memory Start = 1393.30 MB
# [Segment 35] GPU Memory End   = 1393.59 MB
# [Segment 35] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 36] Training Time = 2.36 sec
# [Segment 36] GPU Memory Start = 1393.59 MB
# [Segment 36] GPU Memory End   = 1393.89 MB
# [Segment 36] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 37] Training Time = 1.22 sec
# [Segment 37] GPU Memory Start = 1393.89 MB
# [Segment 37] GPU Memory End   = 1394.18 MB
# [Segment 37] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 38] Training Time = 2.40 sec
# [Segment 38] GPU Memory Start = 1394.18 MB
# [Segment 38] GPU Memory End   = 1394.47 MB
# [Segment 38] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 39] Training Time = 1.95 sec
# [Segment 39] GPU Memory Start = 1394.47 MB
# [Segment 39] GPU Memory End   = 1394.77 MB
# [Segment 39] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 40] Training Time = 1.56 sec
# [Segment 40] GPU Memory Start = 1394.77 MB
# [Segment 40] GPU Memory End   = 1392.12 MB
# [Segment 40] GPU Peak Memory  = 1394.77 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 41] Training Time = 1.32 sec
# [Segment 41] GPU Memory Start = 1392.12 MB
# [Segment 41] GPU Memory End   = 1392.42 MB
# [Segment 41] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 42] Training Time = 2.36 sec
# [Segment 42] GPU Memory Start = 1392.42 MB
# [Segment 42] GPU Memory End   = 1392.71 MB
# [Segment 42] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 43] Training Time = 1.37 sec
# [Segment 43] GPU Memory Start = 1392.71 MB
# [Segment 43] GPU Memory End   = 1393.00 MB
# [Segment 43] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 44] Training Time = 1.44 sec
# [Segment 44] GPU Memory Start = 1393.00 MB
# [Segment 44] GPU Memory End   = 1393.30 MB
# [Segment 44] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 45] Training Time = 2.32 sec
# [Segment 45] GPU Memory Start = 1393.30 MB
# [Segment 45] GPU Memory End   = 1393.59 MB
# [Segment 45] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 46] Training Time = 1.71 sec
# [Segment 46] GPU Memory Start = 1393.59 MB
# [Segment 46] GPU Memory End   = 1393.89 MB
# [Segment 46] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 47] Training Time = 1.90 sec
# [Segment 47] GPU Memory Start = 1393.89 MB
# [Segment 47] GPU Memory End   = 1394.18 MB
# [Segment 47] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 48] Training Time = 2.31 sec
# [Segment 48] GPU Memory Start = 1394.18 MB
# [Segment 48] GPU Memory End   = 1394.47 MB
# [Segment 48] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 49] Training Time = 1.26 sec
# [Segment 49] GPU Memory Start = 1394.47 MB
# [Segment 49] GPU Memory End   = 1394.77 MB
# [Segment 49] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 50] Training Time = 2.21 sec
# [Segment 50] GPU Memory Start = 1394.77 MB
# [Segment 50] GPU Memory End   = 1392.12 MB
# [Segment 50] GPU Peak Memory  = 1394.77 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 51] Training Time = 2.30 sec
# [Segment 51] GPU Memory Start = 1392.12 MB
# [Segment 51] GPU Memory End   = 1392.42 MB
# [Segment 51] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 52] Training Time = 1.67 sec
# [Segment 52] GPU Memory Start = 1392.42 MB
# [Segment 52] GPU Memory End   = 1392.71 MB
# [Segment 52] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 53] Training Time = 1.30 sec
# [Segment 53] GPU Memory Start = 1392.71 MB
# [Segment 53] GPU Memory End   = 1393.00 MB
# [Segment 53] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 54] Training Time = 2.19 sec
# [Segment 54] GPU Memory Start = 1393.00 MB
# [Segment 54] GPU Memory End   = 1393.30 MB
# [Segment 54] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 55] Training Time = 1.29 sec
# [Segment 55] GPU Memory Start = 1393.30 MB
# [Segment 55] GPU Memory End   = 1393.59 MB
# [Segment 55] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 56] Training Time = 1.28 sec
# [Segment 56] GPU Memory Start = 1393.59 MB
# [Segment 56] GPU Memory End   = 1393.89 MB
# [Segment 56] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 57] Training Time = 1.80 sec
# [Segment 57] GPU Memory Start = 1393.89 MB
# [Segment 57] GPU Memory End   = 1394.18 MB
# [Segment 57] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 58] Training Time = 1.34 sec
# [Segment 58] GPU Memory Start = 1394.18 MB
# [Segment 58] GPU Memory End   = 1394.47 MB
# [Segment 58] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 59] Training Time = 1.33 sec
# [Segment 59] GPU Memory Start = 1394.47 MB
# [Segment 59] GPU Memory End   = 1394.77 MB
# [Segment 59] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 60] Training Time = 2.20 sec
# [Segment 60] GPU Memory Start = 1394.77 MB
# [Segment 60] GPU Memory End   = 1392.12 MB
# [Segment 60] GPU Peak Memory  = 1394.77 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 61] Training Time = 1.27 sec
# [Segment 61] GPU Memory Start = 1392.12 MB
# [Segment 61] GPU Memory End   = 1392.42 MB
# [Segment 61] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 62] Training Time = 2.34 sec
# [Segment 62] GPU Memory Start = 1392.42 MB
# [Segment 62] GPU Memory End   = 1392.71 MB
# [Segment 62] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 63] Training Time = 1.50 sec
# [Segment 63] GPU Memory Start = 1392.71 MB
# [Segment 63] GPU Memory End   = 1393.00 MB
# [Segment 63] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 64] Training Time = 1.74 sec
# [Segment 64] GPU Memory Start = 1393.00 MB
# [Segment 64] GPU Memory End   = 1393.30 MB
# [Segment 64] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336,
    pred_len         = 192,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ER_E{epo}_1E/",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=8, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=8, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 0] Training Time = 2.36 sec
# [Segment 0] GPU Memory Start = 1392.12 MB
# [Segment 0] GPU Memory End   = 1392.12 MB
# [Segment 0] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 1] Training Time = 2.09 sec
# [Segment 1] GPU Memory Start = 1392.12 MB
# [Segment 1] GPU Memory End   = 1392.42 MB
# [Segment 1] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 2] Training Time = 1.71 sec
# [Segment 2] GPU Memory Start = 1392.42 MB
# [Segment 2] GPU Memory End   = 1392.71 MB
# [Segment 2] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 3] Training Time = 2.40 sec
# [Segment 3] GPU Memory Start = 1392.71 MB
# [Segment 3] GPU Memory End   = 1393.00 MB
# [Segment 3] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 4] Training Time = 2.41 sec
# [Segment 4] GPU Memory Start = 1393.00 MB
# [Segment 4] GPU Memory End   = 1393.30 MB
# [Segment 4] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 5] Training Time = 2.18 sec
# [Segment 5] GPU Memory Start = 1393.30 MB
# [Segment 5] GPU Memory End   = 1393.59 MB
# [Segment 5] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 6] Training Time = 1.26 sec
# [Segment 6] GPU Memory Start = 1392.12 MB
# [Segment 6] GPU Memory End   = 1392.42 MB
# [Segment 6] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 7] Training Time = 2.18 sec
# [Segment 7] GPU Memory Start = 1392.42 MB
# [Segment 7] GPU Memory End   = 1392.71 MB
# [Segment 7] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 8] Training Time = 2.20 sec
# [Segment 8] GPU Memory Start = 1392.71 MB
# [Segment 8] GPU Memory End   = 1393.00 MB
# [Segment 8] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 9] Training Time = 1.25 sec
# [Segment 9] GPU Memory Start = 1393.00 MB
# [Segment 9] GPU Memory End   = 1393.30 MB
# [Segment 9] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 10] Training Time = 1.67 sec
# [Segment 10] GPU Memory Start = 1393.30 MB
# [Segment 10] GPU Memory End   = 1393.59 MB
# [Segment 10] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 11] Training Time = 1.23 sec
# [Segment 11] GPU Memory Start = 1393.59 MB
# [Segment 11] GPU Memory End   = 1393.89 MB
# [Segment 11] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 12] Training Time = 1.39 sec
# [Segment 12] GPU Memory Start = 1393.89 MB
# [Segment 12] GPU Memory End   = 1394.18 MB
# [Segment 12] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 13] Training Time = 1.43 sec
# [Segment 13] GPU Memory Start = 1394.18 MB
# [Segment 13] GPU Memory End   = 1394.47 MB
# [Segment 13] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 14] Training Time = 1.80 sec
# [Segment 14] GPU Memory Start = 1394.47 MB
# [Segment 14] GPU Memory End   = 1394.77 MB
# [Segment 14] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 15] Training Time = 2.14 sec
# [Segment 15] GPU Memory Start = 1394.77 MB
# [Segment 15] GPU Memory End   = 1395.06 MB
# [Segment 15] GPU Peak Memory  = 1396.09 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 16] Training Time = 2.29 sec
# [Segment 16] GPU Memory Start = 1392.12 MB
# [Segment 16] GPU Memory End   = 1392.42 MB
# [Segment 16] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 17] Training Time = 1.34 sec
# [Segment 17] GPU Memory Start = 1392.42 MB
# [Segment 17] GPU Memory End   = 1392.71 MB
# [Segment 17] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 18] Training Time = 1.30 sec
# [Segment 18] GPU Memory Start = 1392.71 MB
# [Segment 18] GPU Memory End   = 1393.00 MB
# [Segment 18] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 19] Training Time = 1.71 sec
# [Segment 19] GPU Memory Start = 1393.00 MB
# [Segment 19] GPU Memory End   = 1393.30 MB
# [Segment 19] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 20] Training Time = 1.48 sec
# [Segment 20] GPU Memory Start = 1393.30 MB
# [Segment 20] GPU Memory End   = 1393.59 MB
# [Segment 20] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 21] Training Time = 1.33 sec
# [Segment 21] GPU Memory Start = 1393.59 MB
# [Segment 21] GPU Memory End   = 1393.89 MB
# [Segment 21] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 22] Training Time = 1.33 sec
# [Segment 22] GPU Memory Start = 1393.89 MB
# [Segment 22] GPU Memory End   = 1394.18 MB
# [Segment 22] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 23] Training Time = 1.36 sec
# [Segment 23] GPU Memory Start = 1394.18 MB
# [Segment 23] GPU Memory End   = 1394.47 MB
# [Segment 23] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 24] Training Time = 1.31 sec
# [Segment 24] GPU Memory Start = 1394.47 MB
# [Segment 24] GPU Memory End   = 1394.77 MB
# [Segment 24] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 25] Training Time = 1.68 sec
# [Segment 25] GPU Memory Start = 1394.77 MB
# [Segment 25] GPU Memory End   = 1395.06 MB
# [Segment 25] GPU Peak Memory  = 1396.09 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 26] Training Time = 1.31 sec
# [Segment 26] GPU Memory Start = 1392.12 MB
# [Segment 26] GPU Memory End   = 1392.42 MB
# [Segment 26] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 27] Training Time = 1.26 sec
# [Segment 27] GPU Memory Start = 1392.42 MB
# [Segment 27] GPU Memory End   = 1392.71 MB
# [Segment 27] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 28] Training Time = 1.22 sec
# [Segment 28] GPU Memory Start = 1392.71 MB
# [Segment 28] GPU Memory End   = 1393.00 MB
# [Segment 28] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 29] Training Time = 1.28 sec
# [Segment 29] GPU Memory Start = 1393.00 MB
# [Segment 29] GPU Memory End   = 1393.30 MB
# [Segment 29] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 30] Training Time = 2.33 sec
# [Segment 30] GPU Memory Start = 1393.30 MB
# [Segment 30] GPU Memory End   = 1393.59 MB
# [Segment 30] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 31] Training Time = 2.45 sec
# [Segment 31] GPU Memory Start = 1393.59 MB
# [Segment 31] GPU Memory End   = 1393.89 MB
# [Segment 31] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 32] Training Time = 1.30 sec
# [Segment 32] GPU Memory Start = 1393.89 MB
# [Segment 32] GPU Memory End   = 1394.18 MB
# [Segment 32] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 33] Training Time = 1.64 sec
# [Segment 33] GPU Memory Start = 1394.18 MB
# [Segment 33] GPU Memory End   = 1394.47 MB
# [Segment 33] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 34] Training Time = 2.42 sec
# [Segment 34] GPU Memory Start = 1394.47 MB
# [Segment 34] GPU Memory End   = 1394.77 MB
# [Segment 34] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 35] Training Time = 2.39 sec
# [Segment 35] GPU Memory Start = 1394.77 MB
# [Segment 35] GPU Memory End   = 1395.06 MB
# [Segment 35] GPU Peak Memory  = 1396.09 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 36] Training Time = 1.33 sec
# [Segment 36] GPU Memory Start = 1392.12 MB
# [Segment 36] GPU Memory End   = 1392.42 MB
# [Segment 36] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 37] Training Time = 2.42 sec
# [Segment 37] GPU Memory Start = 1392.42 MB
# [Segment 37] GPU Memory End   = 1392.71 MB
# [Segment 37] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 38] Training Time = 2.40 sec
# [Segment 38] GPU Memory Start = 1392.71 MB
# [Segment 38] GPU Memory End   = 1393.00 MB
# [Segment 38] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 39] Training Time = 2.04 sec
# [Segment 39] GPU Memory Start = 1393.00 MB
# [Segment 39] GPU Memory End   = 1393.30 MB
# [Segment 39] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 40] Training Time = 2.40 sec
# [Segment 40] GPU Memory Start = 1393.30 MB
# [Segment 40] GPU Memory End   = 1393.59 MB
# [Segment 40] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 41] Training Time = 2.18 sec
# [Segment 41] GPU Memory Start = 1393.59 MB
# [Segment 41] GPU Memory End   = 1393.89 MB
# [Segment 41] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 42] Training Time = 2.18 sec
# [Segment 42] GPU Memory Start = 1393.89 MB
# [Segment 42] GPU Memory End   = 1394.18 MB
# [Segment 42] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 43] Training Time = 1.32 sec
# [Segment 43] GPU Memory Start = 1394.18 MB
# [Segment 43] GPU Memory End   = 1394.47 MB
# [Segment 43] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 44] Training Time = 1.78 sec
# [Segment 44] GPU Memory Start = 1394.47 MB
# [Segment 44] GPU Memory End   = 1394.77 MB
# [Segment 44] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 45] Training Time = 1.26 sec
# [Segment 45] GPU Memory Start = 1394.77 MB
# [Segment 45] GPU Memory End   = 1395.06 MB
# [Segment 45] GPU Peak Memory  = 1396.09 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 46] Training Time = 1.25 sec
# [Segment 46] GPU Memory Start = 1392.12 MB
# [Segment 46] GPU Memory End   = 1392.42 MB
# [Segment 46] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 47] Training Time = 2.31 sec
# [Segment 47] GPU Memory Start = 1392.42 MB
# [Segment 47] GPU Memory End   = 1392.71 MB
# [Segment 47] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 48] Training Time = 1.82 sec
# [Segment 48] GPU Memory Start = 1392.71 MB
# [Segment 48] GPU Memory End   = 1393.00 MB
# [Segment 48] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 49] Training Time = 1.95 sec
# [Segment 49] GPU Memory Start = 1393.00 MB
# [Segment 49] GPU Memory End   = 1393.30 MB
# [Segment 49] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 50] Training Time = 1.56 sec
# [Segment 50] GPU Memory Start = 1393.30 MB
# [Segment 50] GPU Memory End   = 1393.59 MB
# [Segment 50] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 51] Training Time = 2.16 sec
# [Segment 51] GPU Memory Start = 1393.59 MB
# [Segment 51] GPU Memory End   = 1393.89 MB
# [Segment 51] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 52] Training Time = 1.29 sec
# [Segment 52] GPU Memory Start = 1393.89 MB
# [Segment 52] GPU Memory End   = 1394.18 MB
# [Segment 52] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 53] Training Time = 1.28 sec
# [Segment 53] GPU Memory Start = 1394.18 MB
# [Segment 53] GPU Memory End   = 1394.47 MB
# [Segment 53] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 54] Training Time = 2.04 sec
# [Segment 54] GPU Memory Start = 1394.47 MB
# [Segment 54] GPU Memory End   = 1394.77 MB
# [Segment 54] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 55] Training Time = 1.69 sec
# [Segment 55] GPU Memory Start = 1394.77 MB
# [Segment 55] GPU Memory End   = 1395.06 MB
# [Segment 55] GPU Peak Memory  = 1396.09 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 56] Training Time = 1.80 sec
# [Segment 56] GPU Memory Start = 1392.12 MB
# [Segment 56] GPU Memory End   = 1392.42 MB
# [Segment 56] GPU Peak Memory  = 1393.45 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 57] Training Time = 2.27 sec
# [Segment 57] GPU Memory Start = 1392.42 MB
# [Segment 57] GPU Memory End   = 1392.71 MB
# [Segment 57] GPU Peak Memory  = 1393.74 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 58] Training Time = 2.29 sec
# [Segment 58] GPU Memory Start = 1392.71 MB
# [Segment 58] GPU Memory End   = 1393.00 MB
# [Segment 58] GPU Peak Memory  = 1394.03 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 59] Training Time = 2.21 sec
# [Segment 59] GPU Memory Start = 1393.00 MB
# [Segment 59] GPU Memory End   = 1393.30 MB
# [Segment 59] GPU Peak Memory  = 1394.33 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 60] Training Time = 1.28 sec
# [Segment 60] GPU Memory Start = 1393.30 MB
# [Segment 60] GPU Memory End   = 1393.59 MB
# [Segment 60] GPU Peak Memory  = 1394.62 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 61] Training Time = 1.52 sec
# [Segment 61] GPU Memory Start = 1393.59 MB
# [Segment 61] GPU Memory End   = 1393.89 MB
# [Segment 61] GPU Peak Memory  = 1394.92 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 62] Training Time = 1.35 sec
# [Segment 62] GPU Memory Start = 1393.89 MB
# [Segment 62] GPU Memory End   = 1394.18 MB
# [Segment 62] GPU Peak Memory  = 1395.21 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 63] Training Time = 1.72 sec
# [Segment 63] GPU Memory Start = 1394.18 MB
# [Segment 63] GPU Memory End   = 1394.47 MB
# [Segment 63] GPU Peak Memory  = 1395.50 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0103 MB, total = 6.1318 MB
#   yb per batch = 0.0059 MB, total = 3.5039 MB
#   pv per batch = 0.0020 MB, total = 1.1680 MB
# [Segment 64] Training Time = 2.06 sec
# [Segment 64] GPU Memory Start = 1394.47 MB
# [Segment 64] GPU Memory End   = 1394.77 MB
# [Segment 64] GPU Peak Memory  = 1395.80 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ER/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ER/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ER/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 8

results2_ER_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.4155960977077484  MAE:0.5113980770111084
# ▶ seg0  mean  MSE:0.4155960977077484  MAE:0.5113980770111084
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.6466236710548401  MAE:0.6376911401748657
# ▶ seg1  mean  MSE:0.6466236710548401  MAE:0.6376911401748657
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.5414600372314453  MAE:0.588213324546814
# ▶ seg2  mean  MSE:0.5414600372314453  MAE:0.588213324546814
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.5139680504798889  MAE:0.5734182000160217
# ▶ seg3  mean  MSE:0.5139680504798889  MAE:0.5734182000160217
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.42174530029296875  MAE:0.5250840187072754
# ▶ seg4  mean  MSE:0.42174530029296875  MAE:0.5250840187072754
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.4082719087600708  MAE:0.49814295768737793
# ▶ seg5  mean  MSE:0.4082719087600708  MAE:0.49814295768737793
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.29567092657089233  MAE:0.43364426493644714
# ▶ seg6  mean  MSE:0.29567092657089233  MAE:0.43364426493644714
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.48522084951400757  MAE:0.5591111183166504
# ▶ seg7  mean  MSE:0.48522084951400757  MAE:0.5591111183166504
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.3125403821468353  MAE:0.44219303131103516
# ▶ seg8  mean  MSE:0.3125403821468353  MAE:0.44219303131103516
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.5058936476707458  MAE:0.571591854095459
# ▶ seg9  mean  MSE:0.5058936476707458  MAE:0.571591854095459
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.3879564702510834  MAE:0.49348267912864685
# ▶ seg10  mean  MSE:0.3879564702510834  MAE:0.49348267912864685
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.35618650913238525  MAE:0.47285473346710205
# ▶ seg11  mean  MSE:0.35618650913238525  MAE:0.47285473346710205
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.47635236382484436  MAE:0.553763747215271
# ▶ seg12  mean  MSE:0.47635236382484436  MAE:0.553763747215271
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.7715252637863159  MAE:0.7130177617073059
# ▶ seg13  mean  MSE:0.7715252637863159  MAE:0.7130177617073059
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.7152990102767944  MAE:0.6811434626579285
# ▶ seg14  mean  MSE:0.7152990102767944  MAE:0.6811434626579285
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.489248663187027  MAE:0.565939724445343
# ▶ seg15  mean  MSE:0.489248663187027  MAE:0.565939724445343
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.40890905261039734  MAE:0.5069330334663391
# ▶ seg16  mean  MSE:0.40890905261039734  MAE:0.5069330334663391
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.45862534642219543  MAE:0.5369506478309631
# ▶ seg17  mean  MSE:0.45862534642219543  MAE:0.5369506478309631
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.5118573307991028  MAE:0.578582227230072
# ▶ seg18  mean  MSE:0.5118573307991028  MAE:0.578582227230072
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.316182941198349  MAE:0.4491589069366455
# ▶ seg19  mean  MSE:0.316182941198349  MAE:0.4491589069366455
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.7440666556358337  MAE:0.7120898365974426
# ▶ seg20  mean  MSE:0.7440666556358337  MAE:0.7120898365974426
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.34586262702941895  MAE:0.4667588174343109
# ▶ seg21  mean  MSE:0.34586262702941895  MAE:0.4667588174343109
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.42563560605049133  MAE:0.520293653011322
# ▶ seg22  mean  MSE:0.42563560605049133  MAE:0.520293653011322
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.2724364101886749  MAE:0.4193470776081085
# ▶ seg23  mean  MSE:0.2724364101886749  MAE:0.4193470776081085
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.6866638660430908  MAE:0.679938554763794
# ▶ seg24  mean  MSE:0.6866638660430908  MAE:0.679938554763794
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.39726510643959045  MAE:0.5011553168296814
# ▶ seg25  mean  MSE:0.39726510643959045  MAE:0.5011553168296814
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.2991398572921753  MAE:0.4366297125816345
# ▶ seg26  mean  MSE:0.2991398572921753  MAE:0.4366297125816345
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.6252885460853577  MAE:0.6433845162391663
# ▶ seg27  mean  MSE:0.6252885460853577  MAE:0.6433845162391663
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.35302987694740295  MAE:0.4746014475822449
# ▶ seg28  mean  MSE:0.35302987694740295  MAE:0.4746014475822449
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.39556193351745605  MAE:0.4948415458202362
# ▶ seg29  mean  MSE:0.39556193351745605  MAE:0.4948415458202362
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.6591192483901978  MAE:0.6656100153923035
# ▶ seg30  mean  MSE:0.6591192483901978  MAE:0.6656100153923035
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.48831528425216675  MAE:0.566594123840332
# ▶ seg31  mean  MSE:0.48831528425216675  MAE:0.566594123840332
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.303918719291687  MAE:0.4381226897239685
# ▶ seg32  mean  MSE:0.303918719291687  MAE:0.4381226897239685
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.39684319496154785  MAE:0.49796995520591736
# ▶ seg33  mean  MSE:0.39684319496154785  MAE:0.49796995520591736
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.6514270901679993  MAE:0.6592495441436768
# ▶ seg34  mean  MSE:0.6514270901679993  MAE:0.6592495441436768
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.4892875850200653  MAE:0.5653717517852783
# ▶ seg35  mean  MSE:0.4892875850200653  MAE:0.5653717517852783
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.4192737638950348  MAE:0.5208540558815002
# ▶ seg36  mean  MSE:0.4192737638950348  MAE:0.5208540558815002
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.2971976697444916  MAE:0.42941486835479736
# ▶ seg37  mean  MSE:0.2971976697444916  MAE:0.42941486835479736
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.4029097557067871  MAE:0.5140287280082703
# ▶ seg38  mean  MSE:0.4029097557067871  MAE:0.5140287280082703
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.38511165976524353  MAE:0.4988158345222473
# ▶ seg39  mean  MSE:0.38511165976524353  MAE:0.4988158345222473
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.2949688732624054  MAE:0.43319079279899597
# ▶ seg40  mean  MSE:0.2949688732624054  MAE:0.43319079279899597
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.4950534999370575  MAE:0.5730705857276917
# ▶ seg41  mean  MSE:0.4950534999370575  MAE:0.5730705857276917
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.45161283016204834  MAE:0.5376795530319214
# ▶ seg42  mean  MSE:0.45161283016204834  MAE:0.5376795530319214
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.3378671705722809  MAE:0.45976555347442627
# ▶ seg43  mean  MSE:0.3378671705722809  MAE:0.45976555347442627
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.7008513808250427  MAE:0.7000527381896973
# ▶ seg44  mean  MSE:0.7008513808250427  MAE:0.7000527381896973
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.32876652479171753  MAE:0.4588965177536011
# ▶ seg45  mean  MSE:0.32876652479171753  MAE:0.4588965177536011
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.33144447207450867  MAE:0.46431827545166016
# ▶ seg46  mean  MSE:0.33144447207450867  MAE:0.46431827545166016
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.33607617020606995  MAE:0.46404632925987244
# ▶ seg47  mean  MSE:0.33607617020606995  MAE:0.46404632925987244
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.4294089376926422  MAE:0.5269615650177002
# ▶ seg48  mean  MSE:0.4294089376926422  MAE:0.5269615650177002
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.4765855669975281  MAE:0.5535526275634766
# ▶ seg49  mean  MSE:0.4765855669975281  MAE:0.5535526275634766
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.6383911967277527  MAE:0.6401228308677673
# ▶ seg50  mean  MSE:0.6383911967277527  MAE:0.6401228308677673
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.49530962109565735  MAE:0.5667619109153748
# ▶ seg51  mean  MSE:0.49530962109565735  MAE:0.5667619109153748
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.48624563217163086  MAE:0.5579712986946106
# ▶ seg52  mean  MSE:0.48624563217163086  MAE:0.5579712986946106
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.45584794878959656  MAE:0.542350172996521
# ▶ seg53  mean  MSE:0.45584794878959656  MAE:0.542350172996521
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.4888279139995575  MAE:0.5625883340835571
# ▶ seg54  mean  MSE:0.4888279139995575  MAE:0.5625883340835571
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.41261520981788635  MAE:0.5179169178009033
# ▶ seg55  mean  MSE:0.41261520981788635  MAE:0.5179169178009033
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.49638834595680237  MAE:0.5644168257713318
# ▶ seg56  mean  MSE:0.49638834595680237  MAE:0.5644168257713318
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.28759700059890747  MAE:0.4270094037055969
# ▶ seg57  mean  MSE:0.28759700059890747  MAE:0.4270094037055969
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.3123255968093872  MAE:0.4480070173740387
# ▶ seg58  mean  MSE:0.3123255968093872  MAE:0.4480070173740387
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.5718509554862976  MAE:0.5971850752830505
# ▶ seg59  mean  MSE:0.5718509554862976  MAE:0.5971850752830505
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.4844532907009125  MAE:0.5662145018577576
# ▶ seg60  mean  MSE:0.4844532907009125  MAE:0.5662145018577576
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.3421921133995056  MAE:0.47461968660354614
# ▶ seg61  mean  MSE:0.3421921133995056  MAE:0.47461968660354614
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.2823691666126251  MAE:0.4245637059211731
# ▶ seg62  mean  MSE:0.2823691666126251  MAE:0.4245637059211731
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.4075443744659424  MAE:0.5064603090286255
# ▶ seg63  mean  MSE:0.4075443744659424  MAE:0.5064603090286255
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.41461217403411865  MAE:0.5226171016693115
# ▶ seg64  mean  MSE:0.41461217403411865  MAE:0.5226171016693115
#
# seg10 ch0 MSE : 0.38795647

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_E1_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 8

results2_ER_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.47711676359176636  MAE:0.5513394474983215
# ▶ seg0  mean  MSE:0.47711676359176636  MAE:0.5513394474983215
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.31570473313331604  MAE:0.4513202905654907
# ▶ seg1  mean  MSE:0.31570473313331604  MAE:0.4513202905654907
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.3393293023109436  MAE:0.46500685811042786
# ▶ seg2  mean  MSE:0.3393293023109436  MAE:0.46500685811042786
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.5488174557685852  MAE:0.6029134392738342
# ▶ seg3  mean  MSE:0.5488174557685852  MAE:0.6029134392738342
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.49644726514816284  MAE:0.5588281154632568
# ▶ seg4  mean  MSE:0.49644726514816284  MAE:0.5588281154632568
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.5171853303909302  MAE:0.5816369652748108
# ▶ seg5  mean  MSE:0.5171853303909302  MAE:0.5816369652748108
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.4813617169857025  MAE:0.5688573718070984
# ▶ seg6  mean  MSE:0.4813617169857025  MAE:0.5688573718070984
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.40124961733818054  MAE:0.5049193501472473
# ▶ seg7  mean  MSE:0.40124961733818054  MAE:0.5049193501472473
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.5020685195922852  MAE:0.5699543356895447
# ▶ seg8  mean  MSE:0.5020685195922852  MAE:0.5699543356895447
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.4727914333343506  MAE:0.5598978400230408
# ▶ seg9  mean  MSE:0.4727914333343506  MAE:0.5598978400230408
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.4112789034843445  MAE:0.5088614225387573
# ▶ seg10  mean  MSE:0.4112789034843445  MAE:0.5088614225387573
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.35389649868011475  MAE:0.47243088483810425
# ▶ seg11  mean  MSE:0.35389649868011475  MAE:0.47243088483810425
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.4919274151325226  MAE:0.5702160000801086
# ▶ seg12  mean  MSE:0.4919274151325226  MAE:0.5702160000801086
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.4282584488391876  MAE:0.5233907103538513
# ▶ seg13  mean  MSE:0.4282584488391876  MAE:0.5233907103538513
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.4537099003791809  MAE:0.5395461916923523
# ▶ seg14  mean  MSE:0.4537099003791809  MAE:0.5395461916923523
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.4210898280143738  MAE:0.5145339965820312
# ▶ seg15  mean  MSE:0.4210898280143738  MAE:0.5145339965820312
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.44360509514808655  MAE:0.52826988697052
# ▶ seg16  mean  MSE:0.44360509514808655  MAE:0.52826988697052
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.5835978388786316  MAE:0.6208377480506897
# ▶ seg17  mean  MSE:0.5835978388786316  MAE:0.6208377480506897
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.31444600224494934  MAE:0.44644895195961
# ▶ seg18  mean  MSE:0.31444600224494934  MAE:0.44644895195961
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.35736480355262756  MAE:0.47607865929603577
# ▶ seg19  mean  MSE:0.35736480355262756  MAE:0.47607865929603577
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.6071629524230957  MAE:0.6314877271652222
# ▶ seg20  mean  MSE:0.6071629524230957  MAE:0.6314877271652222
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.7527503371238708  MAE:0.6935434341430664
# ▶ seg21  mean  MSE:0.7527503371238708  MAE:0.6935434341430664
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.4158899188041687  MAE:0.516534149646759
# ▶ seg22  mean  MSE:0.4158899188041687  MAE:0.516534149646759
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.4632123112678528  MAE:0.5437694191932678
# ▶ seg23  mean  MSE:0.4632123112678528  MAE:0.5437694191932678
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.2940284013748169  MAE:0.4349431097507477
# ▶ seg24  mean  MSE:0.2940284013748169  MAE:0.4349431097507477
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.36913734674453735  MAE:0.4874376654624939
# ▶ seg25  mean  MSE:0.36913734674453735  MAE:0.4874376654624939
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.41006240248680115  MAE:0.5110592246055603
# ▶ seg26  mean  MSE:0.41006240248680115  MAE:0.5110592246055603
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.6713545918464661  MAE:0.65799480676651
# ▶ seg27  mean  MSE:0.6713545918464661  MAE:0.65799480676651
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.4758424758911133  MAE:0.5582122802734375
# ▶ seg28  mean  MSE:0.4758424758911133  MAE:0.5582122802734375
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.36421918869018555  MAE:0.4846334457397461
# ▶ seg29  mean  MSE:0.36421918869018555  MAE:0.4846334457397461
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.5187121033668518  MAE:0.5740552544593811
# ▶ seg30  mean  MSE:0.5187121033668518  MAE:0.5740552544593811
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.3615601062774658  MAE:0.4807758927345276
# ▶ seg31  mean  MSE:0.3615601062774658  MAE:0.4807758927345276
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.46023303270339966  MAE:0.5386215448379517
# ▶ seg32  mean  MSE:0.46023303270339966  MAE:0.5386215448379517
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.273318350315094  MAE:0.40661463141441345
# ▶ seg33  mean  MSE:0.273318350315094  MAE:0.40661463141441345
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.8338601589202881  MAE:0.773387610912323
# ▶ seg34  mean  MSE:0.8338601589202881  MAE:0.773387610912323
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.2856176197528839  MAE:0.42270341515541077
# ▶ seg35  mean  MSE:0.2856176197528839  MAE:0.42270341515541077
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.5104965567588806  MAE:0.5754812359809875
# ▶ seg36  mean  MSE:0.5104965567588806  MAE:0.5754812359809875
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.5643991827964783  MAE:0.6146483421325684
# ▶ seg37  mean  MSE:0.5643991827964783  MAE:0.6146483421325684
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.5276979207992554  MAE:0.5891199707984924
# ▶ seg38  mean  MSE:0.5276979207992554  MAE:0.5891199707984924
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.6075056195259094  MAE:0.6342407464981079
# ▶ seg39  mean  MSE:0.6075056195259094  MAE:0.6342407464981079
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.5914753675460815  MAE:0.6078488826751709
# ▶ seg40  mean  MSE:0.5914753675460815  MAE:0.6078488826751709
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.3832349181175232  MAE:0.4991815984249115
# ▶ seg41  mean  MSE:0.3832349181175232  MAE:0.4991815984249115
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.447419673204422  MAE:0.5359594225883484
# ▶ seg42  mean  MSE:0.447419673204422  MAE:0.5359594225883484
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.5398507714271545  MAE:0.5897918939590454
# ▶ seg43  mean  MSE:0.5398507714271545  MAE:0.5897918939590454
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.4135271906852722  MAE:0.5154827833175659
# ▶ seg44  mean  MSE:0.4135271906852722  MAE:0.5154827833175659
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.43591204285621643  MAE:0.5265246629714966
# ▶ seg45  mean  MSE:0.43591204285621643  MAE:0.5265246629714966
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.2802421748638153  MAE:0.4220291078090668
# ▶ seg46  mean  MSE:0.2802421748638153  MAE:0.4220291078090668
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.43115848302841187  MAE:0.5175871849060059
# ▶ seg47  mean  MSE:0.43115848302841187  MAE:0.5175871849060059
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.37129101157188416  MAE:0.48646804690361023
# ▶ seg48  mean  MSE:0.37129101157188416  MAE:0.48646804690361023
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.9117519855499268  MAE:0.794325053691864
# ▶ seg49  mean  MSE:0.9117519855499268  MAE:0.794325053691864
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.3756886422634125  MAE:0.48660269379615784
# ▶ seg50  mean  MSE:0.3756886422634125  MAE:0.48660269379615784
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.4653431177139282  MAE:0.5447798371315002
# ▶ seg51  mean  MSE:0.4653431177139282  MAE:0.5447798371315002
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.4131552278995514  MAE:0.5102318525314331
# ▶ seg52  mean  MSE:0.4131552278995514  MAE:0.5102318525314331
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.5483196973800659  MAE:0.5941043496131897
# ▶ seg53  mean  MSE:0.5483196973800659  MAE:0.5941043496131897
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.42002251744270325  MAE:0.5098128914833069
# ▶ seg54  mean  MSE:0.42002251744270325  MAE:0.5098128914833069
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.3871806859970093  MAE:0.49340635538101196
# ▶ seg55  mean  MSE:0.3871806859970093  MAE:0.49340635538101196
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.41230738162994385  MAE:0.5152706503868103
# ▶ seg56  mean  MSE:0.41230738162994385  MAE:0.5152706503868103
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.44734978675842285  MAE:0.529839277267456
# ▶ seg57  mean  MSE:0.44734978675842285  MAE:0.529839277267456
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.3811110258102417  MAE:0.4961026906967163
# ▶ seg58  mean  MSE:0.3811110258102417  MAE:0.4961026906967163
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.2758254110813141  MAE:0.4161703288555145
# ▶ seg59  mean  MSE:0.2758254110813141  MAE:0.4161703288555145
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.545470118522644  MAE:0.6006529927253723
# ▶ seg60  mean  MSE:0.545470118522644  MAE:0.6006529927253723
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.27299267053604126  MAE:0.4112606644630432
# ▶ seg61  mean  MSE:0.27299267053604126  MAE:0.4112606644630432
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.30739477276802063  MAE:0.43937593698501587
# ▶ seg62  mean  MSE:0.30739477276802063  MAE:0.43937593698501587
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.6974908113479614  MAE:0.6769987940788269
# ▶ seg63  mean  MSE:0.6974908113479614  MAE:0.6769987940788269
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.28354397416114807  MAE:0.4266042113304138
# ▶ seg64  mean  MSE:0.28354397416114807  MAE:0.4266042113304138
#
# seg10 ch0 MSE : 0.4112789

# %% [markdown]
# # 2nd Inference for Test Set

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 192
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_EES_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 8

results2_ER_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.23596008121967316  MAE:0.3792087435722351
# ▶ seg0  mean  MSE:0.23596008121967316  MAE:0.3792087435722351
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.4489486515522003  MAE:0.507975161075592
# ▶ seg1  mean  MSE:0.4489486515522003  MAE:0.507975161075592
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.29956507682800293  MAE:0.422796368598938
# ▶ seg2  mean  MSE:0.29956507682800293  MAE:0.422796368598938
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.3014984726905823  MAE:0.43512260913848877
# ▶ seg3  mean  MSE:0.3014984726905823  MAE:0.43512260913848877
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.2594867944717407  MAE:0.4207799434661865
# ▶ seg4  mean  MSE:0.2594867944717407  MAE:0.4207799434661865
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.3086947202682495  MAE:0.431951642036438
# ▶ seg5  mean  MSE:0.3086947202682495  MAE:0.431951642036438
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.20853003859519958  MAE:0.36513403058052063
# ▶ seg6  mean  MSE:0.20853003859519958  MAE:0.36513403058052063
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.2938389182090759  MAE:0.42697545886039734
# ▶ seg7  mean  MSE:0.2938389182090759  MAE:0.42697545886039734
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.20451389253139496  MAE:0.3651595115661621
# ▶ seg8  mean  MSE:0.20451389253139496  MAE:0.3651595115661621
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.34599733352661133  MAE:0.47168487310409546
# ▶ seg9  mean  MSE:0.34599733352661133  MAE:0.47168487310409546
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.2201848030090332  MAE:0.3717688322067261
# ▶ seg10  mean  MSE:0.2201848030090332  MAE:0.3717688322067261
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.21725085377693176  MAE:0.3731442987918854
# ▶ seg11  mean  MSE:0.21725085377693176  MAE:0.3731442987918854
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.2998027205467224  MAE:0.42687860131263733
# ▶ seg12  mean  MSE:0.2998027205467224  MAE:0.42687860131263733
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.5314524173736572  MAE:0.5851597189903259
# ▶ seg13  mean  MSE:0.5314524173736572  MAE:0.5851597189903259
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.5007643699645996  MAE:0.5515817999839783
# ▶ seg14  mean  MSE:0.5007643699645996  MAE:0.5515817999839783
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.2937476634979248  MAE:0.44478747248649597
# ▶ seg15  mean  MSE:0.2937476634979248  MAE:0.44478747248649597
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.2556484639644623  MAE:0.3985850214958191
# ▶ seg16  mean  MSE:0.2556484639644623  MAE:0.3985850214958191
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.27341097593307495  MAE:0.4199363887310028
# ▶ seg17  mean  MSE:0.27341097593307495  MAE:0.4199363887310028
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.3310110867023468  MAE:0.47240811586380005
# ▶ seg18  mean  MSE:0.3310110867023468  MAE:0.47240811586380005
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.20307953655719757  MAE:0.3633482754230499
# ▶ seg19  mean  MSE:0.20307953655719757  MAE:0.3633482754230499
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.44627901911735535  MAE:0.5345160365104675
# ▶ seg20  mean  MSE:0.44627901911735535  MAE:0.5345160365104675
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.21885669231414795  MAE:0.3734663426876068
# ▶ seg21  mean  MSE:0.21885669231414795  MAE:0.3734663426876068
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.24120324850082397  MAE:0.39930593967437744
# ▶ seg22  mean  MSE:0.24120324850082397  MAE:0.39930593967437744
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.27476072311401367  MAE:0.39352142810821533
# ▶ seg23  mean  MSE:0.27476072311401367  MAE:0.39352142810821533
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.46833837032318115  MAE:0.5485549569129944
# ▶ seg24  mean  MSE:0.46833837032318115  MAE:0.5485549569129944
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.23896797001361847  MAE:0.38237881660461426
# ▶ seg25  mean  MSE:0.23896797001361847  MAE:0.38237881660461426
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.19997233152389526  MAE:0.35545316338539124
# ▶ seg26  mean  MSE:0.19997233152389526  MAE:0.35545316338539124
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.354183554649353  MAE:0.4745115041732788
# ▶ seg27  mean  MSE:0.354183554649353  MAE:0.4745115041732788
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.2064778357744217  MAE:0.36443209648132324
# ▶ seg28  mean  MSE:0.2064778357744217  MAE:0.36443209648132324
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.24184764921665192  MAE:0.3839472532272339
# ▶ seg29  mean  MSE:0.24184764921665192  MAE:0.3839472532272339
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.4039696156978607  MAE:0.5018129944801331
# ▶ seg30  mean  MSE:0.4039696156978607  MAE:0.5018129944801331
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.3229309320449829  MAE:0.46845296025276184
# ▶ seg31  mean  MSE:0.3229309320449829  MAE:0.46845296025276184
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.20153477787971497  MAE:0.3580460250377655
# ▶ seg32  mean  MSE:0.20153477787971497  MAE:0.3580460250377655
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.22466033697128296  MAE:0.37802770733833313
# ▶ seg33  mean  MSE:0.22466033697128296  MAE:0.37802770733833313
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.4656004309654236  MAE:0.5588269233703613
# ▶ seg34  mean  MSE:0.4656004309654236  MAE:0.5588269233703613
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.2993912398815155  MAE:0.43220797181129456
# ▶ seg35  mean  MSE:0.2993912398815155  MAE:0.43220797181129456
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.22790740430355072  MAE:0.38014471530914307
# ▶ seg36  mean  MSE:0.22790740430355072  MAE:0.38014471530914307
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.22782480716705322  MAE:0.37278497219085693
# ▶ seg37  mean  MSE:0.22782480716705322  MAE:0.37278497219085693
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.248650923371315  MAE:0.41240420937538147
# ▶ seg38  mean  MSE:0.248650923371315  MAE:0.41240420937538147
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.21242724359035492  MAE:0.3680991232395172
# ▶ seg39  mean  MSE:0.21242724359035492  MAE:0.3680991232395172
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.2103285789489746  MAE:0.3655760884284973
# ▶ seg40  mean  MSE:0.2103285789489746  MAE:0.3655760884284973
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.27715280652046204  MAE:0.4234900176525116
# ▶ seg41  mean  MSE:0.27715280652046204  MAE:0.4234900176525116
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.2822900712490082  MAE:0.4213816523551941
# ▶ seg42  mean  MSE:0.2822900712490082  MAE:0.4213816523551941
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.213309645652771  MAE:0.36894625425338745
# ▶ seg43  mean  MSE:0.213309645652771  MAE:0.36894625425338745
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.449699342250824  MAE:0.5591490268707275
# ▶ seg44  mean  MSE:0.449699342250824  MAE:0.5591490268707275
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.2088022083044052  MAE:0.3694685697555542
# ▶ seg45  mean  MSE:0.2088022083044052  MAE:0.3694685697555542
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.2128761261701584  MAE:0.3768460750579834
# ▶ seg46  mean  MSE:0.2128761261701584  MAE:0.3768460750579834
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.2096436768770218  MAE:0.36887937784194946
# ▶ seg47  mean  MSE:0.2096436768770218  MAE:0.36887937784194946
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.23350666463375092  MAE:0.38638022541999817
# ▶ seg48  mean  MSE:0.23350666463375092  MAE:0.38638022541999817
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.2518230378627777  MAE:0.3969055712223053
# ▶ seg49  mean  MSE:0.2518230378627777  MAE:0.3969055712223053
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.3752959072589874  MAE:0.46602824330329895
# ▶ seg50  mean  MSE:0.3752959072589874  MAE:0.46602824330329895
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.3438267707824707  MAE:0.4747113287448883
# ▶ seg51  mean  MSE:0.3438267707824707  MAE:0.4747113287448883
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.27463674545288086  MAE:0.41096222400665283
# ▶ seg52  mean  MSE:0.27463674545288086  MAE:0.41096222400665283
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.2721964120864868  MAE:0.40695348381996155
# ▶ seg53  mean  MSE:0.2721964120864868  MAE:0.40695348381996155
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.3136391341686249  MAE:0.4605202376842499
# ▶ seg54  mean  MSE:0.3136391341686249  MAE:0.4605202376842499
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.2365199774503708  MAE:0.39510008692741394
# ▶ seg55  mean  MSE:0.2365199774503708  MAE:0.39510008692741394
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.32031774520874023  MAE:0.4529195725917816
# ▶ seg56  mean  MSE:0.32031774520874023  MAE:0.4529195725917816
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.2191711813211441  MAE:0.36895257234573364
# ▶ seg57  mean  MSE:0.2191711813211441  MAE:0.36895257234573364
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.19863955676555634  MAE:0.35767507553100586
# ▶ seg58  mean  MSE:0.19863955676555634  MAE:0.35767507553100586
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.3912878632545471  MAE:0.48424839973449707
# ▶ seg59  mean  MSE:0.3912878632545471  MAE:0.48424839973449707
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.2879660129547119  MAE:0.4314518868923187
# ▶ seg60  mean  MSE:0.2879660129547119  MAE:0.4314518868923187
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.2529182732105255  MAE:0.4046321213245392
# ▶ seg61  mean  MSE:0.2529182732105255  MAE:0.4046321213245392
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.23600740730762482  MAE:0.3708128035068512
# ▶ seg62  mean  MSE:0.23600740730762482  MAE:0.3708128035068512
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.24216124415397644  MAE:0.39322301745414734
# ▶ seg63  mean  MSE:0.24216124415397644  MAE:0.39322301745414734
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.25098511576652527  MAE:0.4004574418067932
# ▶ seg64  mean  MSE:0.25098511576652527  MAE:0.4004574418067932
#
# seg10 ch0 MSE : 0.2201848

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 192
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.0005,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ER_E1_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 8

results2_ER_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ER_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ER_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.27518710494041443  MAE:0.41235512495040894
# ▶ seg0  mean  MSE:0.27518710494041443  MAE:0.41235512495040894
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.20378872752189636  MAE:0.3656773567199707
# ▶ seg1  mean  MSE:0.20378872752189636  MAE:0.3656773567199707
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.21841512620449066  MAE:0.3777309060096741
# ▶ seg2  mean  MSE:0.21841512620449066  MAE:0.3777309060096741
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.34179702401161194  MAE:0.46566691994667053
# ▶ seg3  mean  MSE:0.34179702401161194  MAE:0.46566691994667053
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.30141863226890564  MAE:0.4344117045402527
# ▶ seg4  mean  MSE:0.30141863226890564  MAE:0.4344117045402527
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.3213688135147095  MAE:0.44602394104003906
# ▶ seg5  mean  MSE:0.3213688135147095  MAE:0.44602394104003906
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.31632882356643677  MAE:0.4659408926963806
# ▶ seg6  mean  MSE:0.31632882356643677  MAE:0.4659408926963806
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.23503226041793823  MAE:0.3861876428127289
# ▶ seg7  mean  MSE:0.23503226041793823  MAE:0.3861876428127289
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.31050583720207214  MAE:0.43861299753189087
# ▶ seg8  mean  MSE:0.31050583720207214  MAE:0.43861299753189087
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.2770392596721649  MAE:0.42782288789749146
# ▶ seg9  mean  MSE:0.2770392596721649  MAE:0.42782288789749146
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.2427765130996704  MAE:0.39110755920410156
# ▶ seg10  mean  MSE:0.2427765130996704  MAE:0.39110755920410156
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.21503783762454987  MAE:0.37182939052581787
# ▶ seg11  mean  MSE:0.21503783762454987  MAE:0.37182939052581787
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.30977991223335266  MAE:0.4534444808959961
# ▶ seg12  mean  MSE:0.30977991223335266  MAE:0.4534444808959961
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.24683402478694916  MAE:0.4035034775733948
# ▶ seg13  mean  MSE:0.24683402478694916  MAE:0.4035034775733948
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.24040475487709045  MAE:0.38900163769721985
# ▶ seg14  mean  MSE:0.24040475487709045  MAE:0.38900163769721985
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.2553390860557556  MAE:0.39407792687416077
# ▶ seg15  mean  MSE:0.2553390860557556  MAE:0.39407792687416077
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.2781977951526642  MAE:0.4110669493675232
# ▶ seg16  mean  MSE:0.2781977951526642  MAE:0.4110669493675232
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.4099513590335846  MAE:0.5025697350502014
# ▶ seg17  mean  MSE:0.4099513590335846  MAE:0.5025697350502014
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.20588824152946472  MAE:0.3565049469470978
# ▶ seg18  mean  MSE:0.20588824152946472  MAE:0.3565049469470978
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.20921513438224792  MAE:0.3642462491989136
# ▶ seg19  mean  MSE:0.20921513438224792  MAE:0.3642462491989136
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.37019050121307373  MAE:0.4820072650909424
# ▶ seg20  mean  MSE:0.37019050121307373  MAE:0.4820072650909424
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.5966576337814331  MAE:0.5923672914505005
# ▶ seg21  mean  MSE:0.5966576337814331  MAE:0.5923672914505005
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.24328063428401947  MAE:0.4024364948272705
# ▶ seg22  mean  MSE:0.24328063428401947  MAE:0.4024364948272705
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.31521889567375183  MAE:0.4397420585155487
# ▶ seg23  mean  MSE:0.31521889567375183  MAE:0.4397420585155487
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.2122008055448532  MAE:0.36730319261550903
# ▶ seg24  mean  MSE:0.2122008055448532  MAE:0.36730319261550903
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.2269764542579651  MAE:0.3851557672023773
# ▶ seg25  mean  MSE:0.2269764542579651  MAE:0.3851557672023773
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.24028697609901428  MAE:0.38283830881118774
# ▶ seg26  mean  MSE:0.24028697609901428  MAE:0.38283830881118774
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.4299313724040985  MAE:0.4984605312347412
# ▶ seg27  mean  MSE:0.4299313724040985  MAE:0.4984605312347412
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.2902728319168091  MAE:0.4344981908798218
# ▶ seg28  mean  MSE:0.2902728319168091  MAE:0.4344981908798218
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.21574872732162476  MAE:0.3724270761013031
# ▶ seg29  mean  MSE:0.21574872732162476  MAE:0.3724270761013031
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.3097704350948334  MAE:0.42955517768859863
# ▶ seg30  mean  MSE:0.3097704350948334  MAE:0.42955517768859863
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.20770683884620667  MAE:0.3632514178752899
# ▶ seg31  mean  MSE:0.20770683884620667  MAE:0.3632514178752899
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.2930475175380707  MAE:0.4188525676727295
# ▶ seg32  mean  MSE:0.2930475175380707  MAE:0.4188525676727295
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.3486326336860657  MAE:0.4439430832862854
# ▶ seg33  mean  MSE:0.3486326336860657  MAE:0.4439430832862854
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.5661448836326599  MAE:0.633723258972168
# ▶ seg34  mean  MSE:0.5661448836326599  MAE:0.633723258972168
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.2886902987957001  MAE:0.420896053314209
# ▶ seg35  mean  MSE:0.2886902987957001  MAE:0.420896053314209
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.2645551562309265  MAE:0.40913018584251404
# ▶ seg36  mean  MSE:0.2645551562309265  MAE:0.40913018584251404
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.4015249013900757  MAE:0.519637942314148
# ▶ seg37  mean  MSE:0.4015249013900757  MAE:0.519637942314148
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.30512535572052  MAE:0.44419145584106445
# ▶ seg38  mean  MSE:0.30512535572052  MAE:0.44419145584106445
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.46192362904548645  MAE:0.5435697436332703
# ▶ seg39  mean  MSE:0.46192362904548645  MAE:0.5435697436332703
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.39114224910736084  MAE:0.485653281211853
# ▶ seg40  mean  MSE:0.39114224910736084  MAE:0.485653281211853
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.22790898382663727  MAE:0.3883488178253174
# ▶ seg41  mean  MSE:0.22790898382663727  MAE:0.3883488178253174
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.2965916395187378  MAE:0.4297569990158081
# ▶ seg42  mean  MSE:0.2965916395187378  MAE:0.4297569990158081
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.37518778443336487  MAE:0.5059489011764526
# ▶ seg43  mean  MSE:0.37518778443336487  MAE:0.5059489011764526
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.24572759866714478  MAE:0.39963632822036743
# ▶ seg44  mean  MSE:0.24572759866714478  MAE:0.39963632822036743
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.2520081698894501  MAE:0.400377482175827
# ▶ seg45  mean  MSE:0.2520081698894501  MAE:0.400377482175827
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.22424353659152985  MAE:0.37107083201408386
# ▶ seg46  mean  MSE:0.22424353659152985  MAE:0.37107083201408386
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.24418938159942627  MAE:0.3861355781555176
# ▶ seg47  mean  MSE:0.24418938159942627  MAE:0.3861355781555176
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.212833434343338  MAE:0.3689830005168915
# ▶ seg48  mean  MSE:0.212833434343338  MAE:0.3689830005168915
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.6609465479850769  MAE:0.6667335033416748
# ▶ seg49  mean  MSE:0.6609465479850769  MAE:0.6667335033416748
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.22128786146640778  MAE:0.3703139126300812
# ▶ seg50  mean  MSE:0.22128786146640778  MAE:0.3703139126300812
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.2839825451374054  MAE:0.4110088050365448
# ▶ seg51  mean  MSE:0.2839825451374054  MAE:0.4110088050365448
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.2252551019191742  MAE:0.3761216998100281
# ▶ seg52  mean  MSE:0.2252551019191742  MAE:0.3761216998100281
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.3603486716747284  MAE:0.4626401960849762
# ▶ seg53  mean  MSE:0.3603486716747284  MAE:0.4626401960849762
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.2580970227718353  MAE:0.4012671709060669
# ▶ seg54  mean  MSE:0.2580970227718353  MAE:0.4012671709060669
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.21394044160842896  MAE:0.3677060604095459
# ▶ seg55  mean  MSE:0.21394044160842896  MAE:0.3677060604095459
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.2548693120479584  MAE:0.4093882143497467
# ▶ seg56  mean  MSE:0.2548693120479584  MAE:0.4093882143497467
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.26157522201538086  MAE:0.39881303906440735
# ▶ seg57  mean  MSE:0.26157522201538086  MAE:0.39881303906440735
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.21637111902236938  MAE:0.37445276975631714
# ▶ seg58  mean  MSE:0.21637111902236938  MAE:0.37445276975631714
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.24500969052314758  MAE:0.3878566026687622
# ▶ seg59  mean  MSE:0.24500969052314758  MAE:0.3878566026687622
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.3958980143070221  MAE:0.5159820914268494
# ▶ seg60  mean  MSE:0.3958980143070221  MAE:0.5159820914268494
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.3054031431674957  MAE:0.4137830436229706
# ▶ seg61  mean  MSE:0.3054031431674957  MAE:0.4137830436229706
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.20551836490631104  MAE:0.3580276072025299
# ▶ seg62  mean  MSE:0.20551836490631104  MAE:0.3580276072025299
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.4674093425273895  MAE:0.5405891537666321
# ▶ seg63  mean  MSE:0.4674093425273895  MAE:0.5405891537666321
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.21823270618915558  MAE:0.36582151055336
# ▶ seg64  mean  MSE:0.21823270618915558  MAE:0.36582151055336
#
# seg10 ch0 MSE : 0.24277651

# %% [markdown]
# # Rank Models (by 2nd alidation performance)

# %%
results1_ER_train = torch.load("./1st_results_ER/train_1st_results.pt")
results1_ER_val = torch.load("./1st_results_ER/val_1st_results.pt")
results1_ER_test = torch.load("./1st_results_ER/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ER_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ER_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ER_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ER_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.288409
#
#   Top  1 | seg 23 | MSE 0.272436 (+0.015973)
#   Top  2 | seg 62 | MSE 0.282369 (+0.006040)
#   Top  3 | seg 57 | MSE 0.287597 (+0.000812)
#   Top  4 | seg 40 | MSE 0.294969 (-0.006559)
#   Top  5 | seg 06 | MSE 0.295671 (-0.007261)
#   Top  6 | seg 37 | MSE 0.297198 (-0.008788)
#   Top  7 | seg 26 | MSE 0.299140 (-0.010730)
#   Top  8 | seg 32 | MSE 0.303919 (-0.015509)
#   Top  9 | seg 58 | MSE 0.312326 (-0.023916)
#   Top 10 | seg 08 | MSE 0.312540 (-0.024131)
#   Top 11 | seg 19 | MSE 0.316183 (-0.027773)
#   Top 12 | seg 45 | MSE 0.328767 (-0.040357)
#   Top 13 | seg 46 | MSE 0.331444 (-0.043035)
#   Top 14 | seg 47 | MSE 0.336076 (-0.047667)
#   Top 15 | seg 43 | MSE 0.337867 (-0.049458)
#   Top 16 | seg 61 | MSE 0.342192 (-0.053783)
#   Top 17 | seg 21 | MSE 0.345863 (-0.057453)
#   Top 18 | seg 28 | MSE 0.353030 (-0.064620)
#   Top 19 | seg 11 | MSE 0.356187 (-0.067777)
#   Top 20 | seg 39 | MSE 0.385112 (-0.096702)
#   Top 21 | seg 10 | MSE 0.387956 (-0.099547)
#   Top 22 | seg 29 | MSE 0.395562 (-0.107152)
#   Top 23 | seg 33 | MSE 0.396843 (-0.108434)
#   Top 24 | seg 25 | MSE 0.397265 (-0.108856)
#   Top 25 | seg 38 | MSE 0.402910 (-0.114500)
#   Top 26 | seg 63 | MSE 0.407544 (-0.119135)
#   Top 27 | seg 05 | MSE 0.408272 (-0.119862)
#   Top 28 | seg 16 | MSE 0.408909 (-0.120500)
#   Top 29 | seg 55 | MSE 0.412615 (-0.124206)
#   Top 30 | seg 64 | MSE 0.414612 (-0.126203)
#   Top 31 | seg 00 | MSE 0.415596 (-0.127187)
#   Top 32 | seg 36 | MSE 0.419274 (-0.130864)
#   Top 33 | seg 04 | MSE 0.421745 (-0.133336)
#   Top 34 | seg 22 | MSE 0.425636 (-0.137226)
#   Top 35 | seg 48 | MSE 0.429409 (-0.140999)
#   Top 36 | seg 42 | MSE 0.451613 (-0.163203)
#   Top 37 | seg 53 | MSE 0.455848 (-0.167439)
#   Top 38 | seg 17 | MSE 0.458625 (-0.170216)
#   Top 39 | seg 12 | MSE 0.476352 (-0.187943)
#   Top 40 | seg 49 | MSE 0.476586 (-0.188176)
#   Top 41 | seg 60 | MSE 0.484453 (-0.196044)
#   Top 42 | seg 07 | MSE 0.485221 (-0.196811)
#   Top 43 | seg 52 | MSE 0.486246 (-0.197836)
#   Top 44 | seg 31 | MSE 0.488315 (-0.199906)
#   Top 45 | seg 54 | MSE 0.488828 (-0.200418)
#   Top 46 | seg 15 | MSE 0.489249 (-0.200839)
#   Top 47 | seg 35 | MSE 0.489288 (-0.200878)
#   Top 48 | seg 41 | MSE 0.495053 (-0.206644)
#   Top 49 | seg 51 | MSE 0.495310 (-0.206900)
#   Top 50 | seg 56 | MSE 0.496388 (-0.207979)
#   Top 51 | seg 09 | MSE 0.505894 (-0.217484)
#   Top 52 | seg 18 | MSE 0.511857 (-0.223448)
#   Top 53 | seg 03 | MSE 0.513968 (-0.225559)
#   Top 54 | seg 02 | MSE 0.541460 (-0.253051)
#   Top 55 | seg 59 | MSE 0.571851 (-0.283442)
#   Top 56 | seg 27 | MSE 0.625289 (-0.336879)
#   Top 57 | seg 50 | MSE 0.638391 (-0.349982)
#   Top 58 | seg 01 | MSE 0.646624 (-0.358214)
#   Top 59 | seg 34 | MSE 0.651427 (-0.363018)
#   Top 60 | seg 30 | MSE 0.659119 (-0.370710)
#   Top 61 | seg 24 | MSE 0.686664 (-0.398254)
#   Top 62 | seg 44 | MSE 0.700851 (-0.412442)
#   Top 63 | seg 14 | MSE 0.715299 (-0.426890)
#   Top 64 | seg 20 | MSE 0.744067 (-0.455657)
#   Top 65 | seg 13 | MSE 0.771525 (-0.483116)
#
# Saved top segment indices per channel:
# Channel 0: [23, 62, 57, 40, 6, 37, 26, 32, 58, 8, 19, 45, 46, 47, 43, 61, 21, 28, 11, 39, 10, 29, 33, 25, 38, 63, 5, 16, 55, 64, 0, 36, 4, 22, 48, 42, 53, 17, 12, 49, 60, 7, 52, 31, 54, 15, 35, 41, 51, 56, 9, 18, 3, 2, 59, 27, 50, 1, 34, 30, 24, 44, 14, 20, 13]

# %% [markdown]
# ### 1E->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ER_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ER_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ER_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ER_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.288409
#
#   Top  1 | seg 61 | MSE 0.272993 (+0.015417)
#   Top  2 | seg 33 | MSE 0.273318 (+0.015091)
#   Top  3 | seg 59 | MSE 0.275825 (+0.012584)
#   Top  4 | seg 46 | MSE 0.280242 (+0.008167)
#   Top  5 | seg 64 | MSE 0.283544 (+0.004865)
#   Top  6 | seg 35 | MSE 0.285618 (+0.002792)
#   Top  7 | seg 24 | MSE 0.294028 (-0.005619)
#   Top  8 | seg 62 | MSE 0.307395 (-0.018985)
#   Top  9 | seg 18 | MSE 0.314446 (-0.026037)
#   Top 10 | seg 01 | MSE 0.315705 (-0.027295)
#   Top 11 | seg 02 | MSE 0.339329 (-0.050920)
#   Top 12 | seg 11 | MSE 0.353896 (-0.065487)
#   Top 13 | seg 19 | MSE 0.357365 (-0.068955)
#   Top 14 | seg 31 | MSE 0.361560 (-0.073151)
#   Top 15 | seg 29 | MSE 0.364219 (-0.075810)
#   Top 16 | seg 25 | MSE 0.369137 (-0.080728)
#   Top 17 | seg 48 | MSE 0.371291 (-0.082882)
#   Top 18 | seg 50 | MSE 0.375689 (-0.087279)
#   Top 19 | seg 58 | MSE 0.381111 (-0.092702)
#   Top 20 | seg 41 | MSE 0.383235 (-0.094825)
#   Top 21 | seg 55 | MSE 0.387181 (-0.098771)
#   Top 22 | seg 07 | MSE 0.401250 (-0.112840)
#   Top 23 | seg 26 | MSE 0.410062 (-0.121653)
#   Top 24 | seg 10 | MSE 0.411279 (-0.122869)
#   Top 25 | seg 56 | MSE 0.412307 (-0.123898)
#   Top 26 | seg 52 | MSE 0.413155 (-0.124746)
#   Top 27 | seg 44 | MSE 0.413527 (-0.125118)
#   Top 28 | seg 22 | MSE 0.415890 (-0.127480)
#   Top 29 | seg 54 | MSE 0.420023 (-0.131613)
#   Top 30 | seg 15 | MSE 0.421090 (-0.132680)
#   Top 31 | seg 13 | MSE 0.428258 (-0.139849)
#   Top 32 | seg 47 | MSE 0.431158 (-0.142749)
#   Top 33 | seg 45 | MSE 0.435912 (-0.147503)
#   Top 34 | seg 16 | MSE 0.443605 (-0.155196)
#   Top 35 | seg 57 | MSE 0.447350 (-0.158940)
#   Top 36 | seg 42 | MSE 0.447420 (-0.159010)
#   Top 37 | seg 14 | MSE 0.453710 (-0.165300)
#   Top 38 | seg 32 | MSE 0.460233 (-0.171824)
#   Top 39 | seg 23 | MSE 0.463212 (-0.174803)
#   Top 40 | seg 51 | MSE 0.465343 (-0.176934)
#   Top 41 | seg 09 | MSE 0.472791 (-0.184382)
#   Top 42 | seg 28 | MSE 0.475842 (-0.187433)
#   Top 43 | seg 00 | MSE 0.477117 (-0.188707)
#   Top 44 | seg 06 | MSE 0.481362 (-0.192952)
#   Top 45 | seg 12 | MSE 0.491927 (-0.203518)
#   Top 46 | seg 04 | MSE 0.496447 (-0.208038)
#   Top 47 | seg 08 | MSE 0.502069 (-0.213659)
#   Top 48 | seg 36 | MSE 0.510497 (-0.222087)
#   Top 49 | seg 05 | MSE 0.517185 (-0.228776)
#   Top 50 | seg 30 | MSE 0.518712 (-0.230303)
#   Top 51 | seg 38 | MSE 0.527698 (-0.239288)
#   Top 52 | seg 43 | MSE 0.539851 (-0.251441)
#   Top 53 | seg 60 | MSE 0.545470 (-0.257061)
#   Top 54 | seg 53 | MSE 0.548320 (-0.259910)
#   Top 55 | seg 03 | MSE 0.548817 (-0.260408)
#   Top 56 | seg 37 | MSE 0.564399 (-0.275990)
#   Top 57 | seg 17 | MSE 0.583598 (-0.295188)
#   Top 58 | seg 40 | MSE 0.591475 (-0.303066)
#   Top 59 | seg 20 | MSE 0.607163 (-0.318754)
#   Top 60 | seg 39 | MSE 0.607506 (-0.319096)
#   Top 61 | seg 27 | MSE 0.671355 (-0.382945)
#   Top 62 | seg 63 | MSE 0.697491 (-0.409081)
#   Top 63 | seg 21 | MSE 0.752750 (-0.464341)
#   Top 64 | seg 34 | MSE 0.833860 (-0.545451)
#   Top 65 | seg 49 | MSE 0.911752 (-0.623343)
#
# Saved top segment indices per channel:
# Channel 0: [61, 33, 59, 46, 64, 35, 24, 62, 18, 1, 2, 11, 19, 31, 29, 25, 48, 50, 58, 41, 55, 7, 26, 10, 56, 52, 44, 22, 54, 15, 13, 47, 45, 16, 57, 42, 14, 32, 23, 51, 9, 28, 0, 6, 12, 4, 8, 36, 5, 30, 38, 43, 60, 53, 3, 37, 17, 40, 20, 39, 27, 63, 21, 34, 49]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 8

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ER_test['ES']['mse_test_EES']
    v_mae = results1_ER_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ER_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.247291 | MAE : 0.381075
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.738e-02 | |ρ|=0.9605 | S=0.6891 <- pick
#    K=10 | Var=2.354e-02 | |ρ|=0.9689 | S=0.9138
#    K=15 | Var=2.283e-02 | |ρ|=0.9715 | S=1.0000
#    K=20 | Var=2.512e-02 | |ρ|=0.9691 | S=0.9735
#    K=25 | Var=2.806e-02 | |ρ|=0.9654 | S=0.9135
#    K=30 | Var=3.264e-02 | |ρ|=0.9621 | S=0.9189
#    K=35 | Var=3.244e-02 | |ρ|=0.9634 | S=0.9687
#    K=40 | Var=3.499e-02 | |ρ|=0.9613 | S=0.9607
#    K=45 | Var=3.798e-02 | |ρ|=0.9596 | S=0.9863
#    K=50 | Var=3.980e-02 | |ρ|=0.9597 | S=1.0452
#    K=55 | Var=4.238e-02 | |ρ|=0.9573 | S=1.0273
#    K=60 | Var=4.792e-02 | |ρ|=0.9519 | S=0.9795
#    K=65 | Var=5.472e-02 | |ρ|=0.9472 | S=1.0000
# [Var-Corr]  K=5
#   MSE = 0.207857 | Δ = +0.039434 | Δ% = +15.95%
#   MAE = 0.353875 | Δ = +0.027200 | Δ% = +7.14%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.247291
# Ensemble mean MSE : 0.207857
# Average Δ MSE     : +0.039434
# Average Δ MSE (%) : +15.95%
#
# Vanilla  mean MAE : 0.381075
# Ensemble mean MAE : 0.353875
# Average Δ MAE     : +0.027200
# Average Δ MAE (%) : +7.14%

# %% [markdown]
# ## 1E->1E

# %%
results1_ER_test['ES']['mae_test_EES']
# Out:
# 0.3810746669769287

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 8

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ER_test['ES']['mse_test_EES']
    v_mae = results1_ER_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ER_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.35   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.247291 | MAE : 0.381075
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.804e-02 | |ρ|=0.9715 | S=1.2465
#    K=10 | Var=3.435e-02 | |ρ|=0.9734 | S=1.5249
#    K=15 | Var=3.867e-02 | |ρ|=0.9714 | S=1.5353
#    K=20 | Var=3.971e-02 | |ρ|=0.9709 | S=1.5396
#    K=25 | Var=4.048e-02 | |ρ|=0.9680 | S=1.3982
#    K=30 | Var=4.128e-02 | |ρ|=0.9647 | S=1.2369
#    K=35 | Var=4.161e-02 | |ρ|=0.9637 | S=1.1939
#    K=40 | Var=4.374e-02 | |ρ|=0.9613 | S=1.1166
#    K=45 | Var=4.539e-02 | |ρ|=0.9618 | S=1.1943
#    K=50 | Var=4.603e-02 | |ρ|=0.9606 | S=1.1409
#    K=55 | Var=4.951e-02 | |ρ|=0.9588 | S=1.1374
#    K=60 | Var=5.422e-02 | |ρ|=0.9554 | S=1.0804
#    K=65 | Var=6.410e-02 | |ρ|=0.9490 | S=1.0000 <- pick
# [Var-Corr]  K=65
#    MSE = 0.233293 | Δ = +0.013998 | Δ% = +5.66%
#    MAE = 0.382711 | Δ = -0.001636 | Δ% = -0.43%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.247291
# Ensemble mean MSE  : 0.233293
# Average Δ MSE      : +0.013998
# Average Δ MSE (%)  : +5.66%
#
# Vanilla  mean MAE  : 0.381075
# Ensemble mean MAE  : 0.382711
# Average Δ MAE      : -0.001636
# Average Δ MAE (%)  : -0.43%
