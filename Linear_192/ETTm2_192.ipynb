# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(2)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 2
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTm2.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                           HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# date
# 2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 2016-07-01 00:15:00  39.622002  11.309  35.543999  8.551  3.209  1.258
# 2016-07-01 00:30:00  38.868000  10.555  34.365002  7.586  4.435  1.258
# 2016-07-01 00:45:00  35.518002   9.214  32.569000  8.712  4.435  1.215
# 2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
#
#                             OT
# date
# 2016-07-01 00:00:00  38.661999
# 2016-07-01 00:15:00  38.223000
# 2016-07-01 00:30:00  37.344002
# 2016-07-01 00:45:00  37.124001
# 2016-07-01 01:00:00  37.124001

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (69680, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 00:15:00',
#                '2016-07-01 00:30:00', '2016-07-01 00:45:00',
#                '2016-07-01 01:00:00', '2016-07-01 01:15:00',
#                '2016-07-01 01:30:00', '2016-07-01 01:45:00',
#                '2016-07-01 02:00:00', '2016-07-01 02:15:00',
#                ...
#                '2018-06-26 17:30:00', '2018-06-26 17:45:00',
#                '2018-06-26 18:00:00', '2018-06-26 18:15:00',
#                '2018-06-26 18:30:00', '2018-06-26 18:45:00',
#                '2018-06-26 19:00:00', '2018-06-26 19:15:00',
#                '2018-06-26 19:30:00', '2018-06-26 19:45:00'],
#               dtype='datetime64[ns]', name='date', length=69680, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Model Modification for Linear (Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class Model(nn.Module):
    """
    Linear model with prediction-based augmentation (attach_pv)
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.channels = configs.enc_in

        
        self.attach_pv = getattr(configs, "attach_pv", False)

        
        self.extra_len = self.pred_len // 3

        
        self.seq_len_aug = self.seq_len + (self.extra_len if self.attach_pv else 0)

        self.individual = configs.individual

        
        if self.individual:
            self.Linear = nn.ModuleList()
            for i in range(self.channels):
                self.Linear.append(nn.Linear(self.seq_len_aug, self.pred_len))
        else:
            self.Linear = nn.Linear(self.seq_len_aug, self.pred_len)


    def forward(self, x, ground_truth=None):
        """
        x: [B, L, C]
        ground_truth: [B, L_gt, C] or None
        """
        B, L, C = x.size()

        
        
        
        if self.attach_pv and (ground_truth is not None):
            
            gt_part = ground_truth[:, :self.extra_len, :]  

            
            x = torch.cat([x, gt_part], dim=1)

        
        
        
        if self.individual:
            out = torch.zeros([B, self.pred_len, C], dtype=x.dtype).to(x.device)
            for i in range(C):
                out[:, :, i] = self.Linear[i](x[:, :, i])
            return out

        else:
            
            out = self.Linear(x.permute(0, 2, 1))
            return out.permute(0, 2, 1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 192




train_points = 12 * 30 * 24 * 4
val_points   = 4  * 30 * 24 * 4
test_points  = 4  * 30 * 24 * 4

border1s = [
    0,
    train_points - seq_len,
    train_points + val_points - seq_len
]
border2s = [
    train_points,
    train_points + val_points,
    train_points + val_points + test_points
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([34033, 336, 1])
# Train Labels:    torch.Size([34033, 192, 1])
# Val Sequences:   torch.Size([11329, 336, 1])
# Val Labels:      torch.Size([11329, 192, 1])
# Test Sequences:  torch.Size([11329, 336, 1])
# Test Labels:     torch.Size([11329, 192, 1])

# %%
set_seed(43)

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 192  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.001, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.002
# Epoch 0 | Train Loss: 0.15519417524057671 | Val Loss: 0.14734768819221308
# Validation loss decreased (inf --> 0.147348).  Saving model ...
# Updating learning rate to 0.001
# Epoch 1 | Train Loss: 0.14062262154919536 | Val Loss: 0.14907372435161345
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0005
# Epoch 2 | Train Loss: 0.13726195354448786 | Val Loss: 0.13982804430465043
# Validation loss decreased (0.147348 --> 0.139828).  Saving model ...
# Updating learning rate to 0.00025
# Epoch 3 | Train Loss: 0.13530837050534056 | Val Loss: 0.13531240598285493
# Validation loss decreased (0.139828 --> 0.135312).  Saving model ...
# Updating learning rate to 0.000125
# Epoch 4 | Train Loss: 0.13448954450624778 | Val Loss: 0.1349564072151314
# Validation loss decreased (0.135312 --> 0.134956).  Saving model ...
# Updating learning rate to 6.25e-05
# Epoch 5 | Train Loss: 0.13381462442667635 | Val Loss: 0.1333640985754909
# Validation loss decreased (0.134956 --> 0.133364).  Saving model ...
# Updating learning rate to 3.125e-05
# Epoch 6 | Train Loss: 0.13356479066178986 | Val Loss: 0.13335508340641752
# Validation loss decreased (0.133364 --> 0.133355).  Saving model ...
# Updating learning rate to 1.5625e-05
# Epoch 7 | Train Loss: 0.13342017945798493 | Val Loss: 0.1328065771439021
# Validation loss decreased (0.133355 --> 0.132807).  Saving model ...
# Updating learning rate to 7.8125e-06
# Epoch 8 | Train Loss: 0.1332953449625774 | Val Loss: 0.13281785741868155
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.90625e-06
# Epoch 9 | Train Loss: 0.13325994221591636 | Val Loss: 0.13277969778135
# Validation loss decreased (0.132807 --> 0.132780).  Saving model ...

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 192  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_pv):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv = attach_pv


configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.001, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_pv=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.002
# Epoch 0 | Train Loss: 0.15431357019657926 | Val Loss: 0.1436199483697788
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.09354662150144577 | MAE: 0.2299414724111557
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.1131918728351593 | MAE: 0.25920283794403076

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.13307787477970123 | MAE: 0.2677059769630432
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.14396068453788757 | MAE: 0.2942102253437042

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.1332208812236786 | MAE: 0.26271307468414307
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.14417465031147003 | MAE: 0.28411221504211426

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([34033, 336, 1])
# val_sequences shape:  torch.Size([11329, 336, 1])
# test_sequences shape:  torch.Size([11329, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([34033, 192, 1])
# val_pv shape:  torch.Size([11329, 192, 1])
# test_pv shape:  torch.Size([11329, 192, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([34033, 192, 1])
# val_labels shape:  torch.Size([11329, 192, 1])
# test_labels shape:  torch.Size([11329, 192, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 192

# %%
segment_len = configs.pred_len // 3
stride = 2

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([34033, 65, 64, 1]), Val: torch.Size([11329, 65, 64, 1]), Test: torch.Size([11329, 65, 64, 1])
# [Epoch 1] Train seg shape: torch.Size([34033, 65, 64, 1]), Val: torch.Size([11329, 65, 64, 1]), Test: torch.Size([11329, 65, 64, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTm2'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 192,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 0] Training Time = 4.89 sec
# [Segment 0] GPU Memory Start = 3732.40 MB
# [Segment 0] GPU Memory End   = 2833.31 MB
# [Segment 0] GPU Peak Memory  = 3732.69 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 1] Training Time = 4.86 sec
# [Segment 1] GPU Memory Start = 2833.31 MB
# [Segment 1] GPU Memory End   = 2833.61 MB
# [Segment 1] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 2] Training Time = 4.74 sec
# [Segment 2] GPU Memory Start = 2833.61 MB
# [Segment 2] GPU Memory End   = 2833.90 MB
# [Segment 2] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 3] Training Time = 4.80 sec
# [Segment 3] GPU Memory Start = 2833.90 MB
# [Segment 3] GPU Memory End   = 2834.20 MB
# [Segment 3] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 4] Training Time = 4.69 sec
# [Segment 4] GPU Memory Start = 2834.20 MB
# [Segment 4] GPU Memory End   = 2834.49 MB
# [Segment 4] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 5] Training Time = 4.86 sec
# [Segment 5] GPU Memory Start = 2834.49 MB
# [Segment 5] GPU Memory End   = 2834.78 MB
# [Segment 5] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 6] Training Time = 4.84 sec
# [Segment 6] GPU Memory Start = 2834.78 MB
# [Segment 6] GPU Memory End   = 2835.08 MB
# [Segment 6] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 7] Training Time = 4.32 sec
# [Segment 7] GPU Memory Start = 2835.08 MB
# [Segment 7] GPU Memory End   = 2835.37 MB
# [Segment 7] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 8] Training Time = 4.70 sec
# [Segment 8] GPU Memory Start = 2835.37 MB
# [Segment 8] GPU Memory End   = 2835.67 MB
# [Segment 8] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 9] Training Time = 4.81 sec
# [Segment 9] GPU Memory Start = 2835.67 MB
# [Segment 9] GPU Memory End   = 2835.96 MB
# [Segment 9] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 10] Training Time = 4.83 sec
# [Segment 10] GPU Memory Start = 2833.31 MB
# [Segment 10] GPU Memory End   = 2833.61 MB
# [Segment 10] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 11] Training Time = 4.78 sec
# [Segment 11] GPU Memory Start = 2833.61 MB
# [Segment 11] GPU Memory End   = 2833.90 MB
# [Segment 11] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 12] Training Time = 4.85 sec
# [Segment 12] GPU Memory Start = 2833.90 MB
# [Segment 12] GPU Memory End   = 2834.20 MB
# [Segment 12] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 13] Training Time = 4.28 sec
# [Segment 13] GPU Memory Start = 2834.20 MB
# [Segment 13] GPU Memory End   = 2834.49 MB
# [Segment 13] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 14] Training Time = 4.68 sec
# [Segment 14] GPU Memory Start = 2834.49 MB
# [Segment 14] GPU Memory End   = 2834.78 MB
# [Segment 14] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 15] Training Time = 4.52 sec
# [Segment 15] GPU Memory Start = 2834.78 MB
# [Segment 15] GPU Memory End   = 2835.08 MB
# [Segment 15] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 16] Training Time = 4.84 sec
# [Segment 16] GPU Memory Start = 2835.08 MB
# [Segment 16] GPU Memory End   = 2835.37 MB
# [Segment 16] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 17] Training Time = 4.78 sec
# [Segment 17] GPU Memory Start = 2835.37 MB
# [Segment 17] GPU Memory End   = 2835.67 MB
# [Segment 17] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 18] Training Time = 4.86 sec
# [Segment 18] GPU Memory Start = 2835.67 MB
# [Segment 18] GPU Memory End   = 2835.96 MB
# [Segment 18] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 19] Training Time = 4.47 sec
# [Segment 19] GPU Memory Start = 2835.96 MB
# [Segment 19] GPU Memory End   = 2836.25 MB
# [Segment 19] GPU Peak Memory  = 2837.43 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 20] Training Time = 4.75 sec
# [Segment 20] GPU Memory Start = 2833.31 MB
# [Segment 20] GPU Memory End   = 2833.61 MB
# [Segment 20] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 21] Training Time = 4.74 sec
# [Segment 21] GPU Memory Start = 2833.61 MB
# [Segment 21] GPU Memory End   = 2833.90 MB
# [Segment 21] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 22] Training Time = 4.81 sec
# [Segment 22] GPU Memory Start = 2833.90 MB
# [Segment 22] GPU Memory End   = 2834.20 MB
# [Segment 22] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 23] Training Time = 4.23 sec
# [Segment 23] GPU Memory Start = 2834.20 MB
# [Segment 23] GPU Memory End   = 2834.49 MB
# [Segment 23] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 24] Training Time = 4.81 sec
# [Segment 24] GPU Memory Start = 2834.49 MB
# [Segment 24] GPU Memory End   = 2834.78 MB
# [Segment 24] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 25] Training Time = 4.89 sec
# [Segment 25] GPU Memory Start = 2834.78 MB
# [Segment 25] GPU Memory End   = 2835.08 MB
# [Segment 25] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 26] Training Time = 4.85 sec
# [Segment 26] GPU Memory Start = 2835.08 MB
# [Segment 26] GPU Memory End   = 2835.37 MB
# [Segment 26] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 27] Training Time = 4.88 sec
# [Segment 27] GPU Memory Start = 2835.37 MB
# [Segment 27] GPU Memory End   = 2835.67 MB
# [Segment 27] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 28] Training Time = 4.72 sec
# [Segment 28] GPU Memory Start = 2835.67 MB
# [Segment 28] GPU Memory End   = 2835.96 MB
# [Segment 28] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 29] Training Time = 4.84 sec
# [Segment 29] GPU Memory Start = 2835.96 MB
# [Segment 29] GPU Memory End   = 2836.25 MB
# [Segment 29] GPU Peak Memory  = 2837.43 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 30] Training Time = 4.21 sec
# [Segment 30] GPU Memory Start = 2833.31 MB
# [Segment 30] GPU Memory End   = 2833.61 MB
# [Segment 30] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 31] Training Time = 4.79 sec
# [Segment 31] GPU Memory Start = 2833.61 MB
# [Segment 31] GPU Memory End   = 2833.90 MB
# [Segment 31] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 32] Training Time = 4.92 sec
# [Segment 32] GPU Memory Start = 2833.90 MB
# [Segment 32] GPU Memory End   = 2834.20 MB
# [Segment 32] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 33] Training Time = 4.73 sec
# [Segment 33] GPU Memory Start = 2834.20 MB
# [Segment 33] GPU Memory End   = 2834.49 MB
# [Segment 33] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 34] Training Time = 4.73 sec
# [Segment 34] GPU Memory Start = 2834.49 MB
# [Segment 34] GPU Memory End   = 2834.78 MB
# [Segment 34] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 35] Training Time = 4.84 sec
# [Segment 35] GPU Memory Start = 2834.78 MB
# [Segment 35] GPU Memory End   = 2835.08 MB
# [Segment 35] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 36] Training Time = 4.87 sec
# [Segment 36] GPU Memory Start = 2835.08 MB
# [Segment 36] GPU Memory End   = 2835.37 MB
# [Segment 36] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 37] Training Time = 4.87 sec
# [Segment 37] GPU Memory Start = 2835.37 MB
# [Segment 37] GPU Memory End   = 2835.67 MB
# [Segment 37] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 38] Training Time = 4.76 sec
# [Segment 38] GPU Memory Start = 2835.67 MB
# [Segment 38] GPU Memory End   = 2835.96 MB
# [Segment 38] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 39] Training Time = 3.28 sec
# [Segment 39] GPU Memory Start = 2835.96 MB
# [Segment 39] GPU Memory End   = 2836.25 MB
# [Segment 39] GPU Peak Memory  = 2837.43 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 40] Training Time = 1.47 sec
# [Segment 40] GPU Memory Start = 2833.31 MB
# [Segment 40] GPU Memory End   = 2833.61 MB
# [Segment 40] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 41] Training Time = 4.55 sec
# [Segment 41] GPU Memory Start = 2833.61 MB
# [Segment 41] GPU Memory End   = 2833.90 MB
# [Segment 41] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 42] Training Time = 4.82 sec
# [Segment 42] GPU Memory Start = 2833.90 MB
# [Segment 42] GPU Memory End   = 2834.20 MB
# [Segment 42] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 43] Training Time = 4.89 sec
# [Segment 43] GPU Memory Start = 2834.20 MB
# [Segment 43] GPU Memory End   = 2834.49 MB
# [Segment 43] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 44] Training Time = 4.69 sec
# [Segment 44] GPU Memory Start = 2834.49 MB
# [Segment 44] GPU Memory End   = 2834.78 MB
# [Segment 44] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 45] Training Time = 4.62 sec
# [Segment 45] GPU Memory Start = 2834.78 MB
# [Segment 45] GPU Memory End   = 2835.08 MB
# [Segment 45] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 46] Training Time = 3.83 sec
# [Segment 46] GPU Memory Start = 2835.08 MB
# [Segment 46] GPU Memory End   = 2835.37 MB
# [Segment 46] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 47] Training Time = 3.13 sec
# [Segment 47] GPU Memory Start = 2835.37 MB
# [Segment 47] GPU Memory End   = 2835.67 MB
# [Segment 47] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 48] Training Time = 4.60 sec
# [Segment 48] GPU Memory Start = 2835.67 MB
# [Segment 48] GPU Memory End   = 2835.96 MB
# [Segment 48] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 49] Training Time = 3.10 sec
# [Segment 49] GPU Memory Start = 2835.96 MB
# [Segment 49] GPU Memory End   = 2836.25 MB
# [Segment 49] GPU Peak Memory  = 2837.43 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 50] Training Time = 4.82 sec
# [Segment 50] GPU Memory Start = 2833.31 MB
# [Segment 50] GPU Memory End   = 2833.61 MB
# [Segment 50] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 51] Training Time = 4.92 sec
# [Segment 51] GPU Memory Start = 2833.61 MB
# [Segment 51] GPU Memory End   = 2833.90 MB
# [Segment 51] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 52] Training Time = 4.77 sec
# [Segment 52] GPU Memory Start = 2833.90 MB
# [Segment 52] GPU Memory End   = 2834.20 MB
# [Segment 52] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 53] Training Time = 3.34 sec
# [Segment 53] GPU Memory Start = 2834.20 MB
# [Segment 53] GPU Memory End   = 2834.49 MB
# [Segment 53] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 54] Training Time = 4.71 sec
# [Segment 54] GPU Memory Start = 2834.49 MB
# [Segment 54] GPU Memory End   = 2834.78 MB
# [Segment 54] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 55] Training Time = 4.83 sec
# [Segment 55] GPU Memory Start = 2834.78 MB
# [Segment 55] GPU Memory End   = 2835.08 MB
# [Segment 55] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 56] Training Time = 4.84 sec
# [Segment 56] GPU Memory Start = 2835.08 MB
# [Segment 56] GPU Memory End   = 2835.37 MB
# [Segment 56] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 57] Training Time = 4.82 sec
# [Segment 57] GPU Memory Start = 2835.37 MB
# [Segment 57] GPU Memory End   = 2835.67 MB
# [Segment 57] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 58] Training Time = 4.41 sec
# [Segment 58] GPU Memory Start = 2835.67 MB
# [Segment 58] GPU Memory End   = 2835.96 MB
# [Segment 58] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 59] Training Time = 4.06 sec
# [Segment 59] GPU Memory Start = 2835.96 MB
# [Segment 59] GPU Memory End   = 2833.31 MB
# [Segment 59] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 60] Training Time = 4.85 sec
# [Segment 60] GPU Memory Start = 2833.31 MB
# [Segment 60] GPU Memory End   = 2833.61 MB
# [Segment 60] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 61] Training Time = 4.79 sec
# [Segment 61] GPU Memory Start = 2833.61 MB
# [Segment 61] GPU Memory End   = 2833.90 MB
# [Segment 61] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 62] Training Time = 4.73 sec
# [Segment 62] GPU Memory Start = 2833.90 MB
# [Segment 62] GPU Memory End   = 2834.20 MB
# [Segment 62] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 63] Training Time = 4.88 sec
# [Segment 63] GPU Memory Start = 2834.20 MB
# [Segment 63] GPU Memory End   = 2834.49 MB
# [Segment 63] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 64] Training Time = 4.89 sec
# [Segment 64] GPU Memory Start = 2834.49 MB
# [Segment 64] GPU Memory End   = 2834.78 MB
# [Segment 64] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv




base_cfg = Configs(
    seq_len          = 336 ,
    pred_len         = 192,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E/",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear[c].parameters()) 
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 0] Training Time = 4.83 sec
# [Segment 0] GPU Memory Start = 2833.31 MB
# [Segment 0] GPU Memory End   = 2833.31 MB
# [Segment 0] GPU Peak Memory  = 2834.75 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 1] Training Time = 4.70 sec
# [Segment 1] GPU Memory Start = 2833.31 MB
# [Segment 1] GPU Memory End   = 2833.61 MB
# [Segment 1] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 2] Training Time = 3.68 sec
# [Segment 2] GPU Memory Start = 2833.61 MB
# [Segment 2] GPU Memory End   = 2833.90 MB
# [Segment 2] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 3] Training Time = 2.45 sec
# [Segment 3] GPU Memory Start = 2833.90 MB
# [Segment 3] GPU Memory End   = 2834.20 MB
# [Segment 3] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 4] Training Time = 4.82 sec
# [Segment 4] GPU Memory Start = 2834.20 MB
# [Segment 4] GPU Memory End   = 2834.49 MB
# [Segment 4] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 5] Training Time = 2.79 sec
# [Segment 5] GPU Memory Start = 2834.49 MB
# [Segment 5] GPU Memory End   = 2834.78 MB
# [Segment 5] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 6] Training Time = 4.36 sec
# [Segment 6] GPU Memory Start = 2834.78 MB
# [Segment 6] GPU Memory End   = 2833.31 MB
# [Segment 6] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 7] Training Time = 4.52 sec
# [Segment 7] GPU Memory Start = 2833.31 MB
# [Segment 7] GPU Memory End   = 2833.61 MB
# [Segment 7] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 8] Training Time = 4.91 sec
# [Segment 8] GPU Memory Start = 2833.61 MB
# [Segment 8] GPU Memory End   = 2833.90 MB
# [Segment 8] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 9] Training Time = 4.61 sec
# [Segment 9] GPU Memory Start = 2833.90 MB
# [Segment 9] GPU Memory End   = 2834.20 MB
# [Segment 9] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 10] Training Time = 4.80 sec
# [Segment 10] GPU Memory Start = 2834.20 MB
# [Segment 10] GPU Memory End   = 2834.49 MB
# [Segment 10] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 11] Training Time = 4.38 sec
# [Segment 11] GPU Memory Start = 2834.49 MB
# [Segment 11] GPU Memory End   = 2834.78 MB
# [Segment 11] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 12] Training Time = 2.89 sec
# [Segment 12] GPU Memory Start = 2834.78 MB
# [Segment 12] GPU Memory End   = 2835.08 MB
# [Segment 12] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 13] Training Time = 4.81 sec
# [Segment 13] GPU Memory Start = 2835.08 MB
# [Segment 13] GPU Memory End   = 2835.37 MB
# [Segment 13] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 14] Training Time = 4.83 sec
# [Segment 14] GPU Memory Start = 2835.37 MB
# [Segment 14] GPU Memory End   = 2835.67 MB
# [Segment 14] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 15] Training Time = 2.44 sec
# [Segment 15] GPU Memory Start = 2835.67 MB
# [Segment 15] GPU Memory End   = 2835.96 MB
# [Segment 15] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 16] Training Time = 4.50 sec
# [Segment 16] GPU Memory Start = 2835.96 MB
# [Segment 16] GPU Memory End   = 2833.31 MB
# [Segment 16] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 17] Training Time = 4.69 sec
# [Segment 17] GPU Memory Start = 2833.31 MB
# [Segment 17] GPU Memory End   = 2833.61 MB
# [Segment 17] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 18] Training Time = 2.47 sec
# [Segment 18] GPU Memory Start = 2833.61 MB
# [Segment 18] GPU Memory End   = 2833.90 MB
# [Segment 18] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 19] Training Time = 4.61 sec
# [Segment 19] GPU Memory Start = 2833.90 MB
# [Segment 19] GPU Memory End   = 2834.20 MB
# [Segment 19] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 20] Training Time = 2.81 sec
# [Segment 20] GPU Memory Start = 2834.20 MB
# [Segment 20] GPU Memory End   = 2834.49 MB
# [Segment 20] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 21] Training Time = 3.32 sec
# [Segment 21] GPU Memory Start = 2834.49 MB
# [Segment 21] GPU Memory End   = 2834.78 MB
# [Segment 21] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 22] Training Time = 4.74 sec
# [Segment 22] GPU Memory Start = 2834.78 MB
# [Segment 22] GPU Memory End   = 2835.08 MB
# [Segment 22] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 23] Training Time = 4.67 sec
# [Segment 23] GPU Memory Start = 2835.08 MB
# [Segment 23] GPU Memory End   = 2835.37 MB
# [Segment 23] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 24] Training Time = 4.49 sec
# [Segment 24] GPU Memory Start = 2835.37 MB
# [Segment 24] GPU Memory End   = 2835.67 MB
# [Segment 24] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 25] Training Time = 4.73 sec
# [Segment 25] GPU Memory Start = 2835.67 MB
# [Segment 25] GPU Memory End   = 2835.96 MB
# [Segment 25] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 26] Training Time = 2.51 sec
# [Segment 26] GPU Memory Start = 2835.96 MB
# [Segment 26] GPU Memory End   = 2833.31 MB
# [Segment 26] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 27] Training Time = 4.72 sec
# [Segment 27] GPU Memory Start = 2833.31 MB
# [Segment 27] GPU Memory End   = 2833.61 MB
# [Segment 27] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 28] Training Time = 4.44 sec
# [Segment 28] GPU Memory Start = 2833.61 MB
# [Segment 28] GPU Memory End   = 2833.90 MB
# [Segment 28] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 29] Training Time = 4.49 sec
# [Segment 29] GPU Memory Start = 2833.90 MB
# [Segment 29] GPU Memory End   = 2834.20 MB
# [Segment 29] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 30] Training Time = 4.41 sec
# [Segment 30] GPU Memory Start = 2834.20 MB
# [Segment 30] GPU Memory End   = 2834.49 MB
# [Segment 30] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 31] Training Time = 4.76 sec
# [Segment 31] GPU Memory Start = 2834.49 MB
# [Segment 31] GPU Memory End   = 2834.78 MB
# [Segment 31] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 32] Training Time = 4.45 sec
# [Segment 32] GPU Memory Start = 2834.78 MB
# [Segment 32] GPU Memory End   = 2835.08 MB
# [Segment 32] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 33] Training Time = 3.95 sec
# [Segment 33] GPU Memory Start = 2835.08 MB
# [Segment 33] GPU Memory End   = 2835.37 MB
# [Segment 33] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 34] Training Time = 3.79 sec
# [Segment 34] GPU Memory Start = 2835.37 MB
# [Segment 34] GPU Memory End   = 2835.67 MB
# [Segment 34] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 35] Training Time = 4.61 sec
# [Segment 35] GPU Memory Start = 2835.67 MB
# [Segment 35] GPU Memory End   = 2835.96 MB
# [Segment 35] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 36] Training Time = 4.28 sec
# [Segment 36] GPU Memory Start = 2835.96 MB
# [Segment 36] GPU Memory End   = 2833.31 MB
# [Segment 36] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 37] Training Time = 4.18 sec
# [Segment 37] GPU Memory Start = 2833.31 MB
# [Segment 37] GPU Memory End   = 2833.61 MB
# [Segment 37] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 38] Training Time = 2.04 sec
# [Segment 38] GPU Memory Start = 2833.61 MB
# [Segment 38] GPU Memory End   = 2833.90 MB
# [Segment 38] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 39] Training Time = 2.34 sec
# [Segment 39] GPU Memory Start = 2833.90 MB
# [Segment 39] GPU Memory End   = 2834.20 MB
# [Segment 39] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 40] Training Time = 3.20 sec
# [Segment 40] GPU Memory Start = 2834.20 MB
# [Segment 40] GPU Memory End   = 2834.49 MB
# [Segment 40] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 41] Training Time = 2.07 sec
# [Segment 41] GPU Memory Start = 2834.49 MB
# [Segment 41] GPU Memory End   = 2834.78 MB
# [Segment 41] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 42] Training Time = 1.78 sec
# [Segment 42] GPU Memory Start = 2834.78 MB
# [Segment 42] GPU Memory End   = 2835.08 MB
# [Segment 42] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 43] Training Time = 4.92 sec
# [Segment 43] GPU Memory Start = 2835.08 MB
# [Segment 43] GPU Memory End   = 2835.37 MB
# [Segment 43] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 44] Training Time = 4.82 sec
# [Segment 44] GPU Memory Start = 2835.37 MB
# [Segment 44] GPU Memory End   = 2835.67 MB
# [Segment 44] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 45] Training Time = 4.82 sec
# [Segment 45] GPU Memory Start = 2835.67 MB
# [Segment 45] GPU Memory End   = 2835.96 MB
# [Segment 45] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 46] Training Time = 4.91 sec
# [Segment 46] GPU Memory Start = 2835.96 MB
# [Segment 46] GPU Memory End   = 2833.31 MB
# [Segment 46] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 47] Training Time = 4.79 sec
# [Segment 47] GPU Memory Start = 2833.31 MB
# [Segment 47] GPU Memory End   = 2833.61 MB
# [Segment 47] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 48] Training Time = 4.89 sec
# [Segment 48] GPU Memory Start = 2833.61 MB
# [Segment 48] GPU Memory End   = 2833.90 MB
# [Segment 48] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 49] Training Time = 4.95 sec
# [Segment 49] GPU Memory Start = 2833.90 MB
# [Segment 49] GPU Memory End   = 2834.20 MB
# [Segment 49] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 50] Training Time = 4.84 sec
# [Segment 50] GPU Memory Start = 2834.20 MB
# [Segment 50] GPU Memory End   = 2834.49 MB
# [Segment 50] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 51] Training Time = 4.91 sec
# [Segment 51] GPU Memory Start = 2834.49 MB
# [Segment 51] GPU Memory End   = 2834.78 MB
# [Segment 51] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 52] Training Time = 4.50 sec
# [Segment 52] GPU Memory Start = 2834.78 MB
# [Segment 52] GPU Memory End   = 2835.08 MB
# [Segment 52] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 53] Training Time = 4.51 sec
# [Segment 53] GPU Memory Start = 2835.08 MB
# [Segment 53] GPU Memory End   = 2835.37 MB
# [Segment 53] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 54] Training Time = 4.81 sec
# [Segment 54] GPU Memory Start = 2835.37 MB
# [Segment 54] GPU Memory End   = 2835.67 MB
# [Segment 54] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 55] Training Time = 2.45 sec
# [Segment 55] GPU Memory Start = 2835.67 MB
# [Segment 55] GPU Memory End   = 2835.96 MB
# [Segment 55] GPU Peak Memory  = 2837.13 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 56] Training Time = 5.01 sec
# [Segment 56] GPU Memory Start = 2835.96 MB
# [Segment 56] GPU Memory End   = 2833.31 MB
# [Segment 56] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 57] Training Time = 2.94 sec
# [Segment 57] GPU Memory Start = 2833.31 MB
# [Segment 57] GPU Memory End   = 2833.61 MB
# [Segment 57] GPU Peak Memory  = 2834.78 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 58] Training Time = 4.85 sec
# [Segment 58] GPU Memory Start = 2833.61 MB
# [Segment 58] GPU Memory End   = 2833.90 MB
# [Segment 58] GPU Peak Memory  = 2835.08 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 59] Training Time = 4.53 sec
# [Segment 59] GPU Memory Start = 2833.90 MB
# [Segment 59] GPU Memory End   = 2834.20 MB
# [Segment 59] GPU Peak Memory  = 2835.37 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 60] Training Time = 4.73 sec
# [Segment 60] GPU Memory Start = 2834.20 MB
# [Segment 60] GPU Memory End   = 2834.49 MB
# [Segment 60] GPU Peak Memory  = 2835.66 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 61] Training Time = 4.79 sec
# [Segment 61] GPU Memory Start = 2834.49 MB
# [Segment 61] GPU Memory End   = 2834.78 MB
# [Segment 61] GPU Peak Memory  = 2835.96 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 62] Training Time = 2.49 sec
# [Segment 62] GPU Memory Start = 2834.78 MB
# [Segment 62] GPU Memory End   = 2835.08 MB
# [Segment 62] GPU Peak Memory  = 2836.25 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 63] Training Time = 4.68 sec
# [Segment 63] GPU Memory Start = 2835.08 MB
# [Segment 63] GPU Memory End   = 2835.37 MB
# [Segment 63] GPU Peak Memory  = 2836.55 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.6406 MB
#   yb per batch = 0.0234 MB, total = 24.9375 MB
#   pv per batch = 0.0078 MB, total = 8.3125 MB
# [Segment 64] Training Time = 4.84 sec
# [Segment 64] GPU Memory Start = 2835.37 MB
# [Segment 64] GPU Memory End   = 2835.67 MB
# [Segment 64] GPU Peak Memory  = 2836.84 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv


base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.13529905676841736  MAE:0.27502620220184326
# ▶ seg0  mean  MSE:0.13529905676841736  MAE:0.27502620220184326
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.16648337244987488  MAE:0.2915116250514984
# ▶ seg1  mean  MSE:0.16648337244987488  MAE:0.2915116250514984
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.14916585385799408  MAE:0.27453914284706116
# ▶ seg2  mean  MSE:0.14916585385799408  MAE:0.27453914284706116
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.1447545439004898  MAE:0.2761056125164032
# ▶ seg3  mean  MSE:0.1447545439004898  MAE:0.2761056125164032
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.14007994532585144  MAE:0.2829720675945282
# ▶ seg4  mean  MSE:0.14007994532585144  MAE:0.2829720675945282
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.141363725066185  MAE:0.28737735748291016
# ▶ seg5  mean  MSE:0.141363725066185  MAE:0.28737735748291016
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.14460238814353943  MAE:0.29400908946990967
# ▶ seg6  mean  MSE:0.14460238814353943  MAE:0.29400908946990967
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.14897574484348297  MAE:0.292096346616745
# ▶ seg7  mean  MSE:0.14897574484348297  MAE:0.292096346616745
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.14334683120250702  MAE:0.2875533998012543
# ▶ seg8  mean  MSE:0.14334683120250702  MAE:0.2875533998012543
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.13760986924171448  MAE:0.2754194438457489
# ▶ seg9  mean  MSE:0.13760986924171448  MAE:0.2754194438457489
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.14251551032066345  MAE:0.27360430359840393
# ▶ seg10  mean  MSE:0.14251551032066345  MAE:0.27360430359840393
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.14863638579845428  MAE:0.29319801926612854
# ▶ seg11  mean  MSE:0.14863638579845428  MAE:0.29319801926612854
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.13974355161190033  MAE:0.28778764605522156
# ▶ seg12  mean  MSE:0.13974355161190033  MAE:0.28778764605522156
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.1439666599035263  MAE:0.2750631272792816
# ▶ seg47  mean  MSE:0.1439666599035263  MAE:0.2750631272792816
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.1545017659664154  MAE:0.2842731475830078
# ▶ seg48  mean  MSE:0.1545017659664154  MAE:0.2842731475830078
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.1479731649160385  MAE:0.27836886048316956
# ▶ seg49  mean  MSE:0.1479731649160385  MAE:0.27836886048316956
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.1355239748954773  MAE:0.27235984802246094
# ▶ seg50  mean  MSE:0.1355239748954773  MAE:0.27235984802246094
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.13665322959423065  MAE:0.2738436162471771
# ▶ seg51  mean  MSE:0.13665322959423065  MAE:0.2738436162471771
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.14408451318740845  MAE:0.2933754324913025
# ▶ seg52  mean  MSE:0.14408451318740845  MAE:0.2933754324913025
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.13917016983032227  MAE:0.2774296998977661
# ▶ seg53  mean  MSE:0.13917016983032227  MAE:0.2774296998977661
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.14521633088588715  MAE:0.2755374312400818
# ▶ seg54  mean  MSE:0.14521633088588715  MAE:0.2755374312400818
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.14325663447380066  MAE:0.27220940589904785
# ▶ seg55  mean  MSE:0.14325663447380066  MAE:0.27220940589904785
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.14736154675483704  MAE:0.27721455693244934
# ▶ seg56  mean  MSE:0.14736154675483704  MAE:0.27721455693244934
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.14697331190109253  MAE:0.2936249375343323
# ▶ seg57  mean  MSE:0.14697331190109253  MAE:0.2936249375343323
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.1397470235824585  MAE:0.2744779884815216
# ▶ seg58  mean  MSE:0.1397470235824585  MAE:0.2744779884815216
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.14760370552539825  MAE:0.27606189250946045
# ▶ seg59  mean  MSE:0.14760370552539825  MAE:0.27606189250946045
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.13986216485500336  MAE:0.2782573699951172
# ▶ seg60  mean  MSE:0.13986216485500336  MAE:0.2782573699951172
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.13975946605205536  MAE:0.2738279104232788
# ▶ seg61  mean  MSE:0.13975946605205536  MAE:0.2738279104232788
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.14263999462127686  MAE:0.280010849237442
# ▶ seg62  mean  MSE:0.14263999462127686  MAE:0.280010849237442
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.1399727463722229  MAE:0.2709263861179352
# ▶ seg63  mean  MSE:0.1399727463722229  MAE:0.2709263861179352
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.1441875547170639  MAE:0.28525757789611816
# ▶ seg64  mean  MSE:0.1441875547170639  MAE:0.28525757789611816
#
# seg10 ch0 MSE : 0.13883175

# %% [markdown]
# # 2nd Inference for Test Set

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 192
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_pv  = True,

)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.10066290199756622  MAE:0.24070684611797333
# ▶ seg0  mean  MSE:0.10066290199756622  MAE:0.24070684611797333
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.11861089617013931  MAE:0.26098448038101196
# ▶ seg1  mean  MSE:0.11861089617013931  MAE:0.26098448038101196
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.09628205746412277  MAE:0.23477233946323395
# ▶ seg54  mean  MSE:0.09628205746412277  MAE:0.23477233946323395
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.09875068813562393  MAE:0.2387876659631729
# ▶ seg55  mean  MSE:0.09875068813562393  MAE:0.2387876659631729
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.0984199047088623  MAE:0.23666484653949738
# ▶ seg56  mean  MSE:0.0984199047088623  MAE:0.23666484653949738
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.09502094984054565  MAE:0.23220416903495789
# ▶ seg57  mean  MSE:0.09502094984054565  MAE:0.23220416903495789
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.10346680879592896  MAE:0.24440865218639374
# ▶ seg58  mean  MSE:0.10346680879592896  MAE:0.24440865218639374
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.10621558874845505  MAE:0.24689464271068573
# ▶ seg59  mean  MSE:0.10621558874845505  MAE:0.24689464271068573
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.10678299516439438  MAE:0.24968189001083374
# ▶ seg60  mean  MSE:0.10678299516439438  MAE:0.24968189001083374
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.10451894998550415  MAE:0.24550534784793854
# ▶ seg61  mean  MSE:0.10451894998550415  MAE:0.24550534784793854
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.09900549799203873  MAE:0.2373075783252716
# ▶ seg62  mean  MSE:0.09900549799203873  MAE:0.2373075783252716
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.10672327876091003  MAE:0.2467200756072998
# ▶ seg63  mean  MSE:0.10672327876091003  MAE:0.2467200756072998
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.0984434187412262  MAE:0.23737861216068268
# ▶ seg64  mean  MSE:0.0984434187412262  MAE:0.23737861216068268
#
# seg10 ch0 MSE : 0.09919336

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 192
seq_len = 336 


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_pv):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_pv    = attach_pv



base_cfg = Configs(
    pred_len         = 192,
    seq_len          = 336 ,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_E1_1E",
    attach_pv  = True,
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.1046939417719841  MAE:0.24593046307563782
# ▶ seg0  mean  MSE:0.1046939417719841  MAE:0.24593046307563782
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.10460499674081802  MAE:0.2488221824169159
# ▶ seg1  mean  MSE:0.10460499674081802  MAE:0.2488221824169159
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.14329975843429565  MAE:0.2906123399734497
# ▶ seg2  mean  MSE:0.14329975843429565  MAE:0.2906123399734497
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.10054942965507507  MAE:0.23946928977966309
# ▶ seg3  mean  MSE:0.10054942965507507  MAE:0.23946928977966309
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.13177776336669922  MAE:0.2755400836467743
# ▶ seg4  mean  MSE:0.13177776336669922  MAE:0.2755400836467743
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.1020217016339302  MAE:0.24149025976657867
# ▶ seg5  mean  MSE:0.1020217016339302  MAE:0.24149025976657867
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.09681524336338043  MAE:0.23444294929504395
# ▶ seg6  mean  MSE:0.09681524336338043  MAE:0.23444294929504395
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.0958654060959816  MAE:0.23361849784851074
# ▶ seg7  mean  MSE:0.0958654060959816  MAE:0.23361849784851074
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.10218536853790283  MAE:0.2421182543039322
# ▶ seg8  mean  MSE:0.10218536853790283  MAE:0.2421182543039322
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.09768429398536682  MAE:0.23717565834522247
# ▶ seg60  mean  MSE:0.09768429398536682  MAE:0.23717565834522247
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.10217491537332535  MAE:0.2420462965965271
# ▶ seg61  mean  MSE:0.10217491537332535  MAE:0.2420462965965271
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.10324589163064957  MAE:0.24492812156677246
# ▶ seg62  mean  MSE:0.10324589163064957  MAE:0.24492812156677246
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.0965612530708313  MAE:0.2337866574525833
# ▶ seg63  mean  MSE:0.0965612530708313  MAE:0.2337866574525833
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.11432457715272903  MAE:0.2568744719028473
# ▶ seg64  mean  MSE:0.11432457715272903  MAE:0.2568744719028473
#
# seg10 ch0 MSE : 0.09851324

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTm2_train = torch.load("./1st_results_ETTm2/train_1st_results.pt")
results1_ETTm2_val = torch.load("./1st_results_ETTm2/val_1st_results.pt")
results1_ETTm2_test = torch.load("./1st_results_ETTm2/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.143961
#
#   Top  1 | seg 48 | MSE 0.134938 (+0.009022)
#   Top  2 | seg 32 | MSE 0.135042 (+0.008919)
#   Top  3 | seg 00 | MSE 0.135299 (+0.008662)
#   Top  4 | seg 62 | MSE 0.135562 (+0.008399)
#   Top  5 | seg 25 | MSE 0.136109 (+0.007851)
#   Top  6 | seg 57 | MSE 0.136172 (+0.007789)
#   Top  7 | seg 33 | MSE 0.136629 (+0.007332)
#   Top  8 | seg 13 | MSE 0.136655 (+0.007306)
#   Top  9 | seg 55 | MSE 0.136693 (+0.007268)
#   Top 10 | seg 26 | MSE 0.136725 (+0.007236)
#   Top 11 | seg 28 | MSE 0.137167 (+0.006794)
#   Top 12 | seg 21 | MSE 0.137569 (+0.006391)
#   Top 13 | seg 09 | MSE 0.137610 (+0.006351)
#   Top 14 | seg 53 | MSE 0.137683 (+0.006278)
#   Top 15 | seg 54 | MSE 0.137684 (+0.006277)
#   Top 16 | seg 16 | MSE 0.138031 (+0.005930)
#   Top 17 | seg 31 | MSE 0.138068 (+0.005892)
#   Top 18 | seg 56 | MSE 0.138077 (+0.005884)
#   Top 19 | seg 60 | MSE 0.138090 (+0.005870)
#   Top 20 | seg 36 | MSE 0.138799 (+0.005161)
#   Top 21 | seg 20 | MSE 0.138853 (+0.005107)
#   Top 22 | seg 61 | MSE 0.139200 (+0.004761)
#   Top 23 | seg 15 | MSE 0.139355 (+0.004606)
#   Top 24 | seg 64 | MSE 0.139420 (+0.004541)
#   Top 25 | seg 30 | MSE 0.139516 (+0.004445)
#   Top 26 | seg 37 | MSE 0.139568 (+0.004393)
#   Top 27 | seg 24 | MSE 0.139569 (+0.004392)
#   Top 28 | seg 38 | MSE 0.139623 (+0.004338)
#   Top 29 | seg 12 | MSE 0.139744 (+0.004217)
#   Top 30 | seg 47 | MSE 0.140006 (+0.003954)
#   Top 31 | seg 04 | MSE 0.140080 (+0.003881)
#   Top 32 | seg 14 | MSE 0.140219 (+0.003742)
#   Top 33 | seg 35 | MSE 0.140543 (+0.003418)
#   Top 34 | seg 29 | MSE 0.140643 (+0.003318)
#   Top 35 | seg 17 | MSE 0.140872 (+0.003089)
#   Top 36 | seg 23 | MSE 0.141339 (+0.002622)
#   Top 37 | seg 05 | MSE 0.141364 (+0.002597)
#   Top 38 | seg 49 | MSE 0.141445 (+0.002516)
#   Top 39 | seg 18 | MSE 0.141671 (+0.002290)
#   Top 40 | seg 63 | MSE 0.141872 (+0.002089)
#   Top 41 | seg 59 | MSE 0.141936 (+0.002025)
#   Top 42 | seg 43 | MSE 0.142338 (+0.001623)
#   Top 43 | seg 44 | MSE 0.142484 (+0.001477)
#   Top 44 | seg 10 | MSE 0.142516 (+0.001445)
#   Top 45 | seg 58 | MSE 0.143012 (+0.000948)
#   Top 46 | seg 45 | MSE 0.143312 (+0.000649)
#   Top 47 | seg 08 | MSE 0.143347 (+0.000614)
#   Top 48 | seg 27 | MSE 0.143455 (+0.000506)
#   Top 49 | seg 46 | MSE 0.143696 (+0.000265)
#   Top 50 | seg 41 | MSE 0.144436 (-0.000475)
#   Top 51 | seg 42 | MSE 0.144459 (-0.000499)
#   Top 52 | seg 06 | MSE 0.144602 (-0.000642)
#   Top 53 | seg 03 | MSE 0.144755 (-0.000794)
#   Top 54 | seg 51 | MSE 0.145113 (-0.001153)
#   Top 55 | seg 19 | MSE 0.146105 (-0.002144)
#   Top 56 | seg 34 | MSE 0.146254 (-0.002293)
#   Top 57 | seg 40 | MSE 0.146328 (-0.002367)
#   Top 58 | seg 52 | MSE 0.147717 (-0.003756)
#   Top 59 | seg 11 | MSE 0.148636 (-0.004676)
#   Top 60 | seg 07 | MSE 0.148976 (-0.005015)
#   Top 61 | seg 02 | MSE 0.149166 (-0.005205)
#   Top 62 | seg 39 | MSE 0.151853 (-0.007892)
#   Top 63 | seg 50 | MSE 0.160487 (-0.016526)
#   Top 64 | seg 01 | MSE 0.166483 (-0.022523)
#   Top 65 | seg 22 | MSE 0.168939 (-0.024978)
#
# Saved top segment indices per channel:
# Channel 0: [48, 32, 0, 62, 25, 57, 33, 13, 55, 26, 28, 21, 9, 53, 54, 16, 31, 56, 60, 36, 20, 61, 15, 64, 30, 37, 24, 38, 12, 47, 4, 14, 35, 29, 17, 23, 5, 49, 18, 63, 59, 43, 44, 10, 58, 45, 8, 27, 46, 41, 42, 6, 3, 51, 19, 34, 40, 52, 11, 7, 2, 39, 50, 1, 22]

# %% [markdown]
# ### 1E->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0
#   Top 52 | seg 46 | MSE 0.146854 (-0.002893)
#   Top 53 | seg 57 | MSE 0.146973 (-0.003013)
#   Top 54 | seg 56 | MSE 0.147362 (-0.003401)
#   Top 55 | seg 11 | MSE 0.147474 (-0.003513)
#   Top 56 | seg 59 | MSE 0.147604 (-0.003643)
#   Top 57 | seg 49 | MSE 0.147973 (-0.004012)
#   Top 58 | seg 15 | MSE 0.149661 (-0.005701)
#   Top 59 | seg 43 | MSE 0.152457 (-0.008496)
#   Top 60 | seg 18 | MSE 0.153948 (-0.009987)
#   Top 61 | seg 39 | MSE 0.154308 (-0.010347)
#   Top 62 | seg 48 | MSE 0.154502 (-0.010541)
#   Top 63 | seg 04 | MSE 0.154579 (-0.010619)
#   Top 64 | seg 29 | MSE 0.158743 (-0.014782)
#   Top 65 | seg 02 | MSE 0.159476 (-0.015515)
#
# Saved top segment indices per channel:
# Channel 0: [23, 50, 35, 12, 51, 5, 24, 7, 36, 45, 3, 8, 38, 41, 0, 16, 37, 30, 10, 32, 13, 6, 20, 34, 22, 53, 33, 1, 58, 61, 60, 63, 42, 28, 21, 40, 9, 44, 17, 62, 26, 55, 14, 47, 52, 64, 19, 54, 27, 31, 25, 46, 57, 56, 11, 59, 49, 15, 43, 18, 39, 48, 4, 29, 2]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTm2_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.093547 | MAE : 0.229941
#   — Var / |Corr| / Score —
#    K= 5 | Var=4.158e-03 | |ρ|=0.9883 | S=1.0000
#    K=10 | Var=4.565e-03 | |ρ|=0.9867 | S=0.9071
#    K=15 | Var=5.029e-03 | |ρ|=0.9862 | S=0.9200
#    K=20 | Var=5.418e-03 | |ρ|=0.9853 | S=0.8929
#    K=25 | Var=5.733e-03 | |ρ|=0.9846 | S=0.8743
#    K=30 | Var=6.344e-03 | |ρ|=0.9835 | S=0.8536
#    K=35 | Var=6.687e-03 | |ρ|=0.9828 | S=0.8289
#    K=40 | Var=7.190e-03 | |ρ|=0.9823 | S=0.8503
#    K=45 | Var=7.798e-03 | |ρ|=0.9811 | S=0.8193 <- pick
#    K=50 | Var=8.305e-03 | |ρ|=0.9806 | S=0.8470
#    K=55 | Var=9.043e-03 | |ρ|=0.9797 | S=0.8571
#    K=60 | Var=9.745e-03 | |ρ|=0.9788 | S=0.8740
#    K=65 | Var=1.166e-02 | |ρ|=0.9774 | S=1.0000
# [Var-Corr]  K=45
#   MSE = 0.094459 | Δ = -0.000912 | Δ% = -0.97%
#   MAE = 0.231373 | Δ = -0.001432 | Δ% = -0.62%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.093547
# Ensemble mean MSE : 0.094459
# Average Δ MSE     : -0.000912
# Average Δ MSE (%) : -0.97%
#
# Vanilla  mean MAE : 0.229941
# Ensemble mean MAE : 0.231373
# Average Δ MAE     : -0.001432
# Average Δ MAE (%) : -0.62%

# %% [markdown]
# ## 1E->1E

# %%
results1_ETTm2_test['ES']['mae_test_EES']
# Out:
# 0.2299414724111557

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTm2_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.1   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.093547 | MAE : 0.229941
#   — Var / |Corr| / Score —
#    K= 5 | Var=3.782e-03 | |ρ|=0.9895 | S=1.1000
#    K=10 | Var=4.943e-03 | |ρ|=0.9878 | S=1.1023
#    K=15 | Var=5.272e-03 | |ρ|=0.9873 | S=1.0997
#    K=20 | Var=5.552e-03 | |ρ|=0.9863 | S=1.0559
#    K=25 | Var=5.769e-03 | |ρ|=0.9858 | S=1.0418
#    K=30 | Var=6.038e-03 | |ρ|=0.9849 | S=0.9957
#    K=35 | Var=6.325e-03 | |ρ|=0.9843 | S=0.9815
#    K=40 | Var=6.731e-03 | |ρ|=0.9833 | S=0.9476
#    K=45 | Var=7.248e-03 | |ρ|=0.9830 | S=0.9875
#    K=50 | Var=8.034e-03 | |ρ|=0.9813 | S=0.9466
#    K=55 | Var=8.878e-03 | |ρ|=0.9801 | S=0.9459 <- pick
#    K=60 | Var=9.764e-03 | |ρ|=0.9792 | S=0.9912
#    K=65 | Var=1.136e-02 | |ρ|=0.9769 | S=1.0000
# [Var-Corr]  K=55
#    MSE = 0.094093 | Δ = -0.000547 | Δ% = -0.58%
#    MAE = 0.231194 | Δ = -0.001253 | Δ% = -0.54%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.093547
# Ensemble mean MSE  : 0.094093
# Average Δ MSE      : -0.000547
# Average Δ MSE (%)  : -0.58%
#
# Vanilla  mean MAE  : 0.229941
# Ensemble mean MAE  : 0.231194
# Average Δ MAE      : -0.001253
# Average Δ MAE (%)  : -0.54%
