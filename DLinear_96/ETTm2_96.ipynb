# %% [markdown]
# # Environment Settings

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.4

# %%
import torch

if torch.cuda.is_available():
    gpu_id = torch.cuda.current_device()
    gpu_name = torch.cuda.get_device_name(gpu_id)
    gpu_capability = torch.cuda.get_device_capability(gpu_id)
    total_memory = torch.cuda.get_device_properties(gpu_id).total_memory
    
    print(f"Total number of GPU: {torch.cuda.device_count()}")  
    print(f"Total GPU memory: {total_memory / 1e9} GB")
    print(f"GPU ID: {gpu_id}")
    print(f"GPU Name: {gpu_name}")
    print(f"GPU Compute Capability: {gpu_capability}")
else:
    print("No GPU is available.")
# Out:
# Total number of GPU: 4
# Total GPU memory: 51.033931776 GB
# GPU ID: 0
# GPU Name: NVIDIA RTX A6000
# GPU Compute Capability: (8, 6)

# %%
import torch


torch.cuda.set_device(3)


print("Current Device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# Current Device: 3
# Device Name: NVIDIA RTX A6000
# device(type='cuda')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../dataset/ETTm2.csv', index_col='date', parse_dates=True)

# %%
data.head()
# Out:
#                           HUFL    HULL       MUFL   MULL   LUFL   LULL  \
# date
# 2016-07-01 00:00:00  41.130001  12.481  36.535999  9.355  4.424  1.311
# 2016-07-01 00:15:00  39.622002  11.309  35.543999  8.551  3.209  1.258
# 2016-07-01 00:30:00  38.868000  10.555  34.365002  7.586  4.435  1.258
# 2016-07-01 00:45:00  35.518002   9.214  32.569000  8.712  4.435  1.215
# 2016-07-01 01:00:00  37.528000  10.136  33.936001  7.532  4.435  1.215
#
#                             OT
# date
# 2016-07-01 00:00:00  38.661999
# 2016-07-01 00:15:00  38.223000
# 2016-07-01 00:30:00  37.344002
# 2016-07-01 00:45:00  37.124001
# 2016-07-01 01:00:00  37.124001

# %%
print(data.dtypes)
print('shape: ', data.shape)
# Out:
# HUFL    float64
# HULL    float64
# MUFL    float64
# MULL    float64
# LUFL    float64
# LULL    float64
# OT      float64
# dtype: object
# shape:  (69680, 7)

# %%
target = data['OT']
features = data.drop(['OT'],axis=1)

# %%
features['DATE'] = features.index.strftime('%Y%m%d%H').astype(int)

# %%
target.index
# Out:
# DatetimeIndex(['2016-07-01 00:00:00', '2016-07-01 00:15:00',
#                '2016-07-01 00:30:00', '2016-07-01 00:45:00',
#                '2016-07-01 01:00:00', '2016-07-01 01:15:00',
#                '2016-07-01 01:30:00', '2016-07-01 01:45:00',
#                '2016-07-01 02:00:00', '2016-07-01 02:15:00',
#                ...
#                '2018-06-26 17:30:00', '2018-06-26 17:45:00',
#                '2018-06-26 18:00:00', '2018-06-26 18:15:00',
#                '2018-06-26 18:30:00', '2018-06-26 18:45:00',
#                '2018-06-26 19:00:00', '2018-06-26 19:15:00',
#                '2018-06-26 19:30:00', '2018-06-26 19:45:00'],
#               dtype='datetime64[ns]', name='date', length=69680, freq=None)

# %%
import torch
import numpy as np
import random

def set_seed(seed=42):
    random.seed(seed)                           
    np.random.seed(seed)                        
    torch.manual_seed(seed)                     
    torch.cuda.manual_seed(seed)                
    torch.cuda.manual_seed_all(seed)            
    torch.backends.cudnn.deterministic = True   
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Model Modification for DLinear (Decomposition-wise Look-ahead Augmentation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Decomposition-Linear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.individual = configs.individual
        self.channels = configs.enc_in
        self.attach_to_trend = configs.attach_to_trend
        self.attach_to_seasonal = configs.attach_to_seasonal
        

        
        kernel_size = 25
        self.decompsition = series_decomp(kernel_size)
        

        
        self.seq_len_trend = self.seq_len + (self.pred_len // 3) if self.attach_to_trend else self.seq_len
        self.seq_len_seasonal = self.seq_len + (self.pred_len // 3) if self.attach_to_seasonal else self.seq_len

        
        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))

                
                
                
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            
            
            
            

    def forward(self, x, ground_truth=None):
        
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if ground_truth is not None:
            kernel_size = 25
            self.decompsition = series_decomp(kernel_size)
            ground_truth_seasonal, ground_truth_trend = self.decompsition(ground_truth)

            
            if self.seq_len_seasonal > self.seq_len:
                ground_truth_seasonal=ground_truth_seasonal.permute(0, 2, 1)
                
                seasonal_init = torch.cat([seasonal_init, ground_truth_seasonal], dim=2)
            if self.seq_len_trend > self.seq_len:
                ground_truth_trend=ground_truth_trend.permute(0, 2, 1)
                
                trend_init = torch.cat([trend_init, ground_truth_trend], dim=2)
        
        
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1)

# %% [markdown]
# # Split the Data

# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset


target = data['OT'].values.reshape(-1, 1)  


seq_len = 336
pred_len = 96




train_points = 12 * 30 * 24 * 4
val_points   = 4  * 30 * 24 * 4
test_points  = 4  * 30 * 24 * 4

border1s = [
    0,
    train_points - seq_len,
    train_points + val_points - seq_len
]
border2s = [
    train_points,
    train_points + val_points,
    train_points + val_points + test_points
]


train = target[border1s[0]:border2s[0]]
val   = target[border1s[1]:border2s[1]]
test  = target[border1s[2]:border2s[2]]


scaler = StandardScaler()
train = scaler.fit_transform(train)
val   = scaler.transform(val)
test  = scaler.transform(test)


def create_inout_sequences_univariate(data, seq_len, pred_len):
    seqs = []
    for i in range(len(data) - seq_len - pred_len + 1):
        seq_x = data[i:i + seq_len]
        seq_y = data[i + seq_len:i + seq_len + pred_len]
        seqs.append((seq_x, seq_y))
    return seqs

train_data = create_inout_sequences_univariate(train, seq_len, pred_len)
val_data   = create_inout_sequences_univariate(val,   seq_len, pred_len)
test_data  = create_inout_sequences_univariate(test,  seq_len, pred_len)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_sequences = torch.tensor([x[0] for x in train_data]).float().to(device)  
train_labels    = torch.tensor([x[1] for x in train_data]).float().to(device)

val_sequences   = torch.tensor([x[0] for x in val_data]).float().to(device)
val_labels      = torch.tensor([x[1] for x in val_data]).float().to(device)

test_sequences  = torch.tensor([x[0] for x in test_data]).float().to(device)
test_labels     = torch.tensor([x[1] for x in test_data]).float().to(device)


print("Train Sequences:", train_sequences.shape)
print("Train Labels:   ", train_labels.shape)
print("Val Sequences:  ", val_sequences.shape)
print("Val Labels:     ", val_labels.shape)
print("Test Sequences: ", test_sequences.shape)
print("Test Labels:    ", test_labels.shape)
# Out:
# Train Sequences: torch.Size([34129, 336, 1])
# Train Labels:    torch.Size([34129, 96, 1])
# Val Sequences:   torch.Size([11425, 336, 1])
# Val Labels:      torch.Size([11425, 96, 1])
# Test Sequences:  torch.Size([11425, 336, 1])
# Test Labels:     torch.Size([11425, 96, 1])

# %%
set_seed(43)

# %%
batch_size = 32


train_dataset = TensorDataset(train_sequences, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)


val_dataset = TensorDataset(val_sequences, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TensorDataset(test_sequences, test_labels)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 1st Model Training (Early Stopping)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
import torch.optim as optim
import os


seq_len = 336
pred_len = 96  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.001, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


class EarlyStopping:
    def __init__(self, patience=3, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta

    def __call__(self, val_loss, model, path):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, path)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), os.path.join(path, 'checkpoint_ES.pth'))
        self.val_loss_min = val_loss




def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    early_stopping = EarlyStopping(patience=args.patience, verbose=True)
    for epoch in range(epochs):
        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')
        
        
        early_stopping(val_loss, model, args.save_path)
        if early_stopping.early_stop:
            print("Early stopping triggered. Stopping training.")
            break


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=10, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.002
# Epoch 0 | Train Loss: 0.10650942863542115 | Val Loss: 0.09414837664895946
# Validation loss decreased (inf --> 0.094148).  Saving model ...
# Updating learning rate to 0.001
# Epoch 1 | Train Loss: 0.09321685751241954 | Val Loss: 0.08790192338533949
# Validation loss decreased (0.094148 --> 0.087902).  Saving model ...
# Updating learning rate to 0.0005
# Epoch 2 | Train Loss: 0.09091208959321274 | Val Loss: 0.0878303051736289
# Validation loss decreased (0.087902 --> 0.087830).  Saving model ...
# Updating learning rate to 0.00025
# Epoch 3 | Train Loss: 0.08935800378037147 | Val Loss: 0.08670828703793504
# Validation loss decreased (0.087830 --> 0.086708).  Saving model ...
# Updating learning rate to 0.000125
# Epoch 4 | Train Loss: 0.08830500149360972 | Val Loss: 0.08528003495774497
# Validation loss decreased (0.086708 --> 0.085280).  Saving model ...
# Updating learning rate to 6.25e-05
# Epoch 5 | Train Loss: 0.08806671494061184 | Val Loss: 0.08390098664969435
# Validation loss decreased (0.085280 --> 0.083901).  Saving model ...
# Updating learning rate to 3.125e-05
# Epoch 6 | Train Loss: 0.08778800305953177 | Val Loss: 0.08356012005193741
# Validation loss decreased (0.083901 --> 0.083560).  Saving model ...
# Updating learning rate to 1.5625e-05
# Epoch 7 | Train Loss: 0.08771763820176719 | Val Loss: 0.08359980079483283
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.8125e-06
# Epoch 8 | Train Loss: 0.08761354831886158 | Val Loss: 0.0836056001489597
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.90625e-06
# Epoch 9 | Train Loss: 0.08759712487556941 | Val Loss: 0.08358134293776558
# EarlyStopping counter: 3 out of 3
# Early stopping triggered. Stopping training.

# %% [markdown]
# # 1st Model Training (1 Epoch)

# %%
import torch.optim as optim
import os



seq_len = 336
pred_len = 96  

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual, learning_rate, lradj, patience, save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len = seq_len
        self.pred_len = pred_len  
        self.enc_in = enc_in
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal

configs = Configs(seq_len=seq_len, pred_len=pred_len, enc_in=1, individual=False,
                   learning_rate=0.001, lradj='type1',  patience=3, save_path="./model_ETTm2", attach_to_trend=False , attach_to_seasonal=False) 


model = Model(configs).to(device)
loss_function = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=configs.learning_rate)

if not os.path.exists(configs.save_path):
    os.makedirs(configs.save_path)


def adjust_learning_rate(optimizer, epoch, args):
    if args.lradj == 'type1':
        lr_adjust = {epoch: args.learning_rate * (0.5 ** ((epoch - 1) // 1))}
    elif args.lradj == 'type2':
        lr_adjust = {
            2: 5e-5, 4: 1e-5, 6: 5e-6, 8: 1e-6,
            10: 5e-7, 15: 1e-7, 20: 5e-8
        }
    elif args.lradj == '3':
        lr_adjust = {epoch: args.learning_rate if epoch < 10 else args.learning_rate*0.1}
    elif args.lradj == '4':
        lr_adjust = {epoch: args.learning_rate if epoch < 15 else args.learning_rate*0.1}
    elif args.lradj == '5':
        lr_adjust = {epoch: args.learning_rate if epoch < 25 else args.learning_rate*0.1}
    elif args.lradj == '6':
        lr_adjust = {epoch: args.learning_rate if epoch < 5 else args.learning_rate*0.1}  

    if epoch in lr_adjust.keys():
        lr = lr_adjust[epoch]
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        print(f'Updating learning rate to {lr}')



def train_model(model, dataloader, val_dataloader, optimizer, loss_function, epochs, pred_len, args):
    
    for epoch in range(epochs):

        if epoch == 1:
            torch.save(model.state_dict(), os.path.join(args.save_path, 'checkpoint_1.pth'))
            print("Model saved at epoch 1")

        total_loss = 0
        model.train()
        
        
        adjust_learning_rate(optimizer, epoch, args)
        
        for batch_sequences, batch_labels in dataloader:
            optimizer.zero_grad()

            
            output = model(batch_sequences)
            
            
            
            output = output[:, -pred_len:, :]  
            batch_labels = batch_labels[:, -pred_len:, :]  
            
            
            assert output.shape == batch_labels.shape, f"Output shape {output.shape} and batch_labels shape {batch_labels.shape} must match"
            
            loss = loss_function(output, batch_labels)  
            
            loss.backward()  
            optimizer.step()  

            total_loss += loss.item()

        
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for val_batch_sequences, val_batch_labels in val_dataloader:
                val_output = model(val_batch_sequences)
                val_output = val_output[:, -args.pred_len:, :]
                val_batch_labels = val_batch_labels[:, -args.pred_len:, :]
                
                val_loss += loss_function(val_output, val_batch_labels).item()
        
        val_loss /= len(val_dataloader)

        
        print(f'Epoch {epoch} | Train Loss: {total_loss / len(dataloader)} | Val Loss: {val_loss}')

    torch.save(model.state_dict(), os.path.join(args.save_path, f'checkpoint_{epochs}.pth'))
    print(f"Model saved at epoch {epochs}")
        
        
        
        
        
        


train_model(model, train_dataloader, val_dataloader, optimizer, loss_function, epochs=1, pred_len=configs.pred_len, args=configs)
# Out:
# Updating learning rate to 0.002
# Epoch 0 | Train Loss: 0.10586185100459561 | Val Loss: 0.08854318095771752
# Model saved at epoch 1

# %% [markdown]
# # Perform Inference and Form Predicted Value (PV) Sequences

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


test_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in test_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    test_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    test_1st_results[ckpt_epoch] = {
        f'mse_test_E{ckpt_epoch}': mse,
        f'mae_test_E{ckpt_epoch}': mae,
        f'test_pv_E{ckpt_epoch}': test_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.0637928694486618 | MAE: 0.18411366641521454
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.06744983792304993 | MAE: 0.19361096620559692

# %%
test_1st_results.keys()
# Out:
# dict_keys(['ES', 1])

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


checkpoint_epochs = ['ES', 1]


val_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in val_dataloader:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    val_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    val_1st_results[ckpt_epoch] = {
        f'mse_val_E{ckpt_epoch}': mse,
        f'mae_val_E{ckpt_epoch}': mae,
        f'val_pv_E{ckpt_epoch}': val_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.08367832750082016 | MAE: 0.20249973237514496
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.08871129900217056 | MAE: 0.2075226902961731

# %%
import torch.optim as optim
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch


train_dataloader_infer = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)


checkpoint_epochs = ['ES', 1]


train_1st_results = {}

for ckpt_epoch in checkpoint_epochs:
    print(f'\n[Predicting with model from epoch {ckpt_epoch}]')

    
    model_path = os.path.join(configs.save_path, f'checkpoint_{ckpt_epoch}.pth')
    
    model = Model(configs).to(device)
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    predictions = []
    actuals = []

    with torch.no_grad():
        for batch_sequence, batch_label in train_dataloader_infer:
            batch_sequence = batch_sequence.float().to(device)
            batch_label = batch_label.float().to(device)

            output = model(batch_sequence)
            output = output[:, -configs.pred_len:, :]
            batch_label = batch_label[:, -configs.pred_len:, :]

            predictions.append(output.detach().cpu().numpy())
            actuals.append(batch_label.detach().cpu().numpy())

    
    predictions = np.concatenate(predictions, axis=0)  
    actuals = np.concatenate(actuals, axis=0)

    
    predictions_flatten = predictions.flatten()
    actuals_flatten = actuals.flatten()

    
    mse = mean_squared_error(actuals_flatten, predictions_flatten)
    mae = mean_absolute_error(actuals_flatten, predictions_flatten)

    print(f'Epoch {ckpt_epoch} | MSE: {mse} | MAE: {mae}')

    
    num_samples = len(predictions_flatten) // configs.pred_len
    train_pv = torch.tensor(
        predictions_flatten.reshape(num_samples, configs.pred_len, 1),
        dtype=torch.float32
    )

    
    train_1st_results[ckpt_epoch] = {
        f'mse_train_E{ckpt_epoch}': mse,
        f'mae_train_E{ckpt_epoch}': mae,
        f'train_pv_E{ckpt_epoch}': train_pv
    }
# Out:
# [Predicting with model from epoch ES]
# Epoch ES | MSE: 0.08765079081058502 | MAE: 0.2049695998430252
#
# [Predicting with model from epoch 1]
# Epoch 1 | MSE: 0.09259067475795746 | MAE: 0.21224822103977203

# %%
print("train_sequences shape: ",train_sequences.shape)
print("val_sequences shape: ",val_sequences.shape)
print("test_sequences shape: ",test_sequences.shape)

print('---------------------------------------------')

print("train_pv shape: ",train_pv.shape)
print("val_pv shape: ",val_pv.shape)
print("test_pv shape: ",test_pv.shape)


print('---------------------------------------------')

print("train_labels shape: ",train_labels.shape)
print("val_labels shape: ",val_labels.shape)
print("test_labels shape: ",test_labels.shape)
# Out:
# train_sequences shape:  torch.Size([34129, 336, 1])
# val_sequences shape:  torch.Size([11425, 336, 1])
# test_sequences shape:  torch.Size([11425, 336, 1])
# ---------------------------------------------
# train_pv shape:  torch.Size([34129, 96, 1])
# val_pv shape:  torch.Size([11425, 96, 1])
# test_pv shape:  torch.Size([11425, 96, 1])
# ---------------------------------------------
# train_labels shape:  torch.Size([34129, 96, 1])
# val_labels shape:  torch.Size([11425, 96, 1])
# test_labels shape:  torch.Size([11425, 96, 1])

# %% [markdown]
# # Segment Generation Function (sliding window-based)

# %%
def create_sliding_segments(predictions, labels, segment_length, stride=1):
    """
    시퀀스에 슬라이딩 윈도우를 stride 간격으로 적용하여
    (B, num_segments, segment_length, C) 형태로 반환합니다.

    Args:
        predictions: Tensor of shape (B, T, C)
        labels: Tensor of shape (B, T, C)
        segment_length: int, 각 세그먼트의 길이 (예: pred_len // 3)
        stride: int, 슬라이딩 윈도우 stride 간격

    Returns:
        pred_segments: (B, num_segments, segment_length, C)
        label_segments: (B, num_segments, segment_length, C)
    """
    B, T, C = predictions.shape
    num_segments = (T - segment_length) // stride + 1

    pred_segments = []
    label_segments = []

    for i in range(0, T - segment_length + 1, stride):
        pred_seg = predictions[:, i:i+segment_length, :]  
        label_seg = labels[:, i:i+segment_length, :]      
        pred_segments.append(pred_seg.unsqueeze(1))       
        label_segments.append(label_seg.unsqueeze(1))

    pred_segments = torch.cat(pred_segments, dim=1)       
    label_segments = torch.cat(label_segments, dim=1)     

    return pred_segments, label_segments

# %% [markdown]
# # Segmentation for PV Sequence

# %%
configs.pred_len
# Out:
# 96

# %%
segment_len = configs.pred_len // 3
stride = 1  

train_segments_by_epoch = {}
val_segments_by_epoch = {}
test_segments_by_epoch = {}

for epoch in checkpoint_epochs:
    train_pv = train_1st_results[epoch][f'train_pv_E{epoch}']  
    val_pv = val_1st_results[epoch][f'val_pv_E{epoch}']        
    test_pv = test_1st_results[epoch][f'test_pv_E{epoch}']     

    
    train_pred_segments, train_label_segments = create_sliding_segments(train_pv, train_labels, segment_len,stride)
    val_pred_segments, val_label_segments = create_sliding_segments(val_pv, val_labels, segment_len, stride)
    test_pred_segments, test_label_segments = create_sliding_segments(test_pv, test_labels, segment_len, stride)

    train_segments_by_epoch[epoch] = {
        f'train_pred_segments_E{epoch}': train_pred_segments,  
        f'train_label_segments_E{epoch}': train_label_segments
    }

    val_segments_by_epoch[epoch] = {
        f'val_pred_segments_E{epoch}': val_pred_segments,
        f'val_label_segments_E{epoch}': val_label_segments
    }

    test_segments_by_epoch[epoch] = {
        f'test_pred_segments_E{epoch}': test_pred_segments,
        f'test_label_segments_E{epoch}': test_label_segments
    }

    
    print(f"[Epoch {epoch}] Train seg shape: {train_pred_segments.shape}, Val: {val_pred_segments.shape}, Test: {test_pred_segments.shape}")
# Out:
# [Epoch ES] Train seg shape: torch.Size([34129, 65, 32, 1]), Val: torch.Size([11425, 65, 32, 1]), Test: torch.Size([11425, 65, 32, 1])
# [Epoch 1] Train seg shape: torch.Size([34129, 65, 32, 1]), Val: torch.Size([11425, 65, 32, 1]), Test: torch.Size([11425, 65, 32, 1])

# %% [markdown]
# ## Save 1st Performance Metrics, PV, and Segment

# %%
save_dir = './1st_results_ETTm2'  
os.makedirs(save_dir, exist_ok=True)


torch.save(train_1st_results, os.path.join(save_dir, 'train_1st_results.pt'))
torch.save(val_1st_results, os.path.join(save_dir, 'val_1st_results.pt'))
torch.save(test_1st_results, os.path.join(save_dir, 'test_1st_results.pt'))


torch.save(train_segments_by_epoch, os.path.join(save_dir, 'train_segments_by_epoch.pt'))
torch.save(val_segments_by_epoch, os.path.join(save_dir, 'val_segments_by_epoch.pt'))
torch.save(test_segments_by_epoch, os.path.join(save_dir, 'test_segments_by_epoch.pt'))

print("✅ All dictionaries saved successfully in ./saved_results")
# Out:
# ✅ All dictionaries saved successfully in ./saved_results

# %% [markdown]
# # 2nd Model Training

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
print(train_segments_by_epoch.keys())
print(train_segments_by_epoch['ES'].keys())
print(train_segments_by_epoch[1].keys())
# Out:
# dict_keys(['ES', 1])
# dict_keys(['train_pred_segments_EES', 'train_label_segments_EES'])
# dict_keys(['train_pred_segments_E1', 'train_label_segments_E1'])

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path
import time


epo = 'ES'

class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 96,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()


for seg in range(len(train_pred_segments_ES[0])):
    print(f"\n=========== Segment {seg} ===========")
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_ES[:, seg, :, :]   
    va_pv = val_pred_segments_ES[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False  

        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True


            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()
        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 0] Training Time = 6.13 sec
# [Segment 0] GPU Memory Start = 1467.99 MB
# [Segment 0] GPU Memory End   = 1468.87 MB
# [Segment 0] GPU Peak Memory  = 1470.05 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 1] Training Time = 5.93 sec
# [Segment 1] GPU Memory Start = 1468.87 MB
# [Segment 1] GPU Memory End   = 1469.14 MB
# [Segment 1] GPU Peak Memory  = 1470.32 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 2] Training Time = 5.95 sec
# [Segment 2] GPU Memory Start = 1469.14 MB
# [Segment 2] GPU Memory End   = 1469.41 MB
# [Segment 2] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 3] Training Time = 5.99 sec
# [Segment 3] GPU Memory Start = 1469.41 MB
# [Segment 3] GPU Memory End   = 1469.68 MB
# [Segment 3] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 4] Training Time = 5.87 sec
# [Segment 4] GPU Memory Start = 1469.68 MB
# [Segment 4] GPU Memory End   = 1469.95 MB
# [Segment 4] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 5] Training Time = 5.72 sec
# [Segment 5] GPU Memory Start = 1469.95 MB
# [Segment 5] GPU Memory End   = 1470.22 MB
# [Segment 5] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 6] Training Time = 5.86 sec
# [Segment 6] GPU Memory Start = 1470.22 MB
# [Segment 6] GPU Memory End   = 1470.49 MB
# [Segment 6] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 7] Training Time = 5.94 sec
# [Segment 7] GPU Memory Start = 1470.49 MB
# [Segment 7] GPU Memory End   = 1470.76 MB
# [Segment 7] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 8] Training Time = 5.87 sec
# [Segment 8] GPU Memory Start = 1468.87 MB
# [Segment 8] GPU Memory End   = 1469.14 MB
# [Segment 8] GPU Peak Memory  = 1470.32 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 9] Training Time = 5.85 sec
# [Segment 9] GPU Memory Start = 1469.14 MB
# [Segment 9] GPU Memory End   = 1469.41 MB
# [Segment 9] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 10] Training Time = 5.85 sec
# [Segment 10] GPU Memory Start = 1469.41 MB
# [Segment 10] GPU Memory End   = 1469.68 MB
# [Segment 10] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 11] Training Time = 5.82 sec
# [Segment 11] GPU Memory Start = 1469.68 MB
# [Segment 11] GPU Memory End   = 1469.95 MB
# [Segment 11] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 12] Training Time = 5.23 sec
# [Segment 12] GPU Memory Start = 1469.95 MB
# [Segment 12] GPU Memory End   = 1470.22 MB
# [Segment 12] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 13] Training Time = 3.75 sec
# [Segment 13] GPU Memory Start = 1470.22 MB
# [Segment 13] GPU Memory End   = 1470.49 MB
# [Segment 13] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 14] Training Time = 5.94 sec
# [Segment 14] GPU Memory Start = 1470.49 MB
# [Segment 14] GPU Memory End   = 1470.76 MB
# [Segment 14] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 15] Training Time = 5.62 sec
# [Segment 15] GPU Memory Start = 1470.76 MB
# [Segment 15] GPU Memory End   = 1471.03 MB
# [Segment 15] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 16] Training Time = 5.83 sec
# [Segment 16] GPU Memory Start = 1471.03 MB
# [Segment 16] GPU Memory End   = 1471.30 MB
# [Segment 16] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 17] Training Time = 5.67 sec
# [Segment 17] GPU Memory Start = 1471.30 MB
# [Segment 17] GPU Memory End   = 1468.87 MB
# [Segment 17] GPU Peak Memory  = 1471.57 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 18] Training Time = 5.88 sec
# [Segment 18] GPU Memory Start = 1468.87 MB
# [Segment 18] GPU Memory End   = 1469.14 MB
# [Segment 18] GPU Peak Memory  = 1470.32 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 19] Training Time = 5.87 sec
# [Segment 19] GPU Memory Start = 1469.14 MB
# [Segment 19] GPU Memory End   = 1469.41 MB
# [Segment 19] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 20] Training Time = 5.76 sec
# [Segment 20] GPU Memory Start = 1469.41 MB
# [Segment 20] GPU Memory End   = 1469.68 MB
# [Segment 20] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 21] Training Time = 4.85 sec
# [Segment 21] GPU Memory Start = 1469.68 MB
# [Segment 21] GPU Memory End   = 1469.95 MB
# [Segment 21] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 22] Training Time = 5.53 sec
# [Segment 22] GPU Memory Start = 1469.95 MB
# [Segment 22] GPU Memory End   = 1470.22 MB
# [Segment 22] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 23] Training Time = 5.57 sec
# [Segment 23] GPU Memory Start = 1470.22 MB
# [Segment 23] GPU Memory End   = 1470.49 MB
# [Segment 23] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 24] Training Time = 5.84 sec
# [Segment 24] GPU Memory Start = 1470.49 MB
# [Segment 24] GPU Memory End   = 1470.76 MB
# [Segment 24] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 25] Training Time = 5.81 sec
# [Segment 25] GPU Memory Start = 1470.76 MB
# [Segment 25] GPU Memory End   = 1471.03 MB
# [Segment 25] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 26] Training Time = 5.95 sec
# [Segment 26] GPU Memory Start = 1471.03 MB
# [Segment 26] GPU Memory End   = 1471.30 MB
# [Segment 26] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 27] Training Time = 5.83 sec
# [Segment 27] GPU Memory Start = 1468.87 MB
# [Segment 27] GPU Memory End   = 1469.14 MB
# [Segment 27] GPU Peak Memory  = 1470.32 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 28] Training Time = 5.87 sec
# [Segment 28] GPU Memory Start = 1469.14 MB
# [Segment 28] GPU Memory End   = 1469.41 MB
# [Segment 28] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 29] Training Time = 5.95 sec
# [Segment 29] GPU Memory Start = 1469.41 MB
# [Segment 29] GPU Memory End   = 1469.68 MB
# [Segment 29] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 30] Training Time = 4.90 sec
# [Segment 30] GPU Memory Start = 1469.68 MB
# [Segment 30] GPU Memory End   = 1469.95 MB
# [Segment 30] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 31] Training Time = 5.96 sec
# [Segment 31] GPU Memory Start = 1469.95 MB
# [Segment 31] GPU Memory End   = 1470.22 MB
# [Segment 31] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 32] Training Time = 5.90 sec
# [Segment 32] GPU Memory Start = 1470.22 MB
# [Segment 32] GPU Memory End   = 1470.49 MB
# [Segment 32] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 33] Training Time = 5.84 sec
# [Segment 33] GPU Memory Start = 1470.49 MB
# [Segment 33] GPU Memory End   = 1470.76 MB
# [Segment 33] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 34] Training Time = 5.91 sec
# [Segment 34] GPU Memory Start = 1470.76 MB
# [Segment 34] GPU Memory End   = 1471.03 MB
# [Segment 34] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 35] Training Time = 5.81 sec
# [Segment 35] GPU Memory Start = 1471.03 MB
# [Segment 35] GPU Memory End   = 1471.30 MB
# [Segment 35] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 36] Training Time = 5.69 sec
# [Segment 36] GPU Memory Start = 1471.30 MB
# [Segment 36] GPU Memory End   = 1469.14 MB
# [Segment 36] GPU Peak Memory  = 1471.57 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 37] Training Time = 5.94 sec
# [Segment 37] GPU Memory Start = 1469.14 MB
# [Segment 37] GPU Memory End   = 1469.41 MB
# [Segment 37] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 38] Training Time = 4.98 sec
# [Segment 38] GPU Memory Start = 1469.41 MB
# [Segment 38] GPU Memory End   = 1469.68 MB
# [Segment 38] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 39] Training Time = 5.71 sec
# [Segment 39] GPU Memory Start = 1469.68 MB
# [Segment 39] GPU Memory End   = 1469.95 MB
# [Segment 39] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 40] Training Time = 4.64 sec
# [Segment 40] GPU Memory Start = 1469.95 MB
# [Segment 40] GPU Memory End   = 1470.22 MB
# [Segment 40] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 41] Training Time = 5.77 sec
# [Segment 41] GPU Memory Start = 1470.22 MB
# [Segment 41] GPU Memory End   = 1470.49 MB
# [Segment 41] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 42] Training Time = 5.75 sec
# [Segment 42] GPU Memory Start = 1470.49 MB
# [Segment 42] GPU Memory End   = 1470.76 MB
# [Segment 42] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 43] Training Time = 5.87 sec
# [Segment 43] GPU Memory Start = 1470.76 MB
# [Segment 43] GPU Memory End   = 1471.03 MB
# [Segment 43] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 44] Training Time = 5.94 sec
# [Segment 44] GPU Memory Start = 1471.03 MB
# [Segment 44] GPU Memory End   = 1471.30 MB
# [Segment 44] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 45] Training Time = 5.90 sec
# [Segment 45] GPU Memory Start = 1471.30 MB
# [Segment 45] GPU Memory End   = 1471.57 MB
# [Segment 45] GPU Peak Memory  = 1472.75 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 46] Training Time = 5.83 sec
# [Segment 46] GPU Memory Start = 1469.14 MB
# [Segment 46] GPU Memory End   = 1469.41 MB
# [Segment 46] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 47] Training Time = 5.62 sec
# [Segment 47] GPU Memory Start = 1469.41 MB
# [Segment 47] GPU Memory End   = 1469.68 MB
# [Segment 47] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 48] Training Time = 5.72 sec
# [Segment 48] GPU Memory Start = 1469.68 MB
# [Segment 48] GPU Memory End   = 1469.95 MB
# [Segment 48] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 49] Training Time = 5.52 sec
# [Segment 49] GPU Memory Start = 1469.95 MB
# [Segment 49] GPU Memory End   = 1470.22 MB
# [Segment 49] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 50] Training Time = 5.74 sec
# [Segment 50] GPU Memory Start = 1470.22 MB
# [Segment 50] GPU Memory End   = 1470.49 MB
# [Segment 50] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 51] Training Time = 5.63 sec
# [Segment 51] GPU Memory Start = 1470.49 MB
# [Segment 51] GPU Memory End   = 1470.76 MB
# [Segment 51] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 52] Training Time = 5.76 sec
# [Segment 52] GPU Memory Start = 1470.76 MB
# [Segment 52] GPU Memory End   = 1471.03 MB
# [Segment 52] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 53] Training Time = 5.77 sec
# [Segment 53] GPU Memory Start = 1471.03 MB
# [Segment 53] GPU Memory End   = 1471.30 MB
# [Segment 53] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 54] Training Time = 5.49 sec
# [Segment 54] GPU Memory Start = 1471.30 MB
# [Segment 54] GPU Memory End   = 1471.57 MB
# [Segment 54] GPU Peak Memory  = 1472.75 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 55] Training Time = 5.87 sec
# [Segment 55] GPU Memory Start = 1471.57 MB
# [Segment 55] GPU Memory End   = 1469.41 MB
# [Segment 55] GPU Peak Memory  = 1471.84 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 56] Training Time = 5.82 sec
# [Segment 56] GPU Memory Start = 1469.41 MB
# [Segment 56] GPU Memory End   = 1469.68 MB
# [Segment 56] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 57] Training Time = 5.81 sec
# [Segment 57] GPU Memory Start = 1469.68 MB
# [Segment 57] GPU Memory End   = 1469.95 MB
# [Segment 57] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 58] Training Time = 5.84 sec
# [Segment 58] GPU Memory Start = 1469.95 MB
# [Segment 58] GPU Memory End   = 1470.22 MB
# [Segment 58] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 59] Training Time = 5.78 sec
# [Segment 59] GPU Memory Start = 1470.22 MB
# [Segment 59] GPU Memory End   = 1470.49 MB
# [Segment 59] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 60] Training Time = 5.78 sec
# [Segment 60] GPU Memory Start = 1470.49 MB
# [Segment 60] GPU Memory End   = 1470.76 MB
# [Segment 60] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 61] Training Time = 5.87 sec
# [Segment 61] GPU Memory Start = 1470.76 MB
# [Segment 61] GPU Memory End   = 1471.03 MB
# [Segment 61] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 62] Training Time = 5.88 sec
# [Segment 62] GPU Memory Start = 1471.03 MB
# [Segment 62] GPU Memory End   = 1471.30 MB
# [Segment 62] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 63] Training Time = 5.71 sec
# [Segment 63] GPU Memory Start = 1471.30 MB
# [Segment 63] GPU Memory End   = 1471.57 MB
# [Segment 63] GPU Peak Memory  = 1472.75 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 64] Training Time = 5.87 sec
# [Segment 64] GPU Memory Start = 1471.57 MB
# [Segment 64] GPU Memory End   = 1471.84 MB
# [Segment 64] GPU Peak Memory  = 1473.03 MB
#
# ============= Done =============

# %% [markdown]
# ## 1E->1E

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


epo = 1


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal



base_cfg = Configs(
    seq_len          = 336 + pred_len//3,
    pred_len         = 96,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = f"./model2_ETTm2_E{epo}_1E/",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

loss_fn = nn.MSELoss()



for seg in range(len(train_pred_segments_E1[0])):
    print(f"\n=========== Segment {seg} ===========")
    
    start_time = time.time()

    
    torch.cuda.reset_peak_memory_stats(device)
    mem_start = torch.cuda.memory_allocated(device)

    
    tr_pv = train_pred_segments_E1[:, seg, :, :]   
    va_pv = val_pred_segments_E1[:,  seg, :, :]

    tr_ds = TensorDataset(train_sequences, train_labels, tr_pv)
    va_ds = TensorDataset(val_sequences,   val_labels,   va_pv)
    tr_dl = DataLoader(tr_ds, batch_size=32, shuffle=True)
    va_dl = DataLoader(va_ds, batch_size=32, shuffle=False)

    
    model = Model(base_cfg).to(device)
    C     = model.channels                                    

    opts = []
    for c in range(C):
        params = list(model.Linear_Seasonal[c].parameters()) + \
                 list(model.Linear_Trend[c].parameters())
        opts.append(optim.Adam(params, lr=base_cfg.learning_rate))
        path = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}"
        path.mkdir(parents=True, exist_ok=True)
        
    active = set(range(C))            

    
    for epoch in range(1, 2):
        if not active: break          

        
        model.train()
        for c in active:                              
            if base_cfg.lradj=='type1':
                lr = base_cfg.learning_rate * 0.5**((epoch-1)//1)
                for g in opts[c].param_groups: g['lr'] = lr

        printed_tensor_info = False
        
        for xb, yb, pv in tr_dl:
            xb, yb, pv = xb.float().to(device), yb.float().to(device), pv.float().to(device)

            if not printed_tensor_info:
                
                xb_size = xb.numel() * xb.element_size() / 1024**2
                yb_size = yb.numel() * yb.element_size() / 1024**2
                pv_size = pv.numel() * pv.element_size() / 1024**2

                
                
                num_batches = len(tr_dl)

                
                total_xb_MB = num_batches * xb_size
                total_yb_MB = num_batches * yb_size
                total_pv_MB = num_batches * pv_size
                


                print(f"[Segment {seg}] Batch Size Info:")
                print(f"  xb per batch = {xb_size:.4f} MB, total = {total_xb_MB:.4f} MB")
                print(f"  yb per batch = {yb_size:.4f} MB, total = {total_yb_MB:.4f} MB")
                print(f"  pv per batch = {pv_size:.4f} MB, total = {total_pv_MB:.4f} MB")

                printed_tensor_info = True



            out = model(xb, pv)                       

            loss_list = []
            for c in active:
                pred = out[:, -base_cfg.pred_len:, c]
                tgt  = yb[:, -base_cfg.pred_len:, c]
                loss_list.append(loss_fn(pred, tgt))

            total = torch.stack(loss_list).sum()
            for opt in opts:
                if opt: opt.zero_grad()
            total.backward()
            for c in active:
                opts[c].step()

        
    elapsed = time.time() - start_time
    mem_end = torch.cuda.memory_allocated(device)
    peak_mem = torch.cuda.max_memory_allocated(device)


    print(f"[Segment {seg}] Training Time = {elapsed:.2f} sec")
    print(f"[Segment {seg}] GPU Memory Start = {mem_start/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Memory End   = {mem_end/1024**2:.2f} MB")
    print(f"[Segment {seg}] GPU Peak Memory  = {peak_mem/1024**2:.2f} MB")

    print(f"\n============= Done =============")

    
    torch.save(model.state_dict(),
                Path(base_cfg.save_path) / f"seg{seg}" / f"ch{c}" / "checkpoint.pth")
    del model, opts; torch.cuda.empty_cache()
# Out:
# =========== Segment 0 ===========
# [Segment 0] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 0] Training Time = 5.94 sec
# [Segment 0] GPU Memory Start = 1469.41 MB
# [Segment 0] GPU Memory End   = 1469.68 MB
# [Segment 0] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 1 ===========
# [Segment 1] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 1] Training Time = 5.83 sec
# [Segment 1] GPU Memory Start = 1469.68 MB
# [Segment 1] GPU Memory End   = 1469.68 MB
# [Segment 1] GPU Peak Memory  = 1471.12 MB
#
# ============= Done =============
#
# =========== Segment 2 ===========
# [Segment 2] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 2] Training Time = 5.69 sec
# [Segment 2] GPU Memory Start = 1469.68 MB
# [Segment 2] GPU Memory End   = 1469.95 MB
# [Segment 2] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 3 ===========
# [Segment 3] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 3] Training Time = 5.82 sec
# [Segment 3] GPU Memory Start = 1469.95 MB
# [Segment 3] GPU Memory End   = 1470.22 MB
# [Segment 3] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 4 ===========
# [Segment 4] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 4] Training Time = 5.76 sec
# [Segment 4] GPU Memory Start = 1470.22 MB
# [Segment 4] GPU Memory End   = 1470.49 MB
# [Segment 4] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 5 ===========
# [Segment 5] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 5] Training Time = 5.68 sec
# [Segment 5] GPU Memory Start = 1470.49 MB
# [Segment 5] GPU Memory End   = 1470.76 MB
# [Segment 5] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 6 ===========
# [Segment 6] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 6] Training Time = 5.65 sec
# [Segment 6] GPU Memory Start = 1470.76 MB
# [Segment 6] GPU Memory End   = 1471.03 MB
# [Segment 6] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 7 ===========
# [Segment 7] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 7] Training Time = 5.79 sec
# [Segment 7] GPU Memory Start = 1471.03 MB
# [Segment 7] GPU Memory End   = 1471.30 MB
# [Segment 7] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 8 ===========
# [Segment 8] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 8] Training Time = 5.74 sec
# [Segment 8] GPU Memory Start = 1471.30 MB
# [Segment 8] GPU Memory End   = 1471.57 MB
# [Segment 8] GPU Peak Memory  = 1472.75 MB
#
# ============= Done =============
#
# =========== Segment 9 ===========
# [Segment 9] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 9] Training Time = 5.64 sec
# [Segment 9] GPU Memory Start = 1471.57 MB
# [Segment 9] GPU Memory End   = 1471.84 MB
# [Segment 9] GPU Peak Memory  = 1473.03 MB
#
# ============= Done =============
#
# =========== Segment 10 ===========
# [Segment 10] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 10] Training Time = 4.41 sec
# [Segment 10] GPU Memory Start = 1471.84 MB
# [Segment 10] GPU Memory End   = 1472.11 MB
# [Segment 10] GPU Peak Memory  = 1473.30 MB
#
# ============= Done =============
#
# =========== Segment 11 ===========
# [Segment 11] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 11] Training Time = 5.70 sec
# [Segment 11] GPU Memory Start = 1468.87 MB
# [Segment 11] GPU Memory End   = 1469.14 MB
# [Segment 11] GPU Peak Memory  = 1470.32 MB
#
# ============= Done =============
#
# =========== Segment 12 ===========
# [Segment 12] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 12] Training Time = 5.38 sec
# [Segment 12] GPU Memory Start = 1469.14 MB
# [Segment 12] GPU Memory End   = 1469.41 MB
# [Segment 12] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 13 ===========
# [Segment 13] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 13] Training Time = 5.37 sec
# [Segment 13] GPU Memory Start = 1469.41 MB
# [Segment 13] GPU Memory End   = 1469.68 MB
# [Segment 13] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 14 ===========
# [Segment 14] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 14] Training Time = 5.95 sec
# [Segment 14] GPU Memory Start = 1469.68 MB
# [Segment 14] GPU Memory End   = 1469.95 MB
# [Segment 14] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 15 ===========
# [Segment 15] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 15] Training Time = 3.78 sec
# [Segment 15] GPU Memory Start = 1469.95 MB
# [Segment 15] GPU Memory End   = 1470.22 MB
# [Segment 15] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 16 ===========
# [Segment 16] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 16] Training Time = 5.93 sec
# [Segment 16] GPU Memory Start = 1470.22 MB
# [Segment 16] GPU Memory End   = 1470.49 MB
# [Segment 16] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 17 ===========
# [Segment 17] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 17] Training Time = 5.88 sec
# [Segment 17] GPU Memory Start = 1470.49 MB
# [Segment 17] GPU Memory End   = 1470.76 MB
# [Segment 17] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 18 ===========
# [Segment 18] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 18] Training Time = 5.35 sec
# [Segment 18] GPU Memory Start = 1470.76 MB
# [Segment 18] GPU Memory End   = 1471.03 MB
# [Segment 18] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 19 ===========
# [Segment 19] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 19] Training Time = 5.86 sec
# [Segment 19] GPU Memory Start = 1471.03 MB
# [Segment 19] GPU Memory End   = 1471.30 MB
# [Segment 19] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 20 ===========
# [Segment 20] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 20] Training Time = 6.00 sec
# [Segment 20] GPU Memory Start = 1471.30 MB
# [Segment 20] GPU Memory End   = 1468.87 MB
# [Segment 20] GPU Peak Memory  = 1471.57 MB
#
# ============= Done =============
#
# =========== Segment 21 ===========
# [Segment 21] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 21] Training Time = 5.67 sec
# [Segment 21] GPU Memory Start = 1468.87 MB
# [Segment 21] GPU Memory End   = 1469.14 MB
# [Segment 21] GPU Peak Memory  = 1470.32 MB
#
# ============= Done =============
#
# =========== Segment 22 ===========
# [Segment 22] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 22] Training Time = 5.79 sec
# [Segment 22] GPU Memory Start = 1469.14 MB
# [Segment 22] GPU Memory End   = 1469.41 MB
# [Segment 22] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 23 ===========
# [Segment 23] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 23] Training Time = 5.84 sec
# [Segment 23] GPU Memory Start = 1469.41 MB
# [Segment 23] GPU Memory End   = 1469.68 MB
# [Segment 23] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 24 ===========
# [Segment 24] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 24] Training Time = 5.69 sec
# [Segment 24] GPU Memory Start = 1469.68 MB
# [Segment 24] GPU Memory End   = 1468.87 MB
# [Segment 24] GPU Peak Memory  = 1470.30 MB
#
# ============= Done =============
#
# =========== Segment 25 ===========
# [Segment 25] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 25] Training Time = 5.85 sec
# [Segment 25] GPU Memory Start = 1468.87 MB
# [Segment 25] GPU Memory End   = 1469.14 MB
# [Segment 25] GPU Peak Memory  = 1470.32 MB
#
# ============= Done =============
#
# =========== Segment 26 ===========
# [Segment 26] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 26] Training Time = 5.12 sec
# [Segment 26] GPU Memory Start = 1469.14 MB
# [Segment 26] GPU Memory End   = 1469.41 MB
# [Segment 26] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 27 ===========
# [Segment 27] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 27] Training Time = 5.40 sec
# [Segment 27] GPU Memory Start = 1469.41 MB
# [Segment 27] GPU Memory End   = 1469.68 MB
# [Segment 27] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 28 ===========
# [Segment 28] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 28] Training Time = 5.89 sec
# [Segment 28] GPU Memory Start = 1469.68 MB
# [Segment 28] GPU Memory End   = 1469.95 MB
# [Segment 28] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 29 ===========
# [Segment 29] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 29] Training Time = 5.77 sec
# [Segment 29] GPU Memory Start = 1469.95 MB
# [Segment 29] GPU Memory End   = 1470.22 MB
# [Segment 29] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 30 ===========
# [Segment 30] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 30] Training Time = 4.51 sec
# [Segment 30] GPU Memory Start = 1470.22 MB
# [Segment 30] GPU Memory End   = 1470.49 MB
# [Segment 30] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 31 ===========
# [Segment 31] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 31] Training Time = 5.85 sec
# [Segment 31] GPU Memory Start = 1470.49 MB
# [Segment 31] GPU Memory End   = 1470.76 MB
# [Segment 31] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 32 ===========
# [Segment 32] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 32] Training Time = 5.87 sec
# [Segment 32] GPU Memory Start = 1470.76 MB
# [Segment 32] GPU Memory End   = 1468.87 MB
# [Segment 32] GPU Peak Memory  = 1471.03 MB
#
# ============= Done =============
#
# =========== Segment 33 ===========
# [Segment 33] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 33] Training Time = 5.92 sec
# [Segment 33] GPU Memory Start = 1468.87 MB
# [Segment 33] GPU Memory End   = 1469.14 MB
# [Segment 33] GPU Peak Memory  = 1470.32 MB
#
# ============= Done =============
#
# =========== Segment 34 ===========
# [Segment 34] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 34] Training Time = 5.71 sec
# [Segment 34] GPU Memory Start = 1469.14 MB
# [Segment 34] GPU Memory End   = 1469.41 MB
# [Segment 34] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 35 ===========
# [Segment 35] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 35] Training Time = 5.86 sec
# [Segment 35] GPU Memory Start = 1469.41 MB
# [Segment 35] GPU Memory End   = 1469.68 MB
# [Segment 35] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 36 ===========
# [Segment 36] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 36] Training Time = 5.70 sec
# [Segment 36] GPU Memory Start = 1469.68 MB
# [Segment 36] GPU Memory End   = 1469.95 MB
# [Segment 36] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 37 ===========
# [Segment 37] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 37] Training Time = 5.84 sec
# [Segment 37] GPU Memory Start = 1469.95 MB
# [Segment 37] GPU Memory End   = 1470.22 MB
# [Segment 37] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 38 ===========
# [Segment 38] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 38] Training Time = 3.82 sec
# [Segment 38] GPU Memory Start = 1470.22 MB
# [Segment 38] GPU Memory End   = 1470.49 MB
# [Segment 38] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 39 ===========
# [Segment 39] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 39] Training Time = 5.87 sec
# [Segment 39] GPU Memory Start = 1470.49 MB
# [Segment 39] GPU Memory End   = 1470.76 MB
# [Segment 39] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 40 ===========
# [Segment 40] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 40] Training Time = 5.55 sec
# [Segment 40] GPU Memory Start = 1470.76 MB
# [Segment 40] GPU Memory End   = 1471.03 MB
# [Segment 40] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 41 ===========
# [Segment 41] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 41] Training Time = 5.66 sec
# [Segment 41] GPU Memory Start = 1471.03 MB
# [Segment 41] GPU Memory End   = 1471.30 MB
# [Segment 41] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 42 ===========
# [Segment 42] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 42] Training Time = 4.78 sec
# [Segment 42] GPU Memory Start = 1468.87 MB
# [Segment 42] GPU Memory End   = 1469.14 MB
# [Segment 42] GPU Peak Memory  = 1470.32 MB
#
# ============= Done =============
#
# =========== Segment 43 ===========
# [Segment 43] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 43] Training Time = 5.78 sec
# [Segment 43] GPU Memory Start = 1469.14 MB
# [Segment 43] GPU Memory End   = 1469.41 MB
# [Segment 43] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 44 ===========
# [Segment 44] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 44] Training Time = 5.79 sec
# [Segment 44] GPU Memory Start = 1469.41 MB
# [Segment 44] GPU Memory End   = 1469.68 MB
# [Segment 44] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 45 ===========
# [Segment 45] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 45] Training Time = 5.70 sec
# [Segment 45] GPU Memory Start = 1469.68 MB
# [Segment 45] GPU Memory End   = 1469.95 MB
# [Segment 45] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 46 ===========
# [Segment 46] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 46] Training Time = 5.83 sec
# [Segment 46] GPU Memory Start = 1469.95 MB
# [Segment 46] GPU Memory End   = 1470.22 MB
# [Segment 46] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 47 ===========
# [Segment 47] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 47] Training Time = 5.77 sec
# [Segment 47] GPU Memory Start = 1470.22 MB
# [Segment 47] GPU Memory End   = 1470.49 MB
# [Segment 47] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 48 ===========
# [Segment 48] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 48] Training Time = 5.54 sec
# [Segment 48] GPU Memory Start = 1470.49 MB
# [Segment 48] GPU Memory End   = 1470.76 MB
# [Segment 48] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 49 ===========
# [Segment 49] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 49] Training Time = 5.81 sec
# [Segment 49] GPU Memory Start = 1470.76 MB
# [Segment 49] GPU Memory End   = 1471.03 MB
# [Segment 49] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 50 ===========
# [Segment 50] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 50] Training Time = 5.30 sec
# [Segment 50] GPU Memory Start = 1471.03 MB
# [Segment 50] GPU Memory End   = 1471.30 MB
# [Segment 50] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 51 ===========
# [Segment 51] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 51] Training Time = 5.96 sec
# [Segment 51] GPU Memory Start = 1471.30 MB
# [Segment 51] GPU Memory End   = 1469.14 MB
# [Segment 51] GPU Peak Memory  = 1471.57 MB
#
# ============= Done =============
#
# =========== Segment 52 ===========
# [Segment 52] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 52] Training Time = 5.84 sec
# [Segment 52] GPU Memory Start = 1469.14 MB
# [Segment 52] GPU Memory End   = 1469.41 MB
# [Segment 52] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 53 ===========
# [Segment 53] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 53] Training Time = 5.93 sec
# [Segment 53] GPU Memory Start = 1469.41 MB
# [Segment 53] GPU Memory End   = 1469.68 MB
# [Segment 53] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 54 ===========
# [Segment 54] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 54] Training Time = 5.87 sec
# [Segment 54] GPU Memory Start = 1469.68 MB
# [Segment 54] GPU Memory End   = 1469.95 MB
# [Segment 54] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 55 ===========
# [Segment 55] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 55] Training Time = 5.64 sec
# [Segment 55] GPU Memory Start = 1469.95 MB
# [Segment 55] GPU Memory End   = 1470.22 MB
# [Segment 55] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============
#
# =========== Segment 56 ===========
# [Segment 56] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 56] Training Time = 5.23 sec
# [Segment 56] GPU Memory Start = 1470.22 MB
# [Segment 56] GPU Memory End   = 1470.49 MB
# [Segment 56] GPU Peak Memory  = 1471.67 MB
#
# ============= Done =============
#
# =========== Segment 57 ===========
# [Segment 57] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 57] Training Time = 5.85 sec
# [Segment 57] GPU Memory Start = 1470.49 MB
# [Segment 57] GPU Memory End   = 1470.76 MB
# [Segment 57] GPU Peak Memory  = 1471.94 MB
#
# ============= Done =============
#
# =========== Segment 58 ===========
# [Segment 58] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 58] Training Time = 5.97 sec
# [Segment 58] GPU Memory Start = 1470.76 MB
# [Segment 58] GPU Memory End   = 1471.03 MB
# [Segment 58] GPU Peak Memory  = 1472.21 MB
#
# ============= Done =============
#
# =========== Segment 59 ===========
# [Segment 59] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 59] Training Time = 5.79 sec
# [Segment 59] GPU Memory Start = 1471.03 MB
# [Segment 59] GPU Memory End   = 1471.30 MB
# [Segment 59] GPU Peak Memory  = 1472.48 MB
#
# ============= Done =============
#
# =========== Segment 60 ===========
# [Segment 60] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 60] Training Time = 5.71 sec
# [Segment 60] GPU Memory Start = 1471.30 MB
# [Segment 60] GPU Memory End   = 1471.57 MB
# [Segment 60] GPU Peak Memory  = 1472.75 MB
#
# ============= Done =============
#
# =========== Segment 61 ===========
# [Segment 61] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 61] Training Time = 5.30 sec
# [Segment 61] GPU Memory Start = 1469.14 MB
# [Segment 61] GPU Memory End   = 1469.41 MB
# [Segment 61] GPU Peak Memory  = 1470.59 MB
#
# ============= Done =============
#
# =========== Segment 62 ===========
# [Segment 62] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 62] Training Time = 6.01 sec
# [Segment 62] GPU Memory Start = 1469.41 MB
# [Segment 62] GPU Memory End   = 1469.68 MB
# [Segment 62] GPU Peak Memory  = 1470.86 MB
#
# ============= Done =============
#
# =========== Segment 63 ===========
# [Segment 63] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 63] Training Time = 5.99 sec
# [Segment 63] GPU Memory Start = 1469.68 MB
# [Segment 63] GPU Memory End   = 1469.95 MB
# [Segment 63] GPU Peak Memory  = 1471.13 MB
#
# ============= Done =============
#
# =========== Segment 64 ===========
# [Segment 64] Batch Size Info:
#   xb per batch = 0.0410 MB, total = 43.7637 MB
#   yb per batch = 0.0117 MB, total = 12.5039 MB
#   pv per batch = 0.0039 MB, total = 4.1680 MB
# [Segment 64] Training Time = 6.06 sec
# [Segment 64] GPU Memory Start = 1469.95 MB
# [Segment 64] GPU Memory End   = 1470.22 MB
# [Segment 64] GPU Peak Memory  = 1471.40 MB
#
# ============= Done =============

# %% [markdown]
# # 2nd Inference for Validation Set

# %%
train_segments_by_epoch = torch.load('./1st_results_ETTm2/train_segments_by_epoch.pt', weights_only=False)
val_segments_by_epoch = torch.load('./1st_results_ETTm2/val_segments_by_epoch.pt', weights_only=False)
test_segments_by_epoch = torch.load('./1st_results_ETTm2/test_segments_by_epoch.pt', weights_only=False)

# %%
train_pred_segments_ES = train_segments_by_epoch['ES']['train_pred_segments_EES']  
train_label_segments_ES = train_segments_by_epoch['ES']['train_label_segments_EES']
val_pred_segments_ES = val_segments_by_epoch['ES']['val_pred_segments_EES']  
val_label_segments_ES = val_segments_by_epoch['ES']['val_label_segments_EES']
test_pred_segments_ES = test_segments_by_epoch['ES']['test_pred_segments_EES']  
test_label_segments_ES = test_segments_by_epoch['ES']['test_label_segments_EES']


train_pred_segments_E1 = train_segments_by_epoch[1]['train_pred_segments_E1']  
train_label_segments_E1 = train_segments_by_epoch[1]['train_label_segments_E1']
val_pred_segments_E1 = val_segments_by_epoch[1]['val_pred_segments_E1']  
val_label_segments_E1 = val_segments_by_epoch[1]['val_label_segments_E1']
test_pred_segments_E1 = test_segments_by_epoch[1]['test_pred_segments_E1']  
test_label_segments_E1 = test_segments_by_epoch[1]['test_label_segments_E1']

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 96,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_ES_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()      
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_val_1E[seg] = {
        "pred2_ES_val_1E"    : pred_all,   
        "true2_ES_val_1E"    : true_all,   
        "metrics2_ES_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_val_1E[10]["metrics2_ES_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.0862521082162857  MAE:0.20299705862998962
# ▶ seg0  mean  MSE:0.0862521082162857  MAE:0.20299705862998962
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.08910655230283737  MAE:0.20898596942424774
# ▶ seg1  mean  MSE:0.08910655230283737  MAE:0.20898596942424774
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.09009895473718643  MAE:0.20944608747959137
# ▶ seg2  mean  MSE:0.09009895473718643  MAE:0.20944608747959137
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.08889379352331161  MAE:0.2147277295589447
# ▶ seg3  mean  MSE:0.08889379352331161  MAE:0.2147277295589447
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.08749155700206757  MAE:0.21010935306549072
# ▶ seg4  mean  MSE:0.08749155700206757  MAE:0.21010935306549072
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.09023642539978027  MAE:0.2074190229177475
# ▶ seg5  mean  MSE:0.09023642539978027  MAE:0.2074190229177475
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.08615241944789886  MAE:0.20700006186962128
# ▶ seg6  mean  MSE:0.08615241944789886  MAE:0.20700006186962128
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.09587965905666351  MAE:0.2291906476020813
# ▶ seg7  mean  MSE:0.09587965905666351  MAE:0.2291906476020813
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.08858076483011246  MAE:0.21247480809688568
# ▶ seg8  mean  MSE:0.08858076483011246  MAE:0.21247480809688568
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.0892707109451294  MAE:0.216635063290596
# ▶ seg9  mean  MSE:0.0892707109451294  MAE:0.216635063290596
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.08660869300365448  MAE:0.21034500002861023
# ▶ seg10  mean  MSE:0.08660869300365448  MAE:0.21034500002861023
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.0944800153374672  MAE:0.21178138256072998
# ▶ seg11  mean  MSE:0.0944800153374672  MAE:0.21178138256072998
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.09046007692813873  MAE:0.20802709460258484
# ▶ seg12  mean  MSE:0.09046007692813873  MAE:0.20802709460258484
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.08907313644886017  MAE:0.20937784016132355
# ▶ seg13  mean  MSE:0.08907313644886017  MAE:0.20937784016132355
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.08691819757223129  MAE:0.20373602211475372
# ▶ seg14  mean  MSE:0.08691819757223129  MAE:0.20373602211475372
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.08559607714414597  MAE:0.2058008909225464
# ▶ seg15  mean  MSE:0.08559607714414597  MAE:0.2058008909225464
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.08716915547847748  MAE:0.21272507309913635
# ▶ seg16  mean  MSE:0.08716915547847748  MAE:0.21272507309913635
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.09035331755876541  MAE:0.20878618955612183
# ▶ seg17  mean  MSE:0.09035331755876541  MAE:0.20878618955612183
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.08759249001741409  MAE:0.208727166056633
# ▶ seg18  mean  MSE:0.08759249001741409  MAE:0.208727166056633
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.08857324719429016  MAE:0.2129557877779007
# ▶ seg19  mean  MSE:0.08857324719429016  MAE:0.2129557877779007
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.09411778301000595  MAE:0.22343888878822327
# ▶ seg20  mean  MSE:0.09411778301000595  MAE:0.22343888878822327
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.08757517486810684  MAE:0.2108829915523529
# ▶ seg21  mean  MSE:0.08757517486810684  MAE:0.2108829915523529
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.08825508505105972  MAE:0.20782820880413055
# ▶ seg22  mean  MSE:0.08825508505105972  MAE:0.20782820880413055
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.08700087666511536  MAE:0.21319811046123505
# ▶ seg23  mean  MSE:0.08700087666511536  MAE:0.21319811046123505
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.09162088483572006  MAE:0.21011047065258026
# ▶ seg24  mean  MSE:0.09162088483572006  MAE:0.21011047065258026
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.08695972710847855  MAE:0.20334795117378235
# ▶ seg25  mean  MSE:0.08695972710847855  MAE:0.20334795117378235
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.08952365815639496  MAE:0.21697016060352325
# ▶ seg26  mean  MSE:0.08952365815639496  MAE:0.21697016060352325
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.09608288109302521  MAE:0.21354307234287262
# ▶ seg27  mean  MSE:0.09608288109302521  MAE:0.21354307234287262
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.09374339878559113  MAE:0.22753649950027466
# ▶ seg28  mean  MSE:0.09374339878559113  MAE:0.22753649950027466
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.09341586381196976  MAE:0.21116095781326294
# ▶ seg29  mean  MSE:0.09341586381196976  MAE:0.21116095781326294
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.08873725682497025  MAE:0.20532679557800293
# ▶ seg30  mean  MSE:0.08873725682497025  MAE:0.20532679557800293
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.08778240531682968  MAE:0.21715396642684937
# ▶ seg31  mean  MSE:0.08778240531682968  MAE:0.21715396642684937
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.08705341070890427  MAE:0.21069806814193726
# ▶ seg32  mean  MSE:0.08705341070890427  MAE:0.21069806814193726
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.09568549692630768  MAE:0.22850775718688965
# ▶ seg33  mean  MSE:0.09568549692630768  MAE:0.22850775718688965
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.10739144682884216  MAE:0.23151323199272156
# ▶ seg34  mean  MSE:0.10739144682884216  MAE:0.23151323199272156
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.08494666963815689  MAE:0.20622576773166656
# ▶ seg35  mean  MSE:0.08494666963815689  MAE:0.20622576773166656
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.08944467455148697  MAE:0.21896281838417053
# ▶ seg36  mean  MSE:0.08944467455148697  MAE:0.21896281838417053
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.0883125439286232  MAE:0.20732176303863525
# ▶ seg37  mean  MSE:0.0883125439286232  MAE:0.20732176303863525
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.10134638100862503  MAE:0.2347741574048996
# ▶ seg38  mean  MSE:0.10134638100862503  MAE:0.2347741574048996
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.08659287542104721  MAE:0.20577393472194672
# ▶ seg39  mean  MSE:0.08659287542104721  MAE:0.20577393472194672
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.09077855199575424  MAE:0.22056888043880463
# ▶ seg40  mean  MSE:0.09077855199575424  MAE:0.22056888043880463
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.086665078997612  MAE:0.20629310607910156
# ▶ seg41  mean  MSE:0.086665078997612  MAE:0.20629310607910156
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.08687179535627365  MAE:0.20997150242328644
# ▶ seg42  mean  MSE:0.08687179535627365  MAE:0.20997150242328644
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.09349507838487625  MAE:0.21533936262130737
# ▶ seg43  mean  MSE:0.09349507838487625  MAE:0.21533936262130737
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.0912451446056366  MAE:0.22084371745586395
# ▶ seg44  mean  MSE:0.0912451446056366  MAE:0.22084371745586395
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.09843315184116364  MAE:0.22041121125221252
# ▶ seg45  mean  MSE:0.09843315184116364  MAE:0.22041121125221252
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.0864798054099083  MAE:0.20674411952495575
# ▶ seg46  mean  MSE:0.0864798054099083  MAE:0.20674411952495575
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.09393302351236343  MAE:0.21156752109527588
# ▶ seg47  mean  MSE:0.09393302351236343  MAE:0.21156752109527588
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.08783990889787674  MAE:0.21497738361358643
# ▶ seg48  mean  MSE:0.08783990889787674  MAE:0.21497738361358643
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.0952022597193718  MAE:0.22807571291923523
# ▶ seg49  mean  MSE:0.0952022597193718  MAE:0.22807571291923523
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.08903786540031433  MAE:0.21581058204174042
# ▶ seg50  mean  MSE:0.08903786540031433  MAE:0.21581058204174042
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.09060036391019821  MAE:0.21052148938179016
# ▶ seg51  mean  MSE:0.09060036391019821  MAE:0.21052148938179016
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.10172274708747864  MAE:0.22765593230724335
# ▶ seg52  mean  MSE:0.10172274708747864  MAE:0.22765593230724335
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.08924174308776855  MAE:0.21555429697036743
# ▶ seg53  mean  MSE:0.08924174308776855  MAE:0.21555429697036743
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.09104754775762558  MAE:0.21339552104473114
# ▶ seg54  mean  MSE:0.09104754775762558  MAE:0.21339552104473114
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.08989819884300232  MAE:0.2214171588420868
# ▶ seg55  mean  MSE:0.08989819884300232  MAE:0.2214171588420868
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.0937068983912468  MAE:0.2223394364118576
# ▶ seg56  mean  MSE:0.0937068983912468  MAE:0.2223394364118576
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.0881606712937355  MAE:0.21559511125087738
# ▶ seg57  mean  MSE:0.0881606712937355  MAE:0.21559511125087738
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.08667014539241791  MAE:0.2115287035703659
# ▶ seg58  mean  MSE:0.08667014539241791  MAE:0.2115287035703659
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.09185651689767838  MAE:0.2092970907688141
# ▶ seg59  mean  MSE:0.09185651689767838  MAE:0.2092970907688141
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.08843691647052765  MAE:0.2122604101896286
# ▶ seg60  mean  MSE:0.08843691647052765  MAE:0.2122604101896286
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.09066158533096313  MAE:0.21136200428009033
# ▶ seg61  mean  MSE:0.09066158533096313  MAE:0.21136200428009033
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.08630479127168655  MAE:0.20894934237003326
# ▶ seg62  mean  MSE:0.08630479127168655  MAE:0.20894934237003326
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.09169740229845047  MAE:0.2095346599817276
# ▶ seg63  mean  MSE:0.09169740229845047  MAE:0.2095346599817276
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.08576931059360504  MAE:0.208023801445961
# ▶ seg64  mean  MSE:0.08576931059360504  MAE:0.208023801445961
#
# seg10 ch0 MSE : 0.08660869

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 96,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path


C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_E1_val_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = val_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(val_sequences, val_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_E1_val_1E[seg] = {
        "pred2_E1_val_1E"    : pred_all,   
        "true2_E1_val_1E"    : true_all,   
        "metrics2_E1_val_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_E1_val_1E[10]["metrics2_E1_val_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.08626355975866318  MAE:0.2078295648097992
# ▶ seg0  mean  MSE:0.08626355975866318  MAE:0.2078295648097992
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.0947185531258583  MAE:0.21331967413425446
# ▶ seg1  mean  MSE:0.0947185531258583  MAE:0.21331967413425446
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.08652204275131226  MAE:0.21105413138866425
# ▶ seg2  mean  MSE:0.08652204275131226  MAE:0.21105413138866425
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.09087539464235306  MAE:0.21817223727703094
# ▶ seg3  mean  MSE:0.09087539464235306  MAE:0.21817223727703094
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.08526426553726196  MAE:0.20521679520606995
# ▶ seg4  mean  MSE:0.08526426553726196  MAE:0.20521679520606995
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.09130173176527023  MAE:0.22259770333766937
# ▶ seg5  mean  MSE:0.09130173176527023  MAE:0.22259770333766937
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.0956026092171669  MAE:0.22482532262802124
# ▶ seg6  mean  MSE:0.0956026092171669  MAE:0.22482532262802124
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.08852288126945496  MAE:0.20599965751171112
# ▶ seg7  mean  MSE:0.08852288126945496  MAE:0.20599965751171112
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.08895335346460342  MAE:0.20818519592285156
# ▶ seg8  mean  MSE:0.08895335346460342  MAE:0.20818519592285156
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.0936763733625412  MAE:0.22836339473724365
# ▶ seg9  mean  MSE:0.0936763733625412  MAE:0.22836339473724365
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.10048800706863403  MAE:0.23897594213485718
# ▶ seg10  mean  MSE:0.10048800706863403  MAE:0.23897594213485718
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.08566460013389587  MAE:0.20494118332862854
# ▶ seg11  mean  MSE:0.08566460013389587  MAE:0.20494118332862854
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.08996082097291946  MAE:0.21817167103290558
# ▶ seg12  mean  MSE:0.08996082097291946  MAE:0.21817167103290558
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.08586198836565018  MAE:0.2086907923221588
# ▶ seg13  mean  MSE:0.08586198836565018  MAE:0.2086907923221588
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.09117483347654343  MAE:0.21529558300971985
# ▶ seg14  mean  MSE:0.09117483347654343  MAE:0.21529558300971985
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.09227374941110611  MAE:0.2096726894378662
# ▶ seg15  mean  MSE:0.09227374941110611  MAE:0.2096726894378662
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.0861467719078064  MAE:0.210134357213974
# ▶ seg16  mean  MSE:0.0861467719078064  MAE:0.210134357213974
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.09539424628019333  MAE:0.21124933660030365
# ▶ seg17  mean  MSE:0.09539424628019333  MAE:0.21124933660030365
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.08654019981622696  MAE:0.20920929312705994
# ▶ seg18  mean  MSE:0.08654019981622696  MAE:0.20920929312705994
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.09222634136676788  MAE:0.2106447070837021
# ▶ seg19  mean  MSE:0.09222634136676788  MAE:0.2106447070837021
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.08777511119842529  MAE:0.21409153938293457
# ▶ seg20  mean  MSE:0.08777511119842529  MAE:0.21409153938293457
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.08737919479608536  MAE:0.2041427195072174
# ▶ seg21  mean  MSE:0.08737919479608536  MAE:0.2041427195072174
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.09190253913402557  MAE:0.21348313987255096
# ▶ seg22  mean  MSE:0.09190253913402557  MAE:0.21348313987255096
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.08880864083766937  MAE:0.21148644387722015
# ▶ seg23  mean  MSE:0.08880864083766937  MAE:0.21148644387722015
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.08775286376476288  MAE:0.20829957723617554
# ▶ seg24  mean  MSE:0.08775286376476288  MAE:0.20829957723617554
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.08934712409973145  MAE:0.21470357477664948
# ▶ seg25  mean  MSE:0.08934712409973145  MAE:0.21470357477664948
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.08809103071689606  MAE:0.21452811360359192
# ▶ seg26  mean  MSE:0.08809103071689606  MAE:0.21452811360359192
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.0887942910194397  MAE:0.20957165956497192
# ▶ seg27  mean  MSE:0.0887942910194397  MAE:0.20957165956497192
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.10318132489919662  MAE:0.23390866816043854
# ▶ seg28  mean  MSE:0.10318132489919662  MAE:0.23390866816043854
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.09234697371721268  MAE:0.2202478051185608
# ▶ seg29  mean  MSE:0.09234697371721268  MAE:0.2202478051185608
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.08727609366178513  MAE:0.20951810479164124
# ▶ seg30  mean  MSE:0.08727609366178513  MAE:0.20951810479164124
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.09144880622625351  MAE:0.2195594310760498
# ▶ seg31  mean  MSE:0.09144880622625351  MAE:0.2195594310760498
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.08889881521463394  MAE:0.21521353721618652
# ▶ seg32  mean  MSE:0.08889881521463394  MAE:0.21521353721618652
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.08889372646808624  MAE:0.20829078555107117
# ▶ seg33  mean  MSE:0.08889372646808624  MAE:0.20829078555107117
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.08982419222593307  MAE:0.20790475606918335
# ▶ seg34  mean  MSE:0.08982419222593307  MAE:0.20790475606918335
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.08930041640996933  MAE:0.2128758579492569
# ▶ seg35  mean  MSE:0.08930041640996933  MAE:0.2128758579492569
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.08994407206773758  MAE:0.21448086202144623
# ▶ seg36  mean  MSE:0.08994407206773758  MAE:0.21448086202144623
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.0887136310338974  MAE:0.2175089418888092
# ▶ seg37  mean  MSE:0.0887136310338974  MAE:0.2175089418888092
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.08591017872095108  MAE:0.21041180193424225
# ▶ seg38  mean  MSE:0.08591017872095108  MAE:0.21041180193424225
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.08687087148427963  MAE:0.2115563601255417
# ▶ seg39  mean  MSE:0.08687087148427963  MAE:0.2115563601255417
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.09081315994262695  MAE:0.21114200353622437
# ▶ seg40  mean  MSE:0.09081315994262695  MAE:0.21114200353622437
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.09141850471496582  MAE:0.2103670984506607
# ▶ seg41  mean  MSE:0.09141850471496582  MAE:0.2103670984506607
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.09510686993598938  MAE:0.2166934609413147
# ▶ seg42  mean  MSE:0.09510686993598938  MAE:0.2166934609413147
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.08920811116695404  MAE:0.21023523807525635
# ▶ seg43  mean  MSE:0.08920811116695404  MAE:0.21023523807525635
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.09167739003896713  MAE:0.22235752642154694
# ▶ seg44  mean  MSE:0.09167739003896713  MAE:0.22235752642154694
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.08948179334402084  MAE:0.21383820474147797
# ▶ seg45  mean  MSE:0.08948179334402084  MAE:0.21383820474147797
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.09306115657091141  MAE:0.21431198716163635
# ▶ seg46  mean  MSE:0.09306115657091141  MAE:0.21431198716163635
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.09376812726259232  MAE:0.22011107206344604
# ▶ seg47  mean  MSE:0.09376812726259232  MAE:0.22011107206344604
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.09734375774860382  MAE:0.23538190126419067
# ▶ seg48  mean  MSE:0.09734375774860382  MAE:0.23538190126419067
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.09549283981323242  MAE:0.21863555908203125
# ▶ seg49  mean  MSE:0.09549283981323242  MAE:0.21863555908203125
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.09232249855995178  MAE:0.21596060693264008
# ▶ seg50  mean  MSE:0.09232249855995178  MAE:0.21596060693264008
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.0889243558049202  MAE:0.21596387028694153
# ▶ seg51  mean  MSE:0.0889243558049202  MAE:0.21596387028694153
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.0896964743733406  MAE:0.21615661680698395
# ▶ seg52  mean  MSE:0.0896964743733406  MAE:0.21615661680698395
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.08535738289356232  MAE:0.2066311538219452
# ▶ seg53  mean  MSE:0.08535738289356232  MAE:0.2066311538219452
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.08777657151222229  MAE:0.20578576624393463
# ▶ seg54  mean  MSE:0.08777657151222229  MAE:0.20578576624393463
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.10177846997976303  MAE:0.23773573338985443
# ▶ seg55  mean  MSE:0.10177846997976303  MAE:0.23773573338985443
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.08854936063289642  MAE:0.21366459131240845
# ▶ seg56  mean  MSE:0.08854936063289642  MAE:0.21366459131240845
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.08829610794782639  MAE:0.21185921132564545
# ▶ seg57  mean  MSE:0.08829610794782639  MAE:0.21185921132564545
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.09031811356544495  MAE:0.20779810845851898
# ▶ seg58  mean  MSE:0.09031811356544495  MAE:0.20779810845851898
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.08819834142923355  MAE:0.20973704755306244
# ▶ seg59  mean  MSE:0.08819834142923355  MAE:0.20973704755306244
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.08651235699653625  MAE:0.20836105942726135
# ▶ seg60  mean  MSE:0.08651235699653625  MAE:0.20836105942726135
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.09294932335615158  MAE:0.22080418467521667
# ▶ seg61  mean  MSE:0.09294932335615158  MAE:0.22080418467521667
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.0860741138458252  MAE:0.20918655395507812
# ▶ seg62  mean  MSE:0.0860741138458252  MAE:0.20918655395507812
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.1013801246881485  MAE:0.22165212035179138
# ▶ seg63  mean  MSE:0.1013801246881485  MAE:0.22165212035179138
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.09173597395420074  MAE:0.20844785869121552
# ▶ seg64  mean  MSE:0.09173597395420074  MAE:0.20844785869121552
#
# seg10 ch0 MSE : 0.10048801

# %% [markdown]
# # 2nd Inference for Test Set

# %% [markdown]
# ## ES->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 96
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 96,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_EES_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_ES_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_ES[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_ES_test_1E[seg] = {
        "pred2_ES_test_1E"    : pred_all,   
        "true2_ES_test_1E"    : true_all,   
        "metrics2_ES_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_ES_test_1E[10]["metrics2_ES_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.0649317130446434  MAE:0.18662144243717194
# ▶ seg0  mean  MSE:0.0649317130446434  MAE:0.18662144243717194
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.06939223408699036  MAE:0.19562016427516937
# ▶ seg1  mean  MSE:0.06939223408699036  MAE:0.19562016427516937
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.06832960993051529  MAE:0.1935422718524933
# ▶ seg2  mean  MSE:0.06832960993051529  MAE:0.1935422718524933
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.07524478435516357  MAE:0.20004944503307343
# ▶ seg3  mean  MSE:0.07524478435516357  MAE:0.20004944503307343
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.06926506757736206  MAE:0.19540497660636902
# ▶ seg4  mean  MSE:0.06926506757736206  MAE:0.19540497660636902
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.06835184246301651  MAE:0.1942208856344223
# ▶ seg5  mean  MSE:0.06835184246301651  MAE:0.1942208856344223
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.0676434189081192  MAE:0.19097696244716644
# ▶ seg6  mean  MSE:0.0676434189081192  MAE:0.19097696244716644
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.08178140223026276  MAE:0.21029634773731232
# ▶ seg7  mean  MSE:0.08178140223026276  MAE:0.21029634773731232
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.07045985013246536  MAE:0.19404272735118866
# ▶ seg8  mean  MSE:0.07045985013246536  MAE:0.19404272735118866
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.07286345958709717  MAE:0.2003249228000641
# ▶ seg9  mean  MSE:0.07286345958709717  MAE:0.2003249228000641
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.06837207823991776  MAE:0.19077923893928528
# ▶ seg10  mean  MSE:0.06837207823991776  MAE:0.19077923893928528
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.07085725665092468  MAE:0.1963624507188797
# ▶ seg11  mean  MSE:0.07085725665092468  MAE:0.1963624507188797
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.06758779287338257  MAE:0.19033221900463104
# ▶ seg12  mean  MSE:0.06758779287338257  MAE:0.19033221900463104
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.07022673636674881  MAE:0.1956082135438919
# ▶ seg13  mean  MSE:0.07022673636674881  MAE:0.1956082135438919
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.06530934572219849  MAE:0.1876959502696991
# ▶ seg14  mean  MSE:0.06530934572219849  MAE:0.1876959502696991
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.06668994575738907  MAE:0.18993087112903595
# ▶ seg15  mean  MSE:0.06668994575738907  MAE:0.18993087112903595
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.06967126578092575  MAE:0.1944468468427658
# ▶ seg16  mean  MSE:0.06967126578092575  MAE:0.1944468468427658
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.06849946081638336  MAE:0.1913471221923828
# ▶ seg17  mean  MSE:0.06849946081638336  MAE:0.1913471221923828
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.06786893308162689  MAE:0.1897672712802887
# ▶ seg18  mean  MSE:0.06786893308162689  MAE:0.1897672712802887
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.07169564813375473  MAE:0.20149217545986176
# ▶ seg19  mean  MSE:0.07169564813375473  MAE:0.20149217545986176
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.07957495748996735  MAE:0.21368083357810974
# ▶ seg20  mean  MSE:0.07957495748996735  MAE:0.21368083357810974
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.06924879550933838  MAE:0.1960536539554596
# ▶ seg21  mean  MSE:0.06924879550933838  MAE:0.1960536539554596
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.06757283210754395  MAE:0.19095642864704132
# ▶ seg22  mean  MSE:0.06757283210754395  MAE:0.19095642864704132
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.07081440091133118  MAE:0.19564571976661682
# ▶ seg23  mean  MSE:0.07081440091133118  MAE:0.19564571976661682
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.06746679544448853  MAE:0.19088633358478546
# ▶ seg24  mean  MSE:0.06746679544448853  MAE:0.19088633358478546
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.06415599584579468  MAE:0.18585613369941711
# ▶ seg25  mean  MSE:0.06415599584579468  MAE:0.18585613369941711
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.07559874653816223  MAE:0.20327313244342804
# ▶ seg26  mean  MSE:0.07559874653816223  MAE:0.20327313244342804
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.0735999122262001  MAE:0.1997673064470291
# ▶ seg27  mean  MSE:0.0735999122262001  MAE:0.1997673064470291
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.08252562582492828  MAE:0.216926708817482
# ▶ seg28  mean  MSE:0.08252562582492828  MAE:0.216926708817482
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.07194840162992477  MAE:0.19803987443447113
# ▶ seg29  mean  MSE:0.07194840162992477  MAE:0.19803987443447113
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.06499333679676056  MAE:0.18659640848636627
# ▶ seg30  mean  MSE:0.06499333679676056  MAE:0.18659640848636627
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.07101662456989288  MAE:0.19863273203372955
# ▶ seg31  mean  MSE:0.07101662456989288  MAE:0.19863273203372955
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.06900618970394135  MAE:0.19687773287296295
# ▶ seg32  mean  MSE:0.06900618970394135  MAE:0.19687773287296295
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.08722838759422302  MAE:0.2204221785068512
# ▶ seg33  mean  MSE:0.08722838759422302  MAE:0.2204221785068512
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.08388740569353104  MAE:0.21415799856185913
# ▶ seg34  mean  MSE:0.08388740569353104  MAE:0.21415799856185913
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.06604686379432678  MAE:0.18923580646514893
# ▶ seg35  mean  MSE:0.06604686379432678  MAE:0.18923580646514893
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.07340800017118454  MAE:0.20268672704696655
# ▶ seg36  mean  MSE:0.07340800017118454  MAE:0.20268672704696655
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.06577248871326447  MAE:0.18936046957969666
# ▶ seg37  mean  MSE:0.06577248871326447  MAE:0.18936046957969666
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.08553311973810196  MAE:0.2199040651321411
# ▶ seg38  mean  MSE:0.08553311973810196  MAE:0.2199040651321411
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.06634710729122162  MAE:0.18849922716617584
# ▶ seg39  mean  MSE:0.06634710729122162  MAE:0.18849922716617584
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.0764053463935852  MAE:0.20422296226024628
# ▶ seg40  mean  MSE:0.0764053463935852  MAE:0.20422296226024628
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.06627751141786575  MAE:0.18830294907093048
# ▶ seg41  mean  MSE:0.06627751141786575  MAE:0.18830294907093048
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.06921597570180893  MAE:0.19530239701271057
# ▶ seg42  mean  MSE:0.06921597570180893  MAE:0.19530239701271057
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.0746905505657196  MAE:0.20595699548721313
# ▶ seg43  mean  MSE:0.0746905505657196  MAE:0.20595699548721313
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.07774211466312408  MAE:0.2081063687801361
# ▶ seg44  mean  MSE:0.07774211466312408  MAE:0.2081063687801361
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.07416762411594391  MAE:0.2033161222934723
# ▶ seg45  mean  MSE:0.07416762411594391  MAE:0.2033161222934723
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.06671463698148727  MAE:0.1893957406282425
# ▶ seg46  mean  MSE:0.06671463698148727  MAE:0.1893957406282425
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.07093509286642075  MAE:0.19722646474838257
# ▶ seg47  mean  MSE:0.07093509286642075  MAE:0.19722646474838257
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.06895335018634796  MAE:0.1933060735464096
# ▶ seg48  mean  MSE:0.06895335018634796  MAE:0.1933060735464096
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.0840350016951561  MAE:0.2167925387620926
# ▶ seg49  mean  MSE:0.0840350016951561  MAE:0.2167925387620926
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.07175305485725403  MAE:0.20242533087730408
# ▶ seg50  mean  MSE:0.07175305485725403  MAE:0.20242533087730408
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.06991589814424515  MAE:0.19338461756706238
# ▶ seg51  mean  MSE:0.06991589814424515  MAE:0.19338461756706238
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.08371013402938843  MAE:0.21336603164672852
# ▶ seg52  mean  MSE:0.08371013402938843  MAE:0.21336603164672852
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.07179661095142365  MAE:0.1991971880197525
# ▶ seg53  mean  MSE:0.07179661095142365  MAE:0.1991971880197525
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.07112587243318558  MAE:0.19795416295528412
# ▶ seg54  mean  MSE:0.07112587243318558  MAE:0.19795416295528412
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.0756286233663559  MAE:0.20499593019485474
# ▶ seg55  mean  MSE:0.0756286233663559  MAE:0.20499593019485474
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.08050461858510971  MAE:0.207447350025177
# ▶ seg56  mean  MSE:0.08050461858510971  MAE:0.207447350025177
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.07569537311792374  MAE:0.20351381599903107
# ▶ seg57  mean  MSE:0.07569537311792374  MAE:0.20351381599903107
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.06776241958141327  MAE:0.19157825410366058
# ▶ seg58  mean  MSE:0.06776241958141327  MAE:0.19157825410366058
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.06975952535867691  MAE:0.19447721540927887
# ▶ seg59  mean  MSE:0.06975952535867691  MAE:0.19447721540927887
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.06948883831501007  MAE:0.1944536715745926
# ▶ seg60  mean  MSE:0.06948883831501007  MAE:0.1944536715745926
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.06883861124515533  MAE:0.19499672949314117
# ▶ seg61  mean  MSE:0.06883861124515533  MAE:0.19499672949314117
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.06749849021434784  MAE:0.19017119705677032
# ▶ seg62  mean  MSE:0.06749849021434784  MAE:0.19017119705677032
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.06926442682743073  MAE:0.1941348761320114
# ▶ seg63  mean  MSE:0.06926442682743073  MAE:0.1941348761320114
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.06621439009904861  MAE:0.1890747845172882
# ▶ seg64  mean  MSE:0.06621439009904861  MAE:0.1890747845172882
#
# seg10 ch0 MSE : 0.06837208

# %% [markdown]
# ## 1E->1E

# %% [markdown]
# ### Configs

# %%
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np, os
from pathlib import Path

pred_len = 96
seq_len = 336 + pred_len//3


class Configs:
    def __init__(self, seq_len, pred_len, enc_in, individual,
                 learning_rate, lradj, patience,
                 save_path, attach_to_trend, attach_to_seasonal):
        self.seq_len  = seq_len
        self.pred_len = pred_len
        self.enc_in   = enc_in          
        self.individual = individual
        self.learning_rate = learning_rate
        self.lradj = lradj
        self.patience = patience
        self.save_path = save_path
        self.attach_to_trend    = attach_to_trend
        self.attach_to_seasonal = attach_to_seasonal


base_cfg = Configs(
    pred_len         = 96,
    seq_len          = 336 + pred_len//3,
    enc_in           = 1,
    individual       = True,
    learning_rate    = 0.001,
    lradj            = 'type1',
    patience         = 3,
    save_path        = "./model2_ETTm2_E1_1E",
    attach_to_trend  = True,
    attach_to_seasonal = True
)
Path(base_cfg.save_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Inference

# %%
import torch, numpy as np
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import r2_score
from pathlib import Path

C        = 1                                
P        = base_cfg.pred_len                
seg_cnt  = 65
batch_sz = 32

results2_ETTm2_E1_test_1E = {}  

for seg in range(seg_cnt):
    print(f"\n―――― Inference  |  Segment {seg} ――――")

    
    pv = test_pred_segments_E1[:, seg, :, :]         
    ds = TensorDataset(test_sequences, test_labels, pv) 
    dl = DataLoader(ds, batch_size=batch_sz, shuffle=False)

    
    pred_ch, true_ch, metrics = [], [], {}

    
    for ch in range(C):
        ckpt = Path(base_cfg.save_path) / f"seg{seg}" / f"ch{ch}" / "checkpoint.pth"
        if not ckpt.exists():
            print(f"[Warn] seg{seg}-ch{ch} ckpt 없음 → skip");  continue

        
        model = Model(base_cfg).to(device)
        model.load_state_dict(torch.load(ckpt, map_location=device))
        model.eval()

        preds, trues = [], []
        with torch.no_grad():
            for xb, yb, pv_batch in dl:                 
                xb  = xb.float().to(device)
                yb  = yb.float()        
                pv_ = pv_batch.float().to(device)

                out = model(xb, pv_)                     
                preds.append(out[:, -P:, ch].cpu())
                trues.append(yb[:, -P:, ch])

        preds = torch.cat(preds, 0)     
        trues = torch.cat(trues, 0)
        pred_ch.append(preds)
        true_ch.append(trues)

        
        p, t = preds.reshape(-1).cpu().numpy(), trues.reshape(-1).cpu().numpy()
        mse  = np.mean((p - t)**2)
        mae  = np.mean(np.abs(p - t))
        metrics[ch] = (mse, mae)

        print(f"  seg{seg}-ch{ch}  MSE:{mse}  MAE:{mae}")

        del model; torch.cuda.empty_cache()

    
    pred_all = torch.stack(pred_ch,  dim=2)   
    true_all = torch.stack(true_ch,  dim=2)

    
    mse_avg = np.mean([m for m,_ in metrics.values()])
    mae_avg = np.mean([a for _,a in metrics.values()])
    print(f"▶ seg{seg}  mean  MSE:{mse_avg}  MAE:{mae_avg}")

    
    results2_ETTm2_E1_test_1E[seg] = {
        "pred2_E1_test_1E"    : pred_all,   
        "true2_E1_test_1E"    : true_all,   
        "metrics2_E1_test_1E" : metrics     
    }


seg10_ch0_mse = results2_ETTm2_E1_test_1E[10]["metrics2_E1_test_1E"][0][0]
print("\nseg10 ch0 MSE :", seg10_ch0_mse)
# Out:
# ―――― Inference  |  Segment 0 ――――
#   seg0-ch0  MSE:0.06839022040367126  MAE:0.194734588265419
# ▶ seg0  mean  MSE:0.06839022040367126  MAE:0.194734588265419
#
# ―――― Inference  |  Segment 1 ――――
#   seg1-ch0  MSE:0.06937602907419205  MAE:0.19387350976467133
# ▶ seg1  mean  MSE:0.06937602907419205  MAE:0.19387350976467133
#
# ―――― Inference  |  Segment 2 ――――
#   seg2-ch0  MSE:0.06814893335103989  MAE:0.19449147582054138
# ▶ seg2  mean  MSE:0.06814893335103989  MAE:0.19449147582054138
#
# ―――― Inference  |  Segment 3 ――――
#   seg3-ch0  MSE:0.07373917102813721  MAE:0.20262779295444489
# ▶ seg3  mean  MSE:0.07373917102813721  MAE:0.20262779295444489
#
# ―――― Inference  |  Segment 4 ――――
#   seg4-ch0  MSE:0.06689395010471344  MAE:0.18814513087272644
# ▶ seg4  mean  MSE:0.06689395010471344  MAE:0.18814513087272644
#
# ―――― Inference  |  Segment 5 ――――
#   seg5-ch0  MSE:0.07563340663909912  MAE:0.202678844332695
# ▶ seg5  mean  MSE:0.07563340663909912  MAE:0.202678844332695
#
# ―――― Inference  |  Segment 6 ――――
#   seg6-ch0  MSE:0.08267951756715775  MAE:0.21029934287071228
# ▶ seg6  mean  MSE:0.08267951756715775  MAE:0.21029934287071228
#
# ―――― Inference  |  Segment 7 ――――
#   seg7-ch0  MSE:0.06593533605337143  MAE:0.1887529343366623
# ▶ seg7  mean  MSE:0.06593533605337143  MAE:0.1887529343366623
#
# ―――― Inference  |  Segment 8 ――――
#   seg8-ch0  MSE:0.06656179577112198  MAE:0.1895163357257843
# ▶ seg8  mean  MSE:0.06656179577112198  MAE:0.1895163357257843
#
# ―――― Inference  |  Segment 9 ――――
#   seg9-ch0  MSE:0.07992929965257645  MAE:0.21206893026828766
# ▶ seg9  mean  MSE:0.07992929965257645  MAE:0.21206893026828766
#
# ―――― Inference  |  Segment 10 ――――
#   seg10-ch0  MSE:0.09056316316127777  MAE:0.2266327291727066
# ▶ seg10  mean  MSE:0.09056316316127777  MAE:0.2266327291727066
#
# ―――― Inference  |  Segment 11 ――――
#   seg11-ch0  MSE:0.06598447263240814  MAE:0.18900085985660553
# ▶ seg11  mean  MSE:0.06598447263240814  MAE:0.18900085985660553
#
# ―――― Inference  |  Segment 12 ――――
#   seg12-ch0  MSE:0.07279518246650696  MAE:0.19946373999118805
# ▶ seg12  mean  MSE:0.07279518246650696  MAE:0.19946373999118805
#
# ―――― Inference  |  Segment 13 ――――
#   seg13-ch0  MSE:0.0699157789349556  MAE:0.19673573970794678
# ▶ seg13  mean  MSE:0.0699157789349556  MAE:0.19673573970794678
#
# ―――― Inference  |  Segment 14 ――――
#   seg14-ch0  MSE:0.07075467705726624  MAE:0.19761064648628235
# ▶ seg14  mean  MSE:0.07075467705726624  MAE:0.19761064648628235
#
# ―――― Inference  |  Segment 15 ――――
#   seg15-ch0  MSE:0.07019978016614914  MAE:0.1946030855178833
# ▶ seg15  mean  MSE:0.07019978016614914  MAE:0.1946030855178833
#
# ―――― Inference  |  Segment 16 ――――
#   seg16-ch0  MSE:0.068299300968647  MAE:0.19565975666046143
# ▶ seg16  mean  MSE:0.068299300968647  MAE:0.19565975666046143
#
# ―――― Inference  |  Segment 17 ――――
#   seg17-ch0  MSE:0.07075496017932892  MAE:0.19471587240695953
# ▶ seg17  mean  MSE:0.07075496017932892  MAE:0.19471587240695953
#
# ―――― Inference  |  Segment 18 ――――
#   seg18-ch0  MSE:0.06613001227378845  MAE:0.19010169804096222
# ▶ seg18  mean  MSE:0.06613001227378845  MAE:0.19010169804096222
#
# ―――― Inference  |  Segment 19 ――――
#   seg19-ch0  MSE:0.06995126605033875  MAE:0.19436192512512207
# ▶ seg19  mean  MSE:0.06995126605033875  MAE:0.19436192512512207
#
# ―――― Inference  |  Segment 20 ――――
#   seg20-ch0  MSE:0.0710330680012703  MAE:0.19698059558868408
# ▶ seg20  mean  MSE:0.0710330680012703  MAE:0.19698059558868408
#
# ―――― Inference  |  Segment 21 ――――
#   seg21-ch0  MSE:0.06556495279073715  MAE:0.18870200216770172
# ▶ seg21  mean  MSE:0.06556495279073715  MAE:0.18870200216770172
#
# ―――― Inference  |  Segment 22 ――――
#   seg22-ch0  MSE:0.06804662197828293  MAE:0.1919001042842865
# ▶ seg22  mean  MSE:0.06804662197828293  MAE:0.1919001042842865
#
# ―――― Inference  |  Segment 23 ――――
#   seg23-ch0  MSE:0.06939858943223953  MAE:0.19236184656620026
# ▶ seg23  mean  MSE:0.06939858943223953  MAE:0.19236184656620026
#
# ―――― Inference  |  Segment 24 ――――
#   seg24-ch0  MSE:0.06695785373449326  MAE:0.19014686346054077
# ▶ seg24  mean  MSE:0.06695785373449326  MAE:0.19014686346054077
#
# ―――― Inference  |  Segment 25 ――――
#   seg25-ch0  MSE:0.0709494799375534  MAE:0.19598345458507538
# ▶ seg25  mean  MSE:0.0709494799375534  MAE:0.19598345458507538
#
# ―――― Inference  |  Segment 26 ――――
#   seg26-ch0  MSE:0.07277475297451019  MAE:0.1991686373949051
# ▶ seg26  mean  MSE:0.07277475297451019  MAE:0.1991686373949051
#
# ―――― Inference  |  Segment 27 ――――
#   seg27-ch0  MSE:0.06641997396945953  MAE:0.1916569471359253
# ▶ seg27  mean  MSE:0.06641997396945953  MAE:0.1916569471359253
#
# ―――― Inference  |  Segment 28 ――――
#   seg28-ch0  MSE:0.08558908104896545  MAE:0.22334878146648407
# ▶ seg28  mean  MSE:0.08558908104896545  MAE:0.22334878146648407
#
# ―――― Inference  |  Segment 29 ――――
#   seg29-ch0  MSE:0.07454179227352142  MAE:0.20754268765449524
# ▶ seg29  mean  MSE:0.07454179227352142  MAE:0.20754268765449524
#
# ―――― Inference  |  Segment 30 ――――
#   seg30-ch0  MSE:0.06551380455493927  MAE:0.18892361223697662
# ▶ seg30  mean  MSE:0.06551380455493927  MAE:0.18892361223697662
#
# ―――― Inference  |  Segment 31 ――――
#   seg31-ch0  MSE:0.07516717910766602  MAE:0.20248405635356903
# ▶ seg31  mean  MSE:0.07516717910766602  MAE:0.20248405635356903
#
# ―――― Inference  |  Segment 32 ――――
#   seg32-ch0  MSE:0.07031767815351486  MAE:0.19482585787773132
# ▶ seg32  mean  MSE:0.07031767815351486  MAE:0.19482585787773132
#
# ―――― Inference  |  Segment 33 ――――
#   seg33-ch0  MSE:0.06559958308935165  MAE:0.18841500580310822
# ▶ seg33  mean  MSE:0.06559958308935165  MAE:0.18841500580310822
#
# ―――― Inference  |  Segment 34 ――――
#   seg34-ch0  MSE:0.06622122973203659  MAE:0.18837936222553253
# ▶ seg34  mean  MSE:0.06622122973203659  MAE:0.18837936222553253
#
# ―――― Inference  |  Segment 35 ――――
#   seg35-ch0  MSE:0.0736297219991684  MAE:0.2022843211889267
# ▶ seg35  mean  MSE:0.0736297219991684  MAE:0.2022843211889267
#
# ―――― Inference  |  Segment 36 ――――
#   seg36-ch0  MSE:0.07280553132295609  MAE:0.19818222522735596
# ▶ seg36  mean  MSE:0.07280553132295609  MAE:0.19818222522735596
#
# ―――― Inference  |  Segment 37 ――――
#   seg37-ch0  MSE:0.07448144257068634  MAE:0.2018623948097229
# ▶ seg37  mean  MSE:0.07448144257068634  MAE:0.2018623948097229
#
# ―――― Inference  |  Segment 38 ――――
#   seg38-ch0  MSE:0.06962932646274567  MAE:0.19582119584083557
# ▶ seg38  mean  MSE:0.06962932646274567  MAE:0.19582119584083557
#
# ―――― Inference  |  Segment 39 ――――
#   seg39-ch0  MSE:0.06998611241579056  MAE:0.195245161652565
# ▶ seg39  mean  MSE:0.06998611241579056  MAE:0.195245161652565
#
# ―――― Inference  |  Segment 40 ――――
#   seg40-ch0  MSE:0.0694800466299057  MAE:0.19617173075675964
# ▶ seg40  mean  MSE:0.0694800466299057  MAE:0.19617173075675964
#
# ―――― Inference  |  Segment 41 ――――
#   seg41-ch0  MSE:0.07149536907672882  MAE:0.19655179977416992
# ▶ seg41  mean  MSE:0.07149536907672882  MAE:0.19655179977416992
#
# ―――― Inference  |  Segment 42 ――――
#   seg42-ch0  MSE:0.0727267786860466  MAE:0.20036597549915314
# ▶ seg42  mean  MSE:0.0727267786860466  MAE:0.20036597549915314
#
# ―――― Inference  |  Segment 43 ――――
#   seg43-ch0  MSE:0.06782088428735733  MAE:0.19336897134780884
# ▶ seg43  mean  MSE:0.06782088428735733  MAE:0.19336897134780884
#
# ―――― Inference  |  Segment 44 ――――
#   seg44-ch0  MSE:0.07644201815128326  MAE:0.20729272067546844
# ▶ seg44  mean  MSE:0.07644201815128326  MAE:0.20729272067546844
#
# ―――― Inference  |  Segment 45 ――――
#   seg45-ch0  MSE:0.06920791417360306  MAE:0.19427390396595
# ▶ seg45  mean  MSE:0.06920791417360306  MAE:0.19427390396595
#
# ―――― Inference  |  Segment 46 ――――
#   seg46-ch0  MSE:0.07168056070804596  MAE:0.200193852186203
# ▶ seg46  mean  MSE:0.07168056070804596  MAE:0.200193852186203
#
# ―――― Inference  |  Segment 47 ――――
#   seg47-ch0  MSE:0.07464113086462021  MAE:0.20086902379989624
# ▶ seg47  mean  MSE:0.07464113086462021  MAE:0.20086902379989624
#
# ―――― Inference  |  Segment 48 ――――
#   seg48-ch0  MSE:0.09000277519226074  MAE:0.2264271080493927
# ▶ seg48  mean  MSE:0.09000277519226074  MAE:0.2264271080493927
#
# ―――― Inference  |  Segment 49 ――――
#   seg49-ch0  MSE:0.07501056045293808  MAE:0.20559781789779663
# ▶ seg49  mean  MSE:0.07501056045293808  MAE:0.20559781789779663
#
# ―――― Inference  |  Segment 50 ――――
#   seg50-ch0  MSE:0.0725279226899147  MAE:0.19904214143753052
# ▶ seg50  mean  MSE:0.0725279226899147  MAE:0.19904214143753052
#
# ―――― Inference  |  Segment 51 ――――
#   seg51-ch0  MSE:0.07321620732545853  MAE:0.20440462231636047
# ▶ seg51  mean  MSE:0.07321620732545853  MAE:0.20440462231636047
#
# ―――― Inference  |  Segment 52 ――――
#   seg52-ch0  MSE:0.07179484516382217  MAE:0.1990332454442978
# ▶ seg52  mean  MSE:0.07179484516382217  MAE:0.1990332454442978
#
# ―――― Inference  |  Segment 53 ――――
#   seg53-ch0  MSE:0.06752733141183853  MAE:0.19030801951885223
# ▶ seg53  mean  MSE:0.06752733141183853  MAE:0.19030801951885223
#
# ―――― Inference  |  Segment 54 ――――
#   seg54-ch0  MSE:0.06506440043449402  MAE:0.18823514878749847
# ▶ seg54  mean  MSE:0.06506440043449402  MAE:0.18823514878749847
#
# ―――― Inference  |  Segment 55 ――――
#   seg55-ch0  MSE:0.08865787088871002  MAE:0.22312581539154053
# ▶ seg55  mean  MSE:0.08865787088871002  MAE:0.22312581539154053
#
# ―――― Inference  |  Segment 56 ――――
#   seg56-ch0  MSE:0.07109233736991882  MAE:0.2007923424243927
# ▶ seg56  mean  MSE:0.07109233736991882  MAE:0.2007923424243927
#
# ―――― Inference  |  Segment 57 ――――
#   seg57-ch0  MSE:0.0700187012553215  MAE:0.1947396993637085
# ▶ seg57  mean  MSE:0.0700187012553215  MAE:0.1947396993637085
#
# ―――― Inference  |  Segment 58 ――――
#   seg58-ch0  MSE:0.06873287260532379  MAE:0.19188426434993744
# ▶ seg58  mean  MSE:0.06873287260532379  MAE:0.19188426434993744
#
# ―――― Inference  |  Segment 59 ――――
#   seg59-ch0  MSE:0.06913985311985016  MAE:0.1924709975719452
# ▶ seg59  mean  MSE:0.06913985311985016  MAE:0.1924709975719452
#
# ―――― Inference  |  Segment 60 ――――
#   seg60-ch0  MSE:0.06804728507995605  MAE:0.19142553210258484
# ▶ seg60  mean  MSE:0.06804728507995605  MAE:0.19142553210258484
#
# ―――― Inference  |  Segment 61 ――――
#   seg61-ch0  MSE:0.07716082036495209  MAE:0.20653672516345978
# ▶ seg61  mean  MSE:0.07716082036495209  MAE:0.20653672516345978
#
# ―――― Inference  |  Segment 62 ――――
#   seg62-ch0  MSE:0.06726965308189392  MAE:0.19213548302650452
# ▶ seg62  mean  MSE:0.06726965308189392  MAE:0.19213548302650452
#
# ―――― Inference  |  Segment 63 ――――
#   seg63-ch0  MSE:0.08017170429229736  MAE:0.2102113664150238
# ▶ seg63  mean  MSE:0.08017170429229736  MAE:0.2102113664150238
#
# ―――― Inference  |  Segment 64 ――――
#   seg64-ch0  MSE:0.07053692638874054  MAE:0.19502519071102142
# ▶ seg64  mean  MSE:0.07053692638874054  MAE:0.19502519071102142
#
# seg10 ch0 MSE : 0.09056316

# %% [markdown]
# # Rank Models (by 2nd validation performance)

# %%
results1_ETTm2_train = torch.load("./1st_results_ETTm2/train_1st_results.pt")
results1_ETTm2_val = torch.load("./1st_results_ETTm2/val_1st_results.pt")
results1_ETTm2_test = torch.load("./1st_results_ETTm2/test_1st_results.pt")

# %% [markdown]
# ### ES->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_ES_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_ES_val_1E[seg]["metrics2_ES_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_ES_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_ES_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_ES_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.088711
#
#   Top  1 | seg 35 | MSE 0.084947 (+0.003765)
#   Top  2 | seg 15 | MSE 0.085596 (+0.003115)
#   Top  3 | seg 64 | MSE 0.085769 (+0.002942)
#   Top  4 | seg 06 | MSE 0.086152 (+0.002559)
#   Top  5 | seg 00 | MSE 0.086252 (+0.002459)
#   Top  6 | seg 62 | MSE 0.086305 (+0.002407)
#   Top  7 | seg 46 | MSE 0.086480 (+0.002231)
#   Top  8 | seg 39 | MSE 0.086593 (+0.002118)
#   Top  9 | seg 10 | MSE 0.086609 (+0.002103)
#   Top 10 | seg 41 | MSE 0.086665 (+0.002046)
#   Top 11 | seg 58 | MSE 0.086670 (+0.002041)
#   Top 12 | seg 42 | MSE 0.086872 (+0.001840)
#   Top 13 | seg 14 | MSE 0.086918 (+0.001793)
#   Top 14 | seg 25 | MSE 0.086960 (+0.001752)
#   Top 15 | seg 23 | MSE 0.087001 (+0.001710)
#   Top 16 | seg 32 | MSE 0.087053 (+0.001658)
#   Top 17 | seg 16 | MSE 0.087169 (+0.001542)
#   Top 18 | seg 04 | MSE 0.087492 (+0.001220)
#   Top 19 | seg 21 | MSE 0.087575 (+0.001136)
#   Top 20 | seg 18 | MSE 0.087592 (+0.001119)
#   Top 21 | seg 31 | MSE 0.087782 (+0.000929)
#   Top 22 | seg 48 | MSE 0.087840 (+0.000871)
#   Top 23 | seg 57 | MSE 0.088161 (+0.000551)
#   Top 24 | seg 22 | MSE 0.088255 (+0.000456)
#   Top 25 | seg 37 | MSE 0.088313 (+0.000399)
#   Top 26 | seg 60 | MSE 0.088437 (+0.000274)
#   Top 27 | seg 19 | MSE 0.088573 (+0.000138)
#   Top 28 | seg 08 | MSE 0.088581 (+0.000131)
#   Top 29 | seg 30 | MSE 0.088737 (-0.000026)
#   Top 30 | seg 03 | MSE 0.088894 (-0.000182)
#   Top 31 | seg 50 | MSE 0.089038 (-0.000327)
#   Top 32 | seg 13 | MSE 0.089073 (-0.000362)
#   Top 33 | seg 01 | MSE 0.089107 (-0.000395)
#   Top 34 | seg 53 | MSE 0.089242 (-0.000530)
#   Top 35 | seg 09 | MSE 0.089271 (-0.000559)
#   Top 36 | seg 36 | MSE 0.089445 (-0.000733)
#   Top 37 | seg 26 | MSE 0.089524 (-0.000812)
#   Top 38 | seg 55 | MSE 0.089898 (-0.001187)
#   Top 39 | seg 02 | MSE 0.090099 (-0.001388)
#   Top 40 | seg 05 | MSE 0.090236 (-0.001525)
#   Top 41 | seg 17 | MSE 0.090353 (-0.001642)
#   Top 42 | seg 12 | MSE 0.090460 (-0.001749)
#   Top 43 | seg 51 | MSE 0.090600 (-0.001889)
#   Top 44 | seg 61 | MSE 0.090662 (-0.001950)
#   Top 45 | seg 40 | MSE 0.090779 (-0.002067)
#   Top 46 | seg 54 | MSE 0.091048 (-0.002336)
#   Top 47 | seg 44 | MSE 0.091245 (-0.002534)
#   Top 48 | seg 24 | MSE 0.091621 (-0.002910)
#   Top 49 | seg 63 | MSE 0.091697 (-0.002986)
#   Top 50 | seg 59 | MSE 0.091857 (-0.003145)
#   Top 51 | seg 29 | MSE 0.093416 (-0.004705)
#   Top 52 | seg 43 | MSE 0.093495 (-0.004784)
#   Top 53 | seg 56 | MSE 0.093707 (-0.004996)
#   Top 54 | seg 28 | MSE 0.093743 (-0.005032)
#   Top 55 | seg 47 | MSE 0.093933 (-0.005222)
#   Top 56 | seg 20 | MSE 0.094118 (-0.005406)
#   Top 57 | seg 11 | MSE 0.094480 (-0.005769)
#   Top 58 | seg 49 | MSE 0.095202 (-0.006491)
#   Top 59 | seg 33 | MSE 0.095685 (-0.006974)
#   Top 60 | seg 07 | MSE 0.095880 (-0.007168)
#   Top 61 | seg 27 | MSE 0.096083 (-0.007372)
#   Top 62 | seg 45 | MSE 0.098433 (-0.009722)
#   Top 63 | seg 38 | MSE 0.101346 (-0.012635)
#   Top 64 | seg 52 | MSE 0.101723 (-0.013011)
#   Top 65 | seg 34 | MSE 0.107391 (-0.018680)
#
# Saved top segment indices per channel:
# Channel 0: [35, 15, 64, 6, 0, 62, 46, 39, 10, 41, 58, 42, 14, 25, 23, 32, 16, 4, 21, 18, 31, 48, 57, 22, 37, 60, 19, 8, 30, 3, 50, 13, 1, 53, 9, 36, 26, 55, 2, 5, 17, 12, 51, 61, 40, 54, 44, 24, 63, 59, 29, 43, 56, 28, 47, 20, 11, 49, 33, 7, 27, 45, 38, 52, 34]

# %% [markdown]
# ### 1E->1E

# %%
import numpy as np
from sklearn.metrics import mean_squared_error




TOP_N       = 65
SEG_CNT     = 65
CH_CNT      = 1
metric_idx  = 0          




mse_table = np.full((SEG_CNT, CH_CNT), np.inf)

for seg in range(SEG_CNT):
    if seg not in results2_ETTm2_E1_val_1E:
        continue
    for ch in range(CH_CNT):
        if ch in results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"]:
            mse_table[seg, ch] = results2_ETTm2_E1_val_1E[seg]["metrics2_E1_val_1E"][ch][metric_idx]




print("\n▶ Train-set  Per-Channel  Top-N  MSE\n")
top_seg_idx_E1_val_1E = {}                       

for ch in range(CH_CNT):
    print(f"=== Channel {ch} ===")
    v_mse = results1_ETTm2_val[1]['mse_val_E1']
    print(f"Vanilla MSE : {v_mse:.6f}\n")

    
    pairs = [(seg, mse_table[seg, ch]) for seg in range(SEG_CNT)
             if np.isfinite(mse_table[seg, ch])]
    top   = sorted(pairs, key=lambda x: x[1])[:TOP_N]

    
    top_seg_idx_E1_val_1E[ch] = [seg for seg, _ in top]   

    
    for rank, (seg_id, mse_val) in enumerate(top, 1):
        delta = v_mse - mse_val
        sign  = "+" if delta > 0 else "-"
        print(f"  Top {rank:2d} | seg {seg_id:02d} | MSE {mse_val:.6f} "
              f"({sign}{abs(delta):.6f})")
    print()




print("Saved top segment indices per channel:")
for ch, seg_list in top_seg_idx_E1_val_1E.items():
    print(f"Channel {ch}: {seg_list}")
# Out:
# ▶ Train-set  Per-Channel  Top-N  MSE
#
# === Channel 0 ===
# Vanilla MSE : 0.088711
#
#   Top  1 | seg 04 | MSE 0.085264 (+0.003447)
#   Top  2 | seg 53 | MSE 0.085357 (+0.003354)
#   Top  3 | seg 11 | MSE 0.085665 (+0.003047)
#   Top  4 | seg 13 | MSE 0.085862 (+0.002849)
#   Top  5 | seg 38 | MSE 0.085910 (+0.002801)
#   Top  6 | seg 62 | MSE 0.086074 (+0.002637)
#   Top  7 | seg 16 | MSE 0.086147 (+0.002565)
#   Top  8 | seg 00 | MSE 0.086264 (+0.002448)
#   Top  9 | seg 60 | MSE 0.086512 (+0.002199)
#   Top 10 | seg 02 | MSE 0.086522 (+0.002189)
#   Top 11 | seg 18 | MSE 0.086540 (+0.002171)
#   Top 12 | seg 39 | MSE 0.086871 (+0.001840)
#   Top 13 | seg 30 | MSE 0.087276 (+0.001435)
#   Top 14 | seg 21 | MSE 0.087379 (+0.001332)
#   Top 15 | seg 24 | MSE 0.087753 (+0.000958)
#   Top 16 | seg 20 | MSE 0.087775 (+0.000936)
#   Top 17 | seg 54 | MSE 0.087777 (+0.000935)
#   Top 18 | seg 26 | MSE 0.088091 (+0.000620)
#   Top 19 | seg 59 | MSE 0.088198 (+0.000513)
#   Top 20 | seg 57 | MSE 0.088296 (+0.000415)
#   Top 21 | seg 07 | MSE 0.088523 (+0.000188)
#   Top 22 | seg 56 | MSE 0.088549 (+0.000162)
#   Top 23 | seg 37 | MSE 0.088714 (-0.000002)
#   Top 24 | seg 27 | MSE 0.088794 (-0.000083)
#   Top 25 | seg 23 | MSE 0.088809 (-0.000097)
#   Top 26 | seg 33 | MSE 0.088894 (-0.000182)
#   Top 27 | seg 32 | MSE 0.088899 (-0.000188)
#   Top 28 | seg 51 | MSE 0.088924 (-0.000213)
#   Top 29 | seg 08 | MSE 0.088953 (-0.000242)
#   Top 30 | seg 43 | MSE 0.089208 (-0.000497)
#   Top 31 | seg 35 | MSE 0.089300 (-0.000589)
#   Top 32 | seg 25 | MSE 0.089347 (-0.000636)
#   Top 33 | seg 45 | MSE 0.089482 (-0.000770)
#   Top 34 | seg 52 | MSE 0.089696 (-0.000985)
#   Top 35 | seg 34 | MSE 0.089824 (-0.001113)
#   Top 36 | seg 36 | MSE 0.089944 (-0.001233)
#   Top 37 | seg 12 | MSE 0.089961 (-0.001250)
#   Top 38 | seg 58 | MSE 0.090318 (-0.001607)
#   Top 39 | seg 40 | MSE 0.090813 (-0.002102)
#   Top 40 | seg 03 | MSE 0.090875 (-0.002164)
#   Top 41 | seg 14 | MSE 0.091175 (-0.002464)
#   Top 42 | seg 05 | MSE 0.091302 (-0.002590)
#   Top 43 | seg 41 | MSE 0.091419 (-0.002707)
#   Top 44 | seg 31 | MSE 0.091449 (-0.002738)
#   Top 45 | seg 44 | MSE 0.091677 (-0.002966)
#   Top 46 | seg 64 | MSE 0.091736 (-0.003025)
#   Top 47 | seg 22 | MSE 0.091903 (-0.003191)
#   Top 48 | seg 19 | MSE 0.092226 (-0.003515)
#   Top 49 | seg 15 | MSE 0.092274 (-0.003562)
#   Top 50 | seg 50 | MSE 0.092322 (-0.003611)
#   Top 51 | seg 29 | MSE 0.092347 (-0.003636)
#   Top 52 | seg 61 | MSE 0.092949 (-0.004238)
#   Top 53 | seg 46 | MSE 0.093061 (-0.004350)
#   Top 54 | seg 09 | MSE 0.093676 (-0.004965)
#   Top 55 | seg 47 | MSE 0.093768 (-0.005057)
#   Top 56 | seg 01 | MSE 0.094719 (-0.006007)
#   Top 57 | seg 42 | MSE 0.095107 (-0.006396)
#   Top 58 | seg 17 | MSE 0.095394 (-0.006683)
#   Top 59 | seg 49 | MSE 0.095493 (-0.006782)
#   Top 60 | seg 06 | MSE 0.095603 (-0.006891)
#   Top 61 | seg 48 | MSE 0.097344 (-0.008632)
#   Top 62 | seg 10 | MSE 0.100488 (-0.011777)
#   Top 63 | seg 63 | MSE 0.101380 (-0.012669)
#   Top 64 | seg 55 | MSE 0.101778 (-0.013067)
#   Top 65 | seg 28 | MSE 0.103181 (-0.014470)
#
# Saved top segment indices per channel:
# Channel 0: [4, 53, 11, 13, 38, 62, 16, 0, 60, 2, 18, 39, 30, 21, 24, 20, 54, 26, 59, 57, 7, 56, 37, 27, 23, 33, 32, 51, 8, 43, 35, 25, 45, 52, 34, 36, 12, 58, 40, 3, 14, 5, 41, 31, 44, 64, 22, 19, 15, 50, 29, 61, 46, 9, 47, 1, 42, 17, 49, 6, 48, 10, 63, 55, 28]

# %% [markdown]
# # Ensemble

# %% [markdown]
# ## ES->1E

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)   


van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []




for ch in range(CH_CNT):
    print(f"\n=== Channel {ch} ===")

    
    
    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    for seg in top_seg_idx_ES_val_1E[ch][:TOP_K]:
        ckpt = f"./model2_ETTm2_EES_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] ckpt missing : seg{seg}")
            continue

        pv_seg = test_pred_segments_ES[:, seg, :, :]
        dl     = DataLoader(TensorDataset(test_sequences, test_labels, pv_seg),
                            batch_size=batch_sz, shuffle=False)

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        preds_test_arr.append(infer_one(mdl, dl, ch))   
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list, rho_list = [], []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)

        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min)/(V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min)/(R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1
    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]

    best_K = Ks[int(np.argmin(scores))]

    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)

    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    print(f"[Var-Corr]  K={best_K}")
    print(f"  MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"  MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")




if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE     : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%) : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE     : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%) : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.063793 | MAE : 0.184114
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.979e-03 | |ρ|=0.9918 | S=1.0000
#    K=10 | Var=3.395e-03 | |ρ|=0.9905 | S=0.9235
#    K=15 | Var=3.760e-03 | |ρ|=0.9910 | S=1.0464
#    K=20 | Var=4.017e-03 | |ρ|=0.9900 | S=0.9761
#    K=25 | Var=4.323e-03 | |ρ|=0.9901 | S=1.0365
#    K=30 | Var=4.602e-03 | |ρ|=0.9891 | S=0.9753
#    K=35 | Var=4.926e-03 | |ρ|=0.9881 | S=0.9151
#    K=40 | Var=5.376e-03 | |ρ|=0.9874 | S=0.9078 <- pick
#    K=45 | Var=5.650e-03 | |ρ|=0.9872 | S=0.9364
#    K=50 | Var=6.028e-03 | |ρ|=0.9869 | S=0.9623
#    K=55 | Var=6.775e-03 | |ρ|=0.9859 | S=0.9857
#    K=60 | Var=7.556e-03 | |ρ|=0.9845 | S=0.9500
#    K=65 | Var=8.591e-03 | |ρ|=0.9833 | S=1.0000
# [Var-Corr]  K=40
#   MSE = 0.063940 | Δ = -0.000147 | Δ% = -0.23%
#   MAE = 0.184521 | Δ = -0.000407 | Δ% = -0.22%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE : 0.063793
# Ensemble mean MSE : 0.063940
# Average Δ MSE     : -0.000147
# Average Δ MSE (%) : -0.23%
#
# Vanilla  mean MAE : 0.184114
# Ensemble mean MAE : 0.184521
# Average Δ MAE     : -0.000407
# Average Δ MAE (%) : -0.22%

# %% [markdown]
# ## 1E->1E

# %%
results1_ETTm2_test['ES']['mae_test_EES']
# Out:
# 0.18411366641521454

# %%
import torch, os, numpy as np
from torch.utils.data import DataLoader, TensorDataset

TOP_K    = 65
CH_CNT   = 1
batch_sz = 32

def infer_one(model, loader, ch):
    buf = []
    model.eval()
    with torch.no_grad():
        for xb, yb, pv in loader:
            xb, pv = xb.to(device), pv.to(device)
            buf.append(model(xb, pv)[:, :, ch].cpu())   
    return torch.cat(buf, 0)    



van_mse_list, ens_mse_list, delta_mse_list, delta_mse_pct_list = [], [], [], []
van_mae_list, ens_mae_list, delta_mae_list, delta_mae_pct_list = [], [], [], []





for ch in range(CH_CNT):

    print(f"\n=== Channel {ch} ===")

    
    v_mse = results1_ETTm2_test['ES']['mse_test_EES']
    v_mae = results1_ETTm2_test['ES']['mae_test_EES']

    print(f"[Vanilla]   MSE : {v_mse:.6f} | MAE : {v_mae:.6f}")

    van_mse_list.append(v_mse)
    van_mae_list.append(v_mae)

    preds_test_arr = []
    ok_segs = []

    
    
    
    for seg in top_seg_idx_E1_val_1E[ch][:TOP_K]:

        ckpt = f"./model2_ETTm2_E1_1E/seg{seg}/ch{ch}/checkpoint.pth"
        if not os.path.exists(ckpt):
            print(f"  [skip] missing checkpoint : seg{seg}")
            continue

        mdl = Model(base_cfg).to(device)
        mdl.load_state_dict(torch.load(ckpt, map_location=device))

        pv_seg = test_pred_segments_E1[:, seg, :, :]
        dl = DataLoader(
            TensorDataset(test_sequences, test_labels, pv_seg),
            batch_size=batch_sz, shuffle=False
        )

        preds_test_arr.append(infer_one(mdl, dl, ch))
        ok_segs.append(seg)

    if len(preds_test_arr) < 5:
        print("  Not enough valid models.")
        continue

    
    
    
    step = 5
    Ks = list(range(step, len(preds_test_arr)+1, step))

    var_list = []
    rho_list = []

    for K in Ks:
        F = torch.stack(preds_test_arr[:K], dim=0)   

        
        V = torch.var(F, dim=0).mean().item()
        var_list.append(V)

        
        flat = F.reshape(K, -1).numpy()
        corr = np.corrcoef(flat)
        R    = np.mean(np.abs(corr[np.triu_indices(K, 1)]))
        rho_list.append(R)

    
    
    
    V_min, V_max = min(var_list), max(var_list)
    R_min, R_max = min(rho_list), max(rho_list)

    V_norm = [(v - V_min) / (V_max - V_min + 1e-12) for v in var_list]
    R_norm = [(r - R_min) / (R_max - R_min + 1e-12) for r in rho_list]

    alpha, beta = 1, 1.1   

    scores = [alpha*v + beta*r for v, r in zip(V_norm, R_norm)]
    best_K = Ks[int(np.argmin(scores))]

    
    
    
    print("  — Var / |Corr| / Score —")
    for k, v, r, s in zip(Ks, var_list, rho_list, scores):
        tag = "<- pick" if k == best_K else ""
        print(f"   K={k:2d} | Var={v:.3e} | |ρ|={r:.4f} | S={s:.4f} {tag}")

    
    
    
    ens_pred = torch.mean(torch.stack(preds_test_arr[:best_K]), dim=0)  
    y_true   = test_labels[:, -base_cfg.pred_len:, ch].cpu()

    mse_ens = torch.mean((ens_pred - y_true)**2).item()
    mae_ens = torch.mean(torch.abs(ens_pred - y_true)).item()

    ens_mse_list.append(mse_ens)
    ens_mae_list.append(mae_ens)

    
    delta_mse = v_mse - mse_ens
    delta_mae = v_mae - mae_ens

    
    delta_mse_pct = (delta_mse / v_mse) * 100
    delta_mae_pct = (delta_mae / v_mae) * 100

    delta_mse_list.append(delta_mse)
    delta_mae_list.append(delta_mae)
    delta_mse_pct_list.append(delta_mse_pct)
    delta_mae_pct_list.append(delta_mae_pct)

    sign = "+" if delta_mse > 0 else "-"
    print(f"[Var-Corr]  K={best_K}")
    print(f"   MSE = {mse_ens:.6f} | Δ = {delta_mse:+.6f} | Δ% = {delta_mse_pct:+.2f}%")
    print(f"   MAE = {mae_ens:.6f} | Δ = {delta_mae:+.6f} | Δ% = {delta_mae_pct:+.2f}%")





if ens_mse_list:
    print("\n──────── Summary (Var-Corr) ───────")
    print(f"Vanilla  mean MSE  : {np.mean(van_mse_list):.6f}")
    print(f"Ensemble mean MSE  : {np.mean(ens_mse_list):.6f}")
    print(f"Average Δ MSE      : {np.mean(delta_mse_list):+.6f}")
    print(f"Average Δ MSE (%)  : {np.mean(delta_mse_pct_list):+.2f}%\n")

    print(f"Vanilla  mean MAE  : {np.mean(van_mae_list):.6f}")
    print(f"Ensemble mean MAE  : {np.mean(ens_mae_list):.6f}")
    print(f"Average Δ MAE      : {np.mean(delta_mae_list):+.6f}")
    print(f"Average Δ MAE (%)  : {np.mean(delta_mae_pct_list):+.2f}%")
# Out:
# === Channel 0 ===
# [Vanilla]   MSE : 0.063793 | MAE : 0.184114
#   — Var / |Corr| / Score —
#    K= 5 | Var=2.593e-03 | |ρ|=0.9935 | S=1.1000
#    K=10 | Var=3.180e-03 | |ρ|=0.9916 | S=1.0183
#    K=15 | Var=3.531e-03 | |ρ|=0.9912 | S=1.0387
#    K=20 | Var=3.966e-03 | |ρ|=0.9902 | S=1.0169
#    K=25 | Var=4.212e-03 | |ρ|=0.9897 | S=1.0063
#    K=30 | Var=4.610e-03 | |ρ|=0.9894 | S=1.0470
#    K=35 | Var=5.002e-03 | |ρ|=0.9882 | S=1.0019
#    K=40 | Var=5.396e-03 | |ρ|=0.9871 | S=0.9588
#    K=45 | Var=5.771e-03 | |ρ|=0.9862 | S=0.9400 <- pick
#    K=50 | Var=6.190e-03 | |ρ|=0.9859 | S=0.9852
#    K=55 | Var=6.608e-03 | |ρ|=0.9847 | S=0.9444
#    K=60 | Var=7.166e-03 | |ρ|=0.9839 | S=0.9630
#    K=65 | Var=8.255e-03 | |ρ|=0.9824 | S=1.0000
# [Var-Corr]  K=45
#    MSE = 0.063957 | Δ = -0.000164 | Δ% = -0.26%
#    MAE = 0.184319 | Δ = -0.000205 | Δ% = -0.11%
#
# ──────── Summary (Var-Corr) ───────
# Vanilla  mean MSE  : 0.063793
# Ensemble mean MSE  : 0.063957
# Average Δ MSE      : -0.000164
# Average Δ MSE (%)  : -0.26%
#
# Vanilla  mean MAE  : 0.184114
# Ensemble mean MAE  : 0.184319
# Average Δ MAE      : -0.000205
# Average Δ MAE (%)  : -0.11%
